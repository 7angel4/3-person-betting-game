# %%
# %run 'game1_global.ipynb'
# %run 'game1_loser_analysis.ipynb'

# %% [markdown]
# # When is player 1 better off giving away $1?

# %%
betterGiving1 = findBetterGiving1(1,1000)
betterGiving1

# %%
exportStateProbs(DATA_DIR + 'game1_better_giving_1_memo_1-1000.csv', betterGiving1)

# %%
# retrieve probabilities from file
betterGiving1, given1 = readApproxBetterGiving1Probs(DATA_DIR + 'game1_better_giving_1_memo_1-100.csv')

# %%
betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
                                       filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv')
# Out:
# Approximating hitting prob for (11, 19, 48)
# (11, 19, 48): 0.5334260883826906
# (10, 19, 48): 0.5333426632228018
#
# Approximating hitting prob for (12, 21, 53)
# (12, 21, 53): 0.5340626283748265
# (11, 21, 53): 0.5334548685835285
#
# Approximating hitting prob for (12, 32, 42)
# (12, 32, 42): 0.5301153617677242
# (11, 32, 42): 0.5299467192997049
#
# Approximating hitting prob for (13, 22, 56)
# (13, 22, 56): 0.5328628830327213
# (12, 22, 56): 0.532734806781722
#
# Approximating hitting prob for (13, 23, 58)
# (13, 23, 58): 0.5343093271797525
# (12, 23, 58): 0.5335330764863161
#
# Approximating hitting prob for (13, 35, 46)
# (13, 35, 46): 0.5303291922468697
# (12, 35, 46): 0.5299937351500015
#
# Approximating hitting prob for (14, 24, 61)
# (14, 24, 61): 0.5334281050874531
# (13, 24, 61): 0.532844623278078
#
# Approximating hitting prob for (14, 25, 63)
# (14, 25, 63): 0.534598505539718
# (13, 25, 63): 0.5335740856592848
#
# Approximating hitting prob for (14, 38, 50)
# (14, 38, 50): 0.5306453312687435
# (13, 38, 50): 0.5300535494230575
#
# Approximating hitting prob for (15, 26, 66)
# (15, 26, 66): 0.5335384252806683
# (14, 26, 66): 0.532976559038264
#
# Approximating hitting prob for (15, 27, 68)
# (15, 27, 68): 0.5347937376379311
# (14, 27, 68): 0.5336038259570041
#
# Approximating hitting prob for (15, 40, 52)
# (15, 40, 52): 0.5298390830172897
# (14, 40, 52): 0.5294060634902246
#
# Approximating hitting prob for (15, 41, 54)
# (15, 41, 54): 0.530814252978444
# (14, 41, 54): 0.5300859465232839
#
# Approximating hitting prob for (16, 27, 69)
# (16, 27, 69): 0.5327214805171471
# (15, 27, 69): 0.5323471322790065
#
# Approximating hitting prob for (16, 28, 71)
# (16, 28, 71): 0.533984832978568
# (15, 28, 71): 0.5330636314503749
#
# Approximating hitting prob for (16, 29, 73)
# (16, 29, 73): 0.5349109988994238
# (15, 29, 73): 0.5336260136575318
#
# Approximating hitting prob for (16, 42, 54)
# (16, 42, 54): 0.528455476635441
# (15, 42, 54): 0.5285157285081951
#
# Approximating hitting prob for (16, 43, 56)
# (16, 43, 56): 0.5300165256608894
# (15, 43, 56): 0.5295344851774494
#
# Approximating hitting prob for (16, 44, 58)
# (16, 44, 58): 0.5309755142180325
# (15, 44, 58): 0.5301059314171186
#
# Approximating hitting prob for (17, 29, 74)
# (17, 29, 74): 0.5332717628242919
# (16, 29, 74): 0.5324865172144486
#
# Approximating hitting prob for (17, 30, 76)
# (17, 30, 76): 0.5341834675713876
# (16, 30, 76): 0.5331293350131605
#
# Approximating hitting prob for (17, 31, 78)
# (17, 31, 78): 0.535032026741298
# (16, 31, 78): 0.5336384909534596
#
# Approximating hitting prob for (17, 44, 56)
# (17, 44, 56): 0.5279972266134371
# (16, 44, 56): 0.5279422800090446
#
# Approximating hitting prob for (17, 45, 58)
# (17, 45, 58): 0.529004914693246
# (16, 45, 58): 0.528895160602941
#
# Approximating hitting prob for (17, 46, 60)
# (17, 46, 60): 0.5301804342251579
# (16, 46, 60): 0.5296194711867167
#
# Approximating hitting prob for (17, 47, 62)
# (17, 47, 62): 0.5311378673662993
# (16, 47, 62): 0.5301263625686753
#
# Approximating hitting prob for (18, 27, 71)
# (18, 27, 71): 0.525620501017532
# (17, 27, 71): 0.5254981980685945
#
# Approximating hitting prob for (18, 28, 73)
# (18, 28, 73): 0.5271004988262395
# (17, 28, 73): 0.5270411065910542
#
# Approximating hitting prob for (18, 31, 79)
# (18, 31, 79): 0.5335270635741508
# (17, 31, 79): 0.5326072076759126
#
# Approximating hitting prob for (18, 32, 81)
# (18, 32, 81): 0.5344121912790228
# (17, 32, 81): 0.5332080138741222
#
# Approximating hitting prob for (18, 33, 83)
# (18, 33, 83): 0.5351589143653502
# (17, 33, 83): 0.5336649245359243
#
# Approximating hitting prob for (18, 45, 56)
# (18, 45, 56): 0.5255722330999105
# (17, 45, 56): 0.5254786841463105
#
# Approximating hitting prob for (18, 47, 60)
# (18, 47, 60): 0.5284828625145415
# (17, 47, 60): 0.5281888889502253
#
# Approximating hitting prob for (18, 48, 62)
# (18, 48, 62): 0.5294526933438758
# (17, 48, 62): 0.5290045013080626
#
# Approximating hitting prob for (18, 49, 64)
# (18, 49, 64): 0.5304295920255223
# (17, 49, 64): 0.5297020995866109
#
# Approximating hitting prob for (18, 50, 66)
# (18, 50, 66): 0.5312826982045813
# (17, 50, 66): 0.5301457096165415
#
# Approximating hitting prob for (19, 20, 58)
# (19, 20, 58): 0.5076781471384154
# (18, 20, 58): 0.507459734940809
#
# Approximating hitting prob for (19, 32, 82)
# (19, 32, 82): 0.5327246501234508
# (18, 32, 82): 0.5320769507714677
#
# Approximating hitting prob for (19, 33, 84)
# (19, 33, 84): 0.5335489429772609
# (18, 33, 84): 0.532734806781722
#
# Approximating hitting prob for (19, 34, 86)
# (19, 34, 86): 0.5345634156030413
# (18, 34, 86): 0.5332648124986303
#
# Approximating hitting prob for (19, 35, 88)
# (19, 35, 88): 0.5345634156030413
# (18, 35, 88): 0.5332648124986303
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/659592125.py:18, in stricterFilter(candidates, timeLim, t, printOnGo, filename, continueFrom)
#      17 try:
# ---> 18     pLarge = LoserAnalysis(sLarge).getHittingProb()  # exact probs
#      19     pSmall = LoserAnalysis(sSmall).getHittingProb()
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:68, in LoserAnalysis.getHittingProb(self, asFloat, approx, t)
#      66     return Q(x, y, z, t)
# ---> 68 sol = self.solveEqns()
#      69 if sol:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:46, in LoserAnalysis.solveEqns(self, asFloat)
#      45 self.getEquations()
# ---> 46 sol = solve(self.equations, self.symbols)
#      47 return {s:float(p) for s, p in sol.items() if sol} if asFloat else sol
#
# File /usr/local/lib/python3.9/site-packages/sympy/solvers/solvers.py:1147, in solve(f, *symbols, **flags)
#    1146 else:
# -> 1147     linear, solution = _solve_system(f, symbols, **flags)
#    1148 assert type(solution) is list
#
# File /usr/local/lib/python3.9/site-packages/sympy/solvers/solvers.py:1799, in _solve_system(exprs, symbols, **flags)
#    1797     continue
# -> 1799 poly = g.as_poly(*symbols, extension=True)
#    1801 if poly is not None:
#
# File /usr/local/lib/python3.9/site-packages/sympy/core/expr.py:1102, in Expr.as_poly(self, *gens, **args)
#    1101 try:
# -> 1102     poly = Poly(self, *gens, **args)
#    1104     if not poly.is_Poly:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:182, in Poly.__new__(cls, rep, *gens, **args)
#     181 else:
# --> 182     return cls._from_expr(rep, opt)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:312, in Poly._from_expr(cls, rep, opt)
#     311 rep, opt = _dict_from_expr(rep, opt)
# --> 312 return cls._from_dict(rep, opt)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:261, in Poly._from_dict(cls, rep, opt)
#     259         rep[monom] = domain.convert(coeff)
# --> 261 return cls.new(DMP.from_dict(rep, level, domain), *gens)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polyclasses.py:279, in DMP.from_dict(cls, rep, lev, dom)
#     278 """Construct and instance of ``cls`` from a ``dict`` representation. """
# --> 279 return cls(dmp_from_dict(rep, lev, dom), dom, lev)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
#     [... skipping similar frames: dmp_from_dict at line 1012 (2958 times)]
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:998, in dmp_from_dict(f, u, K)
#     996 coeffs = {}
# --> 998 for monom, coeff in f.items():
#     999     head, tail = monom[0], monom[1:]
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# TimeoutException                          Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
#       2                                        filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv')
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/659592125.py:23, in stricterFilter(candidates, timeLim, t, printOnGo, filename, continueFrom)
#      21 except (TimeoutException, RecursionError):
#      22     print(f'Approximating hitting prob for {sLarge}')
# ---> 23     pLarge = LoserAnalysis(sLarge).getHittingProb(approx=True, t=t)
#      24     pSmall = LoserAnalysis(sSmall).getHittingProb(approx=True, t=t)
#      26 finally:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:66, in LoserAnalysis.getHittingProb(self, asFloat, approx, t)
#      64 if approx:
#      65     x, y, z = self.initState
# ---> 66     return Q(x, y, z, t)
#      68 sol = self.solveEqns()
#      69 if sol:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:31, in Q(x, y, z, t)
#      29 if x==0: return 1
#      30 if z*y==0: return 0
# ---> 31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
#      33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:31, in Q(x, y, z, t)
#      29 if x==0: return 1
#      30 if z*y==0: return 0
# ---> 31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
#      33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
#     [... skipping similar frames: memoize.<locals>.memodict.__call__ at line 8 (11 times), <genexpr> at line 33 (10 times), Q at line 33 (10 times), memoize.<locals>.memodict.__missing__ at line 11 (10 times)]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2027475117.py:12, in sigalarmHandler(signum, frame)
#       8 """
#       9 Handler function to be called when SIGALRM is received.
#      10 """
#      11 # We get signal!
# ---> 12 raise TimeoutException()
#
# TimeoutException:

# %%
betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
                                       filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv',
                                       continueFrom=(69,64,100))
# Out:
# Approximating hitting prob for (70, 12, 93)
# (70, 12, 93): 0.27064890356707977
# (69, 12, 93): 0.2704508979612977
#
# Approximating hitting prob for (70, 13, 95)
# (70, 13, 95): 0.273002814385276
# (69, 13, 95): 0.2728333555110289
#
# Approximating hitting prob for (70, 15, 99)
# (70, 15, 99): 0.2777183843625525
# (69, 15, 99): 0.27732957441332723
#
# Approximating hitting prob for (70, 30, 84)
# (70, 30, 84): 0.2928672871530125
# (69, 30, 84): 0.29290071879804375
#
# Approximating hitting prob for (70, 50, 94)
# (70, 50, 94): 0.32695735265836573
# (69, 50, 94): 0.3267132634013896
#
# Approximating hitting prob for (70, 58, 98)
# (70, 58, 98): 0.3430616778838396
# (69, 58, 98): 0.3428394039934912
#
# Approximating hitting prob for (70, 60, 99)
# (70, 60, 99): 0.34560612414415176
# (69, 60, 99): 0.34492499438010804
#
# Approximating hitting prob for (70, 84, 90)
# (70, 84, 90): 0.4148018936715927
# (69, 84, 90): 0.41468720846314083
#
# Approximating hitting prob for (71, 12, 94)
# (71, 12, 94): 0.27043453644878807
# (70, 12, 94): 0.2702550831661171
#
# Approximating hitting prob for (71, 15, 100)
# (71, 15, 100): 0.2774240055525448
# (70, 15, 100): 0.27714908068396565
#
# Approximating hitting prob for (71, 36, 88)
# (71, 36, 88): 0.3107284046458855
# (70, 36, 88): 0.3107029569244443
#
# Approximating hitting prob for (71, 44, 92)
# (71, 44, 92): 0.31946810865446534
# (70, 44, 92): 0.31933447137280896
#
# Approximating hitting prob for (71, 52, 96)
# (71, 52, 96): 0.3287350571698488
# (70, 52, 96): 0.32848900976647166
#
# Approximating hitting prob for (71, 60, 100)
# (71, 60, 100): 0.3432269284144038
# (70, 60, 100): 0.3428263666917539
#
# Approximating hitting prob for (72, 14, 99)
# (72, 14, 99): 0.27369224353294386
# (71, 14, 99): 0.27347335165357634
#
# Approximating hitting prob for (72, 40, 91)
# (72, 40, 91): 0.3129742549703007
# (71, 40, 91): 0.31282979281170153
#
# Approximating hitting prob for (72, 46, 94)
# (72, 46, 94): 0.32065055730266634
# (71, 46, 94): 0.32060860453920875
#
# Approximating hitting prob for (72, 50, 96)
# (72, 50, 96): 0.32548552599084296
# (71, 50, 96): 0.32522123422559995
#
# Approximating hitting prob for (72, 54, 98)
# (72, 54, 98): 0.33015250293768666
# (71, 54, 98): 0.3299310590778092
#
# Approximating hitting prob for (73, 11, 94)
# (73, 11, 94): 0.26568088778907833
# (72, 11, 94): 0.26555372470314254
#
# Approximating hitting prob for (73, 13, 98)
# (73, 13, 98): 0.2712824779940791
# (72, 13, 98): 0.27092732614422377
#
# Approximating hitting prob for (73, 14, 100)
# (73, 14, 100): 0.2735392177539206
# (72, 14, 100): 0.2733296833190661
#
# Approximating hitting prob for (73, 26, 85)
# (73, 26, 85): 0.2838182327188731
# (72, 26, 85): 0.2838382526274032
#
# Approximating hitting prob for (73, 40, 92)
# (73, 40, 92): 0.31265646156970867
# (72, 40, 92): 0.31256600858492634
#
# Approximating hitting prob for (73, 44, 94)
# (73, 44, 94): 0.31905281367702304
# (72, 44, 94): 0.31898130581150774
#
# Approximating hitting prob for (74, 12, 97)
# (74, 12, 97): 0.26803823241416097
# (73, 12, 97): 0.2678146488650772
#
# Approximating hitting prob for (74, 13, 99)
# (74, 13, 99): 0.27106341315623816
# (73, 13, 99): 0.2708043750088058
#
# Approximating hitting prob for (74, 30, 88)
# (74, 30, 88): 0.29121346643802504
# (73, 30, 88): 0.2911904861374854
#
# Approximating hitting prob for (74, 40, 93)
# (74, 40, 93): 0.3124715276947375
# (73, 40, 93): 0.3123265733297223
#
# Approximating hitting prob for (74, 46, 96)
# (74, 46, 96): 0.3194592906289733
# (73, 46, 96): 0.31936096416339166
#
# Approximating hitting prob for (74, 52, 99)
# (74, 52, 99): 0.32609715069378836
# (73, 52, 99): 0.32593271890358366
#
# Approximating hitting prob for (74, 54, 100)
# (74, 54, 100): 0.3285392810102394
# (73, 54, 100): 0.32834877261967127
#
# Approximating hitting prob for (75, 13, 100)
# (75, 13, 100): 0.2708561821230972
# (74, 13, 100): 0.27060467983388525
#
# Approximating hitting prob for (75, 38, 93)
# (75, 38, 93): 0.3107255922584125
# (74, 38, 93): 0.3106856959891582
#
# Approximating hitting prob for (75, 40, 94)
# (75, 40, 94): 0.31219750777533284
# (74, 40, 94): 0.31212211416489793
#
# Approximating hitting prob for (75, 48, 98)
# (75, 48, 98): 0.3206660566987458
# (74, 48, 98): 0.3206193374288369
#
# Approximating hitting prob for (75, 52, 100)
# (75, 52, 100): 0.32543894655115896
# (74, 52, 100): 0.3251891291627604
#
# Approximating hitting prob for (76, 42, 96)
# (76, 42, 96): 0.31283229353690856
# (75, 42, 96): 0.31269685409230785
#
# Approximating hitting prob for (77, 42, 97)
# (77, 42, 97): 0.31263411481005815
# (76, 42, 97): 0.3124896740010894
#
# Approximating hitting prob for (78, 42, 98)
# (78, 42, 98): 0.312441399741017
# (77, 42, 98): 0.3119828040723916
#
# Approximating hitting prob for (79, 32, 94)
# (79, 32, 94): 0.2912337154122105
# (78, 32, 94): 0.2911642829888588
#
# Approximating hitting prob for (79, 40, 98)
# (79, 40, 98): 0.31073467566545016
# (78, 40, 98): 0.31068391480047436
#
# Approximating hitting prob for (79, 42, 99)
# (79, 42, 99): 0.3121670959474713
# (78, 42, 99): 0.3120607193357822
#
# Approximating hitting prob for (79, 44, 100)
# (79, 44, 100): 0.3130463381703828
# (78, 44, 100): 0.3128490513416133
#
# Approximating hitting prob for (82, 34, 98)
# (82, 34, 98): 0.2917812876569657
# (81, 34, 98): 0.29172992113254753
#
# Approximating hitting prob for (84, 30, 98)
# (84, 30, 98): 0.2839368557613289
# (83, 30, 98): 0.2838357734914572
#
# Approximating hitting prob for (84, 34, 100)
# (84, 34, 100): 0.29123192191006453
# (83, 34, 100): 0.2911447291167216
#
# Approximating hitting prob for (93, 47, 62)
# (93, 47, 62): 0.2078449082948937
# (92, 47, 62): 0.20783817692579917
#
# Approximating hitting prob for (93, 47, 98)
# (93, 47, 98): 0.3020413154785515
# (92, 47, 98): 0.3020379983481061
#
# Approximating hitting prob for (95, 48, 100)
# (95, 48, 100): 0.30201302025080573
# (94, 48, 100): 0.30196433138324996
#
# Approximating hitting prob for (99, 50, 66)
# (99, 50, 66): 0.2078419114332157
# (98, 50, 66): 0.2078180397808808
#
# Approximating hitting prob for (100, 51, 67)
# (100, 51, 67): 0.2080190772886974
# (99, 51, 67): 0.20801576587712575

# %%
class TimeoutException(Exception):
    """
    Custom exception for timeout.
    """
    pass

def sigalarmHandler(signum, frame):
    """
    Handler function to be called when SIGALRM is received.
    """
    # We get signal!
    raise TimeoutException()

# %% [markdown]
# ## When is player 1 better off giving away $1 to another player?

# %%
betterGiving1ToAnother = findBetterGiving1(1,100, t=10, giveToAnother=True)
betterGiving1ToAnother
# Out:
# {(1, 5, 5): 0.5004434876119833,
#  (2, 4, 5): 0.5015168645690443,
#  (1, 6, 6): 0.506093654740131,
#  (2, 5, 6): 0.5184847144955884,
#  (1, 7, 7): 0.5131205254322682,
#  (2, 6, 7): 0.5396071019936831,
#  (1, 8, 8): 0.5177187986883774,
#  (2, 7, 8): 0.553386673567715,
#  (1, 9, 9): 0.5198030383135193,
#  (2, 8, 9): 0.5596511014686955,
#  (1, 10, 10): 0.521353326527545,
#  (2, 9, 10): 0.5643071756348541,
#  (1, 11, 11): 0.5225738105217701,
#  (2, 10, 11): 0.5679767313216567,
#  (1, 12, 12): 0.5237380978085997,
#  (2, 11, 12): 0.5714793837797846,
#  (1, 12, 36): 0.6316713165390184,
#  (2, 11, 36): 0.6317622599451304,
#  (1, 13, 13): 0.5248276325593998,
#  (2, 12, 13): 0.5747622273980084,
#  (1, 13, 39): 0.6325682808186844,
#  (2, 12, 39): 0.6347403712118326,
#  (1, 14, 14): 0.5256858644409728,
#  (2, 13, 14): 0.57733900685236,
#  (1, 14, 42): 0.6333982655030145,
#  (2, 13, 42): 0.6366529115385103,
#  (1, 15, 15): 0.5268432387720368,
#  (2, 14, 15): 0.5808387485922709,
#  (1, 15, 45): 0.63421194355006,
#  (2, 14, 45): 0.6395029512036614,
#  (1, 16, 16): 0.5279858610539553,
#  (2, 15, 16): 0.5842379051719758,
#  (1, 16, 48): 0.635051999980948,
#  (2, 15, 48): 0.6419747628823096,
#  (1, 17, 17): 0.5283821156475977,
#  (2, 16, 17): 0.5854285708426477,
#  (1, 17, 51): 0.6353974162348219,
#  (2, 16, 51): 0.6431331129655032,
#  (1, 18, 18): 0.5286972339709394,
#  (2, 17, 18): 0.586367542078401,
#  (1, 18, 54): 0.635696343688081,
#  (2, 17, 54): 0.6438519942124338,
#  (1, 19, 19): 0.5290239620908059,
#  (2, 18, 19): 0.5873462049262054,
#  (1, 19, 57): 0.6359734242165406,
#  (2, 18, 57): 0.644798126476528,
#  (1, 20, 20): 0.5292680655049197,
#  (2, 19, 20): 0.5880847500592729,
#  (1, 20, 60): 0.6362249863460855,
#  (2, 19, 60): 0.6453717860378668,
#  (1, 21, 21): 0.5295149142555335,
#  (2, 20, 21): 0.588833317324383,
#  (1, 21, 63): 0.6364634998581686,
#  (2, 20, 63): 0.6461849514015902,
#  (1, 21, 64): 0.646956969794154,
#  (2, 20, 64): 0.6472510681012803,
#  (1, 22, 22): 0.5297588522879303,
#  (2, 21, 22): 0.5895697621096462,
#  (1, 22, 66): 0.6366529446148538,
#  (2, 21, 66): 0.6466174245912294,
#  (1, 22, 67): 0.6471532117394029,
#  (2, 21, 67): 0.647774501235203,
#  (1, 23, 23): 0.5299781484445122,
#  (2, 22, 23): 0.5902254013880421,
#  (1, 23, 69): 0.6368433485854967,
#  (2, 22, 69): 0.6472793649130383,
#  (1, 23, 70): 0.647343764553591,
#  (2, 22, 70): 0.6483569921802232,
#  (1, 24, 24): 0.5301334749530051,
#  (2, 23, 24): 0.5907054714357991,
#  (1, 24, 72): 0.6370145682769819,
#  (2, 23, 72): 0.6476786129157565,
#  (1, 24, 73): 0.6475028948415723,
#  (2, 23, 73): 0.6487869019532507,
#  (1, 25, 25): 0.5303300145853443,
#  (2, 24, 25): 0.5913062701368778,
#  (1, 25, 75): 0.6371719124424207,
#  (2, 24, 75): 0.6482151442816559,
#  (1, 25, 76): 0.6476655808364664,
#  (2, 24, 76): 0.6492909523499552,
#  (1, 26, 26): 0.5305056830450136,
#  (2, 25, 26): 0.5918398411700453,
#  (1, 26, 78): 0.6373261970460974,
#  (2, 25, 78): 0.6485752629701603,
#  (1, 26, 79): 0.6478181289321158,
#  (2, 25, 79): 0.6496998090304239,
#  (1, 27, 27): 0.5306651440964284,
#  (2, 26, 27): 0.5923164712780911,
#  (1, 27, 81): 0.6374779182331624,
#  (2, 26, 81): 0.6491023179636827,
#  (1, 27, 82): 0.6479675843896594,
#  (2, 26, 82): 0.6501630597575742,
#  (1, 28, 28): 0.5308433925108808,
#  (2, 27, 28): 0.5928632397722654,
#  (1, 28, 84): 0.6376227926171485,
#  (2, 27, 84): 0.6494288807018324,
#  (1, 28, 85): 0.6481137818273807,
#  (2, 27, 85): 0.6505545513577707,
#  (1, 29, 29): 0.531019424810327,
#  (2, 28, 29): 0.593397753481219,
#  (1, 29, 87): 0.6377697342725956,
#  (2, 28, 87): 0.6499273246583346,
#  (1, 29, 88): 0.6482600123414454,
#  (2, 28, 88): 0.651006837277092,
#  (1, 30, 30): 0.5311653907136445,
#  (2, 29, 30): 0.5938409764824553,
#  (1, 30, 90): 0.6379076957008163,
#  (2, 29, 90): 0.650248810177776,
#  (1, 30, 91): 0.6483932438525631,
#  (2, 29, 91): 0.6513514100842097,
#  (1, 31, 31): 0.5313585565589595,
#  (2, 30, 31): 0.5944358379798981,
#  (1, 31, 93): 0.6380471455644888,
#  (2, 30, 93): 0.6507426069080341,
#  (1, 31, 94): 0.6485374236333384,
#  (2, 30, 94): 0.6518048371373775,
#  (1, 32, 32): 0.5316609404901015,
#  (2, 31, 32): 0.5953108064912191,
#  (1, 32, 96): 0.6382585695513472,
#  (2, 31, 96): 0.651341801406459,
#  (1, 32, 97): 0.6487406281488678,
#  (2, 31, 97): 0.6524211817198429,
#  (1, 33, 33): 0.5317385375916611,
#  (2, 32, 33): 0.5955452681512389,
#  (1, 33, 99): 0.6383231014972734,
#  (2, 32, 99): 0.6515462628230367,
#  (1, 33, 100): 0.6488068966028214,
#  (2, 32, 100): 0.6526188624860286,
#  (1, 34, 34): 0.5318062779428949,
#  (2, 33, 34): 0.5957485718957984,
#  (1, 35, 35): 0.5318679983996342,
#  (2, 34, 35): 0.5959310706203745,
#  (1, 36, 36): 0.5319251873973311,
#  (2, 35, 36): 0.5961088063515048,
#  (1, 37, 37): 0.5319769849510576,
#  (2, 36, 37): 0.5962632397987264,
#  (1, 38, 38): 0.5320250779543261,
#  (2, 37, 38): 0.5964045750139714,
#  (1, 39, 39): 0.5320778016456672,
#  (2, 38, 39): 0.5965617868740368,
#  (1, 40, 40): 0.5321167325018205,
#  (2, 39, 40): 0.5966842851117292,
#  (1, 41, 41): 0.5321571517934258,
#  (2, 40, 41): 0.5968058406736355,
#  (2, 14, 41): 0.6338000769223442,
#  (1, 42, 42): 0.5322013748645192,
#  (2, 41, 42): 0.5969399487078528,
#  (1, 43, 43): 0.5322408018658233,
#  (2, 42, 43): 0.5970633565449881,
#  (1, 44, 44): 0.5322755651027112,
#  (2, 43, 44): 0.5971704908211825,
#  (2, 15, 44): 0.6355654440591713,
#  (1, 45, 45): 0.5323146613405815,
#  (2, 44, 45): 0.5972896979627089,
#  (1, 46, 46): 0.5323509791656083,
#  (2, 45, 46): 0.5973977583765179,
#  (1, 47, 47): 0.532385014722942,
#  (2, 46, 47): 0.597498806605531,
#  (2, 16, 47): 0.6375855486545072,
#  (1, 48, 48): 0.5324148826610103,
#  (2, 47, 48): 0.5975902130804501,
#  (1, 49, 49): 0.5324444859883317,
#  (2, 48, 49): 0.5976821983913784,
#  (1, 50, 50): 0.5324711785974361,
#  (2, 49, 50): 0.5977623423713782,
#  (2, 17, 50): 0.6383571866691223,
#  (1, 51, 51): 0.5325028988107334,
#  (2, 50, 51): 0.5978603145004572,
#  (1, 52, 52): 0.5325307160155125,
#  (2, 51, 52): 0.597951109063024,
#  (1, 53, 53): 0.5325579709224543,
#  (2, 52, 53): 0.5980328572456773,
#  (2, 18, 53): 0.6393221393725973,
#  (1, 54, 54): 0.5325877396314925,
#  (2, 53, 54): 0.5981236683464157,
#  (1, 55, 55): 0.5326169460426934,
#  (2, 54, 55): 0.5982126271719249,
#  (1, 56, 56): 0.5326397687196227,
#  (2, 55, 56): 0.5982834436230927,
#  (2, 19, 56): 0.639912667869058,
#  (1, 57, 57): 0.5326706620243357,
#  (2, 56, 57): 0.5983790342554488,
#  (1, 58, 58): 0.5326991076796389,
#  (2, 57, 58): 0.5984666865653948,
#  (1, 59, 59): 0.5327241464715744,
#  (2, 58, 59): 0.5985425140825841,
#  (2, 20, 59): 0.6407575699842504,
#  (1, 60, 60): 0.5327515998365764,
#  (2, 59, 60): 0.5986312082973463,
#  (1, 60, 100): 0.6594202186690291,
#  (2, 59, 100): 0.6594714208485749,
#  (1, 61, 61): 0.5327806408660604,
#  (2, 60, 61): 0.5987212090276719,
#  (1, 62, 62): 0.5328041250698572,
#  (2, 61, 62): 0.5987947377389965,
#  (2, 21, 62): 0.6412867749400921,
#  (1, 63, 63): 0.5328350514509137,
#  (2, 62, 63): 0.5988899810697471,
#  (1, 64, 64): 0.5329295505639383,
#  (2, 63, 64): 0.5991591232757963,
#  (1, 65, 65): 0.5329439718496504,
#  (2, 64, 65): 0.5992017586824079,
#  (2, 22, 65): 0.6419519898198954,
#  (1, 66, 66): 0.5329563424020729,
#  (2, 65, 66): 0.5992384734235551,
#  (1, 67, 67): 0.5329692090996461,
#  (2, 66, 67): 0.5992765939092958,
#  (1, 68, 68): 0.5329786027811648,
#  (2, 67, 68): 0.5993086945005419,
#  (2, 23, 68): 0.6423572742552796,
#  (1, 69, 69): 0.5329891210583583,
#  (2, 68, 69): 0.5993394885762248,
#  (1, 70, 70): 0.5330002016333891,
#  (2, 69, 70): 0.5993723499233687,
#  (1, 71, 71): 0.5330110506740166,
#  (2, 70, 71): 0.5994039212931209,
#  (2, 24, 71): 0.6429282380946333,
#  (1, 72, 72): 0.5330189889964267,
#  (2, 71, 72): 0.5994280670237854,
#  (1, 73, 73): 0.5330284819069756,
#  (2, 72, 73): 0.5994564796027452,
#  (1, 74, 74): 0.5330374786723738,
#  (2, 73, 74): 0.599483089520991,
#  (2, 25, 74): 0.6432813280601704,
#  (1, 75, 75): 0.5330459131399347,
#  (2, 74, 75): 0.5995072187134837,
#  (1, 76, 76): 0.5330541822257785,
#  (2, 75, 76): 0.5995340767043049,
#  (1, 77, 77): 0.5330628151513997,
#  (2, 76, 77): 0.5995594131833307,
#  (2, 26, 77): 0.6438085649735813,
#  (1, 78, 78): 0.5330708527028399,
#  (2, 77, 78): 0.5995827154672391,
#  (1, 79, 79): 0.5330799817736117,
#  (2, 78, 79): 0.5996089284693644,
#  (1, 80, 80): 0.5330863985842266,
#  (2, 79, 80): 0.5996283608210977,
#  (2, 27, 80): 0.6441455136835509,
#  (1, 81, 81): 0.5330929477002151,
#  (2, 80, 81): 0.5996482893179816,
#  (1, 82, 82): 0.5331003237247879,
#  (2, 81, 82): 0.5996707812314773,
#  (1, 83, 83): 0.5331074682149571,
#  (2, 82, 83): 0.599691569713289,
#  (2, 28, 83): 0.6446484064082373,
#  (1, 84, 84): 0.5331135542621382,
#  (2, 83, 84): 0.5997103736144981,
#  (1, 85, 85): 0.5331207318286508,
#  (2, 84, 85): 0.5997354950972921,
#  (1, 86, 86): 0.5331267847994886,
#  (2, 85, 86): 0.5997556055140646,
#  (2, 29, 86): 0.6449977587469728,
#  (1, 87, 87): 0.5331327716176396,
#  (2, 86, 87): 0.5997733675104574,
#  (1, 88, 88): 0.5331386592067605,
#  (2, 87, 88): 0.599791989491778,
#  (1, 89, 89): 0.5331450098646887,
#  (2, 88, 89): 0.5998109256983607,
#  (2, 30, 89): 0.6454688981820182,
#  (1, 90, 90): 0.5331506328430625,
#  (2, 89, 90): 0.5998279269388559,
#  (1, 91, 91): 0.5331572150353944,
#  (2, 90, 91): 0.5998475412104778,
#  (1, 92, 92): 0.5331628049374249,
#  (2, 91, 92): 0.5998653528213856,
#  (2, 31, 92): 0.6457769216297059,
#  (1, 93, 93): 0.5331686925265458,
#  (2, 92, 93): 0.5998821225274772,
#  (1, 94, 94): 0.5331750431844738,
#  (2, 93, 94): 0.5999014225738369,
#  (1, 95, 95): 0.5331811953843418,
#  (2, 94, 95): 0.5999193995664617,
#  (2, 32, 95): 0.646300487069002,
#  (1, 96, 96): 0.5331852306982338,
#  (2, 95, 96): 0.599931571660824,
#  (1, 97, 97): 0.5331905890658605,
#  (2, 96, 97): 0.599948109832512,
#  (1, 98, 98): 0.5331949220668428,
#  (2, 97, 98): 0.5999628122671425,
#  (2, 33, 98): 0.6464613042504953,
#  (1, 99, 99): 0.5331994535258853,
#  (2, 98, 99): 0.59997640664427,
#  (2, 60, 99): 0.6594345241875391,
#  (1, 100, 100): 0.533204183442988,
#  (2, 99, 100): 0.5999915225331928,
#  (2, 6, 6): 0.4693452418753916,
#  (3, 5, 6): 0.4740014979614388,
#  (2, 7, 7): 0.48208386784704227,
#  (3, 6, 7): 0.4955659177124083,
#  (2, 8, 8): 0.49122878218725124,
#  (3, 7, 8): 0.5014666050652847,
#  (2, 9, 9): 0.494262775936087,
#  (3, 8, 9): 0.5178661041836018,
#  (2, 10, 10): 0.5004434876119833,
#  (3, 9, 10): 0.5342839937488357,
#  (2, 11, 11): 0.5025522368075666,
#  (3, 10, 11): 0.5431842258389219,
#  (2, 12, 12): 0.506093654740131,
#  (3, 11, 12): 0.5502830045015581,
#  (2, 13, 13): 0.5085600915129808,
#  (3, 12, 13): 0.5546173616138715,
#  (2, 14, 14): 0.5131205254322682,
#  (3, 13, 14): 0.5568134654323105,
#  (2, 15, 15): 0.5156899950147334,
#  (3, 14, 15): 0.5601744353735879,
#  (2, 16, 16): 0.5177187986883774,
#  (3, 15, 16): 0.5635269543091331,
#  (2, 17, 17): 0.5183972606437027,
#  (3, 16, 17): 0.5645428776577504,
#  (2, 18, 18): 0.5198030383135193,
#  (3, 17, 18): 0.5672856342031618,
#  (2, 19, 19): 0.5202042212823249,
#  (3, 18, 19): 0.5700392728655439,
#  (2, 20, 20): 0.521353326527545,
#  (3, 19, 20): 0.5708707459853257,
#  (2, 20, 60): 0.6295677107148301,
#  (3, 19, 60): 0.6304392723627834,
#  (2, 21, 21): 0.5216864383816829,
#  (3, 20, 21): 0.5735340366157767,
#  (2, 21, 63): 0.6301227813711917,
#  (3, 20, 63): 0.6311136824660452,
#  (2, 22, 22): 0.5225738105217701,
#  (3, 21, 22): 0.5764060555111009,
#  (2, 22, 66): 0.630719892059984,
#  (3, 21, 66): 0.6335248486691138,
#  (2, 23, 23): 0.5230437922847974,
#  (3, 22, 23): 0.5785014418639604,
#  (2, 23, 69): 0.6311993336572169,
#  (3, 22, 69): 0.6351912844629037,
#  (2, 23, 71): 0.641735372847127,
#  (3, 22, 71): 0.6419442003410304,
#  (2, 24, 24): 0.5237380978085997,
#  (3, 23, 24): 0.5800568899875528,
#  (2, 24, 72): 0.6316713165390184,
#  (3, 23, 72): 0.6362437075564361,
#  (2, 24, 74): 0.642247130031838,
#  (3, 23, 74): 0.6426527783069992,
#  (2, 25, 25): 0.524088839353757,
#  (3, 24, 25): 0.5809113180896375,
#  (2, 25, 75): 0.6320944621998256,
#  (3, 24, 75): 0.637120230655896,
#  (2, 25, 77): 0.6426200988797439,
#  (3, 24, 77): 0.6434655302164304,
#  (2, 26, 26): 0.5248276325593998,
#  (3, 25, 26): 0.5813076057596235,
#  (2, 26, 78): 0.6325682808186844,
#  (3, 25, 78): 0.6376919552511473,
#  (2, 26, 80): 0.6431372309702534,
#  (3, 25, 80): 0.6440306064666632,
#  (2, 27, 27): 0.5251138752349743,
#  (3, 26, 27): 0.582175396704432,
#  (2, 27, 81): 0.6329491879890007,
#  (3, 26, 81): 0.6380589868954174,
#  (2, 27, 83): 0.6434930993486342,
#  (3, 26, 83): 0.6444297387021796,
#  (2, 28, 28): 0.5256858644409728,
#  (3, 27, 28): 0.5828712072018578,
#  (2, 28, 84): 0.6333982655030145,
#  (3, 27, 84): 0.6388404320458433,
#  (2, 28, 86): 0.6439339408531474,
#  (3, 27, 86): 0.6451290222156598,
#  (2, 29, 29): 0.5261190653101662,
#  (3, 28, 29): 0.5831610717370319,
#  (2, 29, 87): 0.6337884340494758,
#  (3, 28, 87): 0.6392850773298446,
#  (2, 29, 88): 0.6449055088252976,
#  (3, 28, 88): 0.644998916418991,
#  (2, 29, 89): 0.6443102007972193,
#  (3, 28, 89): 0.6455973005470034,
#  (2, 30, 30): 0.5268432387720368,
#  (3, 29, 30): 0.5837543951845078,
#  (2, 30, 90): 0.63421194355006,
#  (3, 29, 90): 0.6395496715386797,
#  (2, 30, 92): 0.6447714007910802,
#  (3, 29, 92): 0.645899006413106,
#  (2, 31, 31): 0.5275615907974732,
#  (3, 30, 31): 0.5843650506359125,
#  (2, 31, 93): 0.6345886665629393,
#  (3, 30, 93): 0.640241909791021,
#  (2, 31, 94): 0.6457147711805027,
#  (3, 30, 94): 0.645921002181451,
#  (2, 31, 95): 0.6453186488922336,
#  (3, 30, 95): 0.6465264150324307,
#  (2, 32, 32): 0.5279858610539553,
#  (3, 31, 32): 0.5845853886973108,
#  (2, 32, 96): 0.635051999980948,
#  (3, 31, 96): 0.6406006558112753,
#  (2, 32, 97): 0.6461740362082762,
#  (3, 31, 97): 0.646306424272638,
#  (2, 32, 98): 0.645574742480821,
#  (3, 31, 98): 0.6468801499866637,
#  (2, 33, 33): 0.5281335800034718,
#  (3, 32, 33): 0.5851356798220545,
#  (2, 33, 99): 0.6352244269589663,
#  (3, 32, 99): 0.6407475974667225,
#  (2, 33, 100): 0.6463518546302647,
#  (3, 32, 100): 0.6464238949061373,
#  (2, 34, 34): 0.5283821156475977,
#  (3, 33, 34): 0.5857237441309336,
#  (2, 35, 35): 0.5284957328870937,
#  (3, 34, 35): 0.5859061105501363,
#  (2, 36, 36): 0.5286972339709394,
#  (3, 35, 36): 0.5863498462346949,
#  (2, 37, 37): 0.5288185579984419,
#  (3, 36, 37): 0.5868146350118123,
#  (2, 38, 38): 0.5290239620908059,
#  (3, 37, 38): 0.5870175583784231,
#  (2, 39, 39): 0.5291136651340412,
#  (3, 38, 39): 0.5874601198527918,
#  (2, 40, 40): 0.5292680655049197,
#  (3, 39, 40): 0.5879006636702145,
#  (2, 41, 41): 0.5293537993869498,
#  (3, 40, 41): 0.5880250307213077,
#  (2, 42, 42): 0.5295149142555335,
#  (3, 41, 42): 0.5884515170927959,
#  (2, 43, 43): 0.5296025334891361,
#  (3, 42, 43): 0.5889065483486172,
#  (2, 44, 44): 0.5297588522879303,
#  (3, 43, 44): 0.58904100368444,
#  (2, 45, 45): 0.5298143874684583,
#  (3, 44, 45): 0.5894975068375417,
#  (2, 46, 46): 0.5299781484445122,
#  (3, 45, 46): 0.5899698039446054,
#  (3, 45, 47): 0.5976479643759843,
#  (2, 47, 47): 0.5300331874798896,
#  (3, 46, 47): 0.5905717768558739,
#  (3, 46, 48): 0.5985042612914698,
#  (2, 48, 48): 0.5301334749530051,
#  (3, 47, 48): 0.5909074355884519,
#  (3, 47, 49): 0.5986030107146184,
#  (2, 49, 49): 0.5302022075945402,
#  (3, 48, 49): 0.5910961361274111,
#  (3, 48, 50): 0.5987849967558723,
#  (2, 50, 50): 0.5303300145853443,
#  (3, 49, 50): 0.5911701775220579,
#  (3, 49, 51): 0.5989254058335026,
#  (2, 51, 51): 0.530385152849752,
#  (3, 50, 51): 0.5913320862228827,
#  (3, 50, 52): 0.5990053844317854,
#  (2, 52, 52): 0.5305056830450136,
#  (3, 51, 52): 0.5914818062911734,
#  (3, 51, 53): 0.5991632908950618,
#  (2, 53, 53): 0.5305588367288184,
#  (3, 52, 53): 0.5915376556969635,
#  (3, 52, 54): 0.5992909986568359,
#  (2, 18, 54): 0.6281354554321411,
#  (3, 18, 53): 0.6282727553334942,
#  (2, 54, 54): 0.5306651440964284,
#  (3, 53, 54): 0.5916624692786923,
#  (3, 53, 55): 0.5993634193106573,
#  (2, 55, 55): 0.5307288160574269,
#  (3, 54, 55): 0.5918032587342715,
#  (3, 54, 56): 0.599478690367322,
#  (2, 56, 56): 0.5308433925108808,
#  (3, 55, 56): 0.5918555193568054,
#  (3, 55, 57): 0.5995967232986587,
#  (2, 19, 57): 0.6287977430555555,
#  (3, 19, 56): 0.6300712318900404,
#  (2, 57, 57): 0.5308984976989449,
#  (3, 56, 57): 0.5919839713363054,
#  (3, 56, 58): 0.5996486531577588,
#  (2, 58, 58): 0.531019424810327,
#  (3, 57, 58): 0.5921011938972294,
#  (3, 57, 59): 0.5997754843964335,
#  (2, 59, 59): 0.5310688408673304,
#  (3, 58, 59): 0.5921501799617691,
#  (3, 58, 60): 0.5998798898742993,
#  (3, 20, 59): 0.6308086193510897,
#  (2, 60, 60): 0.5311653907136445,
#  (3, 59, 60): 0.5922371045921607,
#  (3, 59, 61): 0.5999254359991278,
#  (2, 61, 61): 0.5312331972175651,
#  (3, 60, 61): 0.5923383678174059,
#  (3, 60, 62): 0.6000335791037951,
#  (2, 62, 62): 0.5313585565589595,
#  (3, 61, 62): 0.5923812182202493,
#  (3, 61, 63): 0.6001316835382479,
#  (3, 21, 62): 0.6330898947537215,
#  (2, 63, 63): 0.5315653498577452,
#  (3, 62, 63): 0.5925049402826467,
#  (3, 62, 64): 0.6001830180231672,
#  (2, 64, 64): 0.5316609404901015,
#  (3, 63, 64): 0.5925977525021593,
#  (3, 63, 65): 0.6002796836366832,
#  (2, 65, 65): 0.531690378435706,
#  (3, 64, 65): 0.592631788059493,
#  (3, 64, 66): 0.6003744142841115,
#  (3, 22, 65): 0.6346719031810446,
#  (2, 66, 66): 0.5317385375916611,
#  (3, 65, 66): 0.5927241372101983,
#  (3, 65, 67): 0.6004132789875781,
#  (2, 67, 67): 0.5317613271922471,
#  (3, 66, 67): 0.5928214643505817,
#  (3, 66, 68): 0.6005093823032567,
#  (2, 68, 68): 0.5318062779428949,
#  (3, 67, 68): 0.5928686808307507,
#  (3, 67, 69): 0.600597067689546,
#  (3, 23, 68): 0.6353617433984912,
#  (2, 69, 69): 0.5318268845048181,
#  (3, 68, 69): 0.5929494532612746,
#  (3, 68, 70): 0.6006299621130332,
#  (2, 70, 70): 0.5318679983996342,
#  (3, 69, 70): 0.5930456061914681,
#  (3, 69, 71): 0.6007228404852326,
#  (2, 71, 71): 0.5318853634799066,
#  (3, 70, 71): 0.5930765987252112,
#  (3, 70, 72): 0.6007995941400363,
#  (3, 24, 71): 0.6368715792445682,
#  (2, 72, 72): 0.5319251873973311,
#  (3, 71, 72): 0.5931494493714966,
#  (3, 71, 73): 0.600835432358084,
#  (2, 73, 73): 0.5319396086830429,
#  (3, 72, 73): 0.5932231434645379,
#  (3, 72, 74): 0.6009037846216702,
#  (2, 74, 74): 0.5319769849510576,
#  (3, 73, 74): 0.5932469749699402,
#  (3, 73, 75): 0.6009758414357144,
#  (3, 25, 74): 0.637481490478247,
#  (2, 75, 75): 0.5319899508776609,
#  (3, 74, 75): 0.5933288389197955,
#  (3, 74, 76): 0.600999127181451,
#  (2, 76, 76): 0.5320250779543261,
#  (3, 75, 76): 0.5934025495510085,
#  (3, 75, 77): 0.6010797838447729,
#  (2, 77, 77): 0.5320406899883995,
#  (3, 76, 77): 0.5934319544202696,
#  (3, 76, 78): 0.6011526014147149,
#  (3, 26, 77): 0.6378954574537672,
#  (2, 78, 78): 0.5320778016456672,
#  (3, 77, 78): 0.5934982559505665,
#  (3, 77, 79): 0.6011803855431506,
#  (2, 79, 79): 0.5320866991820353,
#  (3, 78, 79): 0.5935844198250606,
#  (3, 78, 80): 0.601249680482523,
#  (2, 80, 80): 0.5321167325018205,
#  (3, 79, 80): 0.5935997672483869,
#  (3, 79, 81): 0.6013253922325102,
#  (3, 27, 80): 0.6386029439004047,
#  (2, 81, 81): 0.5321278792295382,
#  (3, 80, 81): 0.5936775793461786,
#  (3, 80, 82): 0.6013561366936782,
#  (2, 82, 82): 0.5321571517934258,
#  (3, 81, 82): 0.5937518688134007,
#  (3, 81, 83): 0.601426787763129,
#  (2, 83, 83): 0.5321697869565954,
#  (3, 82, 83): 0.5937740134252909,
#  (3, 82, 84): 0.6014979184395587,
#  (3, 28, 83): 0.6390618120120578,
#  (2, 84, 84): 0.5322013748645192,
#  (3, 83, 84): 0.5938440691205609,
#  (3, 83, 85): 0.6015204268912259,
#  (2, 85, 85): 0.5322126208212671,
#  (3, 84, 85): 0.5939187058893884,
#  (3, 84, 86): 0.6015962874847584,
#  (2, 86, 86): 0.5322408018658233,
#  (3, 85, 86): 0.5939462915597639,
#  (3, 85, 87): 0.6016669550923809,
#  (3, 29, 86): 0.6394178126958119,
#  (2, 87, 87): 0.532251948593541,
#  (3, 86, 87): 0.5940234421306881,
#  (3, 86, 88): 0.601684650936087,
#  (2, 88, 88): 0.5322755651027112,
#  (3, 87, 88): 0.5940922243867381,
#  (3, 87, 89): 0.6017641830037341,
#  (2, 89, 89): 0.5322872410519229,
#  (3, 88, 89): 0.5941109952116039,
#  (3, 88, 90): 0.6018371328790496,
#  (3, 30, 89): 0.6400308661821116,
#  (2, 90, 90): 0.5323146613405815,
#  (3, 89, 90): 0.5941841270068079,
#  (3, 89, 91): 0.6018690019358922,
#  (2, 91, 91): 0.5323265357478535,
#  (3, 90, 91): 0.5942605664363495,
#  (3, 90, 92): 0.6019353200043608,
#  (2, 92, 92): 0.5323509791656083,
#  (3, 91, 92): 0.5942813383799895,
#  (3, 91, 93): 0.6020062026082151,
#  (3, 31, 92): 0.6404354725524564,
#  (2, 93, 93): 0.5323607366869041,
#  (3, 92, 93): 0.5943591835541245,
#  (3, 92, 94): 0.6020233692304272,
#  (2, 94, 94): 0.532385014722942,
#  (3, 93, 94): 0.5944335226358617,
#  (3, 93, 95): 0.6021049851077072,
#  (2, 95, 95): 0.5323954668474488,
#  (3, 94, 95): 0.5946310545585023,
#  (3, 94, 96): 0.6023667182128402,
#  (3, 32, 95): 0.6407084350761655,
#  (2, 96, 96): 0.5324148826610103,
#  (3, 95, 96): 0.5947102558627156,
#  (3, 95, 97): 0.6023858198011397,
#  (2, 97, 97): 0.5324242763425291,
#  (3, 96, 97): 0.5947447048743416,
#  (3, 96, 98): 0.6024215422519856,
#  (2, 98, 98): 0.5324444859883317,
#  (3, 97, 98): 0.5947557192966858,
#  (3, 97, 99): 0.6024459691315688,
#  (3, 33, 98): 0.6412241118075667,
#  (2, 99, 99): 0.532454276585971,
#  (3, 98, 99): 0.5947932940227607,
#  (3, 98, 100): 0.6024601919592203,
#  (2, 100, 100): 0.5324711785974361,
#  (3, 99, 100): 0.594818828959847,
#  (3, 7, 7): 0.44019443200773933,
#  (4, 6, 7): 0.45015962312549745,
#  (3, 8, 8): 0.4467808250351403,
#  (4, 7, 8): 0.4742427237336788,
#  (3, 9, 9): 0.4693452418753916,
#  (4, 8, 9): 0.49163882961608163,
#  (3, 10, 10): 0.47808047262654746,
#  (4, 9, 10): 0.4967868813136124,
#  (3, 11, 11): 0.48470119889837254,
#  (4, 10, 11): 0.502631388497265,
#  (3, 12, 12): 0.49122878218725124,
#  (4, 11, 12): 0.5167916853217244,
#  (3, 13, 13): 0.4935336740990533,
#  (4, 12, 13): 0.5312539030085183,
#  (3, 14, 14): 0.4956136137995563,
#  (4, 13, 14): 0.5362733208066606,
#  (3, 15, 15): 0.5004434876119833,
#  (4, 14, 15): 0.5434280646422885,
#  (3, 16, 16): 0.5020230153135531,
#  (4, 15, 16): 0.5478861768933428,
#  (3, 17, 17): 0.5030273123274739,
#  (4, 16, 17): 0.5516700278846806,
#  (3, 17, 51): 0.615492767394452,
#  (4, 16, 51): 0.6161914720719234,
#  (3, 18, 18): 0.506093654740131,
#  (4, 17, 18): 0.5534884163999391,
#  (3, 18, 54): 0.6177887948462294,
#  (4, 17, 54): 0.6190445216843214,
#  (3, 19, 19): 0.5081359535618724,
#  (4, 18, 19): 0.5547300196394097,
#  (3, 19, 57): 0.6196168251155819,
#  (4, 18, 57): 0.6206401410269438,
#  (3, 20, 20): 0.5092737466976579,
#  (4, 19, 20): 0.5579425760279598,
#  (3, 20, 60): 0.6203943672574895,
#  (4, 19, 60): 0.6215706116424494,
#  (3, 21, 21): 0.5131205254322682,
#  (4, 20, 21): 0.560842097902801,
#  (3, 21, 63): 0.6225665568796677,
#  (4, 20, 63): 0.6242344480325662,
#  (3, 22, 22): 0.5144697094785687,
#  (4, 21, 22): 0.5619077515336839,
#  (3, 22, 66): 0.624324547991922,
#  (4, 21, 66): 0.6264198516539231,
#  (3, 23, 23): 0.5164820742095548,
#  (4, 22, 23): 0.5623249765290268,
#  (3, 23, 69): 0.6249592168686177,
#  (4, 22, 69): 0.6269802310633965,
#  (3, 24, 24): 0.5177187986883774,
#  (4, 23, 24): 0.5647878741331352,
#  (3, 24, 72): 0.6264351494627344,
#  (4, 23, 72): 0.6274335588875342,
#  (3, 25, 25): 0.518164866255144,
#  (4, 24, 25): 0.5672480925534301,
#  (3, 25, 75): 0.6270372712175482,
#  (4, 24, 75): 0.6295931629610577,
#  (3, 26, 26): 0.5187485975630408,
#  (4, 25, 26): 0.5679596473903029,
#  (3, 26, 78): 0.6274313096961844,
#  (4, 25, 78): 0.6313052441087063,
#  (3, 27, 27): 0.5198030383135193,
#  (4, 26, 27): 0.5688839492677692,
#  (3, 27, 81): 0.6281354554321411,
#  (4, 26, 81): 0.6318541625652001,
#  (3, 28, 28): 0.5200221029356974,
#  (4, 27, 28): 0.571275650042761,
#  (3, 28, 84): 0.6286252830011939,
#  (4, 27, 84): 0.6323139071999525,
#  (3, 29, 29): 0.5204572222328067,
#  (4, 28, 29): 0.5737307747061763,
#  (3, 29, 87): 0.6289591721494013,
#  (4, 28, 87): 0.6344316035464191,
#  (3, 30, 30): 0.521353326527545,
#  (4, 29, 30): 0.5746018071326356,
#  (3, 30, 90): 0.6295677107148301,
#  (4, 29, 90): 0.636175140296618,
#  (4, 29, 93): 0.6410474510575962,
#  (3, 31, 31): 0.5216136373499127,
#  (4, 30, 31): 0.5765721483693628,
#  (3, 31, 93): 0.6299875487412996,
#  (4, 30, 93): 0.6364735716047266,
#  (4, 30, 96): 0.6419747628823096,
#  (3, 32, 32): 0.5218702105454792,
#  (4, 31, 32): 0.57749606986888,
#  (3, 32, 96): 0.6301997334840557,
#  (4, 31, 96): 0.6374555090105252,
#  (3, 32, 98): 0.6418308477122813,
#  (4, 31, 98): 0.64189207202387,
#  (4, 31, 99): 0.6423986858371861,
#  (3, 33, 33): 0.5225738105217701,
#  (4, 32, 33): 0.5782692459334621,
#  (3, 33, 99): 0.630719892059984,
#  (4, 32, 99): 0.6381510714353757,
#  (3, 34, 34): 0.5229414210020491,
#  (4, 33, 34): 0.5785625834846907,
#  (3, 35, 35): 0.5230813339345289,
#  (4, 34, 35): 0.5789247529064845,
#  (4, 34, 36): 0.586367542078401,
#  (3, 36, 36): 0.5237380978085997,
#  (4, 35, 36): 0.5796576089084913,
#  (3, 37, 37): 0.5239908341483345,
#  (4, 36, 37): 0.5802491462334248,
#  (4, 36, 38): 0.5873462049262054,
#  (3, 38, 38): 0.5241945844235296,
#  (4, 37, 38): 0.5804661601223137,
#  (4, 37, 39): 0.58762088741977,
#  (3, 39, 39): 0.5248276325593998,
#  (4, 38, 39): 0.5806532895349625,
#  (4, 38, 40): 0.5880847500592729,
#  (3, 40, 40): 0.5250622099866212,
#  (4, 39, 40): 0.5812160504411591,
#  (4, 39, 41): 0.5883475912219089,
#  (3, 41, 41): 0.5251781094938103,
#  (4, 40, 41): 0.581744395412073,
#  (4, 40, 42): 0.588833317324383,
#  (3, 42, 42): 0.5256858644409728,
#  (4, 41, 42): 0.5820000755463682,
#  (4, 41, 43): 0.5890965057886247,
#  (3, 43, 43): 0.5260332321991058,
#  (4, 42, 43): 0.5820988084313451,
#  (4, 42, 44): 0.5895697621096462,
#  (3, 44, 44): 0.5262173020499924,
#  (4, 43, 44): 0.5826556321339057,
#  (4, 43, 45): 0.5897379057011973,
#  (3, 45, 45): 0.5268432387720368,
#  (4, 44, 45): 0.5831276480920508,
#  (4, 44, 46): 0.5902254013880421,
#  (3, 46, 46): 0.5271012011740249,
#  (4, 45, 46): 0.583270240208344,
#  (3, 47, 47): 0.5277467521676913,
#  (4, 46, 47): 0.5834219779335806,
#  (3, 48, 48): 0.5279858610539553,
#  (4, 47, 48): 0.583798849790005,
#  (3, 49, 49): 0.5280672950113465,
#  (4, 48, 49): 0.58421129525373,
#  (4, 48, 50): 0.5913062701368778,
#  (3, 50, 50): 0.5281774061584447,
#  (4, 49, 50): 0.5844009880829905,
#  (4, 49, 51): 0.5914750587171248,
#  (4, 17, 50): 0.6165013477948399,
#  (3, 51, 51): 0.5283821156475977,
#  (4, 50, 51): 0.5845099911725855,
#  (4, 50, 52): 0.5918398411700453,
#  (3, 52, 52): 0.5284536267019764,
#  (4, 51, 52): 0.5848932467632814,
#  (4, 51, 53): 0.5920035690697556,
#  (3, 53, 53): 0.5285409151721452,
#  (4, 52, 53): 0.5853034761120002,
#  (4, 52, 54): 0.5923164712780911,
#  (4, 18, 53): 0.6181123476371319,
#  (3, 54, 54): 0.5286972339709394,
#  (4, 53, 54): 0.5854581080172822,
#  (4, 53, 55): 0.5925202546296297,
#  (3, 55, 55): 0.5287723172704025,
#  (4, 54, 55): 0.5854904070665887,
#  (4, 54, 56): 0.5928632397722654,
#  (3, 56, 56): 0.528849186692408,
#  (4, 55, 56): 0.585891077352072,
#  (4, 55, 57): 0.5930314164401599,
#  (3, 57, 57): 0.5290239620908059,
#  (4, 56, 57): 0.5862959648713356,
#  (4, 56, 58): 0.593397753481219,
#  (3, 58, 58): 0.529078174217599,
#  (4, 57, 58): 0.5864241191637455,
#  (4, 57, 59): 0.5935495408209707,
#  (3, 59, 59): 0.5291300048476689,
#  (4, 58, 59): 0.5865677035703398,
#  (4, 58, 60): 0.5938409764824553,
#  (4, 20, 59): 0.6220633830060628,
#  (3, 60, 60): 0.5292680655049197,
#  (4, 59, 60): 0.5869693992224677,
#  (4, 59, 61): 0.5940510939537503,
#  (3, 61, 61): 0.5293283636788938,
#  (4, 60, 61): 0.5873862934543769,
#  (4, 60, 62): 0.5944358379798981,
#  (3, 62, 62): 0.5293856188292774,
#  (4, 61, 62): 0.5875231799014378,
#  (4, 61, 63): 0.5950046353187607,
#  (4, 21, 62): 0.6242603302712578,
#  (3, 63, 63): 0.5295149142555335,
#  (4, 62, 63): 0.5881961511837626,
#  (4, 62, 64): 0.5953108064912191,
#  (3, 64, 64): 0.5295760062617487,
#  (4, 63, 64): 0.5883510807761351,
#  (4, 63, 65): 0.5954003937672526,
#  (3, 65, 65): 0.5296215523865772,
#  (4, 64, 65): 0.5884918206171993,
#  (4, 64, 66): 0.5955452681512389,
#  (4, 22, 65): 0.6248344032868888,
#  (3, 66, 66): 0.5297588522879303,
#  (4, 65, 66): 0.5885713692230182,
#  (4, 65, 67): 0.5956124131282917,
#  (3, 67, 67): 0.5298012561601383,
#  (4, 66, 67): 0.5886375219097698,
#  (4, 66, 68): 0.5957485718957984,
#  (3, 68, 68): 0.529846471521533,
#  (4, 67, 68): 0.5887764094756051,
#  (4, 67, 69): 0.5958102427380226,
#  (4, 23, 68): 0.6256472213490067,
#  (3, 69, 69): 0.5299781484445122,
#  (4, 68, 69): 0.5889008426793849,
#  (4, 68, 70): 0.5959310706203745,
#  (3, 70, 70): 0.5300216107597081,
#  (4, 69, 70): 0.5889561794018526,
#  (4, 69, 71): 0.5959897480535233,
#  (3, 71, 71): 0.5300431103829023,
#  (4, 70, 71): 0.5889931587537468,
#  (4, 70, 72): 0.5961088063515048,
#  (4, 24, 71): 0.6278304253935291,
#  (3, 72, 72): 0.5301334749530051,
#  (4, 71, 72): 0.5891061971572339,
#  (4, 71, 73): 0.596151656754348,
#  (3, 73, 73): 0.5301830563917255,
#  (4, 72, 73): 0.5892122399140968,
#  (4, 72, 74): 0.5962632397987264,
#  (3, 74, 74): 0.5302213918736981,
#  (4, 73, 74): 0.5892634255554708,
#  (4, 73, 75): 0.5963052632929854,
#  (4, 25, 74): 0.6295195515588748,
#  (3, 75, 75): 0.5303300145853443,
#  (4, 74, 75): 0.5893170257699115,
#  (4, 74, 76): 0.5964045750139714,
#  (3, 76, 76): 0.5303685816017206,
#  (4, 75, 76): 0.5894298161008231,
#  (4, 75, 77): 0.5964538256892581,
#  (3, 77, 77): 0.530398449539789,
#  (4, 76, 77): 0.5895255886530678,
#  (4, 76, 78): 0.5965617868740368,
#  (4, 26, 77): 0.6298821178967892,
#  (3, 78, 78): 0.5305056830450136,
#  (4, 77, 78): 0.5895662560172484,
#  (4, 77, 79): 0.5965969635652171,
#  (3, 79, 79): 0.5305416701066065,
#  (4, 78, 79): 0.5895925020957171,
#  (4, 78, 80): 0.5966842851117292,
#  (3, 80, 80): 0.5305744818392352,
#  (4, 79, 80): 0.5896747464235211,
#  (4, 79, 81): 0.5967190152722739,
#  (4, 27, 80): 0.6305618532913343,
#  (3, 81, 81): 0.5306651440964284,
#  (4, 80, 81): 0.5897592564808464,
#  (4, 80, 82): 0.5968058406736355,
#  (3, 82, 82): 0.5307149570695524,
#  (4, 81, 82): 0.5898063737319853,
#  (4, 81, 83): 0.5968468057249064,
#  (3, 83, 83): 0.5307373497540179,
#  (4, 82, 83): 0.5898409219726414,
#  (4, 82, 84): 0.5969399487078528,
#  (4, 28, 83): 0.632644984858973,
#  (3, 84, 84): 0.5308433925108808,
#  (4, 83, 84): 0.5899515788794052,
#  (4, 83, 85): 0.5969784495715423,
#  (3, 85, 85): 0.5308807357025521,
#  (4, 84, 85): 0.590039297342038,
#  (4, 84, 86): 0.5970633565449881,
#  (3, 86, 86): 0.5309161604663076,
#  (4, 85, 86): 0.5900632776909854,
#  (4, 85, 87): 0.5971014439543854,
#  (4, 29, 86): 0.6341472958369321,
#  (3, 87, 87): 0.531019424810327,
#  (4, 86, 87): 0.5900916241172586,
#  (4, 86, 88): 0.5971704908211825,
#  (3, 88, 88): 0.5310544195816186,
#  (4, 87, 88): 0.5901717184827432,
#  (4, 87, 89): 0.5972081978526308,
#  (3, 89, 89): 0.5310768122660842,
#  (4, 88, 89): 0.5902565427653305,
#  (4, 88, 90): 0.5972896979627089,
#  (4, 30, 89): 0.6345409208612762,
#  (3, 90, 90): 0.5311653907136445,
#  (4, 89, 90): 0.5902962343773815,
#  (4, 89, 91): 0.597325304646353,
#  (3, 91, 91): 0.5312151706104252,
#  (4, 90, 91): 0.5903176513097174,
#  (4, 90, 92): 0.5973977583765179,
#  (3, 92, 92): 0.5312498676946266,
#  (4, 91, 92): 0.5904037490315247,
#  (4, 91, 93): 0.5974274443946976,
#  (4, 31, 92): 0.6350845636410015,
#  (3, 93, 93): 0.5313585565589595,
#  (4, 92, 93): 0.5904832480228285,
#  (4, 92, 94): 0.597498806605531,
#  (3, 94, 94): 0.5313904421539738,
#  (4, 93, 94): 0.5905108667695473,
#  (4, 93, 95): 0.5975329083155515,
#  (3, 95, 95): 0.5316191650684178,
#  (4, 94, 95): 0.590518887782816,
#  (4, 94, 96): 0.5975902130804501,
#  (4, 32, 95): 0.6364357157297329,
#  (3, 96, 96): 0.5316609404901015,
#  (4, 95, 96): 0.5905898365393571,
#  (4, 95, 97): 0.5976202960147504,
#  (3, 97, 97): 0.5316739725693914,
#  (4, 96, 97): 0.5906563199895426,
#  (4, 96, 98): 0.5976821983913784,
#  (3, 98, 98): 0.5317002351860319,
#  (4, 97, 98): 0.5906784149869176,
#  (4, 97, 99): 0.5977121324821334,
#  (4, 33, 98): 0.6369774566197142,
#  (3, 99, 99): 0.5317385375916611,
#  (4, 98, 99): 0.5907043468401243,
#  (4, 98, 100): 0.5977623423713782,
#  (3, 100, 100): 0.53174793127318,
#  (4, 99, 100): 0.5907712272064303,
#  (4, 6, 6): 0.38529044734034446,
#  (5, 5, 6): 0.3960503141458788,
#  (4, 7, 7): 0.4024199248187945,
#  (5, 6, 7): 0.42052775091978695,
#  (4, 8, 8): 0.4285657819670951,
#  (5, 7, 8): 0.43856474403143997,
#  (4, 9, 9): 0.4379673356555573,
#  (5, 8, 9): 0.45166674671141765,
#  (4, 10, 10): 0.4425199304814645,
#  (5, 9, 10): 0.47425496198072786,
#  (4, 11, 11): 0.44806372408931566,
#  (5, 10, 11): 0.4900424495175617,
#  (4, 12, 12): 0.4693452418753916,
#  (5, 11, 12): 0.4940311588415976,
#  (4, 13, 13): 0.47675533508188117,
#  (5, 12, 13): 0.4998499491682755,
#  (4, 14, 14): 0.48208386784704227,
#  (5, 13, 14): 0.5030468273700656,
#  (4, 15, 15): 0.4852509608016224,
#  (5, 14, 15): 0.5158300733289302,
#  (4, 16, 16): 0.49122878218725124,
#  (5, 15, 16): 0.5299008986445578,
#  (4, 17, 17): 0.49264620272993614,
#  (5, 16, 17): 0.5345106990063337,
#  (4, 17, 51): 0.606547849164465,
#  (5, 16, 51): 0.6068501173284052,
#  (4, 18, 18): 0.494262775936087,
#  (5, 17, 18): 0.5398539672824688,
#  (4, 18, 54): 0.6085029752832394,
#  (5, 17, 54): 0.6086456500903911,
#  (4, 19, 19): 0.4959453033709292,
#  (5, 18, 19): 0.543222478630036,
#  (4, 19, 57): 0.6093778611037021,
#  (5, 18, 57): 0.6110883711250402,
#  (4, 20, 20): 0.5004434876119833,
#  (5, 19, 20): 0.5470177244216667,
#  (4, 20, 60): 0.6124243742485055,
#  (5, 19, 60): 0.6127122872794205,
#  (4, 21, 21): 0.501754931550492,
#  (5, 20, 21): 0.5505264463888041,
#  (4, 21, 63): 0.614252404517858,
#  (5, 20, 63): 0.6159845133914207,
#  (4, 22, 22): 0.5025522368075666,
#  (5, 21, 22): 0.5517973221921625,
#  (4, 22, 66): 0.6150826703511068,
#  (5, 21, 66): 0.6187561455845992,
#  (4, 23, 23): 0.5031675890997307,
#  (5, 22, 23): 0.5531504092469813,
#  (4, 23, 69): 0.6156283473259496,
#  (5, 22, 69): 0.6198103713388458,
#  (4, 24, 24): 0.506093654740131,
#  (5, 23, 24): 0.5539436130374774,
#  (4, 24, 72): 0.6177887948462294,
#  (5, 23, 72): 0.6206770046116361,
#  (4, 25, 25): 0.5079278041330082,
#  (5, 24, 25): 0.5569707103687193,
#  (4, 25, 75): 0.619438130170494,
#  (5, 24, 75): 0.6214497341455826,
#  (4, 26, 26): 0.5085600915129808,
#  (5, 25, 26): 0.5597136488340192,
#  (4, 26, 78): 0.6200700371725177,
#  (5, 25, 78): 0.6240545788772883,
#  (4, 27, 27): 0.5094988642906738,
#  (5, 26, 27): 0.5606478239999831,
#  (4, 27, 81): 0.6205027253583889,
#  (5, 26, 81): 0.6261406211631442,
#  (4, 28, 28): 0.5131205254322682,
#  (5, 27, 28): 0.5612278672955936,
#  (4, 28, 84): 0.6225665568796677,
#  (5, 27, 84): 0.6265492628473809,
#  (4, 29, 29): 0.5143106453432743,
#  (5, 28, 29): 0.5613912478936984,
#  (4, 29, 87): 0.6242289738977375,
#  (5, 28, 87): 0.626946129353376,
#  (4, 30, 30): 0.5156899950147334,
#  (5, 29, 30): 0.5637915319797965,
#  (4, 30, 90): 0.6246810778971702,
#  (5, 29, 90): 0.6272628022648563,
#  (4, 31, 31): 0.5166124611551424,
#  (5, 30, 31): 0.566074510814112,
#  (4, 31, 93): 0.6255271046080374,
#  (5, 30, 93): 0.6294413425449626,
#  (4, 32, 32): 0.5177187986883774,
#  (5, 31, 32): 0.5665562016026944,
#  (4, 32, 96): 0.6264351494627344,
#  (5, 31, 96): 0.6310857660322359,
#  (4, 33, 33): 0.5180689779356974,
#  (5, 32, 33): 0.5674294005296449,
#  (4, 33, 99): 0.626903626252138,
#  (5, 32, 99): 0.6314149087251689,
#  (4, 34, 34): 0.5183972606437027,
#  (5, 33, 34): 0.5680504584910413,
#  (4, 35, 35): 0.5188368121708242,
#  ...}

# %%
exportStateProbs(DATA_DIR + 'game1_better_giving_1_to_another_memo_1-100.csv', betterGiving1ToAnother)

# %%
betterGiving1ToAnother, given1ToAnother = readApproxBetterGiving1Probs(DATA_DIR + 'game1_better_giving_1_to_another_memo_1-100.csv')

# %%
betterGiving1ToAnother, given1ToAnother = stricterFilter(betterGiving1ToAnother, printOnGo=True,
                                                         filename=DATA_DIR + 'game1_better_giving_1_to_another_stricter_1-100.csv',
                                                         giveToAnother=True, continueFrom=(87,40,96))
# Out:
# Approximating hitting prob for (86, 24, 95)
# (86, 24, 95): 0.2621756239877832
# (85, 25, 95): 0.26415840550904085
#
# Approximating hitting prob for (86, 48, 95)
# (86, 48, 95): 0.30513012981100857
# (85, 49, 95): 0.30699311832045856
#
# Approximating hitting prob for (86, 95, 96)
# (86, 95, 96): 0.4043701990650226
# (85, 96, 96): 0.3607453096563375
#
# Approximating hitting prob for (86, 96, 97)
# (86, 96, 97): 0.4050136399868915
# (85, 97, 97): 0.36105351178447403
#
# Approximating hitting prob for (86, 42, 97)
# (86, 42, 97): 0.2921837787009233
# (85, 43, 97): 0.30524993090253333
#
# Approximating hitting prob for (85, 98, 98)
# (85, 98, 98): 0.3616057182935702
# (84, 99, 98): 0.4085337281404437
#
# Approximating hitting prob for (86, 33, 98)
# (86, 33, 98): 0.28678360550568543
# (85, 34, 98): 0.2879756737275779
#
# Approximating hitting prob for (86, 98, 99)
# (86, 98, 99): 0.406312111814015
# (85, 99, 99): 0.36189839913097605
#
# Approximating hitting prob for (86, 25, 99)
# (86, 25, 99): 0.26453512234685816
# (85, 26, 99): 0.26673103119373465
#
# Approximating hitting prob for (86, 60, 99)
# (86, 60, 99): 0.32041316912301376
# (85, 61, 99): 0.32184387408611065
#
# Approximating hitting prob for (86, 99, 100)
# (86, 99, 100): 0.406669596728308
# (85, 100, 100): 0.36342365070381427
#
# Approximating hitting prob for (87, 1, 30)
# (87, 1, 30): 0.060585930326500205
# (86, 2, 30): 0.059303680375866495
#
# Approximating hitting prob for (87, 1, 90)
# (87, 1, 90): 0.24921714493369293
# (86, 2, 90): 0.24774057313784606
#
# Approximating hitting prob for (87, 1, 91)
# (87, 1, 91): 0.249295528160311
# (86, 2, 91): 0.24793525432432262
#
# Approximating hitting prob for (87, 1, 94)
# (87, 1, 94): 0.2501717901448777
# (86, 2, 94): 0.2501141925797477
#
# Approximating hitting prob for (87, 1, 95)
# (87, 1, 95): 0.25023373821168676
# (86, 2, 95): 0.25024492734900106
#
# Approximating hitting prob for (87, 2, 31)
# (87, 2, 31): 0.061802146494203014
# (86, 3, 31): 0.06090418858375629
#
# Approximating hitting prob for (87, 2, 93)
# (87, 2, 93): 0.24989933728988056
# (86, 3, 93): 0.2488313471470177
#
# Approximating hitting prob for (87, 2, 94)
# (87, 2, 94): 0.25001982123718675
# (86, 3, 94): 0.24902515906136768
#
# Approximating hitting prob for (87, 3, 4)
# (87, 3, 4): 0.002571270694443467
# (86, 4, 4): 0.0022791208589751305
#
# Approximating hitting prob for (87, 3, 8)
# (87, 3, 8): 0.00613807483708689
# (86, 4, 8): 0.0059056771086283015
#
# Approximating hitting prob for (87, 3, 32)
# (87, 3, 32): 0.06315876551946463
# (86, 4, 32): 0.06282720502648445
#
# Approximating hitting prob for (87, 3, 96)
# (87, 3, 96): 0.25093012653196994
# (86, 4, 96): 0.24997833402398115
#
# Approximating hitting prob for (87, 3, 97)
# (87, 3, 97): 0.2511408281447342
# (86, 4, 97): 0.25021008086892366
#
# Approximating hitting prob for (87, 4, 5)
# (87, 4, 5): 0.0038732405546169743
# (86, 5, 5): 0.0034957631597845227
#
# Approximating hitting prob for (87, 4, 10)
# (87, 4, 10): 0.008735605615422205
# (86, 5, 10): 0.008383314032519453
#
# Approximating hitting prob for (87, 4, 33)
# (87, 4, 33): 0.06530426115785255
# (86, 5, 33): 0.06517954220047795
#
# Approximating hitting prob for (87, 4, 99)
# (87, 4, 99): 0.25218762535587047
# (86, 5, 99): 0.25129597915363117
#
# Approximating hitting prob for (87, 4, 100)
# (87, 4, 100): 0.2524386302022074
# (86, 5, 100): 0.25141758104871026
#
# Approximating hitting prob for (87, 5, 6)
# (87, 5, 6): 0.00601129038625518
# (86, 6, 6): 0.0057838998406309775
#
# Approximating hitting prob for (87, 6, 7)
# (87, 6, 7): 0.008636553534892817
# (86, 7, 7): 0.007227838877335759
#
# Approximating hitting prob for (87, 6, 35)
# (87, 6, 35): 0.06931045613792057
# (86, 7, 35): 0.06847906276533064
#
# Approximating hitting prob for (86, 8, 8)
# (86, 8, 8): 0.008445104685333531
# (85, 9, 8): 0.013914455760299593
#
# Approximating hitting prob for (86, 8, 16)
# (86, 8, 16): 0.023360256015917135
# (85, 9, 16): 0.027526997328649588
#
# Approximating hitting prob for (86, 9, 9)
# (86, 9, 9): 0.011255255803102784
# (85, 10, 9): 0.016250154585925467
#
# Approximating hitting prob for (86, 9, 18)
# (86, 9, 18): 0.02594904910704671
# (85, 10, 18): 0.031594921142042647
#
# Approximating hitting prob for (87, 5, 9)
# (87, 5, 9): 0.008824769002410885
# (86, 6, 9): 0.010584060250643906
#
# Approximating hitting prob for (87, 9, 10)
# (87, 9, 10): 0.015837662149662656
# (86, 10, 10): 0.01282926117580241
#
# Approximating hitting prob for (87, 9, 30)
# (87, 9, 30): 0.06635336201545274
# (86, 10, 30): 0.0649896226822997
#
# Approximating hitting prob for (87, 10, 11)
# (87, 10, 11): 0.018995631813599635
# (86, 11, 11): 0.01790246993634371
#
# Approximating hitting prob for (87, 10, 22)
# (87, 10, 22): 0.038124760256507316
# (86, 11, 22): 0.037172370849350156
#
# Approximating hitting prob for (87, 10, 39)
# (87, 10, 39): 0.08147299734329594
# (86, 11, 39): 0.08135389795177696
#
# Approximating hitting prob for (87, 10, 44)
# (87, 10, 44): 0.08640664408340724
# (86, 11, 44): 0.08632605004694498
#
# Approximating hitting prob for (87, 11, 12)
# (87, 11, 12): 0.02325257413190876
# (86, 12, 12): 0.019583748448085938
#
# Approximating hitting prob for (87, 11, 24)
# (87, 11, 24): 0.043241077795330186
# (86, 12, 24): 0.04018845439121782
#
# Approximating hitting prob for (87, 11, 36)
# (87, 11, 36): 0.07807032619921704
# (86, 12, 36): 0.07670005777176336
#
# Approximating hitting prob for (87, 11, 48)
# (87, 11, 48): 0.09218918521441759
# (86, 12, 48): 0.0905030923297561
#
# Approximating hitting prob for (87, 11, 60)
# (87, 11, 60): 0.11291752750389934
# (86, 12, 60): 0.11287613990978712
#
# Approximating hitting prob for (87, 11, 96)
# (87, 11, 96): 0.24545091364388597
# (86, 12, 96): 0.24541009455879795
#
# Approximating hitting prob for (87, 12, 13)
# (87, 12, 13): 0.027115454330257135
# (86, 13, 13): 0.02447609653793496
#
# Approximating hitting prob for (87, 13, 14)
# (87, 13, 14): 0.030366779773195754
# (86, 14, 14): 0.025142202643694895
#
# Approximating hitting prob for (87, 13, 28)
# (87, 13, 28): 0.0614467148199703
# (86, 14, 28): 0.05903771257614151
#
# Approximating hitting prob for (87, 13, 42)
# (87, 13, 42): 0.08926020272932529
# (86, 14, 42): 0.0854566747392926
#
# Approximating hitting prob for (87, 13, 70)
# (87, 13, 70): 0.12992542317932945
# (86, 14, 70): 0.1295122202325133
#
# Approximating hitting prob for (87, 13, 98)
# (87, 13, 98): 0.2507110129320439
# (86, 14, 98): 0.2505556422909564
#
# Approximating hitting prob for (87, 14, 15)
# (87, 14, 15): 0.03556343783975363
# (86, 15, 15): 0.03177397346436248
#
# Approximating hitting prob for (87, 14, 30)
# (87, 14, 30): 0.07420858517527573
# (86, 15, 30): 0.07288933905614121
#
# Approximating hitting prob for (86, 16, 16)
# (86, 16, 16): 0.03265941540128537
# (85, 17, 16): 0.047177528777479195
#
# Approximating hitting prob for (86, 16, 32)
# (86, 16, 32): 0.07464478542402657
# (85, 17, 32): 0.0826278229966687
#
# Approximating hitting prob for (86, 16, 44)
# (86, 16, 44): 0.10354556633660027
# (85, 17, 44): 0.10737719141234077
#
# Approximating hitting prob for (86, 16, 48)
# (86, 16, 48): 0.10410194707171054
# (85, 17, 48): 0.11330440976082919
#
# Approximating hitting prob for (86, 16, 96)
# (86, 16, 96): 0.25245545202569736
# (85, 17, 96): 0.2564270391641589
#
# Approximating hitting prob for (86, 17, 17)
# (86, 17, 17): 0.034060687253849344
# (85, 18, 17): 0.049552094600046726
#
# Approximating hitting prob for (86, 17, 34)
# (86, 17, 34): 0.07565138370348705
# (85, 18, 34): 0.09704430973183797
#
# Approximating hitting prob for (86, 17, 51)
# (86, 17, 51): 0.10904804021822684
# (85, 18, 51): 0.1218387175297288
#
# Approximating hitting prob for (86, 17, 68)
# (86, 17, 68): 0.13133066220627668
# (85, 18, 68): 0.17130919601858374
#
# Approximating hitting prob for (86, 6, 18)
# (86, 6, 18): 0.023554049545825795
# (85, 7, 18): 0.0279579736383537
#
# Approximating hitting prob for (87, 9, 17)
# (87, 9, 17): 0.027860544982158886
# (86, 10, 17): 0.030483018443676787
#
# Approximating hitting prob for (87, 17, 18)
# (87, 17, 18): 0.04877983484198983
# (86, 18, 18): 0.03642316117570286
#
# Approximating hitting prob for (87, 17, 54)
# (87, 17, 54): 0.11982324823367994
# (86, 18, 54): 0.11904847022561238
#
# Approximating hitting prob for (87, 18, 19)
# (87, 18, 19): 0.050712412935622404
# (86, 19, 19): 0.03857379889615905
#
# Approximating hitting prob for (87, 18, 38)
# (87, 18, 38): 0.10396600260296303
# (86, 19, 38): 0.09670907639819808
#
# Approximating hitting prob for (87, 18, 57)
# (87, 18, 57): 0.12511524311250433
# (86, 19, 57): 0.12248518375232621
#
# Approximating hitting prob for (87, 18, 76)
# (87, 18, 76): 0.17618812590186173
# (86, 19, 76): 0.17586372624068017
#
# Approximating hitting prob for (87, 18, 95)
# (87, 18, 95): 0.25566985819497534
# (86, 19, 95): 0.25557147808908515
#
# Approximating hitting prob for (87, 10, 19)
# (87, 10, 19): 0.0340148031487442
# (86, 11, 19): 0.03650479366399636
#
# Approximating hitting prob for (87, 19, 20)
# (87, 19, 20): 0.052801199398779114
# (86, 20, 20): 0.040805495619319725
#
# Approximating hitting prob for (87, 19, 40)
# (87, 19, 40): 0.10586443751776237
# (86, 20, 40): 0.09997559335103333
#
# Approximating hitting prob for (87, 19, 60)
# (87, 19, 60): 0.1288313894625924
# (86, 20, 60): 0.12602382492480133
#
# Approximating hitting prob for (87, 19, 61)
# (87, 19, 61): 0.1308867729097693
# (86, 20, 61): 0.13078809910551573
#
# Approximating hitting prob for (87, 19, 100)
# (87, 19, 100): 0.25861837541117566
# (86, 20, 100): 0.25838872867701723
#
# Approximating hitting prob for (87, 7, 20)
# (87, 7, 20): 0.02898693453056779
# (86, 8, 20): 0.03033302014740638
#
# Approximating hitting prob for (87, 20, 21)
# (87, 20, 21): 0.05528088740873832
# (86, 21, 21): 0.04190578975273018
#
# Approximating hitting prob for (87, 20, 42)
# (87, 20, 42): 0.10893447767423568
# (86, 21, 42): 0.10196825309275044
#
# Approximating hitting prob for (87, 20, 49)
# (87, 20, 49): 0.12071450487804848
# (86, 21, 49): 0.12057396700809873
#
# Approximating hitting prob for (87, 20, 63)
# (87, 20, 63): 0.13285982457281023
# (86, 21, 63): 0.1279359137056557
#
# Approximating hitting prob for (86, 22, 22)
# (86, 22, 22): 0.058920258640406176
# (85, 23, 22): 0.0739145385787132
#
# Approximating hitting prob for (86, 22, 33)
# (86, 22, 33): 0.09679440704394471
# (85, 23, 33): 0.10080527725712789
#
# Approximating hitting prob for (86, 22, 44)
# (86, 22, 44): 0.10734169927335104
# (85, 23, 44): 0.11730236907324715
#
# Approximating hitting prob for (86, 23, 23)
# (86, 23, 23): 0.05990365031014248
# (85, 24, 23): 0.07592462683214064
#
# Approximating hitting prob for (86, 23, 46)
# (86, 23, 46): 0.10953775799344312
# (85, 24, 46): 0.12125048326568612
#
# Approximating hitting prob for (86, 23, 69)
# (86, 23, 69): 0.1742958742514326
# (85, 24, 69): 0.18290816109743743
#
# Approximating hitting prob for (86, 23, 92)
# (86, 23, 92): 0.25808347012103233
# (85, 24, 92): 0.2618342735290915
#
# Approximating hitting prob for (86, 8, 24)
# (86, 8, 24): 0.03664668270920903
# (85, 9, 24): 0.042216571078721614
#
# Approximating hitting prob for (87, 12, 23)
# (87, 12, 23): 0.042879515902688896
# (86, 13, 23): 0.04777686089496103
#
# Approximating hitting prob for (87, 23, 24)
# (87, 23, 24): 0.07487072417278949
# (86, 24, 24): 0.061842738492322136
#
# Approximating hitting prob for (87, 23, 36)
# (87, 23, 36): 0.10168917540924867
# (86, 24, 36): 0.10111296083367753
#
# Approximating hitting prob for (87, 23, 48)
# (87, 23, 48): 0.12073579002507784
# (86, 24, 48): 0.11499978096809664
#
# Approximating hitting prob for (87, 23, 68)
# (87, 23, 68): 0.18014092720028352
# (86, 24, 68): 0.17994927815759512
#
# Approximating hitting prob for (87, 23, 72)
# (87, 23, 72): 0.18272913303521607
# (86, 24, 72): 0.1774414432921386
#
# Approximating hitting prob for (87, 23, 96)
# (87, 23, 96): 0.2615320498477954
# (86, 24, 96): 0.2602576397609323
#
# Approximating hitting prob for (87, 24, 25)
# (87, 24, 25): 0.07694080650409138
# (86, 25, 25): 0.06424161252534111
#
# Approximating hitting prob for (87, 24, 50)
# (87, 24, 50): 0.12490139810465702
# (86, 25, 50): 0.1177753662921962
#
# Approximating hitting prob for (87, 24, 75)
# (87, 24, 75): 0.18714807836221192
# (86, 25, 75): 0.18338424761039263
#
# Approximating hitting prob for (87, 24, 100)
# (87, 24, 100): 0.2635182843087413
# (86, 25, 100): 0.26271293101014814
#
# Approximating hitting prob for (87, 13, 25)
# (87, 13, 25): 0.05658244847232405
# (86, 14, 25): 0.05800359383850109
#
# Approximating hitting prob for (87, 25, 26)
# (87, 25, 26): 0.07941611000579034
# (86, 26, 26): 0.06754394159733522
#
# Approximating hitting prob for (87, 25, 52)
# (87, 25, 52): 0.12754840880189666
# (86, 26, 52): 0.12235970282991705
#
# Approximating hitting prob for (87, 25, 78)
# (87, 25, 78): 0.1917083568322828
# (86, 26, 78): 0.19007371272058282
#
# Approximating hitting prob for (87, 26, 27)
# (87, 26, 27): 0.08326356098943324
# (86, 27, 27): 0.0692686867959358
#
# Approximating hitting prob for (87, 26, 54)
# (87, 26, 54): 0.1317364062887674
# (86, 27, 54): 0.12435724396415125
#
# Approximating hitting prob for (87, 26, 81)
# (87, 26, 81): 0.19828765185226563
# (86, 27, 81): 0.19418837455790663
#
# Approximating hitting prob for (86, 28, 28)
# (86, 28, 28): 0.07101913233861558
# (85, 29, 28): 0.10335939523293003
#
# Approximating hitting prob for (86, 28, 56)
# (86, 28, 56): 0.12605467843568524
# (85, 29, 56): 0.17032761352112227
#
# Approximating hitting prob for (86, 28, 84)
# (86, 28, 84): 0.1980442689275923
# (85, 29, 84): 0.21844113012517785
#
# Approximating hitting prob for (86, 29, 29)
# (86, 29, 29): 0.09699702664072853
# (85, 30, 29): 0.1145244094962073
#
# Approximating hitting prob for (87, 10, 29)
# (87, 10, 29): 0.06654962612113974
# (86, 11, 29): 0.06796819565939598
#
# Approximating hitting prob for (86, 30, 30)
# (86, 30, 30): 0.09769116590006859
# (85, 31, 30): 0.115579134931668
#
# Approximating hitting prob for (86, 30, 60)
# (86, 30, 60): 0.17730757045553583
# (85, 31, 60): 0.18747967155400866
#
# Approximating hitting prob for (86, 30, 90)
# (86, 30, 90): 0.2719450001136396
# (85, 31, 90): 0.28063400412272627
#
# Approximating hitting prob for (86, 31, 31)
# (86, 31, 31): 0.09864489665765173
# (85, 32, 31): 0.11672758132001787
#
# Approximating hitting prob for (86, 31, 59)
# (86, 31, 59): 0.1839576185779156
# (85, 32, 59): 0.18561478839367815
#
# Approximating hitting prob for (86, 31, 62)
# (86, 31, 62): 0.17911204096145447
# (85, 32, 62): 0.18947634903162025
#
# Approximating hitting prob for (86, 31, 93)
# (86, 31, 93): 0.2739595662925361
# (85, 32, 93): 0.28216818807038785
#
# Approximating hitting prob for (87, 16, 31)
# (87, 16, 31): 0.07817444908156225
# (86, 17, 31): 0.08139347746018331
#
# Approximating hitting prob for (87, 31, 32)
# (87, 31, 32): 0.11600810780666072
# (86, 32, 32): 0.09943930575963568
#
# Approximating hitting prob for (87, 31, 48)
# (87, 31, 48): 0.13996822348987897
# (86, 32, 48): 0.13956247104513284
#
# Approximating hitting prob for (87, 31, 64)
# (87, 31, 64): 0.18848397583986698
# (86, 32, 64): 0.18134035540746027
#
# Approximating hitting prob for (87, 31, 96)
# (87, 31, 96): 0.2813853787875565
# (86, 32, 96): 0.27506799227556106
#
# Approximating hitting prob for (87, 32, 33)
# (87, 32, 33): 0.11761064422785557
# (86, 33, 33): 0.10208712776114533
#
# Approximating hitting prob for (87, 32, 66)
# (87, 32, 66): 0.19190535561057956
# (86, 33, 66): 0.1836912491598451
#
# Approximating hitting prob for (87, 32, 99)
# (87, 32, 99): 0.2834025240501629
# (86, 33, 99): 0.27994370296855997
#
# Approximating hitting prob for (86, 34, 34)
# (86, 34, 34): 0.10323680645433543
# (85, 35, 34): 0.12269090127147701
#
# Approximating hitting prob for (86, 34, 51)
# (86, 34, 51): 0.1427736437814365
# (85, 35, 51): 0.1822149942788712
#
# Approximating hitting prob for (86, 34, 68)
# (86, 34, 68): 0.18668233422198768
# (85, 35, 68): 0.20118477166813595
#
# Approximating hitting prob for (86, 34, 85)
# (86, 34, 85): 0.21966528265356408
# (85, 35, 85): 0.27920695062428347
#
# Approximating hitting prob for (86, 35, 35)
# (86, 35, 35): 0.10479074625884797
# (85, 36, 35): 0.12405574703455585
#
# Approximating hitting prob for (86, 35, 38)
# (86, 35, 38): 0.12642896800797063
# (85, 36, 38): 0.12749544864152276
#
# Approximating hitting prob for (86, 35, 70)
# (86, 35, 70): 0.1923634762813503
# (85, 36, 70): 0.2029876980627849
#
# Approximating hitting prob for (86, 9, 36)
# (86, 9, 36): 0.07360366529840599
# (85, 10, 36): 0.078289082060518
#
# Approximating hitting prob for (87, 12, 35)
# (87, 12, 35): 0.07846461133348141
# (86, 13, 35): 0.08210197949020336
#
# Approximating hitting prob for (87, 18, 35)
# (87, 18, 35): 0.09991443796736464
# (86, 19, 35): 0.10052903664582097
#
# Approximating hitting prob for (86, 36, 36)
# (86, 36, 36): 0.1061512421863151
# (85, 37, 36): 0.12538762255875696
#
# Approximating hitting prob for (86, 36, 54)
# (86, 36, 54): 0.1825774473250554
# (85, 37, 54): 0.1858613599732026
#
# Approximating hitting prob for (86, 36, 72)
# (86, 36, 72): 0.1940673207499689
# (85, 37, 72): 0.20773573260817577
#
# Approximating hitting prob for (86, 36, 88)
# (86, 36, 88): 0.28318746849599596
# (85, 37, 88): 0.28472086628820537
#
# Approximating hitting prob for (86, 37, 37)
# (86, 37, 37): 0.10706443231812023
# (85, 38, 37): 0.1266736076162678
#
# Approximating hitting prob for (86, 37, 74)
# (86, 37, 74): 0.20241176161416263
# (85, 38, 74): 0.21359648960520847
#
# Approximating hitting prob for (87, 19, 37)
# (87, 19, 37): 0.10402302198864137
# (86, 20, 37): 0.10441345000765001
#
# Approximating hitting prob for (87, 37, 38)
# (87, 37, 38): 0.12552455390276643
# (86, 38, 38): 0.10797346593593388
#
# Approximating hitting prob for (86, 38, 57)
# (86, 38, 57): 0.18586855772794744
# (85, 39, 57): 0.1900573436195022
#
# Approximating hitting prob for (86, 38, 76)
# (86, 38, 76): 0.20368360545520525
# (85, 39, 76): 0.21629766124788072
#
# Approximating hitting prob for (86, 13, 39)
# (86, 13, 39): 0.08269136158242725
# (85, 14, 39): 0.08734033277090199
#
# Approximating hitting prob for (86, 26, 39)
# (86, 26, 39): 0.11383804111584321
# (85, 27, 39): 0.11675762109991673
#
# Approximating hitting prob for (86, 39, 39)
# (86, 39, 39): 0.10875943682492538
# (85, 40, 39): 0.1297690728143414
#
# Approximating hitting prob for (87, 38, 40)
# (87, 38, 40): 0.1290436196379223
# (86, 39, 40): 0.12874480523272733
#
# Approximating hitting prob for (87, 38, 78)
# (87, 38, 78): 0.21507799497934635
# (86, 39, 78): 0.20567162836810518
#
# Approximating hitting prob for (87, 38, 93)
# (87, 38, 93): 0.2871299987235038
# (86, 39, 93): 0.2867120363708282
#
# Approximating hitting prob for (86, 40, 40)
# (86, 40, 40): 0.11000559323046638
# (85, 41, 40): 0.13150280184494337
#
# Approximating hitting prob for (87, 39, 41)
# (87, 39, 41): 0.13080167250245506
# (86, 40, 41): 0.13065999112052368
#
# Approximating hitting prob for (87, 39, 68)
# (87, 39, 68): 0.20477977212492482
# (86, 40, 68): 0.20471292421068346
#
# Approximating hitting prob for (87, 39, 80)
# (87, 39, 80): 0.2175650007754134
# (86, 40, 80): 0.20923166360028642
#
# Approximating hitting prob for (87, 40, 41)
# (87, 40, 41): 0.1297932801091923
# (86, 41, 41): 0.11054960812998761
#
# Approximating hitting prob for (87, 40, 82)
# (87, 40, 82): 0.2208348227648238
# (86, 41, 82): 0.21180795074085626
#
# Approximating hitting prob for (87, 40, 96)
# (87, 40, 96): 0.2914985300459176
# (86, 41, 96): 0.29095451785255816
#
# Approximating hitting prob for (87, 21, 41)
# (87, 21, 41): 0.10930286701456615
# (86, 22, 41): 0.11071396338618882
#
# Approximating hitting prob for (87, 28, 41)
# (87, 28, 41): 0.11918748555001214
# (86, 29, 41): 0.13125450455318596
#
# Approximating hitting prob for (87, 41, 42)
# (87, 41, 42): 0.13152212258550966
# (86, 42, 42): 0.11093730041861244
#
# Approximating hitting prob for (87, 41, 63)
# (87, 41, 63): 0.19768147492296792
# (86, 42, 63): 0.19758838587703742
#
# Approximating hitting prob for (87, 41, 70)
# (87, 41, 70): 0.20764304369802963
# (86, 42, 70): 0.20688782539184628
#
# Approximating hitting prob for (87, 41, 84)
# (87, 41, 84): 0.22296876591166534
# (86, 42, 84): 0.2139416356047508
#
# Approximating hitting prob for (87, 41, 98)
# (87, 41, 98): 0.292540409490794
# (86, 42, 98): 0.2914418694880051
#
# Approximating hitting prob for (87, 22, 43)
# (87, 22, 43): 0.11369795373445078
# (86, 23, 43): 0.11584942212975706
#
# Approximating hitting prob for (87, 43, 44)
# (87, 43, 44): 0.16826200600308117
# (86, 44, 44): 0.16357429479290744
#
# Approximating hitting prob for (86, 30, 45)
# (86, 30, 45): 0.1342128424711582
# (85, 31, 45): 0.13877733593996908
#
# Approximating hitting prob for (86, 45, 45)
# (86, 45, 45): 0.16392414530918745
# (85, 46, 45): 0.2061126210627772
#
# Approximating hitting prob for (86, 45, 73)
# (86, 45, 73): 0.22630662812293245
# (85, 46, 73): 0.22768350385231043
#
# Approximating hitting prob for (86, 45, 90)
# (86, 45, 90): 0.29183611475608506
# (85, 46, 90): 0.30361262960247193
#
# Approximating hitting prob for (87, 23, 45)
# (87, 23, 45): 0.11695876179563724
# (86, 24, 45): 0.11904105733350179
#
# Approximating hitting prob for (87, 45, 46)
# (87, 45, 46): 0.20538880607758114
# (86, 46, 46): 0.1645499135140422
#
# Approximating hitting prob for (87, 45, 69)
# (87, 45, 69): 0.22002127846215092
# (86, 46, 69): 0.2194986815072544
#
# Approximating hitting prob for (87, 45, 92)
# (87, 45, 92): 0.30216449077674673
# (86, 46, 92): 0.29301555996874523
#
# Approximating hitting prob for (87, 46, 47)
# (87, 46, 47): 0.20607553386906954
# (86, 47, 47): 0.16534354039299967
#
# Approximating hitting prob for (87, 46, 94)
# (87, 46, 94): 0.30368590493948017
# (86, 47, 94): 0.2939252003229121
#
# Approximating hitting prob for (87, 16, 47)
# (87, 16, 47): 0.10670735826744292
# (86, 17, 47): 0.10893353938942428
#
# Approximating hitting prob for (87, 32, 47)
# (87, 32, 47): 0.13982861839788632
# (86, 33, 47): 0.1413117297709323
#
# Approximating hitting prob for (87, 47, 48)
# (87, 47, 48): 0.20697851676248227
# (86, 48, 48): 0.1661010893957866
#
# Approximating hitting prob for (87, 47, 72)
# (87, 47, 72): 0.22576795194643218
# (86, 48, 72): 0.22472906534698808
#
# Approximating hitting prob for (87, 47, 96)
# (87, 47, 96): 0.30461746431149184
# (86, 48, 96): 0.29564933219357414
#
# Approximating hitting prob for (87, 48, 49)
# (87, 48, 49): 0.20784529846724273
# (86, 49, 49): 0.1671026403329929
#
# Approximating hitting prob for (87, 48, 98)
# (87, 48, 98): 0.3061344390258362
# (86, 49, 98): 0.29635810787243166
#
# Approximating hitting prob for (86, 50, 50)
# (86, 50, 50): 0.16791831087407227
# (85, 51, 50): 0.21249320726529977
#
# Approximating hitting prob for (86, 50, 100)
# (86, 50, 100): 0.2974860575178738
# (85, 51, 100): 0.31076737944637045
#
# Approximating hitting prob for (87, 17, 50)
# (87, 17, 50): 0.11129645938793713
# (86, 18, 50): 0.11754878376356047
#
# Approximating hitting prob for (86, 51, 51)
# (86, 51, 51): 0.16893096798839458
# (85, 52, 51): 0.21571088774111855
#
# Approximating hitting prob for (86, 51, 68)
# (86, 51, 68): 0.22239511680403348
# (85, 52, 68): 0.23646833068135423
#
# Approximating hitting prob for (86, 51, 85)
# (86, 51, 85): 0.24241193391360227
# (85, 52, 85): 0.30247085244696154
#
# Approximating hitting prob for (87, 26, 51)
# (87, 26, 51): 0.12780224926361916
# (86, 27, 51): 0.1300216976170261
#
# Approximating hitting prob for (87, 51, 52)
# (87, 51, 52): 0.21081473888130897
# (86, 52, 52): 0.17405170383744537
#
# Approximating hitting prob for (87, 52, 53)
# (87, 52, 53): 0.21403922007346501
# (86, 53, 53): 0.17472746912609635
#
# Approximating hitting prob for (87, 27, 53)
# (87, 27, 53): 0.13214824112289802
# (86, 28, 53): 0.13377239290567225
#
# Approximating hitting prob for (86, 54, 54)
# (86, 54, 54): 0.17676987076628545
# (85, 55, 54): 0.21955550282870284
#
# Approximating hitting prob for (86, 54, 81)
# (86, 54, 81): 0.2374596747440095
# (85, 55, 81): 0.24121807627381628
#
# Approximating hitting prob for (86, 54, 82)
# (86, 54, 82): 0.24086066710486406
# (85, 55, 82): 0.24143055377830988
#
# Approximating hitting prob for (86, 55, 55)
# (86, 55, 55): 0.17717101213140687
# (85, 56, 55): 0.22072768416932362
#
# Approximating hitting prob for (86, 55, 83)
# (86, 55, 83): 0.24115768265105572
# (85, 56, 83): 0.24429217050376728
#
# Approximating hitting prob for (86, 14, 56)
# (86, 14, 56): 0.11318419077273702
# (85, 15, 56): 0.12193950595311764
#
# Approximating hitting prob for (87, 28, 55)
# (87, 28, 55): 0.1342440686427301
# (86, 29, 55): 0.14662869162151856
#
# Approximating hitting prob for (87, 55, 56)
# (87, 55, 56): 0.2192696689168259
# (86, 56, 56): 0.17829893238613384
#
# Approximating hitting prob for (87, 55, 84)
# (87, 55, 84): 0.2430359206390624
# (86, 56, 84): 0.2393874442857192
#
# Approximating hitting prob for (87, 38, 56)
# (87, 38, 56): 0.18632987101193757
# (86, 39, 56): 0.18816852114066562
#
# Approximating hitting prob for (87, 56, 57)
# (87, 56, 57): 0.2204677900127193
# (86, 57, 57): 0.1788262460172647
#
# Approximating hitting prob for (87, 57, 58)
# (87, 57, 58): 0.22171487504335222
# (86, 58, 58): 0.18496409596034194
#
# Approximating hitting prob for (87, 58, 59)
# (87, 58, 59): 0.22693536876316975
# (86, 59, 59): 0.18573327872650755
#
# Approximating hitting prob for (87, 10, 59)
# (87, 10, 59): 0.11197207234264943
# (86, 11, 59): 0.1125485188032694
#
# Approximating hitting prob for (87, 15, 59)
# (87, 15, 59): 0.12251941874956061
# (86, 16, 59): 0.1243697449503015
#
# Approximating hitting prob for (86, 60, 60)
# (86, 60, 60): 0.18654929319046387
# (85, 61, 60): 0.23181711141213976
#
# Approximating hitting prob for (86, 60, 88)
# (86, 60, 88): 0.3221518877874146
# (85, 61, 88): 0.3231576050296567
#
# Approximating hitting prob for (86, 60, 100)
# (86, 60, 100): 0.3195041561372457
# (85, 61, 100): 0.32201368331672925
#
# Approximating hitting prob for (86, 61, 61)
# (86, 61, 61): 0.1887191881058189
# (85, 62, 61): 0.23284592111360727
#
# Approximating hitting prob for (86, 61, 89)
# (86, 61, 89): 0.3226235924423148
# (85, 62, 89): 0.32379752891482816
#
# Approximating hitting prob for (87, 31, 61)
# (87, 31, 61): 0.18662652264463606
# (86, 32, 61): 0.188168455095436
#
# Approximating hitting prob for (87, 61, 62)
# (87, 61, 62): 0.23115411283760298
# (86, 62, 62): 0.19008233513720904
#
# Approximating hitting prob for (87, 61, 90)
# (87, 61, 90): 0.32423494434297623
# (86, 62, 90): 0.32347154703568026
#
# Approximating hitting prob for (87, 42, 62)
# (87, 42, 62): 0.1977187899313374
# (86, 43, 62): 0.21111790938860156
#
# Approximating hitting prob for (87, 62, 63)
# (87, 62, 63): 0.23229131612354312
# (86, 63, 63): 0.1907805231046669
#
# Approximating hitting prob for (87, 62, 91)
# (87, 62, 91): 0.32473115516939505
# (86, 63, 91): 0.3240084728168579
#
# Approximating hitting prob for (87, 16, 63)
# (87, 16, 63): 0.1279679696990474
# (86, 17, 63): 0.12970510748714076
#
# Approximating hitting prob for (86, 64, 64)
# (86, 64, 64): 0.19128043746165957
# (85, 65, 64): 0.2429754299966187
#
# Approximating hitting prob for (86, 64, 92)
# (86, 64, 92): 0.3248994401772693
# (85, 65, 92): 0.326048444647357
#
# Approximating hitting prob for (86, 65, 65)
# (86, 65, 65): 0.2007380893500049
# (85, 66, 65): 0.24414130452937702
#
# Approximating hitting prob for (86, 65, 93)
# (86, 65, 93): 0.325929282912917
# (85, 66, 93): 0.32727956651283446
#
# Approximating hitting prob for (87, 33, 65)
# (87, 33, 65): 0.19141048439063946
# (86, 34, 65): 0.1936146828005922
#
# Approximating hitting prob for (87, 65, 66)
# (87, 65, 66): 0.24043760213861307
# (86, 66, 66): 0.20119763496438722
#
# Approximating hitting prob for (87, 65, 94)
# (87, 65, 94): 0.32685619352705375
# (86, 66, 94): 0.32641714331527544
#
# Approximating hitting prob for (87, 66, 67)
# (87, 66, 67): 0.2438153255002166
# (86, 67, 67): 0.20265083855213717
#
# Approximating hitting prob for (87, 34, 67)
# (87, 34, 67): 0.19448569219471704
# (86, 35, 67): 0.1964092433533532
#
# Approximating hitting prob for (87, 67, 68)
# (87, 67, 68): 0.24492098515646052
# (86, 68, 68): 0.203151269216312
#
# Approximating hitting prob for (86, 69, 69)
# (86, 69, 69): 0.20473828290344054
# (85, 70, 69): 0.2485057814202367
#
# Approximating hitting prob for (86, 69, 97)
# (86, 69, 97): 0.3292971771396889
# (85, 70, 97): 0.33078229566765777
#
# Approximating hitting prob for (87, 14, 69)
# (87, 14, 69): 0.12971437273203126
# (86, 15, 69): 0.13351111536071952
#
# Approximating hitting prob for (87, 42, 69)
# (87, 42, 69): 0.20687571548010084
# (86, 43, 69): 0.2197363107133912
#
# Approximating hitting prob for (87, 69, 70)
# (87, 69, 70): 0.24690892765395323
# (86, 70, 70): 0.20541370184931737
#
# Approximating hitting prob for (87, 69, 98)
# (87, 69, 98): 0.33080815242200895
# (86, 70, 98): 0.32990125995679465
#
# Approximating hitting prob for (87, 70, 71)
# (87, 70, 71): 0.24806003829915213
# (86, 71, 71): 0.20581051528550795
#
# Approximating hitting prob for (87, 70, 99)
# (87, 70, 99): 0.3314070575249963
# (86, 71, 99): 0.33089546635883726
#
# Approximating hitting prob for (87, 18, 71)
# (87, 18, 71): 0.1723147151897517
# (86, 19, 71): 0.1733763502785046
#
# Approximating hitting prob for (87, 36, 71)
# (87, 36, 71): 0.20199264149322446
# (86, 37, 71): 0.203619371723797
#
# Approximating hitting prob for (87, 71, 72)
# (87, 71, 72): 0.2488115720563072
# (86, 72, 72): 0.20940421141536092
#
# Approximating hitting prob for (87, 72, 73)
# (87, 72, 73): 0.250761743011451
# (86, 73, 73): 0.20991908687337688
#
# Approximating hitting prob for (86, 74, 74)
# (86, 74, 74): 0.21167468893437627
# (85, 75, 74): 0.25762065194577777
#
# Approximating hitting prob for (87, 25, 74)
# (87, 25, 74): 0.18550007993946196
# (86, 26, 74): 0.1905870638416751
#
# Approximating hitting prob for (87, 74, 75)
# (87, 74, 75): 0.25512817610064414
# (86, 75, 75): 0.2121722125654194
#
# Approximating hitting prob for (87, 38, 75)
# (87, 38, 75): 0.21231282154057576
# (86, 39, 75): 0.21359932846915208
#
# Approximating hitting prob for (87, 75, 76)
# (87, 75, 76): 0.2564352892803041
# (86, 76, 76): 0.2144554663173088
#
# Approximating hitting prob for (87, 76, 77)
# (87, 76, 77): 0.25807192534257034
# (86, 77, 77): 0.21502490711471425
#
# Approximating hitting prob for (87, 39, 77)
# (87, 39, 77): 0.2144210520168162
# (86, 40, 77): 0.2173920311401434
#
# Approximating hitting prob for (87, 77, 78)
# (87, 77, 78): 0.25916979939646456
# (86, 78, 78): 0.215903280107813
#
# Approximating hitting prob for (87, 78, 79)
# (87, 78, 79): 0.25988882646982087
# (86, 79, 79): 0.2171233600449343
#
# Approximating hitting prob for (86, 80, 80)
# (86, 80, 80): 0.2182079537150826
# (85, 81, 80): 0.2638607090823937
#
# Approximating hitting prob for (87, 27, 80)
# (87, 27, 80): 0.19813172584729696
# (86, 28, 80): 0.20041169048641894
#
# Approximating hitting prob for (86, 81, 81)
# (86, 81, 81): 0.21916050774154672
# (85, 82, 81): 0.2646120119552127
#
# Approximating hitting prob for (87, 41, 81)
# (87, 41, 81): 0.2201933579438403
# (86, 42, 81): 0.22260869539938197
#
# Approximating hitting prob for (87, 81, 82)
# (87, 81, 82): 0.26311907853981836
# (86, 82, 82): 0.21970271096091545
#
# Approximating hitting prob for (87, 82, 83)
# (87, 82, 83): 0.26391557566949225
# (86, 83, 83): 0.22061424386631723
#
# Approximating hitting prob for (87, 42, 83)
# (87, 42, 83): 0.22266647880838333
# (86, 43, 83): 0.23567904115768126
#
# Approximating hitting prob for (86, 84, 84)
# (86, 84, 84): 0.22124709342542614
# (85, 85, 84): 0.3221246420204126
#
# Approximating hitting prob for (87, 51, 84)
# (87, 51, 84): 0.24247301155700432
# (86, 52, 84): 0.24547570096194116
#
# Approximating hitting prob for (87, 84, 85)
# (87, 84, 85): 0.2654810598481162
# (86, 85, 85): 0.22184018184215926
#
# Approximating hitting prob for (87, 22, 87)
# (87, 22, 87): 0.2565272678673232
# (86, 23, 87): 0.25876025435662914
#
# Approximating hitting prob for (87, 44, 87)
# (87, 44, 87): 0.2955197088468257
# (86, 45, 87): 0.29978474105486735
#
# Approximating hitting prob for (87, 87, 88)
# (87, 87, 88): 0.3890699344918027
# (86, 88, 88): 0.35601022245396424
#
# Approximating hitting prob for (87, 88, 89)
# (87, 88, 89): 0.4004243808750862
# (86, 89, 89): 0.3563412258973133
#
# Approximating hitting prob for (87, 15, 89)
# (87, 15, 89): 0.24994025823464797
# (86, 16, 89): 0.25062982409975093
#
# Approximating hitting prob for (87, 18, 89)
# (87, 18, 89): 0.25337445471229086
# (86, 19, 89): 0.2551198268591071
#
# Approximating hitting prob for (87, 45, 89)
# (87, 45, 89): 0.3016077352213534
# (86, 46, 89): 0.302602487842606
#
# Approximating hitting prob for (87, 89, 90)
# (87, 89, 90): 0.4007368974725487
# (86, 90, 90): 0.3567766219578958
#
# Approximating hitting prob for (87, 90, 91)
# (87, 90, 91): 0.4011197719544752
# (86, 91, 91): 0.35714899195047217
#
# Approximating hitting prob for (87, 46, 91)
# (87, 46, 91): 0.30255052892625994
# (86, 47, 91): 0.30387370694967025
#
# Approximating hitting prob for (87, 91, 92)
# (87, 91, 92): 0.401507517963011
# (86, 92, 92): 0.35754949630649824
#
# Approximating hitting prob for (86, 93, 93)
# (86, 93, 93): 0.3580534671484037
# (85, 94, 93): 0.40373238332080913
#
# Approximating hitting prob for (87, 47, 93)
# (87, 47, 93): 0.30373934802960917
# (86, 48, 93): 0.3049186422285067
#
# Approximating hitting prob for (87, 93, 94)
# (87, 93, 94): 0.4024678171165233
# (86, 94, 94): 0.3585568486980353
#
# Approximating hitting prob for (86, 95, 95)
# (86, 95, 95): 0.35930299744460253
# (85, 96, 95): 0.40516278729669025
#
# Approximating hitting prob for (87, 16, 95)
# (87, 16, 95): 0.25269768729803577
# (86, 17, 95): 0.25383224763436957
#
# Approximating hitting prob for (87, 32, 95)
# (87, 32, 95): 0.2815083831473036
# (86, 33, 95): 0.2853051267398203
#
# Approximating hitting prob for (86, 96, 96)
# (86, 96, 96): 0.35956487828210476
# (85, 97, 96): 0.40585370978352525
#
# Approximating hitting prob for (86, 97, 97)
# (86, 97, 97): 0.36073264302155433
# (85, 98, 97): 0.40642483558902276
#
# Approximating hitting prob for (87, 14, 97)
# (87, 14, 97): 0.2507984950567075
# (86, 15, 97): 0.2537163984820037
#
# Approximating hitting prob for (87, 49, 97)
# (87, 49, 97): 0.30629559998025974
# (86, 50, 97): 0.3074179126909732
#
# Approximating hitting prob for (87, 97, 98)
# (87, 97, 98): 0.40486306280049433
# (86, 98, 98): 0.3610193336006882
#
# Approximating hitting prob for (86, 99, 99)
# (86, 99, 99): 0.36157257809275417
# (85, 100, 99): 0.40819551216236566
#
# Approximating hitting prob for (87, 20, 99)
# (87, 20, 99): 0.2590208368270395
# (86, 21, 99): 0.2606269962407461
# Approximating hitting prob for (87, 50, 99)
# (87, 50, 99): 0.3071533685372601
# (86, 51, 99): 0.3083838638703625
#
# Approximating hitting prob for (86, 100, 100)
# (86, 100, 100): 0.36187807444200537
# (85, 101, 100): 0.4086723925924088
#
# Approximating hitting prob for (87, 2, 32)
# (87, 2, 32): 0.062154245799804
# (86, 3, 32): 0.06340441917275179
#
# Approximating hitting prob for (87, 2, 91)
# (87, 2, 91): 0.2477319295831094
# (86, 3, 91): 0.24853025098490567
#
# Approximating hitting prob for (87, 2, 92)
# (87, 2, 92): 0.24791425177664575
# (86, 3, 92): 0.24868914788912178
#
# Approximating hitting prob for (87, 2, 95)
# (87, 2, 95): 0.2501031045377907
# (86, 3, 95): 0.2509519734682948
#
# Approximating hitting prob for (87, 2, 96)
# (87, 2, 96): 0.2502008382654676
# (86, 3, 96): 0.25117121659671854
#
# Approximating hitting prob for (87, 3, 94)
# (87, 3, 94): 0.2488332164467858
# (86, 4, 94): 0.2496414697114309
#
# Approximating hitting prob for (87, 3, 95)
# (87, 3, 95): 0.2489770775044803
# (86, 4, 95): 0.24982874862149904
#
# Approximating hitting prob for (87, 4, 4)
# (87, 4, 4): 0.002266171834976626
# (86, 5, 4): 0.003985505726979563
#
# Approximating hitting prob for (87, 4, 8)
# (87, 4, 8): 0.00586318448291668
# (86, 5, 8): 0.00795244440470032
#
# Approximating hitting prob for (87, 4, 97)
# (87, 4, 97): 0.2499805987282319
# (86, 5, 97): 0.25082508604353154
#
# Approximating hitting prob for (87, 4, 98)
# (87, 4, 98): 0.25015327045368513
# (86, 5, 98): 0.251106771755389
#
# Approximating hitting prob for (87, 5, 5)
# (87, 5, 5): 0.003461987609213023
# (86, 6, 5): 0.006068001478417368
#
# Approximating hitting prob for (87, 5, 10)
# (87, 5, 10): 0.008312937379243998
# (86, 6, 10): 0.012231607511194509
#
# Approximating hitting prob for (87, 5, 100)
# (87, 5, 100): 0.2511843290038282
# (86, 6, 100): 0.2526755092552631
#
# Approximating hitting prob for (87, 7, 7)
# (87, 7, 7): 0.007165550760053124
# (86, 8, 7): 0.01149185123387935
#
# Approximating hitting prob for (88, 4, 7)
# (88, 4, 7): 0.006062677718912606
# (87, 5, 7): 0.0068238537038474234
#
# Approximating hitting prob for (88, 7, 8)
# (88, 7, 8): 0.011324799808935582
# (87, 8, 8): 0.008365358299676278
#
# Approximating hitting prob for (88, 7, 16)
# (88, 7, 16): 0.024621062116847562
# (87, 8, 16): 0.023193459448378403
#
# Approximating hitting prob for (88, 8, 9)
# (88, 8, 9): 0.012688051781990367
# (87, 9, 9): 0.011190083249602687
#
# Approximating hitting prob for (88, 8, 18)
# (88, 8, 18): 0.027503514873807356
# (87, 9, 18): 0.025727033521321583
#
# Approximating hitting prob for (87, 10, 10)
# (87, 10, 10): 0.012445887833388564
# (86, 11, 10): 0.019584829303677335
#
# Approximating hitting prob for (87, 10, 30)
# (87, 10, 30): 0.06450691944715797
# (86, 11, 30): 0.06866779575470357
#
# Approximating hitting prob for (87, 11, 22)
# (87, 11, 22): 0.03696695253663605
# (86, 12, 22): 0.042081431003276985
#
# Approximating hitting prob for (87, 12, 12)
# (87, 12, 12): 0.019389861549836178
# (86, 13, 12): 0.027384384177993843
#
# Approximating hitting prob for (87, 12, 24)
# (87, 12, 24): 0.03990760386723218
# (86, 13, 24): 0.04883753658234674
#
# Approximating hitting prob for (87, 12, 36)
# (87, 12, 36): 0.07619310164224845
# (86, 13, 36): 0.08265529232927137
#
# Approximating hitting prob for (87, 12, 48)
# (87, 12, 48): 0.09018081507800464
# (86, 13, 48): 0.10399528200803464
#
# Approximating hitting prob for (87, 12, 96)
# (87, 12, 96): 0.24506749367951608
# (86, 13, 96): 0.2505289158100368
#
# Approximating hitting prob for (87, 13, 13)
# (87, 13, 13): 0.024333513508184076
# (86, 14, 13): 0.03055245154925246
#
# Approximating hitting prob for (87, 14, 14)
# (87, 14, 14): 0.025084526318204712
# (86, 15, 14): 0.03703980842735078
#
# Approximating hitting prob for (87, 14, 28)
# (87, 14, 28): 0.058365257830267324
# (86, 15, 28): 0.06605884047961326
#
# Approximating hitting prob for (87, 14, 42)
# (87, 14, 42): 0.08509124504326591
# (86, 15, 42): 0.10025663487329324
#
# Approximating hitting prob for (87, 14, 56)
# (87, 14, 56): 0.11229563436482311
# (86, 15, 56): 0.11991168848772572
#
# Approximating hitting prob for (87, 14, 70)
# (87, 14, 70): 0.12887201298371725
# (86, 15, 70): 0.13393554302353908
#
# Approximating hitting prob for (87, 14, 98)
# (87, 14, 98): 0.2501316176652038
# (86, 15, 98): 0.25405121039886774
#
# Approximating hitting prob for (87, 15, 15)
# (87, 15, 15): 0.031674577160871124
# (86, 16, 15): 0.04493986774435119
#
# Approximating hitting prob for (87, 15, 30)
# (87, 15, 30): 0.07266819362875956
# (86, 16, 30): 0.07807591859001918
#
# Approximating hitting prob for (88, 8, 15)
# (88, 8, 15): 0.02448905531002903
# (87, 9, 15): 0.025400568356428514
#
# Approximating hitting prob for (88, 15, 16)
# (88, 15, 16): 0.04419910532749611
# (87, 16, 16): 0.03239784354601067
#
# Approximating hitting prob for (88, 15, 32)
# (88, 15, 32): 0.0783514267250958
# (87, 16, 32): 0.07427515652997387
#
# Approximating hitting prob for (88, 15, 48)
# (88, 15, 48): 0.10597837229984187
# (87, 16, 48): 0.10369407958492582
#
# Approximating hitting prob for (88, 15, 96)
# (88, 15, 96): 0.2522393809163199
# (87, 16, 96): 0.252001496195135
#
# Approximating hitting prob for (88, 16, 17)
# (88, 16, 17): 0.04606479708908906
# (87, 17, 17): 0.03388321901234382
#
# Approximating hitting prob for (88, 16, 34)
# (88, 16, 34): 0.08043494851050152
# (87, 17, 34): 0.07550047025919535
#
# Approximating hitting prob for (88, 16, 51)
# (88, 16, 51): 0.11019778353241828
# (87, 17, 51): 0.10851638497453935
#
# Approximating hitting prob for (88, 16, 57)
# (88, 16, 57): 0.12223435789680469
# (87, 17, 57): 0.12216491783279848
#
# Approximating hitting prob for (88, 16, 68)
# (88, 16, 68): 0.13178902543096507
# (87, 17, 68): 0.13087227099972462
#
# Approximating hitting prob for (87, 18, 18)
# (87, 18, 18): 0.03613619329453719
# (86, 19, 18): 0.0511196285425334
#
# Approximating hitting prob for (87, 19, 19)
# (87, 19, 19): 0.038340347705278076
# (86, 20, 19): 0.053408523459370534
#
# Approximating hitting prob for (87, 19, 38)
# (87, 19, 38): 0.09630731698800639
# (86, 20, 38): 0.10570851195016323
#
# Approximating hitting prob for (87, 19, 57)
# (87, 19, 57): 0.12189191833726438
# (86, 20, 57): 0.12875616767017903
#
# Approximating hitting prob for (87, 20, 20)
# (87, 20, 20): 0.03987830921509896
# (86, 21, 20): 0.056046667833509735
#
# Approximating hitting prob for (87, 20, 40)
# (87, 20, 40): 0.09807527008443505
# (86, 21, 40): 0.10908213486511277
#
# Approximating hitting prob for (87, 20, 60)
# (87, 20, 60): 0.1251800731109399
# (86, 21, 60): 0.1333934001375988
#
# Approximating hitting prob for (87, 20, 62)
# (87, 20, 62): 0.13078596362791564
# (86, 21, 62): 0.13196270495016965
#
# Approximating hitting prob for (87, 20, 80)
# (87, 20, 80): 0.18201765871170786
# (86, 21, 80): 0.1904973350742306
#
# Approximating hitting prob for (87, 20, 100)
# (87, 20, 100): 0.25770500104002747
# (86, 21, 100): 0.26078333137690196
#
# Approximating hitting prob for (87, 7, 21)
# (87, 7, 21): 0.028555708928510892
# (86, 8, 21): 0.03485307114508525
#
# Approximating hitting prob for (87, 21, 21)
# (87, 21, 21): 0.04170490859621418
# (86, 22, 21): 0.06469019109788256
#
# Approximating hitting prob for (87, 21, 42)
# (87, 21, 42): 0.10155378197503717
# (86, 22, 42): 0.11357663909678807
#
# Approximating hitting prob for (87, 21, 63)
# (87, 21, 63): 0.12758397742147723
# (86, 22, 63): 0.13697256513443265
#
# Approximating hitting prob for (87, 21, 64)
# (87, 21, 64): 0.1328691704071663
# (86, 22, 64): 0.160608282419202
#
# Approximating hitting prob for (88, 11, 21)
# (88, 11, 21): 0.037913911116863944
# (87, 12, 21): 0.0403835947895738
#
# Approximating hitting prob for (88, 21, 44)
# (88, 21, 44): 0.11102811988887828
# (87, 22, 44): 0.10693103693868465
#
# Approximating hitting prob for (88, 22, 23)
# (88, 22, 23): 0.07265794616593844
# (87, 23, 23): 0.05953410387989103
#
# Approximating hitting prob for (88, 22, 46)
# (88, 22, 46): 0.11609802498872468
# (87, 23, 46): 0.10923317481883137
#
# Approximating hitting prob for (88, 22, 69)
# (88, 22, 69): 0.17730697397713624
# (87, 23, 69): 0.17362693940980378
#
# Approximating hitting prob for (88, 22, 92)
# (88, 22, 92): 0.25881406707925037
# (87, 23, 92): 0.2577823895948171
#
# Approximating hitting prob for (88, 8, 23)
# (88, 8, 23): 0.03715955211947598
# (87, 9, 23): 0.03793700768473055
#
# Approximating hitting prob for (87, 24, 24)
# (87, 24, 24): 0.0611618710692183
# (86, 25, 24): 0.07764866803524126
#
# Approximating hitting prob for (87, 24, 48)
# (87, 24, 48): 0.11455840719116735
# (86, 25, 48): 0.12426656157022664
#
# Approximating hitting prob for (87, 24, 67)
# (87, 24, 67): 0.17650445948338647
# (86, 25, 67): 0.17818220009160898
#
# Approximating hitting prob for (87, 24, 68)
# (87, 24, 68): 0.17926352860230532
# (86, 25, 68): 0.1806760236456345
#
# Approximating hitting prob for (87, 24, 72)
# (87, 24, 72): 0.17630309917334575
# (86, 25, 72): 0.185028176014396
#
# Approximating hitting prob for (87, 24, 96)
# (87, 24, 96): 0.25982828494970317
# (86, 25, 96): 0.263580610176733
#
# Approximating hitting prob for (87, 25, 25)
# (87, 25, 25): 0.06401499165235398
# (86, 26, 25): 0.08042890854884599
#
# Approximating hitting prob for (87, 25, 50)
# (87, 25, 50): 0.11731004552807577
# (86, 26, 50): 0.1279899946379391
#
# Approximating hitting prob for (87, 25, 68)
# (87, 25, 68): 0.17802746981624332
# (86, 26, 68): 0.17983053338297025
#
# Approximating hitting prob for (87, 25, 70)
# (87, 25, 70): 0.18095255333260118
# (86, 26, 70): 0.18349342059887228
#
# Approximating hitting prob for (87, 25, 75)
# (87, 25, 75): 0.18249378750824305
# (86, 26, 75): 0.19152748366470387
#
# Approximating hitting prob for (87, 25, 100)
# (87, 25, 100): 0.26217989221068067
# (86, 26, 100): 0.2664268468463964
#
# Approximating hitting prob for (87, 13, 26)
# (87, 13, 26): 0.05413273628801982
# (86, 14, 26): 0.059556489490255604
#
# Approximating hitting prob for (87, 26, 26)
# (87, 26, 26): 0.0648693484098256
# (86, 27, 26): 0.08458763283843969
#
# Approximating hitting prob for (87, 26, 52)
# (87, 26, 52): 0.11966087002937818
# (86, 27, 52): 0.1325699662605767
#
# Approximating hitting prob for (87, 26, 69)
# (87, 26, 69): 0.17957160597519226
# (86, 27, 69): 0.18166673886997342
#
# Approximating hitting prob for (87, 26, 78)
# (87, 26, 78): 0.18510067617253498
# (86, 27, 78): 0.19753441633355784
#
# Approximating hitting prob for (87, 27, 27)
# (87, 27, 27): 0.06847384760285687
# (86, 28, 27): 0.0872401033490936
#
# Approximating hitting prob for (87, 27, 54)
# (87, 27, 54): 0.1237203137290291
# (86, 28, 54): 0.13445695639166858
#
# Approximating hitting prob for (87, 27, 81)
# (87, 27, 81): 0.1923398852631302
# (86, 28, 81): 0.20170041427877758
#
# Approximating hitting prob for (88, 14, 27)
# (88, 14, 27): 0.05972041767675742
# (87, 15, 27): 0.06369333452710522
#
# Approximating hitting prob for (88, 27, 28)
# (88, 27, 28): 0.08558767531498274
# (87, 28, 28): 0.07050765164800273
#
# Approximating hitting prob for (88, 27, 56)
# (88, 27, 56): 0.13340724558674963
# (87, 28, 56): 0.12556170235104122
#
# Approximating hitting prob for (88, 27, 84)
# (88, 27, 84): 0.20178521556694587
# (87, 28, 84): 0.1970467514499018
#
# Approximating hitting prob for (88, 29, 30)
# (88, 29, 30): 0.10334208457885936
# (87, 30, 30): 0.09736823850248277
#
# Approximating hitting prob for (88, 30, 31)
# (88, 30, 31): 0.11442323039494594
# (87, 31, 31): 0.09807896382942675
#
# Approximating hitting prob for (88, 30, 62)
# (88, 30, 62): 0.18590821616057773
# (87, 31, 62): 0.1783435761318876
#
# Approximating hitting prob for (88, 30, 74)
# (88, 30, 74): 0.2019274041710595
# (87, 31, 74): 0.20159364659863246
#
# Approximating hitting prob for (88, 30, 93)
# (88, 30, 93): 0.2789633083221103
# (87, 31, 93): 0.27292308227914114
#
# Approximating hitting prob for (87, 32, 32)
# (87, 32, 32): 0.09916888863962396
# (86, 33, 32): 0.11892762191241411
#
# Approximating hitting prob for (87, 32, 48)
# (87, 32, 48): 0.1387241051260454
# (86, 33, 48): 0.142429968622619
#
# Approximating hitting prob for (87, 32, 64)
# (87, 32, 64): 0.1799070660290524
# (86, 33, 64): 0.1914527162201818
#
# Approximating hitting prob for (87, 32, 75)
# (87, 32, 75): 0.20278097100946157
# (86, 33, 75): 0.20637214997457
#
# Approximating hitting prob for (87, 32, 96)
# (87, 32, 96): 0.2746993991669564
# (86, 33, 96): 0.2855087157476717
#
# Approximating hitting prob for (87, 33, 33)
# (87, 33, 33): 0.1018409321473755
# (86, 34, 33): 0.12041123625904308
#
# Approximating hitting prob for (87, 33, 66)
# (87, 33, 66): 0.18332633709812737
# (86, 34, 66): 0.1944304926299697
#
# Approximating hitting prob for (87, 33, 99)
# (87, 33, 99): 0.27951021034508533
# (86, 34, 99): 0.28769290405864495
#
# Approximating hitting prob for (88, 17, 33)
# (88, 17, 33): 0.07985672491304413
# (87, 18, 33): 0.08923320701113911
#
# Approximating hitting prob for (88, 33, 34)
# (88, 33, 34): 0.11916386768467103
# (87, 34, 34): 0.10291389421623304
#
# Approximating hitting prob for (88, 33, 51)
# (88, 33, 51): 0.14330014523093734
# (87, 34, 51): 0.14227402998264052
#
# Approximating hitting prob for (88, 33, 68)
# (88, 33, 68): 0.19315085477995741
# (87, 34, 68): 0.1861659408291587
#
# Approximating hitting prob for (88, 34, 35)
# (88, 34, 35): 0.1205214856867643
# (87, 35, 35): 0.10455157978077446
#
# Approximating hitting prob for (88, 34, 37)
# (88, 34, 37): 0.12442137119862284
# (87, 35, 37): 0.12436479403687976
#
# Approximating hitting prob for (88, 34, 70)
# (88, 34, 70): 0.19584740230416056
# (87, 35, 70): 0.1919850638406695
#
# Approximating hitting prob for (88, 34, 78)
# (88, 34, 78): 0.2108258567737614
# (87, 35, 78): 0.2102999455156321
#
# Approximating hitting prob for (88, 9, 35)
# (88, 9, 35): 0.07360352993474607
# (87, 10, 35): 0.07458490015706869
#
# Approximating hitting prob for (87, 18, 36)
# (87, 18, 36): 0.09488878782539652
# (86, 19, 36): 0.10306467908466765
#
# Approximating hitting prob for (87, 24, 36)
# (87, 24, 36): 0.10083206893730669
# (86, 25, 36): 0.1064118066420225
#
# Approximating hitting prob for (87, 36, 36)
# (87, 36, 36): 0.10521827045402905
# (86, 37, 36): 0.1247353047690329
#
# Approximating hitting prob for (87, 36, 38)
# (87, 36, 38): 0.1255634101464931
# (86, 37, 38): 0.12590141705024552
#
# Approximating hitting prob for (87, 36, 54)
# (87, 36, 54): 0.18199676375548632
# (86, 37, 54): 0.18484351224119355
#
# Approximating hitting prob for (87, 36, 72)
# (87, 36, 72): 0.19351609868326614
# (86, 37, 72): 0.20413082975724658
#
# Approximating hitting prob for (87, 36, 79)
# (87, 36, 79): 0.21193796755398228
# (86, 37, 79): 0.21660172580211032
#
# Approximating hitting prob for (87, 37, 37)
# (87, 37, 37): 0.10651722127820802
# (86, 38, 37): 0.12590141705024552
#
# Approximating hitting prob for (87, 37, 74)
# (87, 37, 74): 0.19456525641565262
# (86, 38, 74): 0.212159407034728
#
# Approximating hitting prob for (87, 37, 90)
# (87, 37, 90): 0.2840050919951249
# (86, 38, 90): 0.2854602632426147
#
# Approximating hitting prob for (88, 19, 37)
# (88, 19, 37): 0.10348227274918209
# (87, 20, 37): 0.10380498935038535
#
# Approximating hitting prob for (88, 37, 38)
# (88, 37, 38): 0.12488459140088143
# (87, 38, 38): 0.10740691517872074
#
# Approximating hitting prob for (87, 38, 57)
# (87, 38, 57): 0.1853213291944017
# (86, 39, 57): 0.18922638444505102
#
# Approximating hitting prob for (87, 38, 76)
# (87, 38, 76): 0.20299394152709724
# (86, 39, 76): 0.2145771474786554
#
# Approximating hitting prob for (87, 13, 39)
# (87, 13, 39): 0.08119399924122526
# (86, 14, 39): 0.08661917681547672
#
# Approximating hitting prob for (87, 39, 39)
# (87, 39, 39): 0.10845533804830165
# (86, 40, 39): 0.12874480523272733
#
# Approximating hitting prob for (88, 38, 40)
# (88, 38, 40): 0.12858849201976089
# (87, 39, 40): 0.12821465628201803
#
# Approximating hitting prob for (88, 38, 78)
# (88, 38, 78): 0.21368378574950955
# ...
#
# Approximating hitting prob for (88, 11, 11)
# (88, 11, 11): 0.01685987905192621
# (87, 12, 11): 0.02325257413190876
#
# Approximating hitting prob for (88, 11, 22)
# (88, 11, 22): 0.03624392813830257
# (87, 12, 22): 0.04161057932559089
#
# Approximating hitting prob for (88, 12, 12)
# (88, 12, 12): 0.0190724324367984
# (87, 13, 12): 0.027115454330257135
#
# Approximating hitting prob for (88, 12, 24)
# (88, 12, 24): 0.03947938296263899
# (87, 13, 24): 0.04854043857307614
#
# Approximating hitting prob for (88, 12, 36)
# (88, 12, 36): 0.07581105790761088
# (87, 13, 36): 0.08227105329480458
#
# Approximating hitting prob for (88, 12, 48)
# (88, 12, 48): 0.08978787333833338
# (87, 13, 48): 0.10043001490068715
#
# Approximating hitting prob for (88, 13, 13)
# (88, 13, 13): 0.024268347928582804
# (87, 14, 13): 0.030366779773195754
#
# Approximating hitting prob for (88, 14, 14)
# (88, 14, 14): 0.02500081104696085
# (87, 15, 14): 0.03556343783975363
#
# Approximating hitting prob for (88, 14, 28)
# (88, 14, 28): 0.057959286152370774
# (87, 15, 28): 0.06540473090612715
#
# Approximating hitting prob for (88, 14, 42)
# (88, 14, 42): 0.08471853020914714
# (87, 15, 42): 0.09684627914873528
#
# Approximating hitting prob for (88, 14, 43)
# (88, 14, 43): 0.08873284329548276
# (87, 15, 43): 0.10033869313693115
#
# Approximating hitting prob for (88, 15, 15)
# (88, 15, 15): 0.03160427777044818
# (87, 16, 15): 0.04471625035557673
#
# Approximating hitting prob for (88, 15, 30)
# (88, 15, 30): 0.07232921409976396
# (87, 16, 30): 0.07759868728018718
#
# Approximating hitting prob for (89, 8, 15)
# (89, 8, 15): 0.024269178757239857
# (88, 9, 15): 0.025211671029832235
#
# Approximating hitting prob for (89, 15, 16)
# (89, 15, 16): 0.04348077859188837
# (88, 16, 16): 0.032266554720203344
#
# Approximating hitting prob for (89, 15, 32)
# (89, 15, 32): 0.07776030475729682
# (88, 16, 32): 0.07399488327240887
#
# Approximating hitting prob for (89, 15, 48)
# (89, 15, 48): 0.10557762519499708
# (88, 16, 48): 0.10322323405706628
#
# Approximating hitting prob for (89, 15, 55)
# (89, 15, 55): 0.11490403596767469
# (88, 16, 55): 0.11479268089428492
#
# Approximating hitting prob for (89, 15, 96)
# (89, 15, 96): 0.25188035555800053
# (88, 16, 96): 0.2513259313883655
#
# Approximating hitting prob for (89, 16, 17)
# (89, 16, 17): 0.045817186459578864
# (88, 17, 17): 0.03379597637115282
#
# Approximating hitting prob for (89, 16, 34)
# (89, 16, 34): 0.08000266570255264
# (88, 17, 34): 0.07534687353429223
#
# Approximating hitting prob for (89, 16, 51)
# (89, 16, 51): 0.10950183489585201
# (88, 17, 51): 0.10776252621337674
#
# Approximating hitting prob for (89, 16, 68)
# (89, 16, 68): 0.13065692086900607
# (88, 17, 68): 0.12998626516372205
#
# Approximating hitting prob for (88, 18, 18)
# (88, 18, 18): 0.035842212551324644
# (87, 19, 18): 0.050712412935622404
#
# Approximating hitting prob for (88, 18, 27)
# (88, 18, 27): 0.06577461020120205
# (87, 19, 27): 0.06943245932292125
#
# Approximating hitting prob for (88, 19, 19)
# (88, 19, 19): 0.03817369771946011
# (87, 20, 19): 0.052801199398779114
#
# Approximating hitting prob for (88, 19, 38)
# (88, 19, 38): 0.09580136274686661
# (87, 20, 38): 0.10484557525626644
#
# Approximating hitting prob for (88, 19, 48)
# (88, 19, 48): 0.1097339170269092
# (87, 20, 48): 0.11621820555480789
#
# Approximating hitting prob for (88, 19, 57)
# (88, 19, 57): 0.12155832784889571
# (87, 20, 57): 0.1278226935917612
#
# Approximating hitting prob for (88, 19, 76)
# (88, 19, 76): 0.17389832791605864
# (87, 20, 76): 0.1780847369860712
#
# Approximating hitting prob for (88, 20, 20)
# (88, 20, 20): 0.03954932744224995
# (87, 21, 20): 0.05528088740873832
#
# Approximating hitting prob for (88, 20, 40)
# (88, 20, 40): 0.0978355973002278
# (87, 21, 40): 0.10852258705085459
#
# Approximating hitting prob for (88, 20, 60)
# (88, 20, 60): 0.12475685864844742
# (87, 21, 60): 0.13134729704605513
#
# Approximating hitting prob for (88, 20, 80)
# (88, 20, 80): 0.1814702781883201
# (87, 21, 80): 0.1878863202624461
#
# Approximating hitting prob for (88, 20, 100)
# (88, 20, 100): 0.257011190629669
# (87, 21, 100): 0.26045626160013796
#
# Approximating hitting prob for (88, 21, 21)
# (88, 21, 21): 0.04144168851885512
# (87, 22, 21): 0.062307486064715235
#
# Approximating hitting prob for (88, 21, 42)
# (88, 21, 42): 0.1013427844364186
# (87, 22, 42): 0.11093467111221687
#
# Approximating hitting prob for (88, 21, 50)
# (88, 21, 50): 0.1203666534404475
# (87, 22, 50): 0.12167173217335664
#
# Approximating hitting prob for (88, 21, 63)
# (88, 21, 63): 0.1271973183020022
# (87, 22, 63): 0.13583361202760977
#
# Approximating hitting prob for (88, 21, 64)
# (88, 21, 64): 0.13199045168149398
# (87, 22, 64): 0.13667709891779609
#
# Approximating hitting prob for (89, 11, 21)
# (89, 11, 21): 0.03759034594814068
# (88, 12, 21): 0.039001833674203734
#
# Approximating hitting prob for (89, 21, 22)
# (89, 21, 22): 0.05632035378863048
# (88, 22, 22): 0.053763440860215055
#
# Approximating hitting prob for (89, 21, 44)
# (89, 21, 44): 0.11022116881658861
# (88, 22, 44): 0.10550458715595556
#
# Approximating hitting prob for (89, 21, 51)
# (89, 21, 51): 0.12246548393147438
# (88, 22, 51): 0.12172852433698639
#
# Approximating hitting prob for (89, 22, 23)
# (89, 22, 23): 0.07024565035639461
# (88, 23, 23): 0.059318027314273075
#
# Approximating hitting prob for (89, 22, 46)
# (89, 22, 46): 0.1154449143556906
# (88, 23, 46): 0.10845137954160707
#
# Approximating hitting prob for (89, 22, 69)
# (89, 22, 69): 0.17361354557999242
# (88, 23, 69): 0.173221070366076
#
# Approximating hitting prob for (89, 8, 23)
# (89, 8, 23): 0.03680301465689385
# (88, 9, 23): 0.037200055388201654
#
# Approximating hitting prob for (88, 24, 24)
# (88, 24, 24): 0.06081596070063703
# (87, 25, 24): 0.07694080650409138
#
# Approximating hitting prob for (88, 24, 48)
# (88, 24, 48): 0.1124288216818159
# (87, 25, 48): 0.1237293439835358
#
# Approximating hitting prob for (88, 24, 72)
# (88, 24, 72): 0.17561824796120884
# (87, 25, 72): 0.1841964354280915
#
# Approximating hitting prob for (88, 24, 96)
# (88, 24, 96): 0.2590532946586614
# (87, 25, 96): 0.26322944319318814
#
# Approximating hitting prob for (88, 25, 25)
# (88, 25, 25): 0.06227235784180989
# (87, 26, 25): 0.07941611000579034
#
# Approximating hitting prob for (88, 25, 50)
# (88, 25, 50): 0.11577116078138878
# (87, 26, 50): 0.1267805640018065
#
# Approximating hitting prob for (88, 25, 54)
# (88, 25, 54): 0.12976349057008688
# (87, 26, 54): 0.1317364062887674
#
# Approximating hitting prob for (88, 25, 70)
# (88, 25, 70): 0.1804148608004801
# (87, 26, 70): 0.18249991140109442
#
# Approximating hitting prob for (88, 25, 75)
# (88, 25, 75): 0.1783140337605713
# (87, 26, 75): 0.19029002542357099
#
# Approximating hitting prob for (88, 25, 100)
# (88, 25, 100): 0.26101138407806673
# (87, 26, 100): 0.26492067462296265
#
# Approximating hitting prob for (88, 26, 26)
# (88, 26, 26): 0.06470484517858141
# (87, 27, 26): 0.08326356098943324
#
# Approximating hitting prob for (88, 26, 52)
# (88, 26, 52): 0.11929934331817205
# (87, 27, 52): 0.13002556375777638
#
# Approximating hitting prob for (88, 26, 55)
# (88, 26, 55): 0.13165156769554096
# (87, 27, 55): 0.13334260851127513
#
# Approximating hitting prob for (88, 26, 78)
# (88, 26, 78): 0.18466632706065836
# (87, 27, 78): 0.19503432867916046
#
# Approximating hitting prob for (88, 27, 27)
# (88, 27, 27): 0.06791894155957137
# (87, 28, 27): 0.08631711844546296
#
# Approximating hitting prob for (88, 27, 54)
# (88, 27, 54): 0.12335442278030774
# (87, 28, 54): 0.13375820904955524
#
# Approximating hitting prob for (89, 26, 56)
# (89, 26, 56): 0.13385204483392862
# (88, 27, 56): 0.13340724558674963
#
# Approximating hitting prob for (89, 26, 81)
# (89, 26, 81): 0.1961088086673218
# (88, 27, 81): 0.19093098343319315
#
# Approximating hitting prob for (88, 28, 28)
# (88, 28, 28): 0.06996620267554672
# (87, 29, 28): 0.09757382712204592
#
# Approximating hitting prob for (88, 28, 56)
# (88, 28, 56): 0.12511472578880414
# (87, 29, 56): 0.14482235234896304
# Approximating hitting prob for (88, 28, 57)
# (88, 28, 57): 0.13451829421697198
# (87, 29, 57): 0.14517141947537712
#
# Approximating hitting prob for (88, 28, 84)
# (88, 28, 84): 0.1956608906883296
# (87, 29, 84): 0.21377073063435034
#
# Approximating hitting prob for (88, 29, 29)
# (88, 29, 29): 0.07146249734398265
# (87, 30, 29): 0.11294947603473328
#
# Approximating hitting prob for (88, 29, 58)
# (88, 29, 58): 0.12644225670397208
# (87, 30, 58): 0.18197194029512034
#
# Approximating hitting prob for (88, 29, 87)
# (88, 29, 87): 0.19899355465833682
# (87, 30, 87): 0.2747494845244535
#
# Approximating hitting prob for (88, 30, 30)
# (88, 30, 30): 0.09714830682368271
# (87, 31, 30): 0.1148230260669957
#
# Approximating hitting prob for (88, 31, 31)
# (88, 31, 31): 0.09792725473591174
# (87, 32, 31): 0.11600810780666072
#
# Approximating hitting prob for (88, 31, 62)
# (88, 31, 62): 0.17773191866989232
# (87, 32, 62): 0.1878520152739173
#
# Approximating hitting prob for (88, 31, 80)
# (88, 31, 80): 0.2097396793656617
# (87, 32, 80): 0.2125642351689041
#
# Approximating hitting prob for (88, 31, 93)
# (88, 31, 93): 0.2725498124508612
# (87, 32, 93): 0.2811909827832337
#
# Approximating hitting prob for (89, 16, 31)
# (89, 16, 31): 0.07743408001818619
# (88, 17, 31): 0.07963251711672042
#
# Approximating hitting prob for (89, 31, 32)
# (89, 31, 32): 0.11514098617926848
# (88, 32, 32): 0.09881769010474889
#
# Approximating hitting prob for (89, 31, 48)
# (89, 31, 48): 0.13870178119171075
# (88, 32, 48): 0.13819798732340433
#
# Approximating hitting prob for (89, 31, 61)
# (89, 31, 61): 0.18571422381117866
# (88, 32, 61): 0.18446665917686175
#
# Approximating hitting prob for (89, 31, 64)
# (89, 31, 64): 0.18693030116503462
# (88, 32, 64): 0.17949465414918586
#
# Approximating hitting prob for (89, 31, 96)
# (89, 31, 96): 0.27994845263054463
# (88, 32, 96): 0.2741885136082182
#
# Approximating hitting prob for (89, 32, 33)
# (89, 32, 33): 0.11620964308512942
# (88, 33, 33): 0.10101028194464957
#
# Approximating hitting prob for (89, 32, 62)
# (89, 32, 62): 0.18668296457792866
# (88, 33, 62): 0.1858925860559151
#
# Approximating hitting prob for (89, 32, 66)
# (89, 32, 66): 0.1896152387708392
# (88, 33, 66): 0.1824478821019516
#
# Approximating hitting prob for (89, 32, 99)
# (89, 32, 99): 0.2818096600447226
# (88, 33, 99): 0.2774623233497526
#
# Approximating hitting prob for (88, 34, 34)
# (88, 34, 34): 0.10230899647951448
# (87, 35, 34): 0.12123010119499202
#
# Approximating hitting prob for (88, 34, 51)
# (88, 34, 51): 0.14170732695369215
# (87, 35, 51): 0.14553090806190194
#
# Approximating hitting prob for (88, 34, 63)
# (88, 34, 63): 0.18720449848287027
# (87, 35, 63): 0.18883858363228367
#
# Approximating hitting prob for (88, 34, 68)
# (88, 34, 68): 0.18546633664687773
# (87, 35, 68): 0.1958452089284973
#
# Approximating hitting prob for (88, 35, 35)
# (88, 35, 35): 0.10334782074525727
# (87, 36, 35): 0.12273417314791372
#
# Approximating hitting prob for (88, 35, 64)
# (88, 35, 64): 0.1885424887462381
# (87, 36, 64): 0.19173474778525001
#
# Approximating hitting prob for (88, 35, 70)
# (88, 35, 70): 0.1868848190890562
# (87, 36, 70): 0.20147313931457714
#
# Approximating hitting prob for (88, 35, 87)
# (88, 35, 87): 0.2198700238997434
# (87, 36, 87): 0.2792916799726491
#
# Approximating hitting prob for (88, 9, 36)
# (88, 9, 36): 0.07259161866619546
# (87, 10, 36): 0.07550273954705695
#
# Approximating hitting prob for (89, 12, 35)
# (89, 12, 35): 0.07759355290482231
# (88, 13, 35): 0.08109193043988505
#
# Approximating hitting prob for (89, 24, 35)
# (89, 24, 35): 0.10088546521288723
# (88, 25, 35): 0.10203754127205333
#
# Approximating hitting prob for (89, 35, 36)
# (89, 35, 36): 0.12180574592807258
# (88, 36, 36): 0.10491149548144753
#
# Approximating hitting prob for (89, 35, 72)
# (89, 35, 72): 0.2002499156202068
# (88, 36, 72): 0.19266908629944393
#
# Approximating hitting prob for (89, 36, 37)
# (89, 36, 37): 0.12295654752303063
# (88, 37, 37): 0.10623214012782901
#
# Approximating hitting prob for (89, 36, 74)
# (89, 36, 74): 0.2025202404479424
# (88, 37, 74): 0.19418171434014606
#
# Approximating hitting prob for (89, 36, 90)
# (89, 36, 90): 0.28400588796145726
# (88, 37, 90): 0.28327583409308604
#
# Approximating hitting prob for (88, 38, 38)
# (88, 38, 38): 0.10712539951673351
# (87, 39, 38): 0.1268017946077399
#
# Approximating hitting prob for (88, 38, 57)
# (88, 38, 57): 0.1843669693347397
# (87, 39, 57): 0.18808923632601482
#
# Approximating hitting prob for (88, 38, 67)
# (88, 38, 67): 0.19517268745545713
# (87, 39, 67): 0.19905403513357778
#
# Approximating hitting prob for (88, 38, 76)
# (88, 38, 76): 0.2024829492168088
# (87, 39, 76): 0.2138715032613864
#
# Approximating hitting prob for (88, 13, 39)
# (88, 13, 39): 0.08098114089434455
# (87, 14, 39): 0.08618006631987331
#
# Approximating hitting prob for (88, 39, 39)
# (88, 39, 39): 0.1080179901631878
# (87, 40, 39): 0.12821465628201803
#
# Approximating hitting prob for (89, 38, 40)
# (89, 38, 40): 0.12775678313381628
# (88, 39, 40): 0.12769085680734998
#
# Approximating hitting prob for (89, 38, 68)
# (89, 38, 68): 0.19740849003649807
# (88, 39, 68): 0.19627607339362893
#
# Approximating hitting prob for (89, 38, 78)
# (89, 38, 78): 0.21246115859658174
# (88, 39, 78): 0.2037978934044051
#
# Approximating hitting prob for (88, 40, 40)
# (88, 40, 40): 0.10943859940463435
# (87, 41, 40): 0.1297932801091923
#
# Approximating hitting prob for (89, 39, 41)
# (89, 39, 41): 0.12911885507869128
# (88, 40, 41): 0.12902887172604935
#
# Approximating hitting prob for (89, 39, 80)
# (89, 39, 80): 0.21531049273313774
# (88, 40, 80): 0.20696436000065802
#
# Approximating hitting prob for (89, 39, 95)
# (89, 39, 95): 0.287296073132715
# (88, 40, 95): 0.2871875235788615
#
# Approximating hitting prob for (89, 40, 41)
# (89, 40, 41): 0.12833894911675495
# (88, 41, 41): 0.11003174646251097
#
# Approximating hitting prob for (88, 41, 70)
# (88, 41, 70): 0.2048997204092339
# (87, 42, 70): 0.20604625473161686
#
# Approximating hitting prob for (88, 41, 82)
# (88, 41, 82): 0.20929211438870232
# (87, 42, 82): 0.222331436248795
#
# Approximating hitting prob for (89, 14, 41)
# (89, 14, 41): 0.08686377664975542
# (88, 15, 41): 0.08979837091598454
#
# Approximating hitting prob for (88, 42, 42)
# (88, 42, 42): 0.11058470760976348
# (87, 43, 42): 0.13531631921527093
#
# Approximating hitting prob for (88, 42, 63)
# (88, 42, 63): 0.19561343577644208
# (87, 43, 63): 0.20024633273345094
#
# Approximating hitting prob for (88, 42, 71)
# (88, 42, 71): 0.20686083660869614
# (87, 43, 71): 0.20896150380913356
#
# Approximating hitting prob for (88, 42, 84)
# (88, 42, 84): 0.21185089523133885
# (87, 43, 84): 0.22404351119228336
#
# Approximating hitting prob for (88, 42, 98)
# (88, 42, 98): 0.2904770338570352
# (87, 43, 98): 0.2925681860362373
#
# Approximating hitting prob for (88, 42, 99)
# (88, 42, 99): 0.2912239848496772
# (87, 43, 99): 0.29284731940417447
#
# Approximating hitting prob for (88, 43, 43)
# (88, 43, 43): 0.11094529399113952
# (87, 44, 43): 0.16826200600308117
#
# Approximating hitting prob for (88, 43, 72)
# (88, 43, 72): 0.20825877024250058
# (87, 44, 72): 0.2217357924685149
#
# Approximating hitting prob for (88, 43, 86)
# (88, 43, 86): 0.21396982881124008
# (87, 44, 86): 0.23952686922770883
#
# Approximating hitting prob for (88, 43, 100)
# (88, 43, 100): 0.2918655234755545
# (87, 44, 100): 0.3055543995974272
#
# Approximating hitting prob for (89, 22, 43)
# (89, 22, 43): 0.11029850330290998
# (88, 23, 43): 0.11444054971920437
#
# Approximating hitting prob for (89, 44, 45)
# (89, 44, 45): 0.16826149042603308
# (88, 45, 45): 0.16356201801318662
#
# Approximating hitting prob for (88, 46, 46)
# (88, 46, 46): 0.16390369136688582
# (87, 47, 46): 0.20607553386906954
#
# Approximating hitting prob for (88, 46, 69)
# (88, 46, 69): 0.21772451564079412
# (87, 47, 69): 0.22148424732821217
#
# Approximating hitting prob for (88, 46, 75)
# (88, 46, 75): 0.22667544784262508
# (87, 47, 75): 0.2277710630638139
#
# Approximating hitting prob for (88, 46, 92)
# (88, 46, 92): 0.2918248433612231
# (87, 47, 92): 0.3035565316637226
#
# Approximating hitting prob for (88, 47, 47)
# (88, 47, 47): 0.16452840529115606
# (87, 48, 47): 0.20697851676248227
#
# Approximating hitting prob for (88, 47, 76)
# (88, 47, 76): 0.2276889307352434
# (87, 48, 76): 0.22986274561068396
#
# Approximating hitting prob for (88, 47, 94)
# (88, 47, 94): 0.29293074810410125
# (87, 48, 94): 0.30442298410545693
#
# Approximating hitting prob for (89, 12, 47)
# (89, 12, 47): 0.09056623341693422
# (88, 13, 47): 0.09362793944453258
# Approximating hitting prob for (89, 24, 47)
# (89, 24, 47): 0.11794643349299895
# (88, 25, 47): 0.12095716163785729
