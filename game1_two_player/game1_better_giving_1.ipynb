# %%
# %run 'game1_global.ipynb'
# %run 'game1_loser_analysis.ipynb'

# %% [markdown]
# # When is player 1 better off giving away $1?

# %%
betterGiving1 = findBetterGiving1(1,1000)
betterGiving1

# %%
exportStateProbs(DATA_DIR + 'game1_better_giving_1_memo_1-1000.csv', betterGiving1)

# %%
# retrieve probabilities from file
betterGiving1, given1 = readApproxBetterGiving1Probs(DATA_DIR + 'game1_better_giving_1_memo_1-100.csv')

# %%
betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
                                       filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv')
# Out:
# Approximating hitting prob for (11, 19, 48)
# (11, 19, 48): 0.5334260883826906
# (10, 19, 48): 0.5333426632228018
#
# Approximating hitting prob for (12, 21, 53)
# (12, 21, 53): 0.5340626283748265
# (11, 21, 53): 0.5334548685835285
#
# Approximating hitting prob for (12, 32, 42)
# (12, 32, 42): 0.5301153617677242
# (11, 32, 42): 0.5299467192997049
#
# Approximating hitting prob for (13, 22, 56)
# (13, 22, 56): 0.5328628830327213
# (12, 22, 56): 0.532734806781722
#
# Approximating hitting prob for (13, 23, 58)
# (13, 23, 58): 0.5343093271797525
# (12, 23, 58): 0.5335330764863161
#
# Approximating hitting prob for (13, 35, 46)
# (13, 35, 46): 0.5303291922468697
# (12, 35, 46): 0.5299937351500015
#
# Approximating hitting prob for (14, 24, 61)
# (14, 24, 61): 0.5334281050874531
# (13, 24, 61): 0.532844623278078
#
# Approximating hitting prob for (14, 25, 63)
# (14, 25, 63): 0.534598505539718
# (13, 25, 63): 0.5335740856592848
#
# Approximating hitting prob for (14, 38, 50)
# (14, 38, 50): 0.5306453312687435
# (13, 38, 50): 0.5300535494230575
#
# Approximating hitting prob for (15, 26, 66)
# (15, 26, 66): 0.5335384252806683
# (14, 26, 66): 0.532976559038264
#
# Approximating hitting prob for (15, 27, 68)
# (15, 27, 68): 0.5347937376379311
# (14, 27, 68): 0.5336038259570041
#
# Approximating hitting prob for (15, 40, 52)
# (15, 40, 52): 0.5298390830172897
# (14, 40, 52): 0.5294060634902246
#
# Approximating hitting prob for (15, 41, 54)
# (15, 41, 54): 0.530814252978444
# (14, 41, 54): 0.5300859465232839
#
# Approximating hitting prob for (16, 27, 69)
# (16, 27, 69): 0.5327214805171471
# (15, 27, 69): 0.5323471322790065
#
# Approximating hitting prob for (16, 28, 71)
# (16, 28, 71): 0.533984832978568
# (15, 28, 71): 0.5330636314503749
#
# Approximating hitting prob for (16, 29, 73)
# (16, 29, 73): 0.5349109988994238
# (15, 29, 73): 0.5336260136575318
#
# Approximating hitting prob for (16, 42, 54)
# (16, 42, 54): 0.528455476635441
# (15, 42, 54): 0.5285157285081951
#
# Approximating hitting prob for (16, 43, 56)
# (16, 43, 56): 0.5300165256608894
# (15, 43, 56): 0.5295344851774494
#
# Approximating hitting prob for (16, 44, 58)
# (16, 44, 58): 0.5309755142180325
# (15, 44, 58): 0.5301059314171186
#
# Approximating hitting prob for (17, 29, 74)
# (17, 29, 74): 0.5332717628242919
# (16, 29, 74): 0.5324865172144486
#
# Approximating hitting prob for (17, 30, 76)
# (17, 30, 76): 0.5341834675713876
# (16, 30, 76): 0.5331293350131605
#
# Approximating hitting prob for (17, 31, 78)
# (17, 31, 78): 0.535032026741298
# (16, 31, 78): 0.5336384909534596
#
# Approximating hitting prob for (17, 44, 56)
# (17, 44, 56): 0.5279972266134371
# (16, 44, 56): 0.5279422800090446
#
# Approximating hitting prob for (17, 45, 58)
# (17, 45, 58): 0.529004914693246
# (16, 45, 58): 0.528895160602941
#
# Approximating hitting prob for (17, 46, 60)
# (17, 46, 60): 0.5301804342251579
# (16, 46, 60): 0.5296194711867167
#
# Approximating hitting prob for (17, 47, 62)
# (17, 47, 62): 0.5311378673662993
# (16, 47, 62): 0.5301263625686753
#
# Approximating hitting prob for (18, 27, 71)
# (18, 27, 71): 0.525620501017532
# (17, 27, 71): 0.5254981980685945
#
# Approximating hitting prob for (18, 28, 73)
# (18, 28, 73): 0.5271004988262395
# (17, 28, 73): 0.5270411065910542
#
# Approximating hitting prob for (18, 31, 79)
# (18, 31, 79): 0.5335270635741508
# (17, 31, 79): 0.5326072076759126
#
# Approximating hitting prob for (18, 32, 81)
# (18, 32, 81): 0.5344121912790228
# (17, 32, 81): 0.5332080138741222
#
# Approximating hitting prob for (18, 33, 83)
# (18, 33, 83): 0.5351589143653502
# (17, 33, 83): 0.5336649245359243
#
# Approximating hitting prob for (18, 45, 56)
# (18, 45, 56): 0.5255722330999105
# (17, 45, 56): 0.5254786841463105
#
# Approximating hitting prob for (18, 47, 60)
# (18, 47, 60): 0.5284828625145415
# (17, 47, 60): 0.5281888889502253
#
# Approximating hitting prob for (18, 48, 62)
# (18, 48, 62): 0.5294526933438758
# (17, 48, 62): 0.5290045013080626
#
# Approximating hitting prob for (18, 49, 64)
# (18, 49, 64): 0.5304295920255223
# (17, 49, 64): 0.5297020995866109
#
# Approximating hitting prob for (18, 50, 66)
# (18, 50, 66): 0.5312826982045813
# (17, 50, 66): 0.5301457096165415
#
# Approximating hitting prob for (19, 20, 58)
# (19, 20, 58): 0.5076781471384154
# (18, 20, 58): 0.507459734940809
#
# Approximating hitting prob for (19, 32, 82)
# (19, 32, 82): 0.5327246501234508
# (18, 32, 82): 0.5320769507714677
#
# Approximating hitting prob for (19, 33, 84)
# (19, 33, 84): 0.5335489429772609
# (18, 33, 84): 0.532734806781722
#
# Approximating hitting prob for (19, 34, 86)
# (19, 34, 86): 0.5345634156030413
# (18, 34, 86): 0.5332648124986303
#
# Approximating hitting prob for (19, 35, 88)
# (19, 35, 88): 0.5345634156030413
# (18, 35, 88): 0.5332648124986303
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/659592125.py:18, in stricterFilter(candidates, timeLim, t, printOnGo, filename, continueFrom)
#      17 try:
# ---> 18     pLarge = LoserAnalysis(sLarge).getHittingProb()  # exact probs
#      19     pSmall = LoserAnalysis(sSmall).getHittingProb()
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:68, in LoserAnalysis.getHittingProb(self, asFloat, approx, t)
#      66     return Q(x, y, z, t)
# ---> 68 sol = self.solveEqns()
#      69 if sol:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:46, in LoserAnalysis.solveEqns(self, asFloat)
#      45 self.getEquations()
# ---> 46 sol = solve(self.equations, self.symbols)
#      47 return {s:float(p) for s, p in sol.items() if sol} if asFloat else sol
#
# File /usr/local/lib/python3.9/site-packages/sympy/solvers/solvers.py:1147, in solve(f, *symbols, **flags)
#    1146 else:
# -> 1147     linear, solution = _solve_system(f, symbols, **flags)
#    1148 assert type(solution) is list
#
# File /usr/local/lib/python3.9/site-packages/sympy/solvers/solvers.py:1799, in _solve_system(exprs, symbols, **flags)
#    1797     continue
# -> 1799 poly = g.as_poly(*symbols, extension=True)
#    1801 if poly is not None:
#
# File /usr/local/lib/python3.9/site-packages/sympy/core/expr.py:1102, in Expr.as_poly(self, *gens, **args)
#    1101 try:
# -> 1102     poly = Poly(self, *gens, **args)
#    1104     if not poly.is_Poly:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:182, in Poly.__new__(cls, rep, *gens, **args)
#     181 else:
# --> 182     return cls._from_expr(rep, opt)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:312, in Poly._from_expr(cls, rep, opt)
#     311 rep, opt = _dict_from_expr(rep, opt)
# --> 312 return cls._from_dict(rep, opt)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:261, in Poly._from_dict(cls, rep, opt)
#     259         rep[monom] = domain.convert(coeff)
# --> 261 return cls.new(DMP.from_dict(rep, level, domain), *gens)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polyclasses.py:279, in DMP.from_dict(cls, rep, lev, dom)
#     278 """Construct and instance of ``cls`` from a ``dict`` representation. """
# --> 279 return cls(dmp_from_dict(rep, lev, dom), dom, lev)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
#     [... skipping similar frames: dmp_from_dict at line 1012 (2958 times)]
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:998, in dmp_from_dict(f, u, K)
#     996 coeffs = {}
# --> 998 for monom, coeff in f.items():
#     999     head, tail = monom[0], monom[1:]
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# TimeoutException                          Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
#       2                                        filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv')
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/659592125.py:23, in stricterFilter(candidates, timeLim, t, printOnGo, filename, continueFrom)
#      21 except (TimeoutException, RecursionError):
#      22     print(f'Approximating hitting prob for {sLarge}')
# ---> 23     pLarge = LoserAnalysis(sLarge).getHittingProb(approx=True, t=t)
#      24     pSmall = LoserAnalysis(sSmall).getHittingProb(approx=True, t=t)
#      26 finally:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:66, in LoserAnalysis.getHittingProb(self, asFloat, approx, t)
#      64 if approx:
#      65     x, y, z = self.initState
# ---> 66     return Q(x, y, z, t)
#      68 sol = self.solveEqns()
#      69 if sol:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:31, in Q(x, y, z, t)
#      29 if x==0: return 1
#      30 if z*y==0: return 0
# ---> 31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
#      33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:31, in Q(x, y, z, t)
#      29 if x==0: return 1
#      30 if z*y==0: return 0
# ---> 31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
#      33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
#     [... skipping similar frames: memoize.<locals>.memodict.__call__ at line 8 (11 times), <genexpr> at line 33 (10 times), Q at line 33 (10 times), memoize.<locals>.memodict.__missing__ at line 11 (10 times)]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2027475117.py:12, in sigalarmHandler(signum, frame)
#       8 """
#       9 Handler function to be called when SIGALRM is received.
#      10 """
#      11 # We get signal!
# ---> 12 raise TimeoutException()
#
# TimeoutException:

# %%
betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
                                       filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv',
                                       continueFrom=(69,64,100))
# Out:
# Approximating hitting prob for (70, 12, 93)
# (70, 12, 93): 0.27064890356707977
# (69, 12, 93): 0.2704508979612977
#
# Approximating hitting prob for (70, 13, 95)
# (70, 13, 95): 0.273002814385276
# (69, 13, 95): 0.2728333555110289
#
# Approximating hitting prob for (70, 15, 99)
# (70, 15, 99): 0.2777183843625525
# (69, 15, 99): 0.27732957441332723
#
# Approximating hitting prob for (70, 30, 84)
# (70, 30, 84): 0.2928672871530125
# (69, 30, 84): 0.29290071879804375
#
# Approximating hitting prob for (70, 50, 94)
# (70, 50, 94): 0.32695735265836573
# (69, 50, 94): 0.3267132634013896
#
# Approximating hitting prob for (70, 58, 98)
# (70, 58, 98): 0.3430616778838396
# (69, 58, 98): 0.3428394039934912
#
# Approximating hitting prob for (70, 60, 99)
# (70, 60, 99): 0.34560612414415176
# (69, 60, 99): 0.34492499438010804
#
# Approximating hitting prob for (70, 84, 90)
# (70, 84, 90): 0.4148018936715927
# (69, 84, 90): 0.41468720846314083
#
# Approximating hitting prob for (71, 12, 94)
# (71, 12, 94): 0.27043453644878807
# (70, 12, 94): 0.2702550831661171
#
# Approximating hitting prob for (71, 15, 100)
# (71, 15, 100): 0.2774240055525448
# (70, 15, 100): 0.27714908068396565
#
# Approximating hitting prob for (71, 36, 88)
# (71, 36, 88): 0.3107284046458855
# (70, 36, 88): 0.3107029569244443
#
# Approximating hitting prob for (71, 44, 92)
# (71, 44, 92): 0.31946810865446534
# (70, 44, 92): 0.31933447137280896
#
# Approximating hitting prob for (71, 52, 96)
# (71, 52, 96): 0.3287350571698488
# (70, 52, 96): 0.32848900976647166
#
# Approximating hitting prob for (71, 60, 100)
# (71, 60, 100): 0.3432269284144038
# (70, 60, 100): 0.3428263666917539
#
# Approximating hitting prob for (72, 14, 99)
# (72, 14, 99): 0.27369224353294386
# (71, 14, 99): 0.27347335165357634
#
# Approximating hitting prob for (72, 40, 91)
# (72, 40, 91): 0.3129742549703007
# (71, 40, 91): 0.31282979281170153
#
# Approximating hitting prob for (72, 46, 94)
# (72, 46, 94): 0.32065055730266634
# (71, 46, 94): 0.32060860453920875
#
# Approximating hitting prob for (72, 50, 96)
# (72, 50, 96): 0.32548552599084296
# (71, 50, 96): 0.32522123422559995
#
# Approximating hitting prob for (72, 54, 98)
# (72, 54, 98): 0.33015250293768666
# (71, 54, 98): 0.3299310590778092
#
# Approximating hitting prob for (73, 11, 94)
# (73, 11, 94): 0.26568088778907833
# (72, 11, 94): 0.26555372470314254
#
# Approximating hitting prob for (73, 13, 98)
# (73, 13, 98): 0.2712824779940791
# (72, 13, 98): 0.27092732614422377
#
# Approximating hitting prob for (73, 14, 100)
# (73, 14, 100): 0.2735392177539206
# (72, 14, 100): 0.2733296833190661
#
# Approximating hitting prob for (73, 26, 85)
# (73, 26, 85): 0.2838182327188731
# (72, 26, 85): 0.2838382526274032
#
# Approximating hitting prob for (73, 40, 92)
# (73, 40, 92): 0.31265646156970867
# (72, 40, 92): 0.31256600858492634
#
# Approximating hitting prob for (73, 44, 94)
# (73, 44, 94): 0.31905281367702304
# (72, 44, 94): 0.31898130581150774
#
# Approximating hitting prob for (74, 12, 97)
# (74, 12, 97): 0.26803823241416097
# (73, 12, 97): 0.2678146488650772
#
# Approximating hitting prob for (74, 13, 99)
# (74, 13, 99): 0.27106341315623816
# (73, 13, 99): 0.2708043750088058
#
# Approximating hitting prob for (74, 30, 88)
# (74, 30, 88): 0.29121346643802504
# (73, 30, 88): 0.2911904861374854
#
# Approximating hitting prob for (74, 40, 93)
# (74, 40, 93): 0.3124715276947375
# (73, 40, 93): 0.3123265733297223
#
# Approximating hitting prob for (74, 46, 96)
# (74, 46, 96): 0.3194592906289733
# (73, 46, 96): 0.31936096416339166
#
# Approximating hitting prob for (74, 52, 99)
# (74, 52, 99): 0.32609715069378836
# (73, 52, 99): 0.32593271890358366
#
# Approximating hitting prob for (74, 54, 100)
# (74, 54, 100): 0.3285392810102394
# (73, 54, 100): 0.32834877261967127
#
# Approximating hitting prob for (75, 13, 100)
# (75, 13, 100): 0.2708561821230972
# (74, 13, 100): 0.27060467983388525
#
# Approximating hitting prob for (75, 38, 93)
# (75, 38, 93): 0.3107255922584125
# (74, 38, 93): 0.3106856959891582
#
# Approximating hitting prob for (75, 40, 94)
# (75, 40, 94): 0.31219750777533284
# (74, 40, 94): 0.31212211416489793
#
# Approximating hitting prob for (75, 48, 98)
# (75, 48, 98): 0.3206660566987458
# (74, 48, 98): 0.3206193374288369
#
# Approximating hitting prob for (75, 52, 100)
# (75, 52, 100): 0.32543894655115896
# (74, 52, 100): 0.3251891291627604
#
# Approximating hitting prob for (76, 42, 96)
# (76, 42, 96): 0.31283229353690856
# (75, 42, 96): 0.31269685409230785
#
# Approximating hitting prob for (77, 42, 97)
# (77, 42, 97): 0.31263411481005815
# (76, 42, 97): 0.3124896740010894
#
# Approximating hitting prob for (78, 42, 98)
# (78, 42, 98): 0.312441399741017
# (77, 42, 98): 0.3119828040723916
#
# Approximating hitting prob for (79, 32, 94)
# (79, 32, 94): 0.2912337154122105
# (78, 32, 94): 0.2911642829888588
#
# Approximating hitting prob for (79, 40, 98)
# (79, 40, 98): 0.31073467566545016
# (78, 40, 98): 0.31068391480047436
#
# Approximating hitting prob for (79, 42, 99)
# (79, 42, 99): 0.3121670959474713
# (78, 42, 99): 0.3120607193357822
#
# Approximating hitting prob for (79, 44, 100)
# (79, 44, 100): 0.3130463381703828
# (78, 44, 100): 0.3128490513416133
#
# Approximating hitting prob for (82, 34, 98)
# (82, 34, 98): 0.2917812876569657
# (81, 34, 98): 0.29172992113254753
#
# Approximating hitting prob for (84, 30, 98)
# (84, 30, 98): 0.2839368557613289
# (83, 30, 98): 0.2838357734914572
#
# Approximating hitting prob for (84, 34, 100)
# (84, 34, 100): 0.29123192191006453
# (83, 34, 100): 0.2911447291167216
#
# Approximating hitting prob for (93, 47, 62)
# (93, 47, 62): 0.2078449082948937
# (92, 47, 62): 0.20783817692579917
#
# Approximating hitting prob for (93, 47, 98)
# (93, 47, 98): 0.3020413154785515
# (92, 47, 98): 0.3020379983481061
#
# Approximating hitting prob for (95, 48, 100)
# (95, 48, 100): 0.30201302025080573
# (94, 48, 100): 0.30196433138324996
#
# Approximating hitting prob for (99, 50, 66)
# (99, 50, 66): 0.2078419114332157
# (98, 50, 66): 0.2078180397808808
#
# Approximating hitting prob for (100, 51, 67)
# (100, 51, 67): 0.2080190772886974
# (99, 51, 67): 0.20801576587712575

# %%
class TimeoutException(Exception):
    """
    Custom exception for timeout.
    """
    pass

def sigalarmHandler(signum, frame):
    """
    Handler function to be called when SIGALRM is received.
    """
    # We get signal!
    raise TimeoutException()

# %% [markdown]
# ## When is player 1 better off giving away $1 to another player?

# %%
betterGiving1ToAnother = findBetterGiving1(1,100, t=10, giveToAnother=True)
betterGiving1ToAnother
# Out:
# {(1, 5, 5): 0.5004434876119833,
#  (2, 4, 5): 0.5015168645690443,
#  (1, 6, 6): 0.506093654740131,
#  (2, 5, 6): 0.5184847144955884,
#  (1, 7, 7): 0.5131205254322682,
#  (2, 6, 7): 0.5396071019936831,
#  (1, 8, 8): 0.5177187986883774,
#  (2, 7, 8): 0.553386673567715,
#  (1, 9, 9): 0.5198030383135193,
#  (2, 8, 9): 0.5596511014686955,
#  (1, 10, 10): 0.521353326527545,
#  (2, 9, 10): 0.5643071756348541,
#  (1, 11, 11): 0.5225738105217701,
#  (2, 10, 11): 0.5679767313216567,
#  (1, 12, 12): 0.5237380978085997,
#  (2, 11, 12): 0.5714793837797846,
#  (1, 12, 36): 0.6316713165390184,
#  (2, 11, 36): 0.6317622599451304,
#  (1, 13, 13): 0.5248276325593998,
#  (2, 12, 13): 0.5747622273980084,
#  (1, 13, 39): 0.6325682808186844,
#  (2, 12, 39): 0.6347403712118326,
#  (1, 14, 14): 0.5256858644409728,
#  (2, 13, 14): 0.57733900685236,
#  (1, 14, 42): 0.6333982655030145,
#  (2, 13, 42): 0.6366529115385103,
#  (1, 15, 15): 0.5268432387720368,
#  (2, 14, 15): 0.5808387485922709,
#  (1, 15, 45): 0.63421194355006,
#  (2, 14, 45): 0.6395029512036614,
#  (1, 16, 16): 0.5279858610539553,
#  (2, 15, 16): 0.5842379051719758,
#  (1, 16, 48): 0.635051999980948,
#  (2, 15, 48): 0.6419747628823096,
#  (1, 17, 17): 0.5283821156475977,
#  (2, 16, 17): 0.5854285708426477,
#  (1, 17, 51): 0.6353974162348219,
#  (2, 16, 51): 0.6431331129655032,
#  (1, 18, 18): 0.5286972339709394,
#  (2, 17, 18): 0.586367542078401,
#  (1, 18, 54): 0.635696343688081,
#  (2, 17, 54): 0.6438519942124338,
#  (1, 19, 19): 0.5290239620908059,
#  (2, 18, 19): 0.5873462049262054,
#  (1, 19, 57): 0.6359734242165406,
#  (2, 18, 57): 0.644798126476528,
#  (1, 20, 20): 0.5292680655049197,
#  (2, 19, 20): 0.5880847500592729,
#  (1, 20, 60): 0.6362249863460855,
#  (2, 19, 60): 0.6453717860378668,
#  (1, 21, 21): 0.5295149142555335,
#  (2, 20, 21): 0.588833317324383,
#  (1, 21, 63): 0.6364634998581686,
#  (2, 20, 63): 0.6461849514015902,
#  (1, 21, 64): 0.646956969794154,
#  (2, 20, 64): 0.6472510681012803,
#  (1, 22, 22): 0.5297588522879303,
#  (2, 21, 22): 0.5895697621096462,
#  (1, 22, 66): 0.6366529446148538,
#  (2, 21, 66): 0.6466174245912294,
#  (1, 22, 67): 0.6471532117394029,
#  (2, 21, 67): 0.647774501235203,
#  (1, 23, 23): 0.5299781484445122,
#  (2, 22, 23): 0.5902254013880421,
#  (1, 23, 69): 0.6368433485854967,
#  (2, 22, 69): 0.6472793649130383,
#  (1, 23, 70): 0.647343764553591,
#  (2, 22, 70): 0.6483569921802232,
#  (1, 24, 24): 0.5301334749530051,
#  (2, 23, 24): 0.5907054714357991,
#  (1, 24, 72): 0.6370145682769819,
#  (2, 23, 72): 0.6476786129157565,
#  (1, 24, 73): 0.6475028948415723,
#  (2, 23, 73): 0.6487869019532507,
#  (1, 25, 25): 0.5303300145853443,
#  (2, 24, 25): 0.5913062701368778,
#  (1, 25, 75): 0.6371719124424207,
#  (2, 24, 75): 0.6482151442816559,
#  (1, 25, 76): 0.6476655808364664,
#  (2, 24, 76): 0.6492909523499552,
#  (1, 26, 26): 0.5305056830450136,
#  (2, 25, 26): 0.5918398411700453,
#  (1, 26, 78): 0.6373261970460974,
#  (2, 25, 78): 0.6485752629701603,
#  (1, 26, 79): 0.6478181289321158,
#  (2, 25, 79): 0.6496998090304239,
#  (1, 27, 27): 0.5306651440964284,
#  (2, 26, 27): 0.5923164712780911,
#  (1, 27, 81): 0.6374779182331624,
#  (2, 26, 81): 0.6491023179636827,
#  (1, 27, 82): 0.6479675843896594,
#  (2, 26, 82): 0.6501630597575742,
#  (1, 28, 28): 0.5308433925108808,
#  (2, 27, 28): 0.5928632397722654,
#  (1, 28, 84): 0.6376227926171485,
#  (2, 27, 84): 0.6494288807018324,
#  (1, 28, 85): 0.6481137818273807,
#  (2, 27, 85): 0.6505545513577707,
#  (1, 29, 29): 0.531019424810327,
#  (2, 28, 29): 0.593397753481219,
#  (1, 29, 87): 0.6377697342725956,
#  (2, 28, 87): 0.6499273246583346,
#  (1, 29, 88): 0.6482600123414454,
#  (2, 28, 88): 0.651006837277092,
#  (1, 30, 30): 0.5311653907136445,
#  (2, 29, 30): 0.5938409764824553,
#  (1, 30, 90): 0.6379076957008163,
#  (2, 29, 90): 0.650248810177776,
#  (1, 30, 91): 0.6483932438525631,
#  (2, 29, 91): 0.6513514100842097,
#  (1, 31, 31): 0.5313585565589595,
#  (2, 30, 31): 0.5944358379798981,
#  (1, 31, 93): 0.6380471455644888,
#  (2, 30, 93): 0.6507426069080341,
#  (1, 31, 94): 0.6485374236333384,
#  (2, 30, 94): 0.6518048371373775,
#  (1, 32, 32): 0.5316609404901015,
#  (2, 31, 32): 0.5953108064912191,
#  (1, 32, 96): 0.6382585695513472,
#  (2, 31, 96): 0.651341801406459,
#  (1, 32, 97): 0.6487406281488678,
#  (2, 31, 97): 0.6524211817198429,
#  (1, 33, 33): 0.5317385375916611,
#  (2, 32, 33): 0.5955452681512389,
#  (1, 33, 99): 0.6383231014972734,
#  (2, 32, 99): 0.6515462628230367,
#  (1, 33, 100): 0.6488068966028214,
#  (2, 32, 100): 0.6526188624860286,
#  (1, 34, 34): 0.5318062779428949,
#  (2, 33, 34): 0.5957485718957984,
#  (1, 35, 35): 0.5318679983996342,
#  (2, 34, 35): 0.5959310706203745,
#  (1, 36, 36): 0.5319251873973311,
#  (2, 35, 36): 0.5961088063515048,
#  (1, 37, 37): 0.5319769849510576,
#  (2, 36, 37): 0.5962632397987264,
#  (1, 38, 38): 0.5320250779543261,
#  (2, 37, 38): 0.5964045750139714,
#  (1, 39, 39): 0.5320778016456672,
#  (2, 38, 39): 0.5965617868740368,
#  (1, 40, 40): 0.5321167325018205,
#  (2, 39, 40): 0.5966842851117292,
#  (1, 41, 41): 0.5321571517934258,
#  (2, 40, 41): 0.5968058406736355,
#  (2, 14, 41): 0.6338000769223442,
#  (1, 42, 42): 0.5322013748645192,
#  (2, 41, 42): 0.5969399487078528,
#  (1, 43, 43): 0.5322408018658233,
#  (2, 42, 43): 0.5970633565449881,
#  (1, 44, 44): 0.5322755651027112,
#  (2, 43, 44): 0.5971704908211825,
#  (2, 15, 44): 0.6355654440591713,
#  (1, 45, 45): 0.5323146613405815,
#  (2, 44, 45): 0.5972896979627089,
#  (1, 46, 46): 0.5323509791656083,
#  (2, 45, 46): 0.5973977583765179,
#  (1, 47, 47): 0.532385014722942,
#  (2, 46, 47): 0.597498806605531,
#  (2, 16, 47): 0.6375855486545072,
#  (1, 48, 48): 0.5324148826610103,
#  (2, 47, 48): 0.5975902130804501,
#  (1, 49, 49): 0.5324444859883317,
#  (2, 48, 49): 0.5976821983913784,
#  (1, 50, 50): 0.5324711785974361,
#  (2, 49, 50): 0.5977623423713782,
#  (2, 17, 50): 0.6383571866691223,
#  (1, 51, 51): 0.5325028988107334,
#  (2, 50, 51): 0.5978603145004572,
#  (1, 52, 52): 0.5325307160155125,
#  (2, 51, 52): 0.597951109063024,
#  (1, 53, 53): 0.5325579709224543,
#  (2, 52, 53): 0.5980328572456773,
#  (2, 18, 53): 0.6393221393725973,
#  (1, 54, 54): 0.5325877396314925,
#  (2, 53, 54): 0.5981236683464157,
#  (1, 55, 55): 0.5326169460426934,
#  (2, 54, 55): 0.5982126271719249,
#  (1, 56, 56): 0.5326397687196227,
#  (2, 55, 56): 0.5982834436230927,
#  (2, 19, 56): 0.639912667869058,
#  (1, 57, 57): 0.5326706620243357,
#  (2, 56, 57): 0.5983790342554488,
#  (1, 58, 58): 0.5326991076796389,
#  (2, 57, 58): 0.5984666865653948,
#  (1, 59, 59): 0.5327241464715744,
#  (2, 58, 59): 0.5985425140825841,
#  (2, 20, 59): 0.6407575699842504,
#  (1, 60, 60): 0.5327515998365764,
#  (2, 59, 60): 0.5986312082973463,
#  (1, 60, 100): 0.6594202186690291,
#  (2, 59, 100): 0.6594714208485749,
#  (1, 61, 61): 0.5327806408660604,
#  (2, 60, 61): 0.5987212090276719,
#  (1, 62, 62): 0.5328041250698572,
#  (2, 61, 62): 0.5987947377389965,
#  (2, 21, 62): 0.6412867749400921,
#  (1, 63, 63): 0.5328350514509137,
#  (2, 62, 63): 0.5988899810697471,
#  (1, 64, 64): 0.5329295505639383,
#  (2, 63, 64): 0.5991591232757963,
#  (1, 65, 65): 0.5329439718496504,
#  (2, 64, 65): 0.5992017586824079,
#  (2, 22, 65): 0.6419519898198954,
#  (1, 66, 66): 0.5329563424020729,
#  (2, 65, 66): 0.5992384734235551,
#  (1, 67, 67): 0.5329692090996461,
#  (2, 66, 67): 0.5992765939092958,
#  (1, 68, 68): 0.5329786027811648,
#  (2, 67, 68): 0.5993086945005419,
#  (2, 23, 68): 0.6423572742552796,
#  (1, 69, 69): 0.5329891210583583,
#  (2, 68, 69): 0.5993394885762248,
#  (1, 70, 70): 0.5330002016333891,
#  (2, 69, 70): 0.5993723499233687,
#  (1, 71, 71): 0.5330110506740166,
#  (2, 70, 71): 0.5994039212931209,
#  (2, 24, 71): 0.6429282380946333,
#  (1, 72, 72): 0.5330189889964267,
#  (2, 71, 72): 0.5994280670237854,
#  (1, 73, 73): 0.5330284819069756,
#  (2, 72, 73): 0.5994564796027452,
#  (1, 74, 74): 0.5330374786723738,
#  (2, 73, 74): 0.599483089520991,
#  (2, 25, 74): 0.6432813280601704,
#  (1, 75, 75): 0.5330459131399347,
#  (2, 74, 75): 0.5995072187134837,
#  (1, 76, 76): 0.5330541822257785,
#  (2, 75, 76): 0.5995340767043049,
#  (1, 77, 77): 0.5330628151513997,
#  (2, 76, 77): 0.5995594131833307,
#  (2, 26, 77): 0.6438085649735813,
#  (1, 78, 78): 0.5330708527028399,
#  (2, 77, 78): 0.5995827154672391,
#  (1, 79, 79): 0.5330799817736117,
#  (2, 78, 79): 0.5996089284693644,
#  (1, 80, 80): 0.5330863985842266,
#  (2, 79, 80): 0.5996283608210977,
#  (2, 27, 80): 0.6441455136835509,
#  (1, 81, 81): 0.5330929477002151,
#  (2, 80, 81): 0.5996482893179816,
#  (1, 82, 82): 0.5331003237247879,
#  (2, 81, 82): 0.5996707812314773,
#  (1, 83, 83): 0.5331074682149571,
#  (2, 82, 83): 0.599691569713289,
#  (2, 28, 83): 0.6446484064082373,
#  (1, 84, 84): 0.5331135542621382,
#  (2, 83, 84): 0.5997103736144981,
#  (1, 85, 85): 0.5331207318286508,
#  (2, 84, 85): 0.5997354950972921,
#  (1, 86, 86): 0.5331267847994886,
#  (2, 85, 86): 0.5997556055140646,
#  (2, 29, 86): 0.6449977587469728,
#  (1, 87, 87): 0.5331327716176396,
#  (2, 86, 87): 0.5997733675104574,
#  (1, 88, 88): 0.5331386592067605,
#  (2, 87, 88): 0.599791989491778,
#  (1, 89, 89): 0.5331450098646887,
#  (2, 88, 89): 0.5998109256983607,
#  (2, 30, 89): 0.6454688981820182,
#  (1, 90, 90): 0.5331506328430625,
#  (2, 89, 90): 0.5998279269388559,
#  (1, 91, 91): 0.5331572150353944,
#  (2, 90, 91): 0.5998475412104778,
#  (1, 92, 92): 0.5331628049374249,
#  (2, 91, 92): 0.5998653528213856,
#  (2, 31, 92): 0.6457769216297059,
#  (1, 93, 93): 0.5331686925265458,
#  (2, 92, 93): 0.5998821225274772,
#  (1, 94, 94): 0.5331750431844738,
#  (2, 93, 94): 0.5999014225738369,
#  (1, 95, 95): 0.5331811953843418,
#  (2, 94, 95): 0.5999193995664617,
#  (2, 32, 95): 0.646300487069002,
#  (1, 96, 96): 0.5331852306982338,
#  (2, 95, 96): 0.599931571660824,
#  (1, 97, 97): 0.5331905890658605,
#  (2, 96, 97): 0.599948109832512,
#  (1, 98, 98): 0.5331949220668428,
#  (2, 97, 98): 0.5999628122671425,
#  (2, 33, 98): 0.6464613042504953,
#  (1, 99, 99): 0.5331994535258853,
#  (2, 98, 99): 0.59997640664427,
#  (2, 60, 99): 0.6594345241875391,
#  (1, 100, 100): 0.533204183442988,
#  (2, 99, 100): 0.5999915225331928,
#  (2, 6, 6): 0.4693452418753916,
#  (3, 5, 6): 0.4740014979614388,
#  (2, 7, 7): 0.48208386784704227,
#  (3, 6, 7): 0.4955659177124083,
#  (2, 8, 8): 0.49122878218725124,
#  (3, 7, 8): 0.5014666050652847,
#  (2, 9, 9): 0.494262775936087,
#  (3, 8, 9): 0.5178661041836018,
#  (2, 10, 10): 0.5004434876119833,
#  (3, 9, 10): 0.5342839937488357,
#  (2, 11, 11): 0.5025522368075666,
#  (3, 10, 11): 0.5431842258389219,
#  (2, 12, 12): 0.506093654740131,
#  (3, 11, 12): 0.5502830045015581,
#  (2, 13, 13): 0.5085600915129808,
#  (3, 12, 13): 0.5546173616138715,
#  (2, 14, 14): 0.5131205254322682,
#  (3, 13, 14): 0.5568134654323105,
#  (2, 15, 15): 0.5156899950147334,
#  (3, 14, 15): 0.5601744353735879,
#  (2, 16, 16): 0.5177187986883774,
#  (3, 15, 16): 0.5635269543091331,
#  (2, 17, 17): 0.5183972606437027,
#  (3, 16, 17): 0.5645428776577504,
#  (2, 18, 18): 0.5198030383135193,
#  (3, 17, 18): 0.5672856342031618,
#  (2, 19, 19): 0.5202042212823249,
#  (3, 18, 19): 0.5700392728655439,
#  (2, 20, 20): 0.521353326527545,
#  (3, 19, 20): 0.5708707459853257,
#  (2, 20, 60): 0.6295677107148301,
#  (3, 19, 60): 0.6304392723627834,
#  (2, 21, 21): 0.5216864383816829,
#  (3, 20, 21): 0.5735340366157767,
#  (2, 21, 63): 0.6301227813711917,
#  (3, 20, 63): 0.6311136824660452,
#  (2, 22, 22): 0.5225738105217701,
#  (3, 21, 22): 0.5764060555111009,
#  (2, 22, 66): 0.630719892059984,
#  (3, 21, 66): 0.6335248486691138,
#  (2, 23, 23): 0.5230437922847974,
#  (3, 22, 23): 0.5785014418639604,
#  (2, 23, 69): 0.6311993336572169,
#  (3, 22, 69): 0.6351912844629037,
#  (2, 23, 71): 0.641735372847127,
#  (3, 22, 71): 0.6419442003410304,
#  (2, 24, 24): 0.5237380978085997,
#  (3, 23, 24): 0.5800568899875528,
#  (2, 24, 72): 0.6316713165390184,
#  (3, 23, 72): 0.6362437075564361,
#  (2, 24, 74): 0.642247130031838,
#  (3, 23, 74): 0.6426527783069992,
#  (2, 25, 25): 0.524088839353757,
#  (3, 24, 25): 0.5809113180896375,
#  (2, 25, 75): 0.6320944621998256,
#  (3, 24, 75): 0.637120230655896,
#  (2, 25, 77): 0.6426200988797439,
#  (3, 24, 77): 0.6434655302164304,
#  (2, 26, 26): 0.5248276325593998,
#  (3, 25, 26): 0.5813076057596235,
#  (2, 26, 78): 0.6325682808186844,
#  (3, 25, 78): 0.6376919552511473,
#  (2, 26, 80): 0.6431372309702534,
#  (3, 25, 80): 0.6440306064666632,
#  (2, 27, 27): 0.5251138752349743,
#  (3, 26, 27): 0.582175396704432,
#  (2, 27, 81): 0.6329491879890007,
#  (3, 26, 81): 0.6380589868954174,
#  (2, 27, 83): 0.6434930993486342,
#  (3, 26, 83): 0.6444297387021796,
#  (2, 28, 28): 0.5256858644409728,
#  (3, 27, 28): 0.5828712072018578,
#  (2, 28, 84): 0.6333982655030145,
#  (3, 27, 84): 0.6388404320458433,
#  (2, 28, 86): 0.6439339408531474,
#  (3, 27, 86): 0.6451290222156598,
#  (2, 29, 29): 0.5261190653101662,
#  (3, 28, 29): 0.5831610717370319,
#  (2, 29, 87): 0.6337884340494758,
#  (3, 28, 87): 0.6392850773298446,
#  (2, 29, 88): 0.6449055088252976,
#  (3, 28, 88): 0.644998916418991,
#  (2, 29, 89): 0.6443102007972193,
#  (3, 28, 89): 0.6455973005470034,
#  (2, 30, 30): 0.5268432387720368,
#  (3, 29, 30): 0.5837543951845078,
#  (2, 30, 90): 0.63421194355006,
#  (3, 29, 90): 0.6395496715386797,
#  (2, 30, 92): 0.6447714007910802,
#  (3, 29, 92): 0.645899006413106,
#  (2, 31, 31): 0.5275615907974732,
#  (3, 30, 31): 0.5843650506359125,
#  (2, 31, 93): 0.6345886665629393,
#  (3, 30, 93): 0.640241909791021,
#  (2, 31, 94): 0.6457147711805027,
#  (3, 30, 94): 0.645921002181451,
#  (2, 31, 95): 0.6453186488922336,
#  (3, 30, 95): 0.6465264150324307,
#  (2, 32, 32): 0.5279858610539553,
#  (3, 31, 32): 0.5845853886973108,
#  (2, 32, 96): 0.635051999980948,
#  (3, 31, 96): 0.6406006558112753,
#  (2, 32, 97): 0.6461740362082762,
#  (3, 31, 97): 0.646306424272638,
#  (2, 32, 98): 0.645574742480821,
#  (3, 31, 98): 0.6468801499866637,
#  (2, 33, 33): 0.5281335800034718,
#  (3, 32, 33): 0.5851356798220545,
#  (2, 33, 99): 0.6352244269589663,
#  (3, 32, 99): 0.6407475974667225,
#  (2, 33, 100): 0.6463518546302647,
#  (3, 32, 100): 0.6464238949061373,
#  (2, 34, 34): 0.5283821156475977,
#  (3, 33, 34): 0.5857237441309336,
#  (2, 35, 35): 0.5284957328870937,
#  (3, 34, 35): 0.5859061105501363,
#  (2, 36, 36): 0.5286972339709394,
#  (3, 35, 36): 0.5863498462346949,
#  (2, 37, 37): 0.5288185579984419,
#  (3, 36, 37): 0.5868146350118123,
#  (2, 38, 38): 0.5290239620908059,
#  (3, 37, 38): 0.5870175583784231,
#  (2, 39, 39): 0.5291136651340412,
#  (3, 38, 39): 0.5874601198527918,
#  (2, 40, 40): 0.5292680655049197,
#  (3, 39, 40): 0.5879006636702145,
#  (2, 41, 41): 0.5293537993869498,
#  (3, 40, 41): 0.5880250307213077,
#  (2, 42, 42): 0.5295149142555335,
#  (3, 41, 42): 0.5884515170927959,
#  (2, 43, 43): 0.5296025334891361,
#  (3, 42, 43): 0.5889065483486172,
#  (2, 44, 44): 0.5297588522879303,
#  (3, 43, 44): 0.58904100368444,
#  (2, 45, 45): 0.5298143874684583,
#  (3, 44, 45): 0.5894975068375417,
#  (2, 46, 46): 0.5299781484445122,
#  (3, 45, 46): 0.5899698039446054,
#  (3, 45, 47): 0.5976479643759843,
#  (2, 47, 47): 0.5300331874798896,
#  (3, 46, 47): 0.5905717768558739,
#  (3, 46, 48): 0.5985042612914698,
#  (2, 48, 48): 0.5301334749530051,
#  (3, 47, 48): 0.5909074355884519,
#  (3, 47, 49): 0.5986030107146184,
#  (2, 49, 49): 0.5302022075945402,
#  (3, 48, 49): 0.5910961361274111,
#  (3, 48, 50): 0.5987849967558723,
#  (2, 50, 50): 0.5303300145853443,
#  (3, 49, 50): 0.5911701775220579,
#  (3, 49, 51): 0.5989254058335026,
#  (2, 51, 51): 0.530385152849752,
#  (3, 50, 51): 0.5913320862228827,
#  (3, 50, 52): 0.5990053844317854,
#  (2, 52, 52): 0.5305056830450136,
#  (3, 51, 52): 0.5914818062911734,
#  (3, 51, 53): 0.5991632908950618,
#  (2, 53, 53): 0.5305588367288184,
#  (3, 52, 53): 0.5915376556969635,
#  (3, 52, 54): 0.5992909986568359,
#  (2, 18, 54): 0.6281354554321411,
#  (3, 18, 53): 0.6282727553334942,
#  (2, 54, 54): 0.5306651440964284,
#  (3, 53, 54): 0.5916624692786923,
#  (3, 53, 55): 0.5993634193106573,
#  (2, 55, 55): 0.5307288160574269,
#  (3, 54, 55): 0.5918032587342715,
#  (3, 54, 56): 0.599478690367322,
#  (2, 56, 56): 0.5308433925108808,
#  (3, 55, 56): 0.5918555193568054,
#  (3, 55, 57): 0.5995967232986587,
#  (2, 19, 57): 0.6287977430555555,
#  (3, 19, 56): 0.6300712318900404,
#  (2, 57, 57): 0.5308984976989449,
#  (3, 56, 57): 0.5919839713363054,
#  (3, 56, 58): 0.5996486531577588,
#  (2, 58, 58): 0.531019424810327,
#  (3, 57, 58): 0.5921011938972294,
#  (3, 57, 59): 0.5997754843964335,
#  (2, 59, 59): 0.5310688408673304,
#  (3, 58, 59): 0.5921501799617691,
#  (3, 58, 60): 0.5998798898742993,
#  (3, 20, 59): 0.6308086193510897,
#  (2, 60, 60): 0.5311653907136445,
#  (3, 59, 60): 0.5922371045921607,
#  (3, 59, 61): 0.5999254359991278,
#  (2, 61, 61): 0.5312331972175651,
#  (3, 60, 61): 0.5923383678174059,
#  (3, 60, 62): 0.6000335791037951,
#  (2, 62, 62): 0.5313585565589595,
#  (3, 61, 62): 0.5923812182202493,
#  (3, 61, 63): 0.6001316835382479,
#  (3, 21, 62): 0.6330898947537215,
#  (2, 63, 63): 0.5315653498577452,
#  (3, 62, 63): 0.5925049402826467,
#  (3, 62, 64): 0.6001830180231672,
#  (2, 64, 64): 0.5316609404901015,
#  (3, 63, 64): 0.5925977525021593,
#  (3, 63, 65): 0.6002796836366832,
#  (2, 65, 65): 0.531690378435706,
#  (3, 64, 65): 0.592631788059493,
#  (3, 64, 66): 0.6003744142841115,
#  (3, 22, 65): 0.6346719031810446,
#  (2, 66, 66): 0.5317385375916611,
#  (3, 65, 66): 0.5927241372101983,
#  (3, 65, 67): 0.6004132789875781,
#  (2, 67, 67): 0.5317613271922471,
#  (3, 66, 67): 0.5928214643505817,
#  (3, 66, 68): 0.6005093823032567,
#  (2, 68, 68): 0.5318062779428949,
#  (3, 67, 68): 0.5928686808307507,
#  (3, 67, 69): 0.600597067689546,
#  (3, 23, 68): 0.6353617433984912,
#  (2, 69, 69): 0.5318268845048181,
#  (3, 68, 69): 0.5929494532612746,
#  (3, 68, 70): 0.6006299621130332,
#  (2, 70, 70): 0.5318679983996342,
#  (3, 69, 70): 0.5930456061914681,
#  (3, 69, 71): 0.6007228404852326,
#  (2, 71, 71): 0.5318853634799066,
#  (3, 70, 71): 0.5930765987252112,
#  (3, 70, 72): 0.6007995941400363,
#  (3, 24, 71): 0.6368715792445682,
#  (2, 72, 72): 0.5319251873973311,
#  (3, 71, 72): 0.5931494493714966,
#  (3, 71, 73): 0.600835432358084,
#  (2, 73, 73): 0.5319396086830429,
#  (3, 72, 73): 0.5932231434645379,
#  (3, 72, 74): 0.6009037846216702,
#  (2, 74, 74): 0.5319769849510576,
#  (3, 73, 74): 0.5932469749699402,
#  (3, 73, 75): 0.6009758414357144,
#  (3, 25, 74): 0.637481490478247,
#  (2, 75, 75): 0.5319899508776609,
#  (3, 74, 75): 0.5933288389197955,
#  (3, 74, 76): 0.600999127181451,
#  (2, 76, 76): 0.5320250779543261,
#  (3, 75, 76): 0.5934025495510085,
#  (3, 75, 77): 0.6010797838447729,
#  (2, 77, 77): 0.5320406899883995,
#  (3, 76, 77): 0.5934319544202696,
#  (3, 76, 78): 0.6011526014147149,
#  (3, 26, 77): 0.6378954574537672,
#  (2, 78, 78): 0.5320778016456672,
#  (3, 77, 78): 0.5934982559505665,
#  (3, 77, 79): 0.6011803855431506,
#  (2, 79, 79): 0.5320866991820353,
#  (3, 78, 79): 0.5935844198250606,
#  (3, 78, 80): 0.601249680482523,
#  (2, 80, 80): 0.5321167325018205,
#  (3, 79, 80): 0.5935997672483869,
#  (3, 79, 81): 0.6013253922325102,
#  (3, 27, 80): 0.6386029439004047,
#  (2, 81, 81): 0.5321278792295382,
#  (3, 80, 81): 0.5936775793461786,
#  (3, 80, 82): 0.6013561366936782,
#  (2, 82, 82): 0.5321571517934258,
#  (3, 81, 82): 0.5937518688134007,
#  (3, 81, 83): 0.601426787763129,
#  (2, 83, 83): 0.5321697869565954,
#  (3, 82, 83): 0.5937740134252909,
#  (3, 82, 84): 0.6014979184395587,
#  (3, 28, 83): 0.6390618120120578,
#  (2, 84, 84): 0.5322013748645192,
#  (3, 83, 84): 0.5938440691205609,
#  (3, 83, 85): 0.6015204268912259,
#  (2, 85, 85): 0.5322126208212671,
#  (3, 84, 85): 0.5939187058893884,
#  (3, 84, 86): 0.6015962874847584,
#  (2, 86, 86): 0.5322408018658233,
#  (3, 85, 86): 0.5939462915597639,
#  (3, 85, 87): 0.6016669550923809,
#  (3, 29, 86): 0.6394178126958119,
#  (2, 87, 87): 0.532251948593541,
#  (3, 86, 87): 0.5940234421306881,
#  (3, 86, 88): 0.601684650936087,
#  (2, 88, 88): 0.5322755651027112,
#  (3, 87, 88): 0.5940922243867381,
#  (3, 87, 89): 0.6017641830037341,
#  (2, 89, 89): 0.5322872410519229,
#  (3, 88, 89): 0.5941109952116039,
#  (3, 88, 90): 0.6018371328790496,
#  (3, 30, 89): 0.6400308661821116,
#  (2, 90, 90): 0.5323146613405815,
#  (3, 89, 90): 0.5941841270068079,
#  (3, 89, 91): 0.6018690019358922,
#  (2, 91, 91): 0.5323265357478535,
#  (3, 90, 91): 0.5942605664363495,
#  (3, 90, 92): 0.6019353200043608,
#  (2, 92, 92): 0.5323509791656083,
#  (3, 91, 92): 0.5942813383799895,
#  (3, 91, 93): 0.6020062026082151,
#  (3, 31, 92): 0.6404354725524564,
#  (2, 93, 93): 0.5323607366869041,
#  (3, 92, 93): 0.5943591835541245,
#  (3, 92, 94): 0.6020233692304272,
#  (2, 94, 94): 0.532385014722942,
#  (3, 93, 94): 0.5944335226358617,
#  (3, 93, 95): 0.6021049851077072,
#  (2, 95, 95): 0.5323954668474488,
#  (3, 94, 95): 0.5946310545585023,
#  (3, 94, 96): 0.6023667182128402,
#  (3, 32, 95): 0.6407084350761655,
#  (2, 96, 96): 0.5324148826610103,
#  (3, 95, 96): 0.5947102558627156,
#  (3, 95, 97): 0.6023858198011397,
#  (2, 97, 97): 0.5324242763425291,
#  (3, 96, 97): 0.5947447048743416,
#  (3, 96, 98): 0.6024215422519856,
#  (2, 98, 98): 0.5324444859883317,
#  (3, 97, 98): 0.5947557192966858,
#  (3, 97, 99): 0.6024459691315688,
#  (3, 33, 98): 0.6412241118075667,
#  (2, 99, 99): 0.532454276585971,
#  (3, 98, 99): 0.5947932940227607,
#  (3, 98, 100): 0.6024601919592203,
#  (2, 100, 100): 0.5324711785974361,
#  (3, 99, 100): 0.594818828959847,
#  (3, 7, 7): 0.44019443200773933,
#  (4, 6, 7): 0.45015962312549745,
#  (3, 8, 8): 0.4467808250351403,
#  (4, 7, 8): 0.4742427237336788,
#  (3, 9, 9): 0.4693452418753916,
#  (4, 8, 9): 0.49163882961608163,
#  (3, 10, 10): 0.47808047262654746,
#  (4, 9, 10): 0.4967868813136124,
#  (3, 11, 11): 0.48470119889837254,
#  (4, 10, 11): 0.502631388497265,
#  (3, 12, 12): 0.49122878218725124,
#  (4, 11, 12): 0.5167916853217244,
#  (3, 13, 13): 0.4935336740990533,
#  (4, 12, 13): 0.5312539030085183,
#  (3, 14, 14): 0.4956136137995563,
#  (4, 13, 14): 0.5362733208066606,
#  (3, 15, 15): 0.5004434876119833,
#  (4, 14, 15): 0.5434280646422885,
#  (3, 16, 16): 0.5020230153135531,
#  (4, 15, 16): 0.5478861768933428,
#  (3, 17, 17): 0.5030273123274739,
#  (4, 16, 17): 0.5516700278846806,
#  (3, 17, 51): 0.615492767394452,
#  (4, 16, 51): 0.6161914720719234,
#  (3, 18, 18): 0.506093654740131,
#  (4, 17, 18): 0.5534884163999391,
#  (3, 18, 54): 0.6177887948462294,
#  (4, 17, 54): 0.6190445216843214,
#  (3, 19, 19): 0.5081359535618724,
#  (4, 18, 19): 0.5547300196394097,
#  (3, 19, 57): 0.6196168251155819,
#  (4, 18, 57): 0.6206401410269438,
#  (3, 20, 20): 0.5092737466976579,
#  (4, 19, 20): 0.5579425760279598,
#  (3, 20, 60): 0.6203943672574895,
#  (4, 19, 60): 0.6215706116424494,
#  (3, 21, 21): 0.5131205254322682,
#  (4, 20, 21): 0.560842097902801,
#  (3, 21, 63): 0.6225665568796677,
#  (4, 20, 63): 0.6242344480325662,
#  (3, 22, 22): 0.5144697094785687,
#  (4, 21, 22): 0.5619077515336839,
#  (3, 22, 66): 0.624324547991922,
#  (4, 21, 66): 0.6264198516539231,
#  (3, 23, 23): 0.5164820742095548,
#  (4, 22, 23): 0.5623249765290268,
#  (3, 23, 69): 0.6249592168686177,
#  (4, 22, 69): 0.6269802310633965,
#  (3, 24, 24): 0.5177187986883774,
#  (4, 23, 24): 0.5647878741331352,
#  (3, 24, 72): 0.6264351494627344,
#  (4, 23, 72): 0.6274335588875342,
#  (3, 25, 25): 0.518164866255144,
#  (4, 24, 25): 0.5672480925534301,
#  (3, 25, 75): 0.6270372712175482,
#  (4, 24, 75): 0.6295931629610577,
#  (3, 26, 26): 0.5187485975630408,
#  (4, 25, 26): 0.5679596473903029,
#  (3, 26, 78): 0.6274313096961844,
#  (4, 25, 78): 0.6313052441087063,
#  (3, 27, 27): 0.5198030383135193,
#  (4, 26, 27): 0.5688839492677692,
#  (3, 27, 81): 0.6281354554321411,
#  (4, 26, 81): 0.6318541625652001,
#  (3, 28, 28): 0.5200221029356974,
#  (4, 27, 28): 0.571275650042761,
#  (3, 28, 84): 0.6286252830011939,
#  (4, 27, 84): 0.6323139071999525,
#  (3, 29, 29): 0.5204572222328067,
#  (4, 28, 29): 0.5737307747061763,
#  (3, 29, 87): 0.6289591721494013,
#  (4, 28, 87): 0.6344316035464191,
#  (3, 30, 30): 0.521353326527545,
#  (4, 29, 30): 0.5746018071326356,
#  (3, 30, 90): 0.6295677107148301,
#  (4, 29, 90): 0.636175140296618,
#  (4, 29, 93): 0.6410474510575962,
#  (3, 31, 31): 0.5216136373499127,
#  (4, 30, 31): 0.5765721483693628,
#  (3, 31, 93): 0.6299875487412996,
#  (4, 30, 93): 0.6364735716047266,
#  (4, 30, 96): 0.6419747628823096,
#  (3, 32, 32): 0.5218702105454792,
#  (4, 31, 32): 0.57749606986888,
#  (3, 32, 96): 0.6301997334840557,
#  (4, 31, 96): 0.6374555090105252,
#  (3, 32, 98): 0.6418308477122813,
#  (4, 31, 98): 0.64189207202387,
#  (4, 31, 99): 0.6423986858371861,
#  (3, 33, 33): 0.5225738105217701,
#  (4, 32, 33): 0.5782692459334621,
#  (3, 33, 99): 0.630719892059984,
#  (4, 32, 99): 0.6381510714353757,
#  (3, 34, 34): 0.5229414210020491,
#  (4, 33, 34): 0.5785625834846907,
#  (3, 35, 35): 0.5230813339345289,
#  (4, 34, 35): 0.5789247529064845,
#  (4, 34, 36): 0.586367542078401,
#  (3, 36, 36): 0.5237380978085997,
#  (4, 35, 36): 0.5796576089084913,
#  (3, 37, 37): 0.5239908341483345,
#  (4, 36, 37): 0.5802491462334248,
#  (4, 36, 38): 0.5873462049262054,
#  (3, 38, 38): 0.5241945844235296,
#  (4, 37, 38): 0.5804661601223137,
#  (4, 37, 39): 0.58762088741977,
#  (3, 39, 39): 0.5248276325593998,
#  (4, 38, 39): 0.5806532895349625,
#  (4, 38, 40): 0.5880847500592729,
#  (3, 40, 40): 0.5250622099866212,
#  (4, 39, 40): 0.5812160504411591,
#  (4, 39, 41): 0.5883475912219089,
#  (3, 41, 41): 0.5251781094938103,
#  (4, 40, 41): 0.581744395412073,
#  (4, 40, 42): 0.588833317324383,
#  (3, 42, 42): 0.5256858644409728,
#  (4, 41, 42): 0.5820000755463682,
#  (4, 41, 43): 0.5890965057886247,
#  (3, 43, 43): 0.5260332321991058,
#  (4, 42, 43): 0.5820988084313451,
#  (4, 42, 44): 0.5895697621096462,
#  (3, 44, 44): 0.5262173020499924,
#  (4, 43, 44): 0.5826556321339057,
#  (4, 43, 45): 0.5897379057011973,
#  (3, 45, 45): 0.5268432387720368,
#  (4, 44, 45): 0.5831276480920508,
#  (4, 44, 46): 0.5902254013880421,
#  (3, 46, 46): 0.5271012011740249,
#  (4, 45, 46): 0.583270240208344,
#  (3, 47, 47): 0.5277467521676913,
#  (4, 46, 47): 0.5834219779335806,
#  (3, 48, 48): 0.5279858610539553,
#  (4, 47, 48): 0.583798849790005,
#  (3, 49, 49): 0.5280672950113465,
#  (4, 48, 49): 0.58421129525373,
#  (4, 48, 50): 0.5913062701368778,
#  (3, 50, 50): 0.5281774061584447,
#  (4, 49, 50): 0.5844009880829905,
#  (4, 49, 51): 0.5914750587171248,
#  (4, 17, 50): 0.6165013477948399,
#  (3, 51, 51): 0.5283821156475977,
#  (4, 50, 51): 0.5845099911725855,
#  (4, 50, 52): 0.5918398411700453,
#  (3, 52, 52): 0.5284536267019764,
#  (4, 51, 52): 0.5848932467632814,
#  (4, 51, 53): 0.5920035690697556,
#  (3, 53, 53): 0.5285409151721452,
#  (4, 52, 53): 0.5853034761120002,
#  (4, 52, 54): 0.5923164712780911,
#  (4, 18, 53): 0.6181123476371319,
#  (3, 54, 54): 0.5286972339709394,
#  (4, 53, 54): 0.5854581080172822,
#  (4, 53, 55): 0.5925202546296297,
#  (3, 55, 55): 0.5287723172704025,
#  (4, 54, 55): 0.5854904070665887,
#  (4, 54, 56): 0.5928632397722654,
#  (3, 56, 56): 0.528849186692408,
#  (4, 55, 56): 0.585891077352072,
#  (4, 55, 57): 0.5930314164401599,
#  (3, 57, 57): 0.5290239620908059,
#  (4, 56, 57): 0.5862959648713356,
#  (4, 56, 58): 0.593397753481219,
#  (3, 58, 58): 0.529078174217599,
#  (4, 57, 58): 0.5864241191637455,
#  (4, 57, 59): 0.5935495408209707,
#  (3, 59, 59): 0.5291300048476689,
#  (4, 58, 59): 0.5865677035703398,
#  (4, 58, 60): 0.5938409764824553,
#  (4, 20, 59): 0.6220633830060628,
#  (3, 60, 60): 0.5292680655049197,
#  (4, 59, 60): 0.5869693992224677,
#  (4, 59, 61): 0.5940510939537503,
#  (3, 61, 61): 0.5293283636788938,
#  (4, 60, 61): 0.5873862934543769,
#  (4, 60, 62): 0.5944358379798981,
#  (3, 62, 62): 0.5293856188292774,
#  (4, 61, 62): 0.5875231799014378,
#  (4, 61, 63): 0.5950046353187607,
#  (4, 21, 62): 0.6242603302712578,
#  (3, 63, 63): 0.5295149142555335,
#  (4, 62, 63): 0.5881961511837626,
#  (4, 62, 64): 0.5953108064912191,
#  (3, 64, 64): 0.5295760062617487,
#  (4, 63, 64): 0.5883510807761351,
#  (4, 63, 65): 0.5954003937672526,
#  (3, 65, 65): 0.5296215523865772,
#  (4, 64, 65): 0.5884918206171993,
#  (4, 64, 66): 0.5955452681512389,
#  (4, 22, 65): 0.6248344032868888,
#  (3, 66, 66): 0.5297588522879303,
#  (4, 65, 66): 0.5885713692230182,
#  (4, 65, 67): 0.5956124131282917,
#  (3, 67, 67): 0.5298012561601383,
#  (4, 66, 67): 0.5886375219097698,
#  (4, 66, 68): 0.5957485718957984,
#  (3, 68, 68): 0.529846471521533,
#  (4, 67, 68): 0.5887764094756051,
#  (4, 67, 69): 0.5958102427380226,
#  (4, 23, 68): 0.6256472213490067,
#  (3, 69, 69): 0.5299781484445122,
#  (4, 68, 69): 0.5889008426793849,
#  (4, 68, 70): 0.5959310706203745,
#  (3, 70, 70): 0.5300216107597081,
#  (4, 69, 70): 0.5889561794018526,
#  (4, 69, 71): 0.5959897480535233,
#  (3, 71, 71): 0.5300431103829023,
#  (4, 70, 71): 0.5889931587537468,
#  (4, 70, 72): 0.5961088063515048,
#  (4, 24, 71): 0.6278304253935291,
#  (3, 72, 72): 0.5301334749530051,
#  (4, 71, 72): 0.5891061971572339,
#  (4, 71, 73): 0.596151656754348,
#  (3, 73, 73): 0.5301830563917255,
#  (4, 72, 73): 0.5892122399140968,
#  (4, 72, 74): 0.5962632397987264,
#  (3, 74, 74): 0.5302213918736981,
#  (4, 73, 74): 0.5892634255554708,
#  (4, 73, 75): 0.5963052632929854,
#  (4, 25, 74): 0.6295195515588748,
#  (3, 75, 75): 0.5303300145853443,
#  (4, 74, 75): 0.5893170257699115,
#  (4, 74, 76): 0.5964045750139714,
#  (3, 76, 76): 0.5303685816017206,
#  (4, 75, 76): 0.5894298161008231,
#  (4, 75, 77): 0.5964538256892581,
#  (3, 77, 77): 0.530398449539789,
#  (4, 76, 77): 0.5895255886530678,
#  (4, 76, 78): 0.5965617868740368,
#  (4, 26, 77): 0.6298821178967892,
#  (3, 78, 78): 0.5305056830450136,
#  (4, 77, 78): 0.5895662560172484,
#  (4, 77, 79): 0.5965969635652171,
#  (3, 79, 79): 0.5305416701066065,
#  (4, 78, 79): 0.5895925020957171,
#  (4, 78, 80): 0.5966842851117292,
#  (3, 80, 80): 0.5305744818392352,
#  (4, 79, 80): 0.5896747464235211,
#  (4, 79, 81): 0.5967190152722739,
#  (4, 27, 80): 0.6305618532913343,
#  (3, 81, 81): 0.5306651440964284,
#  (4, 80, 81): 0.5897592564808464,
#  (4, 80, 82): 0.5968058406736355,
#  (3, 82, 82): 0.5307149570695524,
#  (4, 81, 82): 0.5898063737319853,
#  (4, 81, 83): 0.5968468057249064,
#  (3, 83, 83): 0.5307373497540179,
#  (4, 82, 83): 0.5898409219726414,
#  (4, 82, 84): 0.5969399487078528,
#  (4, 28, 83): 0.632644984858973,
#  (3, 84, 84): 0.5308433925108808,
#  (4, 83, 84): 0.5899515788794052,
#  (4, 83, 85): 0.5969784495715423,
#  (3, 85, 85): 0.5308807357025521,
#  (4, 84, 85): 0.590039297342038,
#  (4, 84, 86): 0.5970633565449881,
#  (3, 86, 86): 0.5309161604663076,
#  (4, 85, 86): 0.5900632776909854,
#  (4, 85, 87): 0.5971014439543854,
#  (4, 29, 86): 0.6341472958369321,
#  (3, 87, 87): 0.531019424810327,
#  (4, 86, 87): 0.5900916241172586,
#  (4, 86, 88): 0.5971704908211825,
#  (3, 88, 88): 0.5310544195816186,
#  (4, 87, 88): 0.5901717184827432,
#  (4, 87, 89): 0.5972081978526308,
#  (3, 89, 89): 0.5310768122660842,
#  (4, 88, 89): 0.5902565427653305,
#  (4, 88, 90): 0.5972896979627089,
#  (4, 30, 89): 0.6345409208612762,
#  (3, 90, 90): 0.5311653907136445,
#  (4, 89, 90): 0.5902962343773815,
#  (4, 89, 91): 0.597325304646353,
#  (3, 91, 91): 0.5312151706104252,
#  (4, 90, 91): 0.5903176513097174,
#  (4, 90, 92): 0.5973977583765179,
#  (3, 92, 92): 0.5312498676946266,
#  (4, 91, 92): 0.5904037490315247,
#  (4, 91, 93): 0.5974274443946976,
#  (4, 31, 92): 0.6350845636410015,
#  (3, 93, 93): 0.5313585565589595,
#  (4, 92, 93): 0.5904832480228285,
#  (4, 92, 94): 0.597498806605531,
#  (3, 94, 94): 0.5313904421539738,
#  (4, 93, 94): 0.5905108667695473,
#  (4, 93, 95): 0.5975329083155515,
#  (3, 95, 95): 0.5316191650684178,
#  (4, 94, 95): 0.590518887782816,
#  (4, 94, 96): 0.5975902130804501,
#  (4, 32, 95): 0.6364357157297329,
#  (3, 96, 96): 0.5316609404901015,
#  (4, 95, 96): 0.5905898365393571,
#  (4, 95, 97): 0.5976202960147504,
#  (3, 97, 97): 0.5316739725693914,
#  (4, 96, 97): 0.5906563199895426,
#  (4, 96, 98): 0.5976821983913784,
#  (3, 98, 98): 0.5317002351860319,
#  (4, 97, 98): 0.5906784149869176,
#  (4, 97, 99): 0.5977121324821334,
#  (4, 33, 98): 0.6369774566197142,
#  (3, 99, 99): 0.5317385375916611,
#  (4, 98, 99): 0.5907043468401243,
#  (4, 98, 100): 0.5977623423713782,
#  (3, 100, 100): 0.53174793127318,
#  (4, 99, 100): 0.5907712272064303,
#  (4, 6, 6): 0.38529044734034446,
#  (5, 5, 6): 0.3960503141458788,
#  (4, 7, 7): 0.4024199248187945,
#  (5, 6, 7): 0.42052775091978695,
#  (4, 8, 8): 0.4285657819670951,
#  (5, 7, 8): 0.43856474403143997,
#  (4, 9, 9): 0.4379673356555573,
#  (5, 8, 9): 0.45166674671141765,
#  (4, 10, 10): 0.4425199304814645,
#  (5, 9, 10): 0.47425496198072786,
#  (4, 11, 11): 0.44806372408931566,
#  (5, 10, 11): 0.4900424495175617,
#  (4, 12, 12): 0.4693452418753916,
#  (5, 11, 12): 0.4940311588415976,
#  (4, 13, 13): 0.47675533508188117,
#  (5, 12, 13): 0.4998499491682755,
#  (4, 14, 14): 0.48208386784704227,
#  (5, 13, 14): 0.5030468273700656,
#  (4, 15, 15): 0.4852509608016224,
#  (5, 14, 15): 0.5158300733289302,
#  (4, 16, 16): 0.49122878218725124,
#  (5, 15, 16): 0.5299008986445578,
#  (4, 17, 17): 0.49264620272993614,
#  (5, 16, 17): 0.5345106990063337,
#  (4, 17, 51): 0.606547849164465,
#  (5, 16, 51): 0.6068501173284052,
#  (4, 18, 18): 0.494262775936087,
#  (5, 17, 18): 0.5398539672824688,
#  (4, 18, 54): 0.6085029752832394,
#  (5, 17, 54): 0.6086456500903911,
#  (4, 19, 19): 0.4959453033709292,
#  (5, 18, 19): 0.543222478630036,
#  (4, 19, 57): 0.6093778611037021,
#  (5, 18, 57): 0.6110883711250402,
#  (4, 20, 20): 0.5004434876119833,
#  (5, 19, 20): 0.5470177244216667,
#  (4, 20, 60): 0.6124243742485055,
#  (5, 19, 60): 0.6127122872794205,
#  (4, 21, 21): 0.501754931550492,
#  (5, 20, 21): 0.5505264463888041,
#  (4, 21, 63): 0.614252404517858,
#  (5, 20, 63): 0.6159845133914207,
#  (4, 22, 22): 0.5025522368075666,
#  (5, 21, 22): 0.5517973221921625,
#  (4, 22, 66): 0.6150826703511068,
#  (5, 21, 66): 0.6187561455845992,
#  (4, 23, 23): 0.5031675890997307,
#  (5, 22, 23): 0.5531504092469813,
#  (4, 23, 69): 0.6156283473259496,
#  (5, 22, 69): 0.6198103713388458,
#  (4, 24, 24): 0.506093654740131,
#  (5, 23, 24): 0.5539436130374774,
#  (4, 24, 72): 0.6177887948462294,
#  (5, 23, 72): 0.6206770046116361,
#  (4, 25, 25): 0.5079278041330082,
#  (5, 24, 25): 0.5569707103687193,
#  (4, 25, 75): 0.619438130170494,
#  (5, 24, 75): 0.6214497341455826,
#  (4, 26, 26): 0.5085600915129808,
#  (5, 25, 26): 0.5597136488340192,
#  (4, 26, 78): 0.6200700371725177,
#  (5, 25, 78): 0.6240545788772883,
#  (4, 27, 27): 0.5094988642906738,
#  (5, 26, 27): 0.5606478239999831,
#  (4, 27, 81): 0.6205027253583889,
#  (5, 26, 81): 0.6261406211631442,
#  (4, 28, 28): 0.5131205254322682,
#  (5, 27, 28): 0.5612278672955936,
#  (4, 28, 84): 0.6225665568796677,
#  (5, 27, 84): 0.6265492628473809,
#  (4, 29, 29): 0.5143106453432743,
#  (5, 28, 29): 0.5613912478936984,
#  (4, 29, 87): 0.6242289738977375,
#  (5, 28, 87): 0.626946129353376,
#  (4, 30, 30): 0.5156899950147334,
#  (5, 29, 30): 0.5637915319797965,
#  (4, 30, 90): 0.6246810778971702,
#  (5, 29, 90): 0.6272628022648563,
#  (4, 31, 31): 0.5166124611551424,
#  (5, 30, 31): 0.566074510814112,
#  (4, 31, 93): 0.6255271046080374,
#  (5, 30, 93): 0.6294413425449626,
#  (4, 32, 32): 0.5177187986883774,
#  (5, 31, 32): 0.5665562016026944,
#  (4, 32, 96): 0.6264351494627344,
#  (5, 31, 96): 0.6310857660322359,
#  (4, 33, 33): 0.5180689779356974,
#  (5, 32, 33): 0.5674294005296449,
#  (4, 33, 99): 0.626903626252138,
#  (5, 32, 99): 0.6314149087251689,
#  (4, 34, 34): 0.5183972606437027,
#  (5, 33, 34): 0.5680504584910413,
#  (4, 35, 35): 0.5188368121708242,
#  ...}

# %%
exportStateProbs(DATA_DIR + 'game1_better_giving_1_to_another_memo_1-100.csv', betterGiving1ToAnother)

# %%
betterGiving1ToAnother, given1ToAnother = readApproxBetterGiving1Probs(DATA_DIR + 'game1_better_giving_1_to_another_memo_1-100.csv')

# %%
betterGiving1ToAnother, given1ToAnother = stricterFilter(betterGiving1ToAnother, printOnGo=True,
                                                         filename=DATA_DIR + 'game1_better_giving_1_to_another_stricter_1-100.csv',
                                                         giveToAnother=True, continueFrom=(49,50,100))
# Out:
# Approximating hitting prob for (49, 13, 51)
# (49, 13, 51): 0.2592326148177825
# (48, 14, 51): 0.26222495411931784
#
# Approximating hitting prob for (48, 52, 52)
# (48, 52, 52): 0.35819501228612277
# (47, 53, 52): 0.4048820291394102
#
# Approximating hitting prob for (48, 53, 53)
# (48, 53, 53): 0.3592968828428967
# (47, 54, 53): 0.4061941848872044
#
# Approximating hitting prob for (49, 18, 53)
# (49, 18, 53): 0.2815075218808878
# (48, 19, 53): 0.2859901290598961
#
# Approximating hitting prob for (48, 54, 54)
# (48, 54, 54): 0.36029471770517746
# (47, 55, 54): 0.40738727636672817
#
# Approximating hitting prob for (48, 55, 55)
# (48, 55, 55): 0.36143027459362226
# (47, 56, 55): 0.40881514435762106
#
# Approximating hitting prob for (49, 14, 55)
# (49, 14, 55): 0.2632974640996106
# (48, 15, 55): 0.26856224051423205
#
# Approximating hitting prob for (48, 56, 56)
# (48, 56, 56): 0.3626759287590275
# (47, 57, 56): 0.40995209832818835
#
# Approximating hitting prob for (49, 19, 56)
# (49, 19, 56): 0.28704168087992094
# (48, 20, 56): 0.2912966267608805
#
# Approximating hitting prob for (49, 56, 57)
# (49, 56, 57): 0.4066045328172547
# (48, 57, 57): 0.36382639059288197
#
# Approximating hitting prob for (48, 58, 58)
# (48, 58, 58): 0.3652114698692203
# (47, 59, 58): 0.4126478339397483
#
# Approximating hitting prob for (48, 59, 59)
# (48, 59, 59): 0.3659401493113596
# (47, 60, 59): 0.4149519962988693
#
# Approximating hitting prob for (49, 15, 59)
# (49, 15, 59): 0.26700646436184877
# (48, 16, 59): 0.2813789467021625
#
# Approximating hitting prob for (49, 30, 59)
# (49, 30, 59): 0.3151979594676562
# (48, 31, 59): 0.31879360038825105
#
# Approximating hitting prob for (49, 59, 60)
# (49, 59, 60): 0.41058376035435146
# (48, 60, 60): 0.3679559744936582
#
# Approximating hitting prob for (49, 60, 61)
# (49, 60, 61): 0.4111620840852263
# (48, 61, 61): 0.3699283221654879
#
# Approximating hitting prob for (48, 62, 62)
# (48, 62, 62): 0.37104945114207005
# (47, 63, 62): 0.41817484685851375
#
# Approximating hitting prob for (48, 62, 79)
# (48, 62, 79): 0.4320171184118014
# (47, 63, 79): 0.4493614553018032
#
# Approximating hitting prob for (49, 21, 62)
# (49, 21, 62): 0.2952513763066793
# (48, 22, 62): 0.29768361510780855
#
# Approximating hitting prob for (49, 62, 63)
# (49, 62, 63): 0.41561828816081126
# (48, 63, 63): 0.37157121141349436
#
# Approximating hitting prob for (48, 64, 64)
# (48, 64, 64): 0.37265977777400555
# (47, 65, 64): 0.4205684760441521
#
# Approximating hitting prob for (48, 13, 65)
# (48, 13, 65): 0.2804609000158867
# (47, 14, 65): 0.28486324116508965
#
# Approximating hitting prob for (48, 65, 65)
# (48, 65, 65): 0.37425656998525175
# (47, 66, 65): 0.42165750069081126
#
# Approximating hitting prob for (48, 11, 66)
# (48, 11, 66): 0.2764054808704029
# (47, 12, 66): 0.2823945081680654
#
# Approximating hitting prob for (49, 22, 65)
# (49, 22, 65): 0.29806803333194226
# (48, 23, 65): 0.3008702485756205
#
# Approximating hitting prob for (48, 66, 66)
# (48, 66, 66): 0.37501017380220114
# (47, 67, 66): 0.4227792606849093
#
# Approximating hitting prob for (48, 67, 67)
# (48, 67, 67): 0.3755913109391485
# (47, 68, 67): 0.42347095118588224
#
# Approximating hitting prob for (48, 67, 76)
# (48, 67, 76): 0.4291249702071076
# (47, 68, 76): 0.44336749410623194
#
# Approximating hitting prob for (49, 34, 67)
# (49, 34, 67): 0.3256532902762281
# (48, 35, 67): 0.3289971136212875
#
# Approximating hitting prob for (49, 67, 68)
# (49, 67, 68): 0.4208397460276385
# (48, 68, 68): 0.37682525554075913
#
# Approximating hitting prob for (49, 67, 82)
# (49, 67, 82): 0.44677857017736605
# (48, 68, 82): 0.4464247909703001
#
# Approximating hitting prob for (48, 69, 69)
# (48, 69, 69): 0.3773700563408832
# (47, 70, 69): 0.4245285597797294
#
# Approximating hitting prob for (48, 14, 70)
# (48, 14, 70): 0.2842357904854372
# (47, 15, 70): 0.2907261487422445
#
# Approximating hitting prob for (49, 35, 69)
# (49, 35, 69): 0.32725988023677854
# (48, 36, 69): 0.33147823434671786
#
# Approximating hitting prob for (49, 69, 70)
# (49, 69, 70): 0.42280912019241684
# (48, 70, 70): 0.3777648829458807
#
# Approximating hitting prob for (49, 69, 83)
# (49, 69, 83): 0.44763583057365364
# (48, 70, 83): 0.4474801587338848
#
# Approximating hitting prob for (49, 70, 71)
# (49, 70, 71): 0.42353907061784607
# (48, 71, 71): 0.37811662419778597
#
# Approximating hitting prob for (48, 72, 72)
# (48, 72, 72): 0.38531294066601585
# (47, 73, 72): 0.4446407391437626
#
# Approximating hitting prob for (48, 73, 73)
# (48, 73, 73): 0.3924802992355947
# (47, 74, 73): 0.4449988803309511
#
# Approximating hitting prob for (49, 37, 73)
# (49, 37, 73): 0.33210496084853
# (48, 38, 73): 0.33519422056882386
#
# Approximating hitting prob for (49, 73, 74)
# (49, 73, 74): 0.43546198792138596
# (48, 74, 74): 0.3927588574432801
#
# Approximating hitting prob for (49, 74, 75)
# (49, 74, 75): 0.44301832935148006
# (48, 75, 75): 0.39321993388563553
#
# Approximating hitting prob for (49, 38, 75)
# (49, 38, 75): 0.33325862213868734
# (48, 39, 75): 0.3370170644562145
#
# Approximating hitting prob for (49, 75, 76)
# (49, 75, 76): 0.44460057337846554
# (48, 76, 76): 0.3936104997905013
#
# Approximating hitting prob for (49, 75, 86)
# (49, 75, 86): 0.45195014929807287
# (48, 76, 86): 0.451806998379116
#
# Approximating hitting prob for (49, 76, 77)
# (49, 76, 77): 0.444948606294527
# (48, 77, 77): 0.39427115778543204
#
# Approximating hitting prob for (49, 39, 77)
# (49, 39, 77): 0.33516705700611893
# (48, 40, 77): 0.3391016940660241
#
# Approximating hitting prob for (49, 77, 78)
# (49, 77, 78): 0.4454580727355204
# (48, 78, 78): 0.3947469573259146
#
# Approximating hitting prob for (49, 78, 79)
# (49, 78, 79): 0.4460533913245179
# (48, 79, 79): 0.3952219431113902
#
# Approximating hitting prob for (48, 80, 80)
# (48, 80, 80): 0.39923107976612376
# (47, 81, 80): 0.45322831186083773
#
# Approximating hitting prob for (49, 27, 80)
# (49, 27, 80): 0.3391778307943564
# (48, 28, 80): 0.3426652141910839
#
# Approximating hitting prob for (49, 80, 81)
# (49, 80, 81): 0.4470478858182299
# (48, 81, 81): 0.4007384634436817
#
# Approximating hitting prob for (48, 82, 82)
# (48, 82, 82): 0.40118779676322874
# (47, 83, 82): 0.45500098456133825
#
# Approximating hitting prob for (48, 83, 83)
# (48, 83, 83): 0.40157359803316517
# (47, 84, 83): 0.4556828089355398
#
# Approximating hitting prob for (48, 14, 84)
# (48, 14, 84): 0.29478745593125777
# (47, 15, 84): 0.29977090720490024
#
# Approximating hitting prob for (48, 18, 84)
# (48, 18, 84): 0.31681802025856354
# (47, 19, 84): 0.3242310439172456
#
# Approximating hitting prob for (49, 28, 83)
# (49, 28, 83): 0.34269418130386037
# (48, 29, 83): 0.3485362654593827
#
# Approximating hitting prob for (48, 84, 84)
# (48, 84, 84): 0.4025301176497849
# (47, 85, 84): 0.456195223675637
#
# Approximating hitting prob for (49, 83, 100)
# (49, 83, 100): 0.4783825677702585
# (48, 84, 100): 0.47820191237330634
#
# Approximating hitting prob for (49, 17, 84)
# (49, 17, 84): 0.3159432044649673
# (48, 18, 84): 0.31681802025856354
#
# Approximating hitting prob for (49, 84, 85)
# (49, 84, 85): 0.45336564730304
# (48, 85, 85): 0.40358541594220004
#
# Approximating hitting prob for (49, 19, 85)
# (49, 19, 85): 0.31819295220233135
# (48, 20, 85): 0.3253213023363381
#
# Approximating hitting prob for (48, 86, 86)
# (48, 86, 86): 0.40399699786783616
# (47, 87, 86): 0.4578298564403098
#
# Approximating hitting prob for (48, 86, 91)
# (48, 86, 91): 0.4574200127044485
# (47, 87, 91): 0.460527392195641
#
# Approximating hitting prob for (49, 29, 86)
# (49, 29, 86): 0.34530488489547523
# (48, 30, 86): 0.35048704719222307
#
# Approximating hitting prob for (48, 87, 87)
# (48, 87, 87): 0.40446053690438927
# (47, 88, 87): 0.4585131388004611
#
# Approximating hitting prob for (49, 44, 87)
# (49, 44, 87): 0.3432274309284069
# (48, 45, 87): 0.3483337812465756
#
# Approximating hitting prob for (49, 87, 88)
# (49, 87, 88): 0.4558767238635346
# (48, 88, 88): 0.40537758745520946
#
# Approximating hitting prob for (49, 87, 92)
# (49, 87, 92): 0.4586606802477029
# (48, 88, 92): 0.45823056779817345
#
# Approximating hitting prob for (48, 89, 89)
# (48, 89, 89): 0.40619028166033755
# (47, 90, 89): 0.45973861805152266
#
# Approximating hitting prob for (48, 15, 90)
# (48, 15, 90): 0.29881760228912907
# (47, 16, 90): 0.3196155994846576
#
# Approximating hitting prob for (48, 21, 90)
# (48, 21, 90): 0.32781766575744514
# (47, 22, 90): 0.33178686062675616
#
# Approximating hitting prob for (49, 30, 89)
# (49, 30, 89): 0.3500195527676698
# (48, 31, 89): 0.35241313668521007
#
# Approximating hitting prob for (48, 90, 90)
# (48, 90, 90): 0.40692635827340995
# (47, 91, 90): 0.4602579783047129
#
# Approximating hitting prob for (48, 90, 93)
# (48, 90, 93): 0.45865698648184733
# (47, 91, 93): 0.46119618809493085
#
# Approximating hitting prob for (48, 13, 91)
# (48, 13, 91): 0.2986952773454194
# (47, 14, 91): 0.30249906058410553
#
# Approximating hitting prob for (49, 46, 90)
# (49, 46, 90): 0.3467517290749254
# (48, 47, 90): 0.3590397281415439
#
# Approximating hitting prob for (49, 90, 91)
# (49, 90, 91): 0.45817996218757323
# (48, 91, 91): 0.40739245208653924
#
# Approximating hitting prob for (49, 22, 91)
# (49, 22, 91): 0.32978951238095683
# (48, 23, 91): 0.3316511180048283
#
# Approximating hitting prob for (48, 92, 92)
# (48, 92, 92): 0.4079108385741359
# (47, 93, 92): 0.459244638763819
#
# Approximating hitting prob for (48, 92, 94)
# (48, 92, 94): 0.45901947506500673
# (47, 93, 94): 0.47243344006801147
#
# Approximating hitting prob for (49, 31, 92)
# (49, 31, 92): 0.3526931592310815
# (48, 32, 92): 0.356892134801176
#
# Approximating hitting prob for (48, 93, 93)
# (48, 93, 93): 0.4083547124385222
# (47, 94, 93): 0.47243344006801147
#
# Approximating hitting prob for (49, 47, 93)
# (49, 47, 93): 0.3467195796164191
# (48, 48, 93): 0.418148001335452
#
# Approximating hitting prob for (49, 93, 94)
# (49, 93, 94): 0.4598191812067823
# (48, 94, 94): 0.40868695190990373
#
# Approximating hitting prob for (49, 19, 94)
# (49, 19, 94): 0.32423166260085967
# (48, 20, 94): 0.32704567925219924
#
# Approximating hitting prob for (49, 94, 95)
# (49, 94, 95): 0.46030344235828746
# (48, 95, 95): 0.4089794238369116
#
# Approximating hitting prob for (48, 96, 96)
# (48, 96, 96): 0.4285714285714286
# (47, 97, 96): 0.48622660126972117
#
# Approximating hitting prob for (48, 97, 97)
# (48, 97, 97): 0.4337311030232429
# (47, 98, 97): 0.4864894340781505
#
# Approximating hitting prob for (48, 98, 98)
# (48, 98, 98): 0.4338893544819032
# (47, 99, 98): 0.4868045903267768
#
# Approximating hitting prob for (49, 33, 98)
# (49, 33, 98): 0.3588799167551415
# (48, 34, 98): 0.3610461632702066
#
# Approximating hitting prob for (49, 98, 99)
# (49, 98, 99): 0.4850986317493325
# (48, 99, 99): 0.4341300809805498
#
# Approximating hitting prob for (49, 20, 99)
# (49, 20, 99): 0.32718738853467405
# (48, 21, 99): 0.32997378641718744
#
# Approximating hitting prob for (48, 98, 100)
# (48, 98, 100): 0.48493918764648036
# (47, 99, 100): 0.4871012322999338
#
# Approximating hitting prob for (49, 99, 100)
# (49, 99, 100): 0.4842647193271105
# (48, 100, 100): 0.4343891715843085
#
# Approximating hitting prob for (50, 1, 53)
# (50, 1, 53): 0.2496928836351724
# (49, 2, 53): 0.24918349496012202
#
# Approximating hitting prob for (50, 1, 54)
# (50, 1, 54): 0.24988871044352057
# (49, 2, 54): 0.24945656565438976
#
# Approximating hitting prob for (50, 2, 56)
# (50, 2, 56): 0.25140366947242754
# (49, 3, 56): 0.2513296165240732
#
# Approximating hitting prob for (50, 2, 57)
# (50, 2, 57): 0.25193922515169026
# (49, 3, 57): 0.2515668730364882
#
# Approximating hitting prob for (50, 4, 5)
# (50, 4, 5): 0.011727922085513319
# (49, 5, 5): 0.011007111978347243
#
# Approximating hitting prob for (50, 4, 10)
# (50, 4, 10): 0.026113208031560767
# (49, 5, 10): 0.025226439167260972
#
# Approximating hitting prob for (50, 5, 6)
# (50, 5, 6): 0.016098796340351756
# (49, 6, 6): 0.01339615146368415
#
# Approximating hitting prob for (50, 5, 18)
# (50, 5, 18): 0.06714689757133159
# (49, 6, 18): 0.0661940053177795
#
# Approximating hitting prob for (50, 5, 66)
# (50, 5, 66): 0.26164167969713004
# (49, 6, 66): 0.2611595463447664
#
# Approximating hitting prob for (50, 7, 8)
# (50, 7, 8): 0.028299924789414427
# (49, 8, 8): 0.025161748991218504
#
# Approximating hitting prob for (50, 7, 24)
# (50, 7, 24): 0.0868908091832921
# (49, 8, 24): 0.0855537773004003
#
# Approximating hitting prob for (50, 8, 9)
# (50, 8, 9): 0.03720967657192853
# (49, 9, 9): 0.032387564216364496
#
# Approximating hitting prob for (50, 8, 18)
# (50, 8, 18): 0.07598848267907553
# (49, 9, 18): 0.07424864699502508
#
# Approximating hitting prob for (50, 8, 27)
# (50, 8, 27): 0.10382881170371878
# (49, 9, 27): 0.10367230204805496
#
# Approximating hitting prob for (49, 10, 10)
# (49, 10, 10): 0.03581648455779717
# (48, 11, 10): 0.051945114992061926
#
# Approximating hitting prob for (49, 11, 11)
# (49, 11, 11): 0.039193650961758565
# (48, 12, 11): 0.05601632595103489
#
# Approximating hitting prob for (49, 11, 22)
# (49, 11, 22): 0.09712152640247916
# (48, 12, 22): 0.10876452426468898
#
# Approximating hitting prob for (49, 11, 33)
# (49, 11, 33): 0.12417440455480343
# (48, 12, 33): 0.13346196619189737
#
# Approximating hitting prob for (49, 6, 12)
# (49, 6, 12): 0.03496692010877083
# (48, 7, 12): 0.04378946463396807
#
# Approximating hitting prob for (49, 12, 12)
# (49, 12, 12): 0.0419644576806451
# (48, 13, 12): 0.07339764381997706
#
# Approximating hitting prob for (49, 12, 24)
# (49, 12, 24): 0.10203853973091737
# (48, 13, 24): 0.11616039971907743
#
# Approximating hitting prob for (49, 12, 36)
# (49, 12, 36): 0.12799705373828887
# (48, 13, 36): 0.1741876294962241
#
# Approximating hitting prob for (49, 12, 60)
# (49, 12, 60): 0.2605094610890844
# (48, 13, 60): 0.26745039557471123
#
# Approximating hitting prob for (49, 12, 84)
# (49, 12, 84): 0.2875086675770506
# (48, 13, 84): 0.2949167353210976
#
# Approximating hitting prob for (49, 12, 85)
# (49, 12, 85): 0.28941227304262046
# (48, 13, 85): 0.2960565815229561
#
# Approximating hitting prob for (49, 13, 13)
# (49, 13, 13): 0.059716725114631074
# (48, 14, 13): 0.07733963516494416
#
# Approximating hitting prob for (49, 13, 26)
# (49, 13, 26): 0.10932432584879058
# (48, 14, 26): 0.12309590343535352
#
# Approximating hitting prob for (49, 14, 14)
# (49, 14, 14): 0.0632403073695315
# (48, 15, 14): 0.08251441388383883
#
# Approximating hitting prob for (49, 14, 28)
# (49, 14, 28): 0.11700666496792217
# (48, 15, 28): 0.12936185628868885
#
# Approximating hitting prob for (49, 14, 38)
# (49, 14, 38): 0.17730885659133824
# (48, 15, 38): 0.1808847196502568
#
# Approximating hitting prob for (49, 14, 42)
# (49, 14, 42): 0.18061955541409938
# (48, 15, 42): 0.19230266884047922
#
# Approximating hitting prob for (49, 14, 56)
# (49, 14, 56): 0.26173204666721905
# (48, 15, 56): 0.2693926249224055
#
# Approximating hitting prob for (49, 14, 90)
# (49, 14, 90): 0.2977417096580865
# (48, 15, 90): 0.29881760228912907
#
# Approximating hitting prob for (49, 15, 15)
# (49, 15, 15): 0.06787509956821229
# (48, 16, 15): 0.09708602044319235
#
# Approximating hitting prob for (49, 15, 30)
# (49, 15, 30): 0.12328765969921446
# (48, 16, 30): 0.14403345626987496
#
# Approximating hitting prob for (49, 15, 45)
# (49, 15, 45): 0.19085006122201742
# (48, 16, 45): 0.21110854702221146
#
# Approximating hitting prob for (49, 15, 60)
# (49, 15, 60): 0.26511837264400123
# (48, 16, 60): 0.2820725912171969
#
# Approximating hitting prob for (49, 16, 16)
# (49, 16, 16): 0.07117067258292283
# (48, 17, 16): 0.11358510032663321
#
# Approximating hitting prob for (49, 16, 32)
# (49, 16, 32): 0.12617641478407973
# (48, 17, 32): 0.1823189331048448
#
# Approximating hitting prob for (49, 16, 48)
# (49, 16, 48): 0.198326056315427
# (48, 17, 48): 0.27526544341109777
#
# Approximating hitting prob for (49, 16, 64)
# (49, 16, 64): 0.26721296665598215
# (48, 17, 64): 0.2947106122827246
#
# Approximating hitting prob for (49, 16, 96)
# (49, 16, 96): 0.3005210124385934
# (48, 17, 96): 0.324665459667733
#
# Approximating hitting prob for (49, 16, 97)
# (49, 16, 97): 0.3023519126299951
# (48, 17, 97): 0.32530912274705653
#
# Approximating hitting prob for (49, 17, 17)
# (49, 17, 17): 0.09759084767774263
# (48, 18, 17): 0.11672547991827764
#
# Approximating hitting prob for (50, 6, 17)
# (50, 6, 17): 0.0675816790181875
# (49, 7, 17): 0.07318487397612713
#
# Approximating hitting prob for (49, 18, 18)
# (49, 18, 18): 0.09915401797776315
# (48, 19, 18): 0.12014544837565981
#
# Approximating hitting prob for (49, 18, 36)
# (49, 18, 36): 0.17988694871688404
# (48, 19, 36): 0.19339464400926118
#
# Approximating hitting prob for (49, 18, 54)
# (49, 18, 54): 0.2746741403232143
# (48, 19, 54): 0.2865319626439633
#
# Approximating hitting prob for (49, 18, 90)
# (49, 18, 90): 0.3175619007003527
# (48, 19, 90): 0.3247698169417423
#
# Approximating hitting prob for (49, 19, 19)
# (49, 19, 19): 0.10235647517351848
# (48, 20, 19): 0.12342964651102391
#
# Approximating hitting prob for (49, 19, 38)
# (49, 19, 38): 0.1855706223160567
# (48, 20, 38): 0.19974354167257524
#
# Approximating hitting prob for (49, 19, 57)
# (49, 19, 57): 0.2805321268976451
# (48, 20, 57): 0.2917791008179888
# Approximating hitting prob for (49, 20, 20)
# (49, 20, 20): 0.10483175066917122
# (48, 21, 20): 0.12587200869754425
#
# Approximating hitting prob for (49, 20, 40)
# (49, 20, 40): 0.1926017709516171
# (48, 21, 40): 0.2070076536579344
#
# Approximating hitting prob for (49, 20, 60)
# (49, 20, 60): 0.28477749159385635
# (48, 21, 60): 0.29511333170583026
#
# Approximating hitting prob for (49, 20, 100)
# (49, 20, 100): 0.32548006608641544
# (48, 21, 100): 0.32954533735344366
#
# Approximating hitting prob for (49, 21, 21)
# (49, 21, 21): 0.10681958255107261
# (48, 22, 21): 0.12888726068963313
#
# Approximating hitting prob for (49, 21, 42)
# (49, 21, 42): 0.1985157958677145
# (48, 22, 42): 0.2146221427281223
#
# Approximating hitting prob for (49, 21, 63)
# (49, 21, 63): 0.2885007764326315
# (48, 22, 63): 0.29851125585957516
#
# Approximating hitting prob for (50, 11, 21)
# (50, 11, 21): 0.10344001822632204
# (49, 12, 21): 0.10527552077936615
#
# Approximating hitting prob for (50, 21, 22)
# (50, 21, 22): 0.1261279206506148
# (49, 22, 22): 0.10848183896048424
#
# Approximating hitting prob for (50, 21, 44)
# (50, 21, 44): 0.21002115423864953
# (49, 22, 44): 0.2053406484698167
#
# Approximating hitting prob for (50, 21, 66)
# (50, 21, 66): 0.29630747402200924
# (49, 22, 66): 0.2912375640174735
#
# Approximating hitting prob for (50, 22, 23)
# (50, 22, 23): 0.1290073948839796
# (49, 23, 23): 0.11026243143031318
#
# Approximating hitting prob for (50, 22, 46)
# (50, 22, 46): 0.21698266317063533
# (49, 23, 46): 0.21074506946462587
#
# Approximating hitting prob for (50, 22, 69)
# (50, 22, 69): 0.2993245760693862
# (49, 23, 69): 0.2941233069012807
#
# Approximating hitting prob for (50, 12, 23)
# (50, 12, 23): 0.10840141025531057
# (49, 13, 23): 0.11287132346373989
#
# Approximating hitting prob for (50, 23, 24)
# (50, 23, 24): 0.13194334861562154
# (49, 24, 24): 0.11097202346105904
#
# Approximating hitting prob for (50, 23, 40)
# (50, 23, 40): 0.2073943346424578
# (49, 24, 40): 0.20706921509378107
#
# Approximating hitting prob for (50, 23, 48)
# (50, 23, 48): 0.22394270772541883
# (49, 24, 48): 0.21411502726103346
#
# Approximating hitting prob for (50, 23, 56)
# (50, 23, 56): 0.2918223315040713
# (49, 24, 56): 0.2915804016240808
#
# Approximating hitting prob for (50, 23, 72)
# (50, 23, 72): 0.3016644122756423
# (49, 24, 72): 0.2956026136421761
#
# Approximating hitting prob for (49, 26, 26)
# (49, 26, 26): 0.16430208365835083
# (48, 27, 26): 0.2072819596568122
#
# Approximating hitting prob for (49, 26, 52)
# (49, 26, 52): 0.2927509107291244
# (48, 27, 52): 0.3051694835601262
#
# Approximating hitting prob for (49, 26, 78)
# (49, 26, 78): 0.33029776307384506
# (48, 27, 78): 0.3395382785392136
#
# Approximating hitting prob for (50, 9, 26)
# (50, 9, 26): 0.10512206926840421
# (49, 10, 26): 0.10847965088215245
#
# Approximating hitting prob for (50, 26, 27)
# (50, 26, 27): 0.2054291992835775
# (49, 27, 27): 0.1656556739998994
#
# Approximating hitting prob for (50, 26, 54)
# (50, 26, 54): 0.3030443690879818
# (49, 27, 54): 0.29415322928729587
#
# Approximating hitting prob for (50, 26, 61)
# (50, 26, 61): 0.3111678198268692
# (49, 27, 61): 0.3109540800027134
#
# Approximating hitting prob for (50, 26, 81)
# (50, 26, 81): 0.3381102307789908
# (49, 27, 81): 0.33230975475272895
#
# Approximating hitting prob for (49, 28, 28)
# (49, 28, 28): 0.16730654501220313
# (48, 29, 28): 0.212739251753674
#
# Approximating hitting prob for (49, 28, 56)
# (49, 28, 56): 0.29645307031430956
# (48, 29, 56): 0.311206785073972
#
# Approximating hitting prob for (49, 28, 84)
# (49, 28, 84): 0.3358327513751364
# (48, 29, 84): 0.348634429453905
#
# Approximating hitting prob for (49, 29, 29)
# (49, 29, 29): 0.16888837593641817
# (48, 30, 29): 0.21675473054293645
#
# Approximating hitting prob for (49, 29, 58)
# (49, 29, 58): 0.2982791959278485
# (48, 30, 58): 0.31605570424869295
#
# Approximating hitting prob for (49, 29, 87)
# (49, 29, 87): 0.338062309247888
# (48, 30, 87): 0.3506641605704081
#
# Approximating hitting prob for (50, 15, 29)
# (50, 15, 29): 0.12748459395753572
# (49, 16, 29): 0.13096721776557554
#
# Approximating hitting prob for (50, 29, 30)
# (50, 29, 30): 0.21225273394749977
# (49, 30, 30): 0.17459352561116503
#
# Approximating hitting prob for (50, 29, 60)
# (50, 29, 60): 0.3099943073188441
# (49, 30, 60): 0.3055563032481636
#
# Approximating hitting prob for (50, 29, 90)
# (50, 29, 90): 0.3458256727808265
# (49, 30, 90): 0.3429378037849202
#
# Approximating hitting prob for (50, 30, 31)
# (50, 30, 31): 0.2161708911654948
# (49, 31, 31): 0.1769235213378387
#
# Approximating hitting prob for (50, 30, 47)
# (50, 30, 47): 0.24198319058981033
# (49, 31, 47): 0.24125391666341378
#
# Approximating hitting prob for (50, 30, 62)
# (50, 30, 62): 0.31607970942162755
# (49, 31, 62): 0.30705050439456966
#
# Approximating hitting prob for (50, 30, 93)
# (50, 30, 93): 0.34937397749504356
# (49, 31, 93): 0.34585294219360246
#
# Approximating hitting prob for (49, 32, 32)
# (49, 32, 32): 0.17836259023424028
# (48, 33, 32): 0.22733445208404765
#
# Approximating hitting prob for (49, 32, 48)
# (49, 32, 48): 0.23952572004654182
# (48, 33, 48): 0.3111544487933215
#
# Approximating hitting prob for (49, 32, 64)
# (49, 32, 64): 0.3096899988283341
# (48, 33, 64): 0.3249205484718774
#
# Approximating hitting prob for (49, 32, 96)
# (49, 32, 96): 0.3472268390937834
# (48, 33, 96): 0.3593695118734197
#
# Approximating hitting prob for (50, 11, 32)
# (50, 11, 32): 0.12473208171120326
# (49, 12, 32): 0.13110160695013487
#
# Approximating hitting prob for (50, 32, 33)
# (50, 32, 33): 0.22071883831683523
# (49, 33, 33): 0.18492657503758092
#
# Approximating hitting prob for (50, 32, 66)
# (50, 32, 66): 0.3204483239933536
# (49, 33, 66): 0.31367039601514496
#
# Approximating hitting prob for (50, 32, 99)
# (50, 32, 99): 0.35487911970819047
# (49, 33, 99): 0.35189246870360485
#
# Approximating hitting prob for (50, 33, 34)
# (50, 33, 34): 0.2263550838425418
# (49, 34, 34): 0.18640456544593267
#
# Approximating hitting prob for (50, 33, 68)
# (50, 33, 68): 0.323005620368295
# (49, 34, 68): 0.31515582547046644
#
# Approximating hitting prob for (50, 34, 35)
# (50, 34, 35): 0.2286359464251613
# (49, 35, 35): 0.18977369529147772
#
# Approximating hitting prob for (50, 34, 51)
# (50, 34, 51): 0.3246833455285531
# (49, 35, 51): 0.32317316427708637
#
# Approximating hitting prob for (50, 34, 70)
# (50, 34, 70): 0.32612933784694426
# (49, 35, 70): 0.31763632498740596
#
# Approximating hitting prob for (50, 18, 35)
# (50, 18, 35): 0.18686262436015688
# (49, 19, 35): 0.18723223220497318
#
# Approximating hitting prob for (50, 35, 36)
# (50, 35, 36): 0.23176817602123626
# (49, 36, 36): 0.19086861247894496
#
# Approximating hitting prob for (50, 35, 52)
# (50, 35, 52): 0.3250817967339627
# (49, 36, 52): 0.3244523567121918
#
# Approximating hitting prob for (50, 35, 60)
# (50, 35, 60): 0.3239060956531146
# (49, 36, 60): 0.32236537202209836
#
# Approximating hitting prob for (50, 35, 72)
# (50, 35, 72): 0.32866163085113914
# (49, 36, 72): 0.31936638941531176
#
# Approximating hitting prob for (50, 36, 37)
# (50, 36, 37): 0.23337137578546682
# (49, 37, 37): 0.20072183264474341
#
# Approximating hitting prob for (50, 36, 53)
# (50, 36, 53): 0.326250725438476
# (49, 37, 53): 0.32593704199581597
#
# Approximating hitting prob for (50, 36, 74)
# (50, 36, 74): 0.3305816059686614
# (49, 37, 74): 0.32119329695436155
#
# Approximating hitting prob for (49, 38, 38)
# (49, 38, 38): 0.2018236264036479
# (48, 39, 38): 0.24727632303364097
#
# Approximating hitting prob for (49, 38, 54)
# (49, 38, 54): 0.32718726491527583
# (48, 39, 54): 0.3296111568190323
#
# Approximating hitting prob for (49, 38, 76)
# (49, 38, 76): 0.32222074553637564
# (48, 39, 76): 0.3367550041499896
#
# Approximating hitting prob for (49, 13, 39)
# (49, 13, 39): 0.17380991032821816
# (48, 14, 39): 0.1822889609414815
#
# Approximating hitting prob for (50, 38, 39)
# (50, 38, 39): 0.24460453977981975
# (49, 39, 39): 0.20342916390703206
#
# Approximating hitting prob for (50, 38, 55)
# (50, 38, 55): 0.3290334842191884
# (49, 39, 55): 0.3290570094733912
#
# Approximating hitting prob for (50, 38, 78)
# (50, 38, 78): 0.3339435942654198
# (49, 39, 78): 0.3240539704897479
#
# Approximating hitting prob for (49, 40, 40)
# (49, 40, 40): 0.2055289712334676
# (48, 41, 40): 0.25323394170577945
#
# Approximating hitting prob for (49, 40, 56)
# (49, 40, 56): 0.33033652288994453
# (48, 41, 56): 0.3345031944014884
#
# Approximating hitting prob for (49, 40, 80)
# (49, 40, 80): 0.3254829117180704
# (48, 41, 80): 0.34129286348316495
#
# Approximating hitting prob for (49, 41, 41)
# (49, 41, 41): 0.2093939376228233
# (48, 42, 41): 0.2562055788569255
#
# Approximating hitting prob for (49, 41, 82)
# (49, 41, 82): 0.3285504307317837
# (48, 42, 82): 0.34297066653169334
#
# Approximating hitting prob for (50, 40, 84)
# (50, 40, 84): 0.3419135632306713
# (49, 41, 84): 0.34149648725321385
#
# Approximating hitting prob for (50, 21, 41)
# (50, 21, 41): 0.20260738207759774
# (49, 22, 41): 0.2083582727234965
#
# Approximating hitting prob for (50, 41, 42)
# (50, 41, 42): 0.2505962853681994
# (49, 42, 42): 0.21108106781728822
#
# Approximating hitting prob for (50, 41, 84)
# (50, 41, 84): 0.34030138004123905
# (49, 42, 84): 0.3295918193334498
#
# Approximating hitting prob for (49, 43, 43)
# (49, 43, 43): 0.2141761811884192
# (48, 44, 43): 0.2604870088288725
#
# Approximating hitting prob for (49, 43, 59)
# (49, 43, 59): 0.33618069372066106
# (48, 44, 59): 0.3388479672622249
#
# Approximating hitting prob for (49, 43, 86)
# (49, 43, 86): 0.33046572033131283
# (48, 44, 86): 0.34546797885562447
#
# Approximating hitting prob for (49, 43, 87)
# (49, 43, 87): 0.34260376537274634
# (48, 44, 87): 0.3441964157964455
#
# Approximating hitting prob for (50, 42, 88)
# (50, 42, 88): 0.34459263517879796
# (49, 43, 88): 0.3438918283587493
#
# Approximating hitting prob for (49, 44, 44)
# (49, 44, 44): 0.21513928406306534
# (48, 45, 44): 0.2623432213181236
#
# Approximating hitting prob for (49, 44, 60)
# (49, 44, 60): 0.3377124235247723
# (48, 45, 60): 0.3398818405391531
#
# Approximating hitting prob for (49, 44, 88)
# (49, 44, 88): 0.3312643727632318
# (48, 45, 88): 0.34671501474584215
#
# Approximating hitting prob for (49, 44, 89)
# (49, 44, 89): 0.3435619378212655
# (48, 45, 89): 0.34535008849652843
#
# Approximating hitting prob for (50, 15, 44)
# (50, 15, 44): 0.19195777564611446
# (49, 16, 44): 0.1976381512366877
#
# Approximating hitting prob for (50, 44, 45)
# (50, 44, 45): 0.2592218872463365
# (49, 45, 45): 0.21711606544227777
#
# Approximating hitting prob for (50, 44, 90)
# (50, 44, 90): 0.34401413350096094
# (49, 45, 90): 0.33188863150651354
#
# Approximating hitting prob for (50, 44, 91)
# (50, 44, 91): 0.3459694738682125
# (49, 45, 91): 0.344516112856758
#
# Approximating hitting prob for (49, 46, 46)
# (49, 46, 46): 0.21904172806146482
# (48, 47, 46): 0.2653640575712269
#
# Approximating hitting prob for (49, 46, 62)
# (49, 46, 62): 0.34062498803256647
# (48, 47, 62): 0.3429985108528337
#
# Approximating hitting prob for (49, 46, 92)
# (49, 46, 92): 0.3324171639855083
# (48, 47, 92): 0.3567999784097667
#
# Approximating hitting prob for (49, 46, 93)
# (49, 46, 93): 0.34568422949659733
# (48, 47, 93): 0.34951463951839506
#
# Approximating hitting prob for (49, 47, 47)
# (49, 47, 47): 0.22022091490532836
# (48, 48, 47): 0.3220168514873083
#
# Approximating hitting prob for (49, 47, 63)
# (49, 47, 63): 0.34188220322427987
# (48, 48, 63): 0.399532070600873
#
# Approximating hitting prob for (49, 47, 94)
# (49, 47, 94): 0.33289693194729386
# (48, 48, 94): 0.4182247182312508
#
# Approximating hitting prob for (49, 47, 95)
# (49, 47, 95): 0.34797932555680494
# (48, 48, 95): 0.41827032329605274
#
# Approximating hitting prob for (50, 16, 47)
# (50, 16, 47): 0.20129648842963452
# (49, 17, 47): 0.2163251664267193
#
# Approximating hitting prob for (50, 32, 47)
# (50, 32, 47): 0.24044472585456167
# (49, 33, 47): 0.24935886963510337
#
# Approximating hitting prob for (50, 47, 48)
# (50, 47, 48): 0.2642015528761425
# (49, 48, 48): 0.2214273032597653
#
# Approximating hitting prob for (50, 47, 64)
# (50, 47, 64): 0.34339120627203906
# (49, 48, 64): 0.3425651792237165
#
# Approximating hitting prob for (50, 47, 96)
# (50, 47, 96): 0.34852444660797194
# (49, 48, 96): 0.33318391121363794
#
# Approximating hitting prob for (50, 17, 50)
# (50, 17, 50): 0.2745534947875036
# (49, 18, 50): 0.279488638255973
#
# Approximating hitting prob for (50, 50, 51)
# (50, 50, 51): 0.38926412365443336
# (49, 51, 51): 0.35655626983945493
#
# Approximating hitting prob for (50, 13, 51)
# (50, 13, 51): 0.2583913307770719
# (49, 14, 51): 0.26164091196152545
#
# Approximating hitting prob for (49, 52, 52)
# (49, 52, 52): 0.35719587853145307
# (48, 53, 52): 0.40351577641653585
#
# Approximating hitting prob for (49, 52, 68)
# (49, 52, 68): 0.41727150815241276
# (48, 53, 68): 0.4192375555577584
#
# Approximating hitting prob for (49, 53, 53)
# (49, 53, 53): 0.35805756557807195
# (48, 54, 53): 0.404615644526731
#
# Approximating hitting prob for (49, 53, 69)
# (49, 53, 69): 0.4182921648138264
# (48, 54, 69): 0.42091139183936227
#
# Approximating hitting prob for (50, 18, 53)
# (50, 18, 53): 0.28025932408739923
# (49, 19, 53): 0.28510314693535327
#
# Approximating hitting prob for (49, 54, 54)
# (49, 54, 54): 0.359266262561243
# (48, 55, 54): 0.4061488097957338
#
# Approximating hitting prob for (49, 54, 70)
# (49, 54, 70): 0.41924477898432855
# (48, 55, 70): 0.4222493186262078
#
# Approximating hitting prob for (49, 11, 55)
# (49, 11, 55): 0.25619578238974255
# (48, 12, 55): 0.26269124797965826
#
# Approximating hitting prob for (49, 55, 55)
# (49, 55, 55): 0.3596826553040129
# (48, 56, 55): 0.4067626987769131
#
# Approximating hitting prob for (50, 14, 55)
# (50, 14, 55): 0.262301018084836
# (49, 15, 55): 0.26749138098498587
#
# Approximating hitting prob for (49, 56, 56)
# (49, 56, 56): 0.36117495610369726
# (48, 57, 56): 0.40880309332261877
#
# Approximating hitting prob for (50, 19, 56)
# (50, 19, 56): 0.2854254298904318
# (49, 20, 56): 0.28829005661308077
#
# Approximating hitting prob for (50, 56, 57)
# (50, 56, 57): 0.4055358616407898
# (49, 57, 57): 0.361885568774068
#
# Approximating hitting prob for (50, 56, 73)
# (50, 56, 73): 0.4243920872933558
# (49, 57, 73): 0.42302339019358337
#
# Approximating hitting prob for (49, 58, 58)
# (49, 58, 58): 0.36369209013696363
# (48, 59, 58): 0.41082643185238443
#
# Approximating hitting prob for (49, 59, 59)
# (49, 59, 59): 0.3651134882427103
# (48, 60, 59): 0.41154209160715477
#
# Approximating hitting prob for (50, 12, 59)
# (50, 12, 59): 0.26110732488031396
# (49, 13, 59): 0.26575947551060786
#
# Approximating hitting prob for (50, 20, 59)
# (50, 20, 59): 0.2889329370257283
# (49, 21, 59): 0.2929774151188676
#
# Approximating hitting prob for (49, 60, 60)
# (49, 60, 60): 0.3657915479086749
# (48, 61, 60): 0.41498037669242765
#
# Approximating hitting prob for (49, 60, 76)
# (49, 60, 76): 0.4275016465032675
# (48, 61, 76): 0.429249307594363
#
# Approximating hitting prob for (49, 60, 84)
# (49, 60, 84): 0.4345245702049563
# (48, 61, 84): 0.44950783686123885
#
# Approximating hitting prob for (49, 60, 100)
# (49, 60, 100): 0.4694858338598537
# (48, 61, 100): 0.4718853081001
#
# Approximating hitting prob for (49, 61, 61)
# (49, 61, 61): 0.3662529332031364
# (48, 62, 61): 0.41589746137475286
#
# Approximating hitting prob for (49, 61, 77)
# (49, 61, 77): 0.4286443210118141
# (48, 62, 77): 0.43034429099048005
#
# Approximating hitting prob for (49, 61, 85)
# (49, 61, 85): 0.435957081850364
# (48, 62, 85): 0.45038725988720324
#
# Approximating hitting prob for (50, 31, 61)
# (50, 31, 61): 0.3164454099060981
# (49, 32, 61): 0.3194639551279124
#
# Approximating hitting prob for (50, 61, 62)
# (50, 61, 62): 0.4112132342227417
# (49, 62, 62): 0.3698273391680389
#
# Approximating hitting prob for (50, 61, 78)
# (50, 61, 78): 0.4302469892882783
# (49, 62, 78): 0.4291818612949208
#
# Approximating hitting prob for (50, 61, 80)
# (50, 61, 80): 0.43133530967141914
# (49, 62, 80): 0.4312487925753909
#
# Approximating hitting prob for (49, 63, 63)
# (49, 63, 63): 0.3708512080439254
# (48, 64, 63): 0.41754208564335477
#
# Approximating hitting prob for (49, 63, 79)
# (49, 63, 79): 0.43032407966339997
# (48, 64, 79): 0.4315892427682815
#
# Approximating hitting prob for (50, 16, 63)
# (50, 16, 63): 0.26900050147855065
# (49, 17, 63): 0.2896807998668974
#
# Approximating hitting prob for (49, 64, 64)
# (49, 64, 64): 0.37140700499520024
# (48, 65, 64): 0.41967502973525234
#
# Approximating hitting prob for (49, 64, 80)
# (49, 64, 80): 0.43087851207346156
# (48, 65, 80): 0.44635140664713274
#
# Approximating hitting prob for (49, 64, 81)
# (49, 64, 81): 0.43227250816819174
# (48, 65, 81): 0.44854875500295927
#
# Approximating hitting prob for (49, 64, 88)
# (49, 64, 88): 0.45106172357649416
# (48, 65, 88): 0.4529744533712048
#
# Approximating hitting prob for (49, 13, 65)
# (49, 13, 65): 0.2798108757011915
# (48, 14, 65): 0.2833404626224601
#
# Approximating hitting prob for (49, 65, 65)
# (49, 65, 65): 0.37184259711783724
# (48, 66, 65): 0.4201995539267371
#
# Approximating hitting prob for (49, 65, 81)
# (49, 65, 81): 0.4313521879637943
# (48, 66, 81): 0.44562919070332163
# Approximating hitting prob for (49, 65, 89)
# (49, 65, 89): 0.4516600170652683
# (48, 66, 89): 0.4536765775593654
#
# Approximating hitting prob for (50, 22, 65)
# (50, 22, 65): 0.2968392477841843
# (49, 23, 65): 0.29947554345068483
#
# Approximating hitting prob for (49, 66, 66)
# (49, 66, 66): 0.3741509403881147
# (48, 67, 66): 0.42115654724473095
#
# Approximating hitting prob for (49, 66, 90)
# (49, 66, 90): 0.453008101998176
# (48, 67, 90): 0.45488979390572565
#
# Approximating hitting prob for (49, 67, 67)
# (49, 67, 67): 0.37469659855154197
# (48, 68, 67): 0.42214128602323014
#
# Approximating hitting prob for (49, 67, 91)
# (49, 67, 91): 0.45357400572255907
# (48, 68, 91): 0.45577334672469144
#
# Approximating hitting prob for (50, 34, 67)
# (50, 34, 67): 0.3238691196192802
# (49, 35, 67): 0.32706911187163606
#
# Approximating hitting prob for (50, 67, 68)
# (50, 67, 68): 0.4195718411586801
# (49, 68, 68): 0.375390018005955
#
# Approximating hitting prob for (50, 67, 84)
# (50, 67, 84): 0.4493539731795912
# (49, 68, 84): 0.44761781762987796
#
# Approximating hitting prob for (50, 67, 92)
# (50, 67, 92): 0.45510101567548683
# (49, 68, 92): 0.4549096848116685
#
# Approximating hitting prob for (49, 69, 69)
# (49, 69, 69): 0.3766518447631743
# (48, 70, 69): 0.42373961329566945
#
# Approximating hitting prob for (49, 69, 85)
# (49, 69, 85): 0.4484760126461101
# (48, 70, 85): 0.44998332414073006
#
# Approximating hitting prob for (50, 35, 69)
# (50, 35, 69): 0.3259293515513037
# (49, 36, 69): 0.32925099772318706
#
# Approximating hitting prob for (50, 69, 70)
# (50, 69, 70): 0.4215316838794359
# (49, 70, 70): 0.3771242300341173
#
# Approximating hitting prob for (50, 69, 84)
# (50, 69, 84): 0.446927116189857
# (49, 70, 84): 0.44639786961356437
#
# Approximating hitting prob for (50, 69, 86)
# (50, 69, 86): 0.450242816785227
# (49, 70, 86): 0.4491031936776942
#
# Approximating hitting prob for (50, 69, 94)
# (50, 69, 94): 0.4570716203380627
# (49, 70, 94): 0.45690962775341704
#
# Approximating hitting prob for (50, 70, 71)
# (50, 70, 71): 0.4224623913712417
# (49, 71, 71): 0.3775953720640357
#
# Approximating hitting prob for (50, 70, 87)
# (50, 70, 87): 0.4510844478914413
# (49, 71, 87): 0.4500088009823342
#
# Approximating hitting prob for (50, 70, 95)
# (50, 70, 95): 0.4578522696460674
# (49, 71, 95): 0.45755615892969587
#
# Approximating hitting prob for (50, 36, 71)
# (50, 36, 71): 0.3281022150153708
# (49, 37, 71): 0.3319397429856715
#
# Approximating hitting prob for (50, 71, 72)
# (50, 71, 72): 0.42320540686819613
# (49, 72, 72): 0.3780145585367758
#
# Approximating hitting prob for (50, 71, 85)
# (50, 71, 85): 0.4478440570029098
# (49, 72, 85): 0.44766010800367323
#
# Approximating hitting prob for (50, 71, 88)
# (50, 71, 88): 0.4517193613570714
# (49, 72, 88): 0.4511655972385546
#
# Approximating hitting prob for (50, 71, 96)
# (50, 71, 96): 0.4589844146312376
# (49, 72, 96): 0.45811255076536717
#
# Approximating hitting prob for (50, 72, 73)
# (50, 72, 73): 0.42380159717514987
# (49, 73, 73): 0.37820623427835326
#
# Approximating hitting prob for (50, 72, 89)
# (50, 72, 89): 0.45253122130715157
# (49, 73, 89): 0.45189790549671627
#
# Approximating hitting prob for (50, 72, 97)
# (50, 72, 97): 0.4596154561703371
# (49, 73, 97): 0.45889994628855346
#
# Approximating hitting prob for (49, 74, 74)
# (49, 74, 74): 0.3923996605517534
# (48, 75, 74): 0.4447828853053209
#
# Approximating hitting prob for (49, 75, 75)
# (49, 75, 75): 0.39259460713216804
# (48, 76, 75): 0.44529052969324373
#
# Approximating hitting prob for (50, 38, 75)
# (50, 38, 75): 0.3324164286956367
# (49, 39, 75): 0.33544545933583675
#
# Approximating hitting prob for (50, 75, 76)
# (50, 75, 76): 0.44288263658141447
# (49, 76, 76): 0.39291830820319174
#
# Approximating hitting prob for (50, 75, 92)
# (50, 75, 92): 0.45759115367539627
# (49, 76, 92): 0.4559241357547344
#
# Approximating hitting prob for (50, 75, 100)
# (50, 75, 100): 0.47393301817697314
# (49, 76, 100): 0.47406423077580156
#
# Approximating hitting prob for (50, 76, 77)
# (50, 76, 77): 0.44429124133069164
# (49, 77, 77): 0.3933855470183209
#
# Approximating hitting prob for (50, 76, 93)
# (50, 76, 93): 0.458009141874427
# (49, 77, 93): 0.4579173210371105
#
# Approximating hitting prob for (50, 39, 77)
# (50, 39, 77): 0.33414116331707877
# (49, 40, 77): 0.33715811993320854
#
# Approximating hitting prob for (50, 58, 77)
# (50, 58, 77): 0.42835770180665267
# (49, 59, 77): 0.42986397797576986
#
# Approximating hitting prob for (50, 77, 78)
# (50, 77, 78): 0.444746643401871
# (49, 78, 78): 0.39383362203493455
#
# Approximating hitting prob for (50, 77, 87)
# (50, 77, 87): 0.4520116455465753
# (49, 78, 87): 0.4519698140993778
#
# Approximating hitting prob for (50, 77, 88)
# (50, 77, 88): 0.4524307789106777
# (49, 78, 88): 0.45188031102953324
#
# Approximating hitting prob for (50, 78, 79)
# (50, 78, 79): 0.4451611733216594
# (49, 79, 79): 0.3944307342273889
#
# Approximating hitting prob for (50, 78, 95)
# (50, 78, 95): 0.4604683696485726
# (49, 79, 95): 0.459142999098128
#
# Approximating hitting prob for (50, 16, 79)
# (50, 16, 79): 0.2935557664012204
# (49, 17, 79): 0.31316723634045335
#
# Approximating hitting prob for (49, 80, 80)
# (49, 80, 80): 0.3949977458574792
# (48, 81, 80): 0.4521917084320946
#
# Approximating hitting prob for (49, 80, 96)
# (49, 80, 96): 0.4596473789820747
# (48, 81, 96): 0.47473788178980536
#
# Approximating hitting prob for (50, 27, 80)
# (50, 27, 80): 0.33816504577161116
# (49, 28, 80): 0.34020689062183446
#
# Approximating hitting prob for (50, 80, 81)
# (50, 80, 81): 0.44625874621578565
# (49, 81, 81): 0.39531030029593045
#
# Approximating hitting prob for (50, 80, 97)
# (50, 80, 97): 0.461677438104895
# (49, 81, 97): 0.46017100650880866
#
# Approximating hitting prob for (49, 82, 82)
# (49, 82, 82): 0.4005487801610677
# (48, 83, 82): 0.4533301025157932
#
# Approximating hitting prob for (49, 83, 83)
# (49, 83, 83): 0.40081907294573343
# (48, 84, 83): 0.45370565487691406
#
# Approximating hitting prob for (50, 28, 83)
# (50, 28, 83): 0.3401516623549128
# (49, 29, 83): 0.3442170395391367
#
# Approximating hitting prob for (49, 84, 84)
# (49, 84, 84): 0.4012852391379158
# (48, 85, 84): 0.4554446303417714
#
# Approximating hitting prob for (49, 17, 85)
# (49, 17, 85): 0.3145258260139033
# (48, 18, 85): 0.3180427303588617
#
# Approximating hitting prob for (49, 18, 85)
# (49, 18, 85): 0.3163439380094322
# (48, 19, 85): 0.31936645767582766
#
# Approximating hitting prob for (49, 85, 85)
# (49, 85, 85): 0.40164984897629474
# (48, 86, 85): 0.4558165289446807
#
# Approximating hitting prob for (50, 43, 85)
# (50, 43, 85): 0.34122732049033777
# (49, 44, 85): 0.34510543269454336
#
# Approximating hitting prob for (50, 85, 86)
# (50, 85, 86): 0.4531375615357895
# (49, 86, 86): 0.40339111530116695
#
# Approximating hitting prob for (50, 19, 86)
# (50, 19, 86): 0.3177753842205402
# (49, 20, 86): 0.3216871283454476
#
# Approximating hitting prob for (49, 87, 87)
# (49, 87, 87): 0.4036315434418018
# (48, 88, 87): 0.45674983055326757
#
# Approximating hitting prob for (50, 44, 87)
# (50, 44, 87): 0.34213857544493265
# (49, 45, 87): 0.3460551325219869
#
# Approximating hitting prob for (50, 87, 88)
# (50, 87, 88): 0.4545588055825535
# (49, 88, 88): 0.4040357027630798
#
# Approximating hitting prob for (50, 87, 93)
# (50, 87, 93): 0.4583040352762469
# (49, 88, 93): 0.4574738261723505
#
# Approximating hitting prob for (49, 89, 89)
# (49, 89, 89): 0.4045240306783355
# (48, 90, 89): 0.4586868142577372
#
# Approximating hitting prob for (49, 15, 90)
# (49, 15, 90): 0.29810517246396084
# (48, 16, 90): 0.3118699300841063
#
# Approximating hitting prob for (50, 30, 89)
# (50, 30, 89): 0.3476951114235747
# (49, 31, 89): 0.35096033348251887
#
# Approximating hitting prob for (49, 90, 90)
# (49, 90, 90): 0.4059549782822868
# (48, 91, 90): 0.45936867434207657
#
# Approximating hitting prob for (49, 90, 94)
# (49, 90, 94): 0.45819430230172403
# (48, 91, 94): 0.4607732397315132
#
# Approximating hitting prob for (49, 13, 91)
# (49, 13, 91): 0.29792540831161324
# (48, 14, 91): 0.3012987798756385
#
# Approximating hitting prob for (49, 91, 91)
# (49, 91, 91): 0.40642576361376737
# (48, 92, 91): 0.4597589666728641
#
# Approximating hitting prob for (50, 46, 91)
# (50, 46, 91): 0.3442851129561058
# (49, 47, 91): 0.35531663180274736
#
# Approximating hitting prob for (50, 91, 92)
# (50, 91, 92): 0.4573488852613132
# (49, 92, 92): 0.4071508979115228
#
# Approximating hitting prob for (50, 91, 95)
# (50, 91, 95): 0.45933437862779386
# (49, 92, 95): 0.4586652747520179
#
# Approximating hitting prob for (50, 22, 92)
# (50, 22, 92): 0.3292072695498574
# (49, 23, 92): 0.3308780845978183
#
# Approximating hitting prob for (50, 47, 92)
# (50, 47, 92): 0.34678490254822214
# (49, 48, 92): 0.35906261228844133
#
# Approximating hitting prob for (50, 92, 93)
# (50, 92, 93): 0.4582590220926159
# (49, 93, 93): 0.40741076891393546
#
# Approximating hitting prob for (49, 94, 94)
# (49, 94, 94): 0.40797029221816655
# (48, 95, 94): 0.4592529942262961
#
# Approximating hitting prob for (49, 94, 96)
# (49, 94, 96): 0.45901612322905244
# (48, 95, 96): 0.4724299307542817
#
# Approximating hitting prob for (49, 19, 95)
# (49, 19, 95): 0.3224756050754372
# (48, 20, 95): 0.32718079457986166
#
# Approximating hitting prob for (49, 23, 95)
# (49, 23, 95): 0.33046627890071156
# (48, 24, 95): 0.34450469454578814
#
# Approximating hitting prob for (50, 92, 94)
# (50, 92, 94): 0.4587461501436921
# (49, 93, 94): 0.4598191812067823
#
# Approximating hitting prob for (50, 94, 95)
# (50, 94, 95): 0.4594299056528787
# (49, 95, 95): 0.4083820860099791
#
# Approximating hitting prob for (50, 32, 95)
# (50, 32, 95): 0.35361558015502226
# (49, 33, 95): 0.3574793267031029
#
# Approximating hitting prob for (49, 96, 96)
# (49, 96, 96): 0.4086986414267435
# (48, 97, 96): 0.48510444740901965
#
# Approximating hitting prob for (50, 95, 97)
# (50, 95, 97): 0.4603463937143944
# (49, 96, 97): 0.459255167794314
#
# Approximating hitting prob for (50, 24, 96)
# (50, 24, 96): 0.33210670700318273
# (49, 25, 96): 0.3471826903812602
#
# Approximating hitting prob for (50, 96, 97)
# (50, 96, 97): 0.46032213752032547
# (49, 97, 97): 0.40898297572217435
#
# Approximating hitting prob for (50, 97, 98)
# (50, 97, 98): 0.4607063884456603
# (49, 98, 98): 0.4285714285714286
#
# Approximating hitting prob for (49, 99, 99)
# (49, 99, 99): 0.43372968454780736
# (48, 100, 99): 0.48648059293159807
#
# Approximating hitting prob for (50, 20, 99)
# (50, 20, 99): 0.326107353002608
# (49, 21, 99): 0.3288330297787917
#
# Approximating hitting prob for (50, 99, 100)
# (50, 99, 100): 0.4724252019792243
# (49, 100, 100): 0.4338862682294002
#
# Approximating hitting prob for (51, 1, 18)
# (51, 1, 18): 0.06125116514804421
# (50, 2, 18): 0.0610759260409948
#
# Approximating hitting prob for (51, 1, 54)
# (51, 1, 54): 0.24966346160584385
# (50, 2, 54): 0.2490847021625984
#
# Approximating hitting prob for (51, 1, 55)
# (51, 1, 55): 0.24986773195050685
# (50, 2, 55): 0.24945716914783111
#
# Approximating hitting prob for (51, 2, 57)
# (51, 2, 57): 0.2513626949697507
# (50, 3, 57): 0.2511902676081124
#
# Approximating hitting prob for (51, 2, 58)
# (51, 2, 58): 0.2518321635638978
# (50, 3, 58): 0.25155296300521685
#
# Approximating hitting prob for (51, 4, 5)
# (51, 4, 5): 0.01156809899351037
# (50, 5, 5): 0.010276778439090492
#
# Approximating hitting prob for (51, 5, 6)
# (51, 5, 6): 0.015784325896851793
# (50, 6, 6): 0.013159794320837538
#
# Approximating hitting prob for (51, 5, 18)
# (51, 5, 18): 0.0666603352468231
# (50, 6, 18): 0.06580277762586492
#
# Approximating hitting prob for (51, 6, 7)
# (51, 6, 7): 0.021270793120765824
# (50, 7, 7): 0.01967923752538044
#
# Approximating hitting prob for (51, 6, 14)
# (51, 6, 14): 0.04172253836087986
# (50, 7, 14): 0.040327908088516766
#
# Approximating hitting prob for (51, 6, 21)
# (51, 6, 21): 0.07688075463586114
# (50, 7, 21): 0.07677329844543193
#
# Approximating hitting prob for (51, 6, 28)
# (51, 6, 28): 0.09115785946241935
# (50, 7, 28): 0.09059379457974276
#
# Approximating hitting prob for (51, 7, 8)
# (51, 7, 8): 0.027667709282333947
# (50, 8, 8): 0.02503917443614127
#
# Approximating hitting prob for (51, 7, 24)
# (51, 7, 24): 0.08579124228537804
# (50, 8, 24): 0.08492819106187045
#
# Approximating hitting prob for (51, 8, 9)
# (51, 8, 9): 0.035580008322006765
# (50, 9, 9): 0.032167043048807915
#
# Approximating hitting prob for (51, 8, 18)
# (51, 8, 18): 0.07489161711169724
# (50, 9, 18): 0.07366955783430462
#
# Approximating hitting prob for (51, 5, 9)
# (51, 5, 9): 0.025486424358611162
# (50, 6, 9): 0.02833994306230811
#
# Approximating hitting prob for (51, 9, 10)
# (51, 9, 10): 0.045726216901374205
# (50, 10, 10): 0.03516819571864877
#
# Approximating hitting prob for (51, 10, 11)
# (51, 10, 11): 0.04959650051699701
# (50, 11, 11): 0.03851650354553234
#
# Approximating hitting prob for (51, 10, 22)
# (51, 10, 22): 0.09814108258363624
# (50, 11, 22): 0.09660266310231497
#
# Approximating hitting prob for (51, 11, 12)
# (51, 11, 12): 0.05366493756239965
# (50, 12, 12): 0.04156656110898064
#
# Approximating hitting prob for (51, 11, 24)
# (51, 11, 24): 0.10688545420694312
# (50, 12, 24): 0.10142525229218892
#
# Approximating hitting prob for (51, 11, 36)
# (51, 11, 36): 0.1309518036972501
# (50, 12, 36): 0.12735948790386942
#
# Approximating hitting prob for (51, 11, 60)
# (51, 11, 60): 0.25983818499475597
# (50, 12, 60): 0.25982717958095863
#
# Approximating hitting prob for (51, 11, 85)
# (51, 11, 85): 0.2888006606501535
# (50, 12, 85): 0.28852159857814597
#
# Approximating hitting prob for (51, 12, 13)
# (51, 12, 13): 0.06222648275541531
# (50, 13, 13): 0.05920273398136714
#
# Approximating hitting prob for (51, 12, 26)
# (51, 12, 26): 0.11140311943434524
# (50, 13, 26): 0.10832631367430083
#
# Approximating hitting prob for (50, 14, 14)
# (50, 14, 14): 0.06199106522539987
# (49, 15, 14): 0.08067382503596865
#
# Approximating hitting prob for (50, 14, 28)
# (50, 14, 28): 0.11525218523508844
# (49, 15, 28): 0.1274607095179757
#
# Approximating hitting prob for (50, 14, 42)
# (50, 14, 42): 0.17759823435894542
# (49, 15, 42): 0.19061103759198558
#
# Approximating hitting prob for (50, 14, 56)
# (50, 14, 56): 0.26043493709561366
# (49, 15, 56): 0.2663488139958801
#
# Approximating hitting prob for (50, 14, 92)
# (50, 14, 92): 0.29775189720566747
# (49, 15, 92): 0.30003387995301456
#
# Approximating hitting prob for (50, 15, 15)
# (50, 15, 15): 0.06617193195590483
# (49, 16, 15): 0.0868004080709789
#
# Approximating hitting prob for (50, 15, 30)
# (50, 15, 30): 0.12193427972182241
# (49, 16, 30): 0.13359343800251286
#
# Approximating hitting prob for (50, 15, 45)
# (50, 15, 45): 0.18775164159564564
# (49, 16, 45): 0.19926636078672508
#
# Approximating hitting prob for (50, 15, 60)
# (50, 15, 60): 0.2642565052336682
# (49, 16, 60): 0.27141057585822664
#
# Approximating hitting prob for (50, 15, 94)
# (50, 15, 94): 0.2992755733202195
# (49, 16, 94): 0.3015823339935792
#
# Approximating hitting prob for (50, 16, 16)
# (50, 16, 16): 0.07031145424576853
# (49, 17, 16): 0.10365326985111878
#
# Approximating hitting prob for (50, 16, 32)
# (50, 16, 32): 0.12539072262928783
# (49, 17, 32): 0.17039235725180682
#
# Approximating hitting prob for (50, 16, 48)
# (50, 16, 48): 0.1963376910296218
# (49, 17, 48): 0.21802854829080512
#
# Approximating hitting prob for (50, 16, 64)
# (50, 16, 64): 0.26658127720179364
# (49, 17, 64): 0.29248675109117334
#
# Approximating hitting prob for (51, 6, 17)
# (51, 6, 17): 0.0668772280501367
# (50, 7, 17): 0.07092297532355467
#
# Approximating hitting prob for (50, 18, 18)
# (50, 18, 18): 0.09862639092077576
# (49, 19, 18): 0.11932240294661639
#
# Approximating hitting prob for (50, 18, 36)
# (50, 18, 36): 0.1789029167297285
# (49, 19, 36): 0.1909839347172604
#
# Approximating hitting prob for (50, 18, 54)
# ...
# (52, 12, 12): 0.04064475990725291
# (51, 13, 12): 0.06222648275541531
#
# Approximating hitting prob for (52, 12, 24)
# (52, 12, 24): 0.0994815688026388
# (51, 13, 24): 0.1101175611298646
#
# Approximating hitting prob for (52, 12, 36)
# (52, 12, 36): 0.12564394994900138
# (51, 13, 36): 0.13525603022232166
#
# Approximating hitting prob for (52, 13, 13)
# (52, 13, 13): 0.053763440860215055
# (51, 14, 13): 0.07393096083531298
#
# Approximating hitting prob for (52, 13, 26)
# (52, 13, 26): 0.10550458715595556
# (51, 14, 26): 0.11719997723071879
#
# Approximating hitting prob for (52, 13, 30)
# (52, 13, 30): 0.12162216735052955
# (51, 14, 30): 0.12586033290463358
#
# Approximating hitting prob for (53, 7, 13)
# (53, 7, 13): 0.03998572853514118
# (52, 8, 13): 0.04605502808186252
#
# Approximating hitting prob for (53, 13, 14)
# (53, 13, 14): 0.07057590212420142
# (52, 14, 14): 0.060198947339934465
#
# Approximating hitting prob for (53, 13, 28)
# (53, 13, 28): 0.11613860751318748
# (52, 14, 28): 0.10975656429702026
#
# Approximating hitting prob for (53, 14, 15)
# (53, 14, 15): 0.07545574496896974
# (52, 15, 15): 0.06407892937903659
#
# Approximating hitting prob for (53, 14, 30)
# (53, 14, 30): 0.12281536076143107
# (52, 15, 30): 0.11741107419247221
#
# Approximating hitting prob for (53, 14, 60)
# (53, 14, 60): 0.26268665657536067
# (52, 15, 60): 0.2623432465454416
#
# Approximating hitting prob for (53, 14, 96)
# (53, 14, 96): 0.2985393272096446
# (52, 15, 96): 0.29818426670344106
#
# Approximating hitting prob for (53, 15, 16)
# (53, 15, 16): 0.07969134129797036
# (52, 16, 16): 0.06814124448035155
#
# Approximating hitting prob for (53, 15, 32)
# (53, 15, 32): 0.12921239213331767
# (52, 16, 32): 0.12344727873675156
#
# Approximating hitting prob for (53, 15, 48)
# (53, 15, 48): 0.19357316250826337
# (52, 16, 48): 0.19149809165068368
#
# Approximating hitting prob for (53, 15, 64)
# (53, 15, 64): 0.26683699016903006
# (52, 16, 64): 0.2652443966904996
#
# Approximating hitting prob for (53, 16, 17)
# (53, 16, 17): 0.08581664033668501
# (52, 17, 17): 0.07120241937930298
#
# Approximating hitting prob for (53, 16, 34)
# (53, 16, 34): 0.1356451934608829
# (52, 17, 34): 0.12620475924080937
#
# Approximating hitting prob for (53, 16, 51)
# (53, 16, 51): 0.20258469409600924
# (52, 17, 51): 0.19838100383003301
#
# Approximating hitting prob for (53, 16, 68)
# (53, 16, 68): 0.2700347758387591
# (52, 17, 68): 0.2672250480010861
#
# Approximating hitting prob for (53, 17, 18)
# (53, 17, 18): 0.10072662734207438
# (52, 18, 18): 0.09751034245633093
#
# Approximating hitting prob for (53, 18, 19)
# (53, 18, 19): 0.11462340760538743
# (52, 19, 19): 0.09897505076567405
#
# Approximating hitting prob for (53, 18, 38)
# (53, 18, 38): 0.18661055116685055
# (52, 19, 38): 0.17973681996016544
#
# Approximating hitting prob for (53, 18, 57)
# (53, 18, 57): 0.2793990661301845
# (52, 19, 57): 0.2744850386397128
#
# Approximating hitting prob for (53, 18, 95)
# (53, 18, 95): 0.3177798203500748
# (52, 19, 95): 0.31719502364612806
#
# Approximating hitting prob for (52, 20, 20)
# (52, 20, 20): 0.10218550169259301
# (51, 21, 20): 0.12300230319222843
#
# Approximating hitting prob for (52, 20, 40)
# (52, 20, 40): 0.18468409874500813
# (51, 21, 40): 0.19723763923807758
#
# Approximating hitting prob for (52, 20, 60)
# (52, 20, 60): 0.2800963792466194
# (51, 21, 60): 0.29117793886251847
#
# Approximating hitting prob for (52, 7, 21)
# (52, 7, 21): 0.07526129375133268
# (51, 8, 21): 0.08284356583102047
#
# Approximating hitting prob for (52, 21, 21)
# (52, 21, 21): 0.10461708915867157
# (51, 22, 21): 0.12508263342319098
#
# Approximating hitting prob for (52, 21, 42)
# (52, 21, 42): 0.1920720227594548
# (51, 22, 42): 0.20344568908804272
#
# Approximating hitting prob for (52, 21, 63)
# (52, 21, 63): 0.28447264606958134
# (51, 22, 63): 0.2942321159591916
#
# Approximating hitting prob for (52, 11, 22)
# (52, 11, 22): 0.0953490483509019
# (51, 12, 22): 0.10466927860543777
#
# Approximating hitting prob for (52, 22, 22)
# (52, 22, 22): 0.10639840568313409
# (51, 23, 22): 0.12762705425982226
#
# Approximating hitting prob for (52, 22, 44)
# (52, 22, 44): 0.19442754164170453
# (51, 23, 44): 0.21267718134210767
#
# Approximating hitting prob for (52, 22, 66)
# (52, 22, 66): 0.2875045553385555
# (51, 23, 66): 0.29712715806066947
#
# Approximating hitting prob for (52, 23, 23)
# (52, 23, 23): 0.10798891675291396
# (51, 24, 23): 0.13041895172635964
#
# Approximating hitting prob for (52, 23, 46)
# (52, 23, 46): 0.20373506905042008
# (51, 24, 46): 0.21804443327659928
#
# Approximating hitting prob for (52, 23, 69)
# (52, 23, 69): 0.2904193474020498
# (51, 24, 69): 0.30047434451485244
#
# Approximating hitting prob for (53, 12, 23)
# (53, 12, 23): 0.10467941596677444
# (52, 13, 23): 0.10654139956315778
#
# Approximating hitting prob for (53, 23, 24)
# (53, 23, 24): 0.12777310055608226
# (52, 24, 24): 0.10986393977777931
#
# Approximating hitting prob for (53, 23, 48)
# (53, 23, 48): 0.21539802150209184
# (52, 24, 48): 0.2085338908917369
#
# Approximating hitting prob for (53, 23, 72)
# (53, 23, 72): 0.29862311245982137
# (52, 24, 72): 0.2933365357868947
#
# Approximating hitting prob for (53, 24, 25)
# (53, 24, 25): 0.13051331617530879
# (52, 25, 25): 0.11070290668884446
#
# Approximating hitting prob for (53, 24, 50)
# (53, 24, 50): 0.22044897205789704
# (52, 25, 50): 0.21259648373620252
# Approximating hitting prob for (53, 24, 75)
# (53, 24, 75): 0.30040301756657084
# (52, 25, 75): 0.294940489127197
#
# Approximating hitting prob for (52, 27, 27)
# (52, 27, 27): 0.1637852307792119
# (51, 28, 27): 0.20636832981098582
#
# Approximating hitting prob for (53, 14, 27)
# (53, 14, 27): 0.11593458062319717
# (52, 15, 27): 0.12042981996664003
#
# Approximating hitting prob for (53, 27, 28)
# (53, 27, 28): 0.2021969513693348
# (52, 28, 28): 0.16472155149116854
#
# Approximating hitting prob for (53, 27, 56)
# (53, 27, 56): 0.301796085686671
# (52, 28, 56): 0.29338555255702997
#
# Approximating hitting prob for (53, 27, 63)
# (53, 27, 63): 0.31020839907722497
# (52, 28, 63): 0.30997233471523655
#
# Approximating hitting prob for (53, 27, 84)
# (53, 27, 84): 0.3368963209355849
# (52, 28, 84): 0.33109955717986334
#
# Approximating hitting prob for (53, 28, 29)
# (53, 28, 29): 0.20624026076782442
# (52, 29, 29): 0.16608633511349474
#
# Approximating hitting prob for (53, 28, 58)
# (53, 28, 58): 0.30384373013648863
# (52, 29, 58): 0.29563754414633153
#
# Approximating hitting prob for (53, 28, 65)
# (53, 28, 65): 0.3114899438554268
# (52, 29, 65): 0.3112466695966974
#
# Approximating hitting prob for (53, 28, 87)
# (53, 28, 87): 0.3387232009420081
# (52, 29, 87): 0.3343459631678876
#
# Approximating hitting prob for (53, 15, 29)
# (53, 15, 29): 0.12328115029596314
# (52, 16, 29): 0.12657114803590316
#
# Approximating hitting prob for (53, 29, 30)
# (53, 29, 30): 0.2077177164797723
# (52, 30, 30): 0.16768631855041602
#
# Approximating hitting prob for (53, 29, 60)
# (53, 29, 60): 0.30634154166359323
# (52, 30, 60): 0.29702546088442033
#
# Approximating hitting prob for (53, 29, 90)
# (53, 29, 90): 0.34194248373215724
# (52, 30, 90): 0.3361977760240174
#
# Approximating hitting prob for (53, 30, 31)
# (53, 30, 31): 0.20939855805676091
# (52, 31, 31): 0.1690922556549933
#
# Approximating hitting prob for (53, 30, 48)
# (53, 30, 48): 0.23704559384068832
# (52, 31, 48): 0.23687611531604638
#
# Approximating hitting prob for (53, 30, 62)
# (53, 30, 62): 0.3082688189231481
# (52, 31, 62): 0.2984724939250944
#
# Approximating hitting prob for (53, 30, 93)
# (53, 30, 93): 0.3437787120097921
# (52, 31, 93): 0.33833413061808154
#
# Approximating hitting prob for (52, 32, 32)
# (52, 32, 32): 0.17469161627505084
# (51, 33, 32): 0.21925607716386475
#
# Approximating hitting prob for (52, 32, 64)
# (52, 32, 64): 0.3058356740611687
# (51, 33, 64): 0.3194309365221441
#
# Approximating hitting prob for (52, 32, 96)
# (52, 32, 96): 0.3430788877981244
# (51, 33, 96): 0.35326475965229837
#
# Approximating hitting prob for (52, 11, 33)
# (52, 11, 33): 0.11932267445491486
# (51, 12, 33): 0.12856994412845754
#
# Approximating hitting prob for (52, 33, 33)
# (52, 33, 33): 0.1770193616735152
# (51, 34, 33): 0.22143527842880018
#
# Approximating hitting prob for (52, 33, 50)
# (52, 33, 50): 0.24144025536269717
# (51, 34, 50): 0.2491609121364394
#
# Approximating hitting prob for (52, 33, 66)
# (52, 33, 66): 0.3070985962634678
# (51, 34, 66): 0.3231510596480173
#
# Approximating hitting prob for (52, 33, 99)
# (52, 33, 99): 0.34593485068640994
# (51, 34, 99): 0.35697927861290296
#
# Approximating hitting prob for (53, 17, 33)
# (53, 17, 33): 0.13392377001878278
# (52, 18, 33): 0.14678617773280064
#
# Approximating hitting prob for (53, 33, 34)
# (53, 33, 34): 0.21884194751536454
# (52, 34, 34): 0.17839319225066383
#
# Approximating hitting prob for (53, 33, 51)
# (53, 33, 51): 0.24412291926333377
# (52, 34, 51): 0.2395573971866749
#
# Approximating hitting prob for (53, 33, 68)
# (53, 33, 68): 0.3185030297886692
# (52, 34, 68): 0.3097104193631988
#
# Approximating hitting prob for (53, 34, 35)
# (53, 34, 35): 0.22080892131963648
# (52, 35, 35): 0.18491450413701505
#
# Approximating hitting prob for (53, 34, 70)
# (53, 34, 70): 0.3204740079908656
# (52, 35, 70): 0.3136547393425373
#
# Approximating hitting prob for (52, 36, 36)
# (52, 36, 36): 0.18630666555273137
# (51, 37, 36): 0.2320667792441019
#
# Approximating hitting prob for (52, 36, 72)
# (52, 36, 72): 0.31473448644434265
# (51, 37, 72): 0.32848113919204164
#
# Approximating hitting prob for (52, 37, 37)
# (52, 37, 37): 0.18884665309355086
# (51, 38, 37): 0.23412187113876334
#
# Approximating hitting prob for (52, 37, 54)
# (52, 37, 54): 0.322763316175056
# (51, 38, 54): 0.32485111782297693
#
# Approximating hitting prob for (52, 37, 74)
# (52, 37, 74): 0.31585778896852784
# (51, 38, 74): 0.330644515773763
#
# Approximating hitting prob for (53, 19, 37)
# (53, 19, 37): 0.1866958234577347
# (52, 20, 37): 0.18686604353896005
#
# Approximating hitting prob for (53, 37, 38)
# (53, 37, 38): 0.23133372010388806
# (52, 38, 38): 0.19066179747628487
#
# Approximating hitting prob for (53, 37, 55)
# (53, 37, 55): 0.32500041251954653
# (52, 38, 55): 0.3239731083463609
#
# Approximating hitting prob for (53, 37, 76)
# (53, 37, 76): 0.3281716769180151
# (52, 38, 76): 0.3189470757097093
#
# Approximating hitting prob for (53, 38, 39)
# (53, 38, 39): 0.2331663599541034
# (52, 39, 39): 0.19596772116592112
#
# Approximating hitting prob for (53, 38, 56)
# (53, 38, 56): 0.32613832581345753
# (52, 39, 56): 0.3255731593999786
#
# Approximating hitting prob for (53, 38, 78)
# (53, 38, 78): 0.3304330838712887
# (52, 39, 78): 0.3204587476532555
#
# Approximating hitting prob for (52, 40, 40)
# (52, 40, 40): 0.2014200365019141
# (51, 41, 40): 0.24671334032671552
#
# Approximating hitting prob for (52, 40, 57)
# (52, 40, 57): 0.326520801173595
# (51, 41, 57): 0.3291524074487971
#
# Approximating hitting prob for (52, 40, 80)
# (52, 40, 80): 0.32193637499940436
# (51, 41, 80): 0.33598647345915805
#
# Approximating hitting prob for (52, 40, 83)
# (52, 40, 83): 0.33516270667662346
# (51, 41, 83): 0.3367400310912532
#
# Approximating hitting prob for (52, 41, 41)
# (52, 41, 41): 0.20308138923728725
# (51, 42, 41): 0.24841967895192865
#
# Approximating hitting prob for (52, 41, 82)
# (52, 41, 82): 0.323399769182946
# (51, 42, 82): 0.3377854765921149
#
# Approximating hitting prob for (52, 14, 42)
# (52, 14, 42): 0.17469198465566982
# (51, 15, 42): 0.1838917856816412
#
# Approximating hitting prob for (53, 21, 41)
# (53, 21, 41): 0.1949393129562064
# (52, 22, 41): 0.20006831965091343
#
# Approximating hitting prob for (53, 41, 42)
# (53, 41, 42): 0.2453312241601243
# (52, 42, 42): 0.20492569144475006
#
# Approximating hitting prob for (53, 41, 84)
# (53, 41, 84): 0.33485572045280526
# (52, 42, 84): 0.3251291287230161
#
# Approximating hitting prob for (53, 42, 43)
# (53, 42, 43): 0.24722903245070282
# (52, 43, 43): 0.2058474206640514
#
# Approximating hitting prob for (53, 42, 60)
# (53, 42, 60): 0.3316021118600507
# (52, 43, 60): 0.3309935246902248
#
# Approximating hitting prob for (53, 42, 86)
# (53, 42, 86): 0.33685836832665195
# (52, 43, 86): 0.3261875916607358
#
# Approximating hitting prob for (53, 42, 89)
# (53, 42, 89): 0.3417857808460931
# (52, 43, 89): 0.3415984252866875
#
# Approximating hitting prob for (53, 11, 43)
# (53, 11, 43): 0.1723162536690275
# (52, 12, 43): 0.17427256337505057
#
# Approximating hitting prob for (52, 44, 44)
# (52, 44, 44): 0.20982444429959204
# (51, 45, 44): 0.2574089939248849
#
# Approximating hitting prob for (52, 44, 88)
# (52, 44, 88): 0.3290903912529402
# (51, 45, 88): 0.34327684475421333
#
# Approximating hitting prob for (53, 43, 90)
# (53, 43, 90): 0.3422956853632157
# (52, 44, 90): 0.3419989566820811
#
# Approximating hitting prob for (53, 15, 44)
# (53, 15, 44): 0.18405515794668437
# (52, 16, 44): 0.18820972907809552
#
# Approximating hitting prob for (53, 44, 45)
# (53, 44, 45): 0.2521124389036942
# (52, 45, 45): 0.21182007607814232
#
# Approximating hitting prob for (53, 44, 90)
# (53, 44, 90): 0.3406572154467313
# (52, 45, 90): 0.3298353953706172
#
# Approximating hitting prob for (53, 23, 45)
# (53, 23, 45): 0.207721115430215
# (52, 24, 45): 0.2140826798275789
#
# Approximating hitting prob for (53, 45, 46)
# (53, 45, 46): 0.25522531698046924
# (52, 46, 46): 0.2145077303024424
#
# Approximating hitting prob for (53, 45, 63)
# (53, 45, 63): 0.3368539358409737
# (52, 46, 63): 0.3365048625459051
#
# Approximating hitting prob for (53, 45, 92)
# (53, 45, 92): 0.34206257047280636
# (52, 46, 92): 0.33078729429113857
#
# Approximating hitting prob for (53, 45, 93)
# (53, 45, 93): 0.34411348301230466
# (52, 46, 93): 0.3428956772797667
#
# Approximating hitting prob for (52, 47, 47)
# (52, 47, 47): 0.21576720179666234
# (51, 48, 47): 0.2627261591724111
#
# Approximating hitting prob for (52, 47, 64)
# (52, 47, 64): 0.3383412494441093
# (51, 48, 64): 0.34002086818318006
#
# Approximating hitting prob for (52, 47, 94)
# (52, 47, 94): 0.33141408476812356
# (51, 48, 94): 0.3468524260762323
#
# Approximating hitting prob for (52, 47, 95)
# (52, 47, 95): 0.3437776513101057
# (51, 48, 95): 0.3454802230257737
#
# Approximating hitting prob for (53, 16, 47)
# (53, 16, 47): 0.19239842121699632
# (52, 17, 47): 0.19810354084026013
#
# Approximating hitting prob for (52, 48, 48)
# (52, 48, 48): 0.21742294138775983
# (51, 49, 48): 0.2642506453684948
#
# Approximating hitting prob for (52, 48, 96)
# (52, 48, 96): 0.3320500926233258
# (51, 49, 96): 0.34910372802853273
#
# Approximating hitting prob for (52, 48, 97)
# (52, 48, 97): 0.34461951660417306
# (51, 49, 97): 0.34675364892128097
#
# Approximating hitting prob for (52, 49, 49)
# (52, 49, 49): 0.21917873882826663
# (51, 50, 49): 0.2654991972975215
#
# Approximating hitting prob for (52, 49, 66)
# (52, 49, 66): 0.34072613355979864
# (51, 50, 66): 0.34301361241345196
#
# Approximating hitting prob for (52, 49, 98)
# (52, 49, 98): 0.3325559533233745
# (51, 50, 98): 0.35682845714908873
#
# Approximating hitting prob for (52, 49, 99)
# (52, 49, 99): 0.34578290751041135
# (51, 50, 99): 0.34953499143412303
#
# Approximating hitting prob for (53, 25, 49)
# (53, 25, 49): 0.21986533564899755
# (52, 26, 49): 0.23410951887770462
#
# Approximating hitting prob for (53, 49, 50)
# (53, 49, 50): 0.26288760602957434
# (52, 50, 50): 0.22037190251093722
#
# Approximating hitting prob for (53, 49, 67)
# (53, 49, 67): 0.3423542826497106
# (52, 50, 67): 0.3419882151092208
#
# Approximating hitting prob for (53, 49, 100)
# (53, 49, 100): 0.34726196573292406
# (52, 50, 100): 0.33293449013725857
#
# Approximating hitting prob for (53, 34, 50)
# (53, 34, 50): 0.24066097522419874
# (52, 35, 50): 0.24944345851538877
#
# Approximating hitting prob for (53, 50, 51)
# (53, 50, 51): 0.2643491640738442
# (52, 51, 51): 0.22148988354485366
#
# Approximating hitting prob for (53, 50, 68)
# (53, 50, 68): 0.3434473733720271
# (52, 51, 68): 0.34260210471040065
#
# Approximating hitting prob for (53, 18, 53)
# (53, 18, 53): 0.2745444168219429
# (52, 19, 53): 0.27931875850788185
#
# Approximating hitting prob for (53, 27, 53)
# (53, 27, 53): 0.29561302796098676
# (52, 28, 53): 0.3007989936828242
#
# Approximating hitting prob for (53, 53, 54)
# (53, 53, 54): 0.38923754870338606
# (52, 54, 54): 0.3564903273835449
#
# Approximating hitting prob for (53, 11, 54)
# (53, 11, 54): 0.253315158634566
# (52, 12, 54): 0.2559961961986157
#
# Approximating hitting prob for (53, 54, 55)
# (53, 54, 55): 0.40082466154266266
# (52, 55, 55): 0.35714019050751333
#
# Approximating hitting prob for (53, 54, 72)
# (53, 54, 72): 0.41812260619895597
# (52, 55, 72): 0.4171750448502583
#
# Approximating hitting prob for (53, 14, 55)
# (53, 14, 55): 0.2591215065419206
# (52, 15, 55): 0.26193000359201574
