# %%
# %run 'game1_global.ipynb'
# %run 'game1_loser_analysis.ipynb'

# %% [markdown]
# # When is player 1 better off giving away $1?

# %%
betterGiving1 = findBetterGiving1(1,1000)
betterGiving1

# %%
exportStateProbs(DATA_DIR + 'game1_better_giving_1_memo_1-1000.csv', betterGiving1)

# %%
# retrieve probabilities from file
betterGiving1, given1 = readApproxBetterGiving1Probs(DATA_DIR + 'game1_better_giving_1_memo_1-100.csv')

# %%
betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
                                       filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv')
# Out:
# Approximating hitting prob for (11, 19, 48)
# (11, 19, 48): 0.5334260883826906
# (10, 19, 48): 0.5333426632228018
#
# Approximating hitting prob for (12, 21, 53)
# (12, 21, 53): 0.5340626283748265
# (11, 21, 53): 0.5334548685835285
#
# Approximating hitting prob for (12, 32, 42)
# (12, 32, 42): 0.5301153617677242
# (11, 32, 42): 0.5299467192997049
#
# Approximating hitting prob for (13, 22, 56)
# (13, 22, 56): 0.5328628830327213
# (12, 22, 56): 0.532734806781722
#
# Approximating hitting prob for (13, 23, 58)
# (13, 23, 58): 0.5343093271797525
# (12, 23, 58): 0.5335330764863161
#
# Approximating hitting prob for (13, 35, 46)
# (13, 35, 46): 0.5303291922468697
# (12, 35, 46): 0.5299937351500015
#
# Approximating hitting prob for (14, 24, 61)
# (14, 24, 61): 0.5334281050874531
# (13, 24, 61): 0.532844623278078
#
# Approximating hitting prob for (14, 25, 63)
# (14, 25, 63): 0.534598505539718
# (13, 25, 63): 0.5335740856592848
#
# Approximating hitting prob for (14, 38, 50)
# (14, 38, 50): 0.5306453312687435
# (13, 38, 50): 0.5300535494230575
#
# Approximating hitting prob for (15, 26, 66)
# (15, 26, 66): 0.5335384252806683
# (14, 26, 66): 0.532976559038264
#
# Approximating hitting prob for (15, 27, 68)
# (15, 27, 68): 0.5347937376379311
# (14, 27, 68): 0.5336038259570041
#
# Approximating hitting prob for (15, 40, 52)
# (15, 40, 52): 0.5298390830172897
# (14, 40, 52): 0.5294060634902246
#
# Approximating hitting prob for (15, 41, 54)
# (15, 41, 54): 0.530814252978444
# (14, 41, 54): 0.5300859465232839
#
# Approximating hitting prob for (16, 27, 69)
# (16, 27, 69): 0.5327214805171471
# (15, 27, 69): 0.5323471322790065
#
# Approximating hitting prob for (16, 28, 71)
# (16, 28, 71): 0.533984832978568
# (15, 28, 71): 0.5330636314503749
#
# Approximating hitting prob for (16, 29, 73)
# (16, 29, 73): 0.5349109988994238
# (15, 29, 73): 0.5336260136575318
#
# Approximating hitting prob for (16, 42, 54)
# (16, 42, 54): 0.528455476635441
# (15, 42, 54): 0.5285157285081951
#
# Approximating hitting prob for (16, 43, 56)
# (16, 43, 56): 0.5300165256608894
# (15, 43, 56): 0.5295344851774494
#
# Approximating hitting prob for (16, 44, 58)
# (16, 44, 58): 0.5309755142180325
# (15, 44, 58): 0.5301059314171186
#
# Approximating hitting prob for (17, 29, 74)
# (17, 29, 74): 0.5332717628242919
# (16, 29, 74): 0.5324865172144486
#
# Approximating hitting prob for (17, 30, 76)
# (17, 30, 76): 0.5341834675713876
# (16, 30, 76): 0.5331293350131605
#
# Approximating hitting prob for (17, 31, 78)
# (17, 31, 78): 0.535032026741298
# (16, 31, 78): 0.5336384909534596
#
# Approximating hitting prob for (17, 44, 56)
# (17, 44, 56): 0.5279972266134371
# (16, 44, 56): 0.5279422800090446
#
# Approximating hitting prob for (17, 45, 58)
# (17, 45, 58): 0.529004914693246
# (16, 45, 58): 0.528895160602941
#
# Approximating hitting prob for (17, 46, 60)
# (17, 46, 60): 0.5301804342251579
# (16, 46, 60): 0.5296194711867167
#
# Approximating hitting prob for (17, 47, 62)
# (17, 47, 62): 0.5311378673662993
# (16, 47, 62): 0.5301263625686753
#
# Approximating hitting prob for (18, 27, 71)
# (18, 27, 71): 0.525620501017532
# (17, 27, 71): 0.5254981980685945
#
# Approximating hitting prob for (18, 28, 73)
# (18, 28, 73): 0.5271004988262395
# (17, 28, 73): 0.5270411065910542
#
# Approximating hitting prob for (18, 31, 79)
# (18, 31, 79): 0.5335270635741508
# (17, 31, 79): 0.5326072076759126
#
# Approximating hitting prob for (18, 32, 81)
# (18, 32, 81): 0.5344121912790228
# (17, 32, 81): 0.5332080138741222
#
# Approximating hitting prob for (18, 33, 83)
# (18, 33, 83): 0.5351589143653502
# (17, 33, 83): 0.5336649245359243
#
# Approximating hitting prob for (18, 45, 56)
# (18, 45, 56): 0.5255722330999105
# (17, 45, 56): 0.5254786841463105
#
# Approximating hitting prob for (18, 47, 60)
# (18, 47, 60): 0.5284828625145415
# (17, 47, 60): 0.5281888889502253
#
# Approximating hitting prob for (18, 48, 62)
# (18, 48, 62): 0.5294526933438758
# (17, 48, 62): 0.5290045013080626
#
# Approximating hitting prob for (18, 49, 64)
# (18, 49, 64): 0.5304295920255223
# (17, 49, 64): 0.5297020995866109
#
# Approximating hitting prob for (18, 50, 66)
# (18, 50, 66): 0.5312826982045813
# (17, 50, 66): 0.5301457096165415
#
# Approximating hitting prob for (19, 20, 58)
# (19, 20, 58): 0.5076781471384154
# (18, 20, 58): 0.507459734940809
#
# Approximating hitting prob for (19, 32, 82)
# (19, 32, 82): 0.5327246501234508
# (18, 32, 82): 0.5320769507714677
#
# Approximating hitting prob for (19, 33, 84)
# (19, 33, 84): 0.5335489429772609
# (18, 33, 84): 0.532734806781722
#
# Approximating hitting prob for (19, 34, 86)
# (19, 34, 86): 0.5345634156030413
# (18, 34, 86): 0.5332648124986303
#
# Approximating hitting prob for (19, 35, 88)
# (19, 35, 88): 0.5345634156030413
# (18, 35, 88): 0.5332648124986303
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/659592125.py:18, in stricterFilter(candidates, timeLim, t, printOnGo, filename, continueFrom)
#      17 try:
# ---> 18     pLarge = LoserAnalysis(sLarge).getHittingProb()  # exact probs
#      19     pSmall = LoserAnalysis(sSmall).getHittingProb()
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:68, in LoserAnalysis.getHittingProb(self, asFloat, approx, t)
#      66     return Q(x, y, z, t)
# ---> 68 sol = self.solveEqns()
#      69 if sol:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:46, in LoserAnalysis.solveEqns(self, asFloat)
#      45 self.getEquations()
# ---> 46 sol = solve(self.equations, self.symbols)
#      47 return {s:float(p) for s, p in sol.items() if sol} if asFloat else sol
#
# File /usr/local/lib/python3.9/site-packages/sympy/solvers/solvers.py:1147, in solve(f, *symbols, **flags)
#    1146 else:
# -> 1147     linear, solution = _solve_system(f, symbols, **flags)
#    1148 assert type(solution) is list
#
# File /usr/local/lib/python3.9/site-packages/sympy/solvers/solvers.py:1799, in _solve_system(exprs, symbols, **flags)
#    1797     continue
# -> 1799 poly = g.as_poly(*symbols, extension=True)
#    1801 if poly is not None:
#
# File /usr/local/lib/python3.9/site-packages/sympy/core/expr.py:1102, in Expr.as_poly(self, *gens, **args)
#    1101 try:
# -> 1102     poly = Poly(self, *gens, **args)
#    1104     if not poly.is_Poly:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:182, in Poly.__new__(cls, rep, *gens, **args)
#     181 else:
# --> 182     return cls._from_expr(rep, opt)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:312, in Poly._from_expr(cls, rep, opt)
#     311 rep, opt = _dict_from_expr(rep, opt)
# --> 312 return cls._from_dict(rep, opt)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:261, in Poly._from_dict(cls, rep, opt)
#     259         rep[monom] = domain.convert(coeff)
# --> 261 return cls.new(DMP.from_dict(rep, level, domain), *gens)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polyclasses.py:279, in DMP.from_dict(cls, rep, lev, dom)
#     278 """Construct and instance of ``cls`` from a ``dict`` representation. """
# --> 279 return cls(dmp_from_dict(rep, lev, dom), dom, lev)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
#     [... skipping similar frames: dmp_from_dict at line 1012 (2958 times)]
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:998, in dmp_from_dict(f, u, K)
#     996 coeffs = {}
# --> 998 for monom, coeff in f.items():
#     999     head, tail = monom[0], monom[1:]
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# TimeoutException                          Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
#       2                                        filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv')
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/659592125.py:23, in stricterFilter(candidates, timeLim, t, printOnGo, filename, continueFrom)
#      21 except (TimeoutException, RecursionError):
#      22     print(f'Approximating hitting prob for {sLarge}')
# ---> 23     pLarge = LoserAnalysis(sLarge).getHittingProb(approx=True, t=t)
#      24     pSmall = LoserAnalysis(sSmall).getHittingProb(approx=True, t=t)
#      26 finally:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:66, in LoserAnalysis.getHittingProb(self, asFloat, approx, t)
#      64 if approx:
#      65     x, y, z = self.initState
# ---> 66     return Q(x, y, z, t)
#      68 sol = self.solveEqns()
#      69 if sol:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:31, in Q(x, y, z, t)
#      29 if x==0: return 1
#      30 if z*y==0: return 0
# ---> 31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
#      33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:31, in Q(x, y, z, t)
#      29 if x==0: return 1
#      30 if z*y==0: return 0
# ---> 31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
#      33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
#     [... skipping similar frames: memoize.<locals>.memodict.__call__ at line 8 (11 times), <genexpr> at line 33 (10 times), Q at line 33 (10 times), memoize.<locals>.memodict.__missing__ at line 11 (10 times)]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2027475117.py:12, in sigalarmHandler(signum, frame)
#       8 """
#       9 Handler function to be called when SIGALRM is received.
#      10 """
#      11 # We get signal!
# ---> 12 raise TimeoutException()
#
# TimeoutException:

# %%
betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
                                       filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv',
                                       continueFrom=(69,64,100))
# Out:
# Approximating hitting prob for (70, 12, 93)
# (70, 12, 93): 0.27064890356707977
# (69, 12, 93): 0.2704508979612977
#
# Approximating hitting prob for (70, 13, 95)
# (70, 13, 95): 0.273002814385276
# (69, 13, 95): 0.2728333555110289
#
# Approximating hitting prob for (70, 15, 99)
# (70, 15, 99): 0.2777183843625525
# (69, 15, 99): 0.27732957441332723
#
# Approximating hitting prob for (70, 30, 84)
# (70, 30, 84): 0.2928672871530125
# (69, 30, 84): 0.29290071879804375
#
# Approximating hitting prob for (70, 50, 94)
# (70, 50, 94): 0.32695735265836573
# (69, 50, 94): 0.3267132634013896
#
# Approximating hitting prob for (70, 58, 98)
# (70, 58, 98): 0.3430616778838396
# (69, 58, 98): 0.3428394039934912
#
# Approximating hitting prob for (70, 60, 99)
# (70, 60, 99): 0.34560612414415176
# (69, 60, 99): 0.34492499438010804
#
# Approximating hitting prob for (70, 84, 90)
# (70, 84, 90): 0.4148018936715927
# (69, 84, 90): 0.41468720846314083
#
# Approximating hitting prob for (71, 12, 94)
# (71, 12, 94): 0.27043453644878807
# (70, 12, 94): 0.2702550831661171
#
# Approximating hitting prob for (71, 15, 100)
# (71, 15, 100): 0.2774240055525448
# (70, 15, 100): 0.27714908068396565
#
# Approximating hitting prob for (71, 36, 88)
# (71, 36, 88): 0.3107284046458855
# (70, 36, 88): 0.3107029569244443
#
# Approximating hitting prob for (71, 44, 92)
# (71, 44, 92): 0.31946810865446534
# (70, 44, 92): 0.31933447137280896
#
# Approximating hitting prob for (71, 52, 96)
# (71, 52, 96): 0.3287350571698488
# (70, 52, 96): 0.32848900976647166
#
# Approximating hitting prob for (71, 60, 100)
# (71, 60, 100): 0.3432269284144038
# (70, 60, 100): 0.3428263666917539
#
# Approximating hitting prob for (72, 14, 99)
# (72, 14, 99): 0.27369224353294386
# (71, 14, 99): 0.27347335165357634
#
# Approximating hitting prob for (72, 40, 91)
# (72, 40, 91): 0.3129742549703007
# (71, 40, 91): 0.31282979281170153
#
# Approximating hitting prob for (72, 46, 94)
# (72, 46, 94): 0.32065055730266634
# (71, 46, 94): 0.32060860453920875
#
# Approximating hitting prob for (72, 50, 96)
# (72, 50, 96): 0.32548552599084296
# (71, 50, 96): 0.32522123422559995
#
# Approximating hitting prob for (72, 54, 98)
# (72, 54, 98): 0.33015250293768666
# (71, 54, 98): 0.3299310590778092
#
# Approximating hitting prob for (73, 11, 94)
# (73, 11, 94): 0.26568088778907833
# (72, 11, 94): 0.26555372470314254
#
# Approximating hitting prob for (73, 13, 98)
# (73, 13, 98): 0.2712824779940791
# (72, 13, 98): 0.27092732614422377
#
# Approximating hitting prob for (73, 14, 100)
# (73, 14, 100): 0.2735392177539206
# (72, 14, 100): 0.2733296833190661
#
# Approximating hitting prob for (73, 26, 85)
# (73, 26, 85): 0.2838182327188731
# (72, 26, 85): 0.2838382526274032
#
# Approximating hitting prob for (73, 40, 92)
# (73, 40, 92): 0.31265646156970867
# (72, 40, 92): 0.31256600858492634
#
# Approximating hitting prob for (73, 44, 94)
# (73, 44, 94): 0.31905281367702304
# (72, 44, 94): 0.31898130581150774
#
# Approximating hitting prob for (74, 12, 97)
# (74, 12, 97): 0.26803823241416097
# (73, 12, 97): 0.2678146488650772
#
# Approximating hitting prob for (74, 13, 99)
# (74, 13, 99): 0.27106341315623816
# (73, 13, 99): 0.2708043750088058
#
# Approximating hitting prob for (74, 30, 88)
# (74, 30, 88): 0.29121346643802504
# (73, 30, 88): 0.2911904861374854
#
# Approximating hitting prob for (74, 40, 93)
# (74, 40, 93): 0.3124715276947375
# (73, 40, 93): 0.3123265733297223
#
# Approximating hitting prob for (74, 46, 96)
# (74, 46, 96): 0.3194592906289733
# (73, 46, 96): 0.31936096416339166
#
# Approximating hitting prob for (74, 52, 99)
# (74, 52, 99): 0.32609715069378836
# (73, 52, 99): 0.32593271890358366
#
# Approximating hitting prob for (74, 54, 100)
# (74, 54, 100): 0.3285392810102394
# (73, 54, 100): 0.32834877261967127
#
# Approximating hitting prob for (75, 13, 100)
# (75, 13, 100): 0.2708561821230972
# (74, 13, 100): 0.27060467983388525
#
# Approximating hitting prob for (75, 38, 93)
# (75, 38, 93): 0.3107255922584125
# (74, 38, 93): 0.3106856959891582
#
# Approximating hitting prob for (75, 40, 94)
# (75, 40, 94): 0.31219750777533284
# (74, 40, 94): 0.31212211416489793
#
# Approximating hitting prob for (75, 48, 98)
# (75, 48, 98): 0.3206660566987458
# (74, 48, 98): 0.3206193374288369
#
# Approximating hitting prob for (75, 52, 100)
# (75, 52, 100): 0.32543894655115896
# (74, 52, 100): 0.3251891291627604
#
# Approximating hitting prob for (76, 42, 96)
# (76, 42, 96): 0.31283229353690856
# (75, 42, 96): 0.31269685409230785
#
# Approximating hitting prob for (77, 42, 97)
# (77, 42, 97): 0.31263411481005815
# (76, 42, 97): 0.3124896740010894
#
# Approximating hitting prob for (78, 42, 98)
# (78, 42, 98): 0.312441399741017
# (77, 42, 98): 0.3119828040723916
#
# Approximating hitting prob for (79, 32, 94)
# (79, 32, 94): 0.2912337154122105
# (78, 32, 94): 0.2911642829888588
#
# Approximating hitting prob for (79, 40, 98)
# (79, 40, 98): 0.31073467566545016
# (78, 40, 98): 0.31068391480047436
#
# Approximating hitting prob for (79, 42, 99)
# (79, 42, 99): 0.3121670959474713
# (78, 42, 99): 0.3120607193357822
#
# Approximating hitting prob for (79, 44, 100)
# (79, 44, 100): 0.3130463381703828
# (78, 44, 100): 0.3128490513416133
#
# Approximating hitting prob for (82, 34, 98)
# (82, 34, 98): 0.2917812876569657
# (81, 34, 98): 0.29172992113254753
#
# Approximating hitting prob for (84, 30, 98)
# (84, 30, 98): 0.2839368557613289
# (83, 30, 98): 0.2838357734914572
#
# Approximating hitting prob for (84, 34, 100)
# (84, 34, 100): 0.29123192191006453
# (83, 34, 100): 0.2911447291167216
#
# Approximating hitting prob for (93, 47, 62)
# (93, 47, 62): 0.2078449082948937
# (92, 47, 62): 0.20783817692579917
#
# Approximating hitting prob for (93, 47, 98)
# (93, 47, 98): 0.3020413154785515
# (92, 47, 98): 0.3020379983481061
#
# Approximating hitting prob for (95, 48, 100)
# (95, 48, 100): 0.30201302025080573
# (94, 48, 100): 0.30196433138324996
#
# Approximating hitting prob for (99, 50, 66)
# (99, 50, 66): 0.2078419114332157
# (98, 50, 66): 0.2078180397808808
#
# Approximating hitting prob for (100, 51, 67)
# (100, 51, 67): 0.2080190772886974
# (99, 51, 67): 0.20801576587712575

# %%
class TimeoutException(Exception):
    """
    Custom exception for timeout.
    """
    pass

def sigalarmHandler(signum, frame):
    """
    Handler function to be called when SIGALRM is received.
    """
    # We get signal!
    raise TimeoutException()

# %% [markdown]
# ## When is player 1 better off giving away $1 to another player?

# %%
betterGiving1ToAnother = findBetterGiving1(1,100, t=10, giveToAnother=True)
betterGiving1ToAnother
# Out:
# {(1, 5, 5): 0.5004434876119833,
#  (2, 4, 5): 0.5015168645690443,
#  (1, 6, 6): 0.506093654740131,
#  (2, 5, 6): 0.5184847144955884,
#  (1, 7, 7): 0.5131205254322682,
#  (2, 6, 7): 0.5396071019936831,
#  (1, 8, 8): 0.5177187986883774,
#  (2, 7, 8): 0.553386673567715,
#  (1, 9, 9): 0.5198030383135193,
#  (2, 8, 9): 0.5596511014686955,
#  (1, 10, 10): 0.521353326527545,
#  (2, 9, 10): 0.5643071756348541,
#  (1, 11, 11): 0.5225738105217701,
#  (2, 10, 11): 0.5679767313216567,
#  (1, 12, 12): 0.5237380978085997,
#  (2, 11, 12): 0.5714793837797846,
#  (1, 12, 36): 0.6316713165390184,
#  (2, 11, 36): 0.6317622599451304,
#  (1, 13, 13): 0.5248276325593998,
#  (2, 12, 13): 0.5747622273980084,
#  (1, 13, 39): 0.6325682808186844,
#  (2, 12, 39): 0.6347403712118326,
#  (1, 14, 14): 0.5256858644409728,
#  (2, 13, 14): 0.57733900685236,
#  (1, 14, 42): 0.6333982655030145,
#  (2, 13, 42): 0.6366529115385103,
#  (1, 15, 15): 0.5268432387720368,
#  (2, 14, 15): 0.5808387485922709,
#  (1, 15, 45): 0.63421194355006,
#  (2, 14, 45): 0.6395029512036614,
#  (1, 16, 16): 0.5279858610539553,
#  (2, 15, 16): 0.5842379051719758,
#  (1, 16, 48): 0.635051999980948,
#  (2, 15, 48): 0.6419747628823096,
#  (1, 17, 17): 0.5283821156475977,
#  (2, 16, 17): 0.5854285708426477,
#  (1, 17, 51): 0.6353974162348219,
#  (2, 16, 51): 0.6431331129655032,
#  (1, 18, 18): 0.5286972339709394,
#  (2, 17, 18): 0.586367542078401,
#  (1, 18, 54): 0.635696343688081,
#  (2, 17, 54): 0.6438519942124338,
#  (1, 19, 19): 0.5290239620908059,
#  (2, 18, 19): 0.5873462049262054,
#  (1, 19, 57): 0.6359734242165406,
#  (2, 18, 57): 0.644798126476528,
#  (1, 20, 20): 0.5292680655049197,
#  (2, 19, 20): 0.5880847500592729,
#  (1, 20, 60): 0.6362249863460855,
#  (2, 19, 60): 0.6453717860378668,
#  (1, 21, 21): 0.5295149142555335,
#  (2, 20, 21): 0.588833317324383,
#  (1, 21, 63): 0.6364634998581686,
#  (2, 20, 63): 0.6461849514015902,
#  (1, 21, 64): 0.646956969794154,
#  (2, 20, 64): 0.6472510681012803,
#  (1, 22, 22): 0.5297588522879303,
#  (2, 21, 22): 0.5895697621096462,
#  (1, 22, 66): 0.6366529446148538,
#  (2, 21, 66): 0.6466174245912294,
#  (1, 22, 67): 0.6471532117394029,
#  (2, 21, 67): 0.647774501235203,
#  (1, 23, 23): 0.5299781484445122,
#  (2, 22, 23): 0.5902254013880421,
#  (1, 23, 69): 0.6368433485854967,
#  (2, 22, 69): 0.6472793649130383,
#  (1, 23, 70): 0.647343764553591,
#  (2, 22, 70): 0.6483569921802232,
#  (1, 24, 24): 0.5301334749530051,
#  (2, 23, 24): 0.5907054714357991,
#  (1, 24, 72): 0.6370145682769819,
#  (2, 23, 72): 0.6476786129157565,
#  (1, 24, 73): 0.6475028948415723,
#  (2, 23, 73): 0.6487869019532507,
#  (1, 25, 25): 0.5303300145853443,
#  (2, 24, 25): 0.5913062701368778,
#  (1, 25, 75): 0.6371719124424207,
#  (2, 24, 75): 0.6482151442816559,
#  (1, 25, 76): 0.6476655808364664,
#  (2, 24, 76): 0.6492909523499552,
#  (1, 26, 26): 0.5305056830450136,
#  (2, 25, 26): 0.5918398411700453,
#  (1, 26, 78): 0.6373261970460974,
#  (2, 25, 78): 0.6485752629701603,
#  (1, 26, 79): 0.6478181289321158,
#  (2, 25, 79): 0.6496998090304239,
#  (1, 27, 27): 0.5306651440964284,
#  (2, 26, 27): 0.5923164712780911,
#  (1, 27, 81): 0.6374779182331624,
#  (2, 26, 81): 0.6491023179636827,
#  (1, 27, 82): 0.6479675843896594,
#  (2, 26, 82): 0.6501630597575742,
#  (1, 28, 28): 0.5308433925108808,
#  (2, 27, 28): 0.5928632397722654,
#  (1, 28, 84): 0.6376227926171485,
#  (2, 27, 84): 0.6494288807018324,
#  (1, 28, 85): 0.6481137818273807,
#  (2, 27, 85): 0.6505545513577707,
#  (1, 29, 29): 0.531019424810327,
#  (2, 28, 29): 0.593397753481219,
#  (1, 29, 87): 0.6377697342725956,
#  (2, 28, 87): 0.6499273246583346,
#  (1, 29, 88): 0.6482600123414454,
#  (2, 28, 88): 0.651006837277092,
#  (1, 30, 30): 0.5311653907136445,
#  (2, 29, 30): 0.5938409764824553,
#  (1, 30, 90): 0.6379076957008163,
#  (2, 29, 90): 0.650248810177776,
#  (1, 30, 91): 0.6483932438525631,
#  (2, 29, 91): 0.6513514100842097,
#  (1, 31, 31): 0.5313585565589595,
#  (2, 30, 31): 0.5944358379798981,
#  (1, 31, 93): 0.6380471455644888,
#  (2, 30, 93): 0.6507426069080341,
#  (1, 31, 94): 0.6485374236333384,
#  (2, 30, 94): 0.6518048371373775,
#  (1, 32, 32): 0.5316609404901015,
#  (2, 31, 32): 0.5953108064912191,
#  (1, 32, 96): 0.6382585695513472,
#  (2, 31, 96): 0.651341801406459,
#  (1, 32, 97): 0.6487406281488678,
#  (2, 31, 97): 0.6524211817198429,
#  (1, 33, 33): 0.5317385375916611,
#  (2, 32, 33): 0.5955452681512389,
#  (1, 33, 99): 0.6383231014972734,
#  (2, 32, 99): 0.6515462628230367,
#  (1, 33, 100): 0.6488068966028214,
#  (2, 32, 100): 0.6526188624860286,
#  (1, 34, 34): 0.5318062779428949,
#  (2, 33, 34): 0.5957485718957984,
#  (1, 35, 35): 0.5318679983996342,
#  (2, 34, 35): 0.5959310706203745,
#  (1, 36, 36): 0.5319251873973311,
#  (2, 35, 36): 0.5961088063515048,
#  (1, 37, 37): 0.5319769849510576,
#  (2, 36, 37): 0.5962632397987264,
#  (1, 38, 38): 0.5320250779543261,
#  (2, 37, 38): 0.5964045750139714,
#  (1, 39, 39): 0.5320778016456672,
#  (2, 38, 39): 0.5965617868740368,
#  (1, 40, 40): 0.5321167325018205,
#  (2, 39, 40): 0.5966842851117292,
#  (1, 41, 41): 0.5321571517934258,
#  (2, 40, 41): 0.5968058406736355,
#  (2, 14, 41): 0.6338000769223442,
#  (1, 42, 42): 0.5322013748645192,
#  (2, 41, 42): 0.5969399487078528,
#  (1, 43, 43): 0.5322408018658233,
#  (2, 42, 43): 0.5970633565449881,
#  (1, 44, 44): 0.5322755651027112,
#  (2, 43, 44): 0.5971704908211825,
#  (2, 15, 44): 0.6355654440591713,
#  (1, 45, 45): 0.5323146613405815,
#  (2, 44, 45): 0.5972896979627089,
#  (1, 46, 46): 0.5323509791656083,
#  (2, 45, 46): 0.5973977583765179,
#  (1, 47, 47): 0.532385014722942,
#  (2, 46, 47): 0.597498806605531,
#  (2, 16, 47): 0.6375855486545072,
#  (1, 48, 48): 0.5324148826610103,
#  (2, 47, 48): 0.5975902130804501,
#  (1, 49, 49): 0.5324444859883317,
#  (2, 48, 49): 0.5976821983913784,
#  (1, 50, 50): 0.5324711785974361,
#  (2, 49, 50): 0.5977623423713782,
#  (2, 17, 50): 0.6383571866691223,
#  (1, 51, 51): 0.5325028988107334,
#  (2, 50, 51): 0.5978603145004572,
#  (1, 52, 52): 0.5325307160155125,
#  (2, 51, 52): 0.597951109063024,
#  (1, 53, 53): 0.5325579709224543,
#  (2, 52, 53): 0.5980328572456773,
#  (2, 18, 53): 0.6393221393725973,
#  (1, 54, 54): 0.5325877396314925,
#  (2, 53, 54): 0.5981236683464157,
#  (1, 55, 55): 0.5326169460426934,
#  (2, 54, 55): 0.5982126271719249,
#  (1, 56, 56): 0.5326397687196227,
#  (2, 55, 56): 0.5982834436230927,
#  (2, 19, 56): 0.639912667869058,
#  (1, 57, 57): 0.5326706620243357,
#  (2, 56, 57): 0.5983790342554488,
#  (1, 58, 58): 0.5326991076796389,
#  (2, 57, 58): 0.5984666865653948,
#  (1, 59, 59): 0.5327241464715744,
#  (2, 58, 59): 0.5985425140825841,
#  (2, 20, 59): 0.6407575699842504,
#  (1, 60, 60): 0.5327515998365764,
#  (2, 59, 60): 0.5986312082973463,
#  (1, 60, 100): 0.6594202186690291,
#  (2, 59, 100): 0.6594714208485749,
#  (1, 61, 61): 0.5327806408660604,
#  (2, 60, 61): 0.5987212090276719,
#  (1, 62, 62): 0.5328041250698572,
#  (2, 61, 62): 0.5987947377389965,
#  (2, 21, 62): 0.6412867749400921,
#  (1, 63, 63): 0.5328350514509137,
#  (2, 62, 63): 0.5988899810697471,
#  (1, 64, 64): 0.5329295505639383,
#  (2, 63, 64): 0.5991591232757963,
#  (1, 65, 65): 0.5329439718496504,
#  (2, 64, 65): 0.5992017586824079,
#  (2, 22, 65): 0.6419519898198954,
#  (1, 66, 66): 0.5329563424020729,
#  (2, 65, 66): 0.5992384734235551,
#  (1, 67, 67): 0.5329692090996461,
#  (2, 66, 67): 0.5992765939092958,
#  (1, 68, 68): 0.5329786027811648,
#  (2, 67, 68): 0.5993086945005419,
#  (2, 23, 68): 0.6423572742552796,
#  (1, 69, 69): 0.5329891210583583,
#  (2, 68, 69): 0.5993394885762248,
#  (1, 70, 70): 0.5330002016333891,
#  (2, 69, 70): 0.5993723499233687,
#  (1, 71, 71): 0.5330110506740166,
#  (2, 70, 71): 0.5994039212931209,
#  (2, 24, 71): 0.6429282380946333,
#  (1, 72, 72): 0.5330189889964267,
#  (2, 71, 72): 0.5994280670237854,
#  (1, 73, 73): 0.5330284819069756,
#  (2, 72, 73): 0.5994564796027452,
#  (1, 74, 74): 0.5330374786723738,
#  (2, 73, 74): 0.599483089520991,
#  (2, 25, 74): 0.6432813280601704,
#  (1, 75, 75): 0.5330459131399347,
#  (2, 74, 75): 0.5995072187134837,
#  (1, 76, 76): 0.5330541822257785,
#  (2, 75, 76): 0.5995340767043049,
#  (1, 77, 77): 0.5330628151513997,
#  (2, 76, 77): 0.5995594131833307,
#  (2, 26, 77): 0.6438085649735813,
#  (1, 78, 78): 0.5330708527028399,
#  (2, 77, 78): 0.5995827154672391,
#  (1, 79, 79): 0.5330799817736117,
#  (2, 78, 79): 0.5996089284693644,
#  (1, 80, 80): 0.5330863985842266,
#  (2, 79, 80): 0.5996283608210977,
#  (2, 27, 80): 0.6441455136835509,
#  (1, 81, 81): 0.5330929477002151,
#  (2, 80, 81): 0.5996482893179816,
#  (1, 82, 82): 0.5331003237247879,
#  (2, 81, 82): 0.5996707812314773,
#  (1, 83, 83): 0.5331074682149571,
#  (2, 82, 83): 0.599691569713289,
#  (2, 28, 83): 0.6446484064082373,
#  (1, 84, 84): 0.5331135542621382,
#  (2, 83, 84): 0.5997103736144981,
#  (1, 85, 85): 0.5331207318286508,
#  (2, 84, 85): 0.5997354950972921,
#  (1, 86, 86): 0.5331267847994886,
#  (2, 85, 86): 0.5997556055140646,
#  (2, 29, 86): 0.6449977587469728,
#  (1, 87, 87): 0.5331327716176396,
#  (2, 86, 87): 0.5997733675104574,
#  (1, 88, 88): 0.5331386592067605,
#  (2, 87, 88): 0.599791989491778,
#  (1, 89, 89): 0.5331450098646887,
#  (2, 88, 89): 0.5998109256983607,
#  (2, 30, 89): 0.6454688981820182,
#  (1, 90, 90): 0.5331506328430625,
#  (2, 89, 90): 0.5998279269388559,
#  (1, 91, 91): 0.5331572150353944,
#  (2, 90, 91): 0.5998475412104778,
#  (1, 92, 92): 0.5331628049374249,
#  (2, 91, 92): 0.5998653528213856,
#  (2, 31, 92): 0.6457769216297059,
#  (1, 93, 93): 0.5331686925265458,
#  (2, 92, 93): 0.5998821225274772,
#  (1, 94, 94): 0.5331750431844738,
#  (2, 93, 94): 0.5999014225738369,
#  (1, 95, 95): 0.5331811953843418,
#  (2, 94, 95): 0.5999193995664617,
#  (2, 32, 95): 0.646300487069002,
#  (1, 96, 96): 0.5331852306982338,
#  (2, 95, 96): 0.599931571660824,
#  (1, 97, 97): 0.5331905890658605,
#  (2, 96, 97): 0.599948109832512,
#  (1, 98, 98): 0.5331949220668428,
#  (2, 97, 98): 0.5999628122671425,
#  (2, 33, 98): 0.6464613042504953,
#  (1, 99, 99): 0.5331994535258853,
#  (2, 98, 99): 0.59997640664427,
#  (2, 60, 99): 0.6594345241875391,
#  (1, 100, 100): 0.533204183442988,
#  (2, 99, 100): 0.5999915225331928,
#  (2, 6, 6): 0.4693452418753916,
#  (3, 5, 6): 0.4740014979614388,
#  (2, 7, 7): 0.48208386784704227,
#  (3, 6, 7): 0.4955659177124083,
#  (2, 8, 8): 0.49122878218725124,
#  (3, 7, 8): 0.5014666050652847,
#  (2, 9, 9): 0.494262775936087,
#  (3, 8, 9): 0.5178661041836018,
#  (2, 10, 10): 0.5004434876119833,
#  (3, 9, 10): 0.5342839937488357,
#  (2, 11, 11): 0.5025522368075666,
#  (3, 10, 11): 0.5431842258389219,
#  (2, 12, 12): 0.506093654740131,
#  (3, 11, 12): 0.5502830045015581,
#  (2, 13, 13): 0.5085600915129808,
#  (3, 12, 13): 0.5546173616138715,
#  (2, 14, 14): 0.5131205254322682,
#  (3, 13, 14): 0.5568134654323105,
#  (2, 15, 15): 0.5156899950147334,
#  (3, 14, 15): 0.5601744353735879,
#  (2, 16, 16): 0.5177187986883774,
#  (3, 15, 16): 0.5635269543091331,
#  (2, 17, 17): 0.5183972606437027,
#  (3, 16, 17): 0.5645428776577504,
#  (2, 18, 18): 0.5198030383135193,
#  (3, 17, 18): 0.5672856342031618,
#  (2, 19, 19): 0.5202042212823249,
#  (3, 18, 19): 0.5700392728655439,
#  (2, 20, 20): 0.521353326527545,
#  (3, 19, 20): 0.5708707459853257,
#  (2, 20, 60): 0.6295677107148301,
#  (3, 19, 60): 0.6304392723627834,
#  (2, 21, 21): 0.5216864383816829,
#  (3, 20, 21): 0.5735340366157767,
#  (2, 21, 63): 0.6301227813711917,
#  (3, 20, 63): 0.6311136824660452,
#  (2, 22, 22): 0.5225738105217701,
#  (3, 21, 22): 0.5764060555111009,
#  (2, 22, 66): 0.630719892059984,
#  (3, 21, 66): 0.6335248486691138,
#  (2, 23, 23): 0.5230437922847974,
#  (3, 22, 23): 0.5785014418639604,
#  (2, 23, 69): 0.6311993336572169,
#  (3, 22, 69): 0.6351912844629037,
#  (2, 23, 71): 0.641735372847127,
#  (3, 22, 71): 0.6419442003410304,
#  (2, 24, 24): 0.5237380978085997,
#  (3, 23, 24): 0.5800568899875528,
#  (2, 24, 72): 0.6316713165390184,
#  (3, 23, 72): 0.6362437075564361,
#  (2, 24, 74): 0.642247130031838,
#  (3, 23, 74): 0.6426527783069992,
#  (2, 25, 25): 0.524088839353757,
#  (3, 24, 25): 0.5809113180896375,
#  (2, 25, 75): 0.6320944621998256,
#  (3, 24, 75): 0.637120230655896,
#  (2, 25, 77): 0.6426200988797439,
#  (3, 24, 77): 0.6434655302164304,
#  (2, 26, 26): 0.5248276325593998,
#  (3, 25, 26): 0.5813076057596235,
#  (2, 26, 78): 0.6325682808186844,
#  (3, 25, 78): 0.6376919552511473,
#  (2, 26, 80): 0.6431372309702534,
#  (3, 25, 80): 0.6440306064666632,
#  (2, 27, 27): 0.5251138752349743,
#  (3, 26, 27): 0.582175396704432,
#  (2, 27, 81): 0.6329491879890007,
#  (3, 26, 81): 0.6380589868954174,
#  (2, 27, 83): 0.6434930993486342,
#  (3, 26, 83): 0.6444297387021796,
#  (2, 28, 28): 0.5256858644409728,
#  (3, 27, 28): 0.5828712072018578,
#  (2, 28, 84): 0.6333982655030145,
#  (3, 27, 84): 0.6388404320458433,
#  (2, 28, 86): 0.6439339408531474,
#  (3, 27, 86): 0.6451290222156598,
#  (2, 29, 29): 0.5261190653101662,
#  (3, 28, 29): 0.5831610717370319,
#  (2, 29, 87): 0.6337884340494758,
#  (3, 28, 87): 0.6392850773298446,
#  (2, 29, 88): 0.6449055088252976,
#  (3, 28, 88): 0.644998916418991,
#  (2, 29, 89): 0.6443102007972193,
#  (3, 28, 89): 0.6455973005470034,
#  (2, 30, 30): 0.5268432387720368,
#  (3, 29, 30): 0.5837543951845078,
#  (2, 30, 90): 0.63421194355006,
#  (3, 29, 90): 0.6395496715386797,
#  (2, 30, 92): 0.6447714007910802,
#  (3, 29, 92): 0.645899006413106,
#  (2, 31, 31): 0.5275615907974732,
#  (3, 30, 31): 0.5843650506359125,
#  (2, 31, 93): 0.6345886665629393,
#  (3, 30, 93): 0.640241909791021,
#  (2, 31, 94): 0.6457147711805027,
#  (3, 30, 94): 0.645921002181451,
#  (2, 31, 95): 0.6453186488922336,
#  (3, 30, 95): 0.6465264150324307,
#  (2, 32, 32): 0.5279858610539553,
#  (3, 31, 32): 0.5845853886973108,
#  (2, 32, 96): 0.635051999980948,
#  (3, 31, 96): 0.6406006558112753,
#  (2, 32, 97): 0.6461740362082762,
#  (3, 31, 97): 0.646306424272638,
#  (2, 32, 98): 0.645574742480821,
#  (3, 31, 98): 0.6468801499866637,
#  (2, 33, 33): 0.5281335800034718,
#  (3, 32, 33): 0.5851356798220545,
#  (2, 33, 99): 0.6352244269589663,
#  (3, 32, 99): 0.6407475974667225,
#  (2, 33, 100): 0.6463518546302647,
#  (3, 32, 100): 0.6464238949061373,
#  (2, 34, 34): 0.5283821156475977,
#  (3, 33, 34): 0.5857237441309336,
#  (2, 35, 35): 0.5284957328870937,
#  (3, 34, 35): 0.5859061105501363,
#  (2, 36, 36): 0.5286972339709394,
#  (3, 35, 36): 0.5863498462346949,
#  (2, 37, 37): 0.5288185579984419,
#  (3, 36, 37): 0.5868146350118123,
#  (2, 38, 38): 0.5290239620908059,
#  (3, 37, 38): 0.5870175583784231,
#  (2, 39, 39): 0.5291136651340412,
#  (3, 38, 39): 0.5874601198527918,
#  (2, 40, 40): 0.5292680655049197,
#  (3, 39, 40): 0.5879006636702145,
#  (2, 41, 41): 0.5293537993869498,
#  (3, 40, 41): 0.5880250307213077,
#  (2, 42, 42): 0.5295149142555335,
#  (3, 41, 42): 0.5884515170927959,
#  (2, 43, 43): 0.5296025334891361,
#  (3, 42, 43): 0.5889065483486172,
#  (2, 44, 44): 0.5297588522879303,
#  (3, 43, 44): 0.58904100368444,
#  (2, 45, 45): 0.5298143874684583,
#  (3, 44, 45): 0.5894975068375417,
#  (2, 46, 46): 0.5299781484445122,
#  (3, 45, 46): 0.5899698039446054,
#  (3, 45, 47): 0.5976479643759843,
#  (2, 47, 47): 0.5300331874798896,
#  (3, 46, 47): 0.5905717768558739,
#  (3, 46, 48): 0.5985042612914698,
#  (2, 48, 48): 0.5301334749530051,
#  (3, 47, 48): 0.5909074355884519,
#  (3, 47, 49): 0.5986030107146184,
#  (2, 49, 49): 0.5302022075945402,
#  (3, 48, 49): 0.5910961361274111,
#  (3, 48, 50): 0.5987849967558723,
#  (2, 50, 50): 0.5303300145853443,
#  (3, 49, 50): 0.5911701775220579,
#  (3, 49, 51): 0.5989254058335026,
#  (2, 51, 51): 0.530385152849752,
#  (3, 50, 51): 0.5913320862228827,
#  (3, 50, 52): 0.5990053844317854,
#  (2, 52, 52): 0.5305056830450136,
#  (3, 51, 52): 0.5914818062911734,
#  (3, 51, 53): 0.5991632908950618,
#  (2, 53, 53): 0.5305588367288184,
#  (3, 52, 53): 0.5915376556969635,
#  (3, 52, 54): 0.5992909986568359,
#  (2, 18, 54): 0.6281354554321411,
#  (3, 18, 53): 0.6282727553334942,
#  (2, 54, 54): 0.5306651440964284,
#  (3, 53, 54): 0.5916624692786923,
#  (3, 53, 55): 0.5993634193106573,
#  (2, 55, 55): 0.5307288160574269,
#  (3, 54, 55): 0.5918032587342715,
#  (3, 54, 56): 0.599478690367322,
#  (2, 56, 56): 0.5308433925108808,
#  (3, 55, 56): 0.5918555193568054,
#  (3, 55, 57): 0.5995967232986587,
#  (2, 19, 57): 0.6287977430555555,
#  (3, 19, 56): 0.6300712318900404,
#  (2, 57, 57): 0.5308984976989449,
#  (3, 56, 57): 0.5919839713363054,
#  (3, 56, 58): 0.5996486531577588,
#  (2, 58, 58): 0.531019424810327,
#  (3, 57, 58): 0.5921011938972294,
#  (3, 57, 59): 0.5997754843964335,
#  (2, 59, 59): 0.5310688408673304,
#  (3, 58, 59): 0.5921501799617691,
#  (3, 58, 60): 0.5998798898742993,
#  (3, 20, 59): 0.6308086193510897,
#  (2, 60, 60): 0.5311653907136445,
#  (3, 59, 60): 0.5922371045921607,
#  (3, 59, 61): 0.5999254359991278,
#  (2, 61, 61): 0.5312331972175651,
#  (3, 60, 61): 0.5923383678174059,
#  (3, 60, 62): 0.6000335791037951,
#  (2, 62, 62): 0.5313585565589595,
#  (3, 61, 62): 0.5923812182202493,
#  (3, 61, 63): 0.6001316835382479,
#  (3, 21, 62): 0.6330898947537215,
#  (2, 63, 63): 0.5315653498577452,
#  (3, 62, 63): 0.5925049402826467,
#  (3, 62, 64): 0.6001830180231672,
#  (2, 64, 64): 0.5316609404901015,
#  (3, 63, 64): 0.5925977525021593,
#  (3, 63, 65): 0.6002796836366832,
#  (2, 65, 65): 0.531690378435706,
#  (3, 64, 65): 0.592631788059493,
#  (3, 64, 66): 0.6003744142841115,
#  (3, 22, 65): 0.6346719031810446,
#  (2, 66, 66): 0.5317385375916611,
#  (3, 65, 66): 0.5927241372101983,
#  (3, 65, 67): 0.6004132789875781,
#  (2, 67, 67): 0.5317613271922471,
#  (3, 66, 67): 0.5928214643505817,
#  (3, 66, 68): 0.6005093823032567,
#  (2, 68, 68): 0.5318062779428949,
#  (3, 67, 68): 0.5928686808307507,
#  (3, 67, 69): 0.600597067689546,
#  (3, 23, 68): 0.6353617433984912,
#  (2, 69, 69): 0.5318268845048181,
#  (3, 68, 69): 0.5929494532612746,
#  (3, 68, 70): 0.6006299621130332,
#  (2, 70, 70): 0.5318679983996342,
#  (3, 69, 70): 0.5930456061914681,
#  (3, 69, 71): 0.6007228404852326,
#  (2, 71, 71): 0.5318853634799066,
#  (3, 70, 71): 0.5930765987252112,
#  (3, 70, 72): 0.6007995941400363,
#  (3, 24, 71): 0.6368715792445682,
#  (2, 72, 72): 0.5319251873973311,
#  (3, 71, 72): 0.5931494493714966,
#  (3, 71, 73): 0.600835432358084,
#  (2, 73, 73): 0.5319396086830429,
#  (3, 72, 73): 0.5932231434645379,
#  (3, 72, 74): 0.6009037846216702,
#  (2, 74, 74): 0.5319769849510576,
#  (3, 73, 74): 0.5932469749699402,
#  (3, 73, 75): 0.6009758414357144,
#  (3, 25, 74): 0.637481490478247,
#  (2, 75, 75): 0.5319899508776609,
#  (3, 74, 75): 0.5933288389197955,
#  (3, 74, 76): 0.600999127181451,
#  (2, 76, 76): 0.5320250779543261,
#  (3, 75, 76): 0.5934025495510085,
#  (3, 75, 77): 0.6010797838447729,
#  (2, 77, 77): 0.5320406899883995,
#  (3, 76, 77): 0.5934319544202696,
#  (3, 76, 78): 0.6011526014147149,
#  (3, 26, 77): 0.6378954574537672,
#  (2, 78, 78): 0.5320778016456672,
#  (3, 77, 78): 0.5934982559505665,
#  (3, 77, 79): 0.6011803855431506,
#  (2, 79, 79): 0.5320866991820353,
#  (3, 78, 79): 0.5935844198250606,
#  (3, 78, 80): 0.601249680482523,
#  (2, 80, 80): 0.5321167325018205,
#  (3, 79, 80): 0.5935997672483869,
#  (3, 79, 81): 0.6013253922325102,
#  (3, 27, 80): 0.6386029439004047,
#  (2, 81, 81): 0.5321278792295382,
#  (3, 80, 81): 0.5936775793461786,
#  (3, 80, 82): 0.6013561366936782,
#  (2, 82, 82): 0.5321571517934258,
#  (3, 81, 82): 0.5937518688134007,
#  (3, 81, 83): 0.601426787763129,
#  (2, 83, 83): 0.5321697869565954,
#  (3, 82, 83): 0.5937740134252909,
#  (3, 82, 84): 0.6014979184395587,
#  (3, 28, 83): 0.6390618120120578,
#  (2, 84, 84): 0.5322013748645192,
#  (3, 83, 84): 0.5938440691205609,
#  (3, 83, 85): 0.6015204268912259,
#  (2, 85, 85): 0.5322126208212671,
#  (3, 84, 85): 0.5939187058893884,
#  (3, 84, 86): 0.6015962874847584,
#  (2, 86, 86): 0.5322408018658233,
#  (3, 85, 86): 0.5939462915597639,
#  (3, 85, 87): 0.6016669550923809,
#  (3, 29, 86): 0.6394178126958119,
#  (2, 87, 87): 0.532251948593541,
#  (3, 86, 87): 0.5940234421306881,
#  (3, 86, 88): 0.601684650936087,
#  (2, 88, 88): 0.5322755651027112,
#  (3, 87, 88): 0.5940922243867381,
#  (3, 87, 89): 0.6017641830037341,
#  (2, 89, 89): 0.5322872410519229,
#  (3, 88, 89): 0.5941109952116039,
#  (3, 88, 90): 0.6018371328790496,
#  (3, 30, 89): 0.6400308661821116,
#  (2, 90, 90): 0.5323146613405815,
#  (3, 89, 90): 0.5941841270068079,
#  (3, 89, 91): 0.6018690019358922,
#  (2, 91, 91): 0.5323265357478535,
#  (3, 90, 91): 0.5942605664363495,
#  (3, 90, 92): 0.6019353200043608,
#  (2, 92, 92): 0.5323509791656083,
#  (3, 91, 92): 0.5942813383799895,
#  (3, 91, 93): 0.6020062026082151,
#  (3, 31, 92): 0.6404354725524564,
#  (2, 93, 93): 0.5323607366869041,
#  (3, 92, 93): 0.5943591835541245,
#  (3, 92, 94): 0.6020233692304272,
#  (2, 94, 94): 0.532385014722942,
#  (3, 93, 94): 0.5944335226358617,
#  (3, 93, 95): 0.6021049851077072,
#  (2, 95, 95): 0.5323954668474488,
#  (3, 94, 95): 0.5946310545585023,
#  (3, 94, 96): 0.6023667182128402,
#  (3, 32, 95): 0.6407084350761655,
#  (2, 96, 96): 0.5324148826610103,
#  (3, 95, 96): 0.5947102558627156,
#  (3, 95, 97): 0.6023858198011397,
#  (2, 97, 97): 0.5324242763425291,
#  (3, 96, 97): 0.5947447048743416,
#  (3, 96, 98): 0.6024215422519856,
#  (2, 98, 98): 0.5324444859883317,
#  (3, 97, 98): 0.5947557192966858,
#  (3, 97, 99): 0.6024459691315688,
#  (3, 33, 98): 0.6412241118075667,
#  (2, 99, 99): 0.532454276585971,
#  (3, 98, 99): 0.5947932940227607,
#  (3, 98, 100): 0.6024601919592203,
#  (2, 100, 100): 0.5324711785974361,
#  (3, 99, 100): 0.594818828959847,
#  (3, 7, 7): 0.44019443200773933,
#  (4, 6, 7): 0.45015962312549745,
#  (3, 8, 8): 0.4467808250351403,
#  (4, 7, 8): 0.4742427237336788,
#  (3, 9, 9): 0.4693452418753916,
#  (4, 8, 9): 0.49163882961608163,
#  (3, 10, 10): 0.47808047262654746,
#  (4, 9, 10): 0.4967868813136124,
#  (3, 11, 11): 0.48470119889837254,
#  (4, 10, 11): 0.502631388497265,
#  (3, 12, 12): 0.49122878218725124,
#  (4, 11, 12): 0.5167916853217244,
#  (3, 13, 13): 0.4935336740990533,
#  (4, 12, 13): 0.5312539030085183,
#  (3, 14, 14): 0.4956136137995563,
#  (4, 13, 14): 0.5362733208066606,
#  (3, 15, 15): 0.5004434876119833,
#  (4, 14, 15): 0.5434280646422885,
#  (3, 16, 16): 0.5020230153135531,
#  (4, 15, 16): 0.5478861768933428,
#  (3, 17, 17): 0.5030273123274739,
#  (4, 16, 17): 0.5516700278846806,
#  (3, 17, 51): 0.615492767394452,
#  (4, 16, 51): 0.6161914720719234,
#  (3, 18, 18): 0.506093654740131,
#  (4, 17, 18): 0.5534884163999391,
#  (3, 18, 54): 0.6177887948462294,
#  (4, 17, 54): 0.6190445216843214,
#  (3, 19, 19): 0.5081359535618724,
#  (4, 18, 19): 0.5547300196394097,
#  (3, 19, 57): 0.6196168251155819,
#  (4, 18, 57): 0.6206401410269438,
#  (3, 20, 20): 0.5092737466976579,
#  (4, 19, 20): 0.5579425760279598,
#  (3, 20, 60): 0.6203943672574895,
#  (4, 19, 60): 0.6215706116424494,
#  (3, 21, 21): 0.5131205254322682,
#  (4, 20, 21): 0.560842097902801,
#  (3, 21, 63): 0.6225665568796677,
#  (4, 20, 63): 0.6242344480325662,
#  (3, 22, 22): 0.5144697094785687,
#  (4, 21, 22): 0.5619077515336839,
#  (3, 22, 66): 0.624324547991922,
#  (4, 21, 66): 0.6264198516539231,
#  (3, 23, 23): 0.5164820742095548,
#  (4, 22, 23): 0.5623249765290268,
#  (3, 23, 69): 0.6249592168686177,
#  (4, 22, 69): 0.6269802310633965,
#  (3, 24, 24): 0.5177187986883774,
#  (4, 23, 24): 0.5647878741331352,
#  (3, 24, 72): 0.6264351494627344,
#  (4, 23, 72): 0.6274335588875342,
#  (3, 25, 25): 0.518164866255144,
#  (4, 24, 25): 0.5672480925534301,
#  (3, 25, 75): 0.6270372712175482,
#  (4, 24, 75): 0.6295931629610577,
#  (3, 26, 26): 0.5187485975630408,
#  (4, 25, 26): 0.5679596473903029,
#  (3, 26, 78): 0.6274313096961844,
#  (4, 25, 78): 0.6313052441087063,
#  (3, 27, 27): 0.5198030383135193,
#  (4, 26, 27): 0.5688839492677692,
#  (3, 27, 81): 0.6281354554321411,
#  (4, 26, 81): 0.6318541625652001,
#  (3, 28, 28): 0.5200221029356974,
#  (4, 27, 28): 0.571275650042761,
#  (3, 28, 84): 0.6286252830011939,
#  (4, 27, 84): 0.6323139071999525,
#  (3, 29, 29): 0.5204572222328067,
#  (4, 28, 29): 0.5737307747061763,
#  (3, 29, 87): 0.6289591721494013,
#  (4, 28, 87): 0.6344316035464191,
#  (3, 30, 30): 0.521353326527545,
#  (4, 29, 30): 0.5746018071326356,
#  (3, 30, 90): 0.6295677107148301,
#  (4, 29, 90): 0.636175140296618,
#  (4, 29, 93): 0.6410474510575962,
#  (3, 31, 31): 0.5216136373499127,
#  (4, 30, 31): 0.5765721483693628,
#  (3, 31, 93): 0.6299875487412996,
#  (4, 30, 93): 0.6364735716047266,
#  (4, 30, 96): 0.6419747628823096,
#  (3, 32, 32): 0.5218702105454792,
#  (4, 31, 32): 0.57749606986888,
#  (3, 32, 96): 0.6301997334840557,
#  (4, 31, 96): 0.6374555090105252,
#  (3, 32, 98): 0.6418308477122813,
#  (4, 31, 98): 0.64189207202387,
#  (4, 31, 99): 0.6423986858371861,
#  (3, 33, 33): 0.5225738105217701,
#  (4, 32, 33): 0.5782692459334621,
#  (3, 33, 99): 0.630719892059984,
#  (4, 32, 99): 0.6381510714353757,
#  (3, 34, 34): 0.5229414210020491,
#  (4, 33, 34): 0.5785625834846907,
#  (3, 35, 35): 0.5230813339345289,
#  (4, 34, 35): 0.5789247529064845,
#  (4, 34, 36): 0.586367542078401,
#  (3, 36, 36): 0.5237380978085997,
#  (4, 35, 36): 0.5796576089084913,
#  (3, 37, 37): 0.5239908341483345,
#  (4, 36, 37): 0.5802491462334248,
#  (4, 36, 38): 0.5873462049262054,
#  (3, 38, 38): 0.5241945844235296,
#  (4, 37, 38): 0.5804661601223137,
#  (4, 37, 39): 0.58762088741977,
#  (3, 39, 39): 0.5248276325593998,
#  (4, 38, 39): 0.5806532895349625,
#  (4, 38, 40): 0.5880847500592729,
#  (3, 40, 40): 0.5250622099866212,
#  (4, 39, 40): 0.5812160504411591,
#  (4, 39, 41): 0.5883475912219089,
#  (3, 41, 41): 0.5251781094938103,
#  (4, 40, 41): 0.581744395412073,
#  (4, 40, 42): 0.588833317324383,
#  (3, 42, 42): 0.5256858644409728,
#  (4, 41, 42): 0.5820000755463682,
#  (4, 41, 43): 0.5890965057886247,
#  (3, 43, 43): 0.5260332321991058,
#  (4, 42, 43): 0.5820988084313451,
#  (4, 42, 44): 0.5895697621096462,
#  (3, 44, 44): 0.5262173020499924,
#  (4, 43, 44): 0.5826556321339057,
#  (4, 43, 45): 0.5897379057011973,
#  (3, 45, 45): 0.5268432387720368,
#  (4, 44, 45): 0.5831276480920508,
#  (4, 44, 46): 0.5902254013880421,
#  (3, 46, 46): 0.5271012011740249,
#  (4, 45, 46): 0.583270240208344,
#  (3, 47, 47): 0.5277467521676913,
#  (4, 46, 47): 0.5834219779335806,
#  (3, 48, 48): 0.5279858610539553,
#  (4, 47, 48): 0.583798849790005,
#  (3, 49, 49): 0.5280672950113465,
#  (4, 48, 49): 0.58421129525373,
#  (4, 48, 50): 0.5913062701368778,
#  (3, 50, 50): 0.5281774061584447,
#  (4, 49, 50): 0.5844009880829905,
#  (4, 49, 51): 0.5914750587171248,
#  (4, 17, 50): 0.6165013477948399,
#  (3, 51, 51): 0.5283821156475977,
#  (4, 50, 51): 0.5845099911725855,
#  (4, 50, 52): 0.5918398411700453,
#  (3, 52, 52): 0.5284536267019764,
#  (4, 51, 52): 0.5848932467632814,
#  (4, 51, 53): 0.5920035690697556,
#  (3, 53, 53): 0.5285409151721452,
#  (4, 52, 53): 0.5853034761120002,
#  (4, 52, 54): 0.5923164712780911,
#  (4, 18, 53): 0.6181123476371319,
#  (3, 54, 54): 0.5286972339709394,
#  (4, 53, 54): 0.5854581080172822,
#  (4, 53, 55): 0.5925202546296297,
#  (3, 55, 55): 0.5287723172704025,
#  (4, 54, 55): 0.5854904070665887,
#  (4, 54, 56): 0.5928632397722654,
#  (3, 56, 56): 0.528849186692408,
#  (4, 55, 56): 0.585891077352072,
#  (4, 55, 57): 0.5930314164401599,
#  (3, 57, 57): 0.5290239620908059,
#  (4, 56, 57): 0.5862959648713356,
#  (4, 56, 58): 0.593397753481219,
#  (3, 58, 58): 0.529078174217599,
#  (4, 57, 58): 0.5864241191637455,
#  (4, 57, 59): 0.5935495408209707,
#  (3, 59, 59): 0.5291300048476689,
#  (4, 58, 59): 0.5865677035703398,
#  (4, 58, 60): 0.5938409764824553,
#  (4, 20, 59): 0.6220633830060628,
#  (3, 60, 60): 0.5292680655049197,
#  (4, 59, 60): 0.5869693992224677,
#  (4, 59, 61): 0.5940510939537503,
#  (3, 61, 61): 0.5293283636788938,
#  (4, 60, 61): 0.5873862934543769,
#  (4, 60, 62): 0.5944358379798981,
#  (3, 62, 62): 0.5293856188292774,
#  (4, 61, 62): 0.5875231799014378,
#  (4, 61, 63): 0.5950046353187607,
#  (4, 21, 62): 0.6242603302712578,
#  (3, 63, 63): 0.5295149142555335,
#  (4, 62, 63): 0.5881961511837626,
#  (4, 62, 64): 0.5953108064912191,
#  (3, 64, 64): 0.5295760062617487,
#  (4, 63, 64): 0.5883510807761351,
#  (4, 63, 65): 0.5954003937672526,
#  (3, 65, 65): 0.5296215523865772,
#  (4, 64, 65): 0.5884918206171993,
#  (4, 64, 66): 0.5955452681512389,
#  (4, 22, 65): 0.6248344032868888,
#  (3, 66, 66): 0.5297588522879303,
#  (4, 65, 66): 0.5885713692230182,
#  (4, 65, 67): 0.5956124131282917,
#  (3, 67, 67): 0.5298012561601383,
#  (4, 66, 67): 0.5886375219097698,
#  (4, 66, 68): 0.5957485718957984,
#  (3, 68, 68): 0.529846471521533,
#  (4, 67, 68): 0.5887764094756051,
#  (4, 67, 69): 0.5958102427380226,
#  (4, 23, 68): 0.6256472213490067,
#  (3, 69, 69): 0.5299781484445122,
#  (4, 68, 69): 0.5889008426793849,
#  (4, 68, 70): 0.5959310706203745,
#  (3, 70, 70): 0.5300216107597081,
#  (4, 69, 70): 0.5889561794018526,
#  (4, 69, 71): 0.5959897480535233,
#  (3, 71, 71): 0.5300431103829023,
#  (4, 70, 71): 0.5889931587537468,
#  (4, 70, 72): 0.5961088063515048,
#  (4, 24, 71): 0.6278304253935291,
#  (3, 72, 72): 0.5301334749530051,
#  (4, 71, 72): 0.5891061971572339,
#  (4, 71, 73): 0.596151656754348,
#  (3, 73, 73): 0.5301830563917255,
#  (4, 72, 73): 0.5892122399140968,
#  (4, 72, 74): 0.5962632397987264,
#  (3, 74, 74): 0.5302213918736981,
#  (4, 73, 74): 0.5892634255554708,
#  (4, 73, 75): 0.5963052632929854,
#  (4, 25, 74): 0.6295195515588748,
#  (3, 75, 75): 0.5303300145853443,
#  (4, 74, 75): 0.5893170257699115,
#  (4, 74, 76): 0.5964045750139714,
#  (3, 76, 76): 0.5303685816017206,
#  (4, 75, 76): 0.5894298161008231,
#  (4, 75, 77): 0.5964538256892581,
#  (3, 77, 77): 0.530398449539789,
#  (4, 76, 77): 0.5895255886530678,
#  (4, 76, 78): 0.5965617868740368,
#  (4, 26, 77): 0.6298821178967892,
#  (3, 78, 78): 0.5305056830450136,
#  (4, 77, 78): 0.5895662560172484,
#  (4, 77, 79): 0.5965969635652171,
#  (3, 79, 79): 0.5305416701066065,
#  (4, 78, 79): 0.5895925020957171,
#  (4, 78, 80): 0.5966842851117292,
#  (3, 80, 80): 0.5305744818392352,
#  (4, 79, 80): 0.5896747464235211,
#  (4, 79, 81): 0.5967190152722739,
#  (4, 27, 80): 0.6305618532913343,
#  (3, 81, 81): 0.5306651440964284,
#  (4, 80, 81): 0.5897592564808464,
#  (4, 80, 82): 0.5968058406736355,
#  (3, 82, 82): 0.5307149570695524,
#  (4, 81, 82): 0.5898063737319853,
#  (4, 81, 83): 0.5968468057249064,
#  (3, 83, 83): 0.5307373497540179,
#  (4, 82, 83): 0.5898409219726414,
#  (4, 82, 84): 0.5969399487078528,
#  (4, 28, 83): 0.632644984858973,
#  (3, 84, 84): 0.5308433925108808,
#  (4, 83, 84): 0.5899515788794052,
#  (4, 83, 85): 0.5969784495715423,
#  (3, 85, 85): 0.5308807357025521,
#  (4, 84, 85): 0.590039297342038,
#  (4, 84, 86): 0.5970633565449881,
#  (3, 86, 86): 0.5309161604663076,
#  (4, 85, 86): 0.5900632776909854,
#  (4, 85, 87): 0.5971014439543854,
#  (4, 29, 86): 0.6341472958369321,
#  (3, 87, 87): 0.531019424810327,
#  (4, 86, 87): 0.5900916241172586,
#  (4, 86, 88): 0.5971704908211825,
#  (3, 88, 88): 0.5310544195816186,
#  (4, 87, 88): 0.5901717184827432,
#  (4, 87, 89): 0.5972081978526308,
#  (3, 89, 89): 0.5310768122660842,
#  (4, 88, 89): 0.5902565427653305,
#  (4, 88, 90): 0.5972896979627089,
#  (4, 30, 89): 0.6345409208612762,
#  (3, 90, 90): 0.5311653907136445,
#  (4, 89, 90): 0.5902962343773815,
#  (4, 89, 91): 0.597325304646353,
#  (3, 91, 91): 0.5312151706104252,
#  (4, 90, 91): 0.5903176513097174,
#  (4, 90, 92): 0.5973977583765179,
#  (3, 92, 92): 0.5312498676946266,
#  (4, 91, 92): 0.5904037490315247,
#  (4, 91, 93): 0.5974274443946976,
#  (4, 31, 92): 0.6350845636410015,
#  (3, 93, 93): 0.5313585565589595,
#  (4, 92, 93): 0.5904832480228285,
#  (4, 92, 94): 0.597498806605531,
#  (3, 94, 94): 0.5313904421539738,
#  (4, 93, 94): 0.5905108667695473,
#  (4, 93, 95): 0.5975329083155515,
#  (3, 95, 95): 0.5316191650684178,
#  (4, 94, 95): 0.590518887782816,
#  (4, 94, 96): 0.5975902130804501,
#  (4, 32, 95): 0.6364357157297329,
#  (3, 96, 96): 0.5316609404901015,
#  (4, 95, 96): 0.5905898365393571,
#  (4, 95, 97): 0.5976202960147504,
#  (3, 97, 97): 0.5316739725693914,
#  (4, 96, 97): 0.5906563199895426,
#  (4, 96, 98): 0.5976821983913784,
#  (3, 98, 98): 0.5317002351860319,
#  (4, 97, 98): 0.5906784149869176,
#  (4, 97, 99): 0.5977121324821334,
#  (4, 33, 98): 0.6369774566197142,
#  (3, 99, 99): 0.5317385375916611,
#  (4, 98, 99): 0.5907043468401243,
#  (4, 98, 100): 0.5977623423713782,
#  (3, 100, 100): 0.53174793127318,
#  (4, 99, 100): 0.5907712272064303,
#  (4, 6, 6): 0.38529044734034446,
#  (5, 5, 6): 0.3960503141458788,
#  (4, 7, 7): 0.4024199248187945,
#  (5, 6, 7): 0.42052775091978695,
#  (4, 8, 8): 0.4285657819670951,
#  (5, 7, 8): 0.43856474403143997,
#  (4, 9, 9): 0.4379673356555573,
#  (5, 8, 9): 0.45166674671141765,
#  (4, 10, 10): 0.4425199304814645,
#  (5, 9, 10): 0.47425496198072786,
#  (4, 11, 11): 0.44806372408931566,
#  (5, 10, 11): 0.4900424495175617,
#  (4, 12, 12): 0.4693452418753916,
#  (5, 11, 12): 0.4940311588415976,
#  (4, 13, 13): 0.47675533508188117,
#  (5, 12, 13): 0.4998499491682755,
#  (4, 14, 14): 0.48208386784704227,
#  (5, 13, 14): 0.5030468273700656,
#  (4, 15, 15): 0.4852509608016224,
#  (5, 14, 15): 0.5158300733289302,
#  (4, 16, 16): 0.49122878218725124,
#  (5, 15, 16): 0.5299008986445578,
#  (4, 17, 17): 0.49264620272993614,
#  (5, 16, 17): 0.5345106990063337,
#  (4, 17, 51): 0.606547849164465,
#  (5, 16, 51): 0.6068501173284052,
#  (4, 18, 18): 0.494262775936087,
#  (5, 17, 18): 0.5398539672824688,
#  (4, 18, 54): 0.6085029752832394,
#  (5, 17, 54): 0.6086456500903911,
#  (4, 19, 19): 0.4959453033709292,
#  (5, 18, 19): 0.543222478630036,
#  (4, 19, 57): 0.6093778611037021,
#  (5, 18, 57): 0.6110883711250402,
#  (4, 20, 20): 0.5004434876119833,
#  (5, 19, 20): 0.5470177244216667,
#  (4, 20, 60): 0.6124243742485055,
#  (5, 19, 60): 0.6127122872794205,
#  (4, 21, 21): 0.501754931550492,
#  (5, 20, 21): 0.5505264463888041,
#  (4, 21, 63): 0.614252404517858,
#  (5, 20, 63): 0.6159845133914207,
#  (4, 22, 22): 0.5025522368075666,
#  (5, 21, 22): 0.5517973221921625,
#  (4, 22, 66): 0.6150826703511068,
#  (5, 21, 66): 0.6187561455845992,
#  (4, 23, 23): 0.5031675890997307,
#  (5, 22, 23): 0.5531504092469813,
#  (4, 23, 69): 0.6156283473259496,
#  (5, 22, 69): 0.6198103713388458,
#  (4, 24, 24): 0.506093654740131,
#  (5, 23, 24): 0.5539436130374774,
#  (4, 24, 72): 0.6177887948462294,
#  (5, 23, 72): 0.6206770046116361,
#  (4, 25, 25): 0.5079278041330082,
#  (5, 24, 25): 0.5569707103687193,
#  (4, 25, 75): 0.619438130170494,
#  (5, 24, 75): 0.6214497341455826,
#  (4, 26, 26): 0.5085600915129808,
#  (5, 25, 26): 0.5597136488340192,
#  (4, 26, 78): 0.6200700371725177,
#  (5, 25, 78): 0.6240545788772883,
#  (4, 27, 27): 0.5094988642906738,
#  (5, 26, 27): 0.5606478239999831,
#  (4, 27, 81): 0.6205027253583889,
#  (5, 26, 81): 0.6261406211631442,
#  (4, 28, 28): 0.5131205254322682,
#  (5, 27, 28): 0.5612278672955936,
#  (4, 28, 84): 0.6225665568796677,
#  (5, 27, 84): 0.6265492628473809,
#  (4, 29, 29): 0.5143106453432743,
#  (5, 28, 29): 0.5613912478936984,
#  (4, 29, 87): 0.6242289738977375,
#  (5, 28, 87): 0.626946129353376,
#  (4, 30, 30): 0.5156899950147334,
#  (5, 29, 30): 0.5637915319797965,
#  (4, 30, 90): 0.6246810778971702,
#  (5, 29, 90): 0.6272628022648563,
#  (4, 31, 31): 0.5166124611551424,
#  (5, 30, 31): 0.566074510814112,
#  (4, 31, 93): 0.6255271046080374,
#  (5, 30, 93): 0.6294413425449626,
#  (4, 32, 32): 0.5177187986883774,
#  (5, 31, 32): 0.5665562016026944,
#  (4, 32, 96): 0.6264351494627344,
#  (5, 31, 96): 0.6310857660322359,
#  (4, 33, 33): 0.5180689779356974,
#  (5, 32, 33): 0.5674294005296449,
#  (4, 33, 99): 0.626903626252138,
#  (5, 32, 99): 0.6314149087251689,
#  (4, 34, 34): 0.5183972606437027,
#  (5, 33, 34): 0.5680504584910413,
#  (4, 35, 35): 0.5188368121708242,
#  ...}

# %%
exportStateProbs(DATA_DIR + 'game1_better_giving_1_to_another_memo_1-100.csv', betterGiving1ToAnother)

# %%
betterGiving1ToAnother, given1ToAnother = readApproxBetterGiving1Probs(DATA_DIR + 'game1_better_giving_1_to_another_memo_1-100.csv')

# %%
betterGiving1ToAnother, given1ToAnother = stricterFilter(betterGiving1ToAnother, printOnGo=True,
                                                         filename=DATA_DIR + 'game1_better_giving_1_to_another_stricter_1-100.csv',
                                                         giveToAnother=True, continueFrom=(59,72,92))
# Out:
# Approximating hitting prob for (58, 74, 74)
# (58, 74, 74): 0.3700090471042421
# (57, 75, 74): 0.4168527100203758
#
# Approximating hitting prob for (58, 74, 93)
# (58, 74, 93): 0.42981435577995225
# (57, 75, 93): 0.4310473738376895
#
# Approximating hitting prob for (58, 74, 95)
# (58, 74, 95): 0.43144993234821777
# (57, 75, 95): 0.4356044148598264
#
# Approximating hitting prob for (59, 25, 74)
# (59, 25, 74): 0.2943121474375082
# (58, 26, 74): 0.29635816058458675
#
# Approximating hitting prob for (59, 74, 75)
# (59, 74, 75): 0.41479316564070623
# (58, 75, 75): 0.37107329704050906
#
# Approximating hitting prob for (59, 74, 94)
# (59, 74, 94): 0.43185294514197664
# (58, 75, 94): 0.43058367962057353
#
# Approximating hitting prob for (59, 38, 75)
# (59, 38, 75): 0.31953985806956403
# (58, 39, 75): 0.32350806377099256
#
# Approximating hitting prob for (59, 75, 76)
# (59, 75, 76): 0.415783901176767
# (58, 76, 76): 0.3714796339473129
#
# Approximating hitting prob for (59, 75, 95)
# (59, 75, 95): 0.43246740534587436
# (58, 76, 95): 0.4309926898139747
#
# Approximating hitting prob for (59, 75, 96)
# (59, 75, 96): 0.43251665284057533
# (58, 76, 96): 0.43233083031573055
#
# Approximating hitting prob for (59, 76, 77)
# (59, 76, 77): 0.416555521861339
# (58, 77, 77): 0.37185511252313974
#
# Approximating hitting prob for (59, 76, 96)
# (59, 76, 96): 0.4332299079203974
# (58, 77, 96): 0.4313694139869145
#
# Approximating hitting prob for (59, 13, 77)
# (59, 13, 77): 0.2756150533492982
# (58, 14, 77): 0.27829509558403215
#
# Approximating hitting prob for (59, 39, 77)
# (59, 39, 77): 0.32086195715508553
# (58, 40, 77): 0.32499541640668783
#
# Approximating hitting prob for (59, 77, 78)
# (59, 77, 78): 0.4170095947704642
# (58, 78, 78): 0.374102739560447
#
# Approximating hitting prob for (59, 78, 79)
# (59, 78, 79): 0.4180785134908962
# (58, 79, 79): 0.37457240421741034
#
# Approximating hitting prob for (59, 40, 79)
# (59, 40, 79): 0.32378954979166913
# (58, 41, 79): 0.3261122836647717
#
# Approximating hitting prob for (59, 48, 79)
# (59, 48, 79): 0.3398134258131229
# (58, 49, 79): 0.34233337398768127
#
# Approximating hitting prob for (59, 79, 80)
# (59, 79, 80): 0.41936395179780933
# (58, 80, 80): 0.3752397453138662
#
# Approximating hitting prob for (59, 79, 99)
# (59, 79, 99): 0.4493407106110669
# (58, 80, 99): 0.44739354116048907
#
# Approximating hitting prob for (58, 81, 81)
# (58, 81, 81): 0.3755983494497785
# (57, 82, 81): 0.42311525124557064
#
# Approximating hitting prob for (58, 81, 92)
# (58, 81, 92): 0.42917329724526126
# (57, 82, 92): 0.4432621981756122
#
# Approximating hitting prob for (58, 81, 100)
# (58, 81, 100): 0.4478596876230265
# (57, 82, 100): 0.4488305756663806
#
# Approximating hitting prob for (59, 41, 81)
# (59, 41, 81): 0.32570143363159565
# (58, 42, 81): 0.3283985907483259
#
# Approximating hitting prob for (59, 81, 82)
# (59, 81, 82): 0.4208738631305764
# (58, 82, 82): 0.3767401414839971
#
# Approximating hitting prob for (59, 81, 99)
# (59, 81, 99): 0.4468868653738871
# (58, 82, 99): 0.4463973255065326
#
# Approximating hitting prob for (59, 82, 83)
# (59, 82, 83): 0.4216947989471651
# (58, 83, 83): 0.37725644553739607
#
# Approximating hitting prob for (59, 42, 83)
# (59, 42, 83): 0.32680981745784116
# (58, 43, 83): 0.3306168181020524
#
# Approximating hitting prob for (59, 83, 84)
# (59, 83, 84): 0.4225247763232805
# (58, 84, 84): 0.3775872466960683
#
# Approximating hitting prob for (59, 83, 95)
# (59, 83, 95): 0.44377843076411255
# (58, 84, 95): 0.4437041992140876
#
# Approximating hitting prob for (59, 83, 100)
# (59, 83, 100): 0.44764179847730334
# (58, 84, 100): 0.4470634656827279
#
# Approximating hitting prob for (59, 17, 84)
# (59, 17, 84): 0.28522070893068135
# (58, 18, 84): 0.28885948795441124
#
# Approximating hitting prob for (59, 51, 84)
# (59, 51, 84): 0.34596189789912285
# (58, 52, 84): 0.3473800413927112
#
# Approximating hitting prob for (59, 84, 85)
# (59, 84, 85): 0.42315828266513217
# (58, 85, 85): 0.3779573739230435
#
# Approximating hitting prob for (58, 86, 86)
# (58, 86, 86): 0.37814969566129736
# (57, 87, 86): 0.4429568259645267
#
# Approximating hitting prob for (58, 87, 87)
# (58, 87, 87): 0.38531294066601585
# (57, 88, 87): 0.4444987781957486
#
# Approximating hitting prob for (59, 44, 87)
# (59, 44, 87): 0.3307540151054656
# (58, 45, 87): 0.33377979830119764
#
# Approximating hitting prob for (59, 87, 88)
# (59, 87, 88): 0.4245288665744475
# (58, 88, 88): 0.3924510057547172
#
# Approximating hitting prob for (59, 88, 89)
# (59, 88, 89): 0.4354228392589338
# (58, 89, 89): 0.392651017531739
#
# Approximating hitting prob for (59, 18, 89)
# (59, 18, 89): 0.2900824856222062
# (58, 19, 89): 0.2923227466642535
#
# Approximating hitting prob for (59, 30, 89)
# (59, 30, 89): 0.3292636167991995
# (58, 31, 89): 0.33013258964657116
#
# Approximating hitting prob for (58, 90, 90)
# (58, 90, 90): 0.39292501876734565
# (57, 91, 90): 0.4455581163205025
#
# Approximating hitting prob for (58, 13, 91)
# (58, 13, 91): 0.2809054546079876
# (57, 14, 91): 0.28533228980392034
#
# Approximating hitting prob for (58, 66, 91)
# (58, 66, 91): 0.42504395195364125
# (57, 67, 91): 0.4297268221608941
#
# Approximating hitting prob for (58, 91, 91)
# (58, 91, 91): 0.3933204830220974
# (57, 92, 91): 0.44611311489572597
#
# Approximating hitting prob for (59, 46, 91)
# (59, 46, 91): 0.33407003881132996
# (58, 47, 91): 0.33661380428181903
#
# Approximating hitting prob for (59, 91, 92)
# (59, 91, 92): 0.4447314776673799
# (58, 92, 92): 0.3937088883212396
#
# Approximating hitting prob for (58, 93, 93)
# (58, 93, 93): 0.3942635301783783
# (57, 94, 93): 0.44700163315259517
#
# Approximating hitting prob for (59, 47, 93)
# (59, 47, 93): 0.3351977436945001
# (58, 48, 93): 0.33800774511273524
#
# Approximating hitting prob for (58, 94, 94)
# (58, 94, 94): 0.39452813692843197
# (57, 95, 94): 0.44881527337620836
#
# Approximating hitting prob for (58, 19, 95)
# (58, 19, 95): 0.29311840374037706
# (57, 20, 95): 0.3156426520599981
#
# Approximating hitting prob for (58, 95, 95)
# (58, 95, 95): 0.3950899321986577
# (57, 96, 95): 0.4521417494028828
#
# Approximating hitting prob for (59, 32, 95)
# (59, 32, 95): 0.3384964515381892
# (58, 33, 95): 0.3401954362706585
#
# Approximating hitting prob for (58, 96, 96)
# (58, 96, 96): 0.39535827096267323
# (57, 97, 96): 0.4527740714707696
#
# Approximating hitting prob for (58, 97, 97)
# (58, 97, 97): 0.4005418397638896
# (57, 98, 97): 0.4531300225741721
#
# Approximating hitting prob for (59, 49, 97)
# (59, 49, 97): 0.3376044041795631
# (58, 50, 97): 0.34242197394506596
#
# Approximating hitting prob for (59, 97, 98)
# (59, 97, 98): 0.4471890831711594
# (58, 98, 98): 0.40077565058451686
#
# Approximating hitting prob for (58, 99, 99)
# (58, 99, 99): 0.4011580636266163
# (57, 100, 99): 0.45414805475692327
#
# Approximating hitting prob for (58, 20, 100)
# (58, 20, 100): 0.3141187089241781
# (57, 21, 100): 0.31742746577962594
#
# Approximating hitting prob for (58, 21, 100)
# (58, 21, 100): 0.315822360626458
# (57, 22, 100): 0.31821857186881336
#
# Approximating hitting prob for (59, 50, 99)
# (59, 50, 99): 0.3403498083662419
# (58, 51, 99): 0.3434489005983585
#
# Approximating hitting prob for (58, 100, 100)
# (58, 100, 100): 0.4015177442239917
# (57, 101, 100): 0.4554358576236021
#
# Approximating hitting prob for (59, 2, 21)
# (59, 2, 21): 0.06054558719284203
# (58, 3, 21): 0.06256652091340098
#
# Approximating hitting prob for (59, 2, 63)
# (59, 2, 63): 0.2485916099833676
# (58, 3, 63): 0.2498465060361136
#
# Approximating hitting prob for (59, 2, 64)
# (59, 2, 64): 0.2488411245020868
# (58, 3, 64): 0.25004605103882405
#
# Approximating hitting prob for (59, 3, 66)
# (59, 3, 66): 0.25026770566320294
# (58, 4, 66): 0.2522489131120413
#
# Approximating hitting prob for (59, 3, 67)
# (59, 3, 67): 0.2506584713837503
# (58, 4, 67): 0.25244634698323687
#
# Approximating hitting prob for (59, 4, 69)
# (59, 4, 69): 0.25258451507986074
# (58, 5, 69): 0.2551794818322152
#
# Approximating hitting prob for (59, 4, 70)
# (59, 4, 70): 0.25288105341239314
# (58, 5, 70): 0.2553526524933592
#
# Approximating hitting prob for (59, 5, 5)
# (59, 5, 5): 0.0077745387484532795
# (58, 6, 5): 0.012446183245473487
#
# Approximating hitting prob for (59, 6, 6)
# (59, 6, 6): 0.010987467409857734
# (58, 7, 6): 0.016418391817157468
#
# Approximating hitting prob for (59, 6, 12)
# (59, 6, 12): 0.02512205925998316
# (58, 7, 12): 0.0316495031333844
#
# Approximating hitting prob for (59, 7, 7)
# (59, 7, 7): 0.013017050804114014
# (58, 8, 7): 0.021567924153925597
#
# Approximating hitting prob for (59, 7, 21)
# (59, 7, 21): 0.06553727449431675
# (58, 8, 21): 0.07216023261748712
# Approximating hitting prob for (59, 7, 79)
# (59, 7, 79): 0.26129734736420807
# (58, 8, 79): 0.2637963739187626
#
# Approximating hitting prob for (59, 8, 8)
# (59, 8, 8): 0.018748656679740138
# (58, 9, 8): 0.027582524488765896
#
# Approximating hitting prob for (59, 8, 16)
# (59, 8, 16): 0.03934974064976218
# (58, 9, 16): 0.049027395890877255
#
# Approximating hitting prob for (59, 8, 32)
# (59, 8, 32): 0.08948097818109735
# (58, 9, 32): 0.10390007951691214
#
# Approximating hitting prob for (59, 9, 9)
# (59, 9, 9): 0.024556519278043223
# (58, 10, 9): 0.032902900668118205
#
# Approximating hitting prob for (59, 10, 10)
# (59, 10, 10): 0.03157943237193148
# (58, 11, 10): 0.0446360603924155
#
# Approximating hitting prob for (59, 10, 20)
# (59, 10, 20): 0.07221180192187047
# (58, 11, 20): 0.07818814986419385
#
# Approximating hitting prob for (59, 11, 11)
# (59, 11, 11): 0.0326763496365622
# (58, 12, 11): 0.04787057018260112
#
# Approximating hitting prob for (59, 11, 22)
# (59, 11, 22): 0.074693735727133
# (58, 12, 22): 0.08923320701113911
#
# Approximating hitting prob for (59, 11, 33)
# (59, 11, 33): 0.10414648791758396
# (58, 12, 33): 0.11396821669746483
#
# Approximating hitting prob for (60, 6, 11)
# (60, 6, 11): 0.026347332091860937
# (59, 7, 11): 0.02953145767044453
#
# Approximating hitting prob for (60, 11, 12)
# (60, 11, 12): 0.04658950118563684
# (59, 12, 12): 0.03573358806862866
#
# Approximating hitting prob for (60, 12, 13)
# (60, 12, 13): 0.05005407355781837
# (59, 13, 13): 0.038539114788860684
#
# Approximating hitting prob for (60, 12, 26)
# (60, 12, 26): 0.10118452459392853
# (59, 13, 26): 0.09662006135571277
#
# Approximating hitting prob for (60, 12, 39)
# (60, 12, 39): 0.12406118599132859
# (59, 13, 39): 0.12230865607975305
#
# Approximating hitting prob for (60, 12, 97)
# (60, 12, 97): 0.284991976364324
# (59, 13, 97): 0.2846484357557371
#
# Approximating hitting prob for (60, 13, 14)
# (60, 13, 14): 0.053303420540560975
# (59, 14, 14): 0.04130185966076153
#
# Approximating hitting prob for (60, 13, 28)
# (60, 13, 28): 0.10611739035525869
# (59, 14, 28): 0.10054729798135276
#
# Approximating hitting prob for (60, 13, 42)
# (60, 13, 42): 0.1306889943639741
# (59, 14, 42): 0.12693302364783807
#
# Approximating hitting prob for (60, 13, 70)
# (60, 13, 70): 0.25970961091440614
# (59, 14, 70): 0.2594497026340819
#
# Approximating hitting prob for (60, 13, 100)
# (60, 13, 100): 0.2888134141164614
# (59, 14, 100): 0.28834357403880817
#
# Approximating hitting prob for (60, 14, 30)
# (60, 14, 30): 0.11082650756499872
# (59, 15, 30): 0.10706074673105981
#
# Approximating hitting prob for (59, 16, 16)
# (59, 16, 16): 0.060446785135750795
# (58, 17, 16): 0.0777669939748728
#
# Approximating hitting prob for (59, 16, 32)
# (59, 16, 32): 0.10991674903470044
# (58, 17, 32): 0.12419616165972559
#
# Approximating hitting prob for (59, 16, 48)
# (59, 16, 48): 0.17503469860039278
# (58, 17, 48): 0.18483350600003345
#
# Approximating hitting prob for (59, 16, 64)
# (59, 16, 64): 0.2584778458958212
# (58, 17, 64): 0.2636078629527903
#
# Approximating hitting prob for (59, 16, 80)
# (59, 16, 80): 0.2804828041526745
# (58, 17, 80): 0.28493884577830336
#
# Approximating hitting prob for (59, 17, 17)
# (59, 17, 17): 0.06406292035550547
# (58, 18, 17): 0.08234660901031975
#
# Approximating hitting prob for (59, 17, 34)
# (59, 17, 34): 0.11738000693093274
# (58, 18, 34): 0.1294074539404832
#
# Approximating hitting prob for (59, 17, 46)
# (59, 17, 46): 0.17794259313568125
# (58, 18, 46): 0.18076704599936586
#
# Approximating hitting prob for (59, 17, 51)
# (59, 17, 51): 0.18260877154096508
# (58, 18, 51): 0.192429926053601
#
# Approximating hitting prob for (59, 17, 68)
# (59, 17, 68): 0.2622817699085757
# (58, 18, 68): 0.26771934528312874
#
# Approximating hitting prob for (59, 17, 85)
# (59, 17, 85): 0.283759209001427
# (58, 18, 85): 0.2898248594789418
#
# Approximating hitting prob for (59, 18, 18)
# (59, 18, 18): 0.06777982934672826
# (58, 19, 18): 0.08721092447589947
#
# Approximating hitting prob for (59, 18, 36)
# (59, 18, 36): 0.12320175561240515
# (58, 19, 36): 0.13414055868379318
#
# Approximating hitting prob for (59, 18, 54)
# (59, 18, 54): 0.19057673981529297
# (58, 19, 54): 0.20056702455229858
#
# Approximating hitting prob for (59, 18, 72)
# (59, 18, 72): 0.26501890792801913
# (58, 19, 72): 0.27209890949975185
#
# Approximating hitting prob for (59, 19, 19)
# (59, 19, 19): 0.0705148366827499
# (58, 20, 19): 0.1035808484815469
#
# Approximating hitting prob for (59, 19, 38)
# (59, 19, 38): 0.12559721640805185
# (58, 20, 38): 0.17039123971573492
#
# Approximating hitting prob for (59, 19, 57)
# (59, 19, 57): 0.19706643241120533
# (58, 20, 57): 0.21817932205860516
#
# Approximating hitting prob for (59, 19, 76)
# (59, 19, 76): 0.2669802285875613
# (58, 20, 76): 0.292458190966083
#
# Approximating hitting prob for (59, 19, 95)
# (59, 19, 95): 0.29231182363663216
# (58, 20, 95): 0.3135269888830451
#
# Approximating hitting prob for (59, 20, 20)
# (59, 20, 20): 0.09707015194158881
# (58, 21, 20): 0.11538015679264775
#
# Approximating hitting prob for (60, 7, 20)
# (60, 7, 20): 0.06673623537973723
# (59, 8, 20): 0.07030389027755644
#
# Approximating hitting prob for (60, 20, 21)
# (60, 20, 21): 0.11333182711290478
# (59, 21, 21): 0.098072448538648
#
# Approximating hitting prob for (60, 20, 42)
# (60, 20, 42): 0.1835544075397908
# (59, 21, 42): 0.1783222446597359
#
# Approximating hitting prob for (60, 20, 63)
# (60, 20, 63): 0.2762117933845714
# (59, 21, 63): 0.27289180558176046
#
# Approximating hitting prob for (59, 22, 22)
# (59, 22, 22): 0.09947256609545518
# (58, 23, 22): 0.12017034473804067
#
# Approximating hitting prob for (59, 22, 33)
# (59, 22, 33): 0.13963298941734803
# (58, 23, 33): 0.14396622569973452
#
# Approximating hitting prob for (59, 22, 44)
# (59, 22, 44): 0.18145095328167749
# (58, 23, 44): 0.19361822642442764
#
# Approximating hitting prob for (59, 22, 51)
# (59, 22, 51): 0.20296486652185056
# (58, 23, 51): 0.20887770552484022
#
# Approximating hitting prob for (59, 22, 66)
# (59, 22, 66): 0.27511339341170893
# (58, 23, 66): 0.28729816014475107
#
# Approximating hitting prob for (59, 23, 23)
# (59, 23, 23): 0.10288429262610616
# (58, 24, 23): 0.12307022245659867
#
# Approximating hitting prob for (59, 23, 46)
# (59, 23, 46): 0.18608136100997386
# (58, 24, 46): 0.1995893147557196
#
# Approximating hitting prob for (59, 23, 69)
# (59, 23, 69): 0.28099157694547133
# (58, 24, 69): 0.29163819331137736
#
# Approximating hitting prob for (59, 8, 24)
# (59, 8, 24): 0.07544725846021018
# (58, 9, 24): 0.08285448059368751
#
# Approximating hitting prob for (59, 24, 24)
# (59, 24, 24): 0.10478334101969072
# (58, 25, 24): 0.12497514743466336
#
# Approximating hitting prob for (59, 24, 48)
# (59, 24, 48): 0.19235421049440074
# (58, 25, 48): 0.20381986392076454
#
# Approximating hitting prob for (59, 24, 72)
# (59, 24, 72): 0.2847014014067966
# (58, 25, 72): 0.2947097597365687
#
# Approximating hitting prob for (59, 25, 25)
# (59, 25, 25): 0.10645885544079249
# (58, 26, 25): 0.1270133121997317
#
# Approximating hitting prob for (59, 25, 50)
# (59, 25, 50): 0.1944639788895278
# (58, 26, 50): 0.21251621164531173
#
# Approximating hitting prob for (59, 25, 75)
# (59, 25, 75): 0.28754029926812635
# (58, 26, 75): 0.2970605028685056
#
# Approximating hitting prob for (60, 13, 25)
# (60, 13, 25): 0.10312616270278341
# (59, 14, 25): 0.10437398070249454
#
# Approximating hitting prob for (60, 25, 26)
# (60, 25, 26): 0.1253401529572488
# (59, 26, 26): 0.10779683508966166
#
# Approximating hitting prob for (60, 25, 52)
# (60, 25, 52): 0.2089693938256355
# (59, 26, 52): 0.20354322962114643
#
# Approximating hitting prob for (60, 25, 78)
# (60, 25, 78): 0.2955684593047263
# (59, 26, 78): 0.29026240858260677
#
# Approximating hitting prob for (60, 9, 26)
# (60, 9, 26): 0.08331402207170538
# (59, 10, 26): 0.08804015385584883
#
# Approximating hitting prob for (60, 26, 27)
# (60, 26, 27): 0.12718130294084207
# (59, 27, 27): 0.10959317403333285
#
# Approximating hitting prob for (60, 26, 54)
# (60, 26, 54): 0.2150471313079797
# (59, 27, 54): 0.20780606038795066
#
# Approximating hitting prob for (60, 26, 81)
# (60, 26, 81): 0.29830726429408183
# (59, 27, 81): 0.2927424707854795
#
# Approximating hitting prob for (59, 28, 28)
# (59, 28, 28): 0.11046868507609305
# (58, 29, 28): 0.1402627944851113
#
# Approximating hitting prob for (59, 28, 56)
# (59, 28, 56): 0.21152295494422604
# (58, 29, 56): 0.23568980490336888
#
# Approximating hitting prob for (59, 28, 84)
# (59, 28, 84): 0.2944663471553027
# (58, 29, 84): 0.31430737173912715
#
# Approximating hitting prob for (59, 29, 29)
# (59, 29, 29): 0.11100378237703808
# (58, 30, 29): 0.19822330488262221
#
# Approximating hitting prob for (59, 29, 58)
# (59, 29, 58): 0.21438749203213492
# (58, 30, 58): 0.29586172399910504
#
# Approximating hitting prob for (59, 29, 87)
# (59, 29, 87): 0.29569079075896726
# (58, 30, 87): 0.32180778289982837
#
# Approximating hitting prob for (60, 15, 29)
# (60, 15, 29): 0.11059104034324947
# (59, 16, 29): 0.11501581906233234
#
# Approximating hitting prob for (60, 30, 31)
# (60, 30, 31): 0.19821098520445665
# (59, 31, 31): 0.16411330822792394
#
# Approximating hitting prob for (60, 30, 62)
# (60, 30, 62): 0.30068359026315145
# (59, 31, 62): 0.2920992455646898
#
# Approximating hitting prob for (60, 30, 93)
# (60, 30, 93): 0.3340453455153585
# (59, 31, 93): 0.32987003705401613
#
# Approximating hitting prob for (59, 32, 32)
# (59, 32, 32): 0.16491611984169863
# (58, 33, 32): 0.2080576303515911
#
# Approximating hitting prob for (59, 32, 61)
# (59, 32, 61): 0.30130028179888074
# (58, 33, 61): 0.3031308525453635
#
# Approximating hitting prob for (59, 32, 64)
# (59, 32, 64): 0.2937033962333506
# (58, 33, 64): 0.3065581986466732
#
# Approximating hitting prob for (59, 32, 72)
# (59, 32, 72): 0.31020168075535454
# (58, 33, 72): 0.3114239909181519
#
# Approximating hitting prob for (59, 32, 96)
# (59, 32, 96): 0.3314521226460408
# (58, 33, 96): 0.3404550714540962
#
# Approximating hitting prob for (60, 11, 32)
# (60, 11, 32): 0.10622184356029644
# (59, 12, 32): 0.11098603305043096
#
# Approximating hitting prob for (60, 32, 33)
# (60, 32, 33): 0.20649505396337628
# (59, 33, 33): 0.16619162056663314
#
# Approximating hitting prob for (60, 32, 66)
# (60, 32, 66): 0.3044275379327558
# (59, 33, 66): 0.2956852694740903
#
# Approximating hitting prob for (60, 32, 74)
# (60, 32, 74): 0.31170563190086775
# (59, 33, 74): 0.3113907939161717
#
# Approximating hitting prob for (60, 32, 99)
# (60, 32, 99): 0.33889865861419777
# (59, 33, 99): 0.334424154991757
#
# Approximating hitting prob for (59, 34, 34)
# (59, 34, 34): 0.1675328378414006
# (58, 35, 34): 0.21281696771286654
#
# Approximating hitting prob for (59, 34, 63)
# (59, 34, 63): 0.3037526539338467
# (58, 35, 63): 0.3081721017382458
#
# Approximating hitting prob for (59, 34, 68)
# (59, 34, 68): 0.29694519504787487
# (58, 35, 68): 0.3111783275524379
#
# Approximating hitting prob for (59, 35, 35)
# (59, 35, 35): 0.16893975757040816
# (58, 36, 35): 0.21654281718250834
#
# Approximating hitting prob for (59, 35, 70)
# (59, 35, 70): 0.2983469678927878
# (58, 36, 70): 0.31570044498817346
#
# Approximating hitting prob for (60, 18, 35)
# (60, 18, 35): 0.1278824859461651
# (59, 19, 35): 0.1306509528887075
#
# Approximating hitting prob for (60, 35, 36)
# (60, 35, 36): 0.21234312786724932
# (59, 36, 36): 0.17421169777099935
#
# Approximating hitting prob for (60, 35, 72)
# (60, 35, 72): 0.3100031008540653
# (59, 36, 72): 0.30549254770270245
#
# Approximating hitting prob for (60, 36, 37)
# (60, 36, 37): 0.21592455164227617
# (59, 37, 37): 0.17675643260435428
#
# Approximating hitting prob for (60, 36, 56)
# (60, 36, 56): 0.24035746401076397
# (59, 37, 56): 0.24015488485965672
#
# Approximating hitting prob for (60, 36, 74)
# (60, 36, 74): 0.31593267142280806
# (59, 37, 74): 0.3067907580903589
#
# Approximating hitting prob for (59, 38, 38)
# (59, 38, 38): 0.17794291324081038
# (58, 39, 38): 0.22373427654284408
#
# Approximating hitting prob for (59, 38, 57)
# (59, 38, 57): 0.23894805617365855
# (58, 39, 57): 0.2518507572149406
#
# Approximating hitting prob for (59, 38, 76)
# (59, 38, 76): 0.3091664804470916
# (58, 39, 76): 0.3239125855367792
#
# Approximating hitting prob for (60, 13, 38)
# (60, 13, 38): 0.12328624128778624
# (59, 14, 38): 0.1291920758359974
#
# Approximating hitting prob for (60, 38, 39)
# (60, 38, 39): 0.2196195075228247
# (59, 39, 39): 0.1787551875667397
#
# Approximating hitting prob for (60, 38, 78)
# (60, 38, 78): 0.32013682576990576
# (59, 39, 78): 0.3100809728905881
#
# Approximating hitting prob for (60, 38, 84)
# (60, 38, 84): 0.3251614966445547
# (59, 39, 84): 0.32516488045150066
#
# Approximating hitting prob for (60, 8, 39)
# (60, 8, 39): 0.11065541184684646
# (59, 9, 39): 0.1145707383741555
#
# Approximating hitting prob for (60, 39, 40)
# (60, 39, 40): 0.22154215964822635
# (59, 40, 40): 0.18519130221340319
#
# Approximating hitting prob for (60, 39, 80)
# (60, 39, 80): 0.32181523620861374
# (59, 40, 80): 0.3138699251599421
#
# Approximating hitting prob for (60, 40, 41)
# (60, 40, 41): 0.22712355794345648
# (59, 41, 41): 0.1864541657687185
#
# Approximating hitting prob for (60, 40, 82)
# (60, 40, 82): 0.3251308104459987
# (59, 41, 82): 0.3151790047190651
#
# Approximating hitting prob for (60, 40, 87)
# (60, 40, 87): 0.3306119537281638
# (59, 41, 87): 0.32979918363743815
#
# Approximating hitting prob for (60, 21, 41)
# (60, 21, 41): 0.1847167062109877
# (59, 22, 41): 0.18531803304575345
#
# Approximating hitting prob for (60, 41, 42)
# (60, 41, 42): 0.2287498359037494
# (59, 42, 42): 0.1888578453901459
#
# Approximating hitting prob for (60, 41, 61)
# (60, 41, 61): 0.32357660994783677
# (59, 42, 61): 0.32269283573236285
#
# Approximating hitting prob for (60, 41, 71)
# (60, 41, 71): 0.32237693913371873
# (59, 42, 71): 0.3223837087803108
#
# Approximating hitting prob for (60, 41, 84)
# (60, 41, 84): 0.3262316749956042
# (59, 42, 84): 0.31586512042924936
#
# Approximating hitting prob for (60, 42, 43)
# (60, 42, 43): 0.23159127497226464
# (59, 43, 43): 0.19052301793384577
#
# Approximating hitting prob for (60, 42, 62)
# (60, 42, 62): 0.32418773686145713
# (59, 43, 62): 0.3237466763132277
#
# Approximating hitting prob for (60, 42, 72)
# (60, 42, 72): 0.3239060956531146
# (59, 43, 72): 0.32342362593165674
#
# Approximating hitting prob for (60, 42, 86)
# (60, 42, 86): 0.32819166914701675
# (59, 43, 86): 0.31882514476170326
#
# Approximating hitting prob for (60, 42, 91)
# (60, 42, 91): 0.3331521996123992
# (59, 43, 91): 0.33303561625579314
#
# Approximating hitting prob for (59, 44, 44)
# (59, 44, 44): 0.1913412922044707
# (58, 45, 44): 0.24412476173609052
#
# Approximating hitting prob for (59, 44, 63)
# (59, 44, 63): 0.32494003237665875
# (58, 45, 63): 0.326688856043135
#
# Approximating hitting prob for (59, 44, 88)
# (59, 44, 88): 0.31973105278674885
# (58, 45, 88): 0.3331296858616935
#
# Approximating hitting prob for (59, 44, 92)
# (59, 44, 92): 0.3338492423585741
# (58, 45, 92): 0.33490684106252594
#
# Approximating hitting prob for (59, 45, 45)
# (59, 45, 45): 0.20095228978775423
# (58, 46, 45): 0.24547223686240474
#
# Approximating hitting prob for (59, 45, 64)
# (59, 45, 64): 0.3261212389275482
# (58, 46, 64): 0.3285754114428462
#
# Approximating hitting prob for (59, 45, 90)
# (59, 45, 90): 0.32146190046731327
# (58, 46, 90): 0.3352397159825928
#
# Approximating hitting prob for (59, 45, 94)
# (59, 45, 94): 0.3350754490839842
# (58, 46, 94): 0.33677855114773786
#
# Approximating hitting prob for (60, 23, 45)
# (60, 23, 45): 0.19216026422968094
# (59, 24, 45): 0.19503008359277385
#
# Approximating hitting prob for (60, 45, 46)
# (60, 45, 46): 0.24255331406372904
# (59, 46, 46): 0.20266036457740358
#
# Approximating hitting prob for (60, 45, 92)
# (60, 45, 92): 0.3329631173765634
# (59, 46, 92): 0.32311909985262977
#
# Approximating hitting prob for (60, 46, 47)
# (60, 46, 47): 0.24492751216756614
# (59, 47, 47): 0.20344825574565187
#
# Approximating hitting prob for (60, 46, 94)
# (60, 46, 94): 0.3339401058953577
# (59, 47, 94): 0.32407524982810676
#
# Approximating hitting prob for (60, 24, 47)
# (60, 24, 47): 0.19578716864643778
# (59, 25, 47): 0.20180928193868472
#
# Approximating hitting prob for (60, 32, 47)
# (60, 32, 47): 0.22062535586074686
# (59, 33, 47): 0.2224506208142878
#
# Approximating hitting prob for (60, 47, 48)
# (60, 47, 48): 0.2462383299017826
# (59, 48, 48): 0.20540788712605365
#
# Approximating hitting prob for (60, 47, 67)
# (60, 47, 67): 0.33046326988970526
# (59, 48, 67): 0.3300510488929452
#
# Approximating hitting prob for (60, 47, 96)
# (60, 47, 96): 0.3355523429594098
# (59, 48, 96): 0.3253949903845062
#
# Approximating hitting prob for (60, 48, 49)
# (60, 48, 49): 0.24797505457163824
# (59, 49, 49): 0.20594273279163888
#
# Approximating hitting prob for (60, 48, 98)
# (60, 48, 98): 0.3372900807920555
# (59, 49, 98): 0.32630196074240464
#
# Approximating hitting prob for (60, 25, 49)
# (60, 25, 49): 0.20220021982379413
# (59, 26, 49): 0.20707067184869454
#
# Approximating hitting prob for (60, 49, 50)
# (60, 49, 50): 0.2493796206067539
# (59, 50, 50): 0.20985618769574024
#
# Approximating hitting prob for (60, 49, 100)
# (60, 49, 100): 0.33968292221660196
# (59, 50, 100): 0.3292098059811058
# Approximating hitting prob for (59, 51, 51)
# (59, 51, 51): 0.21179556255331825
# (58, 52, 51): 0.25903570982900376
#
# Approximating hitting prob for (59, 51, 80)
# (59, 51, 80): 0.3408987873338633
# (58, 52, 80): 0.345166726506972
#
# Approximating hitting prob for (60, 26, 51)
# (60, 26, 51): 0.2077105127942865
# (59, 27, 51): 0.2137384015302357
#
# Approximating hitting prob for (60, 51, 52)
# (60, 51, 52): 0.2552661402666602
# (59, 52, 52): 0.21428312469326402
#
# Approximating hitting prob for (60, 51, 71)
# (60, 51, 71): 0.33629577437727187
# (59, 52, 71): 0.33626709758688683
#
# Approximating hitting prob for (60, 52, 53)
# (60, 52, 53): 0.2575530125518588
# (59, 53, 53): 0.21514680287549715
#
# Approximating hitting prob for (60, 27, 53)
# (60, 27, 53): 0.2144187652642109
# (59, 28, 53): 0.21801587940020403
#
# Approximating hitting prob for (60, 53, 54)
# (60, 53, 54): 0.2593013636770765
# (59, 54, 54): 0.21655889200147094
#
# Approximating hitting prob for (60, 54, 55)
# (60, 54, 55): 0.26058314908241165
# (59, 55, 55): 0.21826805134530047
#
# Approximating hitting prob for (59, 56, 56)
# (59, 56, 56): 0.21951146651581432
# (58, 57, 56): 0.2657155163120072
#
# Approximating hitting prob for (59, 56, 75)
# (59, 56, 75): 0.3409673142652316
# (58, 57, 75): 0.3430832708967158
#
# Approximating hitting prob for (60, 19, 56)
# (60, 19, 56): 0.20017948903063057
# (59, 20, 56): 0.21456739885965112
#
# Approximating hitting prob for (59, 57, 57)
# (59, 57, 57): 0.22067572669727317
# (58, 58, 57): 0.3220664040547
#
# Approximating hitting prob for (59, 57, 76)
# (59, 57, 76): 0.34187096244798326
# (58, 58, 76): 0.39950857043200827
#
# Approximating hitting prob for (60, 29, 57)
# (60, 29, 57): 0.22277237340719988
# (59, 30, 57): 0.23675786494318843
#
# Approximating hitting prob for (60, 57, 58)
# (60, 57, 58): 0.26465134997389833
# (59, 58, 58): 0.22162485730206738
#
# Approximating hitting prob for (60, 57, 87)
# (60, 57, 87): 0.3515030928530331
# (59, 58, 87): 0.3512239532595549
#
# Approximating hitting prob for (60, 60, 61)
# (60, 60, 61): 0.3891723148123898
# (59, 61, 61): 0.35632274355376486
#
# Approximating hitting prob for (60, 61, 62)
# (60, 61, 62): 0.40067220177347757
# (59, 62, 62): 0.3569480996880619
#
# Approximating hitting prob for (60, 61, 81)
# (60, 61, 81): 0.41728842775294145
# (59, 62, 81): 0.41672536906915175
#
# Approximating hitting prob for (60, 61, 90)
# (60, 61, 90): 0.4218251662839365
# (59, 62, 90): 0.4217312287103084
#
# Approximating hitting prob for (60, 61, 91)
# (60, 61, 91): 0.42392140790811766
# (59, 62, 91): 0.42357536256496203
#
# Approximating hitting prob for (59, 63, 63)
# (59, 63, 63): 0.35750981289193745
# (58, 64, 63): 0.4034782821805591
#
# Approximating hitting prob for (59, 63, 82)
# (59, 63, 82): 0.41744897123668423
# (58, 64, 82): 0.41918670485619497
#
# Approximating hitting prob for (60, 16, 63)
# (60, 16, 63): 0.25987417756423076
# (59, 17, 63): 0.2622992665944857
#
# Approximating hitting prob for (59, 64, 64)
# (59, 64, 64): 0.35835524137590596
# (58, 65, 64): 0.4045092833454902
#
# Approximating hitting prob for (59, 64, 83)
# (59, 64, 83): 0.4185357970264902
# (58, 65, 83): 0.4202755843143973
#
# Approximating hitting prob for (59, 13, 65)
# (59, 13, 65): 0.2554940329299927
# (58, 14, 65): 0.2593377383826831
#
# Approximating hitting prob for (59, 65, 65)
# (59, 65, 65): 0.35926404424572134
# (58, 66, 65): 0.405540819717272
#
# Approximating hitting prob for (59, 65, 84)
# (59, 65, 84): 0.41922794590243995
# (58, 66, 84): 0.4217902914816378
#
# Approximating hitting prob for (59, 11, 66)
# (59, 11, 66): 0.2525440606164589
# (58, 12, 66): 0.25786323676147116
#
# Approximating hitting prob for (60, 22, 65)
# (60, 22, 65): 0.28148033500878006
# (59, 23, 65): 0.2856350849887481
#
# Approximating hitting prob for (59, 66, 66)
# (59, 66, 66): 0.3596008218958662
# (58, 67, 66): 0.40649402098509935
#
# Approximating hitting prob for (59, 66, 95)
# (59, 66, 95): 0.4276865413594972
# (58, 67, 95): 0.43024237307607033
#
# Approximating hitting prob for (59, 67, 67)
# (59, 67, 67): 0.3609509877460313
# (58, 68, 67): 0.40769666636800955
#
# Approximating hitting prob for (60, 17, 67)
# (60, 17, 67): 0.2628164069045449
# (59, 18, 67): 0.26619168296190726
#
# Approximating hitting prob for (59, 68, 68)
# (59, 68, 68): 0.36160166252461573
# (58, 69, 68): 0.4088241505789541
#
# Approximating hitting prob for (59, 68, 87)
# (59, 68, 87): 0.4226613696462225
# (58, 69, 87): 0.42535441448908057
#
# Approximating hitting prob for (60, 23, 68)
# (60, 23, 68): 0.2865039050432402
# (59, 24, 68): 0.28842869179400293
#
# Approximating hitting prob for (60, 68, 69)
# (60, 68, 69): 0.4062986095782766
# (59, 69, 69): 0.36332701155270636
#
# Approximating hitting prob for (60, 68, 98)
# (60, 68, 98): 0.431721471934473
# (59, 69, 98): 0.4313238222212192
#
# Approximating hitting prob for (60, 35, 69)
# (60, 35, 69): 0.3079316687085663
# (59, 36, 69): 0.31397080333157007
#
# Approximating hitting prob for (60, 69, 70)
# (60, 69, 70): 0.4068080951521295
# (59, 70, 70): 0.3637529934961954
#
# Approximating hitting prob for (60, 69, 94)
# (60, 69, 94): 0.4287535115845689
# (59, 70, 94): 0.4284063975206382
#
# Approximating hitting prob for (60, 70, 71)
# (60, 70, 71): 0.4087016431101876
# (59, 71, 71): 0.36509521401927825
#
# Approximating hitting prob for (60, 70, 100)
# (60, 70, 100): 0.43478494458675004
# (59, 71, 100): 0.4347658377729971
#
# Approximating hitting prob for (60, 24, 71)
# (60, 24, 71): 0.28898781117358274
# (59, 25, 71): 0.29255281304987424
#
# Approximating hitting prob for (59, 72, 72)
# (59, 72, 72): 0.36569939094618853
# (58, 73, 72): 0.4131788068543343
#
# Approximating hitting prob for (59, 72, 91)
# (59, 72, 91): 0.4267346998767989
# (58, 73, 91): 0.4288100924822205
#
# Approximating hitting prob for (59, 73, 73)
# (59, 73, 73): 0.36612803519477116
# (58, 74, 73): 0.4151398261112768
#
# Approximating hitting prob for (60, 37, 73)
# (60, 37, 73): 0.316272397202269
# (59, 38, 73): 0.31884054272790424
#
# Approximating hitting prob for (60, 73, 74)
# (60, 73, 74): 0.41101748745811123
# (59, 74, 74): 0.36963201360944803
#
# Approximating hitting prob for (60, 73, 96)
# (60, 73, 96): 0.43131548090262495
# (59, 74, 96): 0.4309820494182453
#
# Approximating hitting prob for (59, 75, 75)
# (59, 75, 75): 0.36993175375227877
# (58, 76, 75): 0.41669046836165907
#
# Approximating hitting prob for (59, 75, 94)
# (59, 75, 94): 0.42950578790413996
# (58, 76, 94): 0.4308427655231674
#
# Approximating hitting prob for (60, 19, 75)
# (60, 19, 75): 0.2686306325043643
# (59, 20, 75): 0.2857109743915638
#
# Approximating hitting prob for (59, 76, 76)
# (59, 76, 76): 0.3709872397821427
# (58, 77, 76): 0.416835013626349
#
# Approximating hitting prob for (59, 76, 95)
# (59, 76, 95): 0.43036688640472254
# (58, 77, 95): 0.4309109609830415
#
# Approximating hitting prob for (59, 76, 97)
# (59, 76, 97): 0.43198069272165746
# (58, 77, 97): 0.4445517003047767
#
# Approximating hitting prob for (59, 11, 77)
# (59, 11, 77): 0.2695185658747113
# (58, 12, 77): 0.27550421072747566
#
# Approximating hitting prob for (59, 77, 77)
# (59, 77, 77): 0.37139296078250417
# (58, 78, 77): 0.41888380842755796
#
# Approximating hitting prob for (59, 77, 96)
# (59, 77, 96): 0.4306720035412072
# (58, 78, 96): 0.4403995194737276
#
# Approximating hitting prob for (60, 26, 77)
# (60, 26, 77): 0.2958014473335233
# (59, 27, 77): 0.29776128638172367
#
# Approximating hitting prob for (59, 78, 78)
# (59, 78, 78): 0.37179131171027385
# (58, 79, 78): 0.41981765079143357
#
# Approximating hitting prob for (59, 78, 97)
# (59, 78, 97): 0.43123194990223984
# (58, 79, 97): 0.4467512231723178
#
# Approximating hitting prob for (59, 78, 98)
# (59, 78, 98): 0.4324607315266742
# (58, 79, 98): 0.446987488798048
#
# Approximating hitting prob for (59, 79, 79)
# (59, 79, 79): 0.374021422580016
# (58, 80, 79): 0.42031722391245174
#
# Approximating hitting prob for (60, 16, 79)
# (60, 16, 79): 0.2812297544997259
# (59, 17, 79): 0.2829097141269295
#
# Approximating hitting prob for (59, 80, 80)
# (59, 80, 80): 0.3742731113883335
# (58, 81, 80): 0.4210674847429501
#
# Approximating hitting prob for (60, 27, 80)
# (60, 27, 80): 0.2985838099788179
# (59, 28, 80): 0.30082057165235726
#
# Approximating hitting prob for (60, 44, 80)
# (60, 44, 80): 0.3287090145408468
# (59, 45, 80): 0.33018719482406866
#
# Approximating hitting prob for (60, 80, 81)
# (60, 80, 81): 0.41950736244687387
# (59, 81, 81): 0.37480138055637774
#
# Approximating hitting prob for (59, 82, 82)
# (59, 82, 82): 0.37550059612899683
# (58, 83, 82): 0.4228031406698976
#
# Approximating hitting prob for (59, 82, 100)
# (59, 82, 100): 0.4458607922887879
# (58, 83, 100): 0.44807834093278237
#
# Approximating hitting prob for (59, 83, 83)
# (59, 83, 83): 0.376636093569459
# (58, 84, 83): 0.42346822093993985
#
# Approximating hitting prob for (59, 14, 84)
# (59, 14, 84): 0.27826756986366197
# (58, 15, 84): 0.284125306138922
#
# Approximating hitting prob for (60, 28, 83)
# (60, 28, 83): 0.3009452466138833
# (59, 29, 83): 0.302400039135352
#
# Approximating hitting prob for (59, 84, 84)
# (59, 84, 84): 0.3769815268398478
# (58, 85, 84): 0.42395064329550175
#
# Approximating hitting prob for (59, 13, 85)
# (59, 13, 85): 0.2774422417065372
# (58, 14, 85): 0.28133107791859163
#
# Approximating hitting prob for (60, 17, 84)
# (60, 17, 84): 0.28431663731147694
# (59, 18, 84): 0.28671907480611186
#
# Approximating hitting prob for (60, 52, 84)
# (60, 52, 84): 0.3456062397324969
# (59, 53, 84): 0.3486188865349396
#
# Approximating hitting prob for (60, 84, 85)
# (60, 84, 85): 0.42237750190113443
# (59, 85, 85): 0.37744787784931955
#
# Approximating hitting prob for (59, 54, 86)
# (59, 54, 86): 0.34833110226493263
# (58, 55, 86): 0.3521181699334372
#
# Approximating hitting prob for (59, 86, 86)
# (59, 86, 86): 0.3777483597091582
# (58, 87, 86): 0.4260973828659324
#
# Approximating hitting prob for (60, 29, 86)
# (60, 29, 86): 0.3024237086011042
# (59, 30, 86): 0.3168860186733648
#
# Approximating hitting prob for (60, 86, 87)
# (60, 86, 87): 0.42348530608180335
# (59, 87, 87): 0.3780663242728272
#
# Approximating hitting prob for (59, 88, 88)
# (59, 88, 88): 0.37821615409403314
# (58, 89, 88): 0.4442049927923459
#
# Approximating hitting prob for (59, 89, 89)
# (59, 89, 89): 0.392388498745047
# (58, 90, 89): 0.44452984877861107
#
# Approximating hitting prob for (60, 45, 89)
# (60, 45, 89): 0.33119186396415856
# (59, 46, 89): 0.33422002109787896
#
# Approximating hitting prob for (60, 89, 90)
# (60, 89, 90): 0.4260923108648648
# (59, 90, 90): 0.392530300019932
#
# Approximating hitting prob for (60, 13, 90)
# (60, 13, 90): 0.2802028587328353
# (59, 14, 90): 0.2822961306802261
#
# Approximating hitting prob for (60, 90, 91)
# (60, 90, 91): 0.4428341825149953
# (59, 91, 91): 0.39277186845989664
#
# Approximating hitting prob for (59, 66, 92)
# (59, 66, 92): 0.4246123231569922
# (58, 67, 92): 0.42918272292307497
#
# Approximating hitting prob for (59, 92, 92)
# (59, 92, 92): 0.3931299591636333
# (58, 93, 92): 0.4457375343913565
#
# Approximating hitting prob for (60, 31, 92)
# (60, 31, 92): 0.3364667261866665
# (59, 32, 92): 0.3377640109127129
#
# Approximating hitting prob for (60, 92, 93)
# (60, 92, 93): 0.44450550791005566
# (59, 93, 93): 0.3934577081804766
#
# Approximating hitting prob for (60, 70, 93)
# (60, 70, 93): 0.42857817914926793
# (59, 71, 93): 0.42993083908088553
#
# Approximating hitting prob for (60, 93, 94)
# (60, 93, 94): 0.444858943837094
# (59, 94, 94): 0.3938452985549357
#
# Approximating hitting prob for (59, 95, 95)
# (59, 95, 95): 0.39434125296603795
# (58, 96, 95): 0.44709634682291094
#
# Approximating hitting prob for (59, 16, 96)
# (59, 16, 96): 0.2879221725495355
# (58, 17, 96): 0.29345844125401394
#
# Approximating hitting prob for (60, 32, 95)
# (60, 32, 95): 0.3376860462198877
# (59, 33, 95): 0.3391155748123296
#
# Approximating hitting prob for (60, 74, 95)
# (60, 74, 95): 0.4312028977718436
# (59, 75, 95): 0.43246740534587436
#
# Approximating hitting prob for (60, 95, 96)
# (60, 95, 96): 0.4456484355171216
# (59, 96, 96): 0.39494539293223735
#
# Approximating hitting prob for (60, 96, 97)
# (60, 96, 97): 0.4461874000725629
# (59, 97, 97): 0.3952019520892523
#
# Approximating hitting prob for (60, 14, 97)
# (60, 14, 97): 0.28522821953880856
# (59, 15, 97): 0.28919267854739933
#
# Approximating hitting prob for (59, 98, 98)
# (59, 98, 98): 0.39542225585779867
# (58, 99, 98): 0.4529010835456803
#
# Approximating hitting prob for (60, 33, 98)
# (60, 33, 98): 0.3391432210007128
# (59, 34, 98): 0.3408359872503768
#
# Approximating hitting prob for (60, 98, 99)
# (60, 98, 99): 0.4470236647890755
# (59, 99, 99): 0.40058640360053416
#
# Approximating hitting prob for (59, 100, 100)
# (59, 100, 100): 0.4008318282406609
# (58, 101, 100): 0.45355878432823765
#
# Approximating hitting prob for (60, 2, 64)
# (60, 2, 64): 0.24854777516147733
# (59, 3, 64): 0.2498246912973814
#
# Approximating hitting prob for (60, 2, 65)
# (60, 2, 65): 0.2487834385764385
# (59, 3, 65): 0.24999048596952214
#
# Approximating hitting prob for (60, 3, 67)
# (60, 3, 67): 0.2502120341116832
# (59, 4, 67): 0.25201442113367284
#
# Approximating hitting prob for (60, 3, 68)
# (60, 3, 68): 0.2505778824002713
# (59, 4, 68): 0.25229470361501727
#
# Approximating hitting prob for (60, 4, 70)
# (60, 4, 70): 0.2523511366094025
# (59, 5, 70): 0.25476876367264784
#
# Approximating hitting prob for (60, 4, 71)
# (60, 4, 71): 0.2526063240270068
# (59, 5, 71): 0.2552919561788912
#
# Approximating hitting prob for (60, 5, 5)
# (60, 5, 5): 0.007606113672316607
# (59, 6, 5): 0.012222194384548565
#
# Approximating hitting prob for (60, 6, 6)
# (60, 6, 6): 0.010276778439090492
# (59, 7, 6): 0.016114447200240557
#
# Approximating hitting prob for (60, 6, 12)
# (60, 6, 12): 0.024935245165286505
# (59, 7, 12): 0.03133650941772407
#
# Approximating hitting prob for (60, 7, 7)
# (60, 7, 7): 0.012852935892145811
# (59, 8, 7): 0.021115899631248092
#
# Approximating hitting prob for (60, 7, 21)
# (60, 7, 21): 0.06509398492001406
# (59, 8, 21): 0.07162723126742884
#
# Approximating hitting prob for (60, 8, 8)
# (60, 8, 8): 0.0184663233889489
# (59, 9, 8): 0.027230854822618666
#
# Approximating hitting prob for (60, 8, 16)
# (60, 8, 16): 0.03882058405215375
# (59, 9, 16): 0.048486295711460965
#
# Approximating hitting prob for (60, 9, 9)
# (60, 9, 9): 0.024391525147296426
# (59, 10, 9): 0.03233134704626942
#
# Approximating hitting prob for (60, 10, 10)
# (60, 10, 10): 0.02913548107169975
# (59, 11, 10): 0.04382118885947317
#
# Approximating hitting prob for (60, 11, 11)
# (60, 11, 11): 0.03237384213410944
# (59, 12, 11): 0.04714130193814365
#
# Approximating hitting prob for (60, 11, 22)
# (60, 11, 22): 0.07418203759501656
# (59, 12, 22): 0.08317472423881582
#
# Approximating hitting prob for (60, 11, 33)
# (60, 11, 33): 0.10359719159017279
# (59, 12, 33): 0.11283976648998573
#
# Approximating hitting prob for (61, 6, 11)
# (61, 6, 11): 0.025935450527013505
# (60, 7, 11): 0.028659174642193308
#
# Approximating hitting prob for (61, 11, 12)
# (61, 11, 12): 0.04620015996454743
# (60, 12, 12): 0.03516819571864877
#
# Approximating hitting prob for (61, 12, 13)
# (61, 12, 13): 0.0493366525934344
# (60, 13, 13): 0.0382075605755962
#
# Approximating hitting prob for (61, 12, 26)
# (61, 12, 26): 0.09808363396287606
# (60, 13, 26): 0.09585573922493813
#
# Approximating hitting prob for (61, 13, 14)
# (61, 13, 14): 0.052407486832032196
# (60, 14, 14): 0.04095885105320845
#
# Approximating hitting prob for (61, 13, 28)
# (61, 13, 28): 0.10557292921203698
# (60, 14, 28): 0.10003111488018408
#
# Approximating hitting prob for (61, 13, 42)
# (61, 13, 42): 0.12865537850210132
# (60, 14, 42): 0.1262901789017102
#
# Approximating hitting prob for (61, 13, 70)
# (61, 13, 70): 0.2587002064138361
# (60, 14, 70): 0.2586488873858301
#
# Approximating hitting prob for (61, 14, 15)
# (61, 14, 15): 0.055670877663024344
# (60, 15, 15): 0.053763440860215055
#
# Approximating hitting prob for (61, 14, 30)
# (61, 14, 30): 0.10922552766370507
# (60, 15, 30): 0.10550458715595556
#
# Approximating hitting prob for (60, 16, 16)
# (60, 16, 16): 0.05983155138302699
# (59, 17, 16): 0.0768129056112163
#
# Approximating hitting prob for (60, 16, 32)
# (60, 16, 32): 0.10947898498488035
# (59, 17, 32): 0.12268740266148496
#
# Approximating hitting prob for (60, 16, 48)
# (60, 16, 48): 0.1741507445766303
# (59, 17, 48): 0.18289791375589823
#
# Approximating hitting prob for (60, 17, 17)
# (60, 17, 17): 0.06222744474060516
# (59, 18, 17): 0.08066388656595512
#
# Approximating hitting prob for (60, 17, 34)
# (60, 17, 34): 0.11568724439943297
# (59, 18, 34): 0.12807794796754315
#
# Approximating hitting prob for (60, 17, 51)
# (60, 17, 51): 0.17817680263445326
# (59, 18, 51): 0.19108711225840103
#
# Approximating hitting prob for (60, 17, 68)
# (60, 17, 68): 0.26096796187621135
# (59, 18, 68): 0.26551512981500697
#
# Approximating hitting prob for (60, 18, 18)
# (60, 18, 18): 0.06617193195590483
# (59, 19, 18): 0.08615747469130391
#
# Approximating hitting prob for (60, 18, 36)
# (60, 18, 36): 0.12193427972182241
# (59, 19, 36): 0.13321375559046497
#
# Approximating hitting prob for (60, 18, 54)
# (60, 18, 54): 0.18775164159564564
# (59, 19, 54): 0.1983795315843558
# Approximating hitting prob for (60, 18, 72)
# (60, 18, 72): 0.2642565052336682
# (59, 19, 72): 0.2709082168531547
#
# Approximating hitting prob for (60, 19, 19)
# (60, 19, 19): 0.06969950196924415
# (59, 20, 19): 0.10075387627666094
#
# Approximating hitting prob for (60, 19, 38)
# (60, 19, 38): 0.12479684535843082
# (59, 20, 38): 0.1469118404534094
#
# Approximating hitting prob for (60, 19, 57)
# (60, 19, 57): 0.19514198599204557
# (59, 20, 57): 0.2161531246725001
#
# Approximating hitting prob for (60, 19, 76)
# (60, 19, 76): 0.2662492439149726
# (59, 20, 76): 0.2865025441658516
#
# Approximating hitting prob for (60, 21, 21)
# (60, 21, 21): 0.0977951841856627
# (59, 22, 21): 0.11640334710854489
#
# Approximating hitting prob for (61, 11, 21)
# (61, 11, 21): 0.07710213567868197
# (60, 12, 21): 0.08114532819887178
#
# Approximating hitting prob for (61, 21, 22)
# (61, 21, 22): 0.11520003417840731
# (60, 22, 22): 0.09909085495233928
#
# Approximating hitting prob for (61, 21, 44)
# (61, 21, 44): 0.18699456967507497
# (60, 22, 44): 0.17985395642394217
#
# Approximating hitting prob for (61, 21, 66)
# (61, 21, 66): 0.27982214672030525
# (60, 22, 66): 0.2746034798215632
#
# Approximating hitting prob for (61, 22, 23)
# (61, 22, 23): 0.11683295251638372
# (60, 23, 23): 0.10207388910757055
#
# Approximating hitting prob for (61, 22, 46)
# (61, 22, 46): 0.19032410363845478
# (60, 23, 46): 0.18366882761739864
#
# Approximating hitting prob for (61, 22, 69)
# (61, 22, 69): 0.28293779942174474
# (60, 23, 69): 0.27991502586887385
#
# Approximating hitting prob for (61, 6, 23)
# (61, 6, 23): 0.07192255288986849
# (60, 7, 23): 0.07368656065945454
#
# Approximating hitting prob for (61, 8, 23)
# (61, 8, 23): 0.0754173211573291
# (60, 9, 23): 0.07906450569920206
#
# Approximating hitting prob for (61, 23, 24)
# (61, 23, 24): 0.1199346881655496
# (60, 24, 24): 0.10420134496304477
#
# Approximating hitting prob for (61, 23, 48)
# (61, 23, 48): 0.1948327540901208
# (60, 24, 48): 0.1897209221086149
#
# Approximating hitting prob for (61, 23, 72)
# (61, 23, 72): 0.28763490256709207
# (60, 24, 72): 0.28363636617419685
#
# Approximating hitting prob for (61, 24, 25)
# (61, 24, 25): 0.12275266093524935
# (60, 25, 25): 0.10587877499579529
#
# Approximating hitting prob for (61, 24, 50)
# (61, 24, 50): 0.20109148776684968
# (60, 25, 50): 0.19385068200177302
#
# Approximating hitting prob for (61, 24, 75)
# (61, 24, 75): 0.2917884201435496
# (60, 25, 75): 0.2863483425074648
#
# Approximating hitting prob for (60, 26, 26)
# (60, 26, 26): 0.10720651034857596
# (59, 27, 26): 0.12842710337922492
#
# Approximating hitting prob for (60, 26, 52)
# (60, 26, 52): 0.20263182479219263
# (59, 27, 52): 0.21497399025234087
#
# Approximating hitting prob for (60, 26, 78)
# (60, 26, 78): 0.28908158395425115
# (59, 27, 78): 0.29875355456313485
#
# Approximating hitting prob for (60, 9, 27)
# (60, 9, 27): 0.08197401365612872
# (59, 10, 27): 0.08926559296933768
#
# Approximating hitting prob for (60, 27, 27)
# (60, 27, 27): 0.10860574309151899
# (59, 28, 27): 0.1310197691522187
#
# Approximating hitting prob for (60, 27, 54)
# (60, 27, 54): 0.20542154280874111
# (59, 28, 54): 0.21939840271092168
#
# Approximating hitting prob for (60, 27, 81)
# (60, 27, 81): 0.29154993490218767
# (59, 28, 81): 0.3010838884873009
#
# Approximating hitting prob for (61, 14, 27)
# (61, 14, 27): 0.1055157321830516
# (60, 15, 27): 0.10793801327651918
#
# Approximating hitting prob for (61, 27, 28)
# (61, 27, 28): 0.12859809533466968
# (60, 28, 28): 0.11011662966897982
#
# Approximating hitting prob for (61, 27, 56)
# (61, 27, 56): 0.21708751781872485
# (60, 28, 56): 0.2098986080266461
#
# Approximating hitting prob for (61, 27, 84)
# (61, 27, 84): 0.29946009622256337
# (60, 28, 84): 0.2938176599802187
#
# Approximating hitting prob for (61, 28, 29)
# (61, 28, 29): 0.13106494107283329
# (60, 29, 29): 0.11077737182928633
#
# Approximating hitting prob for (61, 28, 58)
# (61, 28, 58): 0.2213249019367917
# (60, 29, 58): 0.21315545986009563
#
# Approximating hitting prob for (61, 28, 87)
# (61, 28, 87): 0.30136059454657654
# (60, 29, 87): 0.29514040421338855
#
# Approximating hitting prob for (60, 31, 31)
# (60, 31, 31): 0.16371698007797222
# (59, 32, 31): 0.2059901135656551
#
# Approximating hitting prob for (61, 16, 31)
# (61, 16, 31): 0.1157542126985388
# (60, 17, 31): 0.11931092134669057
#
# Approximating hitting prob for (61, 31, 32)
# (61, 31, 32): 0.20211141589675954
# (60, 32, 32): 0.16450143461032898
#
# Approximating hitting prob for (61, 31, 64)
# (61, 31, 64): 0.3016124615130699
# (60, 32, 64): 0.2928625799936198
#
# Approximating hitting prob for (61, 31, 72)
# (61, 31, 72): 0.30916621250291504
# (60, 32, 72): 0.30907609673116404
#
# Approximating hitting prob for (61, 31, 96)
# (61, 31, 96): 0.33656875568910255
# (60, 32, 96): 0.3305315990880884
#
# Approximating hitting prob for (60, 33, 33)
# (60, 33, 33): 0.16556973807610614
# (59, 34, 33): 0.20873959158856126
#
# Approximating hitting prob for (60, 33, 66)
# (60, 33, 66): 0.29411237651546823
# (59, 34, 66): 0.30699743714896804
#
# Approximating hitting prob for (60, 33, 74)
# (60, 33, 74): 0.31065665827234334
# (59, 34, 74): 0.3118808399474323
#
# Approximating hitting prob for (60, 33, 99)
# (60, 33, 99): 0.3320924799933578
# (59, 34, 99): 0.3426185826567474
#
# Approximating hitting prob for (61, 17, 33)
# (61, 17, 33): 0.1209671647815659
# (60, 18, 33): 0.12550371065253374
#
# Approximating hitting prob for (61, 33, 34)
# (61, 33, 34): 0.20709849359903
# (60, 34, 34): 0.1669560935323923
#
# Approximating hitting prob for (61, 33, 51)
# (61, 33, 51): 0.2261478142601804
# (60, 34, 51): 0.2258591867591
#
# Approximating hitting prob for (61, 33, 68)
# (61, 33, 68): 0.30491726240961964
# (60, 34, 68): 0.2962091633094968
#
# Approximating hitting prob for (61, 33, 76)
# (61, 33, 76): 0.3119009057353312
# (60, 34, 76): 0.3118168051929155
#
# Approximating hitting prob for (61, 34, 35)
# (61, 34, 35): 0.20855924911430312
# (60, 35, 35): 0.1681780559678497
#
# Approximating hitting prob for (61, 34, 70)
# (61, 34, 70): 0.3068501366463318
# (60, 35, 70): 0.2976354789365605
#
# Approximating hitting prob for (60, 36, 36)
# (60, 36, 36): 0.173080857772242
# (59, 37, 36): 0.21707671001900478
#
# Approximating hitting prob for (60, 36, 72)
# (60, 36, 72): 0.30303084583395623
# (59, 37, 72): 0.316729278389233
#
# Approximating hitting prob for (60, 37, 37)
# (60, 37, 37): 0.17474385819636537
# (59, 38, 37): 0.2190672258797047
#
# Approximating hitting prob for (60, 37, 74)
# (60, 37, 74): 0.3059243169848707
# (59, 38, 74): 0.3192270570166197
#
# Approximating hitting prob for (61, 19, 37)
# (61, 19, 37): 0.13212842020550178
# (60, 20, 37): 0.14359795131214767
#
# Approximating hitting prob for (61, 37, 38)
# (61, 37, 38): 0.2167920447780385
# (60, 38, 38): 0.17697443386080527
#
# Approximating hitting prob for (61, 37, 57)
# (61, 37, 57): 0.23957897378215973
# (60, 38, 57): 0.2379584101006372
#
# Approximating hitting prob for (61, 37, 58)
# (61, 37, 58): 0.24314824029252743
# (60, 38, 58): 0.24311190081578737
#
# Approximating hitting prob for (61, 37, 76)
# (61, 37, 76): 0.3165835218949113
# (60, 38, 76): 0.30706942552075817
#
# ...
# (60, 20, 38): 0.1444072421658709
#
# Approximating hitting prob for (61, 19, 57)
# (61, 19, 57): 0.19250440424127402
# (60, 20, 57): 0.21215875416317775
#
# Approximating hitting prob for (61, 19, 76)
# (61, 19, 76): 0.26583259312559765
# (60, 20, 76): 0.2823099331806698
#
# Approximating hitting prob for (62, 10, 19)
# (62, 10, 19): 0.060134827486569765
# (61, 11, 19): 0.06443611476820177
#
# Approximating hitting prob for (62, 19, 20)
# (62, 19, 20): 0.08641767604736361
# (61, 20, 20): 0.07128733061584548
#
# Approximating hitting prob for (62, 19, 40)
# (62, 19, 40): 0.13621164470962507
# (61, 20, 40): 0.12627333608709304
#
# Approximating hitting prob for (62, 19, 60)
# (62, 19, 60): 0.20356450210324992
# (61, 20, 60): 0.19860783321485684
#
# Approximating hitting prob for (62, 19, 80)
# (62, 19, 80): 0.27052067696379967
# (61, 20, 80): 0.26726394695529304
#
# Approximating hitting prob for (62, 20, 21)
# (62, 20, 21): 0.10074163372589122
# (61, 21, 21): 0.09735673850355248
#
# Approximating hitting prob for (61, 22, 22)
# (61, 22, 22): 0.0986496945525021
# (60, 23, 22): 0.11814656120504836
#
# Approximating hitting prob for (61, 22, 44)
# (61, 22, 44): 0.17911975740593852
# (60, 23, 44): 0.19016047855943363
#
# Approximating hitting prob for (61, 22, 66)
# (61, 22, 66): 0.27396523951838936
# (60, 23, 66): 0.2852474096055148
#
# Approximating hitting prob for (61, 23, 23)
# (61, 23, 23): 0.10174698130325165
# (60, 24, 23): 0.12087988183644939
#
# Approximating hitting prob for (61, 23, 43)
# (61, 23, 43): 0.18604419306839368
# (60, 24, 43): 0.1884353065884871
#
# Approximating hitting prob for (61, 23, 46)
# (61, 23, 46): 0.18304408633729255
# (60, 24, 46): 0.19469355103651945
#
# Approximating hitting prob for (61, 23, 69)
# (61, 23, 69): 0.27932647654017345
# (60, 24, 69): 0.28791589092089115
#
# Approximating hitting prob for (61, 6, 24)
# (61, 6, 24): 0.07126496959297252
# (60, 7, 24): 0.07477994251388069
#
# Approximating hitting prob for (62, 12, 23)
# (62, 12, 23): 0.07988339972617232
# (61, 13, 23): 0.09156143855507108
#
# Approximating hitting prob for (62, 23, 24)
# (62, 23, 24): 0.11925007078981965
# (61, 24, 24): 0.10312317620704338
#
# Approximating hitting prob for (62, 23, 36)
# (62, 23, 36): 0.1428896202371145
# (61, 24, 36): 0.14258641990754675
#
# Approximating hitting prob for (62, 23, 44)
# (62, 23, 44): 0.1881202799565567
# (61, 24, 44): 0.18808144429602044
#
# Approximating hitting prob for (62, 23, 48)
# (62, 23, 48): 0.19306348142196472
# (61, 24, 48): 0.18648851536044228
#
# Approximating hitting prob for (62, 23, 72)
# (62, 23, 72): 0.28693541240335035
# (61, 24, 72): 0.281453326088769
#
# Approximating hitting prob for (62, 24, 25)
# (62, 24, 25): 0.12122352875075972
# (61, 25, 25): 0.10505608499131952
#
# Approximating hitting prob for (62, 24, 50)
# (62, 24, 50): 0.19835568792525127
# (61, 25, 50): 0.19272483757607664
#
# Approximating hitting prob for (62, 24, 75)
# (62, 24, 75): 0.28903735765888877
# (61, 25, 75): 0.28515987951119987
#
# Approximating hitting prob for (62, 13, 25)
# (62, 13, 25): 0.09998730035859515
# (61, 14, 25): 0.10100849390965479
#
# Approximating hitting prob for (62, 25, 26)
# (62, 25, 26): 0.12353368745789163
# (61, 26, 26): 0.10654594776803478
#
# Approximating hitting prob for (62, 25, 52)
# (62, 25, 52): 0.20286239467803382
# (61, 26, 52): 0.194608045229685
#
# Approximating hitting prob for (62, 25, 63)
# (62, 25, 63): 0.28395809729339955
# (61, 26, 63): 0.2839840396551019
#
# Approximating hitting prob for (62, 25, 78)
# (62, 25, 78): 0.29277974787878175
# (61, 26, 78): 0.28770485434836585
#
# Approximating hitting prob for (62, 9, 26)
# (62, 9, 26): 0.08225384315169366
# (61, 10, 26): 0.08423520933053341
#
# Approximating hitting prob for (62, 26, 27)
# (62, 26, 27): 0.125563444215706
# (61, 27, 27): 0.10799976496472241
#
# Approximating hitting prob for (62, 26, 47)
# (62, 26, 47): 0.19668677290584866
# (61, 27, 47): 0.1962107477018881
#
# Approximating hitting prob for (62, 26, 54)
# (62, 26, 54): 0.20929659482828822
# (61, 27, 54): 0.20375682467889736
#
# Approximating hitting prob for (62, 26, 81)
# (62, 26, 81): 0.2957445819526461
# (61, 27, 81): 0.2904607079412688
#
# Approximating hitting prob for (61, 28, 28)
# (61, 28, 28): 0.10974302574197625
# (60, 29, 28): 0.13212083893978924
#
# Approximating hitting prob for (61, 28, 56)
# (61, 28, 56): 0.2079083628779473
# (60, 29, 56): 0.22176054222252026
#
# Approximating hitting prob for (61, 28, 84)
# (61, 28, 84): 0.29310244173688027
# (60, 29, 84): 0.30190813391933347
#
# Approximating hitting prob for (61, 29, 29)
# (61, 29, 29): 0.11049249924249055
# (60, 30, 29): 0.14026550186513487
#
# Approximating hitting prob for (61, 29, 58)
# (61, 29, 58): 0.21159281008139405
# (60, 30, 58): 0.23577039618811815
#
# Approximating hitting prob for (61, 29, 87)
# (61, 29, 87): 0.29457141191326597
# (60, 30, 87): 0.3143314938247536
#
# Approximating hitting prob for (61, 6, 30)
# (61, 6, 30): 0.07885240346215469
# (60, 7, 30): 0.08637479074837097
#
# Approximating hitting prob for (62, 10, 29)
# (62, 10, 29): 0.08767879602725799
# (61, 11, 29): 0.09993853967252679
#
# Approximating hitting prob for (61, 30, 30)
# (61, 30, 30): 0.11100911908693421
# (60, 31, 30): 0.19821098520445665
#
# Approximating hitting prob for (61, 30, 50)
# (61, 30, 50): 0.20726912091276675
# (60, 31, 50): 0.22529879267614514
#
# Approximating hitting prob for (61, 30, 60)
# (61, 30, 60): 0.21443079146488372
# (60, 31, 60): 0.2958415051248211
#
# Approximating hitting prob for (61, 30, 70)
# (61, 30, 70): 0.2916755437572809
# (60, 31, 70): 0.30724918964887066
#
# Approximating hitting prob for (61, 30, 90)
# (61, 30, 90): 0.2957047635220694
# (60, 31, 90): 0.32180048594142513
#
# Approximating hitting prob for (62, 16, 31)
# (62, 16, 31): 0.11521173835362519
# (61, 17, 31): 0.11826517567280032
#
# Approximating hitting prob for (62, 31, 32)
# (62, 31, 32): 0.1982012305768527
# (61, 32, 32): 0.16407989723755814
#
# Approximating hitting prob for (62, 31, 52)
# (62, 31, 52): 0.22679140738213022
# (61, 32, 52): 0.22680220368292356
# Approximating hitting prob for (62, 31, 64)
# (62, 31, 64): 0.3006164230058453
# (61, 32, 64): 0.2920587248143111
#
# Approximating hitting prob for (62, 31, 96)
# (62, 31, 96): 0.33403624151957834
# (61, 32, 96): 0.32980364827781594
#
# Approximating hitting prob for (61, 33, 33)
# (61, 33, 33): 0.1648153056079224
# (60, 34, 33): 0.20788310229740803
#
# Approximating hitting prob for (61, 33, 53)
# (61, 33, 53): 0.22876421448652762
# (60, 34, 53): 0.23281807607847893
#
# Approximating hitting prob for (61, 33, 63)
# (61, 33, 63): 0.3011464166959703
# (60, 34, 63): 0.3028769811725987
#
# Approximating hitting prob for (61, 33, 66)
# (61, 33, 66): 0.29363127659920524
# (60, 34, 66): 0.305977416563461
#
# Approximating hitting prob for (61, 33, 75)
# (61, 33, 75): 0.3104010743796671
# (60, 34, 75): 0.31148193499931875
#
# Approximating hitting prob for (61, 33, 99)
# (61, 33, 99): 0.3312353979848729
# (60, 34, 99): 0.34031493657804046
#
# Approximating hitting prob for (62, 17, 33)
# (62, 17, 33): 0.1189661933369399
# (61, 18, 33): 0.12342955801041967
#
# Approximating hitting prob for (62, 33, 34)
# (62, 33, 34): 0.20638854254320782
# (61, 34, 34): 0.16607897360366808
#
# Approximating hitting prob for (62, 33, 68)
# (62, 33, 68): 0.3042852436479455
# (61, 34, 68): 0.2956262068318437
#
# Approximating hitting prob for (62, 33, 76)
# (62, 33, 76): 0.31158409364508405
# (61, 34, 76): 0.31109905478282024
#
# Approximating hitting prob for (62, 7, 34)
# (62, 7, 34): 0.09079499838564971
# (61, 8, 34): 0.09293508263818201
#
# Approximating hitting prob for (62, 34, 35)
# (62, 34, 35): 0.20775941537010958
# (61, 35, 35): 0.1674404020636504
#
# Approximating hitting prob for (62, 34, 65)
# (62, 34, 65): 0.30353222590746115
# (61, 35, 65): 0.3033634218683733
#
# Approximating hitting prob for (62, 34, 70)
# (62, 34, 70): 0.3061884677173603
# (61, 35, 70): 0.2968176088444638
#
# Approximating hitting prob for (62, 18, 35)
# (62, 18, 35): 0.12501827384454398
# (61, 19, 35): 0.1279766929835535
#
# Approximating hitting prob for (61, 36, 36)
# (61, 36, 36): 0.16868417222261733
# (60, 37, 36): 0.21592455164227617
#
# Approximating hitting prob for (61, 36, 54)
# (61, 36, 54): 0.23144506358653485
# (60, 37, 54): 0.23754150413096395
#
# Approximating hitting prob for (61, 36, 56)
# (61, 36, 56): 0.236386163507917
# (60, 37, 56): 0.23901815770500576
#
# Approximating hitting prob for (61, 36, 72)
# (61, 36, 72): 0.2981957382089399
# (60, 37, 72): 0.3154897291451418
#
# Approximating hitting prob for (61, 37, 37)
# (61, 37, 37): 0.17409548652912585
# (60, 38, 37): 0.21793728115519295
#
# Approximating hitting prob for (61, 37, 74)
# (61, 37, 74): 0.3052894301634685
# (60, 38, 74): 0.317629703068323
#
# Approximating hitting prob for (62, 19, 37)
# (62, 19, 37): 0.12950883314159625
# (61, 20, 37): 0.13349946583213645
#
# Approximating hitting prob for (62, 37, 38)
# (62, 37, 38): 0.21413522632009865
# (61, 38, 38): 0.17501744565441332
#
# Approximating hitting prob for (62, 37, 76)
# (62, 37, 76): 0.3140715228336402
# (61, 38, 76): 0.3062844922505816
#
# Approximating hitting prob for (61, 39, 39)
# (61, 39, 39): 0.17716771146269672
# (60, 40, 39): 0.22154215964822635
#
# Approximating hitting prob for (61, 39, 59)
# (61, 39, 59): 0.24170572042944424
# (60, 40, 59): 0.24922266273617602
#
# Approximating hitting prob for (61, 39, 78)
# (61, 39, 78): 0.30866419099662595
# (60, 40, 78): 0.32321384802104597
#
# Approximating hitting prob for (62, 20, 39)
# (62, 20, 39): 0.1343300487933106
# (61, 21, 39): 0.14680692778663387
#
# Approximating hitting prob for (62, 39, 40)
# (62, 39, 40): 0.21914604843948002
# (61, 40, 40): 0.17848878089342987
#
# Approximating hitting prob for (62, 39, 60)
# (62, 39, 60): 0.2445265680343874
# (61, 40, 60): 0.23964148062108073
#
# Approximating hitting prob for (62, 39, 80)
# (62, 39, 80): 0.31895348034215737
# (61, 40, 80): 0.30983347141537537
#
# Approximating hitting prob for (62, 39, 86)
# (62, 39, 86): 0.32487082131716166
# (61, 40, 86): 0.3247984807461117
#
# Approximating hitting prob for (62, 40, 41)
# (62, 40, 41): 0.22106895321408673
# (61, 41, 41): 0.18485568265773056
#
# Approximating hitting prob for (62, 40, 82)
# (62, 40, 82): 0.32054934461593815
# (61, 41, 82): 0.3136194206365564
#
# Approximating hitting prob for (61, 28, 42)
# (61, 28, 42): 0.1888715085918415
# (60, 29, 42): 0.1973003384400046
#
# Approximating hitting prob for (61, 42, 42)
# (61, 42, 42): 0.18616712752910114
# (60, 43, 42): 0.23159127497226464
#
# Approximating hitting prob for (61, 42, 84)
# (61, 42, 84): 0.31447266529298507
# (60, 43, 84): 0.3274579727029852
#
# Approximating hitting prob for (61, 43, 43)
# (61, 43, 43): 0.1884493024155068
# (60, 44, 43): 0.2330461354673863
#
# Approximating hitting prob for (61, 43, 63)
# (61, 43, 63): 0.3224894390076767
# (60, 44, 63): 0.323890603577003
#
# Approximating hitting prob for (61, 43, 86)
# (61, 43, 86): 0.31563301199126226
# (60, 44, 86): 0.32998485622404455
#
# Approximating hitting prob for (61, 43, 91)
# (61, 43, 91): 0.3310080510726842
# (60, 44, 91): 0.3319455948429118
#
# Approximating hitting prob for (61, 44, 44)
# (61, 44, 44): 0.190090156855531
# (60, 45, 44): 0.2353013304220055
#
# Approximating hitting prob for (61, 44, 64)
# (61, 44, 64): 0.32357304363736844
# (60, 45, 64): 0.3253226481730939
#
# Approximating hitting prob for (61, 44, 74)
# (61, 44, 74): 0.3230894593967371
# (60, 45, 74): 0.331076363960336
#
# Approximating hitting prob for (61, 44, 88)
# (61, 44, 88): 0.31851814162284603
# (60, 45, 88): 0.33129090345522527
#
# Approximating hitting prob for (62, 15, 44)
# (62, 15, 44): 0.13149599502813702
# (61, 16, 44): 0.13702359396110023
#
# Approximating hitting prob for (62, 44, 45)
# (62, 44, 45): 0.23227220714044824
# (61, 45, 45): 0.19100862276066874
#
# Approximating hitting prob for (62, 44, 65)
# (62, 44, 65): 0.32550195450047265
# (61, 45, 65): 0.32461091007436393
#
# Approximating hitting prob for (62, 44, 75)
# (62, 44, 75): 0.3242834668811286
# (61, 45, 75): 0.3224603838695438
#
# Approximating hitting prob for (62, 44, 90)
# (62, 44, 90): 0.32937532728858904
# (61, 45, 90): 0.31945477747342765
#
# Approximating hitting prob for (62, 44, 95)
# (62, 44, 95): 0.33350058334267424
# (61, 45, 95): 0.33349768432810856
#
# Approximating hitting prob for (61, 46, 46)
# (61, 46, 46): 0.2006947669015324
# (60, 47, 46): 0.24492751216756614
#
# Approximating hitting prob for (61, 46, 66)
# (61, 46, 66): 0.3259272458523241
# (60, 47, 66): 0.32834915708553863
#
# Approximating hitting prob for (61, 46, 92)
# (61, 46, 92): 0.3211595716040241
# (60, 47, 92): 0.33440426268969775
#
# Approximating hitting prob for (61, 46, 96)
# (61, 46, 96): 0.33459126635720843
# (60, 47, 96): 0.3355523429594098
#
# Approximating hitting prob for (61, 47, 47)
# (61, 47, 47): 0.20153739155066197
# (60, 48, 47): 0.2462383299017826
#
# Approximating hitting prob for (61, 47, 67)
# (61, 47, 67): 0.32663130805358737
# (60, 48, 67): 0.32902953851921246
#
# Approximating hitting prob for (61, 47, 94)
# (61, 47, 94): 0.32202914141627215
# (60, 48, 94): 0.3355961182174942
#
# Approximating hitting prob for (61, 47, 98)
# (61, 47, 98): 0.33576532077388216
# (60, 48, 98): 0.3372900807920555
#
# Approximating hitting prob for (62, 12, 47)
# (62, 12, 47): 0.13142389875471464
# (61, 13, 47): 0.13542846565655753
#
# Approximating hitting prob for (62, 24, 47)
# (62, 24, 47): 0.19290708755692398
# (61, 25, 47): 0.19593428762974785
#
# Approximating hitting prob for (62, 47, 48)
# (62, 47, 48): 0.24404526283270547
# (61, 48, 48): 0.20304763194825662
#
# Approximating hitting prob for (62, 47, 68)
# (62, 47, 68): 0.32894826608907984
# (61, 48, 68): 0.32874277987442263
#
# Approximating hitting prob for (62, 47, 78)
# (62, 47, 78): 0.3348553982993776
# (61, 48, 78): 0.3346065531714117
#
# Approximating hitting prob for (62, 47, 96)
# (62, 47, 96): 0.33341264415210176
# (61, 48, 96): 0.32337527182062736
#
# Approximating hitting prob for (62, 48, 49)
# (62, 48, 49): 0.24535301651476416
# (61, 49, 49): 0.20476527256946872
#
# Approximating hitting prob for (62, 48, 69)
# (62, 48, 69): 0.32949458895273126
# (61, 49, 69): 0.32943476881151074
#
# Approximating hitting prob for (62, 48, 98)
# (62, 48, 98): 0.3345156451899822
# (61, 49, 98): 0.32500307617432483
#
# Approximating hitting prob for (61, 50, 50)
# (61, 50, 50): 0.20562406205689257
# (60, 51, 50): 0.25304202559666605
#
# Approximating hitting prob for (61, 50, 70)
# (61, 50, 70): 0.3305910685020887
# (60, 51, 70): 0.3343292383099273
#
# Approximating hitting prob for (61, 50, 100)
# (61, 50, 100): 0.32594413762156343
# (60, 51, 100): 0.3410148884548611
#
# Approximating hitting prob for (62, 17, 50)
# (62, 17, 50): 0.18170222340625786
# (61, 18, 50): 0.18298704870503324
#
# Approximating hitting prob for (62, 50, 51)
# (62, 50, 51): 0.24841498583696398
# (61, 51, 51): 0.20937903822354287
#
# Approximating hitting prob for (61, 52, 52)
# (61, 52, 52): 0.21006262451952382
# (60, 53, 52): 0.2575530125518588
#
# Approximating hitting prob for (61, 53, 53)
# (61, 53, 53): 0.21205277570540296
# (60, 54, 53): 0.2593013636770765
#
# Approximating hitting prob for (61, 53, 73)
# (61, 53, 73): 0.3358187062927602
# (60, 54, 73): 0.33754035618695905
#
# Approximating hitting prob for (61, 53, 83)
# (61, 53, 83): 0.341034551687464
# (60, 54, 83): 0.3454562275011049
#
# Approximating hitting prob for (62, 18, 53)
# (62, 18, 53): 0.18779485276570773
# (61, 19, 53): 0.19186918923113896
#
# Approximating hitting prob for (61, 54, 54)
# (61, 54, 54): 0.21455652425375019
# (60, 55, 54): 0.26058314908241165
#
# Approximating hitting prob for (61, 54, 74)
# (61, 54, 74): 0.3365262787178236
# (60, 55, 74): 0.33920177373961086
#
# Approximating hitting prob for (61, 55, 55)
# (61, 55, 55): 0.2157036799978328
# (60, 56, 55): 0.2620633355487793
#
# Approximating hitting prob for (61, 55, 75)
# (61, 55, 75): 0.3381124161029348
# (60, 56, 75): 0.3400304777407955
#
# Approximating hitting prob for (62, 28, 55)
# (62, 28, 55): 0.21502094349162992
# (61, 29, 55): 0.21816401350035586
#
# Approximating hitting prob for (62, 55, 56)
# (62, 55, 56): 0.2595528554711219
# (61, 56, 56): 0.21710918865773318
#
# Approximating hitting prob for (62, 55, 76)
# (62, 55, 76): 0.3396507330571321
# (61, 56, 76): 0.3394924491729494
#
# Approximating hitting prob for (61, 38, 57)
# (61, 38, 57): 0.2370331286887257
# (60, 39, 57): 0.24314767713770816
#
# Approximating hitting prob for (61, 57, 57)
# (61, 57, 57): 0.21855119409379295
# (60, 58, 57): 0.26465134997389833
#
# Approximating hitting prob for (61, 57, 77)
# (61, 57, 77): 0.340227971004208
# (60, 58, 77): 0.3417751702126504
#
# Approximating hitting prob for (62, 29, 57)
# (62, 29, 57): 0.21880711087063429
# (61, 30, 57): 0.22228755527654043
