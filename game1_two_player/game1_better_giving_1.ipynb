# %%
# %run 'game1_global.ipynb'
# %run 'game1_loser_analysis.ipynb'

# %% [markdown]
# # When is player 1 better off giving away $1?

# %%
betterGiving1 = findBetterGiving1(1,1000)
betterGiving1

# %%
exportStateProbs(DATA_DIR + 'game1_better_giving_1_memo_1-1000.csv', betterGiving1)

# %%
# retrieve probabilities from file
betterGiving1, given1 = readApproxBetterGiving1Probs(DATA_DIR + 'game1_better_giving_1_memo_1-100.csv')

# %%
betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
                                       filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv')
# Out:
# Approximating hitting prob for (11, 19, 48)
# (11, 19, 48): 0.5334260883826906
# (10, 19, 48): 0.5333426632228018
#
# Approximating hitting prob for (12, 21, 53)
# (12, 21, 53): 0.5340626283748265
# (11, 21, 53): 0.5334548685835285
#
# Approximating hitting prob for (12, 32, 42)
# (12, 32, 42): 0.5301153617677242
# (11, 32, 42): 0.5299467192997049
#
# Approximating hitting prob for (13, 22, 56)
# (13, 22, 56): 0.5328628830327213
# (12, 22, 56): 0.532734806781722
#
# Approximating hitting prob for (13, 23, 58)
# (13, 23, 58): 0.5343093271797525
# (12, 23, 58): 0.5335330764863161
#
# Approximating hitting prob for (13, 35, 46)
# (13, 35, 46): 0.5303291922468697
# (12, 35, 46): 0.5299937351500015
#
# Approximating hitting prob for (14, 24, 61)
# (14, 24, 61): 0.5334281050874531
# (13, 24, 61): 0.532844623278078
#
# Approximating hitting prob for (14, 25, 63)
# (14, 25, 63): 0.534598505539718
# (13, 25, 63): 0.5335740856592848
#
# Approximating hitting prob for (14, 38, 50)
# (14, 38, 50): 0.5306453312687435
# (13, 38, 50): 0.5300535494230575
#
# Approximating hitting prob for (15, 26, 66)
# (15, 26, 66): 0.5335384252806683
# (14, 26, 66): 0.532976559038264
#
# Approximating hitting prob for (15, 27, 68)
# (15, 27, 68): 0.5347937376379311
# (14, 27, 68): 0.5336038259570041
#
# Approximating hitting prob for (15, 40, 52)
# (15, 40, 52): 0.5298390830172897
# (14, 40, 52): 0.5294060634902246
#
# Approximating hitting prob for (15, 41, 54)
# (15, 41, 54): 0.530814252978444
# (14, 41, 54): 0.5300859465232839
#
# Approximating hitting prob for (16, 27, 69)
# (16, 27, 69): 0.5327214805171471
# (15, 27, 69): 0.5323471322790065
#
# Approximating hitting prob for (16, 28, 71)
# (16, 28, 71): 0.533984832978568
# (15, 28, 71): 0.5330636314503749
#
# Approximating hitting prob for (16, 29, 73)
# (16, 29, 73): 0.5349109988994238
# (15, 29, 73): 0.5336260136575318
#
# Approximating hitting prob for (16, 42, 54)
# (16, 42, 54): 0.528455476635441
# (15, 42, 54): 0.5285157285081951
#
# Approximating hitting prob for (16, 43, 56)
# (16, 43, 56): 0.5300165256608894
# (15, 43, 56): 0.5295344851774494
#
# Approximating hitting prob for (16, 44, 58)
# (16, 44, 58): 0.5309755142180325
# (15, 44, 58): 0.5301059314171186
#
# Approximating hitting prob for (17, 29, 74)
# (17, 29, 74): 0.5332717628242919
# (16, 29, 74): 0.5324865172144486
#
# Approximating hitting prob for (17, 30, 76)
# (17, 30, 76): 0.5341834675713876
# (16, 30, 76): 0.5331293350131605
#
# Approximating hitting prob for (17, 31, 78)
# (17, 31, 78): 0.535032026741298
# (16, 31, 78): 0.5336384909534596
#
# Approximating hitting prob for (17, 44, 56)
# (17, 44, 56): 0.5279972266134371
# (16, 44, 56): 0.5279422800090446
#
# Approximating hitting prob for (17, 45, 58)
# (17, 45, 58): 0.529004914693246
# (16, 45, 58): 0.528895160602941
#
# Approximating hitting prob for (17, 46, 60)
# (17, 46, 60): 0.5301804342251579
# (16, 46, 60): 0.5296194711867167
#
# Approximating hitting prob for (17, 47, 62)
# (17, 47, 62): 0.5311378673662993
# (16, 47, 62): 0.5301263625686753
#
# Approximating hitting prob for (18, 27, 71)
# (18, 27, 71): 0.525620501017532
# (17, 27, 71): 0.5254981980685945
#
# Approximating hitting prob for (18, 28, 73)
# (18, 28, 73): 0.5271004988262395
# (17, 28, 73): 0.5270411065910542
#
# Approximating hitting prob for (18, 31, 79)
# (18, 31, 79): 0.5335270635741508
# (17, 31, 79): 0.5326072076759126
#
# Approximating hitting prob for (18, 32, 81)
# (18, 32, 81): 0.5344121912790228
# (17, 32, 81): 0.5332080138741222
#
# Approximating hitting prob for (18, 33, 83)
# (18, 33, 83): 0.5351589143653502
# (17, 33, 83): 0.5336649245359243
#
# Approximating hitting prob for (18, 45, 56)
# (18, 45, 56): 0.5255722330999105
# (17, 45, 56): 0.5254786841463105
#
# Approximating hitting prob for (18, 47, 60)
# (18, 47, 60): 0.5284828625145415
# (17, 47, 60): 0.5281888889502253
#
# Approximating hitting prob for (18, 48, 62)
# (18, 48, 62): 0.5294526933438758
# (17, 48, 62): 0.5290045013080626
#
# Approximating hitting prob for (18, 49, 64)
# (18, 49, 64): 0.5304295920255223
# (17, 49, 64): 0.5297020995866109
#
# Approximating hitting prob for (18, 50, 66)
# (18, 50, 66): 0.5312826982045813
# (17, 50, 66): 0.5301457096165415
#
# Approximating hitting prob for (19, 20, 58)
# (19, 20, 58): 0.5076781471384154
# (18, 20, 58): 0.507459734940809
#
# Approximating hitting prob for (19, 32, 82)
# (19, 32, 82): 0.5327246501234508
# (18, 32, 82): 0.5320769507714677
#
# Approximating hitting prob for (19, 33, 84)
# (19, 33, 84): 0.5335489429772609
# (18, 33, 84): 0.532734806781722
#
# Approximating hitting prob for (19, 34, 86)
# (19, 34, 86): 0.5345634156030413
# (18, 34, 86): 0.5332648124986303
#
# Approximating hitting prob for (19, 35, 88)
# (19, 35, 88): 0.5345634156030413
# (18, 35, 88): 0.5332648124986303
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/659592125.py:18, in stricterFilter(candidates, timeLim, t, printOnGo, filename, continueFrom)
#      17 try:
# ---> 18     pLarge = LoserAnalysis(sLarge).getHittingProb()  # exact probs
#      19     pSmall = LoserAnalysis(sSmall).getHittingProb()
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:68, in LoserAnalysis.getHittingProb(self, asFloat, approx, t)
#      66     return Q(x, y, z, t)
# ---> 68 sol = self.solveEqns()
#      69 if sol:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:46, in LoserAnalysis.solveEqns(self, asFloat)
#      45 self.getEquations()
# ---> 46 sol = solve(self.equations, self.symbols)
#      47 return {s:float(p) for s, p in sol.items() if sol} if asFloat else sol
#
# File /usr/local/lib/python3.9/site-packages/sympy/solvers/solvers.py:1147, in solve(f, *symbols, **flags)
#    1146 else:
# -> 1147     linear, solution = _solve_system(f, symbols, **flags)
#    1148 assert type(solution) is list
#
# File /usr/local/lib/python3.9/site-packages/sympy/solvers/solvers.py:1799, in _solve_system(exprs, symbols, **flags)
#    1797     continue
# -> 1799 poly = g.as_poly(*symbols, extension=True)
#    1801 if poly is not None:
#
# File /usr/local/lib/python3.9/site-packages/sympy/core/expr.py:1102, in Expr.as_poly(self, *gens, **args)
#    1101 try:
# -> 1102     poly = Poly(self, *gens, **args)
#    1104     if not poly.is_Poly:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:182, in Poly.__new__(cls, rep, *gens, **args)
#     181 else:
# --> 182     return cls._from_expr(rep, opt)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:312, in Poly._from_expr(cls, rep, opt)
#     311 rep, opt = _dict_from_expr(rep, opt)
# --> 312 return cls._from_dict(rep, opt)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:261, in Poly._from_dict(cls, rep, opt)
#     259         rep[monom] = domain.convert(coeff)
# --> 261 return cls.new(DMP.from_dict(rep, level, domain), *gens)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polyclasses.py:279, in DMP.from_dict(cls, rep, lev, dom)
#     278 """Construct and instance of ``cls`` from a ``dict`` representation. """
# --> 279 return cls(dmp_from_dict(rep, lev, dom), dom, lev)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
#     [... skipping similar frames: dmp_from_dict at line 1012 (2958 times)]
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:998, in dmp_from_dict(f, u, K)
#     996 coeffs = {}
# --> 998 for monom, coeff in f.items():
#     999     head, tail = monom[0], monom[1:]
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# TimeoutException                          Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
#       2                                        filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv')
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/659592125.py:23, in stricterFilter(candidates, timeLim, t, printOnGo, filename, continueFrom)
#      21 except (TimeoutException, RecursionError):
#      22     print(f'Approximating hitting prob for {sLarge}')
# ---> 23     pLarge = LoserAnalysis(sLarge).getHittingProb(approx=True, t=t)
#      24     pSmall = LoserAnalysis(sSmall).getHittingProb(approx=True, t=t)
#      26 finally:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:66, in LoserAnalysis.getHittingProb(self, asFloat, approx, t)
#      64 if approx:
#      65     x, y, z = self.initState
# ---> 66     return Q(x, y, z, t)
#      68 sol = self.solveEqns()
#      69 if sol:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:31, in Q(x, y, z, t)
#      29 if x==0: return 1
#      30 if z*y==0: return 0
# ---> 31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
#      33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:31, in Q(x, y, z, t)
#      29 if x==0: return 1
#      30 if z*y==0: return 0
# ---> 31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
#      33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
#     [... skipping similar frames: memoize.<locals>.memodict.__call__ at line 8 (11 times), <genexpr> at line 33 (10 times), Q at line 33 (10 times), memoize.<locals>.memodict.__missing__ at line 11 (10 times)]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2027475117.py:12, in sigalarmHandler(signum, frame)
#       8 """
#       9 Handler function to be called when SIGALRM is received.
#      10 """
#      11 # We get signal!
# ---> 12 raise TimeoutException()
#
# TimeoutException:

# %%
betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
                                       filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv',
                                       continueFrom=(69,64,100))
# Out:
# Approximating hitting prob for (70, 12, 93)
# (70, 12, 93): 0.27064890356707977
# (69, 12, 93): 0.2704508979612977
#
# Approximating hitting prob for (70, 13, 95)
# (70, 13, 95): 0.273002814385276
# (69, 13, 95): 0.2728333555110289
#
# Approximating hitting prob for (70, 15, 99)
# (70, 15, 99): 0.2777183843625525
# (69, 15, 99): 0.27732957441332723
#
# Approximating hitting prob for (70, 30, 84)
# (70, 30, 84): 0.2928672871530125
# (69, 30, 84): 0.29290071879804375
#
# Approximating hitting prob for (70, 50, 94)
# (70, 50, 94): 0.32695735265836573
# (69, 50, 94): 0.3267132634013896
#
# Approximating hitting prob for (70, 58, 98)
# (70, 58, 98): 0.3430616778838396
# (69, 58, 98): 0.3428394039934912
#
# Approximating hitting prob for (70, 60, 99)
# (70, 60, 99): 0.34560612414415176
# (69, 60, 99): 0.34492499438010804
#
# Approximating hitting prob for (70, 84, 90)
# (70, 84, 90): 0.4148018936715927
# (69, 84, 90): 0.41468720846314083
#
# Approximating hitting prob for (71, 12, 94)
# (71, 12, 94): 0.27043453644878807
# (70, 12, 94): 0.2702550831661171
#
# Approximating hitting prob for (71, 15, 100)
# (71, 15, 100): 0.2774240055525448
# (70, 15, 100): 0.27714908068396565
#
# Approximating hitting prob for (71, 36, 88)
# (71, 36, 88): 0.3107284046458855
# (70, 36, 88): 0.3107029569244443
#
# Approximating hitting prob for (71, 44, 92)
# (71, 44, 92): 0.31946810865446534
# (70, 44, 92): 0.31933447137280896
#
# Approximating hitting prob for (71, 52, 96)
# (71, 52, 96): 0.3287350571698488
# (70, 52, 96): 0.32848900976647166
#
# Approximating hitting prob for (71, 60, 100)
# (71, 60, 100): 0.3432269284144038
# (70, 60, 100): 0.3428263666917539
#
# Approximating hitting prob for (72, 14, 99)
# (72, 14, 99): 0.27369224353294386
# (71, 14, 99): 0.27347335165357634
#
# Approximating hitting prob for (72, 40, 91)
# (72, 40, 91): 0.3129742549703007
# (71, 40, 91): 0.31282979281170153
#
# Approximating hitting prob for (72, 46, 94)
# (72, 46, 94): 0.32065055730266634
# (71, 46, 94): 0.32060860453920875
#
# Approximating hitting prob for (72, 50, 96)
# (72, 50, 96): 0.32548552599084296
# (71, 50, 96): 0.32522123422559995
#
# Approximating hitting prob for (72, 54, 98)
# (72, 54, 98): 0.33015250293768666
# (71, 54, 98): 0.3299310590778092
#
# Approximating hitting prob for (73, 11, 94)
# (73, 11, 94): 0.26568088778907833
# (72, 11, 94): 0.26555372470314254
#
# Approximating hitting prob for (73, 13, 98)
# (73, 13, 98): 0.2712824779940791
# (72, 13, 98): 0.27092732614422377
#
# Approximating hitting prob for (73, 14, 100)
# (73, 14, 100): 0.2735392177539206
# (72, 14, 100): 0.2733296833190661
#
# Approximating hitting prob for (73, 26, 85)
# (73, 26, 85): 0.2838182327188731
# (72, 26, 85): 0.2838382526274032
#
# Approximating hitting prob for (73, 40, 92)
# (73, 40, 92): 0.31265646156970867
# (72, 40, 92): 0.31256600858492634
#
# Approximating hitting prob for (73, 44, 94)
# (73, 44, 94): 0.31905281367702304
# (72, 44, 94): 0.31898130581150774
#
# Approximating hitting prob for (74, 12, 97)
# (74, 12, 97): 0.26803823241416097
# (73, 12, 97): 0.2678146488650772
#
# Approximating hitting prob for (74, 13, 99)
# (74, 13, 99): 0.27106341315623816
# (73, 13, 99): 0.2708043750088058
#
# Approximating hitting prob for (74, 30, 88)
# (74, 30, 88): 0.29121346643802504
# (73, 30, 88): 0.2911904861374854
#
# Approximating hitting prob for (74, 40, 93)
# (74, 40, 93): 0.3124715276947375
# (73, 40, 93): 0.3123265733297223
#
# Approximating hitting prob for (74, 46, 96)
# (74, 46, 96): 0.3194592906289733
# (73, 46, 96): 0.31936096416339166
#
# Approximating hitting prob for (74, 52, 99)
# (74, 52, 99): 0.32609715069378836
# (73, 52, 99): 0.32593271890358366
#
# Approximating hitting prob for (74, 54, 100)
# (74, 54, 100): 0.3285392810102394
# (73, 54, 100): 0.32834877261967127
#
# Approximating hitting prob for (75, 13, 100)
# (75, 13, 100): 0.2708561821230972
# (74, 13, 100): 0.27060467983388525
#
# Approximating hitting prob for (75, 38, 93)
# (75, 38, 93): 0.3107255922584125
# (74, 38, 93): 0.3106856959891582
#
# Approximating hitting prob for (75, 40, 94)
# (75, 40, 94): 0.31219750777533284
# (74, 40, 94): 0.31212211416489793
#
# Approximating hitting prob for (75, 48, 98)
# (75, 48, 98): 0.3206660566987458
# (74, 48, 98): 0.3206193374288369
#
# Approximating hitting prob for (75, 52, 100)
# (75, 52, 100): 0.32543894655115896
# (74, 52, 100): 0.3251891291627604
#
# Approximating hitting prob for (76, 42, 96)
# (76, 42, 96): 0.31283229353690856
# (75, 42, 96): 0.31269685409230785
#
# Approximating hitting prob for (77, 42, 97)
# (77, 42, 97): 0.31263411481005815
# (76, 42, 97): 0.3124896740010894
#
# Approximating hitting prob for (78, 42, 98)
# (78, 42, 98): 0.312441399741017
# (77, 42, 98): 0.3119828040723916
#
# Approximating hitting prob for (79, 32, 94)
# (79, 32, 94): 0.2912337154122105
# (78, 32, 94): 0.2911642829888588
#
# Approximating hitting prob for (79, 40, 98)
# (79, 40, 98): 0.31073467566545016
# (78, 40, 98): 0.31068391480047436
#
# Approximating hitting prob for (79, 42, 99)
# (79, 42, 99): 0.3121670959474713
# (78, 42, 99): 0.3120607193357822
#
# Approximating hitting prob for (79, 44, 100)
# (79, 44, 100): 0.3130463381703828
# (78, 44, 100): 0.3128490513416133
#
# Approximating hitting prob for (82, 34, 98)
# (82, 34, 98): 0.2917812876569657
# (81, 34, 98): 0.29172992113254753
#
# Approximating hitting prob for (84, 30, 98)
# (84, 30, 98): 0.2839368557613289
# (83, 30, 98): 0.2838357734914572
#
# Approximating hitting prob for (84, 34, 100)
# (84, 34, 100): 0.29123192191006453
# (83, 34, 100): 0.2911447291167216
#
# Approximating hitting prob for (93, 47, 62)
# (93, 47, 62): 0.2078449082948937
# (92, 47, 62): 0.20783817692579917
#
# Approximating hitting prob for (93, 47, 98)
# (93, 47, 98): 0.3020413154785515
# (92, 47, 98): 0.3020379983481061
#
# Approximating hitting prob for (95, 48, 100)
# (95, 48, 100): 0.30201302025080573
# (94, 48, 100): 0.30196433138324996
#
# Approximating hitting prob for (99, 50, 66)
# (99, 50, 66): 0.2078419114332157
# (98, 50, 66): 0.2078180397808808
#
# Approximating hitting prob for (100, 51, 67)
# (100, 51, 67): 0.2080190772886974
# (99, 51, 67): 0.20801576587712575

# %%
class TimeoutException(Exception):
    """
    Custom exception for timeout.
    """
    pass

def sigalarmHandler(signum, frame):
    """
    Handler function to be called when SIGALRM is received.
    """
    # We get signal!
    raise TimeoutException()

# %% [markdown]
# ## When is player 1 better off giving away $1 to another player?

# %%
betterGiving1ToAnother = findBetterGiving1(1,100, t=10, giveToAnother=True)
betterGiving1ToAnother
# Out:
# {(1, 5, 5): 0.5004434876119833,
#  (2, 4, 5): 0.5015168645690443,
#  (1, 6, 6): 0.506093654740131,
#  (2, 5, 6): 0.5184847144955884,
#  (1, 7, 7): 0.5131205254322682,
#  (2, 6, 7): 0.5396071019936831,
#  (1, 8, 8): 0.5177187986883774,
#  (2, 7, 8): 0.553386673567715,
#  (1, 9, 9): 0.5198030383135193,
#  (2, 8, 9): 0.5596511014686955,
#  (1, 10, 10): 0.521353326527545,
#  (2, 9, 10): 0.5643071756348541,
#  (1, 11, 11): 0.5225738105217701,
#  (2, 10, 11): 0.5679767313216567,
#  (1, 12, 12): 0.5237380978085997,
#  (2, 11, 12): 0.5714793837797846,
#  (1, 12, 36): 0.6316713165390184,
#  (2, 11, 36): 0.6317622599451304,
#  (1, 13, 13): 0.5248276325593998,
#  (2, 12, 13): 0.5747622273980084,
#  (1, 13, 39): 0.6325682808186844,
#  (2, 12, 39): 0.6347403712118326,
#  (1, 14, 14): 0.5256858644409728,
#  (2, 13, 14): 0.57733900685236,
#  (1, 14, 42): 0.6333982655030145,
#  (2, 13, 42): 0.6366529115385103,
#  (1, 15, 15): 0.5268432387720368,
#  (2, 14, 15): 0.5808387485922709,
#  (1, 15, 45): 0.63421194355006,
#  (2, 14, 45): 0.6395029512036614,
#  (1, 16, 16): 0.5279858610539553,
#  (2, 15, 16): 0.5842379051719758,
#  (1, 16, 48): 0.635051999980948,
#  (2, 15, 48): 0.6419747628823096,
#  (1, 17, 17): 0.5283821156475977,
#  (2, 16, 17): 0.5854285708426477,
#  (1, 17, 51): 0.6353974162348219,
#  (2, 16, 51): 0.6431331129655032,
#  (1, 18, 18): 0.5286972339709394,
#  (2, 17, 18): 0.586367542078401,
#  (1, 18, 54): 0.635696343688081,
#  (2, 17, 54): 0.6438519942124338,
#  (1, 19, 19): 0.5290239620908059,
#  (2, 18, 19): 0.5873462049262054,
#  (1, 19, 57): 0.6359734242165406,
#  (2, 18, 57): 0.644798126476528,
#  (1, 20, 20): 0.5292680655049197,
#  (2, 19, 20): 0.5880847500592729,
#  (1, 20, 60): 0.6362249863460855,
#  (2, 19, 60): 0.6453717860378668,
#  (1, 21, 21): 0.5295149142555335,
#  (2, 20, 21): 0.588833317324383,
#  (1, 21, 63): 0.6364634998581686,
#  (2, 20, 63): 0.6461849514015902,
#  (1, 21, 64): 0.646956969794154,
#  (2, 20, 64): 0.6472510681012803,
#  (1, 22, 22): 0.5297588522879303,
#  (2, 21, 22): 0.5895697621096462,
#  (1, 22, 66): 0.6366529446148538,
#  (2, 21, 66): 0.6466174245912294,
#  (1, 22, 67): 0.6471532117394029,
#  (2, 21, 67): 0.647774501235203,
#  (1, 23, 23): 0.5299781484445122,
#  (2, 22, 23): 0.5902254013880421,
#  (1, 23, 69): 0.6368433485854967,
#  (2, 22, 69): 0.6472793649130383,
#  (1, 23, 70): 0.647343764553591,
#  (2, 22, 70): 0.6483569921802232,
#  (1, 24, 24): 0.5301334749530051,
#  (2, 23, 24): 0.5907054714357991,
#  (1, 24, 72): 0.6370145682769819,
#  (2, 23, 72): 0.6476786129157565,
#  (1, 24, 73): 0.6475028948415723,
#  (2, 23, 73): 0.6487869019532507,
#  (1, 25, 25): 0.5303300145853443,
#  (2, 24, 25): 0.5913062701368778,
#  (1, 25, 75): 0.6371719124424207,
#  (2, 24, 75): 0.6482151442816559,
#  (1, 25, 76): 0.6476655808364664,
#  (2, 24, 76): 0.6492909523499552,
#  (1, 26, 26): 0.5305056830450136,
#  (2, 25, 26): 0.5918398411700453,
#  (1, 26, 78): 0.6373261970460974,
#  (2, 25, 78): 0.6485752629701603,
#  (1, 26, 79): 0.6478181289321158,
#  (2, 25, 79): 0.6496998090304239,
#  (1, 27, 27): 0.5306651440964284,
#  (2, 26, 27): 0.5923164712780911,
#  (1, 27, 81): 0.6374779182331624,
#  (2, 26, 81): 0.6491023179636827,
#  (1, 27, 82): 0.6479675843896594,
#  (2, 26, 82): 0.6501630597575742,
#  (1, 28, 28): 0.5308433925108808,
#  (2, 27, 28): 0.5928632397722654,
#  (1, 28, 84): 0.6376227926171485,
#  (2, 27, 84): 0.6494288807018324,
#  (1, 28, 85): 0.6481137818273807,
#  (2, 27, 85): 0.6505545513577707,
#  (1, 29, 29): 0.531019424810327,
#  (2, 28, 29): 0.593397753481219,
#  (1, 29, 87): 0.6377697342725956,
#  (2, 28, 87): 0.6499273246583346,
#  (1, 29, 88): 0.6482600123414454,
#  (2, 28, 88): 0.651006837277092,
#  (1, 30, 30): 0.5311653907136445,
#  (2, 29, 30): 0.5938409764824553,
#  (1, 30, 90): 0.6379076957008163,
#  (2, 29, 90): 0.650248810177776,
#  (1, 30, 91): 0.6483932438525631,
#  (2, 29, 91): 0.6513514100842097,
#  (1, 31, 31): 0.5313585565589595,
#  (2, 30, 31): 0.5944358379798981,
#  (1, 31, 93): 0.6380471455644888,
#  (2, 30, 93): 0.6507426069080341,
#  (1, 31, 94): 0.6485374236333384,
#  (2, 30, 94): 0.6518048371373775,
#  (1, 32, 32): 0.5316609404901015,
#  (2, 31, 32): 0.5953108064912191,
#  (1, 32, 96): 0.6382585695513472,
#  (2, 31, 96): 0.651341801406459,
#  (1, 32, 97): 0.6487406281488678,
#  (2, 31, 97): 0.6524211817198429,
#  (1, 33, 33): 0.5317385375916611,
#  (2, 32, 33): 0.5955452681512389,
#  (1, 33, 99): 0.6383231014972734,
#  (2, 32, 99): 0.6515462628230367,
#  (1, 33, 100): 0.6488068966028214,
#  (2, 32, 100): 0.6526188624860286,
#  (1, 34, 34): 0.5318062779428949,
#  (2, 33, 34): 0.5957485718957984,
#  (1, 35, 35): 0.5318679983996342,
#  (2, 34, 35): 0.5959310706203745,
#  (1, 36, 36): 0.5319251873973311,
#  (2, 35, 36): 0.5961088063515048,
#  (1, 37, 37): 0.5319769849510576,
#  (2, 36, 37): 0.5962632397987264,
#  (1, 38, 38): 0.5320250779543261,
#  (2, 37, 38): 0.5964045750139714,
#  (1, 39, 39): 0.5320778016456672,
#  (2, 38, 39): 0.5965617868740368,
#  (1, 40, 40): 0.5321167325018205,
#  (2, 39, 40): 0.5966842851117292,
#  (1, 41, 41): 0.5321571517934258,
#  (2, 40, 41): 0.5968058406736355,
#  (2, 14, 41): 0.6338000769223442,
#  (1, 42, 42): 0.5322013748645192,
#  (2, 41, 42): 0.5969399487078528,
#  (1, 43, 43): 0.5322408018658233,
#  (2, 42, 43): 0.5970633565449881,
#  (1, 44, 44): 0.5322755651027112,
#  (2, 43, 44): 0.5971704908211825,
#  (2, 15, 44): 0.6355654440591713,
#  (1, 45, 45): 0.5323146613405815,
#  (2, 44, 45): 0.5972896979627089,
#  (1, 46, 46): 0.5323509791656083,
#  (2, 45, 46): 0.5973977583765179,
#  (1, 47, 47): 0.532385014722942,
#  (2, 46, 47): 0.597498806605531,
#  (2, 16, 47): 0.6375855486545072,
#  (1, 48, 48): 0.5324148826610103,
#  (2, 47, 48): 0.5975902130804501,
#  (1, 49, 49): 0.5324444859883317,
#  (2, 48, 49): 0.5976821983913784,
#  (1, 50, 50): 0.5324711785974361,
#  (2, 49, 50): 0.5977623423713782,
#  (2, 17, 50): 0.6383571866691223,
#  (1, 51, 51): 0.5325028988107334,
#  (2, 50, 51): 0.5978603145004572,
#  (1, 52, 52): 0.5325307160155125,
#  (2, 51, 52): 0.597951109063024,
#  (1, 53, 53): 0.5325579709224543,
#  (2, 52, 53): 0.5980328572456773,
#  (2, 18, 53): 0.6393221393725973,
#  (1, 54, 54): 0.5325877396314925,
#  (2, 53, 54): 0.5981236683464157,
#  (1, 55, 55): 0.5326169460426934,
#  (2, 54, 55): 0.5982126271719249,
#  (1, 56, 56): 0.5326397687196227,
#  (2, 55, 56): 0.5982834436230927,
#  (2, 19, 56): 0.639912667869058,
#  (1, 57, 57): 0.5326706620243357,
#  (2, 56, 57): 0.5983790342554488,
#  (1, 58, 58): 0.5326991076796389,
#  (2, 57, 58): 0.5984666865653948,
#  (1, 59, 59): 0.5327241464715744,
#  (2, 58, 59): 0.5985425140825841,
#  (2, 20, 59): 0.6407575699842504,
#  (1, 60, 60): 0.5327515998365764,
#  (2, 59, 60): 0.5986312082973463,
#  (1, 60, 100): 0.6594202186690291,
#  (2, 59, 100): 0.6594714208485749,
#  (1, 61, 61): 0.5327806408660604,
#  (2, 60, 61): 0.5987212090276719,
#  (1, 62, 62): 0.5328041250698572,
#  (2, 61, 62): 0.5987947377389965,
#  (2, 21, 62): 0.6412867749400921,
#  (1, 63, 63): 0.5328350514509137,
#  (2, 62, 63): 0.5988899810697471,
#  (1, 64, 64): 0.5329295505639383,
#  (2, 63, 64): 0.5991591232757963,
#  (1, 65, 65): 0.5329439718496504,
#  (2, 64, 65): 0.5992017586824079,
#  (2, 22, 65): 0.6419519898198954,
#  (1, 66, 66): 0.5329563424020729,
#  (2, 65, 66): 0.5992384734235551,
#  (1, 67, 67): 0.5329692090996461,
#  (2, 66, 67): 0.5992765939092958,
#  (1, 68, 68): 0.5329786027811648,
#  (2, 67, 68): 0.5993086945005419,
#  (2, 23, 68): 0.6423572742552796,
#  (1, 69, 69): 0.5329891210583583,
#  (2, 68, 69): 0.5993394885762248,
#  (1, 70, 70): 0.5330002016333891,
#  (2, 69, 70): 0.5993723499233687,
#  (1, 71, 71): 0.5330110506740166,
#  (2, 70, 71): 0.5994039212931209,
#  (2, 24, 71): 0.6429282380946333,
#  (1, 72, 72): 0.5330189889964267,
#  (2, 71, 72): 0.5994280670237854,
#  (1, 73, 73): 0.5330284819069756,
#  (2, 72, 73): 0.5994564796027452,
#  (1, 74, 74): 0.5330374786723738,
#  (2, 73, 74): 0.599483089520991,
#  (2, 25, 74): 0.6432813280601704,
#  (1, 75, 75): 0.5330459131399347,
#  (2, 74, 75): 0.5995072187134837,
#  (1, 76, 76): 0.5330541822257785,
#  (2, 75, 76): 0.5995340767043049,
#  (1, 77, 77): 0.5330628151513997,
#  (2, 76, 77): 0.5995594131833307,
#  (2, 26, 77): 0.6438085649735813,
#  (1, 78, 78): 0.5330708527028399,
#  (2, 77, 78): 0.5995827154672391,
#  (1, 79, 79): 0.5330799817736117,
#  (2, 78, 79): 0.5996089284693644,
#  (1, 80, 80): 0.5330863985842266,
#  (2, 79, 80): 0.5996283608210977,
#  (2, 27, 80): 0.6441455136835509,
#  (1, 81, 81): 0.5330929477002151,
#  (2, 80, 81): 0.5996482893179816,
#  (1, 82, 82): 0.5331003237247879,
#  (2, 81, 82): 0.5996707812314773,
#  (1, 83, 83): 0.5331074682149571,
#  (2, 82, 83): 0.599691569713289,
#  (2, 28, 83): 0.6446484064082373,
#  (1, 84, 84): 0.5331135542621382,
#  (2, 83, 84): 0.5997103736144981,
#  (1, 85, 85): 0.5331207318286508,
#  (2, 84, 85): 0.5997354950972921,
#  (1, 86, 86): 0.5331267847994886,
#  (2, 85, 86): 0.5997556055140646,
#  (2, 29, 86): 0.6449977587469728,
#  (1, 87, 87): 0.5331327716176396,
#  (2, 86, 87): 0.5997733675104574,
#  (1, 88, 88): 0.5331386592067605,
#  (2, 87, 88): 0.599791989491778,
#  (1, 89, 89): 0.5331450098646887,
#  (2, 88, 89): 0.5998109256983607,
#  (2, 30, 89): 0.6454688981820182,
#  (1, 90, 90): 0.5331506328430625,
#  (2, 89, 90): 0.5998279269388559,
#  (1, 91, 91): 0.5331572150353944,
#  (2, 90, 91): 0.5998475412104778,
#  (1, 92, 92): 0.5331628049374249,
#  (2, 91, 92): 0.5998653528213856,
#  (2, 31, 92): 0.6457769216297059,
#  (1, 93, 93): 0.5331686925265458,
#  (2, 92, 93): 0.5998821225274772,
#  (1, 94, 94): 0.5331750431844738,
#  (2, 93, 94): 0.5999014225738369,
#  (1, 95, 95): 0.5331811953843418,
#  (2, 94, 95): 0.5999193995664617,
#  (2, 32, 95): 0.646300487069002,
#  (1, 96, 96): 0.5331852306982338,
#  (2, 95, 96): 0.599931571660824,
#  (1, 97, 97): 0.5331905890658605,
#  (2, 96, 97): 0.599948109832512,
#  (1, 98, 98): 0.5331949220668428,
#  (2, 97, 98): 0.5999628122671425,
#  (2, 33, 98): 0.6464613042504953,
#  (1, 99, 99): 0.5331994535258853,
#  (2, 98, 99): 0.59997640664427,
#  (2, 60, 99): 0.6594345241875391,
#  (1, 100, 100): 0.533204183442988,
#  (2, 99, 100): 0.5999915225331928,
#  (2, 6, 6): 0.4693452418753916,
#  (3, 5, 6): 0.4740014979614388,
#  (2, 7, 7): 0.48208386784704227,
#  (3, 6, 7): 0.4955659177124083,
#  (2, 8, 8): 0.49122878218725124,
#  (3, 7, 8): 0.5014666050652847,
#  (2, 9, 9): 0.494262775936087,
#  (3, 8, 9): 0.5178661041836018,
#  (2, 10, 10): 0.5004434876119833,
#  (3, 9, 10): 0.5342839937488357,
#  (2, 11, 11): 0.5025522368075666,
#  (3, 10, 11): 0.5431842258389219,
#  (2, 12, 12): 0.506093654740131,
#  (3, 11, 12): 0.5502830045015581,
#  (2, 13, 13): 0.5085600915129808,
#  (3, 12, 13): 0.5546173616138715,
#  (2, 14, 14): 0.5131205254322682,
#  (3, 13, 14): 0.5568134654323105,
#  (2, 15, 15): 0.5156899950147334,
#  (3, 14, 15): 0.5601744353735879,
#  (2, 16, 16): 0.5177187986883774,
#  (3, 15, 16): 0.5635269543091331,
#  (2, 17, 17): 0.5183972606437027,
#  (3, 16, 17): 0.5645428776577504,
#  (2, 18, 18): 0.5198030383135193,
#  (3, 17, 18): 0.5672856342031618,
#  (2, 19, 19): 0.5202042212823249,
#  (3, 18, 19): 0.5700392728655439,
#  (2, 20, 20): 0.521353326527545,
#  (3, 19, 20): 0.5708707459853257,
#  (2, 20, 60): 0.6295677107148301,
#  (3, 19, 60): 0.6304392723627834,
#  (2, 21, 21): 0.5216864383816829,
#  (3, 20, 21): 0.5735340366157767,
#  (2, 21, 63): 0.6301227813711917,
#  (3, 20, 63): 0.6311136824660452,
#  (2, 22, 22): 0.5225738105217701,
#  (3, 21, 22): 0.5764060555111009,
#  (2, 22, 66): 0.630719892059984,
#  (3, 21, 66): 0.6335248486691138,
#  (2, 23, 23): 0.5230437922847974,
#  (3, 22, 23): 0.5785014418639604,
#  (2, 23, 69): 0.6311993336572169,
#  (3, 22, 69): 0.6351912844629037,
#  (2, 23, 71): 0.641735372847127,
#  (3, 22, 71): 0.6419442003410304,
#  (2, 24, 24): 0.5237380978085997,
#  (3, 23, 24): 0.5800568899875528,
#  (2, 24, 72): 0.6316713165390184,
#  (3, 23, 72): 0.6362437075564361,
#  (2, 24, 74): 0.642247130031838,
#  (3, 23, 74): 0.6426527783069992,
#  (2, 25, 25): 0.524088839353757,
#  (3, 24, 25): 0.5809113180896375,
#  (2, 25, 75): 0.6320944621998256,
#  (3, 24, 75): 0.637120230655896,
#  (2, 25, 77): 0.6426200988797439,
#  (3, 24, 77): 0.6434655302164304,
#  (2, 26, 26): 0.5248276325593998,
#  (3, 25, 26): 0.5813076057596235,
#  (2, 26, 78): 0.6325682808186844,
#  (3, 25, 78): 0.6376919552511473,
#  (2, 26, 80): 0.6431372309702534,
#  (3, 25, 80): 0.6440306064666632,
#  (2, 27, 27): 0.5251138752349743,
#  (3, 26, 27): 0.582175396704432,
#  (2, 27, 81): 0.6329491879890007,
#  (3, 26, 81): 0.6380589868954174,
#  (2, 27, 83): 0.6434930993486342,
#  (3, 26, 83): 0.6444297387021796,
#  (2, 28, 28): 0.5256858644409728,
#  (3, 27, 28): 0.5828712072018578,
#  (2, 28, 84): 0.6333982655030145,
#  (3, 27, 84): 0.6388404320458433,
#  (2, 28, 86): 0.6439339408531474,
#  (3, 27, 86): 0.6451290222156598,
#  (2, 29, 29): 0.5261190653101662,
#  (3, 28, 29): 0.5831610717370319,
#  (2, 29, 87): 0.6337884340494758,
#  (3, 28, 87): 0.6392850773298446,
#  (2, 29, 88): 0.6449055088252976,
#  (3, 28, 88): 0.644998916418991,
#  (2, 29, 89): 0.6443102007972193,
#  (3, 28, 89): 0.6455973005470034,
#  (2, 30, 30): 0.5268432387720368,
#  (3, 29, 30): 0.5837543951845078,
#  (2, 30, 90): 0.63421194355006,
#  (3, 29, 90): 0.6395496715386797,
#  (2, 30, 92): 0.6447714007910802,
#  (3, 29, 92): 0.645899006413106,
#  (2, 31, 31): 0.5275615907974732,
#  (3, 30, 31): 0.5843650506359125,
#  (2, 31, 93): 0.6345886665629393,
#  (3, 30, 93): 0.640241909791021,
#  (2, 31, 94): 0.6457147711805027,
#  (3, 30, 94): 0.645921002181451,
#  (2, 31, 95): 0.6453186488922336,
#  (3, 30, 95): 0.6465264150324307,
#  (2, 32, 32): 0.5279858610539553,
#  (3, 31, 32): 0.5845853886973108,
#  (2, 32, 96): 0.635051999980948,
#  (3, 31, 96): 0.6406006558112753,
#  (2, 32, 97): 0.6461740362082762,
#  (3, 31, 97): 0.646306424272638,
#  (2, 32, 98): 0.645574742480821,
#  (3, 31, 98): 0.6468801499866637,
#  (2, 33, 33): 0.5281335800034718,
#  (3, 32, 33): 0.5851356798220545,
#  (2, 33, 99): 0.6352244269589663,
#  (3, 32, 99): 0.6407475974667225,
#  (2, 33, 100): 0.6463518546302647,
#  (3, 32, 100): 0.6464238949061373,
#  (2, 34, 34): 0.5283821156475977,
#  (3, 33, 34): 0.5857237441309336,
#  (2, 35, 35): 0.5284957328870937,
#  (3, 34, 35): 0.5859061105501363,
#  (2, 36, 36): 0.5286972339709394,
#  (3, 35, 36): 0.5863498462346949,
#  (2, 37, 37): 0.5288185579984419,
#  (3, 36, 37): 0.5868146350118123,
#  (2, 38, 38): 0.5290239620908059,
#  (3, 37, 38): 0.5870175583784231,
#  (2, 39, 39): 0.5291136651340412,
#  (3, 38, 39): 0.5874601198527918,
#  (2, 40, 40): 0.5292680655049197,
#  (3, 39, 40): 0.5879006636702145,
#  (2, 41, 41): 0.5293537993869498,
#  (3, 40, 41): 0.5880250307213077,
#  (2, 42, 42): 0.5295149142555335,
#  (3, 41, 42): 0.5884515170927959,
#  (2, 43, 43): 0.5296025334891361,
#  (3, 42, 43): 0.5889065483486172,
#  (2, 44, 44): 0.5297588522879303,
#  (3, 43, 44): 0.58904100368444,
#  (2, 45, 45): 0.5298143874684583,
#  (3, 44, 45): 0.5894975068375417,
#  (2, 46, 46): 0.5299781484445122,
#  (3, 45, 46): 0.5899698039446054,
#  (3, 45, 47): 0.5976479643759843,
#  (2, 47, 47): 0.5300331874798896,
#  (3, 46, 47): 0.5905717768558739,
#  (3, 46, 48): 0.5985042612914698,
#  (2, 48, 48): 0.5301334749530051,
#  (3, 47, 48): 0.5909074355884519,
#  (3, 47, 49): 0.5986030107146184,
#  (2, 49, 49): 0.5302022075945402,
#  (3, 48, 49): 0.5910961361274111,
#  (3, 48, 50): 0.5987849967558723,
#  (2, 50, 50): 0.5303300145853443,
#  (3, 49, 50): 0.5911701775220579,
#  (3, 49, 51): 0.5989254058335026,
#  (2, 51, 51): 0.530385152849752,
#  (3, 50, 51): 0.5913320862228827,
#  (3, 50, 52): 0.5990053844317854,
#  (2, 52, 52): 0.5305056830450136,
#  (3, 51, 52): 0.5914818062911734,
#  (3, 51, 53): 0.5991632908950618,
#  (2, 53, 53): 0.5305588367288184,
#  (3, 52, 53): 0.5915376556969635,
#  (3, 52, 54): 0.5992909986568359,
#  (2, 18, 54): 0.6281354554321411,
#  (3, 18, 53): 0.6282727553334942,
#  (2, 54, 54): 0.5306651440964284,
#  (3, 53, 54): 0.5916624692786923,
#  (3, 53, 55): 0.5993634193106573,
#  (2, 55, 55): 0.5307288160574269,
#  (3, 54, 55): 0.5918032587342715,
#  (3, 54, 56): 0.599478690367322,
#  (2, 56, 56): 0.5308433925108808,
#  (3, 55, 56): 0.5918555193568054,
#  (3, 55, 57): 0.5995967232986587,
#  (2, 19, 57): 0.6287977430555555,
#  (3, 19, 56): 0.6300712318900404,
#  (2, 57, 57): 0.5308984976989449,
#  (3, 56, 57): 0.5919839713363054,
#  (3, 56, 58): 0.5996486531577588,
#  (2, 58, 58): 0.531019424810327,
#  (3, 57, 58): 0.5921011938972294,
#  (3, 57, 59): 0.5997754843964335,
#  (2, 59, 59): 0.5310688408673304,
#  (3, 58, 59): 0.5921501799617691,
#  (3, 58, 60): 0.5998798898742993,
#  (3, 20, 59): 0.6308086193510897,
#  (2, 60, 60): 0.5311653907136445,
#  (3, 59, 60): 0.5922371045921607,
#  (3, 59, 61): 0.5999254359991278,
#  (2, 61, 61): 0.5312331972175651,
#  (3, 60, 61): 0.5923383678174059,
#  (3, 60, 62): 0.6000335791037951,
#  (2, 62, 62): 0.5313585565589595,
#  (3, 61, 62): 0.5923812182202493,
#  (3, 61, 63): 0.6001316835382479,
#  (3, 21, 62): 0.6330898947537215,
#  (2, 63, 63): 0.5315653498577452,
#  (3, 62, 63): 0.5925049402826467,
#  (3, 62, 64): 0.6001830180231672,
#  (2, 64, 64): 0.5316609404901015,
#  (3, 63, 64): 0.5925977525021593,
#  (3, 63, 65): 0.6002796836366832,
#  (2, 65, 65): 0.531690378435706,
#  (3, 64, 65): 0.592631788059493,
#  (3, 64, 66): 0.6003744142841115,
#  (3, 22, 65): 0.6346719031810446,
#  (2, 66, 66): 0.5317385375916611,
#  (3, 65, 66): 0.5927241372101983,
#  (3, 65, 67): 0.6004132789875781,
#  (2, 67, 67): 0.5317613271922471,
#  (3, 66, 67): 0.5928214643505817,
#  (3, 66, 68): 0.6005093823032567,
#  (2, 68, 68): 0.5318062779428949,
#  (3, 67, 68): 0.5928686808307507,
#  (3, 67, 69): 0.600597067689546,
#  (3, 23, 68): 0.6353617433984912,
#  (2, 69, 69): 0.5318268845048181,
#  (3, 68, 69): 0.5929494532612746,
#  (3, 68, 70): 0.6006299621130332,
#  (2, 70, 70): 0.5318679983996342,
#  (3, 69, 70): 0.5930456061914681,
#  (3, 69, 71): 0.6007228404852326,
#  (2, 71, 71): 0.5318853634799066,
#  (3, 70, 71): 0.5930765987252112,
#  (3, 70, 72): 0.6007995941400363,
#  (3, 24, 71): 0.6368715792445682,
#  (2, 72, 72): 0.5319251873973311,
#  (3, 71, 72): 0.5931494493714966,
#  (3, 71, 73): 0.600835432358084,
#  (2, 73, 73): 0.5319396086830429,
#  (3, 72, 73): 0.5932231434645379,
#  (3, 72, 74): 0.6009037846216702,
#  (2, 74, 74): 0.5319769849510576,
#  (3, 73, 74): 0.5932469749699402,
#  (3, 73, 75): 0.6009758414357144,
#  (3, 25, 74): 0.637481490478247,
#  (2, 75, 75): 0.5319899508776609,
#  (3, 74, 75): 0.5933288389197955,
#  (3, 74, 76): 0.600999127181451,
#  (2, 76, 76): 0.5320250779543261,
#  (3, 75, 76): 0.5934025495510085,
#  (3, 75, 77): 0.6010797838447729,
#  (2, 77, 77): 0.5320406899883995,
#  (3, 76, 77): 0.5934319544202696,
#  (3, 76, 78): 0.6011526014147149,
#  (3, 26, 77): 0.6378954574537672,
#  (2, 78, 78): 0.5320778016456672,
#  (3, 77, 78): 0.5934982559505665,
#  (3, 77, 79): 0.6011803855431506,
#  (2, 79, 79): 0.5320866991820353,
#  (3, 78, 79): 0.5935844198250606,
#  (3, 78, 80): 0.601249680482523,
#  (2, 80, 80): 0.5321167325018205,
#  (3, 79, 80): 0.5935997672483869,
#  (3, 79, 81): 0.6013253922325102,
#  (3, 27, 80): 0.6386029439004047,
#  (2, 81, 81): 0.5321278792295382,
#  (3, 80, 81): 0.5936775793461786,
#  (3, 80, 82): 0.6013561366936782,
#  (2, 82, 82): 0.5321571517934258,
#  (3, 81, 82): 0.5937518688134007,
#  (3, 81, 83): 0.601426787763129,
#  (2, 83, 83): 0.5321697869565954,
#  (3, 82, 83): 0.5937740134252909,
#  (3, 82, 84): 0.6014979184395587,
#  (3, 28, 83): 0.6390618120120578,
#  (2, 84, 84): 0.5322013748645192,
#  (3, 83, 84): 0.5938440691205609,
#  (3, 83, 85): 0.6015204268912259,
#  (2, 85, 85): 0.5322126208212671,
#  (3, 84, 85): 0.5939187058893884,
#  (3, 84, 86): 0.6015962874847584,
#  (2, 86, 86): 0.5322408018658233,
#  (3, 85, 86): 0.5939462915597639,
#  (3, 85, 87): 0.6016669550923809,
#  (3, 29, 86): 0.6394178126958119,
#  (2, 87, 87): 0.532251948593541,
#  (3, 86, 87): 0.5940234421306881,
#  (3, 86, 88): 0.601684650936087,
#  (2, 88, 88): 0.5322755651027112,
#  (3, 87, 88): 0.5940922243867381,
#  (3, 87, 89): 0.6017641830037341,
#  (2, 89, 89): 0.5322872410519229,
#  (3, 88, 89): 0.5941109952116039,
#  (3, 88, 90): 0.6018371328790496,
#  (3, 30, 89): 0.6400308661821116,
#  (2, 90, 90): 0.5323146613405815,
#  (3, 89, 90): 0.5941841270068079,
#  (3, 89, 91): 0.6018690019358922,
#  (2, 91, 91): 0.5323265357478535,
#  (3, 90, 91): 0.5942605664363495,
#  (3, 90, 92): 0.6019353200043608,
#  (2, 92, 92): 0.5323509791656083,
#  (3, 91, 92): 0.5942813383799895,
#  (3, 91, 93): 0.6020062026082151,
#  (3, 31, 92): 0.6404354725524564,
#  (2, 93, 93): 0.5323607366869041,
#  (3, 92, 93): 0.5943591835541245,
#  (3, 92, 94): 0.6020233692304272,
#  (2, 94, 94): 0.532385014722942,
#  (3, 93, 94): 0.5944335226358617,
#  (3, 93, 95): 0.6021049851077072,
#  (2, 95, 95): 0.5323954668474488,
#  (3, 94, 95): 0.5946310545585023,
#  (3, 94, 96): 0.6023667182128402,
#  (3, 32, 95): 0.6407084350761655,
#  (2, 96, 96): 0.5324148826610103,
#  (3, 95, 96): 0.5947102558627156,
#  (3, 95, 97): 0.6023858198011397,
#  (2, 97, 97): 0.5324242763425291,
#  (3, 96, 97): 0.5947447048743416,
#  (3, 96, 98): 0.6024215422519856,
#  (2, 98, 98): 0.5324444859883317,
#  (3, 97, 98): 0.5947557192966858,
#  (3, 97, 99): 0.6024459691315688,
#  (3, 33, 98): 0.6412241118075667,
#  (2, 99, 99): 0.532454276585971,
#  (3, 98, 99): 0.5947932940227607,
#  (3, 98, 100): 0.6024601919592203,
#  (2, 100, 100): 0.5324711785974361,
#  (3, 99, 100): 0.594818828959847,
#  (3, 7, 7): 0.44019443200773933,
#  (4, 6, 7): 0.45015962312549745,
#  (3, 8, 8): 0.4467808250351403,
#  (4, 7, 8): 0.4742427237336788,
#  (3, 9, 9): 0.4693452418753916,
#  (4, 8, 9): 0.49163882961608163,
#  (3, 10, 10): 0.47808047262654746,
#  (4, 9, 10): 0.4967868813136124,
#  (3, 11, 11): 0.48470119889837254,
#  (4, 10, 11): 0.502631388497265,
#  (3, 12, 12): 0.49122878218725124,
#  (4, 11, 12): 0.5167916853217244,
#  (3, 13, 13): 0.4935336740990533,
#  (4, 12, 13): 0.5312539030085183,
#  (3, 14, 14): 0.4956136137995563,
#  (4, 13, 14): 0.5362733208066606,
#  (3, 15, 15): 0.5004434876119833,
#  (4, 14, 15): 0.5434280646422885,
#  (3, 16, 16): 0.5020230153135531,
#  (4, 15, 16): 0.5478861768933428,
#  (3, 17, 17): 0.5030273123274739,
#  (4, 16, 17): 0.5516700278846806,
#  (3, 17, 51): 0.615492767394452,
#  (4, 16, 51): 0.6161914720719234,
#  (3, 18, 18): 0.506093654740131,
#  (4, 17, 18): 0.5534884163999391,
#  (3, 18, 54): 0.6177887948462294,
#  (4, 17, 54): 0.6190445216843214,
#  (3, 19, 19): 0.5081359535618724,
#  (4, 18, 19): 0.5547300196394097,
#  (3, 19, 57): 0.6196168251155819,
#  (4, 18, 57): 0.6206401410269438,
#  (3, 20, 20): 0.5092737466976579,
#  (4, 19, 20): 0.5579425760279598,
#  (3, 20, 60): 0.6203943672574895,
#  (4, 19, 60): 0.6215706116424494,
#  (3, 21, 21): 0.5131205254322682,
#  (4, 20, 21): 0.560842097902801,
#  (3, 21, 63): 0.6225665568796677,
#  (4, 20, 63): 0.6242344480325662,
#  (3, 22, 22): 0.5144697094785687,
#  (4, 21, 22): 0.5619077515336839,
#  (3, 22, 66): 0.624324547991922,
#  (4, 21, 66): 0.6264198516539231,
#  (3, 23, 23): 0.5164820742095548,
#  (4, 22, 23): 0.5623249765290268,
#  (3, 23, 69): 0.6249592168686177,
#  (4, 22, 69): 0.6269802310633965,
#  (3, 24, 24): 0.5177187986883774,
#  (4, 23, 24): 0.5647878741331352,
#  (3, 24, 72): 0.6264351494627344,
#  (4, 23, 72): 0.6274335588875342,
#  (3, 25, 25): 0.518164866255144,
#  (4, 24, 25): 0.5672480925534301,
#  (3, 25, 75): 0.6270372712175482,
#  (4, 24, 75): 0.6295931629610577,
#  (3, 26, 26): 0.5187485975630408,
#  (4, 25, 26): 0.5679596473903029,
#  (3, 26, 78): 0.6274313096961844,
#  (4, 25, 78): 0.6313052441087063,
#  (3, 27, 27): 0.5198030383135193,
#  (4, 26, 27): 0.5688839492677692,
#  (3, 27, 81): 0.6281354554321411,
#  (4, 26, 81): 0.6318541625652001,
#  (3, 28, 28): 0.5200221029356974,
#  (4, 27, 28): 0.571275650042761,
#  (3, 28, 84): 0.6286252830011939,
#  (4, 27, 84): 0.6323139071999525,
#  (3, 29, 29): 0.5204572222328067,
#  (4, 28, 29): 0.5737307747061763,
#  (3, 29, 87): 0.6289591721494013,
#  (4, 28, 87): 0.6344316035464191,
#  (3, 30, 30): 0.521353326527545,
#  (4, 29, 30): 0.5746018071326356,
#  (3, 30, 90): 0.6295677107148301,
#  (4, 29, 90): 0.636175140296618,
#  (4, 29, 93): 0.6410474510575962,
#  (3, 31, 31): 0.5216136373499127,
#  (4, 30, 31): 0.5765721483693628,
#  (3, 31, 93): 0.6299875487412996,
#  (4, 30, 93): 0.6364735716047266,
#  (4, 30, 96): 0.6419747628823096,
#  (3, 32, 32): 0.5218702105454792,
#  (4, 31, 32): 0.57749606986888,
#  (3, 32, 96): 0.6301997334840557,
#  (4, 31, 96): 0.6374555090105252,
#  (3, 32, 98): 0.6418308477122813,
#  (4, 31, 98): 0.64189207202387,
#  (4, 31, 99): 0.6423986858371861,
#  (3, 33, 33): 0.5225738105217701,
#  (4, 32, 33): 0.5782692459334621,
#  (3, 33, 99): 0.630719892059984,
#  (4, 32, 99): 0.6381510714353757,
#  (3, 34, 34): 0.5229414210020491,
#  (4, 33, 34): 0.5785625834846907,
#  (3, 35, 35): 0.5230813339345289,
#  (4, 34, 35): 0.5789247529064845,
#  (4, 34, 36): 0.586367542078401,
#  (3, 36, 36): 0.5237380978085997,
#  (4, 35, 36): 0.5796576089084913,
#  (3, 37, 37): 0.5239908341483345,
#  (4, 36, 37): 0.5802491462334248,
#  (4, 36, 38): 0.5873462049262054,
#  (3, 38, 38): 0.5241945844235296,
#  (4, 37, 38): 0.5804661601223137,
#  (4, 37, 39): 0.58762088741977,
#  (3, 39, 39): 0.5248276325593998,
#  (4, 38, 39): 0.5806532895349625,
#  (4, 38, 40): 0.5880847500592729,
#  (3, 40, 40): 0.5250622099866212,
#  (4, 39, 40): 0.5812160504411591,
#  (4, 39, 41): 0.5883475912219089,
#  (3, 41, 41): 0.5251781094938103,
#  (4, 40, 41): 0.581744395412073,
#  (4, 40, 42): 0.588833317324383,
#  (3, 42, 42): 0.5256858644409728,
#  (4, 41, 42): 0.5820000755463682,
#  (4, 41, 43): 0.5890965057886247,
#  (3, 43, 43): 0.5260332321991058,
#  (4, 42, 43): 0.5820988084313451,
#  (4, 42, 44): 0.5895697621096462,
#  (3, 44, 44): 0.5262173020499924,
#  (4, 43, 44): 0.5826556321339057,
#  (4, 43, 45): 0.5897379057011973,
#  (3, 45, 45): 0.5268432387720368,
#  (4, 44, 45): 0.5831276480920508,
#  (4, 44, 46): 0.5902254013880421,
#  (3, 46, 46): 0.5271012011740249,
#  (4, 45, 46): 0.583270240208344,
#  (3, 47, 47): 0.5277467521676913,
#  (4, 46, 47): 0.5834219779335806,
#  (3, 48, 48): 0.5279858610539553,
#  (4, 47, 48): 0.583798849790005,
#  (3, 49, 49): 0.5280672950113465,
#  (4, 48, 49): 0.58421129525373,
#  (4, 48, 50): 0.5913062701368778,
#  (3, 50, 50): 0.5281774061584447,
#  (4, 49, 50): 0.5844009880829905,
#  (4, 49, 51): 0.5914750587171248,
#  (4, 17, 50): 0.6165013477948399,
#  (3, 51, 51): 0.5283821156475977,
#  (4, 50, 51): 0.5845099911725855,
#  (4, 50, 52): 0.5918398411700453,
#  (3, 52, 52): 0.5284536267019764,
#  (4, 51, 52): 0.5848932467632814,
#  (4, 51, 53): 0.5920035690697556,
#  (3, 53, 53): 0.5285409151721452,
#  (4, 52, 53): 0.5853034761120002,
#  (4, 52, 54): 0.5923164712780911,
#  (4, 18, 53): 0.6181123476371319,
#  (3, 54, 54): 0.5286972339709394,
#  (4, 53, 54): 0.5854581080172822,
#  (4, 53, 55): 0.5925202546296297,
#  (3, 55, 55): 0.5287723172704025,
#  (4, 54, 55): 0.5854904070665887,
#  (4, 54, 56): 0.5928632397722654,
#  (3, 56, 56): 0.528849186692408,
#  (4, 55, 56): 0.585891077352072,
#  (4, 55, 57): 0.5930314164401599,
#  (3, 57, 57): 0.5290239620908059,
#  (4, 56, 57): 0.5862959648713356,
#  (4, 56, 58): 0.593397753481219,
#  (3, 58, 58): 0.529078174217599,
#  (4, 57, 58): 0.5864241191637455,
#  (4, 57, 59): 0.5935495408209707,
#  (3, 59, 59): 0.5291300048476689,
#  (4, 58, 59): 0.5865677035703398,
#  (4, 58, 60): 0.5938409764824553,
#  (4, 20, 59): 0.6220633830060628,
#  (3, 60, 60): 0.5292680655049197,
#  (4, 59, 60): 0.5869693992224677,
#  (4, 59, 61): 0.5940510939537503,
#  (3, 61, 61): 0.5293283636788938,
#  (4, 60, 61): 0.5873862934543769,
#  (4, 60, 62): 0.5944358379798981,
#  (3, 62, 62): 0.5293856188292774,
#  (4, 61, 62): 0.5875231799014378,
#  (4, 61, 63): 0.5950046353187607,
#  (4, 21, 62): 0.6242603302712578,
#  (3, 63, 63): 0.5295149142555335,
#  (4, 62, 63): 0.5881961511837626,
#  (4, 62, 64): 0.5953108064912191,
#  (3, 64, 64): 0.5295760062617487,
#  (4, 63, 64): 0.5883510807761351,
#  (4, 63, 65): 0.5954003937672526,
#  (3, 65, 65): 0.5296215523865772,
#  (4, 64, 65): 0.5884918206171993,
#  (4, 64, 66): 0.5955452681512389,
#  (4, 22, 65): 0.6248344032868888,
#  (3, 66, 66): 0.5297588522879303,
#  (4, 65, 66): 0.5885713692230182,
#  (4, 65, 67): 0.5956124131282917,
#  (3, 67, 67): 0.5298012561601383,
#  (4, 66, 67): 0.5886375219097698,
#  (4, 66, 68): 0.5957485718957984,
#  (3, 68, 68): 0.529846471521533,
#  (4, 67, 68): 0.5887764094756051,
#  (4, 67, 69): 0.5958102427380226,
#  (4, 23, 68): 0.6256472213490067,
#  (3, 69, 69): 0.5299781484445122,
#  (4, 68, 69): 0.5889008426793849,
#  (4, 68, 70): 0.5959310706203745,
#  (3, 70, 70): 0.5300216107597081,
#  (4, 69, 70): 0.5889561794018526,
#  (4, 69, 71): 0.5959897480535233,
#  (3, 71, 71): 0.5300431103829023,
#  (4, 70, 71): 0.5889931587537468,
#  (4, 70, 72): 0.5961088063515048,
#  (4, 24, 71): 0.6278304253935291,
#  (3, 72, 72): 0.5301334749530051,
#  (4, 71, 72): 0.5891061971572339,
#  (4, 71, 73): 0.596151656754348,
#  (3, 73, 73): 0.5301830563917255,
#  (4, 72, 73): 0.5892122399140968,
#  (4, 72, 74): 0.5962632397987264,
#  (3, 74, 74): 0.5302213918736981,
#  (4, 73, 74): 0.5892634255554708,
#  (4, 73, 75): 0.5963052632929854,
#  (4, 25, 74): 0.6295195515588748,
#  (3, 75, 75): 0.5303300145853443,
#  (4, 74, 75): 0.5893170257699115,
#  (4, 74, 76): 0.5964045750139714,
#  (3, 76, 76): 0.5303685816017206,
#  (4, 75, 76): 0.5894298161008231,
#  (4, 75, 77): 0.5964538256892581,
#  (3, 77, 77): 0.530398449539789,
#  (4, 76, 77): 0.5895255886530678,
#  (4, 76, 78): 0.5965617868740368,
#  (4, 26, 77): 0.6298821178967892,
#  (3, 78, 78): 0.5305056830450136,
#  (4, 77, 78): 0.5895662560172484,
#  (4, 77, 79): 0.5965969635652171,
#  (3, 79, 79): 0.5305416701066065,
#  (4, 78, 79): 0.5895925020957171,
#  (4, 78, 80): 0.5966842851117292,
#  (3, 80, 80): 0.5305744818392352,
#  (4, 79, 80): 0.5896747464235211,
#  (4, 79, 81): 0.5967190152722739,
#  (4, 27, 80): 0.6305618532913343,
#  (3, 81, 81): 0.5306651440964284,
#  (4, 80, 81): 0.5897592564808464,
#  (4, 80, 82): 0.5968058406736355,
#  (3, 82, 82): 0.5307149570695524,
#  (4, 81, 82): 0.5898063737319853,
#  (4, 81, 83): 0.5968468057249064,
#  (3, 83, 83): 0.5307373497540179,
#  (4, 82, 83): 0.5898409219726414,
#  (4, 82, 84): 0.5969399487078528,
#  (4, 28, 83): 0.632644984858973,
#  (3, 84, 84): 0.5308433925108808,
#  (4, 83, 84): 0.5899515788794052,
#  (4, 83, 85): 0.5969784495715423,
#  (3, 85, 85): 0.5308807357025521,
#  (4, 84, 85): 0.590039297342038,
#  (4, 84, 86): 0.5970633565449881,
#  (3, 86, 86): 0.5309161604663076,
#  (4, 85, 86): 0.5900632776909854,
#  (4, 85, 87): 0.5971014439543854,
#  (4, 29, 86): 0.6341472958369321,
#  (3, 87, 87): 0.531019424810327,
#  (4, 86, 87): 0.5900916241172586,
#  (4, 86, 88): 0.5971704908211825,
#  (3, 88, 88): 0.5310544195816186,
#  (4, 87, 88): 0.5901717184827432,
#  (4, 87, 89): 0.5972081978526308,
#  (3, 89, 89): 0.5310768122660842,
#  (4, 88, 89): 0.5902565427653305,
#  (4, 88, 90): 0.5972896979627089,
#  (4, 30, 89): 0.6345409208612762,
#  (3, 90, 90): 0.5311653907136445,
#  (4, 89, 90): 0.5902962343773815,
#  (4, 89, 91): 0.597325304646353,
#  (3, 91, 91): 0.5312151706104252,
#  (4, 90, 91): 0.5903176513097174,
#  (4, 90, 92): 0.5973977583765179,
#  (3, 92, 92): 0.5312498676946266,
#  (4, 91, 92): 0.5904037490315247,
#  (4, 91, 93): 0.5974274443946976,
#  (4, 31, 92): 0.6350845636410015,
#  (3, 93, 93): 0.5313585565589595,
#  (4, 92, 93): 0.5904832480228285,
#  (4, 92, 94): 0.597498806605531,
#  (3, 94, 94): 0.5313904421539738,
#  (4, 93, 94): 0.5905108667695473,
#  (4, 93, 95): 0.5975329083155515,
#  (3, 95, 95): 0.5316191650684178,
#  (4, 94, 95): 0.590518887782816,
#  (4, 94, 96): 0.5975902130804501,
#  (4, 32, 95): 0.6364357157297329,
#  (3, 96, 96): 0.5316609404901015,
#  (4, 95, 96): 0.5905898365393571,
#  (4, 95, 97): 0.5976202960147504,
#  (3, 97, 97): 0.5316739725693914,
#  (4, 96, 97): 0.5906563199895426,
#  (4, 96, 98): 0.5976821983913784,
#  (3, 98, 98): 0.5317002351860319,
#  (4, 97, 98): 0.5906784149869176,
#  (4, 97, 99): 0.5977121324821334,
#  (4, 33, 98): 0.6369774566197142,
#  (3, 99, 99): 0.5317385375916611,
#  (4, 98, 99): 0.5907043468401243,
#  (4, 98, 100): 0.5977623423713782,
#  (3, 100, 100): 0.53174793127318,
#  (4, 99, 100): 0.5907712272064303,
#  (4, 6, 6): 0.38529044734034446,
#  (5, 5, 6): 0.3960503141458788,
#  (4, 7, 7): 0.4024199248187945,
#  (5, 6, 7): 0.42052775091978695,
#  (4, 8, 8): 0.4285657819670951,
#  (5, 7, 8): 0.43856474403143997,
#  (4, 9, 9): 0.4379673356555573,
#  (5, 8, 9): 0.45166674671141765,
#  (4, 10, 10): 0.4425199304814645,
#  (5, 9, 10): 0.47425496198072786,
#  (4, 11, 11): 0.44806372408931566,
#  (5, 10, 11): 0.4900424495175617,
#  (4, 12, 12): 0.4693452418753916,
#  (5, 11, 12): 0.4940311588415976,
#  (4, 13, 13): 0.47675533508188117,
#  (5, 12, 13): 0.4998499491682755,
#  (4, 14, 14): 0.48208386784704227,
#  (5, 13, 14): 0.5030468273700656,
#  (4, 15, 15): 0.4852509608016224,
#  (5, 14, 15): 0.5158300733289302,
#  (4, 16, 16): 0.49122878218725124,
#  (5, 15, 16): 0.5299008986445578,
#  (4, 17, 17): 0.49264620272993614,
#  (5, 16, 17): 0.5345106990063337,
#  (4, 17, 51): 0.606547849164465,
#  (5, 16, 51): 0.6068501173284052,
#  (4, 18, 18): 0.494262775936087,
#  (5, 17, 18): 0.5398539672824688,
#  (4, 18, 54): 0.6085029752832394,
#  (5, 17, 54): 0.6086456500903911,
#  (4, 19, 19): 0.4959453033709292,
#  (5, 18, 19): 0.543222478630036,
#  (4, 19, 57): 0.6093778611037021,
#  (5, 18, 57): 0.6110883711250402,
#  (4, 20, 20): 0.5004434876119833,
#  (5, 19, 20): 0.5470177244216667,
#  (4, 20, 60): 0.6124243742485055,
#  (5, 19, 60): 0.6127122872794205,
#  (4, 21, 21): 0.501754931550492,
#  (5, 20, 21): 0.5505264463888041,
#  (4, 21, 63): 0.614252404517858,
#  (5, 20, 63): 0.6159845133914207,
#  (4, 22, 22): 0.5025522368075666,
#  (5, 21, 22): 0.5517973221921625,
#  (4, 22, 66): 0.6150826703511068,
#  (5, 21, 66): 0.6187561455845992,
#  (4, 23, 23): 0.5031675890997307,
#  (5, 22, 23): 0.5531504092469813,
#  (4, 23, 69): 0.6156283473259496,
#  (5, 22, 69): 0.6198103713388458,
#  (4, 24, 24): 0.506093654740131,
#  (5, 23, 24): 0.5539436130374774,
#  (4, 24, 72): 0.6177887948462294,
#  (5, 23, 72): 0.6206770046116361,
#  (4, 25, 25): 0.5079278041330082,
#  (5, 24, 25): 0.5569707103687193,
#  (4, 25, 75): 0.619438130170494,
#  (5, 24, 75): 0.6214497341455826,
#  (4, 26, 26): 0.5085600915129808,
#  (5, 25, 26): 0.5597136488340192,
#  (4, 26, 78): 0.6200700371725177,
#  (5, 25, 78): 0.6240545788772883,
#  (4, 27, 27): 0.5094988642906738,
#  (5, 26, 27): 0.5606478239999831,
#  (4, 27, 81): 0.6205027253583889,
#  (5, 26, 81): 0.6261406211631442,
#  (4, 28, 28): 0.5131205254322682,
#  (5, 27, 28): 0.5612278672955936,
#  (4, 28, 84): 0.6225665568796677,
#  (5, 27, 84): 0.6265492628473809,
#  (4, 29, 29): 0.5143106453432743,
#  (5, 28, 29): 0.5613912478936984,
#  (4, 29, 87): 0.6242289738977375,
#  (5, 28, 87): 0.626946129353376,
#  (4, 30, 30): 0.5156899950147334,
#  (5, 29, 30): 0.5637915319797965,
#  (4, 30, 90): 0.6246810778971702,
#  (5, 29, 90): 0.6272628022648563,
#  (4, 31, 31): 0.5166124611551424,
#  (5, 30, 31): 0.566074510814112,
#  (4, 31, 93): 0.6255271046080374,
#  (5, 30, 93): 0.6294413425449626,
#  (4, 32, 32): 0.5177187986883774,
#  (5, 31, 32): 0.5665562016026944,
#  (4, 32, 96): 0.6264351494627344,
#  (5, 31, 96): 0.6310857660322359,
#  (4, 33, 33): 0.5180689779356974,
#  (5, 32, 33): 0.5674294005296449,
#  (4, 33, 99): 0.626903626252138,
#  (5, 32, 99): 0.6314149087251689,
#  (4, 34, 34): 0.5183972606437027,
#  (5, 33, 34): 0.5680504584910413,
#  (4, 35, 35): 0.5188368121708242,
#  ...}

# %%
exportStateProbs(DATA_DIR + 'game1_better_giving_1_to_another_memo_1-100.csv', betterGiving1ToAnother)

# %%
betterGiving1ToAnother, given1ToAnother = readApproxBetterGiving1Probs(DATA_DIR + 'game1_better_giving_1_to_another_memo_1-100.csv')

# %%
betterGiving1ToAnother, given1ToAnother = stricterFilter(betterGiving1ToAnother, printOnGo=True,
                                                         filename=DATA_DIR + 'game1_better_giving_1_to_another_stricter_1-100.csv',
                                                         giveToAnother=True, continueFrom=(66,86,87))
# Out:
# Approximating hitting prob for (65, 88, 88)
# (65, 88, 88): 0.374252748708161
# (64, 89, 88): 0.4209049376472573
#
# Approximating hitting prob for (65, 89, 89)
# (65, 89, 89): 0.3747350148503575
# (64, 90, 89): 0.42162170955430317
#
# Approximating hitting prob for (66, 18, 89)
# (66, 18, 89): 0.2822575115650746
# (65, 19, 89): 0.2835474750989972
#
# Approximating hitting prob for (66, 45, 89)
# (66, 45, 89): 0.3249431637635349
# (65, 46, 89): 0.32612028895283934
#
# Approximating hitting prob for (66, 54, 89)
# (66, 54, 89): 0.34013756056831634
# (65, 55, 89): 0.3425498641724051
#
# Approximating hitting prob for (66, 89, 90)
# (66, 89, 90): 0.41985354288415105
# (65, 90, 90): 0.3753429470450169
#
# Approximating hitting prob for (66, 90, 91)
# (66, 90, 91): 0.42024780934886435
# (65, 91, 91): 0.3763374877370375
#
# Approximating hitting prob for (65, 92, 92)
# (65, 92, 92): 0.37675442937328735
# (64, 93, 92): 0.4235236724612584
#
# Approximating hitting prob for (65, 14, 93)
# (65, 14, 93): 0.2772377446852446
# (64, 15, 93): 0.2807715095155967
#
# Approximating hitting prob for (66, 31, 92)
# (66, 31, 92): 0.3011806936641607
# (65, 32, 92): 0.30250038504700594
#
# Approximating hitting prob for (66, 92, 93)
# (66, 92, 93): 0.42179878387159525
# (65, 93, 93): 0.37725438154243535
#
# Approximating hitting prob for (65, 94, 94)
# (65, 94, 94): 0.3775606113856677
# (64, 95, 94): 0.42461475238953783
#
# Approximating hitting prob for (66, 19, 94)
# (66, 19, 94): 0.28521409802718756
# (65, 20, 94): 0.2871310433169208
#
# Approximating hitting prob for (66, 57, 94)
# (66, 57, 94): 0.34596015812993075
# (65, 58, 94): 0.3471160560241026
#
# Approximating hitting prob for (66, 60, 94)
# (66, 60, 94): 0.34916421256365865
# (65, 61, 94): 0.3512232000217908
#
# Approximating hitting prob for (66, 94, 95)
# (66, 94, 95): 0.4229898946109021
# (65, 95, 95): 0.37789266461611076
#
# Approximating hitting prob for (66, 16, 95)
# (66, 16, 95): 0.28084398814883776
# (65, 17, 95): 0.2844064266017623
#
# Approximating hitting prob for (66, 48, 95)
# (66, 48, 95): 0.32972387902209427
# (65, 49, 95): 0.331679824918738
#
# Approximating hitting prob for (66, 95, 96)
# (66, 95, 96): 0.42355127855076863
# (65, 96, 96): 0.3780983515690621
#
# Approximating hitting prob for (66, 96, 97)
# (66, 96, 97): 0.42401010885256146
# (65, 97, 97): 0.3782214673104097
#
# Approximating hitting prob for (66, 14, 97)
# (66, 14, 97): 0.27927538841960314
# (65, 15, 97): 0.28101656999976765
#
# Approximating hitting prob for (65, 98, 98)
# (65, 98, 98): 0.3923838875623842
# (64, 99, 98): 0.44445301438863405
#
# Approximating hitting prob for (66, 68, 98)
# (66, 68, 98): 0.4216302579212323
# (65, 69, 98): 0.4229558971689616
#
# Approximating hitting prob for (66, 98, 99)
# (66, 98, 99): 0.42608027240465113
# (65, 99, 99): 0.39249987432036054
#
# Approximating hitting prob for (66, 20, 99)
# (66, 20, 99): 0.28985320532217806
# (65, 21, 99): 0.29193834618592507
#
# Approximating hitting prob for (65, 100, 100)
# (65, 100, 100): 0.39271394324000525
# (64, 101, 100): 0.44516652874821067
#
# Approximating hitting prob for (66, 2, 70)
# (66, 2, 70): 0.24810783591586824
# (65, 3, 70): 0.2494298706581015
#
# Approximating hitting prob for (66, 2, 71)
# (66, 2, 71): 0.24838341044105736
# (65, 3, 71): 0.24960868663612482
#
# Approximating hitting prob for (66, 3, 73)
# (66, 3, 73): 0.2497930362201832
# (65, 4, 73): 0.25090054036902937
#
# Approximating hitting prob for (66, 3, 74)
# (66, 3, 74): 0.2500229768095539
# (65, 4, 74): 0.2513022701747032
#
# Approximating hitting prob for (66, 4, 4)
# (66, 4, 4): 0.0037627196902199453
# (65, 5, 4): 0.007083349891739473
#
# Approximating hitting prob for (66, 4, 76)
# (66, 4, 76): 0.2513587634384788
# (65, 5, 76): 0.2539705565556824
#
# Approximating hitting prob for (66, 4, 77)
# (66, 4, 77): 0.25166099069193243
# (65, 5, 77): 0.2542742060401079
#
# Approximating hitting prob for (66, 6, 6)
# (66, 6, 6): 0.008311748388415632
# (65, 7, 6): 0.013899634544402193
#
# Approximating hitting prob for (66, 6, 12)
# (66, 6, 12): 0.022818341016959277
# (65, 7, 12): 0.02700331076060677
#
# Approximating hitting prob for (66, 7, 7)
# (66, 7, 7): 0.011355696634960463
# (65, 8, 7): 0.01702686160685277
#
# Approximating hitting prob for (66, 7, 14)
# (66, 7, 14): 0.026111950922844986
# (65, 8, 14): 0.0354753126196855
#
# Approximating hitting prob for (66, 8, 8)
# (66, 8, 8): 0.013302534622365343
# (65, 9, 8): 0.02288103869060477
#
# Approximating hitting prob for (66, 8, 16)
# (66, 8, 16): 0.034665826906052626
# (65, 9, 16): 0.04127005287727721
#
# Approximating hitting prob for (66, 8, 24)
# (66, 8, 24): 0.06603024512355089
# (65, 9, 24): 0.07248837559420884
#
# Approximating hitting prob for (66, 8, 88)
# (66, 8, 88): 0.2609158623135371
# (65, 9, 88): 0.26374162957829816
#
# Approximating hitting prob for (66, 8, 89)
# (66, 8, 89): 0.26151280348859024
# (65, 9, 89): 0.2638955819915345
#
# Approximating hitting prob for (66, 9, 9)
# (66, 9, 9): 0.0190724324367984
# (65, 10, 9): 0.027537255591464735
#
# Approximating hitting prob for (66, 9, 18)
# (66, 9, 18): 0.03947938296263899
# (65, 10, 18): 0.04894074940964488
#
# Approximating hitting prob for (66, 9, 27)
# (66, 9, 27): 0.07581105790761088
# (65, 10, 27): 0.08288933130489601
#
# Approximating hitting prob for (66, 9, 36)
# (66, 9, 36): 0.08978787333833338
# (65, 10, 36): 0.10394100076555135
#
# Approximating hitting prob for (66, 10, 10)
# (66, 10, 10): 0.024491244155323565
# (65, 11, 10): 0.03236896884116541
#
# Approximating hitting prob for (66, 11, 11)
# (66, 11, 11): 0.02913548107169975
# (65, 12, 11): 0.04369922226968334
#
# Approximating hitting prob for (67, 6, 11)
# (67, 6, 11): 0.02382576734089646
# (66, 7, 11): 0.025424512249169206
#
# Approximating hitting prob for (67, 11, 12)
# (67, 11, 12): 0.03953788581294416
# (66, 12, 12): 0.032266554720203344
#
# Approximating hitting prob for (67, 11, 24)
# (67, 11, 24): 0.07609138145641313
# (66, 12, 24): 0.07399488327240887
#
# Approximating hitting prob for (67, 11, 36)
# (67, 11, 36): 0.1037796897922238
# (66, 12, 36): 0.10322323405706628
#
# Approximating hitting prob for (67, 12, 13)
# (67, 12, 13): 0.045949100817777026
# (66, 13, 13): 0.034028597100016565
#
# Approximating hitting prob for (67, 12, 26)
# (67, 12, 26): 0.08038776546592159
# (66, 13, 26): 0.07562194394952915
#
# Approximating hitting prob for (67, 12, 39)
# (67, 12, 39): 0.11035326257313798
# (66, 13, 39): 0.10889773696106102
#
# Approximating hitting prob for (67, 12, 52)
# (67, 12, 52): 0.13155937147323937
# (66, 13, 52): 0.1311883175663253
#
# Approximating hitting prob for (67, 12, 78)
# (67, 12, 78): 0.2550858490692745
# (66, 13, 78): 0.2545891964202694
#
# Approximating hitting prob for (66, 14, 14)
# (66, 14, 14): 0.036585521432283274
# (65, 15, 14): 0.05295434729935366
#
# Approximating hitting prob for (66, 14, 42)
# (66, 14, 42): 0.1193992386642135
# (65, 15, 42): 0.126905086258388
#
# Approximating hitting prob for (66, 15, 15)
# (66, 15, 15): 0.03954932744224995
# (65, 16, 15): 0.05602841893185179
#
# Approximating hitting prob for (66, 15, 30)
# (66, 15, 30): 0.0978355973002278
# (65, 16, 30): 0.10908224195595541
#
# Approximating hitting prob for (66, 15, 45)
# (66, 15, 45): 0.12475685864844742
# (65, 16, 45): 0.13323480379594382
#
# Approximating hitting prob for (67, 8, 15)
# (67, 8, 15): 0.03584232662645425
# (66, 9, 15): 0.037702778532046614
#
# Approximating hitting prob for (67, 15, 16)
# (67, 15, 16): 0.05452926295500449
# (66, 16, 16): 0.04179690754303767
#
# Approximating hitting prob for (67, 15, 32)
# (67, 15, 32): 0.108268475561117
# (66, 16, 32): 0.10162400172632408
#
# Approximating hitting prob for (67, 15, 48)
# (67, 15, 48): 0.1321870630083106
# (66, 16, 48): 0.12774469680441572
#
# Approximating hitting prob for (67, 15, 80)
# (67, 15, 80): 0.2605221463879547
# (66, 16, 80): 0.260203280217423
#
# Approximating hitting prob for (67, 16, 17)
# (67, 16, 17): 0.062278899355923366
# (66, 17, 17): 0.059023498449727985
#
# Approximating hitting prob for (67, 16, 34)
# (67, 16, 34): 0.11156131121677905
# (66, 17, 34): 0.10758753415677684
#
# Approximating hitting prob for (66, 18, 18)
# (66, 18, 18): 0.06081596070063703
# (65, 19, 18): 0.07774309865876801
#
# Approximating hitting prob for (66, 18, 36)
# (66, 18, 36): 0.1124288216818159
# (65, 19, 36): 0.12425323048971737
#
# Approximating hitting prob for (66, 18, 54)
# (66, 18, 54): 0.17561824796120884
# (65, 19, 54): 0.184894274490209
#
# Approximating hitting prob for (66, 18, 72)
# (66, 18, 72): 0.2590532946586614
# (65, 19, 72): 0.26358254356216704
#
# Approximating hitting prob for (66, 18, 90)
# (66, 18, 90): 0.2806684346017048
# (65, 19, 90): 0.28492228368559774
# Approximating hitting prob for (66, 19, 19)
# (66, 19, 19): 0.0640463647740417
# (65, 20, 19): 0.08163579053420868
#
# Approximating hitting prob for (66, 19, 38)
# (66, 19, 38): 0.11736690157783917
# (65, 20, 38): 0.12903851228166788
#
# Approximating hitting prob for (66, 19, 57)
# (66, 19, 57): 0.18258087855498553
# (65, 20, 57): 0.19210412357736475
#
# Approximating hitting prob for (66, 19, 76)
# (66, 19, 76): 0.2622076644942842
# (65, 20, 76): 0.2668135804318025
#
# Approximating hitting prob for (66, 19, 95)
# (66, 19, 95): 0.28373045414757303
# (65, 20, 95): 0.2888375716187707
#
# Approximating hitting prob for (66, 20, 20)
# (66, 20, 20): 0.06759997423396923
# (65, 21, 20): 0.08665795302868784
#
# Approximating hitting prob for (66, 20, 40)
# (66, 20, 40): 0.12241648685816488
# (65, 21, 40): 0.1335104939602648
#
# Approximating hitting prob for (66, 20, 60)
# (66, 20, 60): 0.19020119292271384
# (65, 21, 60): 0.19980862043720082
#
# Approximating hitting prob for (66, 20, 80)
# (66, 20, 80): 0.2646696820143638
# (65, 21, 80): 0.2711035137582433
#
# Approximating hitting prob for (66, 21, 21)
# (66, 21, 21): 0.06996620267554672
# (65, 22, 21): 0.10074737454357922
#
# Approximating hitting prob for (66, 21, 42)
# (66, 21, 42): 0.12511472578880414
# (65, 22, 42): 0.1468994945067522
#
# Approximating hitting prob for (66, 21, 63)
# (66, 21, 63): 0.1956608906883296
# (65, 22, 63): 0.21645493143387398
#
# Approximating hitting prob for (66, 21, 84)
# (66, 21, 84): 0.2663744104301448
# (65, 22, 84): 0.286592576625513
#
# Approximating hitting prob for (66, 23, 23)
# (66, 23, 23): 0.09767185332290966
# (65, 24, 23): 0.1160812385251216
#
# Approximating hitting prob for (67, 8, 23)
# (67, 8, 23): 0.06773128525200516
# (66, 9, 23): 0.07109482788986501
#
# Approximating hitting prob for (66, 24, 24)
# (66, 24, 24): 0.09881769010474889
# (65, 25, 24): 0.11887617018734321
#
# Approximating hitting prob for (66, 24, 48)
# (66, 24, 48): 0.17949465414918586
# (65, 25, 48): 0.1909907944510614
#
# Approximating hitting prob for (66, 24, 72)
# (66, 24, 72): 0.2741885136082182
# (65, 25, 72): 0.2854334569041194
#
# Approximating hitting prob for (66, 25, 25)
# (66, 25, 25): 0.10182002633388086
# (65, 26, 25): 0.12090794861283465
#
# Approximating hitting prob for (66, 25, 50)
# (66, 25, 50): 0.18327359992077852
# (65, 26, 50): 0.19473981513184827
#
# Approximating hitting prob for (66, 25, 75)
# (66, 25, 75): 0.27946854172965824
# (65, 26, 75): 0.28802522850207923
#
# Approximating hitting prob for (67, 13, 25)
# (67, 13, 25): 0.07995276771338251
# (66, 14, 25): 0.09184498380832233
#
# Approximating hitting prob for (67, 25, 26)
# (67, 25, 26): 0.11927608141345719
# (66, 26, 26): 0.1031437420668667
#
# Approximating hitting prob for (67, 25, 39)
# (67, 25, 39): 0.14306870757220938
# (66, 26, 39): 0.14263505701605791
#
# Approximating hitting prob for (67, 25, 52)
# (67, 25, 52): 0.19341774363116238
# (66, 26, 52): 0.18656275379610174
#
# Approximating hitting prob for (67, 25, 78)
# (67, 25, 78): 0.28703322584840046
# (66, 26, 78): 0.2814830059311694
#
# Approximating hitting prob for (66, 27, 27)
# (66, 27, 27): 0.10491149548144753
# (65, 28, 27): 0.12498766046417187
#
# Approximating hitting prob for (66, 27, 54)
# (66, 27, 54): 0.19266908629944393
# (65, 28, 54): 0.20396820404115404
#
# Approximating hitting prob for (66, 27, 81)
# (66, 27, 81): 0.2850327486380151
# (65, 28, 81): 0.29465951742680524
#
# Approximating hitting prob for (66, 14, 28)
# (66, 14, 28): 0.09537776042475148
# (65, 15, 28): 0.10470493340127858
#
# Approximating hitting prob for (66, 28, 28)
# (66, 28, 28): 0.10647397375748659
# (65, 29, 28): 0.12675579974645548
#
# Approximating hitting prob for (66, 28, 56)
# (66, 28, 56): 0.19450010747229599
# (65, 29, 56): 0.21235584641357444
#
# Approximating hitting prob for (66, 28, 68)
# (66, 28, 68): 0.2837774625489839
# (65, 29, 68): 0.2855339948576272
#
# Approximating hitting prob for (66, 28, 84)
# (66, 28, 84): 0.2875719465598385
# (65, 29, 84): 0.2969097470708023
#
# Approximating hitting prob for (66, 29, 29)
# (66, 29, 29): 0.10775642401102335
# (65, 30, 29): 0.12882971215265474
#
# Approximating hitting prob for (66, 29, 58)
# (66, 29, 58): 0.20336522978226598
# (65, 30, 58): 0.21635595850342024
#
# Approximating hitting prob for (66, 29, 87)
# (66, 29, 87): 0.2901900615921222
# (65, 30, 87): 0.29965657483713265
#
# Approximating hitting prob for (66, 10, 30)
# (66, 10, 30): 0.08299813242649769
# (65, 11, 30): 0.0894871104497858
#
# Approximating hitting prob for (67, 15, 29)
# (67, 15, 29): 0.104560556546064
# (66, 16, 29): 0.10581843999002398
#
# Approximating hitting prob for (67, 29, 30)
# (67, 29, 30): 0.12684849212278304
# (66, 30, 30): 0.10943859940463435
#
# Approximating hitting prob for (67, 29, 60)
# (67, 29, 60): 0.2147728938305348
# (66, 30, 60): 0.20696436000065802
#
# Approximating hitting prob for (67, 29, 90)
# (67, 29, 90): 0.2978237368236861
# (66, 30, 90): 0.2924521952683694
#
# Approximating hitting prob for (67, 30, 31)
# (67, 30, 31): 0.12895537060894444
# (66, 31, 31): 0.1102938794238868
#
# Approximating hitting prob for (67, 30, 62)
# (67, 30, 62): 0.21815979614398706
# (66, 31, 62): 0.21077887428311246
#
# Approximating hitting prob for (67, 30, 93)
# (67, 30, 93): 0.29978515028343306
# (66, 31, 93): 0.29413612855136767
#
# Approximating hitting prob for (66, 32, 32)
# (66, 32, 32): 0.11084495766771923
# (65, 33, 32): 0.16827593986725478
#
# Approximating hitting prob for (66, 32, 64)
# (66, 32, 64): 0.21351201774897274
# (65, 33, 64): 0.23945071871684653
#
# Approximating hitting prob for (66, 32, 75)
# (66, 32, 75): 0.2916848072140082
# (65, 33, 75): 0.30581617279519385
#
# Approximating hitting prob for (66, 32, 96)
# (66, 32, 96): 0.29527420634189766
# (65, 33, 96): 0.31954383730760283
#
# Approximating hitting prob for (67, 17, 33)
# (67, 17, 33): 0.11367686331512993
# (66, 18, 33): 0.1162539350825138
#
# Approximating hitting prob for (67, 33, 34)
# (67, 33, 34): 0.16827487465219756
# (66, 34, 34): 0.16365868548743653
#
# Approximating hitting prob for (67, 34, 35)
# (67, 34, 35): 0.20197831845663092
# (66, 35, 35): 0.1642936885354744
#
# Approximating hitting prob for (67, 34, 70)
# (67, 34, 70): 0.3014977619589051
# (66, 35, 70): 0.29274163623668953
#
# Approximating hitting prob for (67, 34, 79)
# (67, 34, 79): 0.30915595927756845
# (66, 35, 79): 0.3091985782220566
#
# Approximating hitting prob for (67, 34, 80)
# (67, 34, 80): 0.3097523388363497
# (66, 35, 80): 0.3097526420647772
#
# Approximating hitting prob for (67, 12, 35)
# (67, 12, 35): 0.1052839192937658
# (66, 13, 35): 0.10736338660780237
#
# Approximating hitting prob for (66, 36, 36)
# (66, 36, 36): 0.16524459731426341
# (65, 37, 36): 0.20819732104262403
#
# Approximating hitting prob for (66, 36, 72)
# (66, 36, 72): 0.2937768113033216
# (65, 37, 72): 0.3065415316148837
#
# Approximating hitting prob for (66, 36, 81)
# (66, 36, 81): 0.31044048014279135
# (65, 37, 81): 0.31164172615195174
#
# Approximating hitting prob for (66, 37, 37)
# (66, 37, 37): 0.16622603513369366
# (65, 38, 37): 0.2094994670652807
#
# Approximating hitting prob for (66, 37, 74)
# (66, 37, 74): 0.29574914089533066
# (65, 38, 74): 0.30779259986829816
#
# Approximating hitting prob for (66, 37, 83)
# (66, 37, 83): 0.3114864255589433
# (65, 38, 83): 0.3157177097405874
#
# Approximating hitting prob for (67, 19, 37)
# (67, 19, 37): 0.12346188722966552
# (66, 20, 37): 0.1264007908365368
#
# Approximating hitting prob for (67, 37, 38)
# (67, 37, 38): 0.20805749257698603
# (66, 38, 38): 0.16752188146385938
#
# Approximating hitting prob for (67, 37, 76)
# (67, 37, 76): 0.30641780186181383
# (66, 38, 76): 0.2969251522972007
#
# Approximating hitting prob for (67, 26, 38)
# (67, 26, 38): 0.14335473526047074
# (66, 27, 38): 0.14526882578196765
#
# Approximating hitting prob for (67, 38, 39)
# (67, 38, 39): 0.2093527922297008
# (66, 39, 39): 0.16879410932312547
#
# Approximating hitting prob for (67, 38, 78)
# (67, 38, 78): 0.3078112412324899
# (66, 39, 78): 0.29822329424252986
#
# Approximating hitting prob for (66, 40, 40)
# (66, 40, 40): 0.1740798206339398
# (65, 41, 40): 0.21755911572808564
#
# Approximating hitting prob for (66, 40, 80)
# (66, 40, 80): 0.3052664415601476
# (65, 41, 80): 0.317417557223137
#
# Approximating hitting prob for (66, 41, 41)
# (66, 41, 41): 0.17496121763013253
# (65, 42, 41): 0.21937152683090563
#
# Approximating hitting prob for (66, 41, 82)
# (66, 41, 82): 0.30620026544401957
# (65, 42, 82): 0.31938370506205704
#
# Approximating hitting prob for (67, 14, 41)
# (67, 14, 41): 0.12169842684712602
# (66, 15, 41): 0.1244262211975099
# Approximating hitting prob for (66, 42, 42)
# (66, 42, 42): 0.17707745397460653
# (65, 43, 42): 0.2211036740876913
#
# Approximating hitting prob for (66, 42, 63)
# (66, 42, 63): 0.23826647572896864
# (65, 43, 63): 0.24839439119640364
#
# Approximating hitting prob for (66, 42, 64)
# (66, 42, 64): 0.24330010862739815
# (65, 43, 64): 0.24453685507206524
#
# Approximating hitting prob for (66, 42, 84)
# (66, 42, 84): 0.3080530000872859
# (65, 43, 84): 0.3209881367063668
#
# Approximating hitting prob for (66, 43, 43)
# (66, 43, 43): 0.17831460693385326
# (65, 44, 43): 0.2262717855606958
#
# Approximating hitting prob for (66, 43, 65)
# (66, 43, 65): 0.24407116658657377
# (65, 44, 65): 0.31094950668834404
#
# Approximating hitting prob for (66, 43, 86)
# (66, 43, 86): 0.3094840250999271
# (65, 44, 86): 0.32411850466593434
#
# Approximating hitting prob for (66, 44, 44)
# (66, 44, 44): 0.18348623853210444
# (65, 45, 44): 0.2282271262161433
#
# Approximating hitting prob for (66, 44, 88)
# (66, 44, 88): 0.31260403488913774
# (65, 45, 88): 0.32529755431036106
#
# Approximating hitting prob for (67, 15, 44)
# (67, 15, 44): 0.12648107337022393
# (66, 16, 44): 0.1316858971009304
#
# Approximating hitting prob for (67, 44, 45)
# (67, 44, 45): 0.22373776140727272
# (66, 45, 45): 0.18539997863610067
#
# Approximating hitting prob for (67, 44, 90)
# (67, 44, 90): 0.32217475616291297
# (66, 45, 90): 0.314049126419908
#
# Approximating hitting prob for (67, 23, 45)
# (67, 23, 45): 0.18270096276309175
# (66, 24, 45): 0.18395836157706505
#
# Approximating hitting prob for (67, 45, 46)
# (67, 45, 46): 0.22773486607652407
# (66, 46, 46): 0.18652433533482793
#
# Approximating hitting prob for (67, 45, 92)
# (67, 45, 92): 0.32525212686942817
# (66, 46, 92): 0.31524700825833335
#
# Approximating hitting prob for (67, 45, 98)
# (67, 45, 98): 0.33097515263186217
# (66, 46, 98): 0.3299730027682267
#
# Approximating hitting prob for (67, 46, 47)
# (67, 46, 47): 0.2294079512483632
# (66, 47, 47): 0.18889027192791527
#
# Approximating hitting prob for (66, 47, 94)
# (66, 47, 94): 0.3158704570368716
# (65, 48, 94): 0.3303362905901297
#
# Approximating hitting prob for (67, 16, 47)
# (67, 16, 47): 0.1309362769513925
# (66, 17, 47): 0.1361545944206734
#
# Approximating hitting prob for (66, 48, 48)
# (66, 48, 48): 0.19048276330106628
# (65, 49, 48): 0.2371238187646523
#
# Approximating hitting prob for (66, 48, 96)
# (66, 48, 96): 0.3187635821534672
# (65, 49, 96): 0.33180229292582347
#
# Approximating hitting prob for (66, 49, 49)
# (66, 49, 49): 0.19122789330299572
# (65, 50, 49): 0.24315301009611387
#
# Approximating hitting prob for (66, 49, 98)
# (66, 49, 98): 0.319630200721018
# (65, 50, 98): 0.3328864423181019
#
# Approximating hitting prob for (67, 25, 49)
# (67, 25, 49): 0.1892587373499013
# (66, 26, 49): 0.19249870107559341
#
# Approximating hitting prob for (67, 49, 50)
# (67, 49, 50): 0.234278157193162
# (66, 50, 50): 0.20079326204492423
#
# Approximating hitting prob for (67, 49, 100)
# (67, 49, 100): 0.3310585064642846
# (66, 50, 100): 0.32127617318189194
#
# Approximating hitting prob for (67, 50, 51)
# (67, 50, 51): 0.240506835864981
# (66, 51, 51): 0.2016931009224047
#
# Approximating hitting prob for (67, 26, 51)
# (67, 26, 51): 0.193196095382862
# (66, 27, 51): 0.19611434400286906
#
# Approximating hitting prob for (67, 51, 52)
# (67, 51, 52): 0.24413585197625373
# (66, 52, 52): 0.2030696777178386
#
# Approximating hitting prob for (67, 52, 53)
# (67, 52, 53): 0.24538366106148632
# (66, 53, 53): 0.2047603299337379
#
# Approximating hitting prob for (67, 27, 53)
# (67, 27, 53): 0.1966155059217866
# (66, 28, 53): 0.2020948647571499
#
# Approximating hitting prob for (67, 53, 54)
# (67, 53, 54): 0.24693874937838003
# (66, 54, 54): 0.20556023200191997
#
# Approximating hitting prob for (67, 54, 55)
# (67, 54, 55): 0.2482931840044628
# (66, 55, 55): 0.2077770400570025
#
# Approximating hitting prob for (67, 14, 55)
# (67, 14, 55): 0.17260231393199543
# (66, 15, 55): 0.17433920118521676
#
# Approximating hitting prob for (66, 56, 56)
# (66, 56, 56): 0.20990813484177062
# (65, 57, 56): 0.256970036825173
#
# Approximating hitting prob for (67, 19, 56)
# (67, 19, 56): 0.18463637100039212
# (66, 20, 56): 0.18862376136975667
#
# Approximating hitting prob for (67, 56, 57)
# (67, 56, 57): 0.25345520648352476
# (66, 57, 57): 0.21177096078410249
#
# Approximating hitting prob for (66, 58, 58)
# (66, 58, 58): 0.21419963859685523
# (65, 59, 58): 0.2598350165944448
#
# Approximating hitting prob for (66, 59, 59)
# (66, 59, 59): 0.21499759440364416
# (65, 60, 59): 0.26107259992076365
#
# Approximating hitting prob for (67, 20, 59)
# (67, 20, 59): 0.19152255374568397
# (66, 21, 59): 0.1953208985566929
#
# Approximating hitting prob for (66, 60, 60)
# (66, 60, 60): 0.21609698615287912
# (65, 61, 60): 0.2626391326264154
#
# Approximating hitting prob for (66, 61, 61)
# (66, 61, 61): 0.2175293727307139
# (65, 62, 61): 0.2638214696065422
#
# Approximating hitting prob for (67, 31, 61)
# (67, 31, 61): 0.21809275261704206
# (66, 32, 61): 0.22088793036468832
#
# Approximating hitting prob for (67, 61, 62)
# (67, 61, 62): 0.2613147087884886
# (66, 62, 62): 0.21907059430033546
#
# Approximating hitting prob for (67, 42, 62)
# (67, 42, 62): 0.23926943736610543
# (66, 43, 62): 0.24679826325509804
#
# Approximating hitting prob for (67, 62, 63)
# (67, 62, 63): 0.2627779174071257
# (66, 63, 63): 0.21983121520518434
#
# Approximating hitting prob for (66, 64, 64)
# (66, 64, 64): 0.22097491730300545
# (65, 65, 64): 0.32209424877965176
#
# Approximating hitting prob for (66, 65, 65)
# (66, 65, 65): 0.22172609072310068
# (65, 66, 65): 0.389136954638241
#
# Approximating hitting prob for (66, 65, 78)
# (66, 65, 78): 0.33828956377378905
# (65, 66, 78): 0.4087785111544191
#
# Approximating hitting prob for (66, 17, 68)
# (66, 17, 68): 0.2564828955996521
# (65, 18, 68): 0.26055818491503646
#
# Approximating hitting prob for (66, 34, 68)
# (66, 34, 68): 0.29132888147545877
# (65, 35, 68): 0.3031981946419537
#
# Approximating hitting prob for (66, 68, 68)
# (66, 68, 68): 0.35618485542093103
# (65, 69, 68): 0.4016288472632883
#
# Approximating hitting prob for (66, 23, 69)
# (66, 23, 69): 0.27192679893863714
# (65, 24, 69): 0.28109532334951476
#
# Approximating hitting prob for (66, 69, 69)
# (66, 69, 69): 0.35672707524580066
# (65, 70, 69): 0.4022921124501824
#
# Approximating hitting prob for (66, 14, 70)
# (66, 14, 70): 0.25271700961610116
# (65, 15, 70): 0.2570586607189825
#
# Approximating hitting prob for (67, 35, 69)
# (67, 35, 69): 0.30194086445518825
# (66, 36, 69): 0.3033935249191669
#
# Approximating hitting prob for (67, 69, 70)
# (67, 69, 70): 0.4010445592238863
# (66, 70, 70): 0.35718528187635945
#
# Approximating hitting prob for (67, 70, 71)
# (67, 70, 71): 0.40158866561985196
# (66, 71, 71): 0.35791267140474137
#
# Approximating hitting prob for (67, 12, 71)
# (67, 12, 71): 0.25138486932043896
# (66, 13, 71): 0.2527542096753898
#
# Approximating hitting prob for (67, 24, 71)
# (67, 24, 71): 0.28007914823535607
# (66, 25, 71): 0.2819061802548723
#
# Approximating hitting prob for (66, 72, 72)
# (66, 72, 72): 0.35846076190696907
# (65, 73, 72): 0.4045028328560498
#
# Approximating hitting prob for (66, 73, 73)
# (66, 73, 73): 0.35931883982935453
# (65, 74, 73): 0.4057618319907636
#
# Approximating hitting prob for (67, 37, 73)
# (67, 37, 73): 0.304579669894873
# (66, 38, 73): 0.3068473596888522
#
# Approximating hitting prob for (67, 73, 74)
# (67, 73, 74): 0.40349622101510835
# (66, 74, 74): 0.3596623559425114
#
# Approximating hitting prob for (67, 15, 74)
# (67, 15, 74): 0.2574162656497999
# (66, 16, 74): 0.2593814010914058
#
# Approximating hitting prob for (66, 45, 75)
# (66, 45, 75): 0.31834842764480625
# (65, 46, 75): 0.3207998778016395
#
# Approximating hitting prob for (66, 75, 75)
# (66, 75, 75): 0.36096986792324914
# (65, 76, 75): 0.4073625498136924
#
# Approximating hitting prob for (67, 19, 75)
# (67, 19, 75): 0.26285856177556505
# (66, 20, 75): 0.26535716149620076
#
# Approximating hitting prob for (66, 76, 76)
# (66, 76, 76): 0.36157517954028284
# (65, 77, 76): 0.40861352920496313
#
# Approximating hitting prob for (66, 76, 98)
# (66, 76, 98): 0.4243717547437184
# (65, 77, 98): 0.42544174305262805
#
# Approximating hitting prob for (66, 77, 77)
# (66, 77, 77): 0.3626759287590275
# (65, 78, 77): 0.409390931057134
#
# Approximating hitting prob for (67, 13, 77)
# (67, 13, 77): 0.2551483632015689
# (66, 14, 77): 0.2590679516157295
#
# Approximating hitting prob for (67, 39, 77)
# (67, 39, 77): 0.30778393617708216
# (66, 40, 77): 0.3113227687452759
#
# Approximating hitting prob for (67, 77, 78)
# (67, 77, 78): 0.4065999364328397
# (66, 78, 78): 0.36363833410299046
#
# Approximating hitting prob for (67, 78, 79)
# (67, 78, 79): 0.4082576774506838
# (66, 79, 79): 0.36407599940312346
#
# Approximating hitting prob for (67, 20, 79)
# (67, 20, 79): 0.2658826815468965
# (66, 21, 79): 0.27014779421286833
#
# Approximating hitting prob for (66, 80, 80)
# (66, 80, 80): 0.3652698362124187
# (65, 81, 80): 0.411155898973608
#
# Approximating hitting prob for (67, 27, 80)
# (67, 27, 80): 0.2912157599116711
# (66, 28, 80): 0.29218494863679506
#
# Approximating hitting prob for (67, 80, 81)
# (67, 80, 81): 0.40978135012598416
# (66, 81, 81): 0.3658662303660776
#
# Approximating hitting prob for (66, 82, 82)
# (66, 82, 82): 0.36621701294445846
# (65, 83, 82): 0.4151124240441196
#
# Approximating hitting prob for (66, 83, 83)
# (66, 83, 83): 0.36967956589057555
# (65, 84, 83): 0.4158812790424802
#
# Approximating hitting prob for (66, 14, 84)
# (66, 14, 84): 0.272803533280862
# (65, 15, 84): 0.27619523283231834
#
# Approximating hitting prob for (67, 21, 83)
# (67, 21, 83): 0.2680176223511767
# (66, 22, 83): 0.2822323694186802
#
# Approximating hitting prob for (67, 42, 83)
# (67, 42, 83): 0.3171062444054769
# (66, 43, 83): 0.31956482998842967
#
# Approximating hitting prob for (67, 83, 84)
# (67, 83, 84): 0.41253890222477235
# (66, 84, 84): 0.3699460087792124
#
# Approximating hitting prob for (67, 84, 85)
# (67, 84, 85): 0.4147148000658125
# (66, 85, 85): 0.37098546188418163
#
# Approximating hitting prob for (66, 86, 86)
# (66, 86, 86): 0.371366622536719
# (65, 87, 86): 0.418031805898231
#
# Approximating hitting prob for (67, 29, 86)
# (67, 29, 86): 0.29578632563805535
# (66, 30, 86): 0.2975381584288852
#
# Approximating hitting prob for (67, 86, 87)
# (67, 86, 87): 0.4160464166796613
# (66, 87, 87): 0.3717018877860987
#
# Approximating hitting prob for (66, 88, 88)
# (66, 88, 88): 0.37265977777400555
# (65, 89, 88): 0.419994940717898
#
# Approximating hitting prob for (66, 89, 89)
# (66, 89, 89): 0.37416477274989224
# (65, 90, 89): 0.4206530641905422
#
# Approximating hitting prob for (66, 15, 90)
# (66, 15, 90): 0.2761350719225567
# (65, 16, 90): 0.2792423143668184
#
# Approximating hitting prob for (67, 18, 89)
# (67, 18, 89): 0.2816600049874961
# (66, 19, 89): 0.2830782905227499
#
# Approximating hitting prob for (67, 45, 89)
# (67, 45, 89): 0.32383655591865573
# (66, 46, 89): 0.32491713264035554
#
# Approximating hitting prob for (67, 89, 90)
# (67, 89, 90): 0.4187884986184867
# (66, 90, 90): 0.37462300623853967
#
# Approximating hitting prob for (67, 13, 90)
# (67, 13, 90): 0.27311902646019354
# (66, 14, 90): 0.2767903599237686
#
# Approximating hitting prob for (67, 90, 91)
# (67, 90, 91): 0.41967961907836404
# (66, 91, 91): 0.37523021824014724
#
# Approximating hitting prob for (66, 92, 92)
# (66, 92, 92): 0.3755645955744311
# (65, 93, 92): 0.4227533455189347
#
# Approximating hitting prob for (67, 31, 92)
# (67, 31, 92): 0.30057348086528796
# (66, 32, 92): 0.301796108401639
#
# Approximating hitting prob for (67, 92, 93)
# (67, 92, 93): 0.4207957860705289
# (66, 93, 93): 0.37667461992971746
#
# Approximating hitting prob for (66, 94, 94)
# (66, 94, 94): 0.3769862688637719
# (65, 95, 94): 0.42377489516281863
#
# Approximating hitting prob for (67, 19, 94)
# (67, 19, 94): 0.2843478808250934
# (66, 20, 94): 0.28656238792525957
#
# Approximating hitting prob for (67, 58, 94)
# (67, 58, 94): 0.34556268925708195
# (66, 59, 94): 0.3483412352225779
#
# Approximating hitting prob for (67, 94, 95)
# (67, 94, 95): 0.4223779743511144
# (66, 95, 95): 0.3774333279271662
#
# Approximating hitting prob for (67, 48, 95)
# (67, 48, 95): 0.32784664483696707
# (66, 49, 95): 0.3305068078654609
#
# Approximating hitting prob for (67, 60, 95)
# (67, 60, 95): 0.34835510995520397
# (66, 61, 95): 0.350326027786765
#
# Approximating hitting prob for (67, 95, 96)
# (67, 95, 96): 0.42277662678188305
# (66, 96, 96): 0.3776911024130089
#
# Approximating hitting prob for (67, 62, 96)
# (67, 62, 96): 0.350327548996668
# (66, 63, 96): 0.351808264102844
#
# Approximating hitting prob for (67, 96, 97)
# (67, 96, 97): 0.4233824736545983
# (66, 97, 97): 0.37801671411906285
#
# Approximating hitting prob for (66, 98, 98)
# (66, 98, 98): 0.3781707746841449
# (65, 99, 98): 0.4428982737895419
#
# Approximating hitting prob for (66, 99, 99)
# (66, 99, 99): 0.38531294066601585
# (65, 100, 99): 0.44439248968959405
#
# Approximating hitting prob for (67, 50, 99)
# (67, 50, 99): 0.3307680454128158
# (66, 51, 99): 0.3333701119568775
#
# Approximating hitting prob for (67, 99, 100)
# (67, 99, 100): 0.4245257025756863
# (66, 100, 100): 0.392432266271022
#
# Approximating hitting prob for (68, 1, 24)
# (68, 1, 24): 0.0609827954154526
# (67, 2, 24): 0.06026892307270271
#
# Approximating hitting prob for (68, 1, 71)
# (68, 1, 71): 0.2493348264128551
# (67, 2, 71): 0.2480904943328882
#
# Approximating hitting prob for (68, 1, 72)
# (68, 1, 72): 0.2494396959609432
# (67, 2, 72): 0.24833312851794873
#
# Approximating hitting prob for (68, 2, 74)
# (68, 2, 74): 0.2502917821234501
# (67, 3, 74): 0.24972372645179328
#
# Approximating hitting prob for (68, 2, 75)
# (68, 2, 75): 0.2504942697271601
# (67, 3, 75): 0.24990224235334701
#
# Approximating hitting prob for (68, 3, 4)
# (68, 3, 4): 0.003848809842844102
# (67, 4, 4): 0.003654653917201685
#
# Approximating hitting prob for (68, 3, 77)
# (68, 3, 77): 0.25187644865099773
# (67, 4, 77): 0.2513769761350437
#
# Approximating hitting prob for (68, 3, 78)
# (68, 3, 78): 0.25224557337411274
# (67, 4, 78): 0.251598241042492
#
# Approximating hitting prob for (68, 5, 6)
# (68, 5, 6): 0.010440286501920144
# (67, 6, 6): 0.00816861132413158
#
# Approximating hitting prob for (68, 5, 12)
# (68, 5, 12): 0.022568514609568945
# (67, 6, 12): 0.021783242899786445
#
# Approximating hitting prob for (68, 5, 84)
# (68, 5, 84): 0.25677585257131624
# (67, 6, 84): 0.25637789201469585
#
# Approximating hitting prob for (68, 6, 7)
# (68, 6, 7): 0.01251324113978014
# (67, 7, 7): 0.011239122801284312
#
# Approximating hitting prob for (68, 6, 14)
# (68, 6, 14): 0.02759382022652122
# (67, 7, 14): 0.02590319427597627
#
# Approximating hitting prob for (68, 7, 8)
# (68, 7, 8): 0.015976128704838475
# (67, 8, 8): 0.013116580216528027
#
# Approximating hitting prob for (68, 7, 16)
# (68, 7, 16): 0.03471771204089102
# (67, 8, 16): 0.034187222164365684
#
# Approximating hitting prob for (68, 7, 24)
# (68, 7, 24): 0.0668876014400488
# (67, 8, 24): 0.0656831121587564
#
# Approximating hitting prob for (68, 7, 89)
# (68, 7, 89): 0.2610184157975021
# (67, 8, 89): 0.2610867617823934
#
# Approximating hitting prob for (68, 7, 90)
# (68, 7, 90): 0.26177147110234955
# (67, 8, 90): 0.2613796896794039
#
# Approximating hitting prob for (68, 8, 9)
# (68, 8, 9): 0.020447695332472402
# (67, 9, 9): 0.018663335456300036
#
# Approximating hitting prob for (68, 8, 18)
# (68, 8, 18): 0.04041507065709974
# (67, 9, 18): 0.03902494509124652
#
# Approximating hitting prob for (68, 8, 31)
# (68, 8, 31): 0.08278191762360625
# (67, 9, 31): 0.08270649770452014
#
# Approximating hitting prob for (68, 8, 36)
# (68, 8, 36): 0.08957441956287399
# (67, 9, 36): 0.08917068507244698
#
# Approximating hitting prob for (68, 9, 10)
# (68, 9, 10): 0.026431194578370287
# (67, 10, 10): 0.02432945129624881
#
# Approximating hitting prob for (68, 10, 11)
# (68, 10, 11): 0.03036591770012333
# (67, 11, 11): 0.025200828833912545
#
# Approximating hitting prob for (68, 10, 22)
# (68, 10, 22): 0.0615207118167029
# (67, 11, 22): 0.05943485819225139
#
# Approximating hitting prob for (68, 10, 33)
# (68, 10, 33): 0.08953545690345542
# (67, 11, 33): 0.08568996863115717
#
# Approximating hitting prob for (68, 10, 55)
# (68, 10, 55): 0.13010112614078145
# (67, 11, 55): 0.12986517708036674
#
# Approximating hitting prob for (68, 10, 98)
# (68, 10, 98): 0.2700398257270076
# (67, 11, 98): 0.26995971764381727
#
# Approximating hitting prob for (68, 10, 99)
# (68, 10, 99): 0.27102298162082206
# (67, 11, 99): 0.26928818582092795
#
# Approximating hitting prob for (67, 12, 12)
# (67, 12, 12): 0.03209238182597753
# (66, 13, 12): 0.046272311155968936
#
# Approximating hitting prob for (67, 12, 24)
# (67, 12, 24): 0.07353066326226732
# (66, 13, 24): 0.08169097099873958
#
# Approximating hitting prob for (67, 12, 36)
# (67, 12, 36): 0.10270983173485117
# (66, 13, 36): 0.10884480024756306
#
# Approximating hitting prob for (67, 13, 13)
# (67, 13, 13): 0.03382925467146839
# (66, 14, 13): 0.04928947718478479
#
# Approximating hitting prob for (67, 13, 26)
# (67, 13, 26): 0.07540384713990982
# (66, 14, 26): 0.09647980981546479
#
# Approximating hitting prob for (67, 13, 39)
# (67, 13, 39): 0.10797624427167545
# (66, 14, 39): 0.11985657286200126
#
# Approximating hitting prob for (67, 13, 52)
# (67, 13, 52): 0.1302440490811651
# (66, 14, 52): 0.15938828065013094
#
# Approximating hitting prob for (67, 13, 78)
# (67, 13, 78): 0.2541809884271101
# (66, 14, 78): 0.2597709127789488
#
# Approximating hitting prob for (68, 7, 13)
# (68, 7, 13): 0.02751143230462536
# (67, 8, 13): 0.03044856431529712
#
# Approximating hitting prob for (68, 13, 14)
# (68, 13, 14): 0.0479935357229686
# (67, 14, 14): 0.03640368247442234
#
# Approximating hitting prob for (68, 14, 15)
# (68, 14, 15): 0.05093187829566324
# (67, 15, 15): 0.03913702473075743
#
# Approximating hitting prob for (68, 14, 30)
# (68, 14, 30): 0.10313122733102359
# (67, 15, 30): 0.09705987356818387
#
# Approximating hitting prob for (68, 14, 45)
# (68, 14, 45): 0.12586072800690726
# (67, 15, 45): 0.12404358617120859
#
# Approximating hitting prob for (67, 16, 16)
# (67, 16, 16): 0.041447925710331894
# (66, 17, 16): 0.0647431816715401
#
# Approximating hitting prob for (67, 16, 32)
# (67, 16, 32): 0.10135150493029749
# (66, 17, 32): 0.11349626509204291
#
# Approximating hitting prob for (67, 16, 48)
# (67, 16, 48): 0.12721219707969347
# (66, 17, 48): 0.13691799741488672
#
# Approximating hitting prob for (67, 16, 80)
# (67, 16, 80): 0.2596154864401385
# (66, 17, 80): 0.2652139538314039
#
# Approximating hitting prob for (67, 17, 34)
# (67, 17, 34): 0.10700290341180846
# (66, 18, 34): 0.11717124194116785
#
# Approximating hitting prob for (68, 9, 17)
# (68, 9, 17): 0.04056311330553164
# (67, 10, 17): 0.046085848592287
#
# Approximating hitting prob for (68, 17, 18)
# (68, 17, 18): 0.0728678697393717
# (67, 18, 18): 0.05996231623889121
#
# Approximating hitting prob for (68, 17, 36)
# (68, 17, 36): 0.11689294835099018
# (67, 18, 36): 0.10970341679004536
#
# Approximating hitting prob for (68, 17, 54)
# (68, 17, 54): 0.1776794382679242
# (67, 18, 54): 0.1744665522227996
#
# Approximating hitting prob for (68, 17, 72)
# (68, 17, 72): 0.2591300080518013
# (67, 18, 72): 0.2582843326900624
#
# Approximating hitting prob for (68, 17, 90)
# (68, 17, 90): 0.28072128118444684
# (67, 18, 90): 0.2800875031200542
#
# Approximating hitting prob for (68, 18, 19)
# (68, 18, 19): 0.07519344928195314
# (67, 19, 19): 0.06223680797643206
#
# Approximating hitting prob for (68, 18, 38)
# (68, 18, 38): 0.12164974747705692
# (67, 19, 38): 0.1157213966886164
#
# Approximating hitting prob for (68, 18, 52)
# (68, 18, 52): 0.17775673487809854
# (67, 19, 52): 0.17725288489463986
#
# Approximating hitting prob for (68, 18, 57)
# (68, 18, 57): 0.1831058680292247
# (67, 19, 57): 0.1782527532840733
#
# Approximating hitting prob for (68, 18, 76)
# (68, 18, 76): 0.2619509214575068
# (67, 19, 76): 0.26097912571264636
#
# Approximating hitting prob for (68, 19, 20)
# (68, 19, 20): 0.07806454313447277
# (67, 20, 20): 0.06485898425757987
#
# Approximating hitting prob for (68, 19, 40)
# (68, 19, 40): 0.126284874982386
# (67, 20, 40): 0.1196349276455136
#
# Approximating hitting prob for (68, 19, 60)
# (68, 19, 60): 0.1905117709963028
# (67, 20, 60): 0.185073225458369
#
# Approximating hitting prob for (68, 19, 80)
# (68, 19, 80): 0.2654962832630901
# (67, 20, 80): 0.2638585588786376
#
# Approximating hitting prob for (68, 19, 100)
# (68, 19, 100): 0.2854419073109335
# (67, 20, 100): 0.28510735103114154
#
# Approximating hitting prob for (68, 20, 21)
# (68, 20, 21): 0.08219290374273396
# (67, 21, 21): 0.069238215516589
#
# Approximating hitting prob for (68, 20, 42)
# (68, 20, 42): 0.1311237566538868
# (67, 21, 42): 0.12432506555675064
#
# Approximating hitting prob for (68, 20, 43)
# (68, 20, 43): 0.13423808282332672
# (67, 21, 43): 0.13400877022214672
#
# Approximating hitting prob for (68, 20, 63)
# (68, 20, 63): 0.19748887351582822
# (67, 21, 63): 0.19412192778215878
#
# Approximating hitting prob for (68, 20, 84)
# (68, 20, 84): 0.2680851005791081
# (67, 21, 84): 0.2660037056432093
#
# Approximating hitting prob for (68, 20, 85)
# (68, 20, 85): 0.26884250025554196
# (67, 21, 85): 0.26880646003788017
#
# Approximating hitting prob for (67, 22, 22)
# (67, 22, 22): 0.0713325640170704
# (66, 23, 22): 0.11322570039830963
#
# Approximating hitting prob for (67, 22, 44)
# (67, 22, 44): 0.12632600682289594
# (66, 23, 44): 0.18214370978323338
#
# Approximating hitting prob for (67, 22, 66)
# (67, 22, 66): 0.19872218712812198
# (66, 23, 66): 0.274940582438367
#
# Approximating hitting prob for (67, 22, 88)
# (67, 22, 88): 0.2672778298192398
# (66, 23, 88): 0.2946199266500747
#
# Approximating hitting prob for (67, 23, 23)
# (67, 23, 23): 0.09727494778700457
# (66, 24, 23): 0.11555304228561163
#
# Approximating hitting prob for (67, 6, 24)
# (67, 6, 24): 0.06183649049668272
# (66, 7, 24): 0.0679823933342724
#
# Approximating hitting prob for (68, 8, 23)
# (68, 8, 23): 0.0672589236576485
# (67, 9, 23): 0.07062484521693983
#
# Approximating hitting prob for (67, 24, 24)
# (67, 24, 24): 0.09854977739778602
# (66, 25, 24): 0.11697258328945291
#
# Approximating hitting prob for (67, 24, 48)
# (67, 24, 48): 0.178524125011261
# (66, 25, 48): 0.18954611481271386
#
# Approximating hitting prob for (67, 24, 57)
# (67, 24, 57): 0.20161743114147565
# (66, 25, 57): 0.20375950449575572
#
# Approximating hitting prob for (67, 24, 72)
# (67, 24, 72): 0.273790775017087
# (66, 25, 72): 0.2822917190221372
#
# Approximating hitting prob for (67, 25, 25)
# (67, 25, 25): 0.09948057838619612
# (66, 26, 25): 0.12001353436040278
#
# Approximating hitting prob for (67, 25, 47)
# (67, 25, 47): 0.18552773295171351
# (66, 26, 47): 0.18782634825742936
#
# Approximating hitting prob for (67, 25, 50)
# (67, 25, 50): 0.18146600434955798
# (66, 26, 50): 0.19349481164814772
#
# Approximating hitting prob for (67, 25, 58)
# (67, 25, 58): 0.20300793385471408
# (66, 26, 58): 0.2088897097318478
#
# Approximating hitting prob for (67, 25, 75)
# (67, 25, 75): 0.2751274072558895
# (66, 26, 75): 0.287199740842332
#
# Approximating hitting prob for (68, 13, 25)
# (68, 13, 25): 0.07954384565021315
# (67, 14, 25): 0.08881361825570755
#
# Approximating hitting prob for (68, 25, 26)
# (68, 25, 26): 0.11804200720574037
# (67, 26, 26): 0.10236314198255009
#
# Approximating hitting prob for (68, 25, 39)
# (68, 25, 39): 0.1424838417010088
# (67, 26, 39): 0.1419176521272826
#
# Approximating hitting prob for (68, 25, 48)
# (68, 25, 48): 0.18762175732477412
# (67, 26, 48): 0.18729396745131868
#
# Approximating hitting prob for (68, 25, 52)
# (68, 25, 52): 0.19224330632599193
# (67, 26, 52): 0.1855908755849642
#
# Approximating hitting prob for (68, 25, 78)
# (68, 25, 78): 0.2836348683400583
# (67, 26, 78): 0.2805493747884112
#
# Approximating hitting prob for (68, 9, 26)
# (68, 9, 26): 0.07679157251861966
# (67, 10, 26): 0.0806889608426874
#
# Approximating hitting prob for (68, 26, 27)
# (68, 26, 27): 0.12043885148166018
# (67, 27, 27): 0.10457272033444104
#
# Approximating hitting prob for (68, 26, 54)
# (68, 26, 54): 0.19561398578815906
# (67, 27, 54): 0.1920254520302782
#
# Approximating hitting prob for (68, 26, 60)
# (68, 26, 60): 0.21045480566872224
# (67, 27, 60): 0.2102970658745176
#
# Approximating hitting prob for (68, 26, 81)
# (68, 26, 81): 0.28785249839415916
# (67, 27, 81): 0.2844099533457548
#
# Approximating hitting prob for (68, 7, 27)
# (68, 7, 27): 0.07359367497126139
# (67, 8, 27): 0.07665897252713848
#
# Approximating hitting prob for (68, 14, 27)
# (68, 14, 27): 0.09641879874428705
# (67, 15, 27): 0.09764559154001896
#
# Approximating hitting prob for (68, 27, 28)
# (68, 27, 28): 0.12281189171463347
# (67, 28, 28): 0.10613327540150867
#
# Approximating hitting prob for (68, 27, 56)
# (68, 27, 56): 0.2018720188434233
# (67, 28, 56): 0.19395245296976804
#
# Approximating hitting prob for (68, 27, 84)
# (68, 27, 84): 0.29208887767274355
# (67, 28, 84): 0.2871338642716563
#
# Approximating hitting prob for (68, 28, 29)
# (68, 28, 29): 0.12447844490548758
# (67, 29, 29): 0.10715700356113832
#
# Approximating hitting prob for (68, 28, 58)
# (68, 28, 58): 0.2046036839316341
# (67, 29, 58): 0.20255118186403717
#
# Approximating hitting prob for (68, 28, 87)
# (68, 28, 87): 0.2943670593550695
# (67, 29, 87): 0.2890190230017919
#
# Approximating hitting prob for (68, 10, 29)
# (68, 10, 29): 0.08280186170602845
# (67, 11, 29): 0.084562123640053
#
# Approximating hitting prob for (67, 30, 30)
# (67, 30, 30): 0.10843435424175736
# (66, 31, 30): 0.1301508876440769
#
# Approximating hitting prob for (68, 29, 31)
# (68, 29, 31): 0.1290705233024761
# (67, 30, 31): 0.12895537060894444
#
# Approximating hitting prob for (68, 29, 60)
# (68, 29, 60): 0.21296411098079104
# (67, 30, 60): 0.2049879260365288
# Approximating hitting prob for (68, 29, 90)
# (68, 29, 90): 0.2967776696445605
# (67, 30, 90): 0.29117744231009374
#
# Approximating hitting prob for (68, 30, 31)
# (68, 30, 31): 0.12792651857112755
# (67, 31, 31): 0.10990967383218099
#
# Approximating hitting prob for (68, 30, 62)
# (68, 30, 62): 0.2165059105118002
# (67, 31, 62): 0.20898276303123534
#
# Approximating hitting prob for (68, 30, 93)
# (68, 30, 93): 0.29908397988986885
# (67, 31, 93): 0.29342678283219437
#
# Approximating hitting prob for (68, 16, 31)
# (68, 16, 31): 0.10722057815348975
# (67, 17, 31): 0.10912190595124417
#
# Approximating hitting prob for (68, 31, 32)
# (68, 31, 32): 0.13021044184842326
# (67, 32, 32): 0.11059813820044394
#
# Approximating hitting prob for (68, 31, 54)
# (68, 31, 54): 0.20691423031544773
# (67, 32, 54): 0.20685695946301497
#
# Approximating hitting prob for (68, 31, 64)
# (68, 31, 64): 0.22055856027996823
# (67, 32, 64): 0.21186901622643686
#
# Approximating hitting prob for (68, 31, 75)
# (68, 31, 75): 0.2911644196174936
# (67, 32, 75): 0.29098050012089477
#
# Approximating hitting prob for (68, 31, 96)
# (68, 31, 96): 0.3008447382763448
# (67, 32, 96): 0.2947595410795502
#
# Approximating hitting prob for (67, 33, 33)
# (67, 33, 33): 0.11102905287764252
# (66, 34, 33): 0.19817005908951535
#
# Approximating hitting prob for (67, 33, 55)
# (67, 33, 55): 0.20734882409761424
# (66, 34, 55): 0.2252183981446213
#
# Approximating hitting prob for (67, 33, 66)
# (67, 33, 66): 0.2145274327354402
# (66, 34, 66): 0.2957982301669219
#
# Approximating hitting prob for (67, 33, 77)
# (67, 33, 77): 0.2917225363157984
# (66, 34, 77): 0.3072200141824042
#
# Approximating hitting prob for (67, 33, 99)
# (67, 33, 99): 0.2957426559870899
# (66, 34, 99): 0.32175840511302617
#
# Approximating hitting prob for (68, 17, 33)
# (68, 17, 33): 0.11069936824987907
# (67, 18, 33): 0.1150970726428654
#
# Approximating hitting prob for (68, 34, 35)
# (68, 34, 35): 0.19816495086407981
# (67, 35, 35): 0.16389413897432256
#
# Approximating hitting prob for (68, 34, 57)
# (68, 34, 57): 0.2267734793299746
# (67, 35, 57): 0.22635999616232605
#
# Approximating hitting prob for (68, 34, 70)
# (68, 34, 70): 0.3005655991303914
# (67, 35, 70): 0.2918123238811173
#
# Approximating hitting prob for (68, 18, 35)
# (68, 18, 35): 0.11685772020882362
# (67, 19, 35): 0.11907541582731461
#
# Approximating hitting prob for (68, 35, 36)
# (68, 35, 36): 0.20504382662565881
# (67, 36, 36): 0.16468817916922163
#
# Approximating hitting prob for (68, 35, 58)
# (68, 35, 58): 0.22901533196765364
# (67, 36, 58): 0.22822100249874358
#
# Approximating hitting prob for (68, 35, 69)
# (68, 35, 69): 0.30136087279125473
# (67, 36, 69): 0.30094747703337965
#
# Approximating hitting prob for (68, 35, 72)
# (68, 35, 72): 0.30217219673222223
# (67, 36, 72): 0.2931453595957316
#
# Approximating hitting prob for (68, 35, 82)
# (68, 35, 82): 0.31041926907085343
# (67, 36, 82): 0.30980058377300596
#
# Approximating hitting prob for (68, 36, 37)
# (68, 36, 37): 0.20610322279176196
# (67, 37, 37): 0.1656862733718747
#
# Approximating hitting prob for (68, 36, 59)
# (68, 36, 59): 0.23051853761514352
# (67, 37, 59): 0.22992472268830566
#
# Approximating hitting prob for (68, 36, 70)
# (68, 36, 70): 0.3021932957486554
# (67, 37, 70): 0.30211719482305277
#
# Approximating hitting prob for (68, 36, 74)
# (68, 36, 74): 0.30392363521024407
# (67, 37, 74): 0.2942073260928382
#
# Approximating hitting prob for (68, 36, 83)
# (68, 36, 83): 0.31145289766822554
# (67, 37, 83): 0.3108419991280095
#
# Approximating hitting prob for (67, 38, 38)
# (67, 38, 38): 0.1670349695461166
# (66, 39, 38): 0.21005399555870596
#
# Approximating hitting prob for (67, 38, 57)
# (67, 38, 57): 0.22588864650852458
# (66, 39, 57): 0.23236984156429277
#
# Approximating hitting prob for (67, 38, 71)
# (67, 38, 71): 0.3032015044874939
# (66, 39, 71): 0.3053216152447503
#
# Approximating hitting prob for (67, 38, 76)
# (67, 38, 76): 0.29622149525982644
# (66, 39, 76): 0.3083509989249084
#
# Approximating hitting prob for (67, 38, 85)
# (67, 38, 85): 0.31184204024026574
# (66, 39, 85): 0.3165879260196138
#
# Approximating hitting prob for (68, 13, 38)
# (68, 13, 38): 0.10859448369733767
# (67, 14, 38): 0.11419087184891612
#
# Approximating hitting prob for (67, 39, 39)
# (67, 39, 39): 0.16793627033468786
# (66, 40, 39): 0.21332214014311837
#
# Approximating hitting prob for (67, 39, 61)
# (67, 39, 61): 0.23534865984976275
# (66, 40, 61): 0.23885009798049514
#
# Approximating hitting prob for (67, 39, 72)
# (67, 39, 72): 0.3042249733675388
# (66, 40, 72): 0.30844066753686655
#
# Approximating hitting prob for (67, 39, 78)
# (67, 39, 78): 0.2975238587468357
# (66, 40, 78): 0.31392352100379023
#
# Approximating hitting prob for (68, 20, 39)
# (68, 20, 39): 0.12625833484334756
# (67, 21, 39): 0.12932711067017608
#
# Approximating hitting prob for (68, 39, 40)
# (68, 39, 40): 0.20984955110974124
# (67, 40, 40): 0.16913098722626932
#
# Approximating hitting prob for (68, 39, 60)
# (68, 39, 60): 0.23286596625949998
# (67, 40, 60): 0.23197889243718972
#
# Approximating hitting prob for (68, 39, 62)
# (68, 39, 62): 0.2377655478911539
# (67, 40, 62): 0.23704332755972243
#
# Approximating hitting prob for (68, 39, 80)
# (68, 39, 80): 0.30865351009713227
# (67, 40, 80): 0.29850690494733
#
# Approximating hitting prob for (68, 39, 88)
# (68, 39, 88): 0.31792819417459806
# (67, 40, 88): 0.317110120086775
#
# Approximating hitting prob for (68, 40, 41)
# (68, 40, 41): 0.21284175195127528
# (67, 41, 41): 0.17459073206208206
#
# Approximating hitting prob for (68, 40, 82)
# (68, 40, 82): 0.3103914658757683
# (67, 41, 82): 0.3055487059702478
#
# Approximating hitting prob for (68, 14, 41)
# (68, 14, 41): 0.12127440937698557
# (67, 15, 41): 0.12328427293585976
#
# Approximating hitting prob for (67, 28, 42)
# (67, 28, 42): 0.18241115143068817
# (66, 29, 42): 0.18562479187106495
#
# Approximating hitting prob for (67, 42, 42)
# (67, 42, 42): 0.17674812166989592
# (66, 43, 42): 0.21991146184488505
#
# Approximating hitting prob for (67, 42, 63)
# (67, 42, 63): 0.23740856000675778
# (66, 43, 63): 0.2434388563664952
#
# Approximating hitting prob for (67, 42, 64)
# (67, 42, 64): 0.24107455437674807
# (66, 43, 64): 0.2418198065177304
#
# Approximating hitting prob for (67, 42, 84)
# (67, 42, 84): 0.30677885178364633
# (66, 43, 84): 0.32007501793363335
#
# Approximating hitting prob for (67, 43, 43)
# (67, 43, 43): 0.17724480333029727
# (66, 44, 43): 0.22158069054011553
#
# Approximating hitting prob for (67, 43, 65)
# (67, 43, 65): 0.24184526436294332
# (66, 44, 65): 0.24925499267680654
#
# Approximating hitting prob for (67, 43, 86)
# (67, 43, 86): 0.3087515775217032
# (66, 44, 86): 0.3232102340100872
#
# Approximating hitting prob for (67, 11, 44)
# (67, 11, 44): 0.11341333392200868
# (66, 12, 44): 0.12296060234836871
#
# Approximating hitting prob for (68, 22, 43)
# (68, 22, 43): 0.13450800037433006
# (67, 23, 43): 0.14694093842455236
#
# Approximating hitting prob for (68, 43, 44)
# (68, 43, 44): 0.2194889441565222
# (67, 44, 44): 0.1785700105600461
#
# Approximating hitting prob for (68, 43, 66)
# (68, 43, 66): 0.24467217162437419
# (67, 44, 66): 0.23968194758105135
#
# ...
# (73, 11, 32): 0.08372719423822006
# (72, 12, 32): 0.08765940238605618
#
# Approximating hitting prob for (73, 32, 33)
# (73, 32, 33): 0.12729720294293576
# (72, 33, 33): 0.10969679708428047
#
# Approximating hitting prob for (73, 32, 66)
# (73, 32, 66): 0.21559348732234693
# (72, 33, 66): 0.2078577804526379
#
# Approximating hitting prob for (73, 32, 99)
# (73, 32, 99): 0.2988496216318996
# (72, 33, 99): 0.2929638582195892
#
# Approximating hitting prob for (72, 34, 34)
# (72, 34, 34): 0.11039969575494074
# (71, 35, 34): 0.13526241983003273
#
# Approximating hitting prob for (72, 34, 68)
# (72, 34, 68): 0.21114667219584285
# (71, 35, 68): 0.22342593381231843
#
# Approximating hitting prob for (72, 7, 35)
# (72, 7, 35): 0.07868980220241667
# (71, 8, 35): 0.08502569472506853
#
# Approximating hitting prob for (72, 35, 35)
# (72, 35, 35): 0.1108746277917151
# (71, 36, 35): 0.16827254666866986
#
# Approximating hitting prob for (72, 35, 70)
# (72, 35, 70): 0.21364927523491395
# (71, 36, 70): 0.23947721404754554
#
# Approximating hitting prob for (72, 35, 82)
# (72, 35, 82): 0.2918483296748942
# (71, 36, 82): 0.3058273293694039
#
# Approximating hitting prob for (73, 18, 35)
# (73, 18, 35): 0.11010850332479871
# (72, 19, 35): 0.1145011387113871
#
# Approximating hitting prob for (73, 36, 37)
# (73, 36, 37): 0.16827145146486341
# (72, 37, 37): 0.16362210071388544
#
# Approximating hitting prob for (72, 38, 38)
# (72, 38, 38): 0.16418081559580924
# (71, 39, 38): 0.2065848334145051
#
# Approximating hitting prob for (72, 38, 76)
# (72, 38, 76): 0.2921929398140363
# (71, 39, 76): 0.30416491690900554
#
# Approximating hitting prob for (72, 38, 86)
# (72, 38, 86): 0.3091167282235807
# (71, 39, 86): 0.309915747897842
#
# Approximating hitting prob for (72, 38, 87)
# (72, 38, 87): 0.3094095989284747
# (71, 39, 87): 0.3104935029362134
#
# Approximating hitting prob for (73, 13, 38)
# (73, 13, 38): 0.10511137277699849
# (72, 14, 38): 0.1069958291935572
#
# Approximating hitting prob for (73, 38, 39)
# (73, 38, 39): 0.20558971006373097
# (72, 39, 39): 0.164859544272948
#
# Approximating hitting prob for (73, 38, 78)
# (73, 38, 78): 0.3027246067446446
# (72, 39, 78): 0.29367583942455894
#
# Approximating hitting prob for (73, 38, 88)
# (73, 38, 88): 0.3106700206998077
# (72, 39, 88): 0.3102446790355082
#
# Approximating hitting prob for (73, 20, 39)
# (73, 20, 39): 0.11902737248645519
# (72, 21, 39): 0.12309590343535352
#
# Approximating hitting prob for (73, 39, 40)
# (73, 39, 40): 0.2064873650411021
# (72, 40, 40): 0.16596084427308347
#
# Approximating hitting prob for (73, 39, 80)
# (73, 39, 80): 0.3043109309350348
# (72, 40, 80): 0.2947727242505657
#
# Approximating hitting prob for (73, 39, 90)
# (73, 39, 90): 0.31170759792525055
# (72, 40, 90): 0.31118231431790383
#
# Approximating hitting prob for (73, 40, 41)
# (73, 40, 41): 0.20760685898118936
# (72, 41, 41): 0.16709500228291183
#
# Approximating hitting prob for (73, 40, 82)
# (73, 40, 82): 0.3060263350845438
# (72, 41, 82): 0.2963503977491479
#
# Approximating hitting prob for (73, 40, 92)
# (73, 40, 92): 0.31265646156970867
# (72, 41, 92): 0.3119668075318885
#
# Approximating hitting prob for (73, 21, 41)
# (73, 21, 41): 0.12438643672347847
# (72, 22, 41): 0.12711686946677606
#
# Approximating hitting prob for (72, 42, 42)
# (72, 42, 42): 0.1681780559678497
# (71, 43, 42): 0.21332866087121247
#
# Approximating hitting prob for (72, 42, 84)
# (72, 42, 84): 0.2976354789365605
# (71, 43, 84): 0.31391171717407135
#
# Approximating hitting prob for (72, 43, 43)
# (72, 43, 43): 0.1691366049975969
# (71, 44, 43): 0.2165594116230057
#
# Approximating hitting prob for (72, 43, 86)
# (72, 43, 86): 0.2985133707845321
# (71, 44, 86): 0.31617323726478014
#
# Approximating hitting prob for (72, 43, 95)
# (72, 43, 95): 0.3174023718661068
# (71, 44, 95): 0.32093341810218323
#
# Approximating hitting prob for (73, 22, 43)
# (73, 22, 43): 0.1284702061802625
# (72, 23, 43): 0.13064163705714496
#
# Approximating hitting prob for (73, 43, 44)
# (73, 43, 44): 0.21289293345661942
# (72, 44, 44): 0.1744884469817859
#
# Approximating hitting prob for (73, 43, 88)
# (73, 43, 88): 0.3103743818965884
# (72, 44, 88): 0.3055227964423127
#
# Approximating hitting prob for (73, 15, 44)
# (73, 15, 44): 0.1212395762837819
# (72, 16, 44): 0.12316747022428848
#
# Approximating hitting prob for (73, 30, 44)
# (73, 30, 44): 0.1826599677755747
# (72, 31, 44): 0.18398198510025196
#
# Approximating hitting prob for (73, 44, 45)
# (73, 44, 45): 0.21626419314800593
# (72, 45, 45): 0.17595019969795658
#
# Approximating hitting prob for (72, 45, 90)
# (72, 45, 90): 0.306556505077879
# (71, 46, 90): 0.31952145176715935
#
# Approximating hitting prob for (72, 45, 98)
# (72, 45, 98): 0.3216273603803931
# (71, 46, 98): 0.32351840714598906
#
# Approximating hitting prob for (73, 23, 45)
# (73, 23, 45): 0.13274153910559686
# (72, 24, 45): 0.14403345626987496
#
# Approximating hitting prob for (73, 45, 46)
# (73, 45, 46): 0.2175721586827392
# (72, 46, 46): 0.17715740532268057
#
# Approximating hitting prob for (73, 45, 69)
# (73, 45, 69): 0.2403035896382304
# (72, 46, 69): 0.23852566716749682
#
# Approximating hitting prob for (73, 45, 70)
# (73, 45, 70): 0.24380466176146984
# (72, 46, 70): 0.24341872286617292
#
# Approximating hitting prob for (73, 45, 92)
# (73, 45, 92): 0.31732212169855883
# (72, 46, 92): 0.30865287787852985
#
# Approximating hitting prob for (73, 46, 47)
# (73, 46, 47): 0.21920954906981072
# (72, 47, 47): 0.17835682371532766
#
# Approximating hitting prob for (73, 46, 71)
# (73, 46, 71): 0.2449314919320136
# (72, 47, 71): 0.24411124273608675
#
# Approximating hitting prob for (73, 46, 94)
# (73, 46, 94): 0.3189457086222573
# (72, 47, 94): 0.3096847100671601
#
# Approximating hitting prob for (72, 32, 48)
# (72, 32, 48): 0.186381897996191
# (71, 33, 48): 0.19230015905092354
#
# Approximating hitting prob for (72, 48, 48)
# (72, 48, 48): 0.18348623853210444
# (71, 49, 48): 0.22807615630316425
#
# Approximating hitting prob for (72, 48, 96)
# (72, 48, 96): 0.31260403488913774
# (71, 49, 96): 0.32512235005672635
#
# Approximating hitting prob for (72, 49, 49)
# (72, 49, 49): 0.18530248679255865
# (71, 50, 49): 0.22987019498785996
#
# Approximating hitting prob for (72, 49, 98)
# (72, 49, 98): 0.31401935361881417
# (71, 50, 98): 0.3262022233757413
#
# Approximating hitting prob for (72, 25, 50)
# (72, 25, 50): 0.17711063716812178
# (71, 26, 50): 0.1874557303702733
#
# Approximating hitting prob for (72, 50, 50)
# (72, 50, 50): 0.18642618706456793
# (71, 51, 50): 0.23178696491533024
#
# Approximating hitting prob for (72, 50, 100)
# (72, 50, 100): 0.31516825497417145
# (71, 51, 100): 0.3279764048157509
#
# Approximating hitting prob for (73, 17, 50)
# (73, 17, 50): 0.12942101886175278
# (72, 18, 50): 0.13378861105756865
#
# Approximating hitting prob for (73, 50, 51)
# (73, 50, 51): 0.22882210447875162
# (72, 51, 51): 0.18865411987950534
#
# Approximating hitting prob for (73, 26, 51)
# (73, 26, 51): 0.1865353444600691
# (72, 27, 51): 0.1874701596169277
#
# Approximating hitting prob for (73, 51, 52)
# (73, 51, 52): 0.2308745962008694
# (72, 52, 52): 0.1901816956072473
#
# Approximating hitting prob for (73, 52, 53)
# (73, 52, 53): 0.23233132665942147
# (72, 53, 53): 0.19092170125504626
#
# Approximating hitting prob for (72, 54, 54)
# (72, 54, 54): 0.19596772116592112
# (71, 55, 54): 0.2440843829771475
#
# Approximating hitting prob for (72, 55, 55)
# (72, 55, 55): 0.20102855555747204
# (71, 56, 55): 0.24529595822811953
#
# Approximating hitting prob for (73, 28, 55)
# (73, 28, 55): 0.19226369969378934
# (72, 29, 55): 0.19470927928348836
#
# Approximating hitting prob for (73, 55, 56)
# (73, 55, 56): 0.24306528434097574
# (72, 56, 56): 0.20249800445937116
#
# Approximating hitting prob for (72, 57, 57)
# (72, 57, 57): 0.20322824139244566
# (71, 58, 57): 0.24806488036001395
#
# Approximating hitting prob for (73, 29, 57)
# (73, 29, 57): 0.19558105678286564
# (72, 30, 57): 0.19974354167257524
#
# Approximating hitting prob for (73, 57, 58)
# (73, 57, 58): 0.2459112913163638
# (72, 58, 58): 0.20483370885874386
#
# Approximating hitting prob for (73, 58, 59)
# (73, 58, 59): 0.24708726555061725
# (72, 59, 59): 0.205616172611685
#
# Approximating hitting prob for (73, 15, 59)
# (73, 15, 59): 0.17211492681410645
# (72, 16, 59): 0.1729676442415997
#
# Approximating hitting prob for (73, 30, 59)
# (73, 30, 59): 0.2014920547755743
# (72, 31, 59): 0.20323805962764022
#
# Approximating hitting prob for (73, 59, 60)
# (73, 59, 60): 0.24834061894580517
# (72, 60, 60): 0.2077770400570025
#
# Approximating hitting prob for (73, 60, 61)
# (73, 60, 61): 0.25022650314620715
# (72, 61, 61): 0.20984990015379476
#
# Approximating hitting prob for (72, 62, 62)
# (72, 62, 62): 0.21168922586146863
# (71, 63, 62): 0.25812424248049265
#
# Approximating hitting prob for (73, 21, 62)
# (73, 21, 62): 0.1854555176723445
# (72, 22, 62): 0.19083619706538835
#
# Approximating hitting prob for (73, 62, 63)
# (73, 62, 63): 0.25510358589257476
# (72, 63, 63): 0.21330055984615426
#
# Approximating hitting prob for (72, 64, 64)
# (72, 64, 64): 0.21480519348587843
# (71, 65, 64): 0.26055946645937816
#
# Approximating hitting prob for (72, 65, 65)
# (72, 65, 65): 0.21573275726135888
# (71, 66, 65): 0.26178927157280096
#
# Approximating hitting prob for (73, 22, 65)
# (73, 22, 65): 0.1924961715407929
# (72, 23, 65): 0.19742275884367913
#
# Approximating hitting prob for (72, 44, 66)
# (72, 44, 66): 0.2358685136831884
# (71, 45, 66): 0.23982372899921975
#
# Approximating hitting prob for (72, 66, 66)
# (72, 66, 66): 0.21686811675627718
# (71, 67, 66): 0.2631058966211695
#
# Approximating hitting prob for (72, 67, 67)
# (72, 67, 67): 0.21821430167529035
# (71, 68, 67): 0.2641572895400223
#
# Approximating hitting prob for (73, 34, 67)
# (73, 34, 67): 0.21859293967695917
# (72, 35, 67): 0.22155962223533962
#
# Approximating hitting prob for (73, 67, 68)
# (73, 67, 68): 0.2620085453613603
# (72, 68, 68): 0.21927987391303042
#
# Approximating hitting prob for (73, 46, 68)
# (73, 46, 68): 0.23966710418949122
# (72, 47, 68): 0.24703475398009034
#
# Approximating hitting prob for (73, 68, 69)
# (73, 68, 69): 0.2632040333138858
# (72, 69, 69): 0.22016530937311132
#
# Approximating hitting prob for (72, 70, 70)
# (72, 70, 70): 0.22107022763446207
# (71, 71, 70): 0.32210681550947706
#
# Approximating hitting prob for (72, 71, 71)
# (72, 71, 71): 0.22176535035168643
# (71, 72, 71): 0.3891173248239028
#
# Approximating hitting prob for (72, 37, 74)
# (72, 37, 74): 0.2912525039014997
# (71, 38, 74): 0.3029775908905337
#
# Approximating hitting prob for (72, 74, 74)
# (72, 74, 74): 0.35612167590438565
# (71, 75, 74): 0.40146198404491806
#
# Approximating hitting prob for (72, 15, 75)
# (72, 15, 75): 0.2522750628474802
# (71, 16, 75): 0.2557398869956367
#
# Approximating hitting prob for (72, 25, 75)
# (72, 25, 75): 0.27183303812635956
# (71, 26, 75): 0.2806585802749209
#
# Approximating hitting prob for (72, 75, 75)
# (72, 75, 75): 0.3565953315145561
# (71, 76, 75): 0.4019592386849853
#
# Approximating hitting prob for (72, 75, 89)
# (72, 75, 89): 0.41021094607127834
# (71, 76, 89): 0.4111787139156125
#
# Approximating hitting prob for (72, 19, 76)
# (72, 19, 76): 0.25774247702073627
# (71, 20, 76): 0.2614969283802661
#
# Approximating hitting prob for (73, 38, 75)
# (73, 38, 75): 0.30176649321742127
# (72, 39, 75): 0.30316751475308007
#
# Approximating hitting prob for (73, 75, 76)
# (73, 75, 76): 0.40095096371400113
# (72, 76, 76): 0.357081224342597
#
# Approximating hitting prob for (73, 76, 77)
# (73, 76, 77): 0.4014041490267711
# (72, 77, 77): 0.35754663147039034
#
# Approximating hitting prob for (73, 39, 77)
# (73, 39, 77): 0.303014197444721
# (72, 40, 77): 0.3046555619236741
#
# Approximating hitting prob for (73, 77, 78)
# (73, 77, 78): 0.40195004189189015
# (72, 78, 78): 0.35819501228612277
#
# Approximating hitting prob for (73, 78, 79)
# (73, 78, 79): 0.4024833927275555
# (72, 79, 79): 0.3586474715064372
#
# Approximating hitting prob for (73, 20, 79)
# (73, 20, 79): 0.261126741955882
# (72, 21, 79): 0.26302018234830205
#
# Approximating hitting prob for (72, 80, 80)
# (72, 80, 80): 0.35936162658100074
# (71, 81, 80): 0.4058255158067621
#
# Approximating hitting prob for (73, 27, 80)
# (73, 27, 80): 0.2817839998244378
# (72, 28, 80): 0.2857336814042574
#
# Approximating hitting prob for (73, 80, 81)
# (73, 80, 81): 0.4038924615944828
# (72, 81, 81): 0.36029471770517746
#
# Approximating hitting prob for (72, 82, 82)
# (72, 82, 82): 0.36100881822537284
# (71, 83, 82): 0.4073656685679293
#
# Approximating hitting prob for (72, 83, 83)
# (72, 83, 83): 0.36160421624935185
# (71, 84, 83): 0.408579216711269
#
# Approximating hitting prob for (73, 14, 83)
# (73, 14, 83): 0.25460138286811385
# (72, 15, 83): 0.25869878368072796
#
# Approximating hitting prob for (73, 28, 83)
# (73, 28, 83): 0.2866821801598257
# (72, 29, 83): 0.28814261873276803
#
# Approximating hitting prob for (72, 84, 84)
# (72, 84, 84): 0.3626759287590275
# (71, 85, 84): 0.40887726818200026
#
# Approximating hitting prob for (73, 17, 84)
# (73, 17, 84): 0.2598850252781717
# (72, 18, 84): 0.26327528449465554
#
# Approximating hitting prob for (73, 51, 84)
# (73, 51, 84): 0.320430927645394
# (72, 52, 84): 0.32410310878820114
#
# Approximating hitting prob for (73, 84, 85)
# (73, 84, 85): 0.40659772755225077
# (72, 85, 85): 0.3635080595286175
#
# Approximating hitting prob for (72, 86, 86)
# (72, 86, 86): 0.3640313485020596
# (71, 87, 86): 0.41068344660533634
#
# Approximating hitting prob for (73, 29, 86)
# (73, 29, 86): 0.28875510578639707
# (72, 30, 86): 0.2918383644697366
#
# Approximating hitting prob for (73, 86, 87)
# (73, 86, 87): 0.4087958950988175
# (72, 87, 87): 0.3652114698692203
#
# Approximating hitting prob for (73, 44, 87)
# (73, 44, 87): 0.3137973405536047
# (72, 45, 87): 0.31605570424869295
#
# Approximating hitting prob for (73, 87, 88)
# (73, 87, 88): 0.409692652637158
# (72, 88, 88): 0.36574702933319064
#
# Approximating hitting prob for (73, 88, 89)
# (73, 88, 89): 0.4105367092304822
# (72, 89, 89): 0.36610983078474985
#
# Approximating hitting prob for (73, 15, 89)
# (73, 15, 89): 0.2724160927688974
# (72, 16, 89): 0.2733942885015635
#
# Approximating hitting prob for (73, 45, 89)
# (73, 45, 89): 0.31629257096269797
# (72, 46, 89): 0.3176434568531943
#
# Approximating hitting prob for (73, 89, 90)
# (73, 89, 90): 0.41100077850688416
# (72, 90, 90): 0.3679559744936582
#
# Approximating hitting prob for (73, 90, 91)
# (73, 90, 91): 0.4111626662031611
# (72, 91, 91): 0.3698041081138348
#
# Approximating hitting prob for (73, 46, 91)
# (73, 46, 91): 0.317463389458118
# (72, 47, 91): 0.3196627014218094
#
# Approximating hitting prob for (73, 91, 92)
# (73, 91, 92): 0.41416040964810813
# (72, 92, 92): 0.37011104261802935
#
# Approximating hitting prob for (72, 93, 93)
# (72, 93, 93): 0.37104945114207005
# (71, 94, 93): 0.41703319899980645
#
# Approximating hitting prob for (73, 47, 93)
# (73, 47, 93): 0.31966120627934397
# (72, 48, 93): 0.32315061807159745
#
# Approximating hitting prob for (73, 93, 94)
# (73, 93, 94): 0.41573768724380256
# (72, 94, 94): 0.37139949541556505
#
# Approximating hitting prob for (73, 19, 94)
# (73, 19, 94): 0.2803780730106167
# (72, 20, 94): 0.2813650034715626
#
# Approximating hitting prob for (73, 57, 94)
# (73, 57, 94): 0.3367440772340872
# (72, 58, 94): 0.3380568119131291
#
# Approximating hitting prob for (73, 94, 95)
# (73, 94, 95): 0.41638540397428153
# (72, 95, 95): 0.3717531713786137
#
# Approximating hitting prob for (73, 16, 95)
# (73, 16, 95): 0.275501981713298
# (72, 17, 95): 0.27748648623231936
#
# Approximating hitting prob for (73, 48, 95)
# (73, 48, 95): 0.32078426256483156
# (72, 49, 95): 0.3242708044187505
#
# Approximating hitting prob for (73, 95, 96)
# (73, 95, 96): 0.41678926251832893
# (72, 96, 96): 0.37265977777400555
#
# Approximating hitting prob for (73, 96, 97)
# (73, 96, 97): 0.4167959633997933
# (72, 97, 97): 0.3741528552519655
#
# Approximating hitting prob for (73, 13, 97)
# (73, 13, 97): 0.2709912940500368
# (72, 14, 97): 0.27320090317187984
#
# Approximating hitting prob for (73, 14, 97)
# (73, 14, 97): 0.27253106604665334
# (72, 15, 97): 0.27584498359256643
#
# Approximating hitting prob for (72, 98, 98)
# (72, 98, 98): 0.3745564473811194
# (71, 99, 98): 0.42091262831834136
#
# Approximating hitting prob for (73, 33, 98)
# (73, 33, 98): 0.2988077139233725
# (72, 34, 98): 0.30090307825969403
#
# Approximating hitting prob for (73, 54, 98)
# (73, 54, 98): 0.3294300198190662
# (72, 55, 98): 0.3303065397162613
#
# Approximating hitting prob for (73, 98, 99)
# (73, 98, 99): 0.4195760252363052
# (72, 99, 99): 0.37501017380220114
#
# Approximating hitting prob for (73, 50, 99)
# (73, 50, 99): 0.3250890748988568
# (72, 51, 99): 0.32647315107050373
