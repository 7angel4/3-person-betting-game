# %%
# %run 'game1_global.ipynb'
# %run 'game1_loser_analysis.ipynb'

# %% [markdown]
# # When is player 1 better off giving away $1?

# %%
betterGiving1 = findBetterGiving1(1,1000)
betterGiving1

# %%
exportStateProbs(DATA_DIR + 'game1_better_giving_1_memo_1-1000.csv', betterGiving1)

# %%
# retrieve probabilities from file
betterGiving1, given1 = readApproxBetterGiving1Probs(DATA_DIR + 'game1_better_giving_1_memo_1-100.csv')

# %%
betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
                                       filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv')
# Out:
# Approximating hitting prob for (11, 19, 48)
# (11, 19, 48): 0.5334260883826906
# (10, 19, 48): 0.5333426632228018
#
# Approximating hitting prob for (12, 21, 53)
# (12, 21, 53): 0.5340626283748265
# (11, 21, 53): 0.5334548685835285
#
# Approximating hitting prob for (12, 32, 42)
# (12, 32, 42): 0.5301153617677242
# (11, 32, 42): 0.5299467192997049
#
# Approximating hitting prob for (13, 22, 56)
# (13, 22, 56): 0.5328628830327213
# (12, 22, 56): 0.532734806781722
#
# Approximating hitting prob for (13, 23, 58)
# (13, 23, 58): 0.5343093271797525
# (12, 23, 58): 0.5335330764863161
#
# Approximating hitting prob for (13, 35, 46)
# (13, 35, 46): 0.5303291922468697
# (12, 35, 46): 0.5299937351500015
#
# Approximating hitting prob for (14, 24, 61)
# (14, 24, 61): 0.5334281050874531
# (13, 24, 61): 0.532844623278078
#
# Approximating hitting prob for (14, 25, 63)
# (14, 25, 63): 0.534598505539718
# (13, 25, 63): 0.5335740856592848
#
# Approximating hitting prob for (14, 38, 50)
# (14, 38, 50): 0.5306453312687435
# (13, 38, 50): 0.5300535494230575
#
# Approximating hitting prob for (15, 26, 66)
# (15, 26, 66): 0.5335384252806683
# (14, 26, 66): 0.532976559038264
#
# Approximating hitting prob for (15, 27, 68)
# (15, 27, 68): 0.5347937376379311
# (14, 27, 68): 0.5336038259570041
#
# Approximating hitting prob for (15, 40, 52)
# (15, 40, 52): 0.5298390830172897
# (14, 40, 52): 0.5294060634902246
#
# Approximating hitting prob for (15, 41, 54)
# (15, 41, 54): 0.530814252978444
# (14, 41, 54): 0.5300859465232839
#
# Approximating hitting prob for (16, 27, 69)
# (16, 27, 69): 0.5327214805171471
# (15, 27, 69): 0.5323471322790065
#
# Approximating hitting prob for (16, 28, 71)
# (16, 28, 71): 0.533984832978568
# (15, 28, 71): 0.5330636314503749
#
# Approximating hitting prob for (16, 29, 73)
# (16, 29, 73): 0.5349109988994238
# (15, 29, 73): 0.5336260136575318
#
# Approximating hitting prob for (16, 42, 54)
# (16, 42, 54): 0.528455476635441
# (15, 42, 54): 0.5285157285081951
#
# Approximating hitting prob for (16, 43, 56)
# (16, 43, 56): 0.5300165256608894
# (15, 43, 56): 0.5295344851774494
#
# Approximating hitting prob for (16, 44, 58)
# (16, 44, 58): 0.5309755142180325
# (15, 44, 58): 0.5301059314171186
#
# Approximating hitting prob for (17, 29, 74)
# (17, 29, 74): 0.5332717628242919
# (16, 29, 74): 0.5324865172144486
#
# Approximating hitting prob for (17, 30, 76)
# (17, 30, 76): 0.5341834675713876
# (16, 30, 76): 0.5331293350131605
#
# Approximating hitting prob for (17, 31, 78)
# (17, 31, 78): 0.535032026741298
# (16, 31, 78): 0.5336384909534596
#
# Approximating hitting prob for (17, 44, 56)
# (17, 44, 56): 0.5279972266134371
# (16, 44, 56): 0.5279422800090446
#
# Approximating hitting prob for (17, 45, 58)
# (17, 45, 58): 0.529004914693246
# (16, 45, 58): 0.528895160602941
#
# Approximating hitting prob for (17, 46, 60)
# (17, 46, 60): 0.5301804342251579
# (16, 46, 60): 0.5296194711867167
#
# Approximating hitting prob for (17, 47, 62)
# (17, 47, 62): 0.5311378673662993
# (16, 47, 62): 0.5301263625686753
#
# Approximating hitting prob for (18, 27, 71)
# (18, 27, 71): 0.525620501017532
# (17, 27, 71): 0.5254981980685945
#
# Approximating hitting prob for (18, 28, 73)
# (18, 28, 73): 0.5271004988262395
# (17, 28, 73): 0.5270411065910542
#
# Approximating hitting prob for (18, 31, 79)
# (18, 31, 79): 0.5335270635741508
# (17, 31, 79): 0.5326072076759126
#
# Approximating hitting prob for (18, 32, 81)
# (18, 32, 81): 0.5344121912790228
# (17, 32, 81): 0.5332080138741222
#
# Approximating hitting prob for (18, 33, 83)
# (18, 33, 83): 0.5351589143653502
# (17, 33, 83): 0.5336649245359243
#
# Approximating hitting prob for (18, 45, 56)
# (18, 45, 56): 0.5255722330999105
# (17, 45, 56): 0.5254786841463105
#
# Approximating hitting prob for (18, 47, 60)
# (18, 47, 60): 0.5284828625145415
# (17, 47, 60): 0.5281888889502253
#
# Approximating hitting prob for (18, 48, 62)
# (18, 48, 62): 0.5294526933438758
# (17, 48, 62): 0.5290045013080626
#
# Approximating hitting prob for (18, 49, 64)
# (18, 49, 64): 0.5304295920255223
# (17, 49, 64): 0.5297020995866109
#
# Approximating hitting prob for (18, 50, 66)
# (18, 50, 66): 0.5312826982045813
# (17, 50, 66): 0.5301457096165415
#
# Approximating hitting prob for (19, 20, 58)
# (19, 20, 58): 0.5076781471384154
# (18, 20, 58): 0.507459734940809
#
# Approximating hitting prob for (19, 32, 82)
# (19, 32, 82): 0.5327246501234508
# (18, 32, 82): 0.5320769507714677
#
# Approximating hitting prob for (19, 33, 84)
# (19, 33, 84): 0.5335489429772609
# (18, 33, 84): 0.532734806781722
#
# Approximating hitting prob for (19, 34, 86)
# (19, 34, 86): 0.5345634156030413
# (18, 34, 86): 0.5332648124986303
#
# Approximating hitting prob for (19, 35, 88)
# (19, 35, 88): 0.5345634156030413
# (18, 35, 88): 0.5332648124986303
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/659592125.py:18, in stricterFilter(candidates, timeLim, t, printOnGo, filename, continueFrom)
#      17 try:
# ---> 18     pLarge = LoserAnalysis(sLarge).getHittingProb()  # exact probs
#      19     pSmall = LoserAnalysis(sSmall).getHittingProb()
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:68, in LoserAnalysis.getHittingProb(self, asFloat, approx, t)
#      66     return Q(x, y, z, t)
# ---> 68 sol = self.solveEqns()
#      69 if sol:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:46, in LoserAnalysis.solveEqns(self, asFloat)
#      45 self.getEquations()
# ---> 46 sol = solve(self.equations, self.symbols)
#      47 return {s:float(p) for s, p in sol.items() if sol} if asFloat else sol
#
# File /usr/local/lib/python3.9/site-packages/sympy/solvers/solvers.py:1147, in solve(f, *symbols, **flags)
#    1146 else:
# -> 1147     linear, solution = _solve_system(f, symbols, **flags)
#    1148 assert type(solution) is list
#
# File /usr/local/lib/python3.9/site-packages/sympy/solvers/solvers.py:1799, in _solve_system(exprs, symbols, **flags)
#    1797     continue
# -> 1799 poly = g.as_poly(*symbols, extension=True)
#    1801 if poly is not None:
#
# File /usr/local/lib/python3.9/site-packages/sympy/core/expr.py:1102, in Expr.as_poly(self, *gens, **args)
#    1101 try:
# -> 1102     poly = Poly(self, *gens, **args)
#    1104     if not poly.is_Poly:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:182, in Poly.__new__(cls, rep, *gens, **args)
#     181 else:
# --> 182     return cls._from_expr(rep, opt)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:312, in Poly._from_expr(cls, rep, opt)
#     311 rep, opt = _dict_from_expr(rep, opt)
# --> 312 return cls._from_dict(rep, opt)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:261, in Poly._from_dict(cls, rep, opt)
#     259         rep[monom] = domain.convert(coeff)
# --> 261 return cls.new(DMP.from_dict(rep, level, domain), *gens)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polyclasses.py:279, in DMP.from_dict(cls, rep, lev, dom)
#     278 """Construct and instance of ``cls`` from a ``dict`` representation. """
# --> 279 return cls(dmp_from_dict(rep, lev, dom), dom, lev)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
#     [... skipping similar frames: dmp_from_dict at line 1012 (2958 times)]
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:998, in dmp_from_dict(f, u, K)
#     996 coeffs = {}
# --> 998 for monom, coeff in f.items():
#     999     head, tail = monom[0], monom[1:]
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# TimeoutException                          Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
#       2                                        filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv')
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/659592125.py:23, in stricterFilter(candidates, timeLim, t, printOnGo, filename, continueFrom)
#      21 except (TimeoutException, RecursionError):
#      22     print(f'Approximating hitting prob for {sLarge}')
# ---> 23     pLarge = LoserAnalysis(sLarge).getHittingProb(approx=True, t=t)
#      24     pSmall = LoserAnalysis(sSmall).getHittingProb(approx=True, t=t)
#      26 finally:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:66, in LoserAnalysis.getHittingProb(self, asFloat, approx, t)
#      64 if approx:
#      65     x, y, z = self.initState
# ---> 66     return Q(x, y, z, t)
#      68 sol = self.solveEqns()
#      69 if sol:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:31, in Q(x, y, z, t)
#      29 if x==0: return 1
#      30 if z*y==0: return 0
# ---> 31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
#      33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:31, in Q(x, y, z, t)
#      29 if x==0: return 1
#      30 if z*y==0: return 0
# ---> 31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
#      33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
#     [... skipping similar frames: memoize.<locals>.memodict.__call__ at line 8 (11 times), <genexpr> at line 33 (10 times), Q at line 33 (10 times), memoize.<locals>.memodict.__missing__ at line 11 (10 times)]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2027475117.py:12, in sigalarmHandler(signum, frame)
#       8 """
#       9 Handler function to be called when SIGALRM is received.
#      10 """
#      11 # We get signal!
# ---> 12 raise TimeoutException()
#
# TimeoutException:

# %%
betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
                                       filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv',
                                       continueFrom=(69,64,100))
# Out:
# Approximating hitting prob for (70, 12, 93)
# (70, 12, 93): 0.27064890356707977
# (69, 12, 93): 0.2704508979612977
#
# Approximating hitting prob for (70, 13, 95)
# (70, 13, 95): 0.273002814385276
# (69, 13, 95): 0.2728333555110289
#
# Approximating hitting prob for (70, 15, 99)
# (70, 15, 99): 0.2777183843625525
# (69, 15, 99): 0.27732957441332723
#
# Approximating hitting prob for (70, 30, 84)
# (70, 30, 84): 0.2928672871530125
# (69, 30, 84): 0.29290071879804375
#
# Approximating hitting prob for (70, 50, 94)
# (70, 50, 94): 0.32695735265836573
# (69, 50, 94): 0.3267132634013896
#
# Approximating hitting prob for (70, 58, 98)
# (70, 58, 98): 0.3430616778838396
# (69, 58, 98): 0.3428394039934912
#
# Approximating hitting prob for (70, 60, 99)
# (70, 60, 99): 0.34560612414415176
# (69, 60, 99): 0.34492499438010804
#
# Approximating hitting prob for (70, 84, 90)
# (70, 84, 90): 0.4148018936715927
# (69, 84, 90): 0.41468720846314083
#
# Approximating hitting prob for (71, 12, 94)
# (71, 12, 94): 0.27043453644878807
# (70, 12, 94): 0.2702550831661171
#
# Approximating hitting prob for (71, 15, 100)
# (71, 15, 100): 0.2774240055525448
# (70, 15, 100): 0.27714908068396565
#
# Approximating hitting prob for (71, 36, 88)
# (71, 36, 88): 0.3107284046458855
# (70, 36, 88): 0.3107029569244443
#
# Approximating hitting prob for (71, 44, 92)
# (71, 44, 92): 0.31946810865446534
# (70, 44, 92): 0.31933447137280896
#
# Approximating hitting prob for (71, 52, 96)
# (71, 52, 96): 0.3287350571698488
# (70, 52, 96): 0.32848900976647166
#
# Approximating hitting prob for (71, 60, 100)
# (71, 60, 100): 0.3432269284144038
# (70, 60, 100): 0.3428263666917539
#
# Approximating hitting prob for (72, 14, 99)
# (72, 14, 99): 0.27369224353294386
# (71, 14, 99): 0.27347335165357634
#
# Approximating hitting prob for (72, 40, 91)
# (72, 40, 91): 0.3129742549703007
# (71, 40, 91): 0.31282979281170153
#
# Approximating hitting prob for (72, 46, 94)
# (72, 46, 94): 0.32065055730266634
# (71, 46, 94): 0.32060860453920875
#
# Approximating hitting prob for (72, 50, 96)
# (72, 50, 96): 0.32548552599084296
# (71, 50, 96): 0.32522123422559995
#
# Approximating hitting prob for (72, 54, 98)
# (72, 54, 98): 0.33015250293768666
# (71, 54, 98): 0.3299310590778092
#
# Approximating hitting prob for (73, 11, 94)
# (73, 11, 94): 0.26568088778907833
# (72, 11, 94): 0.26555372470314254
#
# Approximating hitting prob for (73, 13, 98)
# (73, 13, 98): 0.2712824779940791
# (72, 13, 98): 0.27092732614422377
#
# Approximating hitting prob for (73, 14, 100)
# (73, 14, 100): 0.2735392177539206
# (72, 14, 100): 0.2733296833190661
#
# Approximating hitting prob for (73, 26, 85)
# (73, 26, 85): 0.2838182327188731
# (72, 26, 85): 0.2838382526274032
#
# Approximating hitting prob for (73, 40, 92)
# (73, 40, 92): 0.31265646156970867
# (72, 40, 92): 0.31256600858492634
#
# Approximating hitting prob for (73, 44, 94)
# (73, 44, 94): 0.31905281367702304
# (72, 44, 94): 0.31898130581150774
#
# Approximating hitting prob for (74, 12, 97)
# (74, 12, 97): 0.26803823241416097
# (73, 12, 97): 0.2678146488650772
#
# Approximating hitting prob for (74, 13, 99)
# (74, 13, 99): 0.27106341315623816
# (73, 13, 99): 0.2708043750088058
#
# Approximating hitting prob for (74, 30, 88)
# (74, 30, 88): 0.29121346643802504
# (73, 30, 88): 0.2911904861374854
#
# Approximating hitting prob for (74, 40, 93)
# (74, 40, 93): 0.3124715276947375
# (73, 40, 93): 0.3123265733297223
#
# Approximating hitting prob for (74, 46, 96)
# (74, 46, 96): 0.3194592906289733
# (73, 46, 96): 0.31936096416339166
#
# Approximating hitting prob for (74, 52, 99)
# (74, 52, 99): 0.32609715069378836
# (73, 52, 99): 0.32593271890358366
#
# Approximating hitting prob for (74, 54, 100)
# (74, 54, 100): 0.3285392810102394
# (73, 54, 100): 0.32834877261967127
#
# Approximating hitting prob for (75, 13, 100)
# (75, 13, 100): 0.2708561821230972
# (74, 13, 100): 0.27060467983388525
#
# Approximating hitting prob for (75, 38, 93)
# (75, 38, 93): 0.3107255922584125
# (74, 38, 93): 0.3106856959891582
#
# Approximating hitting prob for (75, 40, 94)
# (75, 40, 94): 0.31219750777533284
# (74, 40, 94): 0.31212211416489793
#
# Approximating hitting prob for (75, 48, 98)
# (75, 48, 98): 0.3206660566987458
# (74, 48, 98): 0.3206193374288369
#
# Approximating hitting prob for (75, 52, 100)
# (75, 52, 100): 0.32543894655115896
# (74, 52, 100): 0.3251891291627604
#
# Approximating hitting prob for (76, 42, 96)
# (76, 42, 96): 0.31283229353690856
# (75, 42, 96): 0.31269685409230785
#
# Approximating hitting prob for (77, 42, 97)
# (77, 42, 97): 0.31263411481005815
# (76, 42, 97): 0.3124896740010894
#
# Approximating hitting prob for (78, 42, 98)
# (78, 42, 98): 0.312441399741017
# (77, 42, 98): 0.3119828040723916
#
# Approximating hitting prob for (79, 32, 94)
# (79, 32, 94): 0.2912337154122105
# (78, 32, 94): 0.2911642829888588
#
# Approximating hitting prob for (79, 40, 98)
# (79, 40, 98): 0.31073467566545016
# (78, 40, 98): 0.31068391480047436
#
# Approximating hitting prob for (79, 42, 99)
# (79, 42, 99): 0.3121670959474713
# (78, 42, 99): 0.3120607193357822
#
# Approximating hitting prob for (79, 44, 100)
# (79, 44, 100): 0.3130463381703828
# (78, 44, 100): 0.3128490513416133
#
# Approximating hitting prob for (82, 34, 98)
# (82, 34, 98): 0.2917812876569657
# (81, 34, 98): 0.29172992113254753
#
# Approximating hitting prob for (84, 30, 98)
# (84, 30, 98): 0.2839368557613289
# (83, 30, 98): 0.2838357734914572
#
# Approximating hitting prob for (84, 34, 100)
# (84, 34, 100): 0.29123192191006453
# (83, 34, 100): 0.2911447291167216
#
# Approximating hitting prob for (93, 47, 62)
# (93, 47, 62): 0.2078449082948937
# (92, 47, 62): 0.20783817692579917
#
# Approximating hitting prob for (93, 47, 98)
# (93, 47, 98): 0.3020413154785515
# (92, 47, 98): 0.3020379983481061
#
# Approximating hitting prob for (95, 48, 100)
# (95, 48, 100): 0.30201302025080573
# (94, 48, 100): 0.30196433138324996
#
# Approximating hitting prob for (99, 50, 66)
# (99, 50, 66): 0.2078419114332157
# (98, 50, 66): 0.2078180397808808
#
# Approximating hitting prob for (100, 51, 67)
# (100, 51, 67): 0.2080190772886974
# (99, 51, 67): 0.20801576587712575

# %%
class TimeoutException(Exception):
    """
    Custom exception for timeout.
    """
    pass

def sigalarmHandler(signum, frame):
    """
    Handler function to be called when SIGALRM is received.
    """
    # We get signal!
    raise TimeoutException()

# %% [markdown]
# ## When is player 1 better off giving away $1 to another player?

# %%
betterGiving1ToAnother = findBetterGiving1(1,100, t=10, giveToAnother=True)
betterGiving1ToAnother
# Out:
# {(1, 5, 5): 0.5004434876119833,
#  (2, 4, 5): 0.5015168645690443,
#  (1, 6, 6): 0.506093654740131,
#  (2, 5, 6): 0.5184847144955884,
#  (1, 7, 7): 0.5131205254322682,
#  (2, 6, 7): 0.5396071019936831,
#  (1, 8, 8): 0.5177187986883774,
#  (2, 7, 8): 0.553386673567715,
#  (1, 9, 9): 0.5198030383135193,
#  (2, 8, 9): 0.5596511014686955,
#  (1, 10, 10): 0.521353326527545,
#  (2, 9, 10): 0.5643071756348541,
#  (1, 11, 11): 0.5225738105217701,
#  (2, 10, 11): 0.5679767313216567,
#  (1, 12, 12): 0.5237380978085997,
#  (2, 11, 12): 0.5714793837797846,
#  (1, 12, 36): 0.6316713165390184,
#  (2, 11, 36): 0.6317622599451304,
#  (1, 13, 13): 0.5248276325593998,
#  (2, 12, 13): 0.5747622273980084,
#  (1, 13, 39): 0.6325682808186844,
#  (2, 12, 39): 0.6347403712118326,
#  (1, 14, 14): 0.5256858644409728,
#  (2, 13, 14): 0.57733900685236,
#  (1, 14, 42): 0.6333982655030145,
#  (2, 13, 42): 0.6366529115385103,
#  (1, 15, 15): 0.5268432387720368,
#  (2, 14, 15): 0.5808387485922709,
#  (1, 15, 45): 0.63421194355006,
#  (2, 14, 45): 0.6395029512036614,
#  (1, 16, 16): 0.5279858610539553,
#  (2, 15, 16): 0.5842379051719758,
#  (1, 16, 48): 0.635051999980948,
#  (2, 15, 48): 0.6419747628823096,
#  (1, 17, 17): 0.5283821156475977,
#  (2, 16, 17): 0.5854285708426477,
#  (1, 17, 51): 0.6353974162348219,
#  (2, 16, 51): 0.6431331129655032,
#  (1, 18, 18): 0.5286972339709394,
#  (2, 17, 18): 0.586367542078401,
#  (1, 18, 54): 0.635696343688081,
#  (2, 17, 54): 0.6438519942124338,
#  (1, 19, 19): 0.5290239620908059,
#  (2, 18, 19): 0.5873462049262054,
#  (1, 19, 57): 0.6359734242165406,
#  (2, 18, 57): 0.644798126476528,
#  (1, 20, 20): 0.5292680655049197,
#  (2, 19, 20): 0.5880847500592729,
#  (1, 20, 60): 0.6362249863460855,
#  (2, 19, 60): 0.6453717860378668,
#  (1, 21, 21): 0.5295149142555335,
#  (2, 20, 21): 0.588833317324383,
#  (1, 21, 63): 0.6364634998581686,
#  (2, 20, 63): 0.6461849514015902,
#  (1, 21, 64): 0.646956969794154,
#  (2, 20, 64): 0.6472510681012803,
#  (1, 22, 22): 0.5297588522879303,
#  (2, 21, 22): 0.5895697621096462,
#  (1, 22, 66): 0.6366529446148538,
#  (2, 21, 66): 0.6466174245912294,
#  (1, 22, 67): 0.6471532117394029,
#  (2, 21, 67): 0.647774501235203,
#  (1, 23, 23): 0.5299781484445122,
#  (2, 22, 23): 0.5902254013880421,
#  (1, 23, 69): 0.6368433485854967,
#  (2, 22, 69): 0.6472793649130383,
#  (1, 23, 70): 0.647343764553591,
#  (2, 22, 70): 0.6483569921802232,
#  (1, 24, 24): 0.5301334749530051,
#  (2, 23, 24): 0.5907054714357991,
#  (1, 24, 72): 0.6370145682769819,
#  (2, 23, 72): 0.6476786129157565,
#  (1, 24, 73): 0.6475028948415723,
#  (2, 23, 73): 0.6487869019532507,
#  (1, 25, 25): 0.5303300145853443,
#  (2, 24, 25): 0.5913062701368778,
#  (1, 25, 75): 0.6371719124424207,
#  (2, 24, 75): 0.6482151442816559,
#  (1, 25, 76): 0.6476655808364664,
#  (2, 24, 76): 0.6492909523499552,
#  (1, 26, 26): 0.5305056830450136,
#  (2, 25, 26): 0.5918398411700453,
#  (1, 26, 78): 0.6373261970460974,
#  (2, 25, 78): 0.6485752629701603,
#  (1, 26, 79): 0.6478181289321158,
#  (2, 25, 79): 0.6496998090304239,
#  (1, 27, 27): 0.5306651440964284,
#  (2, 26, 27): 0.5923164712780911,
#  (1, 27, 81): 0.6374779182331624,
#  (2, 26, 81): 0.6491023179636827,
#  (1, 27, 82): 0.6479675843896594,
#  (2, 26, 82): 0.6501630597575742,
#  (1, 28, 28): 0.5308433925108808,
#  (2, 27, 28): 0.5928632397722654,
#  (1, 28, 84): 0.6376227926171485,
#  (2, 27, 84): 0.6494288807018324,
#  (1, 28, 85): 0.6481137818273807,
#  (2, 27, 85): 0.6505545513577707,
#  (1, 29, 29): 0.531019424810327,
#  (2, 28, 29): 0.593397753481219,
#  (1, 29, 87): 0.6377697342725956,
#  (2, 28, 87): 0.6499273246583346,
#  (1, 29, 88): 0.6482600123414454,
#  (2, 28, 88): 0.651006837277092,
#  (1, 30, 30): 0.5311653907136445,
#  (2, 29, 30): 0.5938409764824553,
#  (1, 30, 90): 0.6379076957008163,
#  (2, 29, 90): 0.650248810177776,
#  (1, 30, 91): 0.6483932438525631,
#  (2, 29, 91): 0.6513514100842097,
#  (1, 31, 31): 0.5313585565589595,
#  (2, 30, 31): 0.5944358379798981,
#  (1, 31, 93): 0.6380471455644888,
#  (2, 30, 93): 0.6507426069080341,
#  (1, 31, 94): 0.6485374236333384,
#  (2, 30, 94): 0.6518048371373775,
#  (1, 32, 32): 0.5316609404901015,
#  (2, 31, 32): 0.5953108064912191,
#  (1, 32, 96): 0.6382585695513472,
#  (2, 31, 96): 0.651341801406459,
#  (1, 32, 97): 0.6487406281488678,
#  (2, 31, 97): 0.6524211817198429,
#  (1, 33, 33): 0.5317385375916611,
#  (2, 32, 33): 0.5955452681512389,
#  (1, 33, 99): 0.6383231014972734,
#  (2, 32, 99): 0.6515462628230367,
#  (1, 33, 100): 0.6488068966028214,
#  (2, 32, 100): 0.6526188624860286,
#  (1, 34, 34): 0.5318062779428949,
#  (2, 33, 34): 0.5957485718957984,
#  (1, 35, 35): 0.5318679983996342,
#  (2, 34, 35): 0.5959310706203745,
#  (1, 36, 36): 0.5319251873973311,
#  (2, 35, 36): 0.5961088063515048,
#  (1, 37, 37): 0.5319769849510576,
#  (2, 36, 37): 0.5962632397987264,
#  (1, 38, 38): 0.5320250779543261,
#  (2, 37, 38): 0.5964045750139714,
#  (1, 39, 39): 0.5320778016456672,
#  (2, 38, 39): 0.5965617868740368,
#  (1, 40, 40): 0.5321167325018205,
#  (2, 39, 40): 0.5966842851117292,
#  (1, 41, 41): 0.5321571517934258,
#  (2, 40, 41): 0.5968058406736355,
#  (2, 14, 41): 0.6338000769223442,
#  (1, 42, 42): 0.5322013748645192,
#  (2, 41, 42): 0.5969399487078528,
#  (1, 43, 43): 0.5322408018658233,
#  (2, 42, 43): 0.5970633565449881,
#  (1, 44, 44): 0.5322755651027112,
#  (2, 43, 44): 0.5971704908211825,
#  (2, 15, 44): 0.6355654440591713,
#  (1, 45, 45): 0.5323146613405815,
#  (2, 44, 45): 0.5972896979627089,
#  (1, 46, 46): 0.5323509791656083,
#  (2, 45, 46): 0.5973977583765179,
#  (1, 47, 47): 0.532385014722942,
#  (2, 46, 47): 0.597498806605531,
#  (2, 16, 47): 0.6375855486545072,
#  (1, 48, 48): 0.5324148826610103,
#  (2, 47, 48): 0.5975902130804501,
#  (1, 49, 49): 0.5324444859883317,
#  (2, 48, 49): 0.5976821983913784,
#  (1, 50, 50): 0.5324711785974361,
#  (2, 49, 50): 0.5977623423713782,
#  (2, 17, 50): 0.6383571866691223,
#  (1, 51, 51): 0.5325028988107334,
#  (2, 50, 51): 0.5978603145004572,
#  (1, 52, 52): 0.5325307160155125,
#  (2, 51, 52): 0.597951109063024,
#  (1, 53, 53): 0.5325579709224543,
#  (2, 52, 53): 0.5980328572456773,
#  (2, 18, 53): 0.6393221393725973,
#  (1, 54, 54): 0.5325877396314925,
#  (2, 53, 54): 0.5981236683464157,
#  (1, 55, 55): 0.5326169460426934,
#  (2, 54, 55): 0.5982126271719249,
#  (1, 56, 56): 0.5326397687196227,
#  (2, 55, 56): 0.5982834436230927,
#  (2, 19, 56): 0.639912667869058,
#  (1, 57, 57): 0.5326706620243357,
#  (2, 56, 57): 0.5983790342554488,
#  (1, 58, 58): 0.5326991076796389,
#  (2, 57, 58): 0.5984666865653948,
#  (1, 59, 59): 0.5327241464715744,
#  (2, 58, 59): 0.5985425140825841,
#  (2, 20, 59): 0.6407575699842504,
#  (1, 60, 60): 0.5327515998365764,
#  (2, 59, 60): 0.5986312082973463,
#  (1, 60, 100): 0.6594202186690291,
#  (2, 59, 100): 0.6594714208485749,
#  (1, 61, 61): 0.5327806408660604,
#  (2, 60, 61): 0.5987212090276719,
#  (1, 62, 62): 0.5328041250698572,
#  (2, 61, 62): 0.5987947377389965,
#  (2, 21, 62): 0.6412867749400921,
#  (1, 63, 63): 0.5328350514509137,
#  (2, 62, 63): 0.5988899810697471,
#  (1, 64, 64): 0.5329295505639383,
#  (2, 63, 64): 0.5991591232757963,
#  (1, 65, 65): 0.5329439718496504,
#  (2, 64, 65): 0.5992017586824079,
#  (2, 22, 65): 0.6419519898198954,
#  (1, 66, 66): 0.5329563424020729,
#  (2, 65, 66): 0.5992384734235551,
#  (1, 67, 67): 0.5329692090996461,
#  (2, 66, 67): 0.5992765939092958,
#  (1, 68, 68): 0.5329786027811648,
#  (2, 67, 68): 0.5993086945005419,
#  (2, 23, 68): 0.6423572742552796,
#  (1, 69, 69): 0.5329891210583583,
#  (2, 68, 69): 0.5993394885762248,
#  (1, 70, 70): 0.5330002016333891,
#  (2, 69, 70): 0.5993723499233687,
#  (1, 71, 71): 0.5330110506740166,
#  (2, 70, 71): 0.5994039212931209,
#  (2, 24, 71): 0.6429282380946333,
#  (1, 72, 72): 0.5330189889964267,
#  (2, 71, 72): 0.5994280670237854,
#  (1, 73, 73): 0.5330284819069756,
#  (2, 72, 73): 0.5994564796027452,
#  (1, 74, 74): 0.5330374786723738,
#  (2, 73, 74): 0.599483089520991,
#  (2, 25, 74): 0.6432813280601704,
#  (1, 75, 75): 0.5330459131399347,
#  (2, 74, 75): 0.5995072187134837,
#  (1, 76, 76): 0.5330541822257785,
#  (2, 75, 76): 0.5995340767043049,
#  (1, 77, 77): 0.5330628151513997,
#  (2, 76, 77): 0.5995594131833307,
#  (2, 26, 77): 0.6438085649735813,
#  (1, 78, 78): 0.5330708527028399,
#  (2, 77, 78): 0.5995827154672391,
#  (1, 79, 79): 0.5330799817736117,
#  (2, 78, 79): 0.5996089284693644,
#  (1, 80, 80): 0.5330863985842266,
#  (2, 79, 80): 0.5996283608210977,
#  (2, 27, 80): 0.6441455136835509,
#  (1, 81, 81): 0.5330929477002151,
#  (2, 80, 81): 0.5996482893179816,
#  (1, 82, 82): 0.5331003237247879,
#  (2, 81, 82): 0.5996707812314773,
#  (1, 83, 83): 0.5331074682149571,
#  (2, 82, 83): 0.599691569713289,
#  (2, 28, 83): 0.6446484064082373,
#  (1, 84, 84): 0.5331135542621382,
#  (2, 83, 84): 0.5997103736144981,
#  (1, 85, 85): 0.5331207318286508,
#  (2, 84, 85): 0.5997354950972921,
#  (1, 86, 86): 0.5331267847994886,
#  (2, 85, 86): 0.5997556055140646,
#  (2, 29, 86): 0.6449977587469728,
#  (1, 87, 87): 0.5331327716176396,
#  (2, 86, 87): 0.5997733675104574,
#  (1, 88, 88): 0.5331386592067605,
#  (2, 87, 88): 0.599791989491778,
#  (1, 89, 89): 0.5331450098646887,
#  (2, 88, 89): 0.5998109256983607,
#  (2, 30, 89): 0.6454688981820182,
#  (1, 90, 90): 0.5331506328430625,
#  (2, 89, 90): 0.5998279269388559,
#  (1, 91, 91): 0.5331572150353944,
#  (2, 90, 91): 0.5998475412104778,
#  (1, 92, 92): 0.5331628049374249,
#  (2, 91, 92): 0.5998653528213856,
#  (2, 31, 92): 0.6457769216297059,
#  (1, 93, 93): 0.5331686925265458,
#  (2, 92, 93): 0.5998821225274772,
#  (1, 94, 94): 0.5331750431844738,
#  (2, 93, 94): 0.5999014225738369,
#  (1, 95, 95): 0.5331811953843418,
#  (2, 94, 95): 0.5999193995664617,
#  (2, 32, 95): 0.646300487069002,
#  (1, 96, 96): 0.5331852306982338,
#  (2, 95, 96): 0.599931571660824,
#  (1, 97, 97): 0.5331905890658605,
#  (2, 96, 97): 0.599948109832512,
#  (1, 98, 98): 0.5331949220668428,
#  (2, 97, 98): 0.5999628122671425,
#  (2, 33, 98): 0.6464613042504953,
#  (1, 99, 99): 0.5331994535258853,
#  (2, 98, 99): 0.59997640664427,
#  (2, 60, 99): 0.6594345241875391,
#  (1, 100, 100): 0.533204183442988,
#  (2, 99, 100): 0.5999915225331928,
#  (2, 6, 6): 0.4693452418753916,
#  (3, 5, 6): 0.4740014979614388,
#  (2, 7, 7): 0.48208386784704227,
#  (3, 6, 7): 0.4955659177124083,
#  (2, 8, 8): 0.49122878218725124,
#  (3, 7, 8): 0.5014666050652847,
#  (2, 9, 9): 0.494262775936087,
#  (3, 8, 9): 0.5178661041836018,
#  (2, 10, 10): 0.5004434876119833,
#  (3, 9, 10): 0.5342839937488357,
#  (2, 11, 11): 0.5025522368075666,
#  (3, 10, 11): 0.5431842258389219,
#  (2, 12, 12): 0.506093654740131,
#  (3, 11, 12): 0.5502830045015581,
#  (2, 13, 13): 0.5085600915129808,
#  (3, 12, 13): 0.5546173616138715,
#  (2, 14, 14): 0.5131205254322682,
#  (3, 13, 14): 0.5568134654323105,
#  (2, 15, 15): 0.5156899950147334,
#  (3, 14, 15): 0.5601744353735879,
#  (2, 16, 16): 0.5177187986883774,
#  (3, 15, 16): 0.5635269543091331,
#  (2, 17, 17): 0.5183972606437027,
#  (3, 16, 17): 0.5645428776577504,
#  (2, 18, 18): 0.5198030383135193,
#  (3, 17, 18): 0.5672856342031618,
#  (2, 19, 19): 0.5202042212823249,
#  (3, 18, 19): 0.5700392728655439,
#  (2, 20, 20): 0.521353326527545,
#  (3, 19, 20): 0.5708707459853257,
#  (2, 20, 60): 0.6295677107148301,
#  (3, 19, 60): 0.6304392723627834,
#  (2, 21, 21): 0.5216864383816829,
#  (3, 20, 21): 0.5735340366157767,
#  (2, 21, 63): 0.6301227813711917,
#  (3, 20, 63): 0.6311136824660452,
#  (2, 22, 22): 0.5225738105217701,
#  (3, 21, 22): 0.5764060555111009,
#  (2, 22, 66): 0.630719892059984,
#  (3, 21, 66): 0.6335248486691138,
#  (2, 23, 23): 0.5230437922847974,
#  (3, 22, 23): 0.5785014418639604,
#  (2, 23, 69): 0.6311993336572169,
#  (3, 22, 69): 0.6351912844629037,
#  (2, 23, 71): 0.641735372847127,
#  (3, 22, 71): 0.6419442003410304,
#  (2, 24, 24): 0.5237380978085997,
#  (3, 23, 24): 0.5800568899875528,
#  (2, 24, 72): 0.6316713165390184,
#  (3, 23, 72): 0.6362437075564361,
#  (2, 24, 74): 0.642247130031838,
#  (3, 23, 74): 0.6426527783069992,
#  (2, 25, 25): 0.524088839353757,
#  (3, 24, 25): 0.5809113180896375,
#  (2, 25, 75): 0.6320944621998256,
#  (3, 24, 75): 0.637120230655896,
#  (2, 25, 77): 0.6426200988797439,
#  (3, 24, 77): 0.6434655302164304,
#  (2, 26, 26): 0.5248276325593998,
#  (3, 25, 26): 0.5813076057596235,
#  (2, 26, 78): 0.6325682808186844,
#  (3, 25, 78): 0.6376919552511473,
#  (2, 26, 80): 0.6431372309702534,
#  (3, 25, 80): 0.6440306064666632,
#  (2, 27, 27): 0.5251138752349743,
#  (3, 26, 27): 0.582175396704432,
#  (2, 27, 81): 0.6329491879890007,
#  (3, 26, 81): 0.6380589868954174,
#  (2, 27, 83): 0.6434930993486342,
#  (3, 26, 83): 0.6444297387021796,
#  (2, 28, 28): 0.5256858644409728,
#  (3, 27, 28): 0.5828712072018578,
#  (2, 28, 84): 0.6333982655030145,
#  (3, 27, 84): 0.6388404320458433,
#  (2, 28, 86): 0.6439339408531474,
#  (3, 27, 86): 0.6451290222156598,
#  (2, 29, 29): 0.5261190653101662,
#  (3, 28, 29): 0.5831610717370319,
#  (2, 29, 87): 0.6337884340494758,
#  (3, 28, 87): 0.6392850773298446,
#  (2, 29, 88): 0.6449055088252976,
#  (3, 28, 88): 0.644998916418991,
#  (2, 29, 89): 0.6443102007972193,
#  (3, 28, 89): 0.6455973005470034,
#  (2, 30, 30): 0.5268432387720368,
#  (3, 29, 30): 0.5837543951845078,
#  (2, 30, 90): 0.63421194355006,
#  (3, 29, 90): 0.6395496715386797,
#  (2, 30, 92): 0.6447714007910802,
#  (3, 29, 92): 0.645899006413106,
#  (2, 31, 31): 0.5275615907974732,
#  (3, 30, 31): 0.5843650506359125,
#  (2, 31, 93): 0.6345886665629393,
#  (3, 30, 93): 0.640241909791021,
#  (2, 31, 94): 0.6457147711805027,
#  (3, 30, 94): 0.645921002181451,
#  (2, 31, 95): 0.6453186488922336,
#  (3, 30, 95): 0.6465264150324307,
#  (2, 32, 32): 0.5279858610539553,
#  (3, 31, 32): 0.5845853886973108,
#  (2, 32, 96): 0.635051999980948,
#  (3, 31, 96): 0.6406006558112753,
#  (2, 32, 97): 0.6461740362082762,
#  (3, 31, 97): 0.646306424272638,
#  (2, 32, 98): 0.645574742480821,
#  (3, 31, 98): 0.6468801499866637,
#  (2, 33, 33): 0.5281335800034718,
#  (3, 32, 33): 0.5851356798220545,
#  (2, 33, 99): 0.6352244269589663,
#  (3, 32, 99): 0.6407475974667225,
#  (2, 33, 100): 0.6463518546302647,
#  (3, 32, 100): 0.6464238949061373,
#  (2, 34, 34): 0.5283821156475977,
#  (3, 33, 34): 0.5857237441309336,
#  (2, 35, 35): 0.5284957328870937,
#  (3, 34, 35): 0.5859061105501363,
#  (2, 36, 36): 0.5286972339709394,
#  (3, 35, 36): 0.5863498462346949,
#  (2, 37, 37): 0.5288185579984419,
#  (3, 36, 37): 0.5868146350118123,
#  (2, 38, 38): 0.5290239620908059,
#  (3, 37, 38): 0.5870175583784231,
#  (2, 39, 39): 0.5291136651340412,
#  (3, 38, 39): 0.5874601198527918,
#  (2, 40, 40): 0.5292680655049197,
#  (3, 39, 40): 0.5879006636702145,
#  (2, 41, 41): 0.5293537993869498,
#  (3, 40, 41): 0.5880250307213077,
#  (2, 42, 42): 0.5295149142555335,
#  (3, 41, 42): 0.5884515170927959,
#  (2, 43, 43): 0.5296025334891361,
#  (3, 42, 43): 0.5889065483486172,
#  (2, 44, 44): 0.5297588522879303,
#  (3, 43, 44): 0.58904100368444,
#  (2, 45, 45): 0.5298143874684583,
#  (3, 44, 45): 0.5894975068375417,
#  (2, 46, 46): 0.5299781484445122,
#  (3, 45, 46): 0.5899698039446054,
#  (3, 45, 47): 0.5976479643759843,
#  (2, 47, 47): 0.5300331874798896,
#  (3, 46, 47): 0.5905717768558739,
#  (3, 46, 48): 0.5985042612914698,
#  (2, 48, 48): 0.5301334749530051,
#  (3, 47, 48): 0.5909074355884519,
#  (3, 47, 49): 0.5986030107146184,
#  (2, 49, 49): 0.5302022075945402,
#  (3, 48, 49): 0.5910961361274111,
#  (3, 48, 50): 0.5987849967558723,
#  (2, 50, 50): 0.5303300145853443,
#  (3, 49, 50): 0.5911701775220579,
#  (3, 49, 51): 0.5989254058335026,
#  (2, 51, 51): 0.530385152849752,
#  (3, 50, 51): 0.5913320862228827,
#  (3, 50, 52): 0.5990053844317854,
#  (2, 52, 52): 0.5305056830450136,
#  (3, 51, 52): 0.5914818062911734,
#  (3, 51, 53): 0.5991632908950618,
#  (2, 53, 53): 0.5305588367288184,
#  (3, 52, 53): 0.5915376556969635,
#  (3, 52, 54): 0.5992909986568359,
#  (2, 18, 54): 0.6281354554321411,
#  (3, 18, 53): 0.6282727553334942,
#  (2, 54, 54): 0.5306651440964284,
#  (3, 53, 54): 0.5916624692786923,
#  (3, 53, 55): 0.5993634193106573,
#  (2, 55, 55): 0.5307288160574269,
#  (3, 54, 55): 0.5918032587342715,
#  (3, 54, 56): 0.599478690367322,
#  (2, 56, 56): 0.5308433925108808,
#  (3, 55, 56): 0.5918555193568054,
#  (3, 55, 57): 0.5995967232986587,
#  (2, 19, 57): 0.6287977430555555,
#  (3, 19, 56): 0.6300712318900404,
#  (2, 57, 57): 0.5308984976989449,
#  (3, 56, 57): 0.5919839713363054,
#  (3, 56, 58): 0.5996486531577588,
#  (2, 58, 58): 0.531019424810327,
#  (3, 57, 58): 0.5921011938972294,
#  (3, 57, 59): 0.5997754843964335,
#  (2, 59, 59): 0.5310688408673304,
#  (3, 58, 59): 0.5921501799617691,
#  (3, 58, 60): 0.5998798898742993,
#  (3, 20, 59): 0.6308086193510897,
#  (2, 60, 60): 0.5311653907136445,
#  (3, 59, 60): 0.5922371045921607,
#  (3, 59, 61): 0.5999254359991278,
#  (2, 61, 61): 0.5312331972175651,
#  (3, 60, 61): 0.5923383678174059,
#  (3, 60, 62): 0.6000335791037951,
#  (2, 62, 62): 0.5313585565589595,
#  (3, 61, 62): 0.5923812182202493,
#  (3, 61, 63): 0.6001316835382479,
#  (3, 21, 62): 0.6330898947537215,
#  (2, 63, 63): 0.5315653498577452,
#  (3, 62, 63): 0.5925049402826467,
#  (3, 62, 64): 0.6001830180231672,
#  (2, 64, 64): 0.5316609404901015,
#  (3, 63, 64): 0.5925977525021593,
#  (3, 63, 65): 0.6002796836366832,
#  (2, 65, 65): 0.531690378435706,
#  (3, 64, 65): 0.592631788059493,
#  (3, 64, 66): 0.6003744142841115,
#  (3, 22, 65): 0.6346719031810446,
#  (2, 66, 66): 0.5317385375916611,
#  (3, 65, 66): 0.5927241372101983,
#  (3, 65, 67): 0.6004132789875781,
#  (2, 67, 67): 0.5317613271922471,
#  (3, 66, 67): 0.5928214643505817,
#  (3, 66, 68): 0.6005093823032567,
#  (2, 68, 68): 0.5318062779428949,
#  (3, 67, 68): 0.5928686808307507,
#  (3, 67, 69): 0.600597067689546,
#  (3, 23, 68): 0.6353617433984912,
#  (2, 69, 69): 0.5318268845048181,
#  (3, 68, 69): 0.5929494532612746,
#  (3, 68, 70): 0.6006299621130332,
#  (2, 70, 70): 0.5318679983996342,
#  (3, 69, 70): 0.5930456061914681,
#  (3, 69, 71): 0.6007228404852326,
#  (2, 71, 71): 0.5318853634799066,
#  (3, 70, 71): 0.5930765987252112,
#  (3, 70, 72): 0.6007995941400363,
#  (3, 24, 71): 0.6368715792445682,
#  (2, 72, 72): 0.5319251873973311,
#  (3, 71, 72): 0.5931494493714966,
#  (3, 71, 73): 0.600835432358084,
#  (2, 73, 73): 0.5319396086830429,
#  (3, 72, 73): 0.5932231434645379,
#  (3, 72, 74): 0.6009037846216702,
#  (2, 74, 74): 0.5319769849510576,
#  (3, 73, 74): 0.5932469749699402,
#  (3, 73, 75): 0.6009758414357144,
#  (3, 25, 74): 0.637481490478247,
#  (2, 75, 75): 0.5319899508776609,
#  (3, 74, 75): 0.5933288389197955,
#  (3, 74, 76): 0.600999127181451,
#  (2, 76, 76): 0.5320250779543261,
#  (3, 75, 76): 0.5934025495510085,
#  (3, 75, 77): 0.6010797838447729,
#  (2, 77, 77): 0.5320406899883995,
#  (3, 76, 77): 0.5934319544202696,
#  (3, 76, 78): 0.6011526014147149,
#  (3, 26, 77): 0.6378954574537672,
#  (2, 78, 78): 0.5320778016456672,
#  (3, 77, 78): 0.5934982559505665,
#  (3, 77, 79): 0.6011803855431506,
#  (2, 79, 79): 0.5320866991820353,
#  (3, 78, 79): 0.5935844198250606,
#  (3, 78, 80): 0.601249680482523,
#  (2, 80, 80): 0.5321167325018205,
#  (3, 79, 80): 0.5935997672483869,
#  (3, 79, 81): 0.6013253922325102,
#  (3, 27, 80): 0.6386029439004047,
#  (2, 81, 81): 0.5321278792295382,
#  (3, 80, 81): 0.5936775793461786,
#  (3, 80, 82): 0.6013561366936782,
#  (2, 82, 82): 0.5321571517934258,
#  (3, 81, 82): 0.5937518688134007,
#  (3, 81, 83): 0.601426787763129,
#  (2, 83, 83): 0.5321697869565954,
#  (3, 82, 83): 0.5937740134252909,
#  (3, 82, 84): 0.6014979184395587,
#  (3, 28, 83): 0.6390618120120578,
#  (2, 84, 84): 0.5322013748645192,
#  (3, 83, 84): 0.5938440691205609,
#  (3, 83, 85): 0.6015204268912259,
#  (2, 85, 85): 0.5322126208212671,
#  (3, 84, 85): 0.5939187058893884,
#  (3, 84, 86): 0.6015962874847584,
#  (2, 86, 86): 0.5322408018658233,
#  (3, 85, 86): 0.5939462915597639,
#  (3, 85, 87): 0.6016669550923809,
#  (3, 29, 86): 0.6394178126958119,
#  (2, 87, 87): 0.532251948593541,
#  (3, 86, 87): 0.5940234421306881,
#  (3, 86, 88): 0.601684650936087,
#  (2, 88, 88): 0.5322755651027112,
#  (3, 87, 88): 0.5940922243867381,
#  (3, 87, 89): 0.6017641830037341,
#  (2, 89, 89): 0.5322872410519229,
#  (3, 88, 89): 0.5941109952116039,
#  (3, 88, 90): 0.6018371328790496,
#  (3, 30, 89): 0.6400308661821116,
#  (2, 90, 90): 0.5323146613405815,
#  (3, 89, 90): 0.5941841270068079,
#  (3, 89, 91): 0.6018690019358922,
#  (2, 91, 91): 0.5323265357478535,
#  (3, 90, 91): 0.5942605664363495,
#  (3, 90, 92): 0.6019353200043608,
#  (2, 92, 92): 0.5323509791656083,
#  (3, 91, 92): 0.5942813383799895,
#  (3, 91, 93): 0.6020062026082151,
#  (3, 31, 92): 0.6404354725524564,
#  (2, 93, 93): 0.5323607366869041,
#  (3, 92, 93): 0.5943591835541245,
#  (3, 92, 94): 0.6020233692304272,
#  (2, 94, 94): 0.532385014722942,
#  (3, 93, 94): 0.5944335226358617,
#  (3, 93, 95): 0.6021049851077072,
#  (2, 95, 95): 0.5323954668474488,
#  (3, 94, 95): 0.5946310545585023,
#  (3, 94, 96): 0.6023667182128402,
#  (3, 32, 95): 0.6407084350761655,
#  (2, 96, 96): 0.5324148826610103,
#  (3, 95, 96): 0.5947102558627156,
#  (3, 95, 97): 0.6023858198011397,
#  (2, 97, 97): 0.5324242763425291,
#  (3, 96, 97): 0.5947447048743416,
#  (3, 96, 98): 0.6024215422519856,
#  (2, 98, 98): 0.5324444859883317,
#  (3, 97, 98): 0.5947557192966858,
#  (3, 97, 99): 0.6024459691315688,
#  (3, 33, 98): 0.6412241118075667,
#  (2, 99, 99): 0.532454276585971,
#  (3, 98, 99): 0.5947932940227607,
#  (3, 98, 100): 0.6024601919592203,
#  (2, 100, 100): 0.5324711785974361,
#  (3, 99, 100): 0.594818828959847,
#  (3, 7, 7): 0.44019443200773933,
#  (4, 6, 7): 0.45015962312549745,
#  (3, 8, 8): 0.4467808250351403,
#  (4, 7, 8): 0.4742427237336788,
#  (3, 9, 9): 0.4693452418753916,
#  (4, 8, 9): 0.49163882961608163,
#  (3, 10, 10): 0.47808047262654746,
#  (4, 9, 10): 0.4967868813136124,
#  (3, 11, 11): 0.48470119889837254,
#  (4, 10, 11): 0.502631388497265,
#  (3, 12, 12): 0.49122878218725124,
#  (4, 11, 12): 0.5167916853217244,
#  (3, 13, 13): 0.4935336740990533,
#  (4, 12, 13): 0.5312539030085183,
#  (3, 14, 14): 0.4956136137995563,
#  (4, 13, 14): 0.5362733208066606,
#  (3, 15, 15): 0.5004434876119833,
#  (4, 14, 15): 0.5434280646422885,
#  (3, 16, 16): 0.5020230153135531,
#  (4, 15, 16): 0.5478861768933428,
#  (3, 17, 17): 0.5030273123274739,
#  (4, 16, 17): 0.5516700278846806,
#  (3, 17, 51): 0.615492767394452,
#  (4, 16, 51): 0.6161914720719234,
#  (3, 18, 18): 0.506093654740131,
#  (4, 17, 18): 0.5534884163999391,
#  (3, 18, 54): 0.6177887948462294,
#  (4, 17, 54): 0.6190445216843214,
#  (3, 19, 19): 0.5081359535618724,
#  (4, 18, 19): 0.5547300196394097,
#  (3, 19, 57): 0.6196168251155819,
#  (4, 18, 57): 0.6206401410269438,
#  (3, 20, 20): 0.5092737466976579,
#  (4, 19, 20): 0.5579425760279598,
#  (3, 20, 60): 0.6203943672574895,
#  (4, 19, 60): 0.6215706116424494,
#  (3, 21, 21): 0.5131205254322682,
#  (4, 20, 21): 0.560842097902801,
#  (3, 21, 63): 0.6225665568796677,
#  (4, 20, 63): 0.6242344480325662,
#  (3, 22, 22): 0.5144697094785687,
#  (4, 21, 22): 0.5619077515336839,
#  (3, 22, 66): 0.624324547991922,
#  (4, 21, 66): 0.6264198516539231,
#  (3, 23, 23): 0.5164820742095548,
#  (4, 22, 23): 0.5623249765290268,
#  (3, 23, 69): 0.6249592168686177,
#  (4, 22, 69): 0.6269802310633965,
#  (3, 24, 24): 0.5177187986883774,
#  (4, 23, 24): 0.5647878741331352,
#  (3, 24, 72): 0.6264351494627344,
#  (4, 23, 72): 0.6274335588875342,
#  (3, 25, 25): 0.518164866255144,
#  (4, 24, 25): 0.5672480925534301,
#  (3, 25, 75): 0.6270372712175482,
#  (4, 24, 75): 0.6295931629610577,
#  (3, 26, 26): 0.5187485975630408,
#  (4, 25, 26): 0.5679596473903029,
#  (3, 26, 78): 0.6274313096961844,
#  (4, 25, 78): 0.6313052441087063,
#  (3, 27, 27): 0.5198030383135193,
#  (4, 26, 27): 0.5688839492677692,
#  (3, 27, 81): 0.6281354554321411,
#  (4, 26, 81): 0.6318541625652001,
#  (3, 28, 28): 0.5200221029356974,
#  (4, 27, 28): 0.571275650042761,
#  (3, 28, 84): 0.6286252830011939,
#  (4, 27, 84): 0.6323139071999525,
#  (3, 29, 29): 0.5204572222328067,
#  (4, 28, 29): 0.5737307747061763,
#  (3, 29, 87): 0.6289591721494013,
#  (4, 28, 87): 0.6344316035464191,
#  (3, 30, 30): 0.521353326527545,
#  (4, 29, 30): 0.5746018071326356,
#  (3, 30, 90): 0.6295677107148301,
#  (4, 29, 90): 0.636175140296618,
#  (4, 29, 93): 0.6410474510575962,
#  (3, 31, 31): 0.5216136373499127,
#  (4, 30, 31): 0.5765721483693628,
#  (3, 31, 93): 0.6299875487412996,
#  (4, 30, 93): 0.6364735716047266,
#  (4, 30, 96): 0.6419747628823096,
#  (3, 32, 32): 0.5218702105454792,
#  (4, 31, 32): 0.57749606986888,
#  (3, 32, 96): 0.6301997334840557,
#  (4, 31, 96): 0.6374555090105252,
#  (3, 32, 98): 0.6418308477122813,
#  (4, 31, 98): 0.64189207202387,
#  (4, 31, 99): 0.6423986858371861,
#  (3, 33, 33): 0.5225738105217701,
#  (4, 32, 33): 0.5782692459334621,
#  (3, 33, 99): 0.630719892059984,
#  (4, 32, 99): 0.6381510714353757,
#  (3, 34, 34): 0.5229414210020491,
#  (4, 33, 34): 0.5785625834846907,
#  (3, 35, 35): 0.5230813339345289,
#  (4, 34, 35): 0.5789247529064845,
#  (4, 34, 36): 0.586367542078401,
#  (3, 36, 36): 0.5237380978085997,
#  (4, 35, 36): 0.5796576089084913,
#  (3, 37, 37): 0.5239908341483345,
#  (4, 36, 37): 0.5802491462334248,
#  (4, 36, 38): 0.5873462049262054,
#  (3, 38, 38): 0.5241945844235296,
#  (4, 37, 38): 0.5804661601223137,
#  (4, 37, 39): 0.58762088741977,
#  (3, 39, 39): 0.5248276325593998,
#  (4, 38, 39): 0.5806532895349625,
#  (4, 38, 40): 0.5880847500592729,
#  (3, 40, 40): 0.5250622099866212,
#  (4, 39, 40): 0.5812160504411591,
#  (4, 39, 41): 0.5883475912219089,
#  (3, 41, 41): 0.5251781094938103,
#  (4, 40, 41): 0.581744395412073,
#  (4, 40, 42): 0.588833317324383,
#  (3, 42, 42): 0.5256858644409728,
#  (4, 41, 42): 0.5820000755463682,
#  (4, 41, 43): 0.5890965057886247,
#  (3, 43, 43): 0.5260332321991058,
#  (4, 42, 43): 0.5820988084313451,
#  (4, 42, 44): 0.5895697621096462,
#  (3, 44, 44): 0.5262173020499924,
#  (4, 43, 44): 0.5826556321339057,
#  (4, 43, 45): 0.5897379057011973,
#  (3, 45, 45): 0.5268432387720368,
#  (4, 44, 45): 0.5831276480920508,
#  (4, 44, 46): 0.5902254013880421,
#  (3, 46, 46): 0.5271012011740249,
#  (4, 45, 46): 0.583270240208344,
#  (3, 47, 47): 0.5277467521676913,
#  (4, 46, 47): 0.5834219779335806,
#  (3, 48, 48): 0.5279858610539553,
#  (4, 47, 48): 0.583798849790005,
#  (3, 49, 49): 0.5280672950113465,
#  (4, 48, 49): 0.58421129525373,
#  (4, 48, 50): 0.5913062701368778,
#  (3, 50, 50): 0.5281774061584447,
#  (4, 49, 50): 0.5844009880829905,
#  (4, 49, 51): 0.5914750587171248,
#  (4, 17, 50): 0.6165013477948399,
#  (3, 51, 51): 0.5283821156475977,
#  (4, 50, 51): 0.5845099911725855,
#  (4, 50, 52): 0.5918398411700453,
#  (3, 52, 52): 0.5284536267019764,
#  (4, 51, 52): 0.5848932467632814,
#  (4, 51, 53): 0.5920035690697556,
#  (3, 53, 53): 0.5285409151721452,
#  (4, 52, 53): 0.5853034761120002,
#  (4, 52, 54): 0.5923164712780911,
#  (4, 18, 53): 0.6181123476371319,
#  (3, 54, 54): 0.5286972339709394,
#  (4, 53, 54): 0.5854581080172822,
#  (4, 53, 55): 0.5925202546296297,
#  (3, 55, 55): 0.5287723172704025,
#  (4, 54, 55): 0.5854904070665887,
#  (4, 54, 56): 0.5928632397722654,
#  (3, 56, 56): 0.528849186692408,
#  (4, 55, 56): 0.585891077352072,
#  (4, 55, 57): 0.5930314164401599,
#  (3, 57, 57): 0.5290239620908059,
#  (4, 56, 57): 0.5862959648713356,
#  (4, 56, 58): 0.593397753481219,
#  (3, 58, 58): 0.529078174217599,
#  (4, 57, 58): 0.5864241191637455,
#  (4, 57, 59): 0.5935495408209707,
#  (3, 59, 59): 0.5291300048476689,
#  (4, 58, 59): 0.5865677035703398,
#  (4, 58, 60): 0.5938409764824553,
#  (4, 20, 59): 0.6220633830060628,
#  (3, 60, 60): 0.5292680655049197,
#  (4, 59, 60): 0.5869693992224677,
#  (4, 59, 61): 0.5940510939537503,
#  (3, 61, 61): 0.5293283636788938,
#  (4, 60, 61): 0.5873862934543769,
#  (4, 60, 62): 0.5944358379798981,
#  (3, 62, 62): 0.5293856188292774,
#  (4, 61, 62): 0.5875231799014378,
#  (4, 61, 63): 0.5950046353187607,
#  (4, 21, 62): 0.6242603302712578,
#  (3, 63, 63): 0.5295149142555335,
#  (4, 62, 63): 0.5881961511837626,
#  (4, 62, 64): 0.5953108064912191,
#  (3, 64, 64): 0.5295760062617487,
#  (4, 63, 64): 0.5883510807761351,
#  (4, 63, 65): 0.5954003937672526,
#  (3, 65, 65): 0.5296215523865772,
#  (4, 64, 65): 0.5884918206171993,
#  (4, 64, 66): 0.5955452681512389,
#  (4, 22, 65): 0.6248344032868888,
#  (3, 66, 66): 0.5297588522879303,
#  (4, 65, 66): 0.5885713692230182,
#  (4, 65, 67): 0.5956124131282917,
#  (3, 67, 67): 0.5298012561601383,
#  (4, 66, 67): 0.5886375219097698,
#  (4, 66, 68): 0.5957485718957984,
#  (3, 68, 68): 0.529846471521533,
#  (4, 67, 68): 0.5887764094756051,
#  (4, 67, 69): 0.5958102427380226,
#  (4, 23, 68): 0.6256472213490067,
#  (3, 69, 69): 0.5299781484445122,
#  (4, 68, 69): 0.5889008426793849,
#  (4, 68, 70): 0.5959310706203745,
#  (3, 70, 70): 0.5300216107597081,
#  (4, 69, 70): 0.5889561794018526,
#  (4, 69, 71): 0.5959897480535233,
#  (3, 71, 71): 0.5300431103829023,
#  (4, 70, 71): 0.5889931587537468,
#  (4, 70, 72): 0.5961088063515048,
#  (4, 24, 71): 0.6278304253935291,
#  (3, 72, 72): 0.5301334749530051,
#  (4, 71, 72): 0.5891061971572339,
#  (4, 71, 73): 0.596151656754348,
#  (3, 73, 73): 0.5301830563917255,
#  (4, 72, 73): 0.5892122399140968,
#  (4, 72, 74): 0.5962632397987264,
#  (3, 74, 74): 0.5302213918736981,
#  (4, 73, 74): 0.5892634255554708,
#  (4, 73, 75): 0.5963052632929854,
#  (4, 25, 74): 0.6295195515588748,
#  (3, 75, 75): 0.5303300145853443,
#  (4, 74, 75): 0.5893170257699115,
#  (4, 74, 76): 0.5964045750139714,
#  (3, 76, 76): 0.5303685816017206,
#  (4, 75, 76): 0.5894298161008231,
#  (4, 75, 77): 0.5964538256892581,
#  (3, 77, 77): 0.530398449539789,
#  (4, 76, 77): 0.5895255886530678,
#  (4, 76, 78): 0.5965617868740368,
#  (4, 26, 77): 0.6298821178967892,
#  (3, 78, 78): 0.5305056830450136,
#  (4, 77, 78): 0.5895662560172484,
#  (4, 77, 79): 0.5965969635652171,
#  (3, 79, 79): 0.5305416701066065,
#  (4, 78, 79): 0.5895925020957171,
#  (4, 78, 80): 0.5966842851117292,
#  (3, 80, 80): 0.5305744818392352,
#  (4, 79, 80): 0.5896747464235211,
#  (4, 79, 81): 0.5967190152722739,
#  (4, 27, 80): 0.6305618532913343,
#  (3, 81, 81): 0.5306651440964284,
#  (4, 80, 81): 0.5897592564808464,
#  (4, 80, 82): 0.5968058406736355,
#  (3, 82, 82): 0.5307149570695524,
#  (4, 81, 82): 0.5898063737319853,
#  (4, 81, 83): 0.5968468057249064,
#  (3, 83, 83): 0.5307373497540179,
#  (4, 82, 83): 0.5898409219726414,
#  (4, 82, 84): 0.5969399487078528,
#  (4, 28, 83): 0.632644984858973,
#  (3, 84, 84): 0.5308433925108808,
#  (4, 83, 84): 0.5899515788794052,
#  (4, 83, 85): 0.5969784495715423,
#  (3, 85, 85): 0.5308807357025521,
#  (4, 84, 85): 0.590039297342038,
#  (4, 84, 86): 0.5970633565449881,
#  (3, 86, 86): 0.5309161604663076,
#  (4, 85, 86): 0.5900632776909854,
#  (4, 85, 87): 0.5971014439543854,
#  (4, 29, 86): 0.6341472958369321,
#  (3, 87, 87): 0.531019424810327,
#  (4, 86, 87): 0.5900916241172586,
#  (4, 86, 88): 0.5971704908211825,
#  (3, 88, 88): 0.5310544195816186,
#  (4, 87, 88): 0.5901717184827432,
#  (4, 87, 89): 0.5972081978526308,
#  (3, 89, 89): 0.5310768122660842,
#  (4, 88, 89): 0.5902565427653305,
#  (4, 88, 90): 0.5972896979627089,
#  (4, 30, 89): 0.6345409208612762,
#  (3, 90, 90): 0.5311653907136445,
#  (4, 89, 90): 0.5902962343773815,
#  (4, 89, 91): 0.597325304646353,
#  (3, 91, 91): 0.5312151706104252,
#  (4, 90, 91): 0.5903176513097174,
#  (4, 90, 92): 0.5973977583765179,
#  (3, 92, 92): 0.5312498676946266,
#  (4, 91, 92): 0.5904037490315247,
#  (4, 91, 93): 0.5974274443946976,
#  (4, 31, 92): 0.6350845636410015,
#  (3, 93, 93): 0.5313585565589595,
#  (4, 92, 93): 0.5904832480228285,
#  (4, 92, 94): 0.597498806605531,
#  (3, 94, 94): 0.5313904421539738,
#  (4, 93, 94): 0.5905108667695473,
#  (4, 93, 95): 0.5975329083155515,
#  (3, 95, 95): 0.5316191650684178,
#  (4, 94, 95): 0.590518887782816,
#  (4, 94, 96): 0.5975902130804501,
#  (4, 32, 95): 0.6364357157297329,
#  (3, 96, 96): 0.5316609404901015,
#  (4, 95, 96): 0.5905898365393571,
#  (4, 95, 97): 0.5976202960147504,
#  (3, 97, 97): 0.5316739725693914,
#  (4, 96, 97): 0.5906563199895426,
#  (4, 96, 98): 0.5976821983913784,
#  (3, 98, 98): 0.5317002351860319,
#  (4, 97, 98): 0.5906784149869176,
#  (4, 97, 99): 0.5977121324821334,
#  (4, 33, 98): 0.6369774566197142,
#  (3, 99, 99): 0.5317385375916611,
#  (4, 98, 99): 0.5907043468401243,
#  (4, 98, 100): 0.5977623423713782,
#  (3, 100, 100): 0.53174793127318,
#  (4, 99, 100): 0.5907712272064303,
#  (4, 6, 6): 0.38529044734034446,
#  (5, 5, 6): 0.3960503141458788,
#  (4, 7, 7): 0.4024199248187945,
#  (5, 6, 7): 0.42052775091978695,
#  (4, 8, 8): 0.4285657819670951,
#  (5, 7, 8): 0.43856474403143997,
#  (4, 9, 9): 0.4379673356555573,
#  (5, 8, 9): 0.45166674671141765,
#  (4, 10, 10): 0.4425199304814645,
#  (5, 9, 10): 0.47425496198072786,
#  (4, 11, 11): 0.44806372408931566,
#  (5, 10, 11): 0.4900424495175617,
#  (4, 12, 12): 0.4693452418753916,
#  (5, 11, 12): 0.4940311588415976,
#  (4, 13, 13): 0.47675533508188117,
#  (5, 12, 13): 0.4998499491682755,
#  (4, 14, 14): 0.48208386784704227,
#  (5, 13, 14): 0.5030468273700656,
#  (4, 15, 15): 0.4852509608016224,
#  (5, 14, 15): 0.5158300733289302,
#  (4, 16, 16): 0.49122878218725124,
#  (5, 15, 16): 0.5299008986445578,
#  (4, 17, 17): 0.49264620272993614,
#  (5, 16, 17): 0.5345106990063337,
#  (4, 17, 51): 0.606547849164465,
#  (5, 16, 51): 0.6068501173284052,
#  (4, 18, 18): 0.494262775936087,
#  (5, 17, 18): 0.5398539672824688,
#  (4, 18, 54): 0.6085029752832394,
#  (5, 17, 54): 0.6086456500903911,
#  (4, 19, 19): 0.4959453033709292,
#  (5, 18, 19): 0.543222478630036,
#  (4, 19, 57): 0.6093778611037021,
#  (5, 18, 57): 0.6110883711250402,
#  (4, 20, 20): 0.5004434876119833,
#  (5, 19, 20): 0.5470177244216667,
#  (4, 20, 60): 0.6124243742485055,
#  (5, 19, 60): 0.6127122872794205,
#  (4, 21, 21): 0.501754931550492,
#  (5, 20, 21): 0.5505264463888041,
#  (4, 21, 63): 0.614252404517858,
#  (5, 20, 63): 0.6159845133914207,
#  (4, 22, 22): 0.5025522368075666,
#  (5, 21, 22): 0.5517973221921625,
#  (4, 22, 66): 0.6150826703511068,
#  (5, 21, 66): 0.6187561455845992,
#  (4, 23, 23): 0.5031675890997307,
#  (5, 22, 23): 0.5531504092469813,
#  (4, 23, 69): 0.6156283473259496,
#  (5, 22, 69): 0.6198103713388458,
#  (4, 24, 24): 0.506093654740131,
#  (5, 23, 24): 0.5539436130374774,
#  (4, 24, 72): 0.6177887948462294,
#  (5, 23, 72): 0.6206770046116361,
#  (4, 25, 25): 0.5079278041330082,
#  (5, 24, 25): 0.5569707103687193,
#  (4, 25, 75): 0.619438130170494,
#  (5, 24, 75): 0.6214497341455826,
#  (4, 26, 26): 0.5085600915129808,
#  (5, 25, 26): 0.5597136488340192,
#  (4, 26, 78): 0.6200700371725177,
#  (5, 25, 78): 0.6240545788772883,
#  (4, 27, 27): 0.5094988642906738,
#  (5, 26, 27): 0.5606478239999831,
#  (4, 27, 81): 0.6205027253583889,
#  (5, 26, 81): 0.6261406211631442,
#  (4, 28, 28): 0.5131205254322682,
#  (5, 27, 28): 0.5612278672955936,
#  (4, 28, 84): 0.6225665568796677,
#  (5, 27, 84): 0.6265492628473809,
#  (4, 29, 29): 0.5143106453432743,
#  (5, 28, 29): 0.5613912478936984,
#  (4, 29, 87): 0.6242289738977375,
#  (5, 28, 87): 0.626946129353376,
#  (4, 30, 30): 0.5156899950147334,
#  (5, 29, 30): 0.5637915319797965,
#  (4, 30, 90): 0.6246810778971702,
#  (5, 29, 90): 0.6272628022648563,
#  (4, 31, 31): 0.5166124611551424,
#  (5, 30, 31): 0.566074510814112,
#  (4, 31, 93): 0.6255271046080374,
#  (5, 30, 93): 0.6294413425449626,
#  (4, 32, 32): 0.5177187986883774,
#  (5, 31, 32): 0.5665562016026944,
#  (4, 32, 96): 0.6264351494627344,
#  (5, 31, 96): 0.6310857660322359,
#  (4, 33, 33): 0.5180689779356974,
#  (5, 32, 33): 0.5674294005296449,
#  (4, 33, 99): 0.626903626252138,
#  (5, 32, 99): 0.6314149087251689,
#  (4, 34, 34): 0.5183972606437027,
#  (5, 33, 34): 0.5680504584910413,
#  (4, 35, 35): 0.5188368121708242,
#  ...}

# %%
exportStateProbs(DATA_DIR + 'game1_better_giving_1_to_another_memo_1-100.csv', betterGiving1ToAnother)

# %%
betterGiving1ToAnother, given1ToAnother = readApproxBetterGiving1Probs(DATA_DIR + 'game1_better_giving_1_to_another_memo_1-100.csv')

# %%
betterGiving1ToAnother, given1ToAnother = stricterFilter(betterGiving1ToAnother, printOnGo=True,
                                                         filename=DATA_DIR + 'game1_better_giving_1_to_another_stricter_1-100.csv',
                                                         giveToAnother=True, continueFrom=(74,96,97))
# Out:
# Approximating hitting prob for (74, 14, 97)
# (74, 14, 97): 0.2718879146280189
# (73, 15, 97): 0.2754906810783966
#
# Approximating hitting prob for (73, 98, 98)
# (73, 98, 98): 0.3740677565970287
# (72, 99, 98): 0.42016974784587213
#
# Approximating hitting prob for (74, 33, 98)
# (74, 33, 98): 0.2978499204232529
# (73, 34, 98): 0.2998884736931032
#
# Approximating hitting prob for (74, 98, 99)
# (74, 98, 99): 0.4179870689418381
# (73, 99, 99): 0.37427486021675116
#
# Approximating hitting prob for (74, 50, 99)
# (74, 50, 99): 0.32371246416130556
# (73, 51, 99): 0.3255754107837879
#
# Approximating hitting prob for (74, 60, 99)
# (74, 60, 99): 0.33965749069559265
# (73, 61, 99): 0.34122887236854177
#
# Approximating hitting prob for (74, 99, 100)
# (74, 99, 100): 0.41921059431983193
# (73, 100, 100): 0.3747488430361474
#
# Approximating hitting prob for (75, 1, 26)
# (75, 1, 26): 0.060716931035801
# (74, 2, 26): 0.059658083214383935
#
# Approximating hitting prob for (75, 1, 78)
# (75, 1, 78): 0.24928355458392695
# (74, 2, 78): 0.2479338420124145
#
# Approximating hitting prob for (75, 1, 79)
# (75, 1, 79): 0.24937933467181161
# (74, 2, 79): 0.24818520805940647
#
# Approximating hitting prob for (75, 2, 27)
# (75, 2, 27): 0.06220724390581998
# (74, 3, 27): 0.06143053168073839
#
# Approximating hitting prob for (75, 2, 81)
# (75, 2, 81): 0.2501263498172159
# (74, 3, 81): 0.24935642378285058
#
# Approximating hitting prob for (75, 2, 82)
# (75, 2, 82): 0.25028337596768724
# (74, 3, 82): 0.24960307587964126
#
# Approximating hitting prob for (75, 3, 4)
# (75, 3, 4): 0.0031718187393369734
# (74, 4, 4): 0.002761550412563655
#
# Approximating hitting prob for (75, 3, 28)
# (75, 3, 28): 0.0638987956449212
# (74, 4, 28): 0.06369141308247141
#
# Approximating hitting prob for (75, 3, 84)
# (75, 3, 84): 0.25140366947242754
# (74, 4, 84): 0.2507368460955424
#
# Approximating hitting prob for (75, 3, 85)
# (75, 3, 85): 0.25185349355922115
# (74, 4, 85): 0.2509978918474329
#
# Approximating hitting prob for (75, 4, 87)
# (75, 4, 87): 0.25279550805539924
# (74, 5, 87): 0.2526873416169462
#
# Approximating hitting prob for (75, 4, 88)
# (75, 4, 88): 0.2531377144133993
# (74, 5, 88): 0.2528950210171181
#
# Approximating hitting prob for (75, 5, 6)
# (75, 5, 6): 0.008246320126678015
# (74, 6, 6): 0.007216804081735809
#
# Approximating hitting prob for (75, 5, 30)
# (75, 5, 30): 0.06841367404732487
# (74, 6, 30): 0.06836532977254385
#
# Approximating hitting prob for (75, 6, 7)
# (75, 6, 7): 0.011481847872227863
# (74, 7, 7): 0.008634398091982682
#
# Approximating hitting prob for (75, 6, 14)
# (75, 6, 14): 0.024923876371125347
# (74, 7, 14): 0.023629740864182347
#
# Approximating hitting prob for (75, 6, 94)
# (75, 6, 94): 0.2576581719170176
# (74, 7, 94): 0.25743888468300863
#
# Approximating hitting prob for (75, 7, 8)
# (75, 7, 8): 0.013905549220984297
# (74, 8, 8): 0.011555275635296151
#
# Approximating hitting prob for (75, 7, 16)
# (75, 7, 16): 0.028915810207996957
# (74, 8, 16): 0.026395544524114422
#
# Approximating hitting prob for (75, 7, 32)
# (75, 7, 32): 0.0752829984502184
# (74, 8, 32): 0.07465561122800159
#
# Approximating hitting prob for (75, 7, 97)
# (75, 7, 97): 0.2602121559604484
# (74, 8, 97): 0.2599056940260309
#
# Approximating hitting prob for (75, 8, 9)
# (75, 8, 9): 0.01657890127290652
# (74, 9, 9): 0.013326532590504566
#
# Approximating hitting prob for (75, 8, 18)
# (75, 8, 18): 0.035302897651050096
# (74, 9, 18): 0.03469807216743508
#
# Approximating hitting prob for (75, 8, 27)
# (75, 8, 27): 0.06775560351385261
# (74, 9, 27): 0.0660932394021558
#
# Approximating hitting prob for (75, 8, 99)
# (75, 8, 99): 0.2613115860585066
# (74, 9, 99): 0.2610267630329686
#
# Approximating hitting prob for (75, 8, 100)
# (75, 8, 100): 0.2621590438752815
# (74, 9, 100): 0.2615623088176841
#
# Approximating hitting prob for (75, 9, 10)
# (75, 9, 10): 0.02093476191337897
# (74, 10, 10): 0.01872148390003157
#
# Approximating hitting prob for (75, 9, 20)
# (75, 9, 20): 0.040932966256199174
# (74, 10, 20): 0.03923481207331841
#
# Approximating hitting prob for (75, 9, 30)
# (75, 9, 30): 0.07641199495220372
# (74, 10, 30): 0.07538239122566849
#
# Approximating hitting prob for (75, 9, 40)
# (75, 9, 40): 0.09007807290253572
# (74, 10, 40): 0.08939358833732935
#
# Approximating hitting prob for (75, 10, 11)
# (75, 10, 11): 0.026448293118526506
# (74, 11, 11): 0.02430742014368195
#
# Approximating hitting prob for (75, 11, 12)
# (75, 11, 12): 0.0302705355063984
# (74, 12, 12): 0.02512359265358942
#
# Approximating hitting prob for (75, 11, 24)
# (75, 11, 24): 0.061041372885200236
# (74, 12, 24): 0.05875124534441994
#
# Approximating hitting prob for (75, 11, 36)
# (75, 11, 36): 0.08873467947807916
# (74, 12, 36): 0.08533473235776527
#
# Approximating hitting prob for (75, 12, 13)
# (75, 12, 13): 0.035560117031675866
# (74, 13, 13): 0.03181936716785986
#
# Approximating hitting prob for (75, 12, 26)
# (75, 12, 26): 0.0742084125549744
# (74, 13, 26): 0.07300054052473919
#
# Approximating hitting prob for (74, 14, 14)
# (74, 14, 14): 0.033343704960000185
# (73, 15, 14): 0.04799382488099504
#
# Approximating hitting prob for (74, 14, 28)
# (74, 14, 28): 0.0750024331409937
# (73, 15, 28): 0.08941052766599439
#
# Approximating hitting prob for (74, 14, 84)
# (74, 14, 84): 0.2532134457418985
# (73, 15, 84): 0.25835314331672166
#
# Approximating hitting prob for (74, 15, 15)
# (74, 15, 15): 0.03568691557700375
# (73, 16, 15): 0.050660764485603665
#
# Approximating hitting prob for (75, 8, 15)
# (75, 8, 15): 0.028610306502734453
# (74, 9, 15): 0.031068083547870606
#
# Approximating hitting prob for (75, 15, 16)
# (75, 15, 16): 0.0496082819218692
# (74, 16, 16): 0.038186135730330965
#
# Approximating hitting prob for (75, 15, 32)
# (75, 15, 32): 0.10099919250267508
# (74, 16, 32): 0.09581811833577543
#
# Approximating hitting prob for (75, 15, 40)
# (75, 15, 40): 0.10976324489514477
# (74, 16, 40): 0.1089016318918112
#
# Approximating hitting prob for (75, 15, 48)
# (75, 15, 48): 0.12343276769911571
# (74, 16, 48): 0.12158827708962376
#
# Approximating hitting prob for (75, 15, 64)
# (75, 15, 64): 0.17410823097771475
# (74, 16, 64): 0.1739520854930148
#
# Approximating hitting prob for (75, 16, 17)
# (75, 16, 17): 0.05220914731695914
# (74, 17, 17): 0.03987127782482055
#
# Approximating hitting prob for (75, 16, 34)
# (75, 16, 34): 0.10495655948746996
# (74, 17, 34): 0.0980634454645866
#
# Approximating hitting prob for (75, 16, 51)
# (75, 16, 51): 0.12757909955672883
# (74, 17, 51): 0.12516845965165646
#
# Approximating hitting prob for (75, 16, 68)
# (75, 16, 68): 0.18291980809178146
# (74, 17, 68): 0.1819993997970517
#
# Approximating hitting prob for (75, 16, 85)
# (75, 16, 85): 0.2579002904484985
# (74, 17, 85): 0.25765000457925236
#
# Approximating hitting prob for (75, 6, 17)
# (75, 6, 17): 0.028755602512749463
# (74, 7, 17): 0.030305866752689214
#
# Approximating hitting prob for (74, 18, 18)
# (74, 18, 18): 0.04184324564063621
# (73, 19, 18): 0.07033772402761854
#
# Approximating hitting prob for (74, 18, 36)
# (74, 18, 36): 0.10180151558908139
# (73, 19, 36): 0.11458249412534705
#
# Approximating hitting prob for (74, 18, 42)
# (74, 18, 42): 0.12045521045263168
# (73, 19, 42): 0.1232729254452839
#
# Approximating hitting prob for (74, 18, 54)
# (74, 18, 54): 0.12783278845918364
# (73, 19, 54): 0.16067938746974747
#
# Approximating hitting prob for (74, 18, 90)
# (74, 18, 90): 0.2603192858906427
# (73, 19, 90): 0.2663705168823457
#
# Approximating hitting prob for (74, 19, 19)
# (74, 19, 19): 0.058981426848726363
# (73, 20, 19): 0.07428473392163513
#
# Approximating hitting prob for (74, 19, 38)
# (74, 19, 38): 0.10746892634946885
# (73, 20, 38): 0.11784307907215504
#
# Approximating hitting prob for (75, 10, 19)
# (75, 10, 19): 0.04097406263714699
# (74, 11, 19): 0.04629463925170119
#
# Approximating hitting prob for (75, 19, 20)
# (75, 19, 20): 0.07317534053107726
# (74, 20, 20): 0.060380208013818465
#
# Approximating hitting prob for (75, 19, 40)
# (75, 19, 40): 0.11748750791269234
# (74, 20, 40): 0.10984510874908134
#
# Approximating hitting prob for (75, 19, 60)
# (75, 19, 60): 0.17802128869089054
# (74, 20, 60): 0.17490236662207007
#
# Approximating hitting prob for (75, 19, 80)
# (75, 19, 80): 0.25947663720665165
# (74, 20, 80): 0.2584176747613042
#
# Approximating hitting prob for (75, 19, 100)
# (75, 19, 100): 0.2810264486180147
# (74, 20, 100): 0.28041108091209105
#
# Approximating hitting prob for (75, 7, 20)
# (75, 7, 20): 0.03771982086458762
# (74, 8, 20): 0.04020458150519362
#
# Approximating hitting prob for (75, 20, 21)
# (75, 20, 21): 0.07539597138914797
# (74, 21, 21): 0.06225386330499138
# Approximating hitting prob for (75, 20, 42)
# (75, 20, 42): 0.12223996885465671
# (74, 21, 42): 0.11574286236347124
#
# Approximating hitting prob for (75, 20, 63)
# (75, 20, 63): 0.18349950044285054
# (74, 21, 63): 0.1782791741808365
#
# Approximating hitting prob for (75, 20, 84)
# (75, 20, 84): 0.26204227465663343
# (74, 21, 84): 0.26098973036814554
#
# Approximating hitting prob for (75, 21, 22)
# (75, 21, 22): 0.07804833129108668
# (74, 22, 22): 0.06480918054717485
#
# Approximating hitting prob for (75, 21, 44)
# (75, 21, 44): 0.12627767992891212
# (74, 22, 44): 0.11952057160484054
#
# Approximating hitting prob for (75, 21, 66)
# (75, 21, 66): 0.19043213228475342
# (74, 22, 66): 0.1849317375886533
#
# Approximating hitting prob for (75, 21, 88)
# (75, 21, 88): 0.26515464325097426
# (74, 22, 88): 0.26377188155166525
#
# Approximating hitting prob for (75, 22, 23)
# (75, 22, 23): 0.08158436171492053
# (74, 23, 23): 0.06849442891974718
#
# Approximating hitting prob for (75, 22, 46)
# (75, 22, 46): 0.13065352037353775
# (74, 23, 46): 0.12388614013858375
#
# Approximating hitting prob for (75, 22, 69)
# (75, 22, 69): 0.1967931982840658
# (74, 23, 69): 0.19240342310238123
#
# Approximating hitting prob for (75, 22, 92)
# (75, 22, 92): 0.26772031330776125
# (74, 23, 92): 0.26577866274954265
#
# Approximating hitting prob for (74, 24, 24)
# (74, 24, 24): 0.0708342846388144
# (73, 25, 24): 0.10345235068062308
#
# Approximating hitting prob for (74, 24, 48)
# (74, 24, 48): 0.12589337304212878
# (73, 25, 48): 0.1703583897973163
#
# Approximating hitting prob for (74, 24, 72)
# (74, 24, 72): 0.19765267243037274
# (73, 25, 72): 0.21835525458296104
#
# Approximating hitting prob for (75, 23, 95)
# (75, 23, 95): 0.26955884179156914
# (74, 24, 95): 0.26947002931524167
#
# Approximating hitting prob for (75, 23, 96)
# (75, 23, 96): 0.27003293823594193
# (74, 24, 96): 0.2670958605208466
#
# Approximating hitting prob for (75, 24, 25)
# (75, 24, 25): 0.09752468390142499
# (74, 25, 25): 0.09702334144543757
#
# Approximating hitting prob for (74, 26, 26)
# (74, 26, 26): 0.09789194647478598
# (73, 27, 26): 0.11620055609884984
#
# Approximating hitting prob for (74, 26, 52)
# (74, 26, 52): 0.17760820194417226
# (73, 27, 52): 0.1881338120559142
#
# Approximating hitting prob for (74, 26, 78)
# (74, 26, 78): 0.2724805432160707
# (73, 27, 78): 0.2813500022195274
#
# Approximating hitting prob for (75, 9, 26)
# (75, 9, 26): 0.06794971364111427
# (74, 10, 26): 0.07123654603432973
#
# Approximating hitting prob for (75, 26, 27)
# (75, 26, 27): 0.1151934595504177
# (74, 27, 27): 0.09895752092069438
#
# Approximating hitting prob for (75, 26, 45)
# (75, 26, 45): 0.14493503488174134
# (74, 27, 45): 0.14474839807285925
#
# Approximating hitting prob for (75, 26, 51)
# (75, 26, 51): 0.1844533137457578
# (74, 27, 51): 0.18436517292291169
#
# Approximating hitting prob for (75, 26, 54)
# (75, 26, 54): 0.1869402461175648
# (74, 27, 54): 0.17969183469975702
#
# Approximating hitting prob for (75, 26, 81)
# (75, 26, 81): 0.27978200258005415
# (74, 27, 81): 0.2744349972875349
#
# Approximating hitting prob for (74, 28, 28)
# (74, 28, 28): 0.10179366122432515
# (73, 29, 28): 0.12050375165440519
#
# Approximating hitting prob for (74, 28, 42)
# (74, 28, 42): 0.14053968592816382
# (73, 29, 42): 0.14440854514238297
#
# Approximating hitting prob for (74, 28, 56)
# (74, 28, 56): 0.1832319150288615
# (73, 29, 56): 0.19445605051806322
#
# Approximating hitting prob for (74, 28, 84)
# (74, 28, 84): 0.27944188437507356
# (73, 29, 84): 0.2877544113467285
#
# Approximating hitting prob for (74, 29, 29)
# (74, 29, 29): 0.10306054929858906
# (73, 30, 29): 0.12270063189526137
#
# Approximating hitting prob for (74, 29, 58)
# (74, 29, 58): 0.1863815184378708
# (73, 30, 58): 0.1993899834724331
#
# Approximating hitting prob for (74, 29, 87)
# (74, 29, 87): 0.2812130222878335
# (73, 30, 87): 0.29150512425405345
#
# Approximating hitting prob for (75, 10, 29)
# (75, 10, 29): 0.07702359046345143
# (74, 11, 29): 0.0808984540868005
#
# Approximating hitting prob for (75, 29, 30)
# (75, 29, 30): 0.12085852856009459
# (74, 30, 30): 0.10468304213991127
#
# Approximating hitting prob for (75, 29, 60)
# (75, 29, 60): 0.19615070032785184
# (74, 30, 60): 0.19223678813726264
#
# Approximating hitting prob for (75, 29, 90)
# (75, 29, 90): 0.28880405292836225
# (74, 30, 90): 0.284574237114728
#
# Approximating hitting prob for (75, 30, 31)
# (75, 30, 31): 0.12285861750833361
# (74, 31, 31): 0.10616626159374137
#
# Approximating hitting prob for (75, 30, 62)
# (75, 30, 62): 0.20209434666891815
# (74, 31, 62): 0.1940882421984698
#
# Approximating hitting prob for (75, 30, 76)
# (75, 30, 76): 0.28380990722334315
# (74, 31, 76): 0.283237594405445
#
# Approximating hitting prob for (75, 30, 93)
# (75, 30, 93): 0.2922889709633558
# (74, 31, 93): 0.2871814454323565
#
# Approximating hitting prob for (75, 16, 31)
# (75, 16, 31): 0.10290096242213413
# (74, 17, 31): 0.1034455371735387
#
# Approximating hitting prob for (75, 31, 32)
# (75, 31, 32): 0.12441856251122256
# (74, 32, 32): 0.10714816572091296
#
# Approximating hitting prob for (75, 31, 64)
# (75, 31, 64): 0.20461371275450635
# (74, 32, 64): 0.2025178705547225
#
# Approximating hitting prob for (75, 31, 96)
# (75, 31, 96): 0.29454719925265044
# (74, 32, 96): 0.2889984348044636
#
# Approximating hitting prob for (75, 11, 32)
# (75, 11, 32): 0.08279343287345231
# (74, 12, 32): 0.08436454625384575
#
# Approximating hitting prob for (75, 32, 33)
# (75, 32, 33): 0.12588099747842782
# (74, 33, 33): 0.10834920160651136
#
# Approximating hitting prob for (75, 32, 66)
# (75, 32, 66): 0.2127739751963974
# (74, 33, 66): 0.2048800942539658
#
# Approximating hitting prob for (75, 32, 99)
# (75, 32, 99): 0.29668468015018706
# (74, 33, 99): 0.2910789476624964
#
# Approximating hitting prob for (74, 34, 34)
# (74, 34, 34): 0.1097535908338856
# (73, 35, 34): 0.13133978846806452
#
# Approximating hitting prob for (74, 34, 51)
# (74, 34, 51): 0.18889571074018288
# (73, 35, 51): 0.19673009629539984
#
# Approximating hitting prob for (74, 34, 68)
# (74, 34, 68): 0.20796403677472056
# (73, 35, 68): 0.22120827300177925
#
# Approximating hitting prob for (74, 35, 35)
# (74, 35, 35): 0.11041553123148001
# (73, 36, 35): 0.13526965181521067
#
# Approximating hitting prob for (74, 35, 70)
# (74, 35, 70): 0.21120909075680064
# (73, 36, 70): 0.2235043085674199
#
# Approximating hitting prob for (75, 12, 35)
# (75, 12, 35): 0.08747846474840548
# (74, 13, 35): 0.09659601919661524
#
# Approximating hitting prob for (74, 36, 36)
# (74, 36, 36): 0.11088277144475939
# (73, 37, 36): 0.16827145146486341
#
# Approximating hitting prob for (74, 36, 60)
# (74, 36, 60): 0.2066609586507697
# (73, 37, 60): 0.2214936688289908
#
# Approximating hitting prob for (74, 36, 72)
# (74, 36, 72): 0.2136849267720562
# (73, 37, 72): 0.23948869014677285
#
# Approximating hitting prob for (74, 36, 84)
# (74, 36, 84): 0.291283114019216
# (73, 37, 84): 0.30569057258644694
#
# Approximating hitting prob for (75, 19, 37)
# (75, 19, 37): 0.11367892447765697
# (74, 20, 37): 0.11613767034712974
#
# Approximating hitting prob for (75, 37, 38)
# (75, 37, 38): 0.16827010010958776
# (74, 38, 38): 0.1636162513231499
#
# Approximating hitting prob for (75, 13, 38)
# (75, 13, 38): 0.10365474934053799
# (74, 14, 38): 0.10398999509880051
#
# Approximating hitting prob for (75, 26, 38)
# (75, 26, 38): 0.13451420239434153
# (74, 27, 38): 0.1365628036925285
#
# Approximating hitting prob for (75, 38, 39)
# (75, 38, 39): 0.20193475914125378
# (74, 39, 39): 0.16415950387054776
#
# Approximating hitting prob for (75, 38, 63)
# (75, 38, 63): 0.22681755415918267
# (74, 39, 63): 0.22677058780261442
#
# Approximating hitting prob for (75, 38, 78)
# (75, 38, 78): 0.3013341873953855
# (74, 39, 78): 0.2921521245739223
#
# Approximating hitting prob for (75, 38, 89)
# (75, 38, 89): 0.3099531231974198
# (74, 39, 89): 0.30919509540407825
#
# Approximating hitting prob for (75, 20, 39)
# (75, 20, 39): 0.11725363500316931
# (74, 21, 39): 0.12013462888089362
#
# Approximating hitting prob for (75, 39, 40)
# (75, 39, 40): 0.20556193318470686
# (74, 40, 40): 0.1648071609767115
#
# Approximating hitting prob for (75, 39, 60)
# (75, 39, 60): 0.2206715457046359
# (74, 40, 60): 0.21992438548753102
#
# Approximating hitting prob for (75, 39, 80)
# (75, 39, 80): 0.3026891503218257
# (74, 40, 80): 0.2935828611378699
#
# Approximating hitting prob for (75, 39, 91)
# (75, 39, 91): 0.3110501853006787
# (74, 40, 91): 0.3104011236446745
#
# Approximating hitting prob for (75, 40, 41)
# (75, 40, 41): 0.20639123693230163
# (74, 41, 41): 0.1657805427734144
# Approximating hitting prob for (75, 40, 82)
# (75, 40, 82): 0.3042330170301725
# (74, 41, 82): 0.29424685730810524
#
# Approximating hitting prob for (75, 40, 92)
# (75, 40, 92): 0.31161321531743374
# (74, 41, 92): 0.31101267114503933
#
# Approximating hitting prob for (75, 14, 41)
# (75, 14, 41): 0.10714953085158459
# (74, 15, 41): 0.11153416428853409
#
# Approximating hitting prob for (75, 28, 41)
# (75, 28, 41): 0.1405865139560268
# (74, 29, 41): 0.14240520768601403
#
# Approximating hitting prob for (75, 41, 42)
# (75, 41, 42): 0.2075215652882831
# (74, 42, 42): 0.167046594068637
#
# Approximating hitting prob for (75, 41, 63)
# (75, 41, 63): 0.22673314578680234
# (74, 42, 63): 0.22591061640813895
#
# Approximating hitting prob for (75, 41, 84)
# (75, 41, 84): 0.305560144510907
# (74, 42, 84): 0.2962634727325426
#
# Approximating hitting prob for (75, 41, 94)
# (75, 41, 94): 0.31250794715369906
# (74, 42, 94): 0.31186946827976086
#
# Approximating hitting prob for (75, 42, 43)
# (75, 42, 43): 0.20860529717134046
# (74, 43, 43): 0.1679046917405278
#
# Approximating hitting prob for (75, 42, 86)
# (75, 42, 86): 0.3070144568266206
# (74, 43, 86): 0.2974777067940721
#
# Approximating hitting prob for (74, 44, 44)
# (74, 44, 44): 0.16902672149339423
# (73, 45, 44): 0.21626419314800593
#
# Approximating hitting prob for (74, 44, 66)
# (74, 44, 66): 0.23181448583210593
# (73, 45, 66): 0.23758942194048827
#
# Approximating hitting prob for (74, 44, 88)
# (74, 44, 88): 0.29841769828657166
# (73, 45, 88): 0.3154009959392343
#
# Approximating hitting prob for (74, 44, 97)
# (74, 44, 97): 0.31723244584321614
# (73, 45, 97): 0.3204602775914153
#
# Approximating hitting prob for (74, 45, 45)
# (74, 45, 45): 0.1741407382915102
# (73, 46, 45): 0.2175721586827392
#
# Approximating hitting prob for (74, 45, 90)
# (74, 45, 90): 0.3053663703579343
# (73, 46, 90): 0.3174059667584473
#
# Approximating hitting prob for (75, 23, 45)
# (75, 23, 45): 0.13120704501031233
# (74, 24, 45): 0.13327984478795565
#
# Approximating hitting prob for (75, 45, 46)
# (75, 45, 46): 0.2157386376577836
# (74, 46, 46): 0.17497492823570812
#
# Approximating hitting prob for (75, 45, 69)
# (75, 45, 69): 0.23817423636631815
# (74, 46, 69): 0.23694916792068407
#
# Approximating hitting prob for (75, 45, 70)
# (75, 45, 70): 0.24035746401076397
# (74, 46, 70): 0.2403097308820216
#
# Approximating hitting prob for (75, 45, 92)
# (75, 45, 92): 0.3156615544672947
# (74, 46, 92): 0.3062216673228812
#
# Approximating hitting prob for (75, 46, 47)
# (75, 46, 47): 0.21712549893774682
# (74, 47, 47): 0.17703175607569513
#
# Approximating hitting prob for (75, 46, 71)
# (75, 46, 71): 0.24163414468172975
# (74, 47, 71): 0.24088181133519102
#
# Approximating hitting prob for (75, 46, 94)
# (75, 46, 94): 0.31693740992852854
# (74, 47, 94): 0.30710718166531586
#
# Approximating hitting prob for (75, 8, 47)
# (75, 8, 47): 0.09728560175803787
# (74, 9, 47): 0.1055850222348963
#
# Approximating hitting prob for (75, 24, 47)
# (75, 24, 47): 0.13393482438658139
# (74, 25, 47): 0.14642955643486247
#
# Approximating hitting prob for (75, 32, 47)
# (75, 32, 47): 0.18478707970584954
# (74, 33, 47): 0.18645975747160473
#
# Approximating hitting prob for (75, 47, 48)
# (75, 47, 48): 0.21886577662368453
# (74, 48, 48): 0.1780859916520069
#
# Approximating hitting prob for (75, 47, 72)
# (75, 47, 72): 0.24278419392670694
# (74, 48, 72): 0.23921943085467776
#
# Approximating hitting prob for (75, 47, 96)
# (75, 47, 96): 0.31847619314749365
# (74, 48, 96): 0.3093695286213333
#
# Approximating hitting prob for (75, 48, 49)
# (75, 48, 49): 0.22010588452362
# (74, 49, 49): 0.1788042103892519
#
# Approximating hitting prob for (75, 48, 98)
# (75, 48, 98): 0.3206660566987458
# (74, 49, 98): 0.3101299786569652
#
# Approximating hitting prob for (75, 10, 49)
# (75, 10, 49): 0.11076369437910512
# (74, 11, 49): 0.11449784336817244
#
# Approximating hitting prob for (75, 49, 50)
# (75, 49, 50): 0.22166817742022796
# (74, 50, 50): 0.1850126849571504
#
# Approximating hitting prob for (75, 49, 100)
# (75, 49, 100): 0.32180700985033145
# (74, 50, 100): 0.31376964788545547
#
# Approximating hitting prob for (75, 34, 50)
# (75, 34, 50): 0.18932747982371878
# (74, 35, 50): 0.19448653793966772
#
# Approximating hitting prob for (75, 50, 51)
# (75, 50, 51): 0.22699521999512187
# (74, 51, 51): 0.18618674126892318
#
# Approximating hitting prob for (75, 13, 51)
# (75, 13, 51): 0.12262274475347003
# (74, 14, 51): 0.12567417733777586
#
# Approximating hitting prob for (75, 51, 52)
# (75, 51, 52): 0.22837797512532362
# (74, 52, 52): 0.18836689727216405
#
# Approximating hitting prob for (75, 51, 76)
# (75, 51, 76): 0.32350872434391126
# (74, 52, 76): 0.32223349741027957
#
# Approximating hitting prob for (75, 52, 53)
# (75, 52, 53): 0.23003074275000393
# (74, 53, 53): 0.18987014768598878
#
# Approximating hitting prob for (75, 52, 77)
# (75, 52, 77): 0.32396884203479576
# (74, 53, 77): 0.3231920159208222
#
# Approximating hitting prob for (75, 27, 53)
# (75, 27, 53): 0.18714433127673932
# (74, 28, 53): 0.18905895716515672
#
# Approximating hitting prob for (75, 53, 54)
# (75, 53, 54): 0.23190036951818785
# (74, 54, 54): 0.19056460191372426
#
# Approximating hitting prob for (75, 53, 78)
# (75, 53, 78): 0.32445053325344175
# (74, 54, 78): 0.3238239699166137
#
# Approximating hitting prob for (75, 53, 90)
# (75, 53, 90): 0.32229321690418467
# (74, 54, 90): 0.32216183460476355
#
# Approximating hitting prob for (75, 11, 54)
# (75, 11, 54): 0.12202718110198442
# (74, 12, 54): 0.12394701749337482
#
# Approximating hitting prob for (75, 54, 55)
# (75, 54, 55): 0.23301139250426964
# (74, 55, 55): 0.1912542319917254
#
# Approximating hitting prob for (75, 54, 79)
# (75, 54, 79): 0.32535792863386637
# (74, 55, 79): 0.3247902640554235
#
# Approximating hitting prob for (75, 14, 55)
# (75, 14, 55): 0.12888265477183689
# (74, 15, 55): 0.13274193227724004
#
# Approximating hitting prob for (74, 56, 56)
# (74, 56, 56): 0.20076267902539857
# (73, 57, 56): 0.24474163258454384
#
# Approximating hitting prob for (74, 56, 80)
# (74, 56, 80): 0.32592094115424486
# (73, 57, 80): 0.3281205069403726
#
# Approximating hitting prob for (74, 57, 57)
# (74, 57, 57): 0.20153178015170273
# (73, 58, 57): 0.2459112913163638
#
# Approximating hitting prob for (74, 57, 81)
# (74, 57, 81): 0.326525853890789
# (73, 58, 81): 0.32878811097691213
#
# Approximating hitting prob for (75, 29, 57)
# (75, 29, 57): 0.19293251309668416
# (74, 30, 57): 0.19518772387020397
#
# Approximating hitting prob for (75, 57, 58)
# (75, 57, 58): 0.24402802515801603
# (74, 58, 58): 0.20284476427213097
#
# Approximating hitting prob for (75, 58, 59)
# (75, 58, 59): 0.2451574629705502
# (74, 59, 59): 0.20347370581732174
#
# Approximating hitting prob for (75, 30, 59)
# (75, 30, 59): 0.19587499794529298
# (74, 31, 59): 0.20156176793888772
#
# Approximating hitting prob for (74, 60, 60)
# (74, 60, 60): 0.2050582295246637
# (73, 61, 60): 0.25022650314620715
#
# Approximating hitting prob for (74, 60, 84)
# (74, 60, 84): 0.32962371634683024
# (73, 61, 84): 0.33316333538504334
#
# Approximating hitting prob for (74, 61, 61)
# (74, 61, 61): 0.20578124750227542
# (73, 62, 61): 0.25342357137174343
#
# Approximating hitting prob for (74, 61, 85)
# (74, 61, 85): 0.33084877178128846
# (73, 62, 85): 0.334160566043038
#
# Approximating hitting prob for (75, 31, 61)
# (75, 31, 61): 0.20191319961587206
# (74, 32, 61): 0.20353708187392727
#
# Approximating hitting prob for (75, 61, 62)
# (75, 61, 62): 0.24871727080111472
# (74, 62, 62): 0.2094159993758522
#
# Approximating hitting prob for (75, 42, 62)
# (75, 42, 62): 0.22646956201683746
# (74, 43, 62): 0.22983143849280516
#
# Approximating hitting prob for (75, 62, 63)
# (75, 62, 63): 0.25077577030038084
# (74, 63, 63): 0.21002509041869175
#
# Approximating hitting prob for (75, 32, 63)
# (75, 32, 63): 0.20375452561186158
# (74, 33, 63): 0.21011171779403412
#
# Approximating hitting prob for (75, 63, 64)
# (75, 63, 64): 0.2538936582481911
# (74, 64, 64): 0.21180550788802355
#
# Approximating hitting prob for (75, 63, 88)
# (75, 63, 88): 0.3358547277932556
# (74, 64, 88): 0.335372359636609
#
# Approximating hitting prob for (75, 64, 65)
# (75, 64, 65): 0.2553494204639501
# (74, 65, 65): 0.2141924217880239
#
# Approximating hitting prob for (75, 64, 89)
# (75, 64, 89): 0.33645340388470557
# (74, 65, 89): 0.3361352516997349
#
# Approximating hitting prob for (75, 33, 65)
# (75, 33, 65): 0.21305756342682078
# (74, 34, 65): 0.21535236666922633
#
# Approximating hitting prob for (74, 66, 66)
# (74, 66, 66): 0.2149380440693456
# (73, 67, 66): 0.2607639207029358
# Approximating hitting prob for (74, 66, 90)
# (74, 66, 90): 0.33733457535128814
# (73, 67, 90): 0.3392584180322367
#
# Approximating hitting prob for (74, 67, 67)
# (74, 67, 67): 0.2158053025380772
# (73, 68, 67): 0.2620085453613603
#
# Approximating hitting prob for (75, 17, 67)
# (75, 17, 67): 0.1825805861548793
# (74, 18, 67): 0.18575461989719652
#
# Approximating hitting prob for (74, 68, 68)
# (74, 68, 68): 0.21713414450345844
# (73, 69, 68): 0.2632040333138858
#
# Approximating hitting prob for (74, 68, 92)
# (74, 68, 92): 0.3394589794233483
# (73, 69, 92): 0.3404436515731836
#
# Approximating hitting prob for (75, 23, 68)
# (75, 23, 68): 0.19716507625239255
# (74, 24, 68): 0.1992176114675164
#
# Approximating hitting prob for (74, 69, 69)
# (74, 69, 69): 0.2182738443826244
# (73, 70, 69): 0.2642297962913995
#
# Approximating hitting prob for (74, 69, 93)
# (74, 69, 93): 0.3400414583559923
# (73, 70, 93): 0.34142541693646167
#
# Approximating hitting prob for (75, 35, 69)
# (75, 35, 69): 0.21870181899233612
# (74, 36, 69): 0.22190783339621165
#
# Approximating hitting prob for (75, 69, 70)
# (75, 69, 70): 0.26219172207648733
# (74, 70, 70): 0.21939522112946333
#
# Approximating hitting prob for (75, 69, 94)
# (75, 69, 94): 0.34133063988236584
# (74, 70, 94): 0.34088033387850564
#
# Approximating hitting prob for (75, 70, 71)
# (75, 70, 71): 0.2633549301773993
# (74, 71, 71): 0.220228139893504
#
# Approximating hitting prob for (75, 70, 95)
# (75, 70, 95): 0.3419887581912986
# (74, 71, 95): 0.3416167692577958
#
# Approximating hitting prob for (75, 36, 71)
# (75, 36, 71): 0.22206207416367604
# (74, 37, 71): 0.23524471196671795
#
# Approximating hitting prob for (74, 72, 72)
# (74, 72, 72): 0.22109218227672056
# (73, 73, 72): 0.32210907910431696
#
# Approximating hitting prob for (74, 72, 96)
# (74, 72, 96): 0.34219947871014506
# (73, 73, 96): 0.3995574551461436
#
# Approximating hitting prob for (74, 73, 73)
# (74, 73, 73): 0.22177536242457785
# (73, 74, 73): 0.38911231878748537
#
# Approximating hitting prob for (74, 73, 97)
# (74, 73, 97): 0.34304172838857067
# (73, 74, 97): 0.4140556548850434
#
# Approximating hitting prob for (74, 19, 76)
# (74, 19, 76): 0.25625098333144164
# (73, 20, 76): 0.26013001119609597
#
# Approximating hitting prob for (74, 38, 76)
# (74, 38, 76): 0.2912345087836344
# (73, 39, 76): 0.3028963687555419
#
# Approximating hitting prob for (74, 76, 76)
# (74, 76, 76): 0.356107222667877
# (73, 77, 76): 0.4014041490267711
#
# Approximating hitting prob for (74, 11, 77)
# (74, 11, 77): 0.24565935193411817
# (73, 12, 77): 0.24877463887054482
#
# Approximating hitting prob for (74, 77, 77)
# (74, 77, 77): 0.3565499380588926
# (73, 78, 77): 0.40195004189189015
#
# Approximating hitting prob for (74, 13, 78)
# (74, 13, 78): 0.24960636019467844
# (73, 14, 78): 0.25235282298336886
#
# Approximating hitting prob for (75, 26, 77)
# (75, 26, 77): 0.278607282465909
# (74, 27, 77): 0.27961385057936633
#
# Approximating hitting prob for (74, 78, 78)
# (74, 78, 78): 0.3570002527493408
# (73, 79, 78): 0.4024833927275555
#
# Approximating hitting prob for (74, 79, 79)
# (74, 79, 79): 0.3575070533277455
# (73, 80, 79): 0.4031134744644771
#
# Approximating hitting prob for (75, 20, 79)
# (75, 20, 79): 0.25987176223962166
# (74, 21, 79): 0.2617102021963725
#
# Approximating hitting prob for (74, 80, 80)
# (74, 80, 80): 0.3580455746007865
# (73, 81, 80): 0.4038924615944828
#
# Approximating hitting prob for (75, 27, 80)
# (75, 27, 80): 0.2807165379185073
# (74, 28, 80): 0.28213078226215654
#
# Approximating hitting prob for (75, 80, 81)
# (75, 80, 81): 0.40245512237433007
# (74, 81, 81): 0.35859710229651803
#
# Approximating hitting prob for (74, 82, 82)
# (74, 82, 82): 0.3593547450005788
# (73, 83, 82): 0.40572791888547743
#
# Approximating hitting prob for (74, 83, 83)
# (74, 83, 83): 0.3596672199889328
# (73, 84, 83): 0.4063104645530024
#
# Approximating hitting prob for (74, 12, 84)
# (74, 12, 84): 0.2503816786128138
# (73, 13, 84): 0.2547207098905098
#
# Approximating hitting prob for (75, 14, 83)
# (75, 14, 83): 0.25346477424145913
# (74, 15, 83): 0.25658499221612285
#
# Approximating hitting prob for (75, 28, 83)
# (75, 28, 83): 0.28213497299814355
# (74, 29, 83): 0.2862207940614721
#
# Approximating hitting prob for (74, 84, 84)
# (74, 84, 84): 0.3609460503028083
# (73, 85, 84): 0.40659772755225077
#
# Approximating hitting prob for (75, 17, 84)
# (75, 17, 84): 0.2579189541773198
# (74, 18, 84): 0.2600176416482726
#
# Approximating hitting prob for (75, 51, 84)
# (75, 51, 84): 0.3193982292450081
# (74, 52, 84): 0.32032426246802387
#
# Approximating hitting prob for (75, 84, 85)
# (75, 84, 85): 0.4054251461046256
# (74, 85, 85): 0.36149402709774464
#
# Approximating hitting prob for (74, 86, 86)
# (74, 86, 86): 0.36187175254697523
# (73, 87, 86): 0.4087958950988175
#
# Approximating hitting prob for (75, 29, 86)
# (75, 29, 86): 0.2871989566528891
# (74, 30, 86): 0.28872982679115883
#
# Approximating hitting prob for (75, 86, 87)
# (75, 86, 87): 0.4066713177280115
# (74, 87, 87): 0.36341932699083185
#
# Approximating hitting prob for (75, 44, 87)
# (75, 44, 87): 0.3083156975948025
# (74, 45, 87): 0.3139657206506226
#
# Approximating hitting prob for (75, 87, 88)
# (75, 87, 88): 0.40768836147582915
# (74, 88, 88): 0.363906097074095
#
# Approximating hitting prob for (75, 88, 89)
# (75, 88, 89): 0.40869437172645795
# (74, 89, 89): 0.36508365320698305
#
# Approximating hitting prob for (75, 30, 89)
# (75, 30, 89): 0.2890399946960657
# (74, 31, 89): 0.2920857469821221
#
# Approximating hitting prob for (75, 54, 89)
# (75, 54, 89): 0.32275556325243765
# (74, 55, 89): 0.33030331654201406
#
# Approximating hitting prob for (75, 89, 90)
# (75, 89, 90): 0.4094169474694882
# (74, 90, 90): 0.3656314001289586
#
# Approximating hitting prob for (75, 13, 90)
# (75, 13, 90): 0.2674291209887983
# (74, 14, 90): 0.2685796274061138
#
# Approximating hitting prob for (75, 90, 91)
# (75, 90, 91): 0.4103384682770565
# (74, 91, 91): 0.36595011208201605
#
# Approximating hitting prob for (75, 46, 91)
# (75, 46, 91): 0.3160757136559702
# (74, 47, 91): 0.3174493134304255
#
# Approximating hitting prob for (75, 91, 92)
# (75, 91, 92): 0.4107014078603457
# (74, 92, 92): 0.3662266136986756
#
# Approximating hitting prob for (74, 93, 93)
# (74, 93, 93): 0.36966845751223115
# (73, 94, 93): 0.41573768724380256
#
# Approximating hitting prob for (75, 47, 93)
# (75, 47, 93): 0.31707835740918083
# (74, 48, 93): 0.31952531738181783
#
# Approximating hitting prob for (75, 93, 94)
# (75, 93, 94): 0.41251899263901554
# (74, 94, 94): 0.3699210335794236
#
# Approximating hitting prob for (75, 94, 95)
# (75, 94, 95): 0.4146751598364538
# (74, 95, 95): 0.3702588984008192
#
# Approximating hitting prob for (75, 16, 95)
# (75, 16, 95): 0.27393357822293324
# (74, 17, 95): 0.27536706289757934
#
# Approximating hitting prob for (75, 32, 95)
# (75, 32, 95): 0.29490764715427026
# (74, 33, 95): 0.29641259583021434
#
# Approximating hitting prob for (74, 96, 96)
# (74, 96, 96): 0.37112671201284025
# (73, 97, 96): 0.4167959633997933
#
# Approximating hitting prob for (74, 97, 97)
# (74, 97, 97): 0.3714831837626777
# (73, 98, 97): 0.4187591386807898
#
# Approximating hitting prob for (75, 49, 97)
# (75, 49, 97): 0.3205255287886661
# (74, 50, 97): 0.32407289306509024
#
# Approximating hitting prob for (75, 97, 98)
# (75, 97, 98): 0.4165553731108114
# (74, 98, 98): 0.37181979029391615
#
# Approximating hitting prob for (74, 99, 99)
# (74, 99, 99): 0.37401179160429293
# (73, 100, 99): 0.42001845688613804
#
# Approximating hitting prob for (74, 13, 100)
# (74, 13, 100): 0.27060467983388525
# (73, 14, 100): 0.2735392177539206
#
# Approximating hitting prob for (75, 20, 99)
# (75, 20, 99): 0.28123155099884534
# (74, 21, 99): 0.2824229371107191
#
# Approximating hitting prob for (74, 52, 100)
# (74, 52, 100): 0.3251891291627604
# (73, 53, 100): 0.3279639225672998
#
# Approximating hitting prob for (74, 100, 100)
# (74, 100, 100): 0.37421559382297637
# (73, 101, 100): 0.42057826351944483
#
# Approximating hitting prob for (75, 2, 79)
# (75, 2, 79): 0.24792279914018422
# (74, 3, 79): 0.24901192447179962
#
# Approximating hitting prob for (75, 2, 80)
# (75, 2, 80): 0.2481497246335492
# (74, 3, 80): 0.2491428523567348
#
# Approximating hitting prob for (75, 3, 82)
# (75, 3, 82): 0.24935449910563423
# (74, 4, 82): 0.25025839140736766
#
# Approximating hitting prob for (75, 3, 83)
# (75, 3, 83): 0.2495461732328639
# (74, 4, 83): 0.25049094185641513
#
# Approximating hitting prob for (75, 4, 4)
# (75, 4, 4): 0.002725644687536197
# (74, 5, 4): 0.005776966424976197
#
# Approximating hitting prob for (75, 4, 85)
# (75, 4, 85): 0.2507627310248186
# (74, 5, 85): 0.25224911839307435
#
# Approximating hitting prob for (75, 4, 86)
# (75, 4, 86): 0.2509619956164101
# (74, 5, 86): 0.2524853442811768
#
# Approximating hitting prob for (75, 5, 88)
# (75, 5, 88): 0.25243999673834744
# (74, 6, 88): 0.25454567306864534
#
# Approximating hitting prob for (75, 5, 89)
# (75, 5, 89): 0.25263511689072754
# (74, 6, 89): 0.25471668534900294
#
# Approximating hitting prob for (75, 6, 6)
# (75, 6, 6): 0.007152164969436561
# (74, 7, 6): 0.011614550038571897
#
# Approximating hitting prob for (75, 7, 7)
# (75, 7, 7): 0.008458876439122817
# (74, 8, 7): 0.014021250728491924
#
# Approximating hitting prob for (75, 7, 14)
# (75, 7, 14): 0.023420231273366232
# (74, 8, 14): 0.02779847477167983
#
# Approximating hitting prob for (75, 7, 95)
# (75, 7, 95): 0.25732914191828027
# (74, 8, 95): 0.25918646393251993
#
# Approximating hitting prob for (75, 8, 8)
# (75, 8, 8): 0.011395740721392563
# (74, 9, 8): 0.016901949014843685
#
# Approximating hitting prob for (75, 8, 16)
# (75, 8, 16): 0.026185780778167855
# (74, 9, 16): 0.03542910699286122
#
# Approximating hitting prob for (75, 8, 98)
# (75, 8, 98): 0.2598161416476315
# (74, 9, 98): 0.2611278124589374
#
# Approximating hitting prob for (75, 9, 9)
# (75, 9, 9): 0.013159794320837538
# (74, 10, 9): 0.021277966689307384
#
# Approximating hitting prob for (75, 9, 18)
# (75, 9, 18): 0.03447077651730303
# (74, 10, 18): 0.04024091640506971
#
# Approximating hitting prob for (75, 9, 27)
# (75, 9, 27): 0.06580277762586492
# (74, 10, 27): 0.07217507822615284
#
# Approximating hitting prob for (75, 9, 100)
# (75, 9, 100): 0.2611708943791547
# (74, 10, 100): 0.263085554823505
#
# Approximating hitting prob for (75, 10, 10)
# (75, 10, 10): 0.0184663233889489
# (74, 11, 10): 0.026774626328169262
#
# Approximating hitting prob for (75, 10, 20)
# (75, 10, 20): 0.03882058405215375
# (74, 11, 20): 0.04769047226559475
#
# Approximating hitting prob for (75, 11, 11)
# (75, 11, 11): 0.024146273028499338
# (74, 12, 11): 0.030439661887694567
#
# Approximating hitting prob for (75, 12, 12)
# (75, 12, 12): 0.02503917443614127
# (74, 13, 12): 0.03705753581655181
#
# Approximating hitting prob for (75, 12, 24)
# (75, 12, 24): 0.05816958464963181
# (74, 13, 24): 0.0660471893606372
#
# Approximating hitting prob for (75, 12, 36)
# (75, 12, 36): 0.08492819106187045
# (74, 13, 36): 0.10020728906088244
#
# Approximating hitting prob for (75, 13, 13)
# (75, 13, 13): 0.03171622924837379
# (74, 14, 13): 0.045137816215632794
#
# Approximating hitting prob for (75, 13, 26)
# (75, 13, 26): 0.07280504378591797
# (74, 14, 26): 0.07834773312866226
#
# Approximating hitting prob for (76, 7, 13)
# (76, 7, 13): 0.02450473273265859
# (75, 8, 13): 0.025922365435873732
#
# Approximating hitting prob for (76, 13, 14)
# (76, 13, 14): 0.04432246087120529
# (75, 14, 14): 0.03268378223353987
#
# Approximating hitting prob for (76, 13, 28)
# (76, 13, 28): 0.07861860183566531
# (75, 14, 28): 0.07471155005998945
#
# Approximating hitting prob for (76, 13, 42)
# (76, 13, 42): 0.10645152200831397
# (75, 14, 42): 0.10416897100219187
#
# Approximating hitting prob for (76, 13, 84)
# (76, 13, 84): 0.25276661209370366
# (75, 14, 84): 0.25259445665153174
#
# Approximating hitting prob for (76, 13, 98)
# (76, 13, 98): 0.2696182115212436
# (75, 14, 98): 0.2695358268270291
#
# Approximating hitting prob for (76, 14, 15)
# (76, 14, 15): 0.04638134401716209
# (75, 15, 15): 0.03516819571864877
#
# Approximating hitting prob for (75, 16, 16)
# (75, 16, 16): 0.036638916344830595
# (74, 17, 16): 0.05265990032723617
#
# Approximating hitting prob for (75, 16, 32)
# (75, 16, 32): 0.09548536258497277
# (74, 17, 32): 0.10449238204872831
#
# Approximating hitting prob for (75, 16, 48)
# (75, 16, 48): 0.11952163887905733
# (74, 17, 48): 0.12688566210571808
#
# Approximating hitting prob for (75, 17, 17)
# (75, 17, 17): 0.03932265627015092
# (74, 18, 17): 0.055541992108257804
#
# Approximating hitting prob for (75, 17, 34)
# (75, 17, 34): 0.09747299684500738
# (74, 18, 34): 0.10865112599985277
#
# Approximating hitting prob for (75, 17, 51)
# (75, 17, 51): 0.12445229338272046
# (74, 18, 51): 0.13295341323458246
#
# Approximating hitting prob for (75, 17, 85)
# (75, 17, 85): 0.2564742686115978
# (74, 18, 85): 0.26049865830343627
#
# Approximating hitting prob for (76, 9, 17)
# (76, 9, 17): 0.035748765052067255
# (75, 10, 17): 0.037839506383854755
#
# Approximating hitting prob for (76, 17, 18)
# (76, 17, 18): 0.054095227859020024
# (75, 18, 18): 0.04156656110898064
#
# Approximating hitting prob for (76, 17, 36)
# (76, 17, 36): 0.10766394208065595
# (75, 18, 36): 0.10142525229218892
#
# Approximating hitting prob for (76, 17, 54)
# (76, 17, 54): 0.1316956625794684
# (75, 18, 54): 0.12735948790386942
#
# Approximating hitting prob for (76, 17, 90)
# (76, 17, 90): 0.26022570408730017
# (75, 18, 90): 0.25982717958095863
#
# Approximating hitting prob for (76, 18, 38)
# (76, 18, 38): 0.11098040613315345
# (75, 19, 38): 0.10696713876811559
#
# Approximating hitting prob for (75, 20, 20)
# (75, 20, 20): 0.05983155138302699
# (74, 21, 20): 0.07605884166811132
#
# Approximating hitting prob for (75, 20, 40)
# (75, 20, 40): 0.10947898498488035
# (74, 21, 40): 0.12125992137254288
#
# Approximating hitting prob for (75, 20, 60)
# (75, 20, 60): 0.1741507445766303
# (74, 21, 60): 0.18294981242719363
#
# Approximating hitting prob for (75, 20, 80)
# (75, 20, 80): 0.25795324435062045
# (74, 21, 80): 0.2619543804241364
#
# Approximating hitting prob for (75, 20, 100)
# (75, 20, 100): 0.27990005046563865
# (74, 21, 100): 0.28289528220362675
#
# Approximating hitting prob for (75, 7, 21)
# (75, 7, 21): 0.03672871868171613
# (74, 8, 21): 0.04264338021613723
#
# Approximating hitting prob for (75, 21, 21)
# (75, 21, 21): 0.06199106522539987
# (74, 22, 21): 0.07897723808246941
#
# Approximating hitting prob for (75, 21, 42)
# (75, 21, 42): 0.11525218523508844
# (74, 22, 42): 0.12583176647518987
#
# Approximating hitting prob for (75, 21, 58)
# (75, 21, 58): 0.17693759770870496
# (74, 22, 58): 0.17895438171440717
#
# Approximating hitting prob for (75, 21, 63)
# (75, 21, 63): 0.17759823435894542
# (74, 22, 63): 0.18817976396225167
#
# Approximating hitting prob for (75, 21, 84)
# (75, 21, 84): 0.26043493709561366
# (74, 22, 84): 0.26475686690777384
#
# Approximating hitting prob for (75, 22, 22)
# (75, 22, 22): 0.06455435050881571
# (74, 23, 22): 0.08281369789349637
#
# Approximating hitting prob for (75, 22, 44)
# (75, 22, 44): 0.1179792969498842
# (74, 23, 44): 0.12992627832047612
#
# Approximating hitting prob for (75, 22, 66)
# (75, 22, 66): 0.18415510894762835
# (74, 23, 66): 0.19316684908292117
#
# Approximating hitting prob for (75, 22, 88)
# (75, 22, 88): 0.2629103857785854
# (74, 23, 88): 0.26735101681703516
#
# Approximating hitting prob for (75, 23, 23)
# (75, 23, 23): 0.06791168968340265
# (74, 24, 23): 0.08692288418725502
#
# Approximating hitting prob for (75, 23, 46)
# (75, 23, 46): 0.12333589049201436
# (74, 24, 46): 0.13399230911297597
#
# Approximating hitting prob for (75, 23, 69)
# (75, 23, 69): 0.19091879362834327
# (74, 24, 69): 0.200469053930565
#
# Approximating hitting prob for (75, 23, 92)
# (75, 23, 92): 0.265160516590338
# (74, 24, 92): 0.2716230078671949
#
# Approximating hitting prob for (75, 8, 24)
# (75, 8, 24): 0.05073530639040754
# (74, 9, 24): 0.05665935712775274
#
# Approximating hitting prob for (76, 12, 23)
# (76, 12, 23): 0.05901772668970782
# (75, 13, 23): 0.06359582378620644
#
# Approximating hitting prob for (76, 23, 24)
# (76, 23, 24): 0.08472831032156201
# (75, 24, 24): 0.07031145424576853
#
# Approximating hitting prob for (76, 23, 48)
# (76, 23, 48): 0.13275514698275598
# (75, 24, 48): 0.12539072262928783
#
# Approximating hitting prob for (76, 23, 72)
# (76, 23, 72): 0.20024610805685206
# (75, 24, 72): 0.1963376910296218
#
# Approximating hitting prob for (75, 24, 96)
# (75, 24, 96): 0.26658127720179364
# (74, 25, 96): 0.2866599489783889
#
# Approximating hitting prob for (75, 26, 26)
# (75, 26, 26): 0.0975836369096371
# (74, 27, 26): 0.11562199151466983
#
# Approximating hitting prob for (76, 9, 26)
# (76, 9, 26): 0.06755394368085992
# (75, 10, 26): 0.07083478477779905
#
# Approximating hitting prob for (76, 26, 27)
# (76, 26, 27): 0.11471018113800568
# (75, 27, 27): 0.09862639092077576
#
# Approximating hitting prob for (76, 26, 54)
# (76, 26, 54): 0.18618629347688895
# (75, 27, 54): 0.1789029167297285
#
# Approximating hitting prob for (76, 26, 64)
# (76, 26, 64): 0.20202915561034887
# (75, 27, 64): 0.2018097490386237
#
# Approximating hitting prob for (76, 26, 81)
# (76, 26, 81): 0.27923176078316364
# (75, 27, 81): 0.27393243048481214
# Approximating hitting prob for (75, 28, 28)
# (75, 28, 28): 0.09948668345629628
# (74, 29, 28): 0.11985537883347301
#
# Approximating hitting prob for (75, 28, 42)
# (75, 28, 42): 0.1396607066146994
# (74, 29, 42): 0.14369948906662708
#
# Approximating hitting prob for (75, 28, 56)
# (75, 28, 56): 0.18147849082711542
# (74, 29, 56): 0.19339661695854896
#
# Approximating hitting prob for (75, 28, 65)
# (75, 28, 65): 0.20308789110727746
# (74, 29, 65): 0.20877216463641057
#
# Approximating hitting prob for (75, 28, 84)
# (75, 28, 84): 0.27513304728880666
# (74, 29, 84): 0.28711184373543497
#
# Approximating hitting prob for (75, 29, 29)
# (75, 29, 29): 0.10232517771619243
# (74, 30, 29): 0.12188115488189126
#
# Approximating hitting prob for (75, 29, 58)
# (75, 29, 58): 0.1854946417311176
# (74, 30, 58): 0.19642920510336345
#
# Approximating hitting prob for (75, 29, 87)
# (75, 29, 87): 0.2804812149312566
# (74, 30, 87): 0.28914737319306033
#
# Approximating hitting prob for (75, 10, 30)
# (75, 10, 30): 0.07499333535517545
# (74, 11, 30): 0.08180058815296384
#
# Approximating hitting prob for (75, 30, 30)
# (75, 30, 30): 0.10420134496304477
# (74, 31, 30): 0.12349276887471611
#
# Approximating hitting prob for (75, 30, 60)
# (75, 30, 60): 0.1897209221086149
# (74, 31, 60): 0.2022048339582512
#
# Approximating hitting prob for (75, 30, 67)
# (75, 30, 67): 0.2100898944543925
# (74, 31, 67): 0.21375970579848091
#
# Approximating hitting prob for (75, 30, 90)
# (75, 30, 90): 0.28363636617419685
# (74, 31, 90): 0.2923181784606095
#
# Approximating hitting prob for (75, 31, 31)
# (75, 31, 31): 0.10520822208252854
# (74, 32, 31): 0.12504038032280593
#
# Approximating hitting prob for (75, 31, 62)
# (75, 31, 62): 0.1934740799135478
# (74, 32, 62): 0.20591724177134096
#
# Approximating hitting prob for (75, 31, 68)
# (75, 31, 68): 0.21187350886379708
# (74, 32, 68): 0.21675310471013923
#
# Approximating hitting prob for (75, 31, 93)
# (75, 31, 93): 0.28539789351915523
# (74, 32, 93): 0.2950257667357399
#
# Approximating hitting prob for (75, 8, 32)
# (75, 8, 32): 0.07437959446537251
# (74, 9, 32): 0.07907179083183355
#
# Approximating hitting prob for (76, 16, 31)
# (76, 16, 31): 0.10215951088515697
# (75, 17, 31): 0.10303041702392503
#
# Approximating hitting prob for (76, 31, 32)
# (76, 31, 32): 0.12367032626805485
# (75, 32, 32): 0.10655634968887678
#
# Approximating hitting prob for (76, 31, 64)
# (76, 31, 64): 0.20318746119409317
# (75, 32, 64): 0.19462302322835767
#
# Approximating hitting prob for (76, 31, 78)
# (76, 31, 78): 0.2842506338326898
# (75, 32, 78): 0.28418473135661465
#
# Approximating hitting prob for (76, 31, 96)
# (76, 31, 96): 0.2938587168216652
# (75, 32, 96): 0.28774651065918605
#
# Approximating hitting prob for (76, 11, 32)
# (76, 11, 32): 0.08227888029317991
# (75, 12, 32): 0.08390893778814489
#
# Approximating hitting prob for (76, 32, 33)
# (76, 32, 33): 0.12529013748748322
# (75, 33, 33): 0.10778177870149001
#
# Approximating hitting prob for (75, 33, 66)
# (75, 33, 66): 0.20348678441708287
# (74, 34, 66): 0.21623590095886192
#
# Approximating hitting prob for (75, 33, 99)
# (75, 33, 99): 0.2902262476387004
# (74, 34, 99): 0.2994459630452887
#
# Approximating hitting prob for (76, 17, 33)
# (76, 17, 33): 0.10475931562162498
# (75, 18, 33): 0.10609036713582487
#
# Approximating hitting prob for (76, 33, 34)
# (76, 33, 34): 0.12674706286070764
# (75, 34, 34): 0.1087543145680512
#
# Approximating hitting prob for (75, 34, 68)
# (75, 34, 68): 0.20566483046775855
# (74, 35, 68): 0.21952101393233403
#
# Approximating hitting prob for (75, 34, 81)
# (75, 34, 81): 0.28668969623363605
# (74, 35, 81): 0.2902738859951232
#
# Approximating hitting prob for (75, 35, 35)
# (75, 35, 35): 0.11011662966897982
# (74, 36, 35): 0.13230052887843463
#
# Approximating hitting prob for (75, 35, 70)
# (75, 35, 70): 0.2098986080266461
# (74, 36, 70): 0.2227764956970164
#
# Approximating hitting prob for (76, 12, 35)
# (76, 12, 35): 0.08687658039013334
# (75, 13, 35): 0.0899863363232864
#
# Approximating hitting prob for (75, 36, 36)
# (75, 36, 36): 0.11068336420772164
# (74, 37, 36): 0.14029223366886426
#
# Approximating hitting prob for (75, 36, 54)
# (75, 36, 54): 0.19588435491990627
# (74, 37, 54): 0.21195716171781218
#
# Approximating hitting prob for (75, 36, 72)
# (75, 36, 72): 0.21250285391662493
# (74, 37, 72): 0.2360669025647183
#
# Approximating hitting prob for (75, 36, 73)
# (75, 36, 73): 0.22386092303005534
# (74, 37, 73): 0.23665212433114594
#
# Approximating hitting prob for (75, 36, 84)
# (75, 36, 84): 0.2906320438530627
# (74, 37, 84): 0.3040981407610181
#
# Approximating hitting prob for (75, 37, 37)
# (75, 37, 37): 0.11103925053920359
# (74, 38, 37): 0.19814985198569288
#
# Approximating hitting prob for (75, 37, 74)
# (75, 37, 74): 0.2146048115074155
# (74, 38, 74): 0.29573974616163506
#
# Approximating hitting prob for (75, 37, 86)
# (75, 37, 86): 0.29247468983389013
# (74, 38, 86): 0.3069331630834143
#
# Approximating hitting prob for (76, 19, 37)
# (76, 19, 37): 0.11074906847647546
# (75, 20, 37): 0.1149633459601669
#
# Approximating hitting prob for (76, 13, 38)
# (76, 13, 38): 0.10175487288134671
# (75, 14, 38): 0.10348289912502788
#
# Approximating hitting prob for (76, 38, 39)
# (76, 38, 39): 0.19814515469221097
# (75, 39, 39): 0.1638144455350677
#
# Approximating hitting prob for (76, 38, 78)
# (76, 38, 78): 0.3005065809237501
# (75, 39, 78): 0.2916511471091361
#
# Approximating hitting prob for (76, 8, 39)
# (76, 8, 39): 0.08731298216117846
# (75, 9, 39): 0.08788715044032175
#
# Approximating hitting prob for (75, 40, 40)
# (75, 40, 40): 0.16450143461032898
# (74, 41, 40): 0.2070033782743469
#
# Approximating hitting prob for (75, 40, 77)
# (75, 40, 77): 0.3006376931329789
# (74, 41, 77): 0.30217533078329006
#
# Approximating hitting prob for (75, 40, 80)
# (75, 40, 80): 0.2928625799936198
# (74, 41, 80): 0.3046963252557116
#
# Approximating hitting prob for (75, 40, 91)
# (75, 40, 91): 0.309835089453648
# (74, 41, 91): 0.31073979746062
#
# Approximating hitting prob for (75, 41, 41)
# (75, 41, 41): 0.16534779478581976
# (74, 42, 41): 0.20811922277017916
#
# Approximating hitting prob for (75, 41, 78)
# (75, 41, 78): 0.3016101096055741
# (74, 42, 78): 0.30290054418006185
#
# Approximating hitting prob for (75, 41, 82)
# (75, 41, 82): 0.29392849574844454
# (74, 42, 82): 0.3063775103438624
#
# Approximating hitting prob for (75, 41, 93)
# (75, 41, 93): 0.3107078477157446
# (74, 42, 93): 0.3116192617309402
#
# Approximating hitting prob for (76, 14, 41)
# (76, 14, 41): 0.10671894337558396
# (75, 15, 41): 0.11099796717731351
#
# Approximating hitting prob for (76, 28, 41)
# (76, 28, 41): 0.13989097661157998
# (75, 29, 41): 0.14146992649516674
#
# Approximating hitting prob for (76, 41, 42)
# (76, 41, 42): 0.20693316790835345
# (75, 42, 42): 0.16621133728088905
#
# Approximating hitting prob for (76, 41, 63)
# (76, 41, 63): 0.22582969496635977
# (75, 42, 63): 0.2250254126168281
#
# Approximating hitting prob for (76, 41, 79)
# (76, 41, 79): 0.3031013280421503
# (75, 42, 79): 0.3027626586086113
#
# Approximating hitting prob for (76, 41, 84)
# (76, 41, 84): 0.3046451831798612
# (75, 42, 84): 0.29571723652767984
#
# Approximating hitting prob for (76, 41, 94)
# ...
#
# Approximating hitting prob for (77, 45, 46)
# (77, 45, 46): 0.21076246262616583
# (76, 46, 46): 0.17406537424268256
#
# Approximating hitting prob for (77, 45, 92)
# (77, 45, 92): 0.3092734782758441
# (76, 46, 92): 0.30524094390995987
#
# Approximating hitting prob for (77, 46, 47)
# (77, 46, 47): 0.2140629971720168
# (76, 47, 47): 0.17480650760391625
#
# Approximating hitting prob for (77, 46, 94)
# (77, 46, 94): 0.313912558162675
# (76, 47, 94): 0.3059792875911801
#
# Approximating hitting prob for (77, 24, 47)
# (77, 24, 47): 0.1322544891700922
# (76, 25, 47): 0.1341327275650594
#
# Approximating hitting prob for (77, 47, 48)
# (77, 47, 48): 0.2169066894003406
# (76, 48, 48): 0.17688216482273314
#
# Approximating hitting prob for (77, 47, 72)
# (77, 47, 72): 0.2396294379264049
# (76, 48, 72): 0.23782977450969367
#
# Approximating hitting prob for (77, 47, 73)
# (77, 47, 73): 0.24292805622704425
# (76, 48, 73): 0.24144965565703766
#
# Approximating hitting prob for (77, 47, 96)
# (77, 47, 96): 0.3167547632665949
# (76, 48, 96): 0.30699851563657277
#
# Approximating hitting prob for (77, 48, 49)
# (77, 48, 49): 0.21866628140732633
# (76, 49, 49): 0.1779591781581925
#
# Approximating hitting prob for (77, 48, 74)
# (77, 48, 74): 0.2440229435422988
# (76, 49, 74): 0.24205184956751088
#
# Approximating hitting prob for (77, 48, 98)
# (77, 48, 98): 0.3178291606120846
# (76, 49, 98): 0.30919605030090164
#
# Approximating hitting prob for (76, 50, 50)
# (76, 50, 50): 0.17862928919480303
# (75, 51, 50): 0.22699521999512187
#
# Approximating hitting prob for (76, 50, 75)
# (76, 50, 75): 0.23972840061880965
# (75, 51, 75): 0.31098835835252864
#
# Approximating hitting prob for (76, 50, 100)
# (76, 50, 100): 0.30994977387275313
# (75, 51, 100): 0.3245127566207666
#
# Approximating hitting prob for (77, 17, 50)
# (77, 17, 50): 0.12558080949108646
# (76, 18, 50): 0.12954604027601274
#
# Approximating hitting prob for (77, 50, 51)
# (77, 50, 51): 0.22127208463674072
# (76, 51, 51): 0.18481790947606072
#
# Approximating hitting prob for (77, 51, 52)
# (77, 51, 52): 0.22624248462913768
# (76, 52, 52): 0.18564035397000525
# Approximating hitting prob for (77, 52, 53)
# (77, 52, 53): 0.2279953315344239
# (76, 53, 53): 0.18653929743788591
#
# Approximating hitting prob for (77, 52, 78)
# (77, 52, 78): 0.3245842065686032
# (76, 53, 78): 0.32220256115171875
#
# Approximating hitting prob for (77, 9, 53)
# (77, 9, 53): 0.11276772357055732
# (76, 10, 53): 0.11394633643000444
#
# Approximating hitting prob for (76, 54, 54)
# (76, 54, 54): 0.1887884079422353
# (75, 55, 54): 0.23301139250426964
#
# Approximating hitting prob for (76, 54, 79)
# (76, 54, 79): 0.3227814204249438
# (75, 55, 79): 0.3239659245866114
#
# Approximating hitting prob for (76, 55, 55)
# (76, 55, 55): 0.19033463344172552
# (75, 56, 55): 0.23434060168688184
#
# Approximating hitting prob for (76, 55, 80)
# (76, 55, 80): 0.3236737596586848
# (75, 56, 80): 0.3250196223423582
#
# Approximating hitting prob for (76, 14, 56)
# (76, 14, 56): 0.12674196748225167
# (75, 15, 56): 0.13274184712231632
#
# Approximating hitting prob for (77, 28, 55)
# (77, 28, 55): 0.18770148176348175
# (76, 29, 55): 0.1895781271641884
#
# Approximating hitting prob for (77, 55, 56)
# (77, 55, 56): 0.23270537773418962
# (76, 56, 56): 0.19098456748460502
#
# Approximating hitting prob for (77, 55, 81)
# (77, 55, 81): 0.3259969486296572
# (76, 56, 81): 0.32459996234027316
#
# Approximating hitting prob for (77, 56, 57)
# (77, 56, 57): 0.2334925284880577
# (76, 57, 57): 0.19596772116592112
#
# Approximating hitting prob for (77, 56, 82)
# (77, 56, 82): 0.3265383615682413
# (76, 57, 82): 0.32561955875172505
#
# Approximating hitting prob for (76, 58, 58)
# (76, 58, 58): 0.20098285913598288
# (75, 59, 58): 0.2451574629705502
#
# Approximating hitting prob for (76, 58, 83)
# (76, 58, 83): 0.3263816251510637
# (75, 59, 83): 0.3284883721580484
#
# Approximating hitting prob for (76, 59, 59)
# (76, 59, 59): 0.20184302355528838
# (75, 60, 59): 0.24623287807353653
#
# Approximating hitting prob for (76, 59, 84)
# (76, 59, 84): 0.3272300468204919
# (75, 60, 84): 0.3288275425557689
#
# Approximating hitting prob for (77, 15, 59)
# (77, 15, 59): 0.13189081613402714
# (76, 16, 59): 0.13560777105486496
#
# Approximating hitting prob for (77, 30, 59)
# (77, 30, 59): 0.1938476135981336
# (76, 31, 59): 0.19608875390173783
#
# Approximating hitting prob for (77, 59, 60)
# (77, 59, 60): 0.24462048886561497
# (76, 60, 60): 0.20309718274907462
#
# Approximating hitting prob for (77, 59, 85)
# (77, 59, 85): 0.3292127932711237
# (76, 60, 85): 0.32884597346162586
#
# Approximating hitting prob for (77, 60, 61)
# (77, 60, 61): 0.24578388316004965
# (76, 61, 61): 0.2047465522766344
#
# Approximating hitting prob for (77, 60, 86)
# (77, 60, 86): 0.33097613847837665
# (76, 61, 86): 0.3294356695136234
#
# Approximating hitting prob for (76, 62, 62)
# (76, 62, 62): 0.20551504732486367
# (75, 63, 62): 0.25077577030038084
#
# Approximating hitting prob for (76, 62, 87)
# (76, 62, 87): 0.33067510216955937
# (75, 63, 87): 0.3335976217638447
#
# Approximating hitting prob for (77, 21, 62)
# (77, 21, 62): 0.18158500852999312
# (76, 22, 62): 0.18308541527821073
#
# Approximating hitting prob for (77, 62, 63)
# (77, 62, 63): 0.24815981999413672
# (76, 63, 63): 0.2059143959240279
#
# Approximating hitting prob for (77, 62, 88)
# (77, 62, 88): 0.3324084284954267
# (76, 63, 88): 0.33109153253148654
#
# Approximating hitting prob for (77, 16, 63)
# (77, 16, 63): 0.17243303480785255
# (76, 17, 63): 0.17371611383772279
#
# Approximating hitting prob for (76, 64, 64)
# (76, 64, 64): 0.2095311110085479
# (75, 65, 64): 0.2553494204639501
#
# Approximating hitting prob for (76, 65, 65)
# (76, 65, 65): 0.21018952490163081
# (75, 66, 65): 0.2574013713472539
#
# Approximating hitting prob for (77, 22, 65)
# (77, 22, 65): 0.18512698104703332
# (76, 23, 65): 0.19043792072340746
#
# Approximating hitting prob for (76, 66, 66)
# (76, 66, 66): 0.21201959666151649
# (75, 67, 66): 0.2589335684986739
#
# Approximating hitting prob for (76, 66, 91)
# (76, 66, 91): 0.335817470764145
# (75, 67, 91): 0.3373393043607856
#
# Approximating hitting prob for (76, 67, 67)
# (76, 67, 67): 0.21428764603965947
# (75, 68, 67): 0.2598050178402938
#
# Approximating hitting prob for (76, 67, 92)
# (76, 67, 92): 0.3364017014086358
# (75, 68, 92): 0.3381957941575326
#
# Approximating hitting prob for (77, 34, 67)
# (77, 34, 67): 0.21339655431018154
# (76, 35, 67): 0.2155006032501339
#
# Approximating hitting prob for (77, 67, 68)
# (77, 67, 68): 0.25764642565814927
# (76, 68, 68): 0.21501626810617877
#
# Approximating hitting prob for (77, 67, 93)
# (77, 67, 93): 0.3385533522586102
# (76, 68, 93): 0.33761574023131674
#
# Approximating hitting prob for (76, 69, 69)
# (76, 69, 69): 0.21595017441733455
# (75, 70, 69): 0.26219172207648733
#
# Approximating hitting prob for (76, 69, 94)
# (76, 69, 94): 0.33862573639085686
# (75, 70, 94): 0.340078342116462
#
# Approximating hitting prob for (77, 35, 69)
# (77, 35, 69): 0.21602132010902197
# (76, 36, 69): 0.2190083034203563
#
# Approximating hitting prob for (77, 69, 70)
# (77, 69, 70): 0.259911437415047
# (76, 70, 70): 0.21721840127126582
#
# Approximating hitting prob for (77, 69, 95)
# (77, 69, 95): 0.3405669625258121
# (76, 70, 95): 0.3396350055475506
#
# Approximating hitting prob for (77, 70, 71)
# (77, 70, 71): 0.26110031556268015
# (76, 71, 71): 0.21854741172431894
#
# Approximating hitting prob for (77, 70, 96)
# (77, 70, 96): 0.341425967920615
# (76, 71, 96): 0.3402320983377312
#
# Approximating hitting prob for (77, 36, 71)
# (77, 36, 71): 0.21923587739178962
# (76, 37, 71): 0.22203630988024925
#
# Approximating hitting prob for (76, 72, 72)
# (76, 72, 72): 0.21945386122637278
# (75, 73, 72): 0.2652142439971032
#
# Approximating hitting prob for (76, 72, 97)
# (76, 72, 97): 0.34097860767974897
# (75, 73, 97): 0.3423827926629204
#
# Approximating hitting prob for (76, 73, 73)
# (76, 73, 73): 0.22028951429577023
# (75, 74, 73): 0.2659914937403277
#
# Approximating hitting prob for (76, 73, 98)
# (76, 73, 98): 0.34200667973405646
# (75, 74, 98): 0.34337971988405575
#
# Approximating hitting prob for (77, 37, 73)
# (77, 37, 73): 0.22216849803967828
# (76, 38, 73): 0.23526173463070732
#
# Approximating hitting prob for (77, 73, 74)
# (77, 73, 74): 0.26435090603321315
# (76, 74, 74): 0.2211154924833674
#
# Approximating hitting prob for (77, 73, 99)
# (77, 73, 99): 0.34395126642917423
# (76, 74, 99): 0.3425284326152634
#
# Approximating hitting prob for (77, 50, 74)
# (77, 50, 74): 0.24164444695399392
# (76, 51, 74): 0.24985300278790454
#
# Approximating hitting prob for (77, 74, 75)
# (77, 74, 75): 0.26526165410930896
# (76, 75, 75): 0.2217854255111317
#
# Approximating hitting prob for (77, 74, 90)
# (77, 74, 90): 0.3386632511269601
# (76, 75, 90): 0.3383487375944689
#
# Approximating hitting prob for (77, 74, 100)
# (77, 74, 100): 0.3447431154806804
# (76, 75, 100): 0.3428095466377385
#
# Approximating hitting prob for (77, 26, 77)
# (77, 26, 77): 0.2744813410095706
# (76, 27, 77): 0.2785404025003588
#
# Approximating hitting prob for (77, 39, 77)
# (77, 39, 77): 0.2955369697858246
# (76, 40, 77): 0.30003405145746637
#
# Approximating hitting prob for (77, 77, 78)
# (77, 77, 78): 0.38910294149863395
# (76, 78, 78): 0.35609769715661727
#
# Approximating hitting prob for (77, 78, 79)
# (77, 78, 79): 0.40049835130754924
# (76, 79, 79): 0.35653143674793086
#
# Approximating hitting prob for (77, 78, 94)
# (77, 78, 94): 0.4103508386648205
# (76, 79, 94): 0.41021865873090735
#
# Approximating hitting prob for (77, 16, 79)
# (77, 16, 79): 0.25350321734116443
# (76, 17, 79): 0.25534230937774904
#
# Approximating hitting prob for (77, 20, 79)
# (77, 20, 79): 0.25852024168180515
# (76, 21, 79): 0.2604257944403941
#
# Approximating hitting prob for (76, 80, 80)
# (76, 80, 80): 0.3569686500000437
# (75, 81, 80): 0.40245512237433007
#
# Approximating hitting prob for (77, 27, 80)
# (77, 27, 80): 0.27913963452889856
# (76, 28, 80): 0.28069441886005836
#
# Approximating hitting prob for (77, 80, 81)
# (77, 80, 81): 0.40134751735562
# (76, 81, 81): 0.35743811416485555
#
# Approximating hitting prob for (76, 82, 82)
# (76, 82, 82): 0.3580009801676733
# (75, 83, 82): 0.40375261993034317
#
# Approximating hitting prob for (76, 82, 97)
# (76, 82, 97): 0.41170887635433334
# (75, 83, 97): 0.4131314964561919
#
# Approximating hitting prob for (76, 83, 83)
# (76, 83, 83): 0.35853538098947074
# (75, 84, 83): 0.40447357989731597
#
# Approximating hitting prob for (76, 12, 84)
# (76, 12, 84): 0.24918264976089843
# (75, 13, 84): 0.25333716482480856
#
# Approximating hitting prob for (77, 14, 83)
# (77, 14, 83): 0.25231915556986856
# (76, 15, 83): 0.2535145303678041
#
# Approximating hitting prob for (77, 28, 83)
# (77, 28, 83): 0.28117574525399647
# (76, 29, 83): 0.2841145261130172
#
# Approximating hitting prob for (76, 84, 84)
# (76, 84, 84): 0.3593100232194355
# (75, 85, 84): 0.4054251461046256
#
# Approximating hitting prob for (76, 17, 85)
# (76, 17, 85): 0.25601564219380746
# (75, 18, 85): 0.25986452206378136
#
# Approximating hitting prob for (76, 85, 85)
# (76, 85, 85): 0.35959932490788277
# (75, 86, 85): 0.40620978384032225
#
# Approximating hitting prob for (77, 43, 85)
# (77, 43, 85): 0.3051425479403804
# (76, 44, 85): 0.3071523559237577
#
# Approximating hitting prob for (77, 85, 86)
# (77, 85, 86): 0.4044020852773545
# (76, 86, 86): 0.3607907710696863
#
# Approximating hitting prob for (76, 87, 87)
# (76, 87, 87): 0.36141753978289465
# (75, 88, 87): 0.40768836147582915
#
# Approximating hitting prob for (77, 22, 87)
# (77, 22, 87): 0.2633993189022439
# (76, 23, 87): 0.2654802844991145
#
# Approximating hitting prob for (76, 88, 88)
# (76, 88, 88): 0.3618132089434006
# (75, 89, 88): 0.40869437172645795
#
# Approximating hitting prob for (76, 89, 89)
# (76, 89, 89): 0.36334485150134016
# (75, 90, 89): 0.4094169474694882
#
# Approximating hitting prob for (77, 15, 89)
# (77, 15, 89): 0.25527395283215326
# (76, 16, 89): 0.2591351849492745
#
# Approximating hitting prob for (77, 30, 89)
# (77, 30, 89): 0.2875052141938371
# (76, 31, 89): 0.2890868104152439
#
# Approximating hitting prob for (76, 90, 90)
# (76, 90, 90): 0.36371149580636963
# (75, 91, 90): 0.4103384682770565
#
# Approximating hitting prob for (76, 91, 91)
# (76, 91, 91): 0.3640855580459277
# (75, 92, 91): 0.4107014078603457
#
# Approximating hitting prob for (77, 23, 91)
# (77, 23, 91): 0.26600086683275176
# (76, 24, 91): 0.27009146532862777
#
# Approximating hitting prob for (77, 46, 91)
# (77, 46, 91): 0.3089914756845959
# (76, 47, 91): 0.3154977319507568
#
# Approximating hitting prob for (77, 91, 92)
# (77, 91, 92): 0.4089250174209851
# (76, 92, 92): 0.3652527943003187
#
# Approximating hitting prob for (76, 93, 93)
# (76, 93, 93): 0.3657749647761495
# (75, 94, 93): 0.41251899263901554
#
# Approximating hitting prob for (77, 47, 93)
# (77, 47, 93): 0.31566270126626467
# (76, 48, 93): 0.31714279011442076
#
# Approximating hitting prob for (77, 93, 94)
# (77, 93, 94): 0.4105637214245814
# (76, 94, 94): 0.36612058072544773
#
# Approximating hitting prob for (77, 94, 95)
# (77, 94, 95): 0.41101897870292925
# (76, 95, 95): 0.3679559744936582
#
# Approximating hitting prob for (77, 16, 95)
# (77, 16, 95): 0.2728167728196771
# (76, 17, 95): 0.2736533505074594
#
# Approximating hitting prob for (77, 32, 95)
# (77, 32, 95): 0.29260830798553844
# (76, 33, 95): 0.2950194819173591
#
# Approximating hitting prob for (76, 96, 96)
# (76, 96, 96): 0.369789647046354
# (75, 97, 96): 0.41593712256875054
#
# Approximating hitting prob for (76, 97, 97)
# (76, 97, 97): 0.370012834384787
# (75, 98, 97): 0.4165553731108114
#
# Approximating hitting prob for (76, 14, 98)
# (76, 14, 98): 0.2691073142764016
# (75, 15, 98): 0.2741161768684726
#
# Approximating hitting prob for (77, 49, 97)
# (77, 49, 97): 0.3178406488985341
# (76, 50, 97): 0.32048886702801166
#
# Approximating hitting prob for (77, 97, 98)
# (77, 97, 98): 0.4149953534162656
# (76, 98, 98): 0.371006048877259
#
# Approximating hitting prob for (76, 99, 99)
# (76, 99, 99): 0.37136275891324394
# (75, 100, 99): 0.4174327140551433
#
# Approximating hitting prob for (76, 20, 100)
# (76, 20, 100): 0.27927947241458245
# (75, 21, 100): 0.2821710814519944
#
# Approximating hitting prob for (77, 25, 99)
# (77, 25, 99): 0.2697683828437227
# (76, 26, 99): 0.28993451313634494
#
# Approximating hitting prob for (76, 60, 100)
# (76, 60, 100): 0.33639023786424654
# (75, 61, 100): 0.33975453356401913
#
# Approximating hitting prob for (76, 100, 100)
# (76, 100, 100): 0.37165309500538884
# (75, 101, 100): 0.4193881426076022
#
# Approximating hitting prob for (77, 2, 27)
# (77, 2, 27): 0.05967746612150962
# (76, 3, 27): 0.060771525217233585
#
# Approximating hitting prob for (77, 2, 81)
# (77, 2, 81): 0.24788961398095669
# (76, 3, 81): 0.24888526428919147
#
# Approximating hitting prob for (77, 2, 82)
# (77, 2, 82): 0.24809809896937848
# (76, 3, 82): 0.2490542885536997
#
# Approximating hitting prob for (77, 3, 28)
# (77, 3, 28): 0.06141667508679043
# (76, 4, 28): 0.0629221536716148
#
# Approximating hitting prob for (77, 3, 84)
# (77, 3, 84): 0.24921571686152563
# (76, 4, 84): 0.2501028822469736
#
# Approximating hitting prob for (77, 3, 85)
# (77, 3, 85): 0.24943127967592696
# (76, 4, 85): 0.25041664850314943
#
# Approximating hitting prob for (77, 4, 4)
# (77, 4, 4): 0.002662919949279219
# (76, 5, 4): 0.005153925295643636
#
# Approximating hitting prob for (77, 4, 87)
# (77, 4, 87): 0.2505893872277879
# (76, 5, 87): 0.251689388509204
#
# Approximating hitting prob for (77, 4, 88)
# (77, 4, 88): 0.2507783661473258
# (76, 5, 88): 0.2518867778468954
#
# Approximating hitting prob for (77, 5, 30)
# (77, 5, 30): 0.06535428229917058
# (76, 6, 30): 0.06759910967606016
#
# Approximating hitting prob for (77, 5, 90)
# (77, 5, 90): 0.25191889357337
# (76, 6, 90): 0.2542023807028582
#
# Approximating hitting prob for (77, 5, 91)
# (77, 5, 91): 0.2521443475317568
# (76, 6, 91): 0.2545705166122963
#
# Approximating hitting prob for (77, 6, 6)
# (77, 6, 6): 0.0069922800592287235
# (76, 7, 6): 0.011244413055411516
#
# Approximating hitting prob for (77, 7, 7)
# (77, 7, 7): 0.008311748388415632
# (76, 8, 7): 0.013732014212382697
#
# Approximating hitting prob for (77, 7, 14)
# (77, 7, 14): 0.022818341016959277
# (76, 8, 14): 0.026776925474800265
#
# Approximating hitting prob for (77, 7, 97)
# (77, 7, 97): 0.25701173295250374
# (76, 8, 97): 0.25868973388503297
#
# Approximating hitting prob for (77, 8, 8)
# (77, 8, 8): 0.011216724271978654
# (76, 9, 8): 0.016241887783341458
#
# Approximating hitting prob for (77, 8, 16)
# (77, 8, 16): 0.02581505827129092
# (76, 9, 16): 0.03168992389902193
#
# Approximating hitting prob for (77, 9, 9)
# (77, 9, 9): 0.012865212620309936
# (76, 10, 9): 0.020412940037065706
