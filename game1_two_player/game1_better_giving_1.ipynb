# %%
# %run 'game1_global.ipynb'
# %run 'game1_loser_analysis.ipynb'

# %% [markdown]
# # When is player 1 better off giving away $1?

# %%
betterGiving1 = findBetterGiving1(1,1000)
betterGiving1

# %%
exportStateProbs(DATA_DIR + 'game1_better_giving_1_memo_1-1000.csv', betterGiving1)

# %%
# retrieve probabilities from file
betterGiving1, given1 = readApproxBetterGiving1Probs(DATA_DIR + 'game1_better_giving_1_memo_1-100.csv')

# %%
betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
                                       filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv')
# Out:
# Approximating hitting prob for (11, 19, 48)
# (11, 19, 48): 0.5334260883826906
# (10, 19, 48): 0.5333426632228018
#
# Approximating hitting prob for (12, 21, 53)
# (12, 21, 53): 0.5340626283748265
# (11, 21, 53): 0.5334548685835285
#
# Approximating hitting prob for (12, 32, 42)
# (12, 32, 42): 0.5301153617677242
# (11, 32, 42): 0.5299467192997049
#
# Approximating hitting prob for (13, 22, 56)
# (13, 22, 56): 0.5328628830327213
# (12, 22, 56): 0.532734806781722
#
# Approximating hitting prob for (13, 23, 58)
# (13, 23, 58): 0.5343093271797525
# (12, 23, 58): 0.5335330764863161
#
# Approximating hitting prob for (13, 35, 46)
# (13, 35, 46): 0.5303291922468697
# (12, 35, 46): 0.5299937351500015
#
# Approximating hitting prob for (14, 24, 61)
# (14, 24, 61): 0.5334281050874531
# (13, 24, 61): 0.532844623278078
#
# Approximating hitting prob for (14, 25, 63)
# (14, 25, 63): 0.534598505539718
# (13, 25, 63): 0.5335740856592848
#
# Approximating hitting prob for (14, 38, 50)
# (14, 38, 50): 0.5306453312687435
# (13, 38, 50): 0.5300535494230575
#
# Approximating hitting prob for (15, 26, 66)
# (15, 26, 66): 0.5335384252806683
# (14, 26, 66): 0.532976559038264
#
# Approximating hitting prob for (15, 27, 68)
# (15, 27, 68): 0.5347937376379311
# (14, 27, 68): 0.5336038259570041
#
# Approximating hitting prob for (15, 40, 52)
# (15, 40, 52): 0.5298390830172897
# (14, 40, 52): 0.5294060634902246
#
# Approximating hitting prob for (15, 41, 54)
# (15, 41, 54): 0.530814252978444
# (14, 41, 54): 0.5300859465232839
#
# Approximating hitting prob for (16, 27, 69)
# (16, 27, 69): 0.5327214805171471
# (15, 27, 69): 0.5323471322790065
#
# Approximating hitting prob for (16, 28, 71)
# (16, 28, 71): 0.533984832978568
# (15, 28, 71): 0.5330636314503749
#
# Approximating hitting prob for (16, 29, 73)
# (16, 29, 73): 0.5349109988994238
# (15, 29, 73): 0.5336260136575318
#
# Approximating hitting prob for (16, 42, 54)
# (16, 42, 54): 0.528455476635441
# (15, 42, 54): 0.5285157285081951
#
# Approximating hitting prob for (16, 43, 56)
# (16, 43, 56): 0.5300165256608894
# (15, 43, 56): 0.5295344851774494
#
# Approximating hitting prob for (16, 44, 58)
# (16, 44, 58): 0.5309755142180325
# (15, 44, 58): 0.5301059314171186
#
# Approximating hitting prob for (17, 29, 74)
# (17, 29, 74): 0.5332717628242919
# (16, 29, 74): 0.5324865172144486
#
# Approximating hitting prob for (17, 30, 76)
# (17, 30, 76): 0.5341834675713876
# (16, 30, 76): 0.5331293350131605
#
# Approximating hitting prob for (17, 31, 78)
# (17, 31, 78): 0.535032026741298
# (16, 31, 78): 0.5336384909534596
#
# Approximating hitting prob for (17, 44, 56)
# (17, 44, 56): 0.5279972266134371
# (16, 44, 56): 0.5279422800090446
#
# Approximating hitting prob for (17, 45, 58)
# (17, 45, 58): 0.529004914693246
# (16, 45, 58): 0.528895160602941
#
# Approximating hitting prob for (17, 46, 60)
# (17, 46, 60): 0.5301804342251579
# (16, 46, 60): 0.5296194711867167
#
# Approximating hitting prob for (17, 47, 62)
# (17, 47, 62): 0.5311378673662993
# (16, 47, 62): 0.5301263625686753
#
# Approximating hitting prob for (18, 27, 71)
# (18, 27, 71): 0.525620501017532
# (17, 27, 71): 0.5254981980685945
#
# Approximating hitting prob for (18, 28, 73)
# (18, 28, 73): 0.5271004988262395
# (17, 28, 73): 0.5270411065910542
#
# Approximating hitting prob for (18, 31, 79)
# (18, 31, 79): 0.5335270635741508
# (17, 31, 79): 0.5326072076759126
#
# Approximating hitting prob for (18, 32, 81)
# (18, 32, 81): 0.5344121912790228
# (17, 32, 81): 0.5332080138741222
#
# Approximating hitting prob for (18, 33, 83)
# (18, 33, 83): 0.5351589143653502
# (17, 33, 83): 0.5336649245359243
#
# Approximating hitting prob for (18, 45, 56)
# (18, 45, 56): 0.5255722330999105
# (17, 45, 56): 0.5254786841463105
#
# Approximating hitting prob for (18, 47, 60)
# (18, 47, 60): 0.5284828625145415
# (17, 47, 60): 0.5281888889502253
#
# Approximating hitting prob for (18, 48, 62)
# (18, 48, 62): 0.5294526933438758
# (17, 48, 62): 0.5290045013080626
#
# Approximating hitting prob for (18, 49, 64)
# (18, 49, 64): 0.5304295920255223
# (17, 49, 64): 0.5297020995866109
#
# Approximating hitting prob for (18, 50, 66)
# (18, 50, 66): 0.5312826982045813
# (17, 50, 66): 0.5301457096165415
#
# Approximating hitting prob for (19, 20, 58)
# (19, 20, 58): 0.5076781471384154
# (18, 20, 58): 0.507459734940809
#
# Approximating hitting prob for (19, 32, 82)
# (19, 32, 82): 0.5327246501234508
# (18, 32, 82): 0.5320769507714677
#
# Approximating hitting prob for (19, 33, 84)
# (19, 33, 84): 0.5335489429772609
# (18, 33, 84): 0.532734806781722
#
# Approximating hitting prob for (19, 34, 86)
# (19, 34, 86): 0.5345634156030413
# (18, 34, 86): 0.5332648124986303
#
# Approximating hitting prob for (19, 35, 88)
# (19, 35, 88): 0.5345634156030413
# (18, 35, 88): 0.5332648124986303
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/659592125.py:18, in stricterFilter(candidates, timeLim, t, printOnGo, filename, continueFrom)
#      17 try:
# ---> 18     pLarge = LoserAnalysis(sLarge).getHittingProb()  # exact probs
#      19     pSmall = LoserAnalysis(sSmall).getHittingProb()
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:68, in LoserAnalysis.getHittingProb(self, asFloat, approx, t)
#      66     return Q(x, y, z, t)
# ---> 68 sol = self.solveEqns()
#      69 if sol:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:46, in LoserAnalysis.solveEqns(self, asFloat)
#      45 self.getEquations()
# ---> 46 sol = solve(self.equations, self.symbols)
#      47 return {s:float(p) for s, p in sol.items() if sol} if asFloat else sol
#
# File /usr/local/lib/python3.9/site-packages/sympy/solvers/solvers.py:1147, in solve(f, *symbols, **flags)
#    1146 else:
# -> 1147     linear, solution = _solve_system(f, symbols, **flags)
#    1148 assert type(solution) is list
#
# File /usr/local/lib/python3.9/site-packages/sympy/solvers/solvers.py:1799, in _solve_system(exprs, symbols, **flags)
#    1797     continue
# -> 1799 poly = g.as_poly(*symbols, extension=True)
#    1801 if poly is not None:
#
# File /usr/local/lib/python3.9/site-packages/sympy/core/expr.py:1102, in Expr.as_poly(self, *gens, **args)
#    1101 try:
# -> 1102     poly = Poly(self, *gens, **args)
#    1104     if not poly.is_Poly:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:182, in Poly.__new__(cls, rep, *gens, **args)
#     181 else:
# --> 182     return cls._from_expr(rep, opt)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:312, in Poly._from_expr(cls, rep, opt)
#     311 rep, opt = _dict_from_expr(rep, opt)
# --> 312 return cls._from_dict(rep, opt)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:261, in Poly._from_dict(cls, rep, opt)
#     259         rep[monom] = domain.convert(coeff)
# --> 261 return cls.new(DMP.from_dict(rep, level, domain), *gens)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polyclasses.py:279, in DMP.from_dict(cls, rep, lev, dom)
#     278 """Construct and instance of ``cls`` from a ``dict`` representation. """
# --> 279 return cls(dmp_from_dict(rep, lev, dom), dom, lev)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
#     [... skipping similar frames: dmp_from_dict at line 1012 (2958 times)]
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:998, in dmp_from_dict(f, u, K)
#     996 coeffs = {}
# --> 998 for monom, coeff in f.items():
#     999     head, tail = monom[0], monom[1:]
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# TimeoutException                          Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
#       2                                        filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv')
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/659592125.py:23, in stricterFilter(candidates, timeLim, t, printOnGo, filename, continueFrom)
#      21 except (TimeoutException, RecursionError):
#      22     print(f'Approximating hitting prob for {sLarge}')
# ---> 23     pLarge = LoserAnalysis(sLarge).getHittingProb(approx=True, t=t)
#      24     pSmall = LoserAnalysis(sSmall).getHittingProb(approx=True, t=t)
#      26 finally:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:66, in LoserAnalysis.getHittingProb(self, asFloat, approx, t)
#      64 if approx:
#      65     x, y, z = self.initState
# ---> 66     return Q(x, y, z, t)
#      68 sol = self.solveEqns()
#      69 if sol:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:31, in Q(x, y, z, t)
#      29 if x==0: return 1
#      30 if z*y==0: return 0
# ---> 31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
#      33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:31, in Q(x, y, z, t)
#      29 if x==0: return 1
#      30 if z*y==0: return 0
# ---> 31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
#      33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
#     [... skipping similar frames: memoize.<locals>.memodict.__call__ at line 8 (11 times), <genexpr> at line 33 (10 times), Q at line 33 (10 times), memoize.<locals>.memodict.__missing__ at line 11 (10 times)]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2027475117.py:12, in sigalarmHandler(signum, frame)
#       8 """
#       9 Handler function to be called when SIGALRM is received.
#      10 """
#      11 # We get signal!
# ---> 12 raise TimeoutException()
#
# TimeoutException:

# %%
betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
                                       filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv',
                                       continueFrom=(69,64,100))
# Out:
# Approximating hitting prob for (70, 12, 93)
# (70, 12, 93): 0.27064890356707977
# (69, 12, 93): 0.2704508979612977
#
# Approximating hitting prob for (70, 13, 95)
# (70, 13, 95): 0.273002814385276
# (69, 13, 95): 0.2728333555110289
#
# Approximating hitting prob for (70, 15, 99)
# (70, 15, 99): 0.2777183843625525
# (69, 15, 99): 0.27732957441332723
#
# Approximating hitting prob for (70, 30, 84)
# (70, 30, 84): 0.2928672871530125
# (69, 30, 84): 0.29290071879804375
#
# Approximating hitting prob for (70, 50, 94)
# (70, 50, 94): 0.32695735265836573
# (69, 50, 94): 0.3267132634013896
#
# Approximating hitting prob for (70, 58, 98)
# (70, 58, 98): 0.3430616778838396
# (69, 58, 98): 0.3428394039934912
#
# Approximating hitting prob for (70, 60, 99)
# (70, 60, 99): 0.34560612414415176
# (69, 60, 99): 0.34492499438010804
#
# Approximating hitting prob for (70, 84, 90)
# (70, 84, 90): 0.4148018936715927
# (69, 84, 90): 0.41468720846314083
#
# Approximating hitting prob for (71, 12, 94)
# (71, 12, 94): 0.27043453644878807
# (70, 12, 94): 0.2702550831661171
#
# Approximating hitting prob for (71, 15, 100)
# (71, 15, 100): 0.2774240055525448
# (70, 15, 100): 0.27714908068396565
#
# Approximating hitting prob for (71, 36, 88)
# (71, 36, 88): 0.3107284046458855
# (70, 36, 88): 0.3107029569244443
#
# Approximating hitting prob for (71, 44, 92)
# (71, 44, 92): 0.31946810865446534
# (70, 44, 92): 0.31933447137280896
#
# Approximating hitting prob for (71, 52, 96)
# (71, 52, 96): 0.3287350571698488
# (70, 52, 96): 0.32848900976647166
#
# Approximating hitting prob for (71, 60, 100)
# (71, 60, 100): 0.3432269284144038
# (70, 60, 100): 0.3428263666917539
#
# Approximating hitting prob for (72, 14, 99)
# (72, 14, 99): 0.27369224353294386
# (71, 14, 99): 0.27347335165357634
#
# Approximating hitting prob for (72, 40, 91)
# (72, 40, 91): 0.3129742549703007
# (71, 40, 91): 0.31282979281170153
#
# Approximating hitting prob for (72, 46, 94)
# (72, 46, 94): 0.32065055730266634
# (71, 46, 94): 0.32060860453920875
#
# Approximating hitting prob for (72, 50, 96)
# (72, 50, 96): 0.32548552599084296
# (71, 50, 96): 0.32522123422559995
#
# Approximating hitting prob for (72, 54, 98)
# (72, 54, 98): 0.33015250293768666
# (71, 54, 98): 0.3299310590778092
#
# Approximating hitting prob for (73, 11, 94)
# (73, 11, 94): 0.26568088778907833
# (72, 11, 94): 0.26555372470314254
#
# Approximating hitting prob for (73, 13, 98)
# (73, 13, 98): 0.2712824779940791
# (72, 13, 98): 0.27092732614422377
#
# Approximating hitting prob for (73, 14, 100)
# (73, 14, 100): 0.2735392177539206
# (72, 14, 100): 0.2733296833190661
#
# Approximating hitting prob for (73, 26, 85)
# (73, 26, 85): 0.2838182327188731
# (72, 26, 85): 0.2838382526274032
#
# Approximating hitting prob for (73, 40, 92)
# (73, 40, 92): 0.31265646156970867
# (72, 40, 92): 0.31256600858492634
#
# Approximating hitting prob for (73, 44, 94)
# (73, 44, 94): 0.31905281367702304
# (72, 44, 94): 0.31898130581150774
#
# Approximating hitting prob for (74, 12, 97)
# (74, 12, 97): 0.26803823241416097
# (73, 12, 97): 0.2678146488650772
#
# Approximating hitting prob for (74, 13, 99)
# (74, 13, 99): 0.27106341315623816
# (73, 13, 99): 0.2708043750088058
#
# Approximating hitting prob for (74, 30, 88)
# (74, 30, 88): 0.29121346643802504
# (73, 30, 88): 0.2911904861374854
#
# Approximating hitting prob for (74, 40, 93)
# (74, 40, 93): 0.3124715276947375
# (73, 40, 93): 0.3123265733297223
#
# Approximating hitting prob for (74, 46, 96)
# (74, 46, 96): 0.3194592906289733
# (73, 46, 96): 0.31936096416339166
#
# Approximating hitting prob for (74, 52, 99)
# (74, 52, 99): 0.32609715069378836
# (73, 52, 99): 0.32593271890358366
#
# Approximating hitting prob for (74, 54, 100)
# (74, 54, 100): 0.3285392810102394
# (73, 54, 100): 0.32834877261967127
#
# Approximating hitting prob for (75, 13, 100)
# (75, 13, 100): 0.2708561821230972
# (74, 13, 100): 0.27060467983388525
#
# Approximating hitting prob for (75, 38, 93)
# (75, 38, 93): 0.3107255922584125
# (74, 38, 93): 0.3106856959891582
#
# Approximating hitting prob for (75, 40, 94)
# (75, 40, 94): 0.31219750777533284
# (74, 40, 94): 0.31212211416489793
#
# Approximating hitting prob for (75, 48, 98)
# (75, 48, 98): 0.3206660566987458
# (74, 48, 98): 0.3206193374288369
#
# Approximating hitting prob for (75, 52, 100)
# (75, 52, 100): 0.32543894655115896
# (74, 52, 100): 0.3251891291627604
#
# Approximating hitting prob for (76, 42, 96)
# (76, 42, 96): 0.31283229353690856
# (75, 42, 96): 0.31269685409230785
#
# Approximating hitting prob for (77, 42, 97)
# (77, 42, 97): 0.31263411481005815
# (76, 42, 97): 0.3124896740010894
#
# Approximating hitting prob for (78, 42, 98)
# (78, 42, 98): 0.312441399741017
# (77, 42, 98): 0.3119828040723916
#
# Approximating hitting prob for (79, 32, 94)
# (79, 32, 94): 0.2912337154122105
# (78, 32, 94): 0.2911642829888588
#
# Approximating hitting prob for (79, 40, 98)
# (79, 40, 98): 0.31073467566545016
# (78, 40, 98): 0.31068391480047436
#
# Approximating hitting prob for (79, 42, 99)
# (79, 42, 99): 0.3121670959474713
# (78, 42, 99): 0.3120607193357822
#
# Approximating hitting prob for (79, 44, 100)
# (79, 44, 100): 0.3130463381703828
# (78, 44, 100): 0.3128490513416133
#
# Approximating hitting prob for (82, 34, 98)
# (82, 34, 98): 0.2917812876569657
# (81, 34, 98): 0.29172992113254753
#
# Approximating hitting prob for (84, 30, 98)
# (84, 30, 98): 0.2839368557613289
# (83, 30, 98): 0.2838357734914572
#
# Approximating hitting prob for (84, 34, 100)
# (84, 34, 100): 0.29123192191006453
# (83, 34, 100): 0.2911447291167216
#
# Approximating hitting prob for (93, 47, 62)
# (93, 47, 62): 0.2078449082948937
# (92, 47, 62): 0.20783817692579917
#
# Approximating hitting prob for (93, 47, 98)
# (93, 47, 98): 0.3020413154785515
# (92, 47, 98): 0.3020379983481061
#
# Approximating hitting prob for (95, 48, 100)
# (95, 48, 100): 0.30201302025080573
# (94, 48, 100): 0.30196433138324996
#
# Approximating hitting prob for (99, 50, 66)
# (99, 50, 66): 0.2078419114332157
# (98, 50, 66): 0.2078180397808808
#
# Approximating hitting prob for (100, 51, 67)
# (100, 51, 67): 0.2080190772886974
# (99, 51, 67): 0.20801576587712575

# %%
class TimeoutException(Exception):
    """
    Custom exception for timeout.
    """
    pass

def sigalarmHandler(signum, frame):
    """
    Handler function to be called when SIGALRM is received.
    """
    # We get signal!
    raise TimeoutException()

# %% [markdown]
# ## When is player 1 better off giving away $1 to another player?

# %%
betterGiving1ToAnother = findBetterGiving1(1,100, t=10, giveToAnother=True)
betterGiving1ToAnother
# Out:
# {(1, 5, 5): 0.5004434876119833,
#  (2, 4, 5): 0.5015168645690443,
#  (1, 6, 6): 0.506093654740131,
#  (2, 5, 6): 0.5184847144955884,
#  (1, 7, 7): 0.5131205254322682,
#  (2, 6, 7): 0.5396071019936831,
#  (1, 8, 8): 0.5177187986883774,
#  (2, 7, 8): 0.553386673567715,
#  (1, 9, 9): 0.5198030383135193,
#  (2, 8, 9): 0.5596511014686955,
#  (1, 10, 10): 0.521353326527545,
#  (2, 9, 10): 0.5643071756348541,
#  (1, 11, 11): 0.5225738105217701,
#  (2, 10, 11): 0.5679767313216567,
#  (1, 12, 12): 0.5237380978085997,
#  (2, 11, 12): 0.5714793837797846,
#  (1, 12, 36): 0.6316713165390184,
#  (2, 11, 36): 0.6317622599451304,
#  (1, 13, 13): 0.5248276325593998,
#  (2, 12, 13): 0.5747622273980084,
#  (1, 13, 39): 0.6325682808186844,
#  (2, 12, 39): 0.6347403712118326,
#  (1, 14, 14): 0.5256858644409728,
#  (2, 13, 14): 0.57733900685236,
#  (1, 14, 42): 0.6333982655030145,
#  (2, 13, 42): 0.6366529115385103,
#  (1, 15, 15): 0.5268432387720368,
#  (2, 14, 15): 0.5808387485922709,
#  (1, 15, 45): 0.63421194355006,
#  (2, 14, 45): 0.6395029512036614,
#  (1, 16, 16): 0.5279858610539553,
#  (2, 15, 16): 0.5842379051719758,
#  (1, 16, 48): 0.635051999980948,
#  (2, 15, 48): 0.6419747628823096,
#  (1, 17, 17): 0.5283821156475977,
#  (2, 16, 17): 0.5854285708426477,
#  (1, 17, 51): 0.6353974162348219,
#  (2, 16, 51): 0.6431331129655032,
#  (1, 18, 18): 0.5286972339709394,
#  (2, 17, 18): 0.586367542078401,
#  (1, 18, 54): 0.635696343688081,
#  (2, 17, 54): 0.6438519942124338,
#  (1, 19, 19): 0.5290239620908059,
#  (2, 18, 19): 0.5873462049262054,
#  (1, 19, 57): 0.6359734242165406,
#  (2, 18, 57): 0.644798126476528,
#  (1, 20, 20): 0.5292680655049197,
#  (2, 19, 20): 0.5880847500592729,
#  (1, 20, 60): 0.6362249863460855,
#  (2, 19, 60): 0.6453717860378668,
#  (1, 21, 21): 0.5295149142555335,
#  (2, 20, 21): 0.588833317324383,
#  (1, 21, 63): 0.6364634998581686,
#  (2, 20, 63): 0.6461849514015902,
#  (1, 21, 64): 0.646956969794154,
#  (2, 20, 64): 0.6472510681012803,
#  (1, 22, 22): 0.5297588522879303,
#  (2, 21, 22): 0.5895697621096462,
#  (1, 22, 66): 0.6366529446148538,
#  (2, 21, 66): 0.6466174245912294,
#  (1, 22, 67): 0.6471532117394029,
#  (2, 21, 67): 0.647774501235203,
#  (1, 23, 23): 0.5299781484445122,
#  (2, 22, 23): 0.5902254013880421,
#  (1, 23, 69): 0.6368433485854967,
#  (2, 22, 69): 0.6472793649130383,
#  (1, 23, 70): 0.647343764553591,
#  (2, 22, 70): 0.6483569921802232,
#  (1, 24, 24): 0.5301334749530051,
#  (2, 23, 24): 0.5907054714357991,
#  (1, 24, 72): 0.6370145682769819,
#  (2, 23, 72): 0.6476786129157565,
#  (1, 24, 73): 0.6475028948415723,
#  (2, 23, 73): 0.6487869019532507,
#  (1, 25, 25): 0.5303300145853443,
#  (2, 24, 25): 0.5913062701368778,
#  (1, 25, 75): 0.6371719124424207,
#  (2, 24, 75): 0.6482151442816559,
#  (1, 25, 76): 0.6476655808364664,
#  (2, 24, 76): 0.6492909523499552,
#  (1, 26, 26): 0.5305056830450136,
#  (2, 25, 26): 0.5918398411700453,
#  (1, 26, 78): 0.6373261970460974,
#  (2, 25, 78): 0.6485752629701603,
#  (1, 26, 79): 0.6478181289321158,
#  (2, 25, 79): 0.6496998090304239,
#  (1, 27, 27): 0.5306651440964284,
#  (2, 26, 27): 0.5923164712780911,
#  (1, 27, 81): 0.6374779182331624,
#  (2, 26, 81): 0.6491023179636827,
#  (1, 27, 82): 0.6479675843896594,
#  (2, 26, 82): 0.6501630597575742,
#  (1, 28, 28): 0.5308433925108808,
#  (2, 27, 28): 0.5928632397722654,
#  (1, 28, 84): 0.6376227926171485,
#  (2, 27, 84): 0.6494288807018324,
#  (1, 28, 85): 0.6481137818273807,
#  (2, 27, 85): 0.6505545513577707,
#  (1, 29, 29): 0.531019424810327,
#  (2, 28, 29): 0.593397753481219,
#  (1, 29, 87): 0.6377697342725956,
#  (2, 28, 87): 0.6499273246583346,
#  (1, 29, 88): 0.6482600123414454,
#  (2, 28, 88): 0.651006837277092,
#  (1, 30, 30): 0.5311653907136445,
#  (2, 29, 30): 0.5938409764824553,
#  (1, 30, 90): 0.6379076957008163,
#  (2, 29, 90): 0.650248810177776,
#  (1, 30, 91): 0.6483932438525631,
#  (2, 29, 91): 0.6513514100842097,
#  (1, 31, 31): 0.5313585565589595,
#  (2, 30, 31): 0.5944358379798981,
#  (1, 31, 93): 0.6380471455644888,
#  (2, 30, 93): 0.6507426069080341,
#  (1, 31, 94): 0.6485374236333384,
#  (2, 30, 94): 0.6518048371373775,
#  (1, 32, 32): 0.5316609404901015,
#  (2, 31, 32): 0.5953108064912191,
#  (1, 32, 96): 0.6382585695513472,
#  (2, 31, 96): 0.651341801406459,
#  (1, 32, 97): 0.6487406281488678,
#  (2, 31, 97): 0.6524211817198429,
#  (1, 33, 33): 0.5317385375916611,
#  (2, 32, 33): 0.5955452681512389,
#  (1, 33, 99): 0.6383231014972734,
#  (2, 32, 99): 0.6515462628230367,
#  (1, 33, 100): 0.6488068966028214,
#  (2, 32, 100): 0.6526188624860286,
#  (1, 34, 34): 0.5318062779428949,
#  (2, 33, 34): 0.5957485718957984,
#  (1, 35, 35): 0.5318679983996342,
#  (2, 34, 35): 0.5959310706203745,
#  (1, 36, 36): 0.5319251873973311,
#  (2, 35, 36): 0.5961088063515048,
#  (1, 37, 37): 0.5319769849510576,
#  (2, 36, 37): 0.5962632397987264,
#  (1, 38, 38): 0.5320250779543261,
#  (2, 37, 38): 0.5964045750139714,
#  (1, 39, 39): 0.5320778016456672,
#  (2, 38, 39): 0.5965617868740368,
#  (1, 40, 40): 0.5321167325018205,
#  (2, 39, 40): 0.5966842851117292,
#  (1, 41, 41): 0.5321571517934258,
#  (2, 40, 41): 0.5968058406736355,
#  (2, 14, 41): 0.6338000769223442,
#  (1, 42, 42): 0.5322013748645192,
#  (2, 41, 42): 0.5969399487078528,
#  (1, 43, 43): 0.5322408018658233,
#  (2, 42, 43): 0.5970633565449881,
#  (1, 44, 44): 0.5322755651027112,
#  (2, 43, 44): 0.5971704908211825,
#  (2, 15, 44): 0.6355654440591713,
#  (1, 45, 45): 0.5323146613405815,
#  (2, 44, 45): 0.5972896979627089,
#  (1, 46, 46): 0.5323509791656083,
#  (2, 45, 46): 0.5973977583765179,
#  (1, 47, 47): 0.532385014722942,
#  (2, 46, 47): 0.597498806605531,
#  (2, 16, 47): 0.6375855486545072,
#  (1, 48, 48): 0.5324148826610103,
#  (2, 47, 48): 0.5975902130804501,
#  (1, 49, 49): 0.5324444859883317,
#  (2, 48, 49): 0.5976821983913784,
#  (1, 50, 50): 0.5324711785974361,
#  (2, 49, 50): 0.5977623423713782,
#  (2, 17, 50): 0.6383571866691223,
#  (1, 51, 51): 0.5325028988107334,
#  (2, 50, 51): 0.5978603145004572,
#  (1, 52, 52): 0.5325307160155125,
#  (2, 51, 52): 0.597951109063024,
#  (1, 53, 53): 0.5325579709224543,
#  (2, 52, 53): 0.5980328572456773,
#  (2, 18, 53): 0.6393221393725973,
#  (1, 54, 54): 0.5325877396314925,
#  (2, 53, 54): 0.5981236683464157,
#  (1, 55, 55): 0.5326169460426934,
#  (2, 54, 55): 0.5982126271719249,
#  (1, 56, 56): 0.5326397687196227,
#  (2, 55, 56): 0.5982834436230927,
#  (2, 19, 56): 0.639912667869058,
#  (1, 57, 57): 0.5326706620243357,
#  (2, 56, 57): 0.5983790342554488,
#  (1, 58, 58): 0.5326991076796389,
#  (2, 57, 58): 0.5984666865653948,
#  (1, 59, 59): 0.5327241464715744,
#  (2, 58, 59): 0.5985425140825841,
#  (2, 20, 59): 0.6407575699842504,
#  (1, 60, 60): 0.5327515998365764,
#  (2, 59, 60): 0.5986312082973463,
#  (1, 60, 100): 0.6594202186690291,
#  (2, 59, 100): 0.6594714208485749,
#  (1, 61, 61): 0.5327806408660604,
#  (2, 60, 61): 0.5987212090276719,
#  (1, 62, 62): 0.5328041250698572,
#  (2, 61, 62): 0.5987947377389965,
#  (2, 21, 62): 0.6412867749400921,
#  (1, 63, 63): 0.5328350514509137,
#  (2, 62, 63): 0.5988899810697471,
#  (1, 64, 64): 0.5329295505639383,
#  (2, 63, 64): 0.5991591232757963,
#  (1, 65, 65): 0.5329439718496504,
#  (2, 64, 65): 0.5992017586824079,
#  (2, 22, 65): 0.6419519898198954,
#  (1, 66, 66): 0.5329563424020729,
#  (2, 65, 66): 0.5992384734235551,
#  (1, 67, 67): 0.5329692090996461,
#  (2, 66, 67): 0.5992765939092958,
#  (1, 68, 68): 0.5329786027811648,
#  (2, 67, 68): 0.5993086945005419,
#  (2, 23, 68): 0.6423572742552796,
#  (1, 69, 69): 0.5329891210583583,
#  (2, 68, 69): 0.5993394885762248,
#  (1, 70, 70): 0.5330002016333891,
#  (2, 69, 70): 0.5993723499233687,
#  (1, 71, 71): 0.5330110506740166,
#  (2, 70, 71): 0.5994039212931209,
#  (2, 24, 71): 0.6429282380946333,
#  (1, 72, 72): 0.5330189889964267,
#  (2, 71, 72): 0.5994280670237854,
#  (1, 73, 73): 0.5330284819069756,
#  (2, 72, 73): 0.5994564796027452,
#  (1, 74, 74): 0.5330374786723738,
#  (2, 73, 74): 0.599483089520991,
#  (2, 25, 74): 0.6432813280601704,
#  (1, 75, 75): 0.5330459131399347,
#  (2, 74, 75): 0.5995072187134837,
#  (1, 76, 76): 0.5330541822257785,
#  (2, 75, 76): 0.5995340767043049,
#  (1, 77, 77): 0.5330628151513997,
#  (2, 76, 77): 0.5995594131833307,
#  (2, 26, 77): 0.6438085649735813,
#  (1, 78, 78): 0.5330708527028399,
#  (2, 77, 78): 0.5995827154672391,
#  (1, 79, 79): 0.5330799817736117,
#  (2, 78, 79): 0.5996089284693644,
#  (1, 80, 80): 0.5330863985842266,
#  (2, 79, 80): 0.5996283608210977,
#  (2, 27, 80): 0.6441455136835509,
#  (1, 81, 81): 0.5330929477002151,
#  (2, 80, 81): 0.5996482893179816,
#  (1, 82, 82): 0.5331003237247879,
#  (2, 81, 82): 0.5996707812314773,
#  (1, 83, 83): 0.5331074682149571,
#  (2, 82, 83): 0.599691569713289,
#  (2, 28, 83): 0.6446484064082373,
#  (1, 84, 84): 0.5331135542621382,
#  (2, 83, 84): 0.5997103736144981,
#  (1, 85, 85): 0.5331207318286508,
#  (2, 84, 85): 0.5997354950972921,
#  (1, 86, 86): 0.5331267847994886,
#  (2, 85, 86): 0.5997556055140646,
#  (2, 29, 86): 0.6449977587469728,
#  (1, 87, 87): 0.5331327716176396,
#  (2, 86, 87): 0.5997733675104574,
#  (1, 88, 88): 0.5331386592067605,
#  (2, 87, 88): 0.599791989491778,
#  (1, 89, 89): 0.5331450098646887,
#  (2, 88, 89): 0.5998109256983607,
#  (2, 30, 89): 0.6454688981820182,
#  (1, 90, 90): 0.5331506328430625,
#  (2, 89, 90): 0.5998279269388559,
#  (1, 91, 91): 0.5331572150353944,
#  (2, 90, 91): 0.5998475412104778,
#  (1, 92, 92): 0.5331628049374249,
#  (2, 91, 92): 0.5998653528213856,
#  (2, 31, 92): 0.6457769216297059,
#  (1, 93, 93): 0.5331686925265458,
#  (2, 92, 93): 0.5998821225274772,
#  (1, 94, 94): 0.5331750431844738,
#  (2, 93, 94): 0.5999014225738369,
#  (1, 95, 95): 0.5331811953843418,
#  (2, 94, 95): 0.5999193995664617,
#  (2, 32, 95): 0.646300487069002,
#  (1, 96, 96): 0.5331852306982338,
#  (2, 95, 96): 0.599931571660824,
#  (1, 97, 97): 0.5331905890658605,
#  (2, 96, 97): 0.599948109832512,
#  (1, 98, 98): 0.5331949220668428,
#  (2, 97, 98): 0.5999628122671425,
#  (2, 33, 98): 0.6464613042504953,
#  (1, 99, 99): 0.5331994535258853,
#  (2, 98, 99): 0.59997640664427,
#  (2, 60, 99): 0.6594345241875391,
#  (1, 100, 100): 0.533204183442988,
#  (2, 99, 100): 0.5999915225331928,
#  (2, 6, 6): 0.4693452418753916,
#  (3, 5, 6): 0.4740014979614388,
#  (2, 7, 7): 0.48208386784704227,
#  (3, 6, 7): 0.4955659177124083,
#  (2, 8, 8): 0.49122878218725124,
#  (3, 7, 8): 0.5014666050652847,
#  (2, 9, 9): 0.494262775936087,
#  (3, 8, 9): 0.5178661041836018,
#  (2, 10, 10): 0.5004434876119833,
#  (3, 9, 10): 0.5342839937488357,
#  (2, 11, 11): 0.5025522368075666,
#  (3, 10, 11): 0.5431842258389219,
#  (2, 12, 12): 0.506093654740131,
#  (3, 11, 12): 0.5502830045015581,
#  (2, 13, 13): 0.5085600915129808,
#  (3, 12, 13): 0.5546173616138715,
#  (2, 14, 14): 0.5131205254322682,
#  (3, 13, 14): 0.5568134654323105,
#  (2, 15, 15): 0.5156899950147334,
#  (3, 14, 15): 0.5601744353735879,
#  (2, 16, 16): 0.5177187986883774,
#  (3, 15, 16): 0.5635269543091331,
#  (2, 17, 17): 0.5183972606437027,
#  (3, 16, 17): 0.5645428776577504,
#  (2, 18, 18): 0.5198030383135193,
#  (3, 17, 18): 0.5672856342031618,
#  (2, 19, 19): 0.5202042212823249,
#  (3, 18, 19): 0.5700392728655439,
#  (2, 20, 20): 0.521353326527545,
#  (3, 19, 20): 0.5708707459853257,
#  (2, 20, 60): 0.6295677107148301,
#  (3, 19, 60): 0.6304392723627834,
#  (2, 21, 21): 0.5216864383816829,
#  (3, 20, 21): 0.5735340366157767,
#  (2, 21, 63): 0.6301227813711917,
#  (3, 20, 63): 0.6311136824660452,
#  (2, 22, 22): 0.5225738105217701,
#  (3, 21, 22): 0.5764060555111009,
#  (2, 22, 66): 0.630719892059984,
#  (3, 21, 66): 0.6335248486691138,
#  (2, 23, 23): 0.5230437922847974,
#  (3, 22, 23): 0.5785014418639604,
#  (2, 23, 69): 0.6311993336572169,
#  (3, 22, 69): 0.6351912844629037,
#  (2, 23, 71): 0.641735372847127,
#  (3, 22, 71): 0.6419442003410304,
#  (2, 24, 24): 0.5237380978085997,
#  (3, 23, 24): 0.5800568899875528,
#  (2, 24, 72): 0.6316713165390184,
#  (3, 23, 72): 0.6362437075564361,
#  (2, 24, 74): 0.642247130031838,
#  (3, 23, 74): 0.6426527783069992,
#  (2, 25, 25): 0.524088839353757,
#  (3, 24, 25): 0.5809113180896375,
#  (2, 25, 75): 0.6320944621998256,
#  (3, 24, 75): 0.637120230655896,
#  (2, 25, 77): 0.6426200988797439,
#  (3, 24, 77): 0.6434655302164304,
#  (2, 26, 26): 0.5248276325593998,
#  (3, 25, 26): 0.5813076057596235,
#  (2, 26, 78): 0.6325682808186844,
#  (3, 25, 78): 0.6376919552511473,
#  (2, 26, 80): 0.6431372309702534,
#  (3, 25, 80): 0.6440306064666632,
#  (2, 27, 27): 0.5251138752349743,
#  (3, 26, 27): 0.582175396704432,
#  (2, 27, 81): 0.6329491879890007,
#  (3, 26, 81): 0.6380589868954174,
#  (2, 27, 83): 0.6434930993486342,
#  (3, 26, 83): 0.6444297387021796,
#  (2, 28, 28): 0.5256858644409728,
#  (3, 27, 28): 0.5828712072018578,
#  (2, 28, 84): 0.6333982655030145,
#  (3, 27, 84): 0.6388404320458433,
#  (2, 28, 86): 0.6439339408531474,
#  (3, 27, 86): 0.6451290222156598,
#  (2, 29, 29): 0.5261190653101662,
#  (3, 28, 29): 0.5831610717370319,
#  (2, 29, 87): 0.6337884340494758,
#  (3, 28, 87): 0.6392850773298446,
#  (2, 29, 88): 0.6449055088252976,
#  (3, 28, 88): 0.644998916418991,
#  (2, 29, 89): 0.6443102007972193,
#  (3, 28, 89): 0.6455973005470034,
#  (2, 30, 30): 0.5268432387720368,
#  (3, 29, 30): 0.5837543951845078,
#  (2, 30, 90): 0.63421194355006,
#  (3, 29, 90): 0.6395496715386797,
#  (2, 30, 92): 0.6447714007910802,
#  (3, 29, 92): 0.645899006413106,
#  (2, 31, 31): 0.5275615907974732,
#  (3, 30, 31): 0.5843650506359125,
#  (2, 31, 93): 0.6345886665629393,
#  (3, 30, 93): 0.640241909791021,
#  (2, 31, 94): 0.6457147711805027,
#  (3, 30, 94): 0.645921002181451,
#  (2, 31, 95): 0.6453186488922336,
#  (3, 30, 95): 0.6465264150324307,
#  (2, 32, 32): 0.5279858610539553,
#  (3, 31, 32): 0.5845853886973108,
#  (2, 32, 96): 0.635051999980948,
#  (3, 31, 96): 0.6406006558112753,
#  (2, 32, 97): 0.6461740362082762,
#  (3, 31, 97): 0.646306424272638,
#  (2, 32, 98): 0.645574742480821,
#  (3, 31, 98): 0.6468801499866637,
#  (2, 33, 33): 0.5281335800034718,
#  (3, 32, 33): 0.5851356798220545,
#  (2, 33, 99): 0.6352244269589663,
#  (3, 32, 99): 0.6407475974667225,
#  (2, 33, 100): 0.6463518546302647,
#  (3, 32, 100): 0.6464238949061373,
#  (2, 34, 34): 0.5283821156475977,
#  (3, 33, 34): 0.5857237441309336,
#  (2, 35, 35): 0.5284957328870937,
#  (3, 34, 35): 0.5859061105501363,
#  (2, 36, 36): 0.5286972339709394,
#  (3, 35, 36): 0.5863498462346949,
#  (2, 37, 37): 0.5288185579984419,
#  (3, 36, 37): 0.5868146350118123,
#  (2, 38, 38): 0.5290239620908059,
#  (3, 37, 38): 0.5870175583784231,
#  (2, 39, 39): 0.5291136651340412,
#  (3, 38, 39): 0.5874601198527918,
#  (2, 40, 40): 0.5292680655049197,
#  (3, 39, 40): 0.5879006636702145,
#  (2, 41, 41): 0.5293537993869498,
#  (3, 40, 41): 0.5880250307213077,
#  (2, 42, 42): 0.5295149142555335,
#  (3, 41, 42): 0.5884515170927959,
#  (2, 43, 43): 0.5296025334891361,
#  (3, 42, 43): 0.5889065483486172,
#  (2, 44, 44): 0.5297588522879303,
#  (3, 43, 44): 0.58904100368444,
#  (2, 45, 45): 0.5298143874684583,
#  (3, 44, 45): 0.5894975068375417,
#  (2, 46, 46): 0.5299781484445122,
#  (3, 45, 46): 0.5899698039446054,
#  (3, 45, 47): 0.5976479643759843,
#  (2, 47, 47): 0.5300331874798896,
#  (3, 46, 47): 0.5905717768558739,
#  (3, 46, 48): 0.5985042612914698,
#  (2, 48, 48): 0.5301334749530051,
#  (3, 47, 48): 0.5909074355884519,
#  (3, 47, 49): 0.5986030107146184,
#  (2, 49, 49): 0.5302022075945402,
#  (3, 48, 49): 0.5910961361274111,
#  (3, 48, 50): 0.5987849967558723,
#  (2, 50, 50): 0.5303300145853443,
#  (3, 49, 50): 0.5911701775220579,
#  (3, 49, 51): 0.5989254058335026,
#  (2, 51, 51): 0.530385152849752,
#  (3, 50, 51): 0.5913320862228827,
#  (3, 50, 52): 0.5990053844317854,
#  (2, 52, 52): 0.5305056830450136,
#  (3, 51, 52): 0.5914818062911734,
#  (3, 51, 53): 0.5991632908950618,
#  (2, 53, 53): 0.5305588367288184,
#  (3, 52, 53): 0.5915376556969635,
#  (3, 52, 54): 0.5992909986568359,
#  (2, 18, 54): 0.6281354554321411,
#  (3, 18, 53): 0.6282727553334942,
#  (2, 54, 54): 0.5306651440964284,
#  (3, 53, 54): 0.5916624692786923,
#  (3, 53, 55): 0.5993634193106573,
#  (2, 55, 55): 0.5307288160574269,
#  (3, 54, 55): 0.5918032587342715,
#  (3, 54, 56): 0.599478690367322,
#  (2, 56, 56): 0.5308433925108808,
#  (3, 55, 56): 0.5918555193568054,
#  (3, 55, 57): 0.5995967232986587,
#  (2, 19, 57): 0.6287977430555555,
#  (3, 19, 56): 0.6300712318900404,
#  (2, 57, 57): 0.5308984976989449,
#  (3, 56, 57): 0.5919839713363054,
#  (3, 56, 58): 0.5996486531577588,
#  (2, 58, 58): 0.531019424810327,
#  (3, 57, 58): 0.5921011938972294,
#  (3, 57, 59): 0.5997754843964335,
#  (2, 59, 59): 0.5310688408673304,
#  (3, 58, 59): 0.5921501799617691,
#  (3, 58, 60): 0.5998798898742993,
#  (3, 20, 59): 0.6308086193510897,
#  (2, 60, 60): 0.5311653907136445,
#  (3, 59, 60): 0.5922371045921607,
#  (3, 59, 61): 0.5999254359991278,
#  (2, 61, 61): 0.5312331972175651,
#  (3, 60, 61): 0.5923383678174059,
#  (3, 60, 62): 0.6000335791037951,
#  (2, 62, 62): 0.5313585565589595,
#  (3, 61, 62): 0.5923812182202493,
#  (3, 61, 63): 0.6001316835382479,
#  (3, 21, 62): 0.6330898947537215,
#  (2, 63, 63): 0.5315653498577452,
#  (3, 62, 63): 0.5925049402826467,
#  (3, 62, 64): 0.6001830180231672,
#  (2, 64, 64): 0.5316609404901015,
#  (3, 63, 64): 0.5925977525021593,
#  (3, 63, 65): 0.6002796836366832,
#  (2, 65, 65): 0.531690378435706,
#  (3, 64, 65): 0.592631788059493,
#  (3, 64, 66): 0.6003744142841115,
#  (3, 22, 65): 0.6346719031810446,
#  (2, 66, 66): 0.5317385375916611,
#  (3, 65, 66): 0.5927241372101983,
#  (3, 65, 67): 0.6004132789875781,
#  (2, 67, 67): 0.5317613271922471,
#  (3, 66, 67): 0.5928214643505817,
#  (3, 66, 68): 0.6005093823032567,
#  (2, 68, 68): 0.5318062779428949,
#  (3, 67, 68): 0.5928686808307507,
#  (3, 67, 69): 0.600597067689546,
#  (3, 23, 68): 0.6353617433984912,
#  (2, 69, 69): 0.5318268845048181,
#  (3, 68, 69): 0.5929494532612746,
#  (3, 68, 70): 0.6006299621130332,
#  (2, 70, 70): 0.5318679983996342,
#  (3, 69, 70): 0.5930456061914681,
#  (3, 69, 71): 0.6007228404852326,
#  (2, 71, 71): 0.5318853634799066,
#  (3, 70, 71): 0.5930765987252112,
#  (3, 70, 72): 0.6007995941400363,
#  (3, 24, 71): 0.6368715792445682,
#  (2, 72, 72): 0.5319251873973311,
#  (3, 71, 72): 0.5931494493714966,
#  (3, 71, 73): 0.600835432358084,
#  (2, 73, 73): 0.5319396086830429,
#  (3, 72, 73): 0.5932231434645379,
#  (3, 72, 74): 0.6009037846216702,
#  (2, 74, 74): 0.5319769849510576,
#  (3, 73, 74): 0.5932469749699402,
#  (3, 73, 75): 0.6009758414357144,
#  (3, 25, 74): 0.637481490478247,
#  (2, 75, 75): 0.5319899508776609,
#  (3, 74, 75): 0.5933288389197955,
#  (3, 74, 76): 0.600999127181451,
#  (2, 76, 76): 0.5320250779543261,
#  (3, 75, 76): 0.5934025495510085,
#  (3, 75, 77): 0.6010797838447729,
#  (2, 77, 77): 0.5320406899883995,
#  (3, 76, 77): 0.5934319544202696,
#  (3, 76, 78): 0.6011526014147149,
#  (3, 26, 77): 0.6378954574537672,
#  (2, 78, 78): 0.5320778016456672,
#  (3, 77, 78): 0.5934982559505665,
#  (3, 77, 79): 0.6011803855431506,
#  (2, 79, 79): 0.5320866991820353,
#  (3, 78, 79): 0.5935844198250606,
#  (3, 78, 80): 0.601249680482523,
#  (2, 80, 80): 0.5321167325018205,
#  (3, 79, 80): 0.5935997672483869,
#  (3, 79, 81): 0.6013253922325102,
#  (3, 27, 80): 0.6386029439004047,
#  (2, 81, 81): 0.5321278792295382,
#  (3, 80, 81): 0.5936775793461786,
#  (3, 80, 82): 0.6013561366936782,
#  (2, 82, 82): 0.5321571517934258,
#  (3, 81, 82): 0.5937518688134007,
#  (3, 81, 83): 0.601426787763129,
#  (2, 83, 83): 0.5321697869565954,
#  (3, 82, 83): 0.5937740134252909,
#  (3, 82, 84): 0.6014979184395587,
#  (3, 28, 83): 0.6390618120120578,
#  (2, 84, 84): 0.5322013748645192,
#  (3, 83, 84): 0.5938440691205609,
#  (3, 83, 85): 0.6015204268912259,
#  (2, 85, 85): 0.5322126208212671,
#  (3, 84, 85): 0.5939187058893884,
#  (3, 84, 86): 0.6015962874847584,
#  (2, 86, 86): 0.5322408018658233,
#  (3, 85, 86): 0.5939462915597639,
#  (3, 85, 87): 0.6016669550923809,
#  (3, 29, 86): 0.6394178126958119,
#  (2, 87, 87): 0.532251948593541,
#  (3, 86, 87): 0.5940234421306881,
#  (3, 86, 88): 0.601684650936087,
#  (2, 88, 88): 0.5322755651027112,
#  (3, 87, 88): 0.5940922243867381,
#  (3, 87, 89): 0.6017641830037341,
#  (2, 89, 89): 0.5322872410519229,
#  (3, 88, 89): 0.5941109952116039,
#  (3, 88, 90): 0.6018371328790496,
#  (3, 30, 89): 0.6400308661821116,
#  (2, 90, 90): 0.5323146613405815,
#  (3, 89, 90): 0.5941841270068079,
#  (3, 89, 91): 0.6018690019358922,
#  (2, 91, 91): 0.5323265357478535,
#  (3, 90, 91): 0.5942605664363495,
#  (3, 90, 92): 0.6019353200043608,
#  (2, 92, 92): 0.5323509791656083,
#  (3, 91, 92): 0.5942813383799895,
#  (3, 91, 93): 0.6020062026082151,
#  (3, 31, 92): 0.6404354725524564,
#  (2, 93, 93): 0.5323607366869041,
#  (3, 92, 93): 0.5943591835541245,
#  (3, 92, 94): 0.6020233692304272,
#  (2, 94, 94): 0.532385014722942,
#  (3, 93, 94): 0.5944335226358617,
#  (3, 93, 95): 0.6021049851077072,
#  (2, 95, 95): 0.5323954668474488,
#  (3, 94, 95): 0.5946310545585023,
#  (3, 94, 96): 0.6023667182128402,
#  (3, 32, 95): 0.6407084350761655,
#  (2, 96, 96): 0.5324148826610103,
#  (3, 95, 96): 0.5947102558627156,
#  (3, 95, 97): 0.6023858198011397,
#  (2, 97, 97): 0.5324242763425291,
#  (3, 96, 97): 0.5947447048743416,
#  (3, 96, 98): 0.6024215422519856,
#  (2, 98, 98): 0.5324444859883317,
#  (3, 97, 98): 0.5947557192966858,
#  (3, 97, 99): 0.6024459691315688,
#  (3, 33, 98): 0.6412241118075667,
#  (2, 99, 99): 0.532454276585971,
#  (3, 98, 99): 0.5947932940227607,
#  (3, 98, 100): 0.6024601919592203,
#  (2, 100, 100): 0.5324711785974361,
#  (3, 99, 100): 0.594818828959847,
#  (3, 7, 7): 0.44019443200773933,
#  (4, 6, 7): 0.45015962312549745,
#  (3, 8, 8): 0.4467808250351403,
#  (4, 7, 8): 0.4742427237336788,
#  (3, 9, 9): 0.4693452418753916,
#  (4, 8, 9): 0.49163882961608163,
#  (3, 10, 10): 0.47808047262654746,
#  (4, 9, 10): 0.4967868813136124,
#  (3, 11, 11): 0.48470119889837254,
#  (4, 10, 11): 0.502631388497265,
#  (3, 12, 12): 0.49122878218725124,
#  (4, 11, 12): 0.5167916853217244,
#  (3, 13, 13): 0.4935336740990533,
#  (4, 12, 13): 0.5312539030085183,
#  (3, 14, 14): 0.4956136137995563,
#  (4, 13, 14): 0.5362733208066606,
#  (3, 15, 15): 0.5004434876119833,
#  (4, 14, 15): 0.5434280646422885,
#  (3, 16, 16): 0.5020230153135531,
#  (4, 15, 16): 0.5478861768933428,
#  (3, 17, 17): 0.5030273123274739,
#  (4, 16, 17): 0.5516700278846806,
#  (3, 17, 51): 0.615492767394452,
#  (4, 16, 51): 0.6161914720719234,
#  (3, 18, 18): 0.506093654740131,
#  (4, 17, 18): 0.5534884163999391,
#  (3, 18, 54): 0.6177887948462294,
#  (4, 17, 54): 0.6190445216843214,
#  (3, 19, 19): 0.5081359535618724,
#  (4, 18, 19): 0.5547300196394097,
#  (3, 19, 57): 0.6196168251155819,
#  (4, 18, 57): 0.6206401410269438,
#  (3, 20, 20): 0.5092737466976579,
#  (4, 19, 20): 0.5579425760279598,
#  (3, 20, 60): 0.6203943672574895,
#  (4, 19, 60): 0.6215706116424494,
#  (3, 21, 21): 0.5131205254322682,
#  (4, 20, 21): 0.560842097902801,
#  (3, 21, 63): 0.6225665568796677,
#  (4, 20, 63): 0.6242344480325662,
#  (3, 22, 22): 0.5144697094785687,
#  (4, 21, 22): 0.5619077515336839,
#  (3, 22, 66): 0.624324547991922,
#  (4, 21, 66): 0.6264198516539231,
#  (3, 23, 23): 0.5164820742095548,
#  (4, 22, 23): 0.5623249765290268,
#  (3, 23, 69): 0.6249592168686177,
#  (4, 22, 69): 0.6269802310633965,
#  (3, 24, 24): 0.5177187986883774,
#  (4, 23, 24): 0.5647878741331352,
#  (3, 24, 72): 0.6264351494627344,
#  (4, 23, 72): 0.6274335588875342,
#  (3, 25, 25): 0.518164866255144,
#  (4, 24, 25): 0.5672480925534301,
#  (3, 25, 75): 0.6270372712175482,
#  (4, 24, 75): 0.6295931629610577,
#  (3, 26, 26): 0.5187485975630408,
#  (4, 25, 26): 0.5679596473903029,
#  (3, 26, 78): 0.6274313096961844,
#  (4, 25, 78): 0.6313052441087063,
#  (3, 27, 27): 0.5198030383135193,
#  (4, 26, 27): 0.5688839492677692,
#  (3, 27, 81): 0.6281354554321411,
#  (4, 26, 81): 0.6318541625652001,
#  (3, 28, 28): 0.5200221029356974,
#  (4, 27, 28): 0.571275650042761,
#  (3, 28, 84): 0.6286252830011939,
#  (4, 27, 84): 0.6323139071999525,
#  (3, 29, 29): 0.5204572222328067,
#  (4, 28, 29): 0.5737307747061763,
#  (3, 29, 87): 0.6289591721494013,
#  (4, 28, 87): 0.6344316035464191,
#  (3, 30, 30): 0.521353326527545,
#  (4, 29, 30): 0.5746018071326356,
#  (3, 30, 90): 0.6295677107148301,
#  (4, 29, 90): 0.636175140296618,
#  (4, 29, 93): 0.6410474510575962,
#  (3, 31, 31): 0.5216136373499127,
#  (4, 30, 31): 0.5765721483693628,
#  (3, 31, 93): 0.6299875487412996,
#  (4, 30, 93): 0.6364735716047266,
#  (4, 30, 96): 0.6419747628823096,
#  (3, 32, 32): 0.5218702105454792,
#  (4, 31, 32): 0.57749606986888,
#  (3, 32, 96): 0.6301997334840557,
#  (4, 31, 96): 0.6374555090105252,
#  (3, 32, 98): 0.6418308477122813,
#  (4, 31, 98): 0.64189207202387,
#  (4, 31, 99): 0.6423986858371861,
#  (3, 33, 33): 0.5225738105217701,
#  (4, 32, 33): 0.5782692459334621,
#  (3, 33, 99): 0.630719892059984,
#  (4, 32, 99): 0.6381510714353757,
#  (3, 34, 34): 0.5229414210020491,
#  (4, 33, 34): 0.5785625834846907,
#  (3, 35, 35): 0.5230813339345289,
#  (4, 34, 35): 0.5789247529064845,
#  (4, 34, 36): 0.586367542078401,
#  (3, 36, 36): 0.5237380978085997,
#  (4, 35, 36): 0.5796576089084913,
#  (3, 37, 37): 0.5239908341483345,
#  (4, 36, 37): 0.5802491462334248,
#  (4, 36, 38): 0.5873462049262054,
#  (3, 38, 38): 0.5241945844235296,
#  (4, 37, 38): 0.5804661601223137,
#  (4, 37, 39): 0.58762088741977,
#  (3, 39, 39): 0.5248276325593998,
#  (4, 38, 39): 0.5806532895349625,
#  (4, 38, 40): 0.5880847500592729,
#  (3, 40, 40): 0.5250622099866212,
#  (4, 39, 40): 0.5812160504411591,
#  (4, 39, 41): 0.5883475912219089,
#  (3, 41, 41): 0.5251781094938103,
#  (4, 40, 41): 0.581744395412073,
#  (4, 40, 42): 0.588833317324383,
#  (3, 42, 42): 0.5256858644409728,
#  (4, 41, 42): 0.5820000755463682,
#  (4, 41, 43): 0.5890965057886247,
#  (3, 43, 43): 0.5260332321991058,
#  (4, 42, 43): 0.5820988084313451,
#  (4, 42, 44): 0.5895697621096462,
#  (3, 44, 44): 0.5262173020499924,
#  (4, 43, 44): 0.5826556321339057,
#  (4, 43, 45): 0.5897379057011973,
#  (3, 45, 45): 0.5268432387720368,
#  (4, 44, 45): 0.5831276480920508,
#  (4, 44, 46): 0.5902254013880421,
#  (3, 46, 46): 0.5271012011740249,
#  (4, 45, 46): 0.583270240208344,
#  (3, 47, 47): 0.5277467521676913,
#  (4, 46, 47): 0.5834219779335806,
#  (3, 48, 48): 0.5279858610539553,
#  (4, 47, 48): 0.583798849790005,
#  (3, 49, 49): 0.5280672950113465,
#  (4, 48, 49): 0.58421129525373,
#  (4, 48, 50): 0.5913062701368778,
#  (3, 50, 50): 0.5281774061584447,
#  (4, 49, 50): 0.5844009880829905,
#  (4, 49, 51): 0.5914750587171248,
#  (4, 17, 50): 0.6165013477948399,
#  (3, 51, 51): 0.5283821156475977,
#  (4, 50, 51): 0.5845099911725855,
#  (4, 50, 52): 0.5918398411700453,
#  (3, 52, 52): 0.5284536267019764,
#  (4, 51, 52): 0.5848932467632814,
#  (4, 51, 53): 0.5920035690697556,
#  (3, 53, 53): 0.5285409151721452,
#  (4, 52, 53): 0.5853034761120002,
#  (4, 52, 54): 0.5923164712780911,
#  (4, 18, 53): 0.6181123476371319,
#  (3, 54, 54): 0.5286972339709394,
#  (4, 53, 54): 0.5854581080172822,
#  (4, 53, 55): 0.5925202546296297,
#  (3, 55, 55): 0.5287723172704025,
#  (4, 54, 55): 0.5854904070665887,
#  (4, 54, 56): 0.5928632397722654,
#  (3, 56, 56): 0.528849186692408,
#  (4, 55, 56): 0.585891077352072,
#  (4, 55, 57): 0.5930314164401599,
#  (3, 57, 57): 0.5290239620908059,
#  (4, 56, 57): 0.5862959648713356,
#  (4, 56, 58): 0.593397753481219,
#  (3, 58, 58): 0.529078174217599,
#  (4, 57, 58): 0.5864241191637455,
#  (4, 57, 59): 0.5935495408209707,
#  (3, 59, 59): 0.5291300048476689,
#  (4, 58, 59): 0.5865677035703398,
#  (4, 58, 60): 0.5938409764824553,
#  (4, 20, 59): 0.6220633830060628,
#  (3, 60, 60): 0.5292680655049197,
#  (4, 59, 60): 0.5869693992224677,
#  (4, 59, 61): 0.5940510939537503,
#  (3, 61, 61): 0.5293283636788938,
#  (4, 60, 61): 0.5873862934543769,
#  (4, 60, 62): 0.5944358379798981,
#  (3, 62, 62): 0.5293856188292774,
#  (4, 61, 62): 0.5875231799014378,
#  (4, 61, 63): 0.5950046353187607,
#  (4, 21, 62): 0.6242603302712578,
#  (3, 63, 63): 0.5295149142555335,
#  (4, 62, 63): 0.5881961511837626,
#  (4, 62, 64): 0.5953108064912191,
#  (3, 64, 64): 0.5295760062617487,
#  (4, 63, 64): 0.5883510807761351,
#  (4, 63, 65): 0.5954003937672526,
#  (3, 65, 65): 0.5296215523865772,
#  (4, 64, 65): 0.5884918206171993,
#  (4, 64, 66): 0.5955452681512389,
#  (4, 22, 65): 0.6248344032868888,
#  (3, 66, 66): 0.5297588522879303,
#  (4, 65, 66): 0.5885713692230182,
#  (4, 65, 67): 0.5956124131282917,
#  (3, 67, 67): 0.5298012561601383,
#  (4, 66, 67): 0.5886375219097698,
#  (4, 66, 68): 0.5957485718957984,
#  (3, 68, 68): 0.529846471521533,
#  (4, 67, 68): 0.5887764094756051,
#  (4, 67, 69): 0.5958102427380226,
#  (4, 23, 68): 0.6256472213490067,
#  (3, 69, 69): 0.5299781484445122,
#  (4, 68, 69): 0.5889008426793849,
#  (4, 68, 70): 0.5959310706203745,
#  (3, 70, 70): 0.5300216107597081,
#  (4, 69, 70): 0.5889561794018526,
#  (4, 69, 71): 0.5959897480535233,
#  (3, 71, 71): 0.5300431103829023,
#  (4, 70, 71): 0.5889931587537468,
#  (4, 70, 72): 0.5961088063515048,
#  (4, 24, 71): 0.6278304253935291,
#  (3, 72, 72): 0.5301334749530051,
#  (4, 71, 72): 0.5891061971572339,
#  (4, 71, 73): 0.596151656754348,
#  (3, 73, 73): 0.5301830563917255,
#  (4, 72, 73): 0.5892122399140968,
#  (4, 72, 74): 0.5962632397987264,
#  (3, 74, 74): 0.5302213918736981,
#  (4, 73, 74): 0.5892634255554708,
#  (4, 73, 75): 0.5963052632929854,
#  (4, 25, 74): 0.6295195515588748,
#  (3, 75, 75): 0.5303300145853443,
#  (4, 74, 75): 0.5893170257699115,
#  (4, 74, 76): 0.5964045750139714,
#  (3, 76, 76): 0.5303685816017206,
#  (4, 75, 76): 0.5894298161008231,
#  (4, 75, 77): 0.5964538256892581,
#  (3, 77, 77): 0.530398449539789,
#  (4, 76, 77): 0.5895255886530678,
#  (4, 76, 78): 0.5965617868740368,
#  (4, 26, 77): 0.6298821178967892,
#  (3, 78, 78): 0.5305056830450136,
#  (4, 77, 78): 0.5895662560172484,
#  (4, 77, 79): 0.5965969635652171,
#  (3, 79, 79): 0.5305416701066065,
#  (4, 78, 79): 0.5895925020957171,
#  (4, 78, 80): 0.5966842851117292,
#  (3, 80, 80): 0.5305744818392352,
#  (4, 79, 80): 0.5896747464235211,
#  (4, 79, 81): 0.5967190152722739,
#  (4, 27, 80): 0.6305618532913343,
#  (3, 81, 81): 0.5306651440964284,
#  (4, 80, 81): 0.5897592564808464,
#  (4, 80, 82): 0.5968058406736355,
#  (3, 82, 82): 0.5307149570695524,
#  (4, 81, 82): 0.5898063737319853,
#  (4, 81, 83): 0.5968468057249064,
#  (3, 83, 83): 0.5307373497540179,
#  (4, 82, 83): 0.5898409219726414,
#  (4, 82, 84): 0.5969399487078528,
#  (4, 28, 83): 0.632644984858973,
#  (3, 84, 84): 0.5308433925108808,
#  (4, 83, 84): 0.5899515788794052,
#  (4, 83, 85): 0.5969784495715423,
#  (3, 85, 85): 0.5308807357025521,
#  (4, 84, 85): 0.590039297342038,
#  (4, 84, 86): 0.5970633565449881,
#  (3, 86, 86): 0.5309161604663076,
#  (4, 85, 86): 0.5900632776909854,
#  (4, 85, 87): 0.5971014439543854,
#  (4, 29, 86): 0.6341472958369321,
#  (3, 87, 87): 0.531019424810327,
#  (4, 86, 87): 0.5900916241172586,
#  (4, 86, 88): 0.5971704908211825,
#  (3, 88, 88): 0.5310544195816186,
#  (4, 87, 88): 0.5901717184827432,
#  (4, 87, 89): 0.5972081978526308,
#  (3, 89, 89): 0.5310768122660842,
#  (4, 88, 89): 0.5902565427653305,
#  (4, 88, 90): 0.5972896979627089,
#  (4, 30, 89): 0.6345409208612762,
#  (3, 90, 90): 0.5311653907136445,
#  (4, 89, 90): 0.5902962343773815,
#  (4, 89, 91): 0.597325304646353,
#  (3, 91, 91): 0.5312151706104252,
#  (4, 90, 91): 0.5903176513097174,
#  (4, 90, 92): 0.5973977583765179,
#  (3, 92, 92): 0.5312498676946266,
#  (4, 91, 92): 0.5904037490315247,
#  (4, 91, 93): 0.5974274443946976,
#  (4, 31, 92): 0.6350845636410015,
#  (3, 93, 93): 0.5313585565589595,
#  (4, 92, 93): 0.5904832480228285,
#  (4, 92, 94): 0.597498806605531,
#  (3, 94, 94): 0.5313904421539738,
#  (4, 93, 94): 0.5905108667695473,
#  (4, 93, 95): 0.5975329083155515,
#  (3, 95, 95): 0.5316191650684178,
#  (4, 94, 95): 0.590518887782816,
#  (4, 94, 96): 0.5975902130804501,
#  (4, 32, 95): 0.6364357157297329,
#  (3, 96, 96): 0.5316609404901015,
#  (4, 95, 96): 0.5905898365393571,
#  (4, 95, 97): 0.5976202960147504,
#  (3, 97, 97): 0.5316739725693914,
#  (4, 96, 97): 0.5906563199895426,
#  (4, 96, 98): 0.5976821983913784,
#  (3, 98, 98): 0.5317002351860319,
#  (4, 97, 98): 0.5906784149869176,
#  (4, 97, 99): 0.5977121324821334,
#  (4, 33, 98): 0.6369774566197142,
#  (3, 99, 99): 0.5317385375916611,
#  (4, 98, 99): 0.5907043468401243,
#  (4, 98, 100): 0.5977623423713782,
#  (3, 100, 100): 0.53174793127318,
#  (4, 99, 100): 0.5907712272064303,
#  (4, 6, 6): 0.38529044734034446,
#  (5, 5, 6): 0.3960503141458788,
#  (4, 7, 7): 0.4024199248187945,
#  (5, 6, 7): 0.42052775091978695,
#  (4, 8, 8): 0.4285657819670951,
#  (5, 7, 8): 0.43856474403143997,
#  (4, 9, 9): 0.4379673356555573,
#  (5, 8, 9): 0.45166674671141765,
#  (4, 10, 10): 0.4425199304814645,
#  (5, 9, 10): 0.47425496198072786,
#  (4, 11, 11): 0.44806372408931566,
#  (5, 10, 11): 0.4900424495175617,
#  (4, 12, 12): 0.4693452418753916,
#  (5, 11, 12): 0.4940311588415976,
#  (4, 13, 13): 0.47675533508188117,
#  (5, 12, 13): 0.4998499491682755,
#  (4, 14, 14): 0.48208386784704227,
#  (5, 13, 14): 0.5030468273700656,
#  (4, 15, 15): 0.4852509608016224,
#  (5, 14, 15): 0.5158300733289302,
#  (4, 16, 16): 0.49122878218725124,
#  (5, 15, 16): 0.5299008986445578,
#  (4, 17, 17): 0.49264620272993614,
#  (5, 16, 17): 0.5345106990063337,
#  (4, 17, 51): 0.606547849164465,
#  (5, 16, 51): 0.6068501173284052,
#  (4, 18, 18): 0.494262775936087,
#  (5, 17, 18): 0.5398539672824688,
#  (4, 18, 54): 0.6085029752832394,
#  (5, 17, 54): 0.6086456500903911,
#  (4, 19, 19): 0.4959453033709292,
#  (5, 18, 19): 0.543222478630036,
#  (4, 19, 57): 0.6093778611037021,
#  (5, 18, 57): 0.6110883711250402,
#  (4, 20, 20): 0.5004434876119833,
#  (5, 19, 20): 0.5470177244216667,
#  (4, 20, 60): 0.6124243742485055,
#  (5, 19, 60): 0.6127122872794205,
#  (4, 21, 21): 0.501754931550492,
#  (5, 20, 21): 0.5505264463888041,
#  (4, 21, 63): 0.614252404517858,
#  (5, 20, 63): 0.6159845133914207,
#  (4, 22, 22): 0.5025522368075666,
#  (5, 21, 22): 0.5517973221921625,
#  (4, 22, 66): 0.6150826703511068,
#  (5, 21, 66): 0.6187561455845992,
#  (4, 23, 23): 0.5031675890997307,
#  (5, 22, 23): 0.5531504092469813,
#  (4, 23, 69): 0.6156283473259496,
#  (5, 22, 69): 0.6198103713388458,
#  (4, 24, 24): 0.506093654740131,
#  (5, 23, 24): 0.5539436130374774,
#  (4, 24, 72): 0.6177887948462294,
#  (5, 23, 72): 0.6206770046116361,
#  (4, 25, 25): 0.5079278041330082,
#  (5, 24, 25): 0.5569707103687193,
#  (4, 25, 75): 0.619438130170494,
#  (5, 24, 75): 0.6214497341455826,
#  (4, 26, 26): 0.5085600915129808,
#  (5, 25, 26): 0.5597136488340192,
#  (4, 26, 78): 0.6200700371725177,
#  (5, 25, 78): 0.6240545788772883,
#  (4, 27, 27): 0.5094988642906738,
#  (5, 26, 27): 0.5606478239999831,
#  (4, 27, 81): 0.6205027253583889,
#  (5, 26, 81): 0.6261406211631442,
#  (4, 28, 28): 0.5131205254322682,
#  (5, 27, 28): 0.5612278672955936,
#  (4, 28, 84): 0.6225665568796677,
#  (5, 27, 84): 0.6265492628473809,
#  (4, 29, 29): 0.5143106453432743,
#  (5, 28, 29): 0.5613912478936984,
#  (4, 29, 87): 0.6242289738977375,
#  (5, 28, 87): 0.626946129353376,
#  (4, 30, 30): 0.5156899950147334,
#  (5, 29, 30): 0.5637915319797965,
#  (4, 30, 90): 0.6246810778971702,
#  (5, 29, 90): 0.6272628022648563,
#  (4, 31, 31): 0.5166124611551424,
#  (5, 30, 31): 0.566074510814112,
#  (4, 31, 93): 0.6255271046080374,
#  (5, 30, 93): 0.6294413425449626,
#  (4, 32, 32): 0.5177187986883774,
#  (5, 31, 32): 0.5665562016026944,
#  (4, 32, 96): 0.6264351494627344,
#  (5, 31, 96): 0.6310857660322359,
#  (4, 33, 33): 0.5180689779356974,
#  (5, 32, 33): 0.5674294005296449,
#  (4, 33, 99): 0.626903626252138,
#  (5, 32, 99): 0.6314149087251689,
#  (4, 34, 34): 0.5183972606437027,
#  (5, 33, 34): 0.5680504584910413,
#  (4, 35, 35): 0.5188368121708242,
#  ...}

# %%
exportStateProbs(DATA_DIR + 'game1_better_giving_1_to_another_memo_1-100.csv', betterGiving1ToAnother)

# %%
betterGiving1ToAnother, given1ToAnother = readApproxBetterGiving1Probs(DATA_DIR + 'game1_better_giving_1_to_another_memo_1-100.csv')

# %%
betterGiving1ToAnother, given1ToAnother = stricterFilter(betterGiving1ToAnother, printOnGo=True,
                                                         filename=DATA_DIR + 'game1_better_giving_1_to_another_stricter_1-100.csv',
                                                         giveToAnother=True, continueFrom=(11,60,61))
# Out:
# Approximating hitting prob for (11, 61, 62)
# (11, 61, 62): 0.5590438794551355
# (10, 62, 62): 0.5079744337725204
#
# Approximating hitting prob for (11, 62, 63)
# (11, 62, 63): 0.5592541162725423
# (10, 63, 63): 0.5082188401689026
#
# Approximating hitting prob for (11, 63, 64)
# (11, 63, 64): 0.5595275183041343
# (10, 64, 64): 0.5084498634873543
#
# Approximating hitting prob for (11, 64, 65)
# (11, 64, 65): 0.5593928048412107
# (10, 65, 65): 0.5086833565440755
#
# Approximating hitting prob for (11, 65, 66)
# (11, 65, 66): 0.5614415294867466
# (10, 66, 66): 0.5092268310704737
#
# Approximating hitting prob for (11, 66, 67)
# (11, 66, 67): 0.5635066531941149
# (10, 67, 67): 0.5095467182741686
#
# Approximating hitting prob for (11, 67, 68)
# (11, 67, 68): 0.5637262072954773
# (10, 68, 68): 0.5098373124662873
#
# Approximating hitting prob for (11, 23, 68)
# (11, 23, 68): 0.5714190833879089
# (10, 24, 68): 0.5766933232188515
#
# Approximating hitting prob for (11, 68, 69)
# (11, 68, 69): 0.5642080484766445
# (10, 69, 69): 0.5100418694283785
#
# Approximating hitting prob for (11, 69, 70)
# (11, 69, 70): 0.5644624921124054
# (10, 70, 70): 0.5132792892835697
#
# Approximating hitting prob for (11, 70, 71)
# (11, 70, 71): 0.5646994073152453
# (10, 71, 71): 0.5142215877307255
#
# Approximating hitting prob for (10, 72, 72)
# (10, 72, 72): 0.5144179580280415
# (9, 73, 72): 0.5750585744895248
#
# Approximating hitting prob for (10, 73, 73)
# (10, 73, 73): 0.514617936707139
# (9, 74, 73): 0.5751089338458985
#
# Approximating hitting prob for (10, 74, 74)
# (10, 74, 74): 0.5147815308282214
# (9, 75, 74): 0.5752954249582151
#
# Approximating hitting prob for (11, 25, 74)
# (11, 25, 74): 0.5742060844967759
# (10, 26, 74): 0.5809470958259934
#
# Approximating hitting prob for (11, 74, 75)
# (11, 74, 75): 0.5659686505209514
# (10, 75, 75): 0.5157871505527319
#
# Approximating hitting prob for (11, 75, 76)
# (11, 75, 76): 0.5661991600694067
# (10, 76, 76): 0.5165136560722244
#
# Approximating hitting prob for (11, 76, 77)
# (11, 76, 77): 0.5679200579621755
# (10, 77, 77): 0.5167356504805906
#
# Approximating hitting prob for (10, 78, 78)
# (10, 78, 78): 0.5168844732829251
# (9, 79, 78): 0.575994253774641
#
# Approximating hitting prob for (10, 79, 79)
# (10, 79, 79): 0.5170449303057132
# (9, 80, 79): 0.576095941576053
#
# Approximating hitting prob for (10, 80, 80)
# (10, 80, 80): 0.5178637899251295
# (9, 81, 80): 0.5765624101832495
#
# Approximating hitting prob for (11, 27, 80)
# (11, 27, 80): 0.5781545495867139
# (10, 28, 80): 0.5839954543842047
#
# Approximating hitting prob for (11, 80, 81)
# (11, 80, 81): 0.5709784259142611
# (10, 81, 81): 0.5180855060900768
#
# Approximating hitting prob for (11, 81, 82)
# (11, 81, 82): 0.5711975541503831
# (10, 82, 82): 0.5181952546483684
#
# Approximating hitting prob for (11, 81, 85)
# (11, 81, 85): 0.5809169876720727
# (10, 82, 85): 0.5796740882753815
#
# Approximating hitting prob for (11, 82, 83)
# (11, 82, 83): 0.5723542265694664
# (10, 83, 83): 0.5182966195436733
#
# Approximating hitting prob for (11, 82, 86)
# (11, 82, 86): 0.5810414926800961
# (10, 83, 86): 0.5797439476787756
#
# Approximating hitting prob for (11, 28, 83)
# (11, 28, 83): 0.5804965451028691
# (10, 29, 83): 0.5846792799019579
#
# Approximating hitting prob for (11, 83, 84)
# (11, 83, 84): 0.5730651442123286
# (10, 84, 84): 0.518399497169347
#
# Approximating hitting prob for (11, 83, 87)
# (11, 83, 87): 0.5812405135870248
# (10, 84, 87): 0.5799192827601403
#
# Approximating hitting prob for (10, 85, 85)
# (10, 85, 85): 0.5185307858705364
# (9, 86, 85): 0.5773944985633092
#
# Approximating hitting prob for (11, 84, 86)
# (11, 84, 86): 0.5754789716239533
# (10, 85, 86): 0.5754425564096062
#
# Approximating hitting prob for (11, 84, 88)
# (11, 84, 88): 0.5817866262121816
# (10, 85, 88): 0.5800375375255457
#
# Approximating hitting prob for (10, 86, 86)
# (10, 86, 86): 0.5187660394762205
# (9, 87, 86): 0.5775102397045122
#
# Approximating hitting prob for (11, 85, 87)
# (11, 85, 87): 0.5757117289491872
# (10, 86, 87): 0.5756623981789685
#
# Approximating hitting prob for (10, 86, 89)
# (10, 86, 89): 0.5801580336229762
# (9, 87, 89): 0.5805244212868065
#
# Approximating hitting prob for (11, 85, 91)
# (11, 85, 91): 0.5870163465130352
# (10, 86, 91): 0.5867814192689712
#
# Approximating hitting prob for (10, 87, 87)
# (10, 87, 87): 0.5189739547022397
# (9, 88, 87): 0.5776529294934628
#
# Approximating hitting prob for (11, 86, 88)
# (11, 86, 88): 0.5762880999911807
# (10, 87, 88): 0.5758399877681589
#
# Approximating hitting prob for (11, 86, 90)
# (11, 86, 90): 0.582126912045231
# (10, 87, 90): 0.5807392325042589
#
# Approximating hitting prob for (10, 88, 88)
# (10, 88, 88): 0.5190875054050416
# (9, 89, 88): 0.5777956272167452
#
# Approximating hitting prob for (11, 87, 89)
# (11, 87, 89): 0.5763933967800892
# (10, 88, 89): 0.5759332887276928
#
# Approximating hitting prob for (11, 87, 91)
# (11, 87, 91): 0.582235965874054
# (10, 88, 91): 0.5808564407788442
#
# Approximating hitting prob for (10, 89, 89)
# (10, 89, 89): 0.5191698655001508
# (9, 90, 89): 0.5781833199381466
#
# Approximating hitting prob for (11, 88, 90)
# (11, 88, 90): 0.5769259232994824
# (10, 89, 90): 0.5763657931264511
#
# Approximating hitting prob for (10, 89, 92)
# (10, 89, 92): 0.5809239184476419
# (9, 90, 92): 0.5814269597009231
#
# Approximating hitting prob for (11, 88, 94)
# (11, 88, 94): 0.587771675444832
# (10, 89, 94): 0.587173706162016
#
# Approximating hitting prob for (11, 89, 90)
# (11, 89, 90): 0.5747371155481483
# (10, 90, 90): 0.5199577202363833
#
# Approximating hitting prob for (10, 90, 93)
# (10, 90, 93): 0.5813523423047268
# (9, 91, 93): 0.5815655902788451
#
# Approximating hitting prob for (11, 89, 95)
# (11, 89, 95): 0.5878602360893764
# (10, 90, 95): 0.5876135193236097
#
# Approximating hitting prob for (11, 90, 91)
# (11, 90, 91): 0.5748552109237453
# (10, 91, 91): 0.5200529181180552
#
# Approximating hitting prob for (10, 91, 94)
# (10, 91, 94): 0.581438856791516
# (9, 92, 94): 0.5816821381683521
#
# Approximating hitting prob for (11, 90, 96)
# (11, 90, 96): 0.5880541649812533
# (10, 91, 96): 0.5876997769368272
#
# Approximating hitting prob for (11, 91, 92)
# (11, 91, 92): 0.5749758901748218
# (10, 92, 92): 0.5201189678515461
#
# Approximating hitting prob for (10, 92, 95)
# (10, 92, 95): 0.5815405432175531
# (9, 93, 95): 0.5817543167417046
#
# Approximating hitting prob for (11, 91, 97)
# (11, 91, 97): 0.5881423937672713
# (10, 92, 97): 0.5878231278021341
#
# Approximating hitting prob for (11, 92, 93)
# (11, 92, 93): 0.5751063434343545
# (10, 93, 93): 0.5201991138843146
#
# Approximating hitting prob for (10, 93, 96)
# (10, 93, 96): 0.5816031582174421
# (9, 94, 96): 0.5818003670503659
#
# Approximating hitting prob for (11, 92, 98)
# (11, 92, 98): 0.5882660434105332
# (10, 93, 98): 0.5879323215813482
#
# Approximating hitting prob for (11, 93, 94)
# (11, 93, 94): 0.5752303711553104
# (10, 94, 94): 0.5202705104500421
#
# Approximating hitting prob for (10, 94, 97)
# (10, 94, 97): 0.5817101987700005
# (9, 95, 97): 0.581802908212291
#
# Approximating hitting prob for (11, 93, 99)
# (11, 93, 99): 0.5887066651033357
# (10, 94, 99): 0.5880007868321663
#
# Approximating hitting prob for (11, 94, 95)
# (11, 94, 95): 0.5753417511448581
# (10, 95, 95): 0.5203277783520273
#
# Approximating hitting prob for (10, 95, 98)
# (10, 95, 98): 0.5817814558019724
# (9, 96, 98): 0.5819819075785133
#
# Approximating hitting prob for (11, 94, 100)
# (11, 94, 100): 0.5887329133466702
# (10, 95, 100): 0.5883470404886351
#
# Approximating hitting prob for (11, 95, 96)
# (11, 95, 96): 0.5755432854379668
# (10, 96, 96): 0.5204841209498031
#
# Approximating hitting prob for (10, 96, 99)
# (10, 96, 99): 0.5818773170015558
# (9, 97, 99): 0.5823535640973861
#
# Approximating hitting prob for (10, 97, 97)
# (10, 97, 97): 0.5206688600934221
# (9, 98, 97): 0.579154794879296
#
# Approximating hitting prob for (11, 96, 98)
# (11, 96, 98): 0.5779545812849897
# (10, 97, 98): 0.5775235948884047
#
# Approximating hitting prob for (10, 97, 100)
# (10, 97, 100): 0.5823032281481973
# (9, 98, 100): 0.5824615631774769
#
# Approximating hitting prob for (10, 98, 98)
# (10, 98, 98): 0.5207588776616505
# (9, 99, 98): 0.5795646365040076
#
# Approximating hitting prob for (11, 97, 99)
# (11, 97, 99): 0.5783865257532841
# (10, 98, 99): 0.5776137971532372
#
# Approximating hitting prob for (10, 99, 99)
# (10, 99, 99): 0.5208389554848502
# (9, 100, 99): 0.579971207809388
#
# Approximating hitting prob for (11, 98, 100)
# (11, 98, 100): 0.5784598490381204
# (10, 99, 100): 0.577991635621108
#
# Approximating hitting prob for (11, 99, 100)
# (11, 99, 100): 0.5766712882554493
# (10, 100, 100): 0.5215152482895976
#
# (12, 4, 5): 25361212786530323488632165090773/211231236001418922729686365577742
# (11, 5, 5): 23116850618517454250797454599207/211231236001418922729686365577742
#
# (12, 6, 7): 3399555829063804162342241726600861534135561391117/16934029942992829195466851270975670880587990430730
# (11, 7, 7): 13493857085263733115639739713755916115830706734809/76203134743467731379600830719390518962645956938285
#
# (12, 7, 8): 2393199649256035856386933004372057535658076702242189411/11046774187701380572574518534649183196387591553689214837
# (11, 8, 8): 2104220072837383791062118201423568197316465865536797149/11046774187701380572574518534649183196387591553689214837
#
# Approximating hitting prob for (12, 7, 16)
# (12, 7, 16): 0.31906536664272855
# (11, 8, 16): 0.3187635821534672
#
# (12, 8, 9): 208347417492008940356461716964372663360399714857197503198848306009355/897015618933726609046711175540668692802579934916003127026343873340697
# (11, 9, 9): 1106344432424677496537703845962890245562688022148036691423497666001189/5382093713602359654280267053244012156815479609496018762158063240044182
#
# Approximating hitting prob for (12, 8, 18)
# (12, 8, 18): 0.3318465091696148
# (11, 9, 18): 0.325817229274621
#
# Approximating hitting prob for (12, 9, 10)
# (12, 9, 10): 0.2466435551627768
# (11, 10, 10): 0.21609698615287912
#
# Approximating hitting prob for (12, 9, 20)
# (12, 9, 20): 0.3407114937619487
# (11, 10, 20): 0.33157865494867217
#
# Approximating hitting prob for (12, 12, 13)
# (12, 12, 13): 0.39128852930595964
# (11, 13, 13): 0.36363833410299046
#
# Approximating hitting prob for (12, 13, 14)
# (12, 13, 14): 0.40633207448087494
# (11, 14, 14): 0.3699460087792124
#
# Approximating hitting prob for (12, 13, 42)
# (12, 13, 42): 0.5128539620622384
# (11, 14, 42): 0.5084249459213945
#
# Approximating hitting prob for (12, 14, 15)
# (12, 14, 15): 0.4116179812122858
# (11, 15, 15): 0.37462300623853967
#
# Approximating hitting prob for (12, 14, 45)
# (12, 14, 45): 0.515825786849529
# (11, 15, 45): 0.5118737679005787
#
# Approximating hitting prob for (11, 16, 16)
# (11, 16, 16): 0.3776911024130089
# (10, 17, 16): 0.4503779727879429
#
# Approximating hitting prob for (11, 16, 48)
# (11, 16, 48): 0.5153369110827438
# (10, 17, 48): 0.5386940394040961
#
# Approximating hitting prob for (11, 17, 17)
# (11, 17, 17): 0.3928300316696654
# (10, 18, 17): 0.45575394769873445
#
# Approximating hitting prob for (12, 9, 17)
# (12, 9, 17): 0.33140914134985283
# (11, 10, 17): 0.3503866324219116
#
# Approximating hitting prob for (12, 17, 18)
# (12, 17, 18): 0.42655449604438306
# (11, 18, 18): 0.39506446768910264
#
# Approximating hitting prob for (12, 17, 54)
# (12, 17, 54): 0.5292668243031974
# (11, 18, 54): 0.5261660975291451
#
# Approximating hitting prob for (12, 18, 19)
# (12, 18, 19): 0.444384011785716
# (11, 19, 19): 0.40155394751118595
#
# Approximating hitting prob for (12, 18, 57)
# (12, 18, 57): 0.533515610693152
# (11, 19, 57): 0.5307173157610799
#
# Approximating hitting prob for (11, 20, 20)
# (11, 20, 20): 0.4045194140683756
# (10, 21, 20): 0.48704587834570295
#
# Approximating hitting prob for (11, 20, 60)
# (11, 20, 60): 0.5355122308571131
# (10, 21, 60): 0.5714737365476836
#
# Approximating hitting prob for (11, 21, 21)
# (11, 21, 21): 0.4077714420320468
# (10, 22, 21): 0.4874440666178697
#
# Approximating hitting prob for (11, 21, 63)
# (11, 21, 63): 0.5372262523937242
# (10, 22, 63): 0.5734902249382895
#
# Approximating hitting prob for (11, 21, 74)
# (11, 21, 74): 0.552234563359569
# (10, 22, 74): 0.5789544263178836
#
# Approximating hitting prob for (11, 22, 22)
# (11, 22, 22): 0.4285714285714286
# (10, 23, 22): 0.49170534029663493
#
# Approximating hitting prob for (11, 23, 23)
# (11, 23, 23): 0.43446450830631705
# (10, 24, 23): 0.49416172077943515
#
# Approximating hitting prob for (11, 8, 24)
# (11, 8, 24): 0.35565433383563844
# (10, 9, 24): 0.3828144260467387
#
# Approximating hitting prob for (11, 24, 24)
# (11, 24, 24): 0.4359025674992279
# (10, 25, 24): 0.49694408459778655
#
# Approximating hitting prob for (11, 25, 25)
# (11, 25, 25): 0.4387112287836596
# (10, 26, 25): 0.49832919050059377
#
# Approximating hitting prob for (11, 26, 26)
# (11, 26, 26): 0.44077241624456337
# (10, 27, 26): 0.500775364795268
#
# Approximating hitting prob for (11, 26, 78)
# (11, 26, 78): 0.5678889232439301
# (10, 27, 78): 0.5828205295717622
#
# Approximating hitting prob for (11, 26, 88)
# (11, 26, 88): 0.5818480291138146
# (10, 27, 88): 0.5853840717878519
#
# Approximating hitting prob for (11, 26, 89)
# (11, 26, 89): 0.5808515625266004
# (10, 27, 89): 0.5857000069297035
#
# Approximating hitting prob for (11, 27, 27)
# (11, 27, 27): 0.44177797367349303
# (10, 28, 27): 0.5025645852802855
#
# Approximating hitting prob for (11, 27, 32)
# (11, 27, 32): 0.506545033456724
# (10, 28, 32): 0.5245122545567659
#
# Approximating hitting prob for (11, 27, 81)
# (11, 27, 81): 0.5689357081263134
# (10, 28, 81): 0.5835507612211969
#
# Approximating hitting prob for (11, 27, 91)
# (11, 27, 91): 0.582637342205857
# (10, 28, 91): 0.5863609284081434
#
# Approximating hitting prob for (11, 27, 92)
# (11, 27, 92): 0.581573548893903
# (10, 28, 92): 0.5864577582165801
#
# Approximating hitting prob for (11, 28, 28)
# (11, 28, 28): 0.4451226810061315
# (10, 29, 28): 0.503918912202037
#
# Approximating hitting prob for (11, 28, 84)
# (11, 28, 84): 0.5715090401342657
# (10, 29, 84): 0.5841714031861797
#
# Approximating hitting prob for (11, 28, 94)
# (11, 28, 94): 0.5842513492178663
# (10, 29, 94): 0.5869792660881015
#
# Approximating hitting prob for (11, 28, 95)
# (11, 28, 95): 0.5833756936892246
# (10, 29, 95): 0.5870368786399133
#
# Approximating hitting prob for (11, 29, 29)
# (11, 29, 29): 0.4464254342986484
# (10, 30, 29): 0.5145462315759913
#
# Approximating hitting prob for (11, 29, 87)
# (11, 29, 87): 0.5723488039431522
# (10, 30, 87): 0.5952517262746951
#
# Approximating hitting prob for (11, 29, 97)
# (11, 29, 97): 0.5851519576380734
# (10, 30, 97): 0.5979008380896979
#
# Approximating hitting prob for (11, 29, 98)
# (11, 29, 98): 0.5841113533344332
# (10, 30, 98): 0.5980121065099605
#
# Approximating hitting prob for (11, 10, 30)
# (11, 10, 30): 0.3790316949939627
# (10, 11, 30): 0.5061165218704154
#
# Approximating hitting prob for (11, 30, 30)
# (11, 30, 30): 0.44760468361701844
# (10, 31, 30): 0.5269549795841763
#
# Approximating hitting prob for (11, 30, 90)
# (11, 30, 90): 0.5731535880179397
# (10, 31, 90): 0.6033685405536998
#
# Approximating hitting prob for (11, 30, 100)
# (11, 30, 100): 0.5859738996064268
# (10, 31, 100): 0.6061472462927538
#
# Approximating hitting prob for (11, 31, 31)
# (11, 31, 31): 0.4494444673140446
# (10, 32, 31): 0.5300124858036691
#
# Approximating hitting prob for (11, 31, 93)
# (11, 31, 93): 0.5737410823601247
# (10, 32, 93): 0.6041431219906895
#
# Approximating hitting prob for (11, 32, 32)
# (11, 32, 32): 0.45060275470087197
# (10, 33, 32): 0.531465090413153
#
# Approximating hitting prob for (11, 32, 42)
# (11, 32, 42): 0.5299467192997049
# (10, 33, 42): 0.5575096978558335
#
# Approximating hitting prob for (11, 32, 96)
# (11, 32, 96): 0.5744361126274681
# (10, 33, 96): 0.6043282993937718
#
# Approximating hitting prob for (11, 33, 33)
# (11, 33, 33): 0.46941896024464413
# (10, 34, 33): 0.5330711350256487
#
# Approximating hitting prob for (11, 34, 34)
# (11, 34, 34): 0.47509662525827784
# (10, 35, 34): 0.5342524051768919
#
# Approximating hitting prob for (11, 35, 35)
# (11, 35, 35): 0.4761940069474678
# (10, 36, 35): 0.5396893701655553
#
# Approximating hitting prob for (11, 36, 36)
# (11, 36, 36): 0.47726048486501454
# (10, 37, 36): 0.540548255006309
#
# Approximating hitting prob for (11, 37, 37)
# (11, 37, 37): 0.478615564224479
# (10, 38, 37): 0.5414962129360283
#
# Approximating hitting prob for (11, 38, 38)
# (11, 38, 38): 0.4791921049675931
# (10, 39, 38): 0.542335422320878
#
# Approximating hitting prob for (11, 13, 39)
# (11, 13, 39): 0.5050775098285955
# (10, 14, 39): 0.5208618463994813
#
# Approximating hitting prob for (11, 39, 39)
# (11, 39, 39): 0.4840828113651341
# (10, 40, 39): 0.5452033888255238
#
# Approximating hitting prob for (11, 40, 40)
# (11, 40, 40): 0.48456605268576186
# (10, 41, 40): 0.547981895779608
#
# Approximating hitting prob for (11, 41, 41)
# (11, 41, 41): 0.4852465852899932
# (10, 42, 41): 0.5484505239609024
#
# Approximating hitting prob for (12, 14, 41)
# (12, 14, 41): 0.5124796052372294
# (11, 15, 41): 0.5175837407238292
#
# Approximating hitting prob for (12, 41, 42)
# (12, 41, 42): 0.5340016232154506
# (11, 42, 42): 0.48607952584385555
# Approximating hitting prob for (12, 42, 43)
# (12, 42, 43): 0.5393330739497434
# (11, 43, 43): 0.4867405618371725
#
# Approximating hitting prob for (12, 43, 44)
# (12, 43, 44): 0.5401219518023271
# (11, 44, 44): 0.49131100605898986
#
# Approximating hitting prob for (11, 45, 45)
# (11, 45, 45): 0.4920519111833448
# (10, 46, 45): 0.5512081869622386
#
# Approximating hitting prob for (11, 46, 46)
# (11, 46, 46): 0.49253956210096644
# (10, 47, 46): 0.5518152423439187
#
# Approximating hitting prob for (11, 47, 47)
# (11, 47, 47): 0.4929570092828773
# (10, 48, 47): 0.5522808167881138
#
# Approximating hitting prob for (12, 16, 47)
# (12, 16, 47): 0.5197403115507948
# (11, 17, 47): 0.5277435735248535
#
# Approximating hitting prob for (12, 47, 48)
# (12, 47, 48): 0.5449359620475656
# (11, 48, 48): 0.4939296710933537
#
# Approximating hitting prob for (12, 48, 49)
# (12, 48, 49): 0.547656885485973
# (11, 49, 49): 0.4943063345036723
#
# Approximating hitting prob for (12, 49, 50)
# (12, 49, 50): 0.5480763667988452
# (11, 50, 50): 0.49534264414538315
#
# Approximating hitting prob for (12, 49, 53)
# (12, 49, 53): 0.5557410429078665
# (11, 50, 53): 0.5557073104011839
#
# Approximating hitting prob for (12, 50, 51)
# (12, 50, 51): 0.5482592528507347
# (11, 51, 51): 0.49561394646334794
#
# Approximating hitting prob for (12, 50, 54)
# (12, 50, 54): 0.5560948110732223
# (11, 51, 54): 0.5560709785449526
#
# Approximating hitting prob for (12, 51, 52)
# (12, 51, 52): 0.5490401662262971
# (11, 52, 52): 0.49598407559608376
#
# Approximating hitting prob for (12, 21, 52)
# (12, 21, 52): 0.5340591809817995
# (11, 22, 52): 0.5538745746235664
#
# Approximating hitting prob for (12, 52, 53)
# (12, 52, 53): 0.5498216673795236
# (11, 53, 53): 0.49637511942599694
#
# Approximating hitting prob for (11, 54, 54)
# (11, 54, 54): 0.49669704310874657
# (10, 55, 54): 0.5588870334556197
#
# Approximating hitting prob for (11, 55, 55)
# (11, 55, 55): 0.5005600203855535
# (10, 56, 55): 0.5590940855146266
#
# Approximating hitting prob for (11, 56, 56)
# (11, 56, 56): 0.501446985176917
# (10, 57, 56): 0.5593610343152777
#
# Approximating hitting prob for (12, 19, 56)
# (12, 19, 56): 0.5336068209781215
# (11, 20, 56): 0.5414993169541993
#
# Approximating hitting prob for (12, 56, 57)
# (12, 56, 57): 0.5517523373974397
# (11, 57, 57): 0.5016835150186071
#
# Approximating hitting prob for (12, 57, 58)
# (12, 57, 58): 0.5521888784475736
# (11, 58, 58): 0.5020308063326712
#
# Approximating hitting prob for (12, 58, 59)
# (12, 58, 59): 0.5524790534041518
# (11, 59, 59): 0.5022616177218541
#
# Approximating hitting prob for (11, 60, 60)
# (11, 60, 60): 0.5025294282084917
# (10, 61, 60): 0.563685301116246
#
# Approximating hitting prob for (11, 61, 61)
# (11, 61, 61): 0.5028791488058696
# (10, 62, 61): 0.5639122704184213
#
# Approximating hitting prob for (11, 61, 64)
# (11, 61, 64): 0.5635471633997512
# (10, 62, 64): 0.5668084066781369
#
# Approximating hitting prob for (11, 62, 62)
# (11, 62, 62): 0.5030579524421552
# (10, 63, 62): 0.5644269976246686
#
# Approximating hitting prob for (12, 61, 63)
# (12, 61, 63): 0.5595211207787573
# (11, 62, 63): 0.5592541162725423
#
# Approximating hitting prob for (12, 61, 64)
# (12, 61, 64): 0.5617421305442849
# (11, 62, 64): 0.5612358075852533
#
# Approximating hitting prob for (12, 61, 65)
# (12, 61, 65): 0.5643944381989183
# (11, 62, 65): 0.5637709303405527
#
# Approximating hitting prob for (11, 63, 63)
# (11, 63, 63): 0.503289536510145
# (10, 64, 63): 0.5646952662136119
#
# Approximating hitting prob for (12, 62, 64)
# (12, 62, 64): 0.5598657886675368
# (11, 63, 64): 0.5595275183041343
#
# Approximating hitting prob for (12, 62, 65)
# (12, 62, 65): 0.5620031412434047
# (11, 63, 65): 0.5618049321873033
#
# Approximating hitting prob for (12, 63, 64)
# (12, 63, 64): 0.5580425044905629
# (11, 64, 64): 0.5034612436307917
#
# Approximating hitting prob for (11, 65, 65)
# (11, 65, 65): 0.5036543323470686
# (10, 66, 65): 0.5652918737256848
#
# Approximating hitting prob for (11, 66, 66)
# (11, 66, 66): 0.5062234648424173
# (10, 67, 66): 0.5657619847471859
#
# Approximating hitting prob for (11, 67, 67)
# (11, 67, 67): 0.5077144944862294
# (10, 68, 67): 0.5660717205404924
#
# Approximating hitting prob for (11, 68, 68)
# (11, 68, 68): 0.5079464085946906
# (10, 69, 68): 0.5663394358552553
#
# Approximating hitting prob for (11, 69, 69)
# (11, 69, 69): 0.5081827850918059
# (10, 70, 69): 0.5680842180381213
#
# Approximating hitting prob for (11, 70, 70)
# (11, 70, 70): 0.5083767245401815
# (10, 71, 70): 0.5701999530731602
#
# Approximating hitting prob for (11, 71, 71)
# (11, 71, 71): 0.5085100177204818
# (10, 72, 71): 0.5708133326463632
#
# Approximating hitting prob for (11, 72, 72)
# (11, 72, 72): 0.509131974159772
# (10, 73, 72): 0.5710256341163161
#
# Approximating hitting prob for (11, 73, 73)
# (11, 73, 73): 0.5092972263035165
# (10, 74, 73): 0.5712465947358049
#
# Approximating hitting prob for (11, 73, 76)
# (11, 73, 76): 0.5700840782064827
# (10, 74, 76): 0.575031816040725
#
# Approximating hitting prob for (11, 74, 74)
# (11, 74, 74): 0.5095797253248923
# (10, 75, 74): 0.571408556584565
#
# Approximating hitting prob for (11, 25, 75)
# (11, 25, 75): 0.5650654709046529
# (10, 26, 75): 0.580429962549371
#
# Approximating hitting prob for (11, 75, 75)
# (11, 75, 75): 0.5098591880655512
# (10, 76, 75): 0.573147915276829
#
# Approximating hitting prob for (11, 76, 76)
# (11, 76, 76): 0.5100554938022989
# (10, 77, 76): 0.5733577685326772
#
# Approximating hitting prob for (11, 77, 77)
# (11, 77, 77): 0.5132792892835697
# (10, 78, 77): 0.5735742506192187
#
# Approximating hitting prob for (12, 26, 77)
# (12, 26, 77): 0.5722196077501283
# (11, 27, 77): 0.5789652929869346
#
# Approximating hitting prob for (12, 77, 78)
# (12, 77, 78): 0.5648077897303805
# (11, 78, 78): 0.5142032061032813
#
# Approximating hitting prob for (12, 78, 79)
# (12, 78, 79): 0.5649711653387638
# (11, 79, 79): 0.5143941301887703
#
# Approximating hitting prob for (12, 79, 80)
# (12, 79, 80): 0.5653966697436186
# (11, 80, 80): 0.5145903955455164
#
# Approximating hitting prob for (11, 81, 81)
# (11, 81, 81): 0.5147366385771898
# (10, 82, 81): 0.574902790887724
#
# Approximating hitting prob for (11, 82, 82)
# (11, 82, 82): 0.5148302996643643
# (10, 83, 82): 0.5750557579706255
#
# Approximating hitting prob for (11, 83, 83)
# (11, 83, 83): 0.516457093052538
# (10, 84, 83): 0.5751712950823377
#
# Approximating hitting prob for (12, 28, 83)
# (12, 28, 83): 0.5751005222694944
# (11, 29, 83): 0.5812187081170485
#
# Approximating hitting prob for (12, 83, 84)
# (12, 83, 84): 0.5677788162084983
# (11, 84, 84): 0.5165497721689212
#
# Approximating hitting prob for (12, 84, 85)
# (12, 84, 85): 0.5698862947103663
# (11, 85, 85): 0.5167612653524367
#
# Approximating hitting prob for (12, 85, 86)
# (12, 85, 86): 0.570414029344772
# (11, 86, 86): 0.5169038509488207
#
# Approximating hitting prob for (11, 87, 87)
# (11, 87, 87): 0.5170590789611494
# (10, 88, 87): 0.5758399877681589
#
# Approximating hitting prob for (11, 88, 88)
# (11, 88, 88): 0.5178637899251295
# (10, 89, 88): 0.5759332887276928
#
# Approximating hitting prob for (11, 89, 89)
# (11, 89, 89): 0.5180787699181538
# (10, 90, 89): 0.5763657931264511
#
# Approximating hitting prob for (11, 89, 94)
# (11, 89, 94): 0.5835818133594587
# (10, 90, 94): 0.5850141291271279
#
# Approximating hitting prob for (12, 30, 89)
# (12, 30, 89): 0.5788911078837832
# (11, 31, 89): 0.5841151200712568
#
# Approximating hitting prob for (12, 89, 90)
# (12, 89, 90): 0.5711117185585043
# (11, 90, 90): 0.5181826941279716
#
# Approximating hitting prob for (12, 89, 93)
# (12, 89, 93): 0.5793769809267779
# (11, 90, 93): 0.5793353828213262
#
# Approximating hitting prob for (12, 89, 95)
# (12, 89, 95): 0.5839303873719001
# (11, 90, 95): 0.5836890698484263
#
# Approximating hitting prob for (12, 90, 91)
# (12, 90, 91): 0.5728350920544675
# (11, 91, 91): 0.5182797683671884
#
# Approximating hitting prob for (12, 90, 94)
# (12, 90, 94): 0.5795397681111825
# (11, 91, 94): 0.5793949328419122
#
# Approximating hitting prob for (12, 90, 96)
# (12, 90, 96): 0.584498879893192
# (11, 91, 96): 0.5838742957234878
#
# Approximating hitting prob for (12, 91, 92)
# (12, 91, 92): 0.5730110771920238
# (11, 92, 92): 0.5183838036420626
#
# Approximating hitting prob for (12, 91, 95)
# (12, 91, 95): 0.5796871690119462
# (11, 92, 95): 0.5795334221028978
#
# Approximating hitting prob for (12, 91, 97)
# (12, 91, 97): 0.584600713085779
# (11, 92, 97): 0.5839692379437619
#
# Approximating hitting prob for (11, 93, 93)
# (11, 93, 93): 0.5184454374274061
# (10, 94, 93): 0.5771013352851926
# Approximating hitting prob for (11, 93, 96)
# (11, 93, 96): 0.5796538330169096
# (10, 94, 96): 0.5796980203615311
#
# Approximating hitting prob for (11, 93, 98)
# (11, 93, 98): 0.5840540944834527
# (10, 94, 98): 0.5853787463174241
#
# Approximating hitting prob for (11, 94, 94)
# (11, 94, 94): 0.5187176885764764
# (10, 95, 94): 0.5771696692609517
#
# Approximating hitting prob for (12, 93, 96)
# (12, 93, 96): 0.5777922980878437
# (11, 94, 96): 0.5776286976476999
#
# Approximating hitting prob for (12, 93, 97)
# (12, 93, 97): 0.580405195739701
# (11, 94, 97): 0.5797872926425681
#
# Approximating hitting prob for (12, 93, 99)
# (12, 93, 99): 0.5849146699770245
# (11, 94, 99): 0.5845334476050914
#
# Approximating hitting prob for (12, 94, 95)
# (12, 94, 95): 0.5734566701930459
# (11, 95, 95): 0.518801427059656
#
# Approximating hitting prob for (12, 94, 97)
# (12, 94, 97): 0.5779108280670974
# (11, 95, 97): 0.5778223607500648
#
# Approximating hitting prob for (12, 94, 98)
# (12, 94, 98): 0.5805380097486296
# (11, 95, 98): 0.5799002780911164
#
# Approximating hitting prob for (12, 94, 100)
# (12, 94, 100): 0.5850943007722194
# (11, 95, 100): 0.5846228082785351
#
# Approximating hitting prob for (11, 96, 96)
# (11, 96, 96): 0.5189972188617425
# (10, 97, 96): 0.57735383960398
#
# Approximating hitting prob for (12, 95, 97)
# (12, 95, 97): 0.5760129457732669
# (11, 96, 97): 0.5757069510153402
#
# Approximating hitting prob for (12, 95, 99)
# (12, 95, 99): 0.5806349057334392
# (11, 96, 99): 0.5804479997352473
#
# Approximating hitting prob for (12, 96, 97)
# (12, 96, 97): 0.5745465239707642
# (11, 97, 97): 0.5191022259073789
#
# Approximating hitting prob for (12, 96, 99)
# (12, 96, 99): 0.5785577554473362
# (11, 97, 99): 0.5783865257532841
#
# Approximating hitting prob for (11, 98, 98)
# (11, 98, 98): 0.5191758171553545
# (10, 99, 98): 0.5776137971532372
#
# Approximating hitting prob for (12, 97, 99)
# (12, 97, 99): 0.5765990629857999
# (11, 98, 99): 0.5762063035265689
#
# Approximating hitting prob for (11, 99, 99)
# (11, 99, 99): 0.5199577202363833
# (10, 100, 99): 0.577991635621108
#
# Approximating hitting prob for (11, 100, 100)
# (11, 100, 100): 0.5200511674913905
# (10, 101, 100): 0.5783851149045777
#
# (12, 7, 7): 64859651520837325528794909478116125563432082536131451122197118007873/385660609213043593618440362611741319988816999340127538390104173663324
# (11, 8, 7): 22084750562722940721712297800221817035438129184541175159753379871913/96415152303260898404610090652935329997204249835031884597526043415831
#
# (12, 8, 8): 20/109
# (11, 9, 8): 158435180917763707504416016204764910795589348244042602752244209808265649234311325/650601217491802300436959194816660273443895106112585651284984080366466613120808936
#
# (12, 9, 9): 1590310/8115163
# (11, 10, 9): 395340425560797403048616793305058432310054927047081346921942877163746452646976467167/1544474951691439298802955162891018276800268326373477469418454346679294130403670608862
#
# (12, 9, 18): 136757774089/426756252062
# (11, 10, 18): 509837128340887421357413825608705023636450632755910989385515488056379776814591418209861487751563354824672314901372146389/1452034787553860601866278238621003940765284194880728920534957472514971711937078655144240882002919746321786178716421594053
#
# (12, 10, 10): 3377957002474178998319/16257604793809051013145
# (11, 11, 10): 4659858586868138911586702086275511917283047029533569370196875900801737699178796884257452954374825616187418/14538545406775929571640726983868999091436149146672921990770587719542255887971829844090928554266179490858765
#
# Approximating hitting prob for (12, 10, 20)
# (12, 10, 20): 0.32831579821399354
# (11, 11, 20): 0.4172151309618404
#
# Approximating hitting prob for (12, 11, 11)
# (12, 11, 11): 0.21686811675627718
# (11, 12, 11): 0.3915659416218141
#
# Approximating hitting prob for (12, 11, 22)
# (12, 11, 22): 0.331857301121022
# (11, 12, 22): 0.469115939859041
#
# Approximating hitting prob for (12, 14, 14)
# (12, 14, 14): 0.3626759287590275
# (11, 15, 14): 0.41917393861280566
#
# Approximating hitting prob for (12, 15, 15)
# (12, 15, 15): 0.3679559744936582
# (11, 16, 15): 0.42343572024549586
#
# Approximating hitting prob for (12, 15, 45)
# (12, 15, 45): 0.5073181242949473
# (11, 16, 45): 0.5229657865229244
#
# (12, 8, 16): 4695/15019
# (11, 9, 16): 
#
# Approximating hitting prob for (12, 16, 16)
# (12, 16, 16): 0.37265977777400555
# (11, 17, 16): 0.4365027522483306
#
# Approximating hitting prob for (12, 16, 48)
# (12, 16, 48): 0.5110406441009517
# (11, 17, 48): 0.5283493624741583
#
# Approximating hitting prob for (12, 17, 17)
# (12, 17, 17): 0.37682525554075913
# (11, 18, 17): 0.44544111867867725
#
# Approximating hitting prob for (12, 17, 51)
# (12, 17, 51): 0.5141379706563384
# (11, 18, 51): 0.5328179795911183
#
# Approximating hitting prob for (13, 9, 17)
# (13, 9, 17): 0.3252064851832775
# (12, 10, 17): 0.34260478186104487
#
# Approximating hitting prob for (13, 17, 18)
# (13, 17, 18): 0.4207974003991941
# (12, 18, 18): 0.38531294066601585
#
# Approximating hitting prob for (13, 18, 19)
# (13, 18, 19): 0.4239139615801191
# (12, 19, 19): 0.3936104997905013
#
# Approximating hitting prob for (13, 18, 57)
# (13, 18, 57): 0.5261850959069942
# (12, 19, 57): 0.5249670664270975
#
# Approximating hitting prob for (12, 20, 20)
# (12, 20, 20): 0.39923107976612376
# (11, 21, 20): 0.457896805184316
#
# Approximating hitting prob for (12, 20, 60)
# (12, 20, 60): 0.5285380286570163
# (11, 21, 60): 0.5460254446497447
#
# Approximating hitting prob for (12, 21, 21)
# (12, 21, 21): 0.4025301176497849
# (11, 22, 21): 0.4730711108751047
#
# Approximating hitting prob for (12, 21, 63)
# (12, 21, 63): 0.5329836301279316
# (11, 22, 63): 0.5603518307697052
#
# Approximating hitting prob for (13, 11, 21)
# (13, 11, 21): 0.34009913712128315
# (12, 12, 21): 0.4163467274937926
#
# Approximating hitting prob for (13, 21, 22)
# (13, 21, 22): 0.4501389809411121
# (12, 22, 22): 0.40537758745520946
#
# Approximating hitting prob for (13, 21, 66)
# (13, 21, 66): 0.5361370234241049
# (12, 22, 66): 0.5357973435892338
#
# Approximating hitting prob for (13, 22, 23)
# (13, 22, 23): 0.45463761378079576
# (12, 23, 23): 0.4079108385741359
#
# Approximating hitting prob for (13, 22, 58)
# (13, 22, 58): 0.5335599145484052
# (12, 23, 58): 0.5335330764863161
#
# Approximating hitting prob for (13, 22, 69)
# (13, 22, 69): 0.5427080797329465
# (12, 23, 69): 0.5374575035296082
#
# Approximating hitting prob for (13, 22, 80)
# (13, 22, 80): 0.5541125835705574
# (12, 23, 80): 0.5532536257675832
#
# Approximating hitting prob for (13, 22, 81)
# (13, 22, 81): 0.554368538698877
# (12, 23, 81): 0.5523284378125901
#
# Approximating hitting prob for (13, 23, 24)
# (13, 23, 24): 0.45755678242531655
# (12, 24, 24): 0.4285714285714286
#
# Approximating hitting prob for (13, 24, 25)
# (13, 24, 25): 0.45832887426803165
# (12, 25, 25): 0.4343891715843085
#
# Approximating hitting prob for (13, 25, 26)
# (13, 25, 26): 0.4729554315916396
# (12, 26, 26): 0.43555797041404976
#
# Approximating hitting prob for (13, 26, 27)
# (13, 26, 27): 0.4863539186080857
# (12, 27, 27): 0.4381003152708904
#
# Approximating hitting prob for (13, 27, 28)
# (13, 27, 28): 0.4862808943204229
# (12, 28, 28): 0.4403379450546962
#
# Approximating hitting prob for (13, 27, 84)
# (13, 27, 84): 0.5721746850166608
# (12, 28, 84): 0.5674280980003379
#
# Approximating hitting prob for (13, 27, 95)
# (13, 27, 95): 0.5822211640716094
# (12, 28, 95): 0.5813309268184454
#
# Approximating hitting prob for (13, 27, 96)
# (13, 27, 96): 0.582095089565368
# (12, 28, 96): 0.5801495809847527
#
# Approximating hitting prob for (13, 28, 29)
# (13, 28, 29): 0.4895677391515754
# (12, 29, 29): 0.4414166400543895
#
# Approximating hitting prob for (13, 28, 87)
# (13, 28, 87): 0.5733231305657885
# (12, 29, 87): 0.5685519892622154
#
# Approximating hitting prob for (13, 28, 98)
# (13, 28, 98): 0.5828488411698927
# (12, 29, 98): 0.5823166706259364
#
# Approximating hitting prob for (13, 28, 99)
# (13, 28, 99): 0.5830148885902181
# (12, 29, 99): 0.5812803820229479
#
# Approximating hitting prob for (13, 29, 30)
# (13, 29, 30): 0.4921279217162759
# (12, 30, 30): 0.44255325660645745
#
# Approximating hitting prob for (13, 29, 90)
# (13, 29, 90): 0.5743539668553956
# (12, 30, 90): 0.5707436686787252
#
# Approximating hitting prob for (13, 30, 31)
# (13, 30, 31): 0.49352325948249565
# (12, 31, 31): 0.44572076580876246
# Approximating hitting prob for (13, 30, 93)
# (13, 30, 93): 0.5767069814373239
# (12, 31, 93): 0.571957641531358
#
# Approximating hitting prob for (13, 31, 32)
# (13, 31, 32): 0.49538516449546693
# (12, 32, 32): 0.44694562306725144
#
# Approximating hitting prob for (13, 31, 96)
# (13, 31, 96): 0.5795190142779226
# (12, 32, 96): 0.5726922251898705
#
# Approximating hitting prob for (13, 11, 32)
# (13, 11, 32): 0.38094777191099044
# (12, 12, 32): 0.4494948590276684
#
# Approximating hitting prob for (13, 32, 33)
# (13, 32, 33): 0.4971142779175724
# (12, 33, 33): 0.44820689847484574
#
# Approximating hitting prob for (13, 32, 99)
# (13, 32, 99): 0.5805120270120996
# (12, 33, 99): 0.5732573958023478
#
# Approximating hitting prob for (13, 33, 34)
# (13, 33, 34): 0.4983913454241961
# (12, 34, 34): 0.44967941127936356
#
# Approximating hitting prob for (13, 34, 35)
# (13, 34, 35): 0.5002204685350943
# (12, 35, 35): 0.450650888877433
#
# Approximating hitting prob for (13, 34, 46)
# (13, 34, 46): 0.5304725182843997
# (12, 35, 46): 0.5299937351500015
#
# Approximating hitting prob for (13, 35, 36)
# (13, 35, 36): 0.5017433449209412
# (12, 36, 36): 0.46941896024464413
#
# Approximating hitting prob for (13, 36, 37)
# (13, 36, 37): 0.5031125394952282
# (12, 37, 37): 0.47504349293042863
#
# Approximating hitting prob for (13, 37, 38)
# (13, 37, 38): 0.503889086919408
# (12, 38, 38): 0.4759784725562271
#
# Approximating hitting prob for (13, 38, 39)
# (13, 38, 39): 0.5141762633475967
# (12, 39, 39): 0.4769314080948765
#
# Approximating hitting prob for (13, 39, 40)
# (13, 39, 40): 0.5264354766944456
# (12, 40, 40): 0.4782616481955468
#
# Approximating hitting prob for (13, 40, 41)
# (13, 40, 41): 0.5291137941620764
# (12, 41, 41): 0.47902415549389477
#
# Approximating hitting prob for (13, 14, 41)
# (13, 14, 41): 0.5064692033313632
# (12, 15, 41): 0.5153637681078594
#
# Approximating hitting prob for (13, 41, 42)
# (13, 41, 42): 0.5302646029708272
# (12, 42, 42): 0.4821387523777809
#
# Approximating hitting prob for (13, 42, 43)
# (13, 42, 43): 0.5312799224153013
# (12, 43, 43): 0.48432676780332495
#
# Approximating hitting prob for (13, 43, 44)
# (13, 43, 44): 0.5324495399899213
# (12, 44, 44): 0.48487580101649524
#
# Approximating hitting prob for (12, 45, 45)
# (12, 45, 45): 0.48540954999808766
# (11, 46, 45): 0.5482089426020038
#
# Approximating hitting prob for (12, 46, 46)
# (12, 46, 46): 0.48623135833849834
# (11, 47, 46): 0.5485107338157368
#
# Approximating hitting prob for (12, 47, 47)
# (12, 47, 47): 0.4867649499730509
# (11, 48, 47): 0.5493694933955676
#
# Approximating hitting prob for (13, 16, 47)
# (13, 16, 47): 0.5151304392613484
# (12, 17, 47): 0.5218126499019241
#
# Approximating hitting prob for (13, 47, 48)
# (13, 47, 48): 0.5401623721339343
# (12, 48, 48): 0.49131100605898986
#
# Approximating hitting prob for (13, 48, 49)
# (13, 48, 49): 0.5409080176526019
# (12, 49, 49): 0.4920287516946575
#
# Approximating hitting prob for (13, 49, 50)
# (13, 49, 50): 0.5414899742357869
# (12, 50, 50): 0.49238952424855054
#
# Approximating hitting prob for (12, 51, 51)
# (12, 51, 51): 0.49280520932956623
# (11, 52, 51): 0.5518373896069692
#
# Approximating hitting prob for (12, 52, 52)
# (12, 52, 52): 0.4937056394014537
# (11, 53, 52): 0.5522048643574841
#
# Approximating hitting prob for (12, 53, 53)
# (12, 53, 53): 0.49422242160701163
# (11, 54, 53): 0.5525411399333361
#
# Approximating hitting prob for (12, 18, 54)
# (12, 18, 54): 0.520847348354239
# (11, 19, 54): 0.5393744116936139
#
# Approximating hitting prob for (12, 54, 54)
# (12, 54, 54): 0.4943291983296177
# (11, 55, 54): 0.5547304366259892
#
# Approximating hitting prob for (12, 55, 55)
# (12, 55, 55): 0.4954647621189803
# (11, 56, 55): 0.5571234313251544
#
# Approximating hitting prob for (12, 22, 56)
# (12, 22, 56): 0.532734806781722
# (11, 23, 56): 0.5697511165852556
#
# Approximating hitting prob for (12, 56, 56)
# (12, 56, 56): 0.49579489100046387
# (11, 57, 56): 0.5576263394104631
#
# Approximating hitting prob for (12, 57, 57)
# (12, 57, 57): 0.4961191780067134
# (11, 58, 57): 0.5579622139076122
#
# Approximating hitting prob for (13, 23, 57)
# (13, 23, 57): 0.5343468440483866
# (12, 24, 57): 0.5538901673609508
#
# Approximating hitting prob for (13, 57, 58)
# (13, 57, 58): 0.5498578707833741
# (12, 58, 58): 0.4964517685378212
#
# Approximating hitting prob for (13, 58, 59)
# (13, 58, 59): 0.5505361318565152
# (12, 59, 59): 0.4967126920048394
#
# Approximating hitting prob for (12, 60, 60)
# (12, 60, 60): 0.5005600203855535
# (11, 61, 60): 0.5588290843326048
#
# Approximating hitting prob for (12, 61, 61)
# (12, 61, 61): 0.5014366784626665
# (11, 62, 61): 0.5590438794551355
#
# Approximating hitting prob for (12, 62, 62)
# (12, 62, 62): 0.5016440900497224
# (11, 63, 62): 0.5592541162725423
#
# Approximating hitting prob for (13, 21, 62)
# (13, 21, 62): 0.534357741173075
# (12, 22, 62): 0.5437956949094455
#
# Approximating hitting prob for (13, 62, 63)
# (13, 62, 63): 0.5520465220214942
# (12, 63, 63): 0.501925664345551
#
# Approximating hitting prob for (13, 63, 64)
# (13, 63, 64): 0.5523634862302644
# (12, 64, 64): 0.5022083161109352
#
# Approximating hitting prob for (13, 64, 65)
# (13, 64, 65): 0.5544610825455121
# (12, 65, 65): 0.5024734144175195
#
# Approximating hitting prob for (12, 66, 66)
# (12, 66, 66): 0.5026381251870221
# (11, 67, 66): 0.5635066531941149
#
# Approximating hitting prob for (12, 67, 67)
# (12, 67, 67): 0.5029340972319404
# (11, 68, 67): 0.5637262072954773
#
# Approximating hitting prob for (13, 66, 68)
# (13, 66, 68): 0.5591588548132135
# (12, 67, 68): 0.559014927012051
#
# Approximating hitting prob for (13, 66, 69)
# (13, 66, 69): 0.5611061367015426
# (12, 67, 69): 0.5610262795458046
#
# Approximating hitting prob for (13, 66, 71)
# (13, 66, 71): 0.5661724912419452
# (12, 67, 71): 0.5658270336522973
#
# Approximating hitting prob for (13, 67, 68)
# (13, 67, 68): 0.5575084436585162
# (12, 68, 68): 0.5032031783052567
#
# Approximating hitting prob for (12, 68, 70)
# (12, 68, 70): 0.5609528839525325
# (11, 69, 70): 0.5644624921124054
#
# Approximating hitting prob for (13, 23, 68)
# (13, 23, 68): 0.542495391113376
# (12, 24, 68): 0.5605565510938499
#
# Approximating hitting prob for (13, 68, 69)
# (13, 68, 69): 0.5578343657715348
# (12, 69, 69): 0.5033410974106731
#
# Approximating hitting prob for (12, 69, 71)
# (12, 69, 71): 0.5614463083847895
# (11, 70, 71): 0.5646994073152453
#
# Approximating hitting prob for (12, 70, 70)
# (12, 70, 70): 0.5035238808435724
# (11, 71, 70): 0.5646994073152453
#
# Approximating hitting prob for (13, 69, 71)
# (13, 69, 71): 0.5599457530503643
# (12, 70, 71): 0.5593008312957938
#
# Approximating hitting prob for (13, 70, 71)
# (13, 70, 71): 0.558332164503906
# (12, 71, 71): 0.5036580384476812
#
# Approximating hitting prob for (13, 71, 72)
# (13, 71, 72): 0.5585496363544756
# (12, 72, 72): 0.5062234648424173
#
# Approximating hitting prob for (13, 72, 73)
# (13, 72, 73): 0.5587273461667993
# (12, 73, 73): 0.5077050859338721
#
# Approximating hitting prob for (13, 73, 74)
# (13, 73, 74): 0.5589377490903457
# (12, 74, 74): 0.5079014004848482
#
# Approximating hitting prob for (13, 74, 75)
# (13, 74, 75): 0.5591577076275643
# (12, 75, 75): 0.5081098880182108
#
# Approximating hitting prob for (13, 75, 76)
# (13, 75, 76): 0.5592933852190273
# (12, 76, 76): 0.5083228942284245
#
# Approximating hitting prob for (13, 76, 77)
# (13, 76, 77): 0.5591715504796746
# (12, 77, 77): 0.5084691133291055
#
# Approximating hitting prob for (13, 77, 78)
# (13, 77, 78): 0.5611643899040152
# (12, 78, 78): 0.5086833565440755
#
# Approximating hitting prob for (13, 78, 79)
# (13, 78, 79): 0.5632065224997196
# (12, 79, 79): 0.509186030988742
#
# Approximating hitting prob for (13, 78, 83)
# (13, 78, 83): 0.5721278739398199
# (12, 79, 83): 0.572022922334792
#
# Approximating hitting prob for (13, 79, 80)
# (13, 79, 80): 0.563392913649116
# (12, 80, 80): 0.509461859014558
#
# Approximating hitting prob for (13, 27, 80)
# (13, 27, 80): 0.5712835889924658
# (12, 28, 80): 0.5757215488470568
#
# Approximating hitting prob for (13, 80, 81)
# (13, 80, 81): 0.5638426037679527
# (12, 81, 81): 0.5096813732733328
#
# Approximating hitting prob for (13, 81, 82)
# (13, 81, 82): 0.5640559803236164
# (12, 82, 82): 0.5098906774569679
#
# Approximating hitting prob for (13, 82, 83)
# (13, 82, 83): 0.5642519506154539
# (12, 83, 83): 0.5100654045417762
#
# Approximating hitting prob for (12, 84, 84)
# (12, 84, 84): 0.5132792892835697
# (11, 85, 84): 0.5732316508162416
#
# Approximating hitting prob for (12, 85, 85)
# (12, 85, 85): 0.5141939499622782
# (11, 86, 85): 0.5734573647305002
# Approximating hitting prob for (12, 86, 86)
# (12, 86, 86): 0.5143665315974582
# (11, 87, 86): 0.5735579290729752
#
# Approximating hitting prob for (13, 29, 86)
# (13, 29, 86): 0.5735142274938925
# (12, 30, 86): 0.579583266038559
#
# Approximating hitting prob for (13, 86, 87)
# (13, 86, 87): 0.5653349006516714
# (12, 87, 87): 0.5145098261669587
#
# Approximating hitting prob for (13, 87, 88)
# (13, 87, 88): 0.5655683245965019
# (12, 88, 88): 0.5146836094207132
#
# Approximating hitting prob for (13, 88, 89)
# (13, 88, 89): 0.5657941561653512
# (12, 89, 89): 0.5148004691446899
#
# Approximating hitting prob for (12, 90, 90)
# (12, 90, 90): 0.5157871505527319
# (11, 91, 90): 0.5748552109237453
#
# Approximating hitting prob for (12, 91, 91)
# (12, 91, 91): 0.5164822669277831
# (11, 92, 91): 0.5749758901748218
#
# Approximating hitting prob for (12, 92, 92)
# (12, 92, 92): 0.5166591333857613
# (11, 93, 92): 0.5751063434343545
#
# Approximating hitting prob for (13, 31, 92)
# (13, 31, 92): 0.5773393459100734
# (12, 32, 92): 0.5824873171603832
#
# Approximating hitting prob for (13, 92, 93)
# (13, 92, 93): 0.5702660583049463
# (12, 93, 93): 0.5167979603934619
#
# Approximating hitting prob for (13, 93, 94)
# (13, 93, 94): 0.5704326469920743
# (12, 94, 94): 0.5169432528654477
#
# Approximating hitting prob for (13, 94, 95)
# (13, 94, 95): 0.5706356672840742
# (12, 95, 95): 0.5170667033165738
#
# Approximating hitting prob for (12, 96, 96)
# (12, 96, 96): 0.5178637899251295
# (11, 97, 96): 0.5757069510153402
#
# Approximating hitting prob for (12, 97, 97)
# (12, 97, 97): 0.5180743077190337
# (11, 98, 97): 0.5757846738303137
#
# Approximating hitting prob for (12, 98, 98)
# (12, 98, 98): 0.5181445875751
# (11, 99, 98): 0.5762063035265689
#
# Approximating hitting prob for (13, 33, 98)
# (13, 33, 98): 0.5804357896468267
# (12, 34, 98): 0.5839509570781521
#
# Approximating hitting prob for (13, 98, 99)
# (13, 98, 99): 0.5727872866435904
# (12, 99, 99): 0.5182471718963392
#
# Approximating hitting prob for (13, 99, 100)
# (13, 99, 100): 0.5729100488312424
# (12, 100, 100): 0.5183484686887088
#
# (14, 5, 6): 3151009220063522365786457491601579533407057274931/25401044914489243793200276906463506320881985646095
# (13, 6, 6): 2790658868779964604695439391660894387044003242561/25401044914489243793200276906463506320881985646095
#
# (14, 7, 8): 179673693471949107629284268086623705264111116755672822315407244683571/897015618933726609046711175540668692802579934916003127026343873340697
# (13, 8, 8): 52233702765193470778422700842764533795246149297522720228111710528447/299005206311242203015570391846889564267526644972001042342114624446899
#
# (14, 8, 9): 37519874140213880230867289869555878163572698320669444281886033789661792299467190/174772675430178374555854751414038185949454217749495465591344704262064230788888197
# (13, 9, 9): 32561314389144425777016732631798212295964594212718771901006217573539266509635710/174772675430178374555854751414038185949454217749495465591344704262064230788888197
#
# Approximating hitting prob for (14, 8, 18)
# (14, 8, 18): 0.3152909193361297
# (13, 9, 18): 0.31473448644434265
#
# (14, 9, 10): 28031003360904318620296161362174324571876223089602606255659383821511887295661058892/122822591897773440413161930882052440364139770964292720246221750269184233191066339805
# (13, 10, 10): 24738930943321000102567708019312422540444518671171420241617049687653185002140835237/122822591897773440413161930882052440364139770964292720246221750269184233191066339805
#
# Approximating hitting prob for (14, 9, 20)
# (14, 9, 20): 0.326205129399119
# (13, 10, 20): 0.32193637499940436
#
# (14, 10, 11): 952379977214627384639883274536867212481187102821468571286573772909350614414439487760967131687466244273/3971484671534318571411641000458453443568043922916992331970984992238035082718799356330073791940582171184
# (13, 11, 11): 2499943692748366348263483995764957785349770249057406691519198242660911785695832785653681603657290455079/11914454014602955714234923001375360330704131768750976995912954976714105248156398068990221375821746513552
#
# Approximating hitting prob for (14, 10, 22)
# (14, 10, 22): 0.33498833967614794
# (13, 11, 22): 0.3290903912529402
#
# Approximating hitting prob for (14, 10, 33)
# (14, 10, 33): 0.3742905346150647
# (13, 11, 33): 0.3738000530446186
#
# Approximating hitting prob for (14, 11, 12)
# (14, 11, 12): 0.2507795674616255
# (13, 12, 12): 0.21742294138775983
#
# Approximating hitting prob for (14, 11, 24)
# (14, 11, 24): 0.3431767700078338
# (13, 12, 24): 0.3320500926233258
#
# Approximating hitting prob for (14, 14, 15)
# (14, 14, 15): 0.39078117620401787
# (13, 15, 15): 0.36170497220667547
#
# Approximating hitting prob for (14, 15, 16)
# (14, 15, 16): 0.4052207139987006
# (13, 16, 16): 0.3659940543149818
#
# Approximating hitting prob for (14, 15, 48)
# (14, 15, 48): 0.5118745041772441
# (13, 16, 48): 0.5066708929321712
#
# Approximating hitting prob for (14, 16, 17)
# (14, 16, 17): 0.40965188938729913
# (13, 17, 17): 0.3714384029452223
#
# Approximating hitting prob for (14, 16, 51)
# (14, 16, 51): 0.5147678030242867
# (13, 17, 51): 0.509958504343098
#
# Approximating hitting prob for (13, 18, 18)
# (13, 18, 18): 0.3753429470450169
# (12, 19, 18): 0.444384011785716
#
# Approximating hitting prob for (13, 18, 54)
# (13, 18, 54): 0.512831869363238
# (12, 19, 54): 0.5293255665973641
#
# Approximating hitting prob for (13, 19, 19)
# (13, 19, 19): 0.37789266461611076
# (12, 20, 19): 0.4488697960587303
#
# Approximating hitting prob for (13, 19, 57)
# (13, 19, 57): 0.5154913965005025
# (12, 20, 57): 0.5370970241700537
#
# Approximating hitting prob for (14, 10, 19)
# (14, 10, 19): 0.32631613417949
# (13, 11, 19): 0.34532900779439424
#
# Approximating hitting prob for (14, 19, 20)
# (14, 19, 20): 0.4228097946777934
# (13, 20, 20): 0.39271394324000525
#
# Approximating hitting prob for (14, 20, 21)
# (14, 20, 21): 0.426383822314138
# (13, 21, 21): 0.3944597023339642
#
# Approximating hitting prob for (14, 20, 63)
# (14, 20, 63): 0.5293196451538248
# (13, 21, 63): 0.5256360400225283
#
# Approximating hitting prob for (13, 22, 22)
# (13, 22, 22): 0.4008051075144838
# (12, 23, 22): 0.45823056779817345
#
# Approximating hitting prob for (13, 22, 66)
# (13, 22, 66): 0.5302912491786588
# (12, 23, 66): 0.5462703826699812
#
# Approximating hitting prob for (13, 23, 23)
# (13, 23, 23): 0.403561366973023
# (12, 24, 23): 0.4730389694804016
#
# Approximating hitting prob for (13, 23, 69)
# (13, 23, 69): 0.5348253863388018
# (12, 24, 69): 0.5603122375865669
#
# Approximating hitting prob for (14, 12, 23)
# (14, 12, 23): 0.3406365814481258
# (13, 13, 23): 0.4165817072039437
#
# Approximating hitting prob for (14, 23, 24)
# (14, 23, 24): 0.45104550293020845
# (13, 24, 24): 0.4060459627122948
#
# Approximating hitting prob for (14, 23, 72)
# (14, 23, 72): 0.536693069263508
# (13, 24, 72): 0.5360030112091226
#
# Approximating hitting prob for (14, 24, 25)
# (14, 24, 25): 0.45519411013805827
# (13, 25, 25): 0.408023538960004
#
# Approximating hitting prob for (14, 24, 63)
# (14, 24, 63): 0.533796706749462
# (13, 25, 63): 0.5335740856592848
#
# Approximating hitting prob for (14, 24, 75)
# ...
# (13, 35, 35): 0.44726382376013024
# (12, 36, 35): 0.5142960721624588
#
# Approximating hitting prob for (13, 12, 36)
# (13, 12, 36): 0.3800350523001926
# (12, 13, 36): 0.5057421319800425
#
# Approximating hitting prob for (13, 36, 36)
# (13, 36, 36): 0.4488453664738778
# (12, 37, 36): 0.5266050725671872
#
# Approximating hitting prob for (13, 37, 37)
# (13, 37, 37): 0.44995885795872925
# (12, 38, 37): 0.5293195612320053
#
# Approximating hitting prob for (13, 38, 38)
# (13, 38, 38): 0.4507200042445933
# (12, 39, 38): 0.5305666378797677
#
# Approximating hitting prob for (13, 38, 50)
# (13, 38, 50): 0.5300535494230575
# (12, 39, 50): 0.5573019242994626
#
# Approximating hitting prob for (13, 39, 39)
# (13, 39, 39): 0.46941896024464413
# (12, 40, 39): 0.5319831104897255
#
# Approximating hitting prob for (13, 40, 40)
# (13, 40, 40): 0.4749839716362169
# (12, 41, 40): 0.5332446007666086
#
# Approximating hitting prob for (13, 41, 41)
# (13, 41, 41): 0.475741799379039
# (12, 42, 41): 0.5340016232154506
#
# Approximating hitting prob for (13, 42, 42)
# (13, 42, 42): 0.4765044801877723
# (12, 43, 42): 0.5393330739497434
#
# Approximating hitting prob for (13, 43, 43)
# (13, 43, 43): 0.47748849831742773
# (12, 44, 43): 0.5401219518023271
#
# Approximating hitting prob for (13, 44, 44)
# (13, 44, 44): 0.47875717054008
# (12, 45, 44): 0.5408739835174964
#
# Approximating hitting prob for (13, 15, 45)
# (13, 15, 45): 0.503559190058981
# (12, 16, 45): 0.5188809250552542
#
# Approximating hitting prob for (13, 45, 45)
# (13, 45, 45): 0.4792153552360417
# (12, 46, 45): 0.5415270048540594
#
# Approximating hitting prob for (13, 46, 46)
# (13, 46, 46): 0.484067284568702
# (12, 47, 46): 0.5423174060012552
#
# Approximating hitting prob for (13, 47, 47)
# (13, 47, 47): 0.48447003886028145
# (12, 48, 47): 0.5449359620475656
#
# Approximating hitting prob for (14, 16, 47)
# (14, 16, 47): 0.5114102327962057
# (13, 17, 47): 0.5151526822645944
#
# Approximating hitting prob for (14, 47, 48)
# (14, 47, 48): 0.5331610541635935
# (13, 48, 48): 0.4850772755363184
#
# Approximating hitting prob for (14, 48, 49)
# (14, 48, 49): 0.5337595858332124
# (13, 49, 49): 0.48572053126523246
#
# Approximating hitting prob for (14, 49, 50)
# (14, 49, 50): 0.539080854213105
# (13, 50, 50): 0.4863383373955115
#
# Approximating hitting prob for (13, 51, 51)
# (13, 51, 51): 0.48680643973809606
# (12, 52, 51): 0.5490401662262971
#
# Approximating hitting prob for (13, 52, 52)
# (13, 52, 52): 0.49131100605898986
# (12, 53, 52): 0.5498216673795236
#
# Approximating hitting prob for (13, 53, 53)
# (13, 53, 53): 0.4920140277741212
# (12, 54, 53): 0.5504862127462572
#
# Approximating hitting prob for (14, 18, 53)
# (14, 18, 53): 0.5171853108756925
# (13, 19, 53): 0.5229131656018736
#
# Approximating hitting prob for (14, 53, 54)
# (14, 53, 54): 0.5415102675529109
# (13, 54, 54): 0.4922989141399566
#
# Approximating hitting prob for (14, 54, 55)
# (14, 54, 55): 0.5421450569400429
# (13, 55, 55): 0.49265527990556585
#
# Approximating hitting prob for (14, 55, 56)
# (14, 55, 56): 0.5447067560251851
# (13, 56, 56): 0.49304767777954367
#
# Approximating hitting prob for (13, 57, 57)
# (13, 57, 57): 0.4939971573470196
# (12, 58, 57): 0.5521888784475736
#
# Approximating hitting prob for (13, 57, 61)
# (13, 57, 61): 0.555486505850642
# (12, 58, 61): 0.558799633907061
#
# Approximating hitting prob for (13, 57, 63)
# (13, 57, 63): 0.5599103748484106
# (12, 58, 63): 0.5635919331678251
#
# Approximating hitting prob for (13, 58, 58)
# (13, 58, 58): 0.4943164880811406
# (12, 59, 58): 0.5524790534041518
#
# Approximating hitting prob for (13, 58, 62)
# (13, 58, 62): 0.5559171478116922
# (12, 59, 62): 0.5590553103749795
#
# Approximating hitting prob for (13, 59, 59)
# (13, 59, 59): 0.49533081442140087
# (12, 60, 59): 0.5545944067221326
#
# Approximating hitting prob for (13, 59, 63)
# (13, 59, 63): 0.5562244881929895
# (12, 60, 63): 0.5611251246208548
#
# Approximating hitting prob for (13, 60, 60)
# (13, 60, 60): 0.49553747520821817
# (12, 61, 60): 0.5569703695751761
#
# Approximating hitting prob for (13, 60, 64)
# (13, 60, 64): 0.5563740060315906
# (12, 61, 64): 0.5617421305442849
#
# Approximating hitting prob for (13, 24, 61)
# (13, 24, 61): 0.532844623278078
# (12, 25, 61): 0.5697188733895713
#
# Approximating hitting prob for (13, 61, 61)
# (13, 61, 61): 0.49585808354874006
# (12, 62, 61): 0.55746237477115
#
# Approximating hitting prob for (13, 62, 62)
# (13, 62, 62): 0.4962441048548804
# (12, 63, 62): 0.5577220837758349
#
# Approximating hitting prob for (14, 21, 62)
# (14, 21, 62): 0.5266825850477496
# (13, 22, 62): 0.5385569449889718
#
# Approximating hitting prob for (13, 63, 63)
# (13, 63, 63): 0.49653650265472216
# (12, 64, 63): 0.5580425044905629
#
# Approximating hitting prob for (13, 64, 64)
# (13, 64, 64): 0.4967233101101014
# (12, 65, 64): 0.5583684366574463
#
# Approximating hitting prob for (13, 64, 70)
# (13, 64, 70): 0.564292238785438
# (12, 65, 70): 0.5674301381291613
#
# Approximating hitting prob for (13, 65, 65)
# (13, 65, 65): 0.5005600203855535
# (12, 66, 65): 0.558598922353432
#
# Approximating hitting prob for (14, 22, 65)
# (14, 22, 65): 0.5334183854510192
# (13, 23, 65): 0.5402421530055771
#
# Approximating hitting prob for (14, 65, 66)
# (14, 65, 66): 0.551417454465328
# (13, 66, 66): 0.5014316803470865
#
# Approximating hitting prob for (14, 66, 67)
# (14, 66, 67): 0.5517177619364122
# (13, 67, 67): 0.5015683781907428
#
# Approximating hitting prob for (14, 67, 68)
# (14, 67, 68): 0.5519960024790322
# (13, 68, 68): 0.5017461209591149
#
# Approximating hitting prob for (14, 68, 69)
# (14, 68, 69): 0.5522647442406007
# (13, 69, 69): 0.5021331437307667
#
# Approximating hitting prob for (14, 69, 70)
# (14, 69, 70): 0.5543398914691131
# (13, 70, 70): 0.502320832270475
#
# Approximating hitting prob for (14, 69, 74)
# (14, 69, 74): 0.5633114506871335
# (13, 70, 74): 0.5632623071591955
#
# Approximating hitting prob for (14, 70, 71)
# (14, 70, 71): 0.5566977317121715
# (13, 71, 71): 0.5025345275116362
#
# Approximating hitting prob for (14, 70, 73)
# (14, 70, 73): 0.5604229354475742
# (13, 71, 73): 0.5602999797683369
#
# Approximating hitting prob for (14, 70, 75)
# (14, 70, 75): 0.5654298412717126
# (13, 71, 75): 0.563758758672223
#
# Approximating hitting prob for (14, 70, 77)
# (14, 70, 77): 0.5682163750511314
# (13, 71, 77): 0.5680098549330853
#
# Approximating hitting prob for (13, 72, 72)
# (13, 72, 72): 0.5028679838068744
# (12, 73, 72): 0.5633458001472211
#
# Approximating hitting prob for (14, 71, 73)
# (14, 71, 73): 0.5587677742136798
# (13, 72, 73): 0.5587273461667993
#
# Approximating hitting prob for (14, 71, 74)
# (14, 71, 74): 0.5609149280530868
# (13, 72, 74): 0.5605446396550934
#
# Approximating hitting prob for (14, 71, 75)
# (14, 71, 75): 0.5623528842671339
# (13, 72, 75): 0.5621348894110535
#
# Approximating hitting prob for (14, 71, 76)
# (14, 71, 76): 0.5658922769266325
# (13, 72, 76): 0.5639650521470191
#
# Approximating hitting prob for (14, 72, 73)
# (14, 72, 73): 0.5573360260241046
# (13, 73, 73): 0.5029898513575704
#
# Approximating hitting prob for (13, 73, 75)
# (13, 73, 75): 0.5607095238496214
# (12, 74, 75): 0.5640099971406181
#
# Approximating hitting prob for (13, 73, 77)
# (13, 73, 77): 0.5641712793614491
# (12, 74, 77): 0.568421397911052
#
# Approximating hitting prob for (13, 74, 74)
# (13, 74, 74): 0.5032381657668349
# (12, 75, 74): 0.5640099971406181
#
# Approximating hitting prob for (14, 73, 75)
# (14, 73, 75): 0.5592840273518352
# (13, 74, 75): 0.5591577076275643
#
# Approximating hitting prob for (14, 73, 76)
# (14, 73, 76): 0.5614468526750773
# (13, 74, 76): 0.5606082240519208
#
# Approximating hitting prob for (14, 73, 78)
# (14, 73, 78): 0.5663583894701514
# (13, 74, 78): 0.5659342768161939
#
# Approximating hitting prob for (13, 75, 75)
# (13, 75, 75): 0.5033940604286838
# (12, 76, 75): 0.5642772899371641
#
# Approximating hitting prob for (14, 74, 76)
# (14, 74, 76): 0.559522895871474
# (13, 75, 76): 0.5592933852190273
# Approximating hitting prob for (14, 74, 77)
# (14, 74, 77): 0.5616337095184988
# (13, 75, 77): 0.56111434909642
#
# Approximating hitting prob for (14, 75, 76)
# (14, 75, 76): 0.55813450873846
# (13, 76, 76): 0.5035562664998553
#
# Approximating hitting prob for (13, 76, 80)
# (13, 76, 80): 0.5666052174423589
# (12, 77, 80): 0.5690010674824938
#
# Approximating hitting prob for (13, 77, 77)
# (13, 77, 77): 0.5036627569196829
# (12, 78, 77): 0.5648077897303805
#
# Approximating hitting prob for (13, 77, 81)
# (13, 77, 81): 0.5667303643552973
# (12, 78, 81): 0.5691997502484238
#
# Approximating hitting prob for (13, 78, 78)
# (13, 78, 78): 0.5062234648424173
# (12, 79, 78): 0.5649711653387638
#
# Approximating hitting prob for (13, 79, 79)
# (13, 79, 79): 0.5076975244701748
# (12, 80, 79): 0.5653966697436186
#
# Approximating hitting prob for (13, 80, 80)
# (13, 80, 80): 0.5078603354914208
# (12, 81, 80): 0.5656425859154961
#
# Approximating hitting prob for (13, 81, 81)
# (13, 81, 81): 0.5080177214100969
# (12, 82, 81): 0.5658980929350634
#
# Approximating hitting prob for (13, 81, 85)
# (13, 81, 85): 0.5695022255380597
# (12, 82, 85): 0.5721256064553576
#
# Approximating hitting prob for (13, 82, 82)
# (13, 82, 82): 0.5082358564229335
# (12, 83, 82): 0.5660713979500107
#
# Approximating hitting prob for (13, 82, 86)
# (13, 82, 86): 0.5693344721841348
# (12, 83, 86): 0.5723356916451687
#
# Approximating hitting prob for (13, 83, 83)
# (13, 83, 83): 0.5084277543255307
# (12, 84, 83): 0.5677788162084983
#
# Approximating hitting prob for (13, 83, 87)
# (13, 83, 87): 0.5698477469230013
# (12, 84, 87): 0.5740390414414921
#
# Approximating hitting prob for (13, 84, 84)
# (13, 84, 84): 0.5085186549986762
# (12, 85, 84): 0.5698862947103663
#
# Approximating hitting prob for (13, 84, 88)
# (13, 84, 88): 0.5700258471472975
# (12, 85, 88): 0.5746059807683923
#
# Approximating hitting prob for (13, 85, 85)
# (13, 85, 85): 0.509125727112023
# (12, 86, 85): 0.570414029344772
#
# Approximating hitting prob for (13, 85, 87)
# (13, 85, 87): 0.5667640111327981
# (12, 86, 87): 0.5706256848321728
#
# Approximating hitting prob for (13, 85, 89)
# (13, 85, 89): 0.5702465181376225
# (12, 86, 89): 0.5747828005285968
#
# Approximating hitting prob for (13, 86, 86)
# (13, 86, 86): 0.5092580547137858
# (12, 87, 86): 0.5706256848321728
#
# Approximating hitting prob for (13, 86, 88)
# (13, 86, 88): 0.5671731920664296
# (12, 87, 88): 0.5708263820240175
#
# Approximating hitting prob for (13, 86, 90)
# (13, 86, 90): 0.5703945553658775
# (12, 87, 90): 0.574945750710182
#
# Approximating hitting prob for (13, 29, 87)
# (13, 29, 87): 0.564290352614398
# (12, 30, 87): 0.5793708854407448
#
# Approximating hitting prob for (13, 87, 87)
# (13, 87, 87): 0.5095361184974877
# (12, 88, 87): 0.5708263820240175
#
# Approximating hitting prob for (13, 87, 89)
# (13, 87, 89): 0.5674100160879835
# (12, 88, 89): 0.5709863596876777
#
# Approximating hitting prob for (13, 87, 91)
# (13, 87, 91): 0.5723803790068066
# (12, 88, 91): 0.5750412925913746
#
# Approximating hitting prob for (13, 88, 88)
# (13, 88, 88): 0.5097850938026401
# (12, 89, 88): 0.5709863596876777
#
# Approximating hitting prob for (13, 89, 89)
# (13, 89, 89): 0.5099487909297413
# (12, 90, 89): 0.5711117185585043
#
# Approximating hitting prob for (14, 30, 89)
# (14, 30, 89): 0.5719260483022627
# (13, 31, 89): 0.5761098770598968
#
# Approximating hitting prob for (14, 89, 90)
# (14, 89, 90): 0.5642035931052654
# (13, 90, 90): 0.5100740025087896
#
# Approximating hitting prob for (14, 90, 91)
# (14, 90, 91): 0.5645497512497563
# (13, 91, 91): 0.5132792892835697
#
# Approximating hitting prob for (14, 91, 92)
# (14, 91, 92): 0.5646878440617354
# (13, 92, 92): 0.5141851629932259
#
# Approximating hitting prob for (13, 93, 93)
# (13, 93, 93): 0.5143325385315882
# (12, 94, 93): 0.5733494545508591
#
# Approximating hitting prob for (13, 94, 94)
# (13, 94, 94): 0.5144516451316689
# (12, 95, 94): 0.5734566701930459
#
# Approximating hitting prob for (13, 95, 95)
# (13, 95, 95): 0.514626304265469
# (12, 96, 95): 0.5740230484732874
#
# Approximating hitting prob for (13, 95, 99)
# (13, 95, 99): 0.5759374150627267
# (12, 96, 99): 0.5785577554473362
#
# Approximating hitting prob for (14, 32, 95)
# (14, 32, 95): 0.5743070795559289
# (13, 33, 95): 0.5798131222881212
#
# Approximating hitting prob for (14, 95, 96)
# (14, 95, 96): 0.5657047468176334
# (13, 96, 96): 0.5147636318553644
#
# Approximating hitting prob for (14, 96, 97)
# (14, 96, 97): 0.56585585998419
# (13, 97, 97): 0.514835422661687
#
# Approximating hitting prob for (14, 97, 98)
# (14, 97, 98): 0.5675100873865423
# (13, 98, 98): 0.5164518092577945
#
# Approximating hitting prob for (13, 99, 99)
# (13, 99, 99): 0.5165288832910498
# (12, 100, 99): 0.574805492142384
#
# Approximating hitting prob for (13, 100, 100)
# (13, 100, 100): 0.5167296265399633
# (12, 101, 100): 0.574901081167435
#
# (14, 6, 6): 136757774089/1280268756186
# (13, 7, 6): 13949318608797038963454336412631022715848475859018734101235184952995/82641559117080770061094363416801711426175071287170186797879465784998
#
# (14, 8, 8): 5801365285876/34675064776757
# (13, 9, 8): 8203897534327020826311896279388226589307923337884691374552743871572745656739060664/36773213135510459495308456259309958971434960151749463557582246349507003104849300211
#
# Approximating hitting prob for (14, 9, 9)
# (14, 9, 9): 0.1776150040254999
# (13, 10, 9): 0.23604754607879774
#
# (14, 10, 10): 1495573108152538186574/7880824082891064441747
# (13, 11, 10): 798052200358667706011701253437578630828716785359467559728758293465053991146240314146791468571895748265607736201238492848/3210569802688360765014492052662479370978827590352730811781403011083886419736545603943941710985329942557015452780765682949
#
# Approximating hitting prob for (14, 10, 20)
# (14, 10, 20): 0.31763632498740596
# (13, 11, 20): 0.3410179294623839
#
# Approximating hitting prob for (14, 11, 11)
# (14, 11, 11): 0.20296443875000358
# (13, 12, 11): 0.25841289824460817
#
# Approximating hitting prob for (14, 11, 22)
# (14, 11, 22): 0.32334533610463406
# (13, 12, 22): 0.35403037683558863
#
# Approximating hitting prob for (14, 12, 12)
# (14, 12, 12): 0.21108106781728822
# (13, 13, 12): 0.3209024938568647
#
# Approximating hitting prob for (14, 12, 24)
# (14, 12, 24): 0.3295918193334498
# (13, 13, 24): 0.4175702278633991
#
# Approximating hitting prob for (14, 12, 36)
# (14, 12, 36): 0.37470229520714415
# (13, 13, 36): 0.4506562204636224
#
# Approximating hitting prob for (14, 13, 13)
# (14, 13, 13): 0.2178703900482322
# (13, 14, 13): 0.39106480497588386
#
# Approximating hitting prob for (14, 13, 26)
# (14, 13, 26): 0.33217407166897694
# (13, 14, 26): 0.4690164345790224
#
# Approximating hitting prob for (14, 8, 16)
# (14, 8, 16): 0.29645307031430956
# (13, 9, 16): 0.323920712844408
#
# Approximating hitting prob for (14, 16, 16)
# (14, 16, 16): 0.36117495610369726
# (13, 17, 16): 0.41598965877316046
#
# Approximating hitting prob for (14, 17, 17)
# (14, 17, 17): 0.3654037136249164
# (13, 18, 17): 0.4207974003991941
#
# Approximating hitting prob for (14, 17, 51)
# (14, 17, 51): 0.5062768170822735
# (13, 18, 51): 0.5200842024413986
#
# Approximating hitting prob for (14, 9, 18)
# (14, 9, 18): 0.309084892971718
# (13, 10, 18): 0.33045396499476404
#
# Approximating hitting prob for (14, 18, 18)
# (14, 18, 18): 0.3708512080439254
# (13, 19, 18): 0.4239139615801191
#
# Approximating hitting prob for (14, 18, 54)
# (14, 18, 54): 0.509055356345569
# (13, 19, 54): 0.523558869977565
#
# Approximating hitting prob for (14, 19, 19)
# (14, 19, 19): 0.3744252063441933
# (13, 20, 19): 0.43627530348982174
#
# Approximating hitting prob for (14, 19, 57)
# (14, 19, 57): 0.5117863727429497
# (13, 20, 57): 0.5281751751462992
#
# Approximating hitting prob for (15, 10, 19)
# (15, 10, 19): 0.3227761872071942
# (14, 11, 19): 0.33330671215551505
#
# Approximating hitting prob for (15, 19, 20)
# (15, 19, 20): 0.41752587749506986
# (14, 20, 20): 0.3771242300341173
#
# Approximating hitting prob for (15, 19, 60)
# (15, 19, 60): 0.5187229526411115
# (14, 20, 60): 0.5145645278632247
#
# Approximating hitting prob for (15, 20, 21)
# (15, 20, 21): 0.42191353896908773
# (14, 21, 21): 0.38531294066601585
#
# Approximating hitting prob for (15, 20, 63)
# (15, 20, 63): 0.5214198904931256
# (14, 21, 63): 0.520847348354239
#
# Approximating hitting prob for (14, 22, 22)
# (14, 22, 22): 0.3933855470183209
# (13, 23, 22): 0.45463761378079576
#
# Approximating hitting prob for (14, 22, 66)
# (14, 22, 66): 0.5247417123561
# (13, 23, 66): 0.5402829230225349
#
# Approximating hitting prob for (14, 23, 23)
# (14, 23, 23): 0.39516544994925756
# (13, 24, 23): 0.45755678242531655
#
# Approximating hitting prob for (14, 23, 69)
# (14, 23, 69): 0.5262617179849073
# (13, 24, 69): 0.5450103253562159

# %%
import signal

class TimeoutException(Exception):
    """
    Custom exception for timeout.
    """
    pass

def sigalarmHandler(signum, frame):
    """
    Handler function to be called when SIGALRM is received.
    """
    # We get signal!
    raise TimeoutException()
