# %%
# %run 'game1_global.ipynb'
# %run 'game1_loser_analysis.ipynb'

# %% [markdown]
# # When is player 1 better off giving away $1?

# %%
betterGiving1 = findBetterGiving1(1,1000)
betterGiving1

# %%
exportStateProbs(DATA_DIR + 'game1_better_giving_1_memo_1-1000.csv', betterGiving1)

# %%
# retrieve probabilities from file
betterGiving1, given1 = readApproxBetterGiving1Probs(DATA_DIR + 'game1_better_giving_1_memo_1-100.csv')

# %%
betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
                                       filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv')
# Out:
# Approximating hitting prob for (11, 19, 48)
# (11, 19, 48): 0.5334260883826906
# (10, 19, 48): 0.5333426632228018
#
# Approximating hitting prob for (12, 21, 53)
# (12, 21, 53): 0.5340626283748265
# (11, 21, 53): 0.5334548685835285
#
# Approximating hitting prob for (12, 32, 42)
# (12, 32, 42): 0.5301153617677242
# (11, 32, 42): 0.5299467192997049
#
# Approximating hitting prob for (13, 22, 56)
# (13, 22, 56): 0.5328628830327213
# (12, 22, 56): 0.532734806781722
#
# Approximating hitting prob for (13, 23, 58)
# (13, 23, 58): 0.5343093271797525
# (12, 23, 58): 0.5335330764863161
#
# Approximating hitting prob for (13, 35, 46)
# (13, 35, 46): 0.5303291922468697
# (12, 35, 46): 0.5299937351500015
#
# Approximating hitting prob for (14, 24, 61)
# (14, 24, 61): 0.5334281050874531
# (13, 24, 61): 0.532844623278078
#
# Approximating hitting prob for (14, 25, 63)
# (14, 25, 63): 0.534598505539718
# (13, 25, 63): 0.5335740856592848
#
# Approximating hitting prob for (14, 38, 50)
# (14, 38, 50): 0.5306453312687435
# (13, 38, 50): 0.5300535494230575
#
# Approximating hitting prob for (15, 26, 66)
# (15, 26, 66): 0.5335384252806683
# (14, 26, 66): 0.532976559038264
#
# Approximating hitting prob for (15, 27, 68)
# (15, 27, 68): 0.5347937376379311
# (14, 27, 68): 0.5336038259570041
#
# Approximating hitting prob for (15, 40, 52)
# (15, 40, 52): 0.5298390830172897
# (14, 40, 52): 0.5294060634902246
#
# Approximating hitting prob for (15, 41, 54)
# (15, 41, 54): 0.530814252978444
# (14, 41, 54): 0.5300859465232839
#
# Approximating hitting prob for (16, 27, 69)
# (16, 27, 69): 0.5327214805171471
# (15, 27, 69): 0.5323471322790065
#
# Approximating hitting prob for (16, 28, 71)
# (16, 28, 71): 0.533984832978568
# (15, 28, 71): 0.5330636314503749
#
# Approximating hitting prob for (16, 29, 73)
# (16, 29, 73): 0.5349109988994238
# (15, 29, 73): 0.5336260136575318
#
# Approximating hitting prob for (16, 42, 54)
# (16, 42, 54): 0.528455476635441
# (15, 42, 54): 0.5285157285081951
#
# Approximating hitting prob for (16, 43, 56)
# (16, 43, 56): 0.5300165256608894
# (15, 43, 56): 0.5295344851774494
#
# Approximating hitting prob for (16, 44, 58)
# (16, 44, 58): 0.5309755142180325
# (15, 44, 58): 0.5301059314171186
#
# Approximating hitting prob for (17, 29, 74)
# (17, 29, 74): 0.5332717628242919
# (16, 29, 74): 0.5324865172144486
#
# Approximating hitting prob for (17, 30, 76)
# (17, 30, 76): 0.5341834675713876
# (16, 30, 76): 0.5331293350131605
#
# Approximating hitting prob for (17, 31, 78)
# (17, 31, 78): 0.535032026741298
# (16, 31, 78): 0.5336384909534596
#
# Approximating hitting prob for (17, 44, 56)
# (17, 44, 56): 0.5279972266134371
# (16, 44, 56): 0.5279422800090446
#
# Approximating hitting prob for (17, 45, 58)
# (17, 45, 58): 0.529004914693246
# (16, 45, 58): 0.528895160602941
#
# Approximating hitting prob for (17, 46, 60)
# (17, 46, 60): 0.5301804342251579
# (16, 46, 60): 0.5296194711867167
#
# Approximating hitting prob for (17, 47, 62)
# (17, 47, 62): 0.5311378673662993
# (16, 47, 62): 0.5301263625686753
#
# Approximating hitting prob for (18, 27, 71)
# (18, 27, 71): 0.525620501017532
# (17, 27, 71): 0.5254981980685945
#
# Approximating hitting prob for (18, 28, 73)
# (18, 28, 73): 0.5271004988262395
# (17, 28, 73): 0.5270411065910542
#
# Approximating hitting prob for (18, 31, 79)
# (18, 31, 79): 0.5335270635741508
# (17, 31, 79): 0.5326072076759126
#
# Approximating hitting prob for (18, 32, 81)
# (18, 32, 81): 0.5344121912790228
# (17, 32, 81): 0.5332080138741222
#
# Approximating hitting prob for (18, 33, 83)
# (18, 33, 83): 0.5351589143653502
# (17, 33, 83): 0.5336649245359243
#
# Approximating hitting prob for (18, 45, 56)
# (18, 45, 56): 0.5255722330999105
# (17, 45, 56): 0.5254786841463105
#
# Approximating hitting prob for (18, 47, 60)
# (18, 47, 60): 0.5284828625145415
# (17, 47, 60): 0.5281888889502253
#
# Approximating hitting prob for (18, 48, 62)
# (18, 48, 62): 0.5294526933438758
# (17, 48, 62): 0.5290045013080626
#
# Approximating hitting prob for (18, 49, 64)
# (18, 49, 64): 0.5304295920255223
# (17, 49, 64): 0.5297020995866109
#
# Approximating hitting prob for (18, 50, 66)
# (18, 50, 66): 0.5312826982045813
# (17, 50, 66): 0.5301457096165415
#
# Approximating hitting prob for (19, 20, 58)
# (19, 20, 58): 0.5076781471384154
# (18, 20, 58): 0.507459734940809
#
# Approximating hitting prob for (19, 32, 82)
# (19, 32, 82): 0.5327246501234508
# (18, 32, 82): 0.5320769507714677
#
# Approximating hitting prob for (19, 33, 84)
# (19, 33, 84): 0.5335489429772609
# (18, 33, 84): 0.532734806781722
#
# Approximating hitting prob for (19, 34, 86)
# (19, 34, 86): 0.5345634156030413
# (18, 34, 86): 0.5332648124986303
#
# Approximating hitting prob for (19, 35, 88)
# (19, 35, 88): 0.5345634156030413
# (18, 35, 88): 0.5332648124986303
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/659592125.py:18, in stricterFilter(candidates, timeLim, t, printOnGo, filename, continueFrom)
#      17 try:
# ---> 18     pLarge = LoserAnalysis(sLarge).getHittingProb()  # exact probs
#      19     pSmall = LoserAnalysis(sSmall).getHittingProb()
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:68, in LoserAnalysis.getHittingProb(self, asFloat, approx, t)
#      66     return Q(x, y, z, t)
# ---> 68 sol = self.solveEqns()
#      69 if sol:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:46, in LoserAnalysis.solveEqns(self, asFloat)
#      45 self.getEquations()
# ---> 46 sol = solve(self.equations, self.symbols)
#      47 return {s:float(p) for s, p in sol.items() if sol} if asFloat else sol
#
# File /usr/local/lib/python3.9/site-packages/sympy/solvers/solvers.py:1147, in solve(f, *symbols, **flags)
#    1146 else:
# -> 1147     linear, solution = _solve_system(f, symbols, **flags)
#    1148 assert type(solution) is list
#
# File /usr/local/lib/python3.9/site-packages/sympy/solvers/solvers.py:1799, in _solve_system(exprs, symbols, **flags)
#    1797     continue
# -> 1799 poly = g.as_poly(*symbols, extension=True)
#    1801 if poly is not None:
#
# File /usr/local/lib/python3.9/site-packages/sympy/core/expr.py:1102, in Expr.as_poly(self, *gens, **args)
#    1101 try:
# -> 1102     poly = Poly(self, *gens, **args)
#    1104     if not poly.is_Poly:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:182, in Poly.__new__(cls, rep, *gens, **args)
#     181 else:
# --> 182     return cls._from_expr(rep, opt)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:312, in Poly._from_expr(cls, rep, opt)
#     311 rep, opt = _dict_from_expr(rep, opt)
# --> 312 return cls._from_dict(rep, opt)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:261, in Poly._from_dict(cls, rep, opt)
#     259         rep[monom] = domain.convert(coeff)
# --> 261 return cls.new(DMP.from_dict(rep, level, domain), *gens)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polyclasses.py:279, in DMP.from_dict(cls, rep, lev, dom)
#     278 """Construct and instance of ``cls`` from a ``dict`` representation. """
# --> 279 return cls(dmp_from_dict(rep, lev, dom), dom, lev)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
#     [... skipping similar frames: dmp_from_dict at line 1012 (2958 times)]
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:998, in dmp_from_dict(f, u, K)
#     996 coeffs = {}
# --> 998 for monom, coeff in f.items():
#     999     head, tail = monom[0], monom[1:]
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# TimeoutException                          Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
#       2                                        filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv')
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/659592125.py:23, in stricterFilter(candidates, timeLim, t, printOnGo, filename, continueFrom)
#      21 except (TimeoutException, RecursionError):
#      22     print(f'Approximating hitting prob for {sLarge}')
# ---> 23     pLarge = LoserAnalysis(sLarge).getHittingProb(approx=True, t=t)
#      24     pSmall = LoserAnalysis(sSmall).getHittingProb(approx=True, t=t)
#      26 finally:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:66, in LoserAnalysis.getHittingProb(self, asFloat, approx, t)
#      64 if approx:
#      65     x, y, z = self.initState
# ---> 66     return Q(x, y, z, t)
#      68 sol = self.solveEqns()
#      69 if sol:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:31, in Q(x, y, z, t)
#      29 if x==0: return 1
#      30 if z*y==0: return 0
# ---> 31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
#      33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:31, in Q(x, y, z, t)
#      29 if x==0: return 1
#      30 if z*y==0: return 0
# ---> 31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
#      33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
#     [... skipping similar frames: memoize.<locals>.memodict.__call__ at line 8 (11 times), <genexpr> at line 33 (10 times), Q at line 33 (10 times), memoize.<locals>.memodict.__missing__ at line 11 (10 times)]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2027475117.py:12, in sigalarmHandler(signum, frame)
#       8 """
#       9 Handler function to be called when SIGALRM is received.
#      10 """
#      11 # We get signal!
# ---> 12 raise TimeoutException()
#
# TimeoutException:

# %%
betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
                                       filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv',
                                       continueFrom=(69,64,100))
# Out:
# Approximating hitting prob for (70, 12, 93)
# (70, 12, 93): 0.27064890356707977
# (69, 12, 93): 0.2704508979612977
#
# Approximating hitting prob for (70, 13, 95)
# (70, 13, 95): 0.273002814385276
# (69, 13, 95): 0.2728333555110289
#
# Approximating hitting prob for (70, 15, 99)
# (70, 15, 99): 0.2777183843625525
# (69, 15, 99): 0.27732957441332723
#
# Approximating hitting prob for (70, 30, 84)
# (70, 30, 84): 0.2928672871530125
# (69, 30, 84): 0.29290071879804375
#
# Approximating hitting prob for (70, 50, 94)
# (70, 50, 94): 0.32695735265836573
# (69, 50, 94): 0.3267132634013896
#
# Approximating hitting prob for (70, 58, 98)
# (70, 58, 98): 0.3430616778838396
# (69, 58, 98): 0.3428394039934912
#
# Approximating hitting prob for (70, 60, 99)
# (70, 60, 99): 0.34560612414415176
# (69, 60, 99): 0.34492499438010804
#
# Approximating hitting prob for (70, 84, 90)
# (70, 84, 90): 0.4148018936715927
# (69, 84, 90): 0.41468720846314083
#
# Approximating hitting prob for (71, 12, 94)
# (71, 12, 94): 0.27043453644878807
# (70, 12, 94): 0.2702550831661171
#
# Approximating hitting prob for (71, 15, 100)
# (71, 15, 100): 0.2774240055525448
# (70, 15, 100): 0.27714908068396565
#
# Approximating hitting prob for (71, 36, 88)
# (71, 36, 88): 0.3107284046458855
# (70, 36, 88): 0.3107029569244443
#
# Approximating hitting prob for (71, 44, 92)
# (71, 44, 92): 0.31946810865446534
# (70, 44, 92): 0.31933447137280896
#
# Approximating hitting prob for (71, 52, 96)
# (71, 52, 96): 0.3287350571698488
# (70, 52, 96): 0.32848900976647166
#
# Approximating hitting prob for (71, 60, 100)
# (71, 60, 100): 0.3432269284144038
# (70, 60, 100): 0.3428263666917539
#
# Approximating hitting prob for (72, 14, 99)
# (72, 14, 99): 0.27369224353294386
# (71, 14, 99): 0.27347335165357634
#
# Approximating hitting prob for (72, 40, 91)
# (72, 40, 91): 0.3129742549703007
# (71, 40, 91): 0.31282979281170153
#
# Approximating hitting prob for (72, 46, 94)
# (72, 46, 94): 0.32065055730266634
# (71, 46, 94): 0.32060860453920875
#
# Approximating hitting prob for (72, 50, 96)
# (72, 50, 96): 0.32548552599084296
# (71, 50, 96): 0.32522123422559995
#
# Approximating hitting prob for (72, 54, 98)
# (72, 54, 98): 0.33015250293768666
# (71, 54, 98): 0.3299310590778092
#
# Approximating hitting prob for (73, 11, 94)
# (73, 11, 94): 0.26568088778907833
# (72, 11, 94): 0.26555372470314254
#
# Approximating hitting prob for (73, 13, 98)
# (73, 13, 98): 0.2712824779940791
# (72, 13, 98): 0.27092732614422377
#
# Approximating hitting prob for (73, 14, 100)
# (73, 14, 100): 0.2735392177539206
# (72, 14, 100): 0.2733296833190661
#
# Approximating hitting prob for (73, 26, 85)
# (73, 26, 85): 0.2838182327188731
# (72, 26, 85): 0.2838382526274032
#
# Approximating hitting prob for (73, 40, 92)
# (73, 40, 92): 0.31265646156970867
# (72, 40, 92): 0.31256600858492634
#
# Approximating hitting prob for (73, 44, 94)
# (73, 44, 94): 0.31905281367702304
# (72, 44, 94): 0.31898130581150774
#
# Approximating hitting prob for (74, 12, 97)
# (74, 12, 97): 0.26803823241416097
# (73, 12, 97): 0.2678146488650772
#
# Approximating hitting prob for (74, 13, 99)
# (74, 13, 99): 0.27106341315623816
# (73, 13, 99): 0.2708043750088058
#
# Approximating hitting prob for (74, 30, 88)
# (74, 30, 88): 0.29121346643802504
# (73, 30, 88): 0.2911904861374854
#
# Approximating hitting prob for (74, 40, 93)
# (74, 40, 93): 0.3124715276947375
# (73, 40, 93): 0.3123265733297223
#
# Approximating hitting prob for (74, 46, 96)
# (74, 46, 96): 0.3194592906289733
# (73, 46, 96): 0.31936096416339166
#
# Approximating hitting prob for (74, 52, 99)
# (74, 52, 99): 0.32609715069378836
# (73, 52, 99): 0.32593271890358366
#
# Approximating hitting prob for (74, 54, 100)
# (74, 54, 100): 0.3285392810102394
# (73, 54, 100): 0.32834877261967127
#
# Approximating hitting prob for (75, 13, 100)
# (75, 13, 100): 0.2708561821230972
# (74, 13, 100): 0.27060467983388525
#
# Approximating hitting prob for (75, 38, 93)
# (75, 38, 93): 0.3107255922584125
# (74, 38, 93): 0.3106856959891582
#
# Approximating hitting prob for (75, 40, 94)
# (75, 40, 94): 0.31219750777533284
# (74, 40, 94): 0.31212211416489793
#
# Approximating hitting prob for (75, 48, 98)
# (75, 48, 98): 0.3206660566987458
# (74, 48, 98): 0.3206193374288369
#
# Approximating hitting prob for (75, 52, 100)
# (75, 52, 100): 0.32543894655115896
# (74, 52, 100): 0.3251891291627604
#
# Approximating hitting prob for (76, 42, 96)
# (76, 42, 96): 0.31283229353690856
# (75, 42, 96): 0.31269685409230785
#
# Approximating hitting prob for (77, 42, 97)
# (77, 42, 97): 0.31263411481005815
# (76, 42, 97): 0.3124896740010894
#
# Approximating hitting prob for (78, 42, 98)
# (78, 42, 98): 0.312441399741017
# (77, 42, 98): 0.3119828040723916
#
# Approximating hitting prob for (79, 32, 94)
# (79, 32, 94): 0.2912337154122105
# (78, 32, 94): 0.2911642829888588
#
# Approximating hitting prob for (79, 40, 98)
# (79, 40, 98): 0.31073467566545016
# (78, 40, 98): 0.31068391480047436
#
# Approximating hitting prob for (79, 42, 99)
# (79, 42, 99): 0.3121670959474713
# (78, 42, 99): 0.3120607193357822
#
# Approximating hitting prob for (79, 44, 100)
# (79, 44, 100): 0.3130463381703828
# (78, 44, 100): 0.3128490513416133
#
# Approximating hitting prob for (82, 34, 98)
# (82, 34, 98): 0.2917812876569657
# (81, 34, 98): 0.29172992113254753
#
# Approximating hitting prob for (84, 30, 98)
# (84, 30, 98): 0.2839368557613289
# (83, 30, 98): 0.2838357734914572
#
# Approximating hitting prob for (84, 34, 100)
# (84, 34, 100): 0.29123192191006453
# (83, 34, 100): 0.2911447291167216
#
# Approximating hitting prob for (93, 47, 62)
# (93, 47, 62): 0.2078449082948937
# (92, 47, 62): 0.20783817692579917
#
# Approximating hitting prob for (93, 47, 98)
# (93, 47, 98): 0.3020413154785515
# (92, 47, 98): 0.3020379983481061
#
# Approximating hitting prob for (95, 48, 100)
# (95, 48, 100): 0.30201302025080573
# (94, 48, 100): 0.30196433138324996
#
# Approximating hitting prob for (99, 50, 66)
# (99, 50, 66): 0.2078419114332157
# (98, 50, 66): 0.2078180397808808
#
# Approximating hitting prob for (100, 51, 67)
# (100, 51, 67): 0.2080190772886974
# (99, 51, 67): 0.20801576587712575

# %%
class TimeoutException(Exception):
    """
    Custom exception for timeout.
    """
    pass

def sigalarmHandler(signum, frame):
    """
    Handler function to be called when SIGALRM is received.
    """
    # We get signal!
    raise TimeoutException()

# %% [markdown]
# ## When is player 1 better off giving away $1 to another player?

# %%
betterGiving1ToAnother = findBetterGiving1(1,100, t=10, giveToAnother=True)
betterGiving1ToAnother
# Out:
# {(1, 5, 5): 0.5004434876119833,
#  (2, 4, 5): 0.5015168645690443,
#  (1, 6, 6): 0.506093654740131,
#  (2, 5, 6): 0.5184847144955884,
#  (1, 7, 7): 0.5131205254322682,
#  (2, 6, 7): 0.5396071019936831,
#  (1, 8, 8): 0.5177187986883774,
#  (2, 7, 8): 0.553386673567715,
#  (1, 9, 9): 0.5198030383135193,
#  (2, 8, 9): 0.5596511014686955,
#  (1, 10, 10): 0.521353326527545,
#  (2, 9, 10): 0.5643071756348541,
#  (1, 11, 11): 0.5225738105217701,
#  (2, 10, 11): 0.5679767313216567,
#  (1, 12, 12): 0.5237380978085997,
#  (2, 11, 12): 0.5714793837797846,
#  (1, 12, 36): 0.6316713165390184,
#  (2, 11, 36): 0.6317622599451304,
#  (1, 13, 13): 0.5248276325593998,
#  (2, 12, 13): 0.5747622273980084,
#  (1, 13, 39): 0.6325682808186844,
#  (2, 12, 39): 0.6347403712118326,
#  (1, 14, 14): 0.5256858644409728,
#  (2, 13, 14): 0.57733900685236,
#  (1, 14, 42): 0.6333982655030145,
#  (2, 13, 42): 0.6366529115385103,
#  (1, 15, 15): 0.5268432387720368,
#  (2, 14, 15): 0.5808387485922709,
#  (1, 15, 45): 0.63421194355006,
#  (2, 14, 45): 0.6395029512036614,
#  (1, 16, 16): 0.5279858610539553,
#  (2, 15, 16): 0.5842379051719758,
#  (1, 16, 48): 0.635051999980948,
#  (2, 15, 48): 0.6419747628823096,
#  (1, 17, 17): 0.5283821156475977,
#  (2, 16, 17): 0.5854285708426477,
#  (1, 17, 51): 0.6353974162348219,
#  (2, 16, 51): 0.6431331129655032,
#  (1, 18, 18): 0.5286972339709394,
#  (2, 17, 18): 0.586367542078401,
#  (1, 18, 54): 0.635696343688081,
#  (2, 17, 54): 0.6438519942124338,
#  (1, 19, 19): 0.5290239620908059,
#  (2, 18, 19): 0.5873462049262054,
#  (1, 19, 57): 0.6359734242165406,
#  (2, 18, 57): 0.644798126476528,
#  (1, 20, 20): 0.5292680655049197,
#  (4, 25, 25): 0.5079278041330082,
#  (5, 24, 25): 0.5569707103687193,
#  (4, 25, 75): 0.619438130170494,
#  (5, 24, 75): 0.6214497341455826,
#  (4, 26, 26): 0.5085600915129808,
#  (5, 25, 26): 0.5597136488340192,
#  (4, 26, 78): 0.6200700371725177,
#  (5, 25, 78): 0.6240545788772883,
#  (4, 27, 27): 0.5094988642906738,
#  (5, 26, 27): 0.5606478239999831,
#  (4, 27, 81): 0.6205027253583889,
#  (5, 26, 81): 0.6261406211631442,
#  (4, 28, 28): 0.5131205254322682,
#  (5, 27, 28): 0.5612278672955936,
#  (4, 28, 84): 0.6225665568796677,
#  (5, 27, 84): 0.6265492628473809,
#  (4, 29, 29): 0.5143106453432743,
#  (5, 28, 29): 0.5613912478936984,
#  (4, 29, 87): 0.6242289738977375,
#  (5, 28, 87): 0.626946129353376,
#  (4, 30, 30): 0.5156899950147334,
#  (5, 29, 30): 0.5637915319797965,
#  (4, 30, 90): 0.6246810778971702,
#  (5, 29, 90): 0.6272628022648563,
#  (4, 31, 31): 0.5166124611551424,
#  (5, 30, 31): 0.566074510814112,
#  (4, 31, 93): 0.6255271046080374,
#  (5, 30, 93): 0.6294413425449626,
#  (4, 32, 32): 0.5177187986883774,
#  (5, 31, 32): 0.5665562016026944,
#  (4, 32, 96): 0.6264351494627344,
#  (5, 31, 96): 0.6310857660322359,
#  (4, 33, 33): 0.5180689779356974,
#  (5, 32, 33): 0.5674294005296449,
#  (4, 33, 99): 0.626903626252138,
#  (5, 32, 99): 0.6314149087251689,
#  (4, 34, 34): 0.5183972606437027,
#  (5, 33, 34): 0.5680504584910413,
#  (4, 35, 35): 0.5188368121708242,
#  ...}

# %%
exportStateProbs(DATA_DIR + 'game1_better_giving_1_to_another_memo_1-100.csv', betterGiving1ToAnother)

# %%
betterGiving1ToAnother, given1ToAnother = readApproxBetterGiving1Probs(DATA_DIR + 'game1_better_giving_1_to_another_memo_1-100.csv')

# %%
betterGiving1ToAnother, given1ToAnother = stricterFilter(betterGiving1ToAnother, printOnGo=True,
                                                         filename=DATA_DIR + 'game1_better_giving_1_to_another_stricter_1-100.csv',
                                                         giveToAnother=True, continueFrom=(94,69,100))
# Out:
# Approximating hitting prob for (94, 14, 70)
# (94, 14, 70): 0.12199766189749872
# (93, 15, 70): 0.12582825175468762
#
# Approximating hitting prob for (95, 35, 69)
# (95, 35, 69): 0.18867062339516005
# (94, 36, 69): 0.19015201339859886
#
# Approximating hitting prob for (95, 69, 70)
# (95, 69, 70): 0.2332703712081712
# (94, 70, 70): 0.19129850966025716
#
# Approximating hitting prob for (95, 70, 71)
# (95, 70, 71): 0.2344236159041961
# (94, 71, 71): 0.20072496592947195
#
# Approximating hitting prob for (95, 36, 71)
# (95, 36, 71): 0.1914022748802718
# (94, 37, 71): 0.19347487091860452
#
# Approximating hitting prob for (95, 71, 72)
# (95, 71, 72): 0.24042629485319789
# (94, 72, 72): 0.20109611251833345
#
# Approximating hitting prob for (95, 72, 73)
# (95, 72, 73): 0.2437481549545768
# (94, 73, 73): 0.20184786255081485
#
# Approximating hitting prob for (94, 74, 74)
# (94, 74, 74): 0.20305339686512744
# (93, 75, 74): 0.2470213541339307
#
# Approximating hitting prob for (95, 50, 74)
# (95, 50, 74): 0.21986646048123645
# (94, 51, 74): 0.22098494588713632
#
# Approximating hitting prob for (95, 74, 75)
# (95, 74, 75): 0.24568953334896537
# (94, 75, 75): 0.20348788322119368
#
# Approximating hitting prob for (94, 76, 76)
# (94, 76, 76): 0.20498970110394144
# (93, 77, 76): 0.24882636530464797
#
# Approximating hitting prob for (94, 77, 77)
# (94, 77, 77): 0.20560868125602513
# (93, 78, 77): 0.25075419250540293
#
# Approximating hitting prob for (95, 26, 77)
# (95, 26, 77): 0.18205099592830623
# (94, 27, 77): 0.18361942805694823
#
# Approximating hitting prob for (94, 78, 78)
# (94, 78, 78): 0.20593009215715108
# (93, 79, 78): 0.2537821227032768
#
# Approximating hitting prob for (94, 79, 79)
# (94, 79, 79): 0.20947988440450205
# (93, 80, 79): 0.25506299280350264
#
# Approximating hitting prob for (95, 20, 79)
# (95, 20, 79): 0.1734487923629512
# (94, 21, 79): 0.17471685874186035
#
# Approximating hitting prob for (94, 80, 80)
# (94, 80, 80): 0.2100150814543644
# (93, 81, 80): 0.2562126601686782
#
# Approximating hitting prob for (95, 27, 80)
# (95, 27, 80): 0.18495170348709067
# (94, 28, 80): 0.18820121796669978
#
# Approximating hitting prob for (95, 80, 81)
# (95, 80, 81): 0.2539608236723228
# (94, 81, 81): 0.2117053332725115
#
# Approximating hitting prob for (94, 82, 82)
# (94, 82, 82): 0.21217961930964524
# (93, 83, 82): 0.2589635803382282
#
# Approximating hitting prob for (94, 83, 83)
# (94, 83, 83): 0.214438515056758
# (93, 84, 83): 0.25962668387213633
#
# Approximating hitting prob for (95, 28, 83)
# (95, 28, 83): 0.19080857620922212
# (94, 29, 83): 0.19257860031521945
#
# Approximating hitting prob for (95, 56, 83)
# (95, 56, 83): 0.23249514521289863
# (94, 57, 83): 0.23617485573634425
#
# Approximating hitting prob for (95, 83, 84)
# (95, 83, 84): 0.25805381999405524
# (94, 84, 84): 0.21498337075211593
#
# Approximating hitting prob for (95, 84, 85)
# (95, 84, 85): 0.2590931802233722
# (94, 85, 85): 0.21577642178122391
#
# Approximating hitting prob for (94, 86, 86)
# (94, 86, 86): 0.21654694344311468
# (93, 87, 86): 0.26247917438893675
#
# Approximating hitting prob for (95, 29, 86)
# (95, 29, 86): 0.19705142972478626
# (94, 30, 86): 0.19806121360669326
#
# Approximating hitting prob for (94, 87, 87)
# (94, 87, 87): 0.21756807439339035
# (93, 88, 87): 0.2634033952349806
#
# Approximating hitting prob for (95, 44, 87)
# (95, 44, 87): 0.21843467809032127
# (94, 45, 87): 0.22055982550682598
#
# Approximating hitting prob for (95, 87, 88)
# (95, 87, 88): 0.2615892648524263
# (94, 88, 88): 0.2186279702391084
#
# Approximating hitting prob for (95, 88, 89)
# (95, 88, 89): 0.26257310070489653
# (94, 89, 89): 0.2194161834474195
#
# Approximating hitting prob for (95, 45, 89)
# (95, 45, 89): 0.22118282562763747
# (94, 46, 89): 0.2229896403567921
#
# Approximating hitting prob for (94, 90, 90)
# (94, 90, 90): 0.2200874463506165
# (93, 91, 90): 0.2656128377485115
#
# Approximating hitting prob for (94, 91, 91)
# (94, 91, 91): 0.22086688854172085
# (93, 92, 91): 0.26614593131571407
#
# Approximating hitting prob for (95, 46, 91)
# (95, 46, 91): 0.2229917232592187
# (94, 47, 91): 0.23585312696789199
#
# Approximating hitting prob for (95, 91, 92)
# (95, 91, 92): 0.264995401062543
# (94, 92, 92): 0.22138635945102617
#
# Approximating hitting prob for (95, 62, 92)
# (95, 62, 92): 0.24190466992054416
# (94, 63, 92): 0.2500361705129969
#
# Approximating hitting prob for (95, 92, 93)
# (95, 92, 93): 0.265646406198217
# (94, 93, 93): 0.22188823678431566
#
# Approximating hitting prob for (95, 24, 95)
# (95, 24, 95): 0.25651999669878395
# (94, 25, 95): 0.25863209998753584
#
# Approximating hitting prob for (95, 32, 95)
# (95, 32, 95): 0.2744544164118116
# (94, 33, 95): 0.2781777313165581
#
# Approximating hitting prob for (95, 48, 95)
# (95, 48, 95): 0.29551028808129703
# (94, 49, 95): 0.29970703419367756
#
# Approximating hitting prob for (95, 95, 96)
# (95, 95, 96): 0.3890503160488285
# (94, 96, 96): 0.35596629702485466
#
# Approximating hitting prob for (95, 96, 97)
# (95, 96, 97): 0.4003785106293141
# (94, 97, 97): 0.3562450174617211
#
# Approximating hitting prob for (95, 14, 97)
# (95, 14, 97): 0.24640815710601124
# (94, 15, 97): 0.24764464298806912
#
# Approximating hitting prob for (94, 98, 98)
# (94, 98, 98): 0.35663619151636006
# (93, 99, 98): 0.40183843661655944
#
# Approximating hitting prob for (95, 33, 98)
# (95, 33, 98): 0.2787556186392362
# (94, 34, 98): 0.2799184363479494
#
# Approximating hitting prob for (95, 98, 99)
# (95, 98, 99): 0.4009980378672339
# (94, 99, 99): 0.35698895087346605
#
# Approximating hitting prob for (95, 25, 99)
# (95, 25, 99): 0.25915715059595595
# (94, 26, 99): 0.2605481738936005
#
# Approximating hitting prob for (94, 60, 100)
# (94, 60, 100): 0.30902153115261727
# (93, 61, 100): 0.3146723322625174
#
# Approximating hitting prob for (94, 100, 100)
# (94, 100, 100): 0.3573903858070959
# (93, 101, 100): 0.40275617598817365
#
# Approximating hitting prob for (95, 2, 33)
# (95, 2, 33): 0.059077520122208536
# (94, 3, 33): 0.0599142073759234
#
# Approximating hitting prob for (96, 1, 34)
# (96, 1, 34): 0.061740434039459786
# (95, 2, 34): 0.06154226391178393
#
# Approximating hitting prob for (96, 1, 99)
# (96, 1, 99): 0.24917313643545344
# (95, 2, 99): 0.24763525000413578
#
# Approximating hitting prob for (96, 1, 100)
# (96, 1, 100): 0.2492516979652368
# (95, 2, 100): 0.24780037966845572
#
# Approximating hitting prob for (96, 2, 34)
# (96, 2, 34): 0.061404212946109225
# (95, 3, 34): 0.06043843333822583
#
# Approximating hitting prob for (96, 3, 35)
# (96, 3, 35): 0.06269471133100697
# (95, 4, 35): 0.062223941424681246
#
# Approximating hitting prob for (96, 4, 5)
# (96, 4, 5): 0.003200662741110017
# (95, 5, 5): 0.0026933564974217627
#
# Approximating hitting prob for (96, 4, 36)
# (96, 4, 36): 0.06421772504419952
# (95, 5, 36): 0.06417626122828489
#
# Approximating hitting prob for (96, 5, 37)
# (96, 5, 37): 0.06628802522424558
# (95, 6, 37): 0.06580165695117073
#
# Approximating hitting prob for (96, 6, 38)
# (96, 6, 38): 0.06792353123088281
# (95, 7, 38): 0.0679083415431698
#
# Approximating hitting prob for (96, 4, 7)
# (96, 4, 7): 0.005442908116428748
# (95, 5, 7): 0.006167808272656473
#
# Approximating hitting prob for (96, 7, 8)
# (96, 7, 8): 0.010242375779216889
# (95, 8, 8): 0.007731153149394155
#
# Approximating hitting prob for (96, 7, 16)
# (96, 7, 16): 0.021635937235983792
# (95, 8, 16): 0.020934150869567222
#
# Approximating hitting prob for (96, 8, 9)
# (96, 8, 9): 0.01164755939493458
# (95, 9, 9): 0.00864968303561854
#
# Approximating hitting prob for (96, 8, 18)
# (96, 8, 18): 0.02531145532798519
# (95, 9, 18): 0.023639376442660787
#
# Approximating hitting prob for (96, 8, 27)
# (96, 8, 27): 0.0381137345760788
# (95, 9, 27): 0.03751252223817501
#
# Approximating hitting prob for (96, 9, 10)
# (96, 9, 10): 0.013811718720860032
# (95, 10, 10): 0.01129643784044451
#
# Approximating hitting prob for (96, 9, 20)
# (96, 9, 20): 0.028035388022235274
# (95, 10, 20): 0.02602059792648416
#
# Approximating hitting prob for (96, 10, 11)
# (96, 10, 11): 0.015802662697158788
# (95, 11, 11): 0.01280756719539515
#
# Approximating hitting prob for (96, 10, 33)
# (96, 10, 33): 0.06641862194691837
# (95, 11, 33): 0.06493218512429579
#
# Approximating hitting prob for (96, 10, 49)
# (96, 10, 49): 0.08718583443869467
# (95, 11, 49): 0.08713374534307562
#
# Approximating hitting prob for (96, 11, 24)
# (96, 11, 24): 0.03804325619597542
# (95, 12, 24): 0.036947618343856674
#
# Approximating hitting prob for (96, 11, 43)
# (96, 11, 43): 0.08142422638656188
# (95, 12, 43): 0.08119987788158721
#
# Approximating hitting prob for (96, 12, 13)
# (96, 12, 13): 0.02290787790060354
# (95, 13, 13): 0.019288345833262853
#
# Approximating hitting prob for (96, 12, 26)
# (96, 12, 26): 0.04208840317592011
# (95, 13, 26): 0.03958102300557511
#
# Approximating hitting prob for (96, 12, 39)
# (96, 12, 39): 0.07768127907200008
# (95, 13, 39): 0.0760569089557999
#
# Approximating hitting prob for (96, 12, 52)
# (96, 12, 52): 0.09074822441923637
# (95, 13, 52): 0.0899566619045916
#
# Approximating hitting prob for (96, 13, 14)
# (96, 13, 14): 0.02646546150065109
# (95, 14, 14): 0.024259634150388416
#
# Approximating hitting prob for (96, 14, 15)
# (96, 14, 15): 0.02986282049913022
# (95, 15, 15): 0.02494136300070882
#
# Approximating hitting prob for (96, 14, 30)
# (96, 14, 30): 0.05978074003601493
# (95, 15, 30): 0.057217297310404265
#
# Approximating hitting prob for (96, 14, 45)
# (96, 14, 45): 0.08666996097691078
# (95, 15, 45): 0.08442849102420581
#
# Approximating hitting prob for (96, 14, 46)
# (96, 14, 46): 0.0886594183328675
# (95, 15, 46): 0.08840875156312826
#
# Approximating hitting prob for (96, 14, 75)
# (96, 14, 75): 0.12781845058879196
# (95, 15, 75): 0.12767384405348928
#
# Approximating hitting prob for (95, 16, 16)
# (95, 16, 16): 0.03155990453558046
# (94, 17, 16): 0.04415280384411724
#
# Approximating hitting prob for (95, 16, 32)
# (95, 16, 32): 0.07213631665621083
# (94, 17, 32): 0.077178755597104
#
# Approximating hitting prob for (95, 17, 17)
# (95, 17, 17): 0.03208791899374964
# (94, 18, 17): 0.045872475624250626
#
# Approximating hitting prob for (95, 17, 34)
# (95, 17, 34): 0.07351854467362422
# (94, 18, 34): 0.07932490024303047
#
# Approximating hitting prob for (95, 17, 51)
# (95, 17, 51): 0.10269948010303089
# (94, 18, 51): 0.10789341215627613
#
# Approximating hitting prob for (96, 9, 17)
# (96, 9, 17): 0.025361803401846423
# (95, 10, 17): 0.02634788624068475
#
# Approximating hitting prob for (96, 17, 18)
# (96, 17, 18): 0.04533321517781299
# (95, 18, 18): 0.03335240863721765
#
# Approximating hitting prob for (96, 17, 36)
# (96, 17, 36): 0.07939422832563352
# (95, 18, 36): 0.07503544334883257
#
# Approximating hitting prob for (96, 17, 54)
# (96, 17, 54): 0.10729572403249758
# (95, 18, 54): 0.10694869551798736
#
# Approximating hitting prob for (96, 17, 72)
# (96, 17, 72): 0.12913611513131282
# (95, 18, 72): 0.12903257771491594
#
# Approximating hitting prob for (96, 18, 19)
# (96, 18, 19): 0.046911052730503076
# (95, 19, 19): 0.03516819571864877
#
# Approximating hitting prob for (95, 20, 20)
# (95, 20, 20): 0.036492994994913784
# (94, 21, 20): 0.051732057263508054
#
# Approximating hitting prob for (95, 20, 40)
# (95, 20, 40): 0.09525959659747035
# (94, 21, 40): 0.10381494681535751
#
# Approximating hitting prob for (95, 20, 60)
# (95, 20, 60): 0.1192015229070842
# (94, 21, 60): 0.12498081644837129
#
# Approximating hitting prob for (95, 21, 21)
# (95, 21, 21): 0.03858095412108708
# (94, 22, 21): 0.053759508300055714
#
# Approximating hitting prob for (95, 21, 42)
# (95, 21, 42): 0.09671505033971611
# (94, 22, 42): 0.10624857326986191
#
# Approximating hitting prob for (95, 21, 63)
# (95, 21, 63): 0.12249484639032655
# (94, 22, 63): 0.1290329488875611
#
# Approximating hitting prob for (95, 21, 84)
# (95, 21, 84): 0.175891705648081
# (94, 22, 84): 0.1840482824855334
#
# Approximating hitting prob for (95, 11, 22)
# (95, 11, 22): 0.03362791065290646
# (94, 12, 22): 0.038023799961388646
#
# Approximating hitting prob for (95, 22, 22)
# (95, 22, 22): 0.040756155807793695
# (94, 23, 22): 0.05611892043872288
#
# Approximating hitting prob for (95, 22, 44)
# (95, 22, 44): 0.09991967172467835
# (94, 23, 44): 0.10923732436535823
#
# Approximating hitting prob for (95, 22, 66)
# (95, 22, 66): 0.12588692203805912
# (94, 23, 66): 0.1336475050239432
#
# Approximating hitting prob for (95, 22, 68)
# (95, 22, 68): 0.1312703693601131
# (94, 23, 68): 0.13211311425946082
#
# Approximating hitting prob for (95, 23, 23)
# (95, 23, 23): 0.0417815995277706
# (94, 24, 23): 0.06468533188895627
#
# Approximating hitting prob for (95, 23, 46)
# (95, 23, 46): 0.10160709798401157
# (94, 24, 46): 0.11360955351544468
#
# Approximating hitting prob for (95, 23, 54)
# (95, 23, 54): 0.12070216189659892
# (94, 24, 54): 0.12226791633864414
#
# Approximating hitting prob for (95, 23, 69)
# (95, 23, 69): 0.12769155714261107
# (94, 24, 69): 0.13698752442510845
#
# Approximating hitting prob for (95, 23, 70)
# (95, 23, 70): 0.13291469110895257
# (94, 24, 70): 0.1606035138377979
#
# Approximating hitting prob for (96, 12, 23)
# (96, 12, 23): 0.03796279609670902
# (95, 13, 23): 0.04041710029903066
#
# Approximating hitting prob for (96, 23, 48)
# (96, 23, 48): 0.11123270111777418
# (95, 24, 48): 0.10686727011849852
#
# Approximating hitting prob for (96, 24, 25)
# (96, 24, 25): 0.07259514536338389
# (95, 25, 25): 0.059472536551322376
#
# Approximating hitting prob for (96, 24, 50)
# (96, 24, 50): 0.11593380929506036
# (95, 25, 50): 0.10905281630411172
#
# Approximating hitting prob for (96, 24, 75)
# (96, 24, 75): 0.1772188584928677
# (95, 25, 75): 0.17349225230375445
#
# Approximating hitting prob for (96, 24, 100)
# (96, 24, 100): 0.2587392395633792
# (95, 25, 100): 0.2574621931480659
#
# Approximating hitting prob for (95, 26, 26)
# (95, 26, 26): 0.061010037695611787
# (94, 27, 26): 0.07697136732393767
#
# Approximating hitting prob for (95, 26, 39)
# (95, 26, 39): 0.10059177906212417
# (94, 27, 39): 0.1036353979545797
#
# Approximating hitting prob for (95, 26, 52)
# (95, 26, 52): 0.11442067723269934
# (94, 27, 52): 0.12375445327652619
#
# Approximating hitting prob for (95, 26, 73)
# (95, 26, 73): 0.17629779303496698
# (94, 27, 73): 0.1774401953564404
#
# Approximating hitting prob for (95, 26, 74)
# (95, 26, 74): 0.17908033821793523
# (94, 27, 74): 0.18033133365187007
#
# Approximating hitting prob for (95, 26, 78)
# (95, 26, 78): 0.17601623433387906
# (94, 27, 78): 0.18453371169765284
#
# Approximating hitting prob for (96, 9, 26)
# (96, 9, 26): 0.03843242900101902
# (95, 10, 26): 0.040807724721393636
#
# Approximating hitting prob for (96, 26, 27)
# (96, 26, 27): 0.07578771667380911
# (95, 27, 27): 0.062275564901247686
#
# Approximating hitting prob for (96, 26, 54)
# (96, 26, 54): 0.12288111045262705
# (95, 27, 54): 0.11579586392679464
#
# Approximating hitting prob for (96, 26, 58)
# (96, 26, 58): 0.12966202801811774
# (95, 27, 58): 0.12967144312333137
#
# Approximating hitting prob for (96, 26, 74)
# (96, 26, 74): 0.17827657233002836
# (95, 27, 74): 0.17773779022925362
#
# Approximating hitting prob for (96, 26, 76)
# (96, 26, 76): 0.18078861568292956
# (95, 27, 76): 0.18072744149439446
#
# Approximating hitting prob for (96, 26, 81)
# (96, 26, 81): 0.1840414754075783
# (95, 27, 81): 0.17832874280411978
#
# Approximating hitting prob for (96, 27, 28)
# (96, 27, 28): 0.077944609866627
# (95, 28, 28): 0.06465081765651783
#
# Approximating hitting prob for (96, 27, 56)
# (96, 27, 56): 0.12618878474929338
# (95, 28, 56): 0.11924655794869511
#
# Approximating hitting prob for (96, 27, 75)
# (96, 27, 75): 0.17965980165705187
# (95, 28, 75): 0.17917691295121632
#
# Approximating hitting prob for (96, 27, 84)
# (96, 27, 84): 0.19001443832133233
# (95, 28, 84): 0.18450695471078607
#
# Approximating hitting prob for (96, 28, 29)
# (96, 28, 29): 0.08044160650809176
# (95, 29, 29): 0.06778840992734822
#
# Approximating hitting prob for (96, 28, 58)
# (96, 28, 58): 0.12990433964083942
# (95, 29, 58): 0.12320930032264842
#
# Approximating hitting prob for (96, 28, 87)
# (96, 28, 87): 0.19598420088359
# (95, 29, 87): 0.19058847604152562
#
# Approximating hitting prob for (96, 10, 29)
# (96, 10, 29): 0.05118672854686438
# (95, 11, 29): 0.05277091512183363
#
# Approximating hitting prob for (95, 30, 30)
# (95, 30, 30): 0.06951129696386722
# (94, 31, 30): 0.0879420117682146
#
# Approximating hitting prob for (95, 30, 60)
# (95, 30, 60): 0.12469968332708194
# (94, 31, 60): 0.13506469136084726
#
# Approximating hitting prob for (95, 30, 61)
# (95, 30, 61): 0.1341825181183362
# (94, 31, 61): 0.13548958818999768
#
# Approximating hitting prob for (95, 30, 77)
# (95, 30, 77): 0.1824831848535299
# (94, 31, 77): 0.18383643336098357
#
# Approximating hitting prob for (95, 30, 90)
# (95, 30, 90): 0.1947383379919065
# (94, 31, 90): 0.20381763500935834
#
# Approximating hitting prob for (95, 31, 31)
# (95, 31, 31): 0.07115605689346938
# (94, 32, 31): 0.10330602158730161
#
# Approximating hitting prob for (95, 31, 62)
# (95, 31, 62): 0.1261554356882558
# (94, 32, 62): 0.17031253330814947
#
# Approximating hitting prob for (95, 31, 78)
# (95, 31, 78): 0.18388105787725398
# (94, 32, 78): 0.19803613669264528
#
# Approximating hitting prob for (95, 31, 93)
# (95, 31, 93): 0.19829044256067538
# (94, 32, 93): 0.2184856293436793
#
# Approximating hitting prob for (95, 32, 32)
# (95, 32, 32): 0.09698019345807911
# (94, 33, 32): 0.1143451133974804
#
# Approximating hitting prob for (96, 11, 32)
# (96, 11, 32): 0.0665183947820535
# (95, 12, 32): 0.06759453403582076
#
# Approximating hitting prob for (96, 32, 33)
# (96, 32, 33): 0.11286745571298938
# (95, 33, 33): 0.09761083322085083
#
# Approximating hitting prob for (96, 32, 66)
# (96, 32, 66): 0.1830539426141445
# (95, 33, 66): 0.1771189361274106
#
# Approximating hitting prob for (96, 32, 99)
# (96, 32, 99): 0.2758019934709082
# (95, 33, 99): 0.27184905368915135
#
# Approximating hitting prob for (95, 34, 34)
# (95, 34, 34): 0.09854206894387378
# (94, 35, 34): 0.11633233307975967
#
# Approximating hitting prob for (95, 34, 65)
# (95, 34, 65): 0.18374802342285812
# (94, 35, 65): 0.185124985569762
#
# Approximating hitting prob for (95, 34, 68)
# (95, 34, 68): 0.17849438250146374
# (94, 35, 68): 0.18888687658138323
#
# Approximating hitting prob for (95, 34, 81)
# (95, 34, 81): 0.20170587126606462
# (94, 35, 81): 0.20285700114885855
#
# Approximating hitting prob for (95, 35, 35)
# (95, 35, 35): 0.09921182631214444
# (94, 36, 35): 0.11884956677392051
#
# Approximating hitting prob for (95, 35, 66)
# (95, 35, 66): 0.18487566961474486
# (94, 36, 66): 0.18626569449673955
#
# Approximating hitting prob for (95, 35, 70)
# (95, 35, 70): 0.18059684201980344
# (94, 36, 70): 0.19140427777676994
#
# Approximating hitting prob for (95, 35, 82)
# (95, 35, 82): 0.20283970594864717
# (94, 36, 82): 0.20637702649753453
#
# Approximating hitting prob for (96, 18, 35)
# (96, 18, 35): 0.07875482630868544
# (95, 19, 35): 0.08238741544254219
#
# Approximating hitting prob for (96, 35, 36)
# (96, 35, 36): 0.11658165412878885
# (95, 36, 36): 0.10183084923416126
#
# Approximating hitting prob for (96, 35, 54)
# (96, 35, 54): 0.14119011789196037
# (95, 36, 54): 0.14079441184048172
#
# Approximating hitting prob for (96, 35, 67)
# (96, 35, 67): 0.18620392750350642
# (95, 36, 67): 0.18621994120709692
#
# Approximating hitting prob for (96, 35, 72)
# (96, 35, 72): 0.19052839980109335
# (95, 36, 72): 0.18328228930200333
#
# Approximating hitting prob for (96, 36, 37)
# (96, 36, 37): 0.11905900465249052
# (95, 37, 37): 0.10287814864700935
#
# Approximating hitting prob for (96, 36, 74)
# (96, 36, 74): 0.19304895180612017
# (95, 37, 74): 0.18602499961597976
#
# Approximating hitting prob for (96, 37, 38)
# (96, 37, 38): 0.12045714634561765
# (95, 38, 38): 0.10420134496304477
#
# Approximating hitting prob for (96, 37, 76)
# (96, 37, 76): 0.19559002726023125
# (95, 38, 76): 0.1897209221086149
#
# Approximating hitting prob for (96, 37, 85)
# (96, 37, 85): 0.21075624782683614
# (95, 38, 85): 0.2101508212942301
#
# Approximating hitting prob for (96, 37, 94)
# (96, 37, 94): 0.2202383448443234
# (95, 38, 94): 0.2200279634113912
#
# Approximating hitting prob for (96, 26, 38)
# (96, 26, 38): 0.10110459198299844
# (95, 27, 38): 0.10239621677174852
#
# Approximating hitting prob for (96, 38, 39)
# (96, 38, 39): 0.12227978644651565
# (95, 39, 39): 0.10507795756563093
#
# Approximating hitting prob for (96, 38, 78)
# (96, 38, 78): 0.2008046811351192
# (95, 39, 78): 0.19278116232444317
#
# Approximating hitting prob for (96, 38, 86)
# (96, 38, 86): 0.2119909936037178
# (95, 39, 86): 0.2114914164587538
#
# Approximating hitting prob for (96, 10, 39)
# (96, 10, 39): 0.07421822482124145
# (95, 11, 39): 0.07528425002900392
#
# Approximating hitting prob for (95, 40, 40)
# (95, 40, 40): 0.10625452738444387
# (94, 41, 40): 0.1254081040123528
#
# Approximating hitting prob for (95, 40, 60)
# (95, 40, 60): 0.1829374165956037
# (94, 41, 60): 0.18612846333992994
#
# Approximating hitting prob for (95, 40, 80)
# (95, 40, 80): 0.1942560090296168
# (94, 41, 80): 0.20805947034327396
#
# Approximating hitting prob for (95, 40, 97)
# (95, 40, 97): 0.28322873336791815
# (94, 41, 97): 0.2844362582141767
#
# Approximating hitting prob for (95, 40, 98)
# (95, 40, 98): 0.2835574586390662
# (94, 41, 98): 0.28497926540297897
#
# Approximating hitting prob for (95, 41, 41)
# (95, 41, 41): 0.10711019715514082
# (94, 42, 41): 0.1265744028188926
#
# Approximating hitting prob for (95, 41, 82)
# (95, 41, 82): 0.20247165089521282
# (94, 42, 82): 0.2136851608234069
#
# Approximating hitting prob for (95, 14, 42)
# (95, 14, 42): 0.0809412647661392
# (94, 15, 42): 0.0859358020145214
#
# Approximating hitting prob for (96, 21, 41)
# (96, 21, 41): 0.10407766359097705
# (95, 22, 41): 0.10483420424924912
#
# Approximating hitting prob for (96, 41, 42)
# (96, 41, 42): 0.12549667668599937
# (95, 42, 42): 0.10797891704984196
#
# Approximating hitting prob for (96, 41, 44)
# (96, 41, 44): 0.12962384769457438
# (95, 42, 44): 0.12937403154803853
#
# Approximating hitting prob for (96, 41, 63)
# (96, 41, 63): 0.18647532489309868
# (95, 42, 63): 0.18589037868799463
#
# Approximating hitting prob for (96, 41, 73)
# (96, 41, 73): 0.19610657117630595
# (95, 42, 73): 0.19614789478284345
#
# Approximating hitting prob for (96, 41, 84)
# (96, 41, 84): 0.21239754360759477
# (95, 42, 84): 0.20372308694602467
#
# Approximating hitting prob for (96, 42, 43)
# (96, 42, 43): 0.12664206286225682
# (95, 43, 43): 0.10872919722017395
#
# Approximating hitting prob for (95, 43, 86)
# (95, 43, 86): 0.20561359632112694
# (94, 44, 86): 0.21863318077254712
#
# Approximating hitting prob for (95, 43, 90)
# (95, 43, 90): 0.22066639617327957
# (94, 44, 90): 0.22223977094156022
#
# Approximating hitting prob for (95, 11, 44)
# (95, 11, 44): 0.08132905002296713
# (94, 12, 44): 0.08433841807599
#
# Approximating hitting prob for (95, 44, 44)
# (95, 44, 44): 0.10992952160995305
# (94, 45, 44): 0.13075940088193108
#
# Approximating hitting prob for (96, 43, 45)
# (96, 43, 45): 0.13029133181982613
# (95, 44, 45): 0.12994305836193343
#
# Approximating hitting prob for (96, 43, 75)
# (96, 43, 75): 0.20476455604473956
# (95, 44, 75): 0.20478051188992696
#
# Approximating hitting prob for (96, 43, 88)
# (96, 43, 88): 0.2171736326680966
# (95, 44, 88): 0.2090614941261706
#
# Approximating hitting prob for (96, 43, 91)
# (96, 43, 91): 0.22217735625986598
# (95, 44, 91): 0.22202146491622307
#
# Approximating hitting prob for (96, 9, 44)
# (96, 9, 44): 0.07815377324421692
# (95, 10, 44): 0.08012660395185399
#
# Approximating hitting prob for (95, 45, 45)
# (95, 45, 45): 0.11044474190068237
# (94, 46, 45): 0.13246009181266633
#
# Approximating hitting prob for (96, 44, 46)
# (96, 44, 46): 0.13184227461822298
# (95, 45, 46): 0.13158085129465028
#
# Approximating hitting prob for (96, 44, 90)
# (96, 44, 90): 0.22048272477114153
# (95, 45, 90): 0.2113804407189753
#
# Approximating hitting prob for (96, 23, 45)
# (96, 23, 45): 0.10888254971213811
# (95, 24, 45): 0.11001975049064398
#
# Approximating hitting prob for (96, 45, 46)
# (96, 45, 46): 0.1307785475002571
# (95, 46, 46): 0.1108057213284336
#
# Approximating hitting prob for (96, 45, 92)
# (96, 45, 92): 0.22232200312110598
# (95, 46, 92): 0.21345770225442984
#
# Approximating hitting prob for (96, 45, 93)
# (96, 45, 93): 0.22506413731574612
# (95, 46, 93): 0.22434379407198965
#
# Approximating hitting prob for (96, 46, 47)
# (96, 46, 47): 0.1324697537463775
# (95, 47, 47): 0.11105914106474758
#
# Approximating hitting prob for (96, 46, 94)
# (96, 46, 94): 0.22606085572991852
# (95, 47, 94): 0.21473873196449764
#
# Approximating hitting prob for (95, 49, 49)
# (95, 49, 49): 0.16368624662895473
# (94, 50, 49): 0.20554708137178898
#
# Approximating hitting prob for (95, 49, 98)
# (95, 49, 98): 0.29138244699021604
# (94, 50, 98): 0.30267514967542086
#
# Approximating hitting prob for (95, 10, 50)
# (95, 10, 50): 0.086726161666342
# (94, 11, 50): 0.0903599599472958
#
# Approximating hitting prob for (95, 50, 50)
# (95, 50, 50): 0.1641357749739061
# (94, 51, 50): 0.20626729991853945
#
# Approximating hitting prob for (95, 50, 81)
# (95, 50, 81): 0.2268666801173347
# (94, 51, 81): 0.22782351276264623
#
# Approximating hitting prob for (95, 50, 97)
# (95, 50, 97): 0.30012201018233536
# (94, 51, 97): 0.30123090840899924
#
# Approximating hitting prob for (95, 50, 100)
# (95, 50, 100): 0.2921047155076177
# (94, 51, 100): 0.3036967999659631
#
# Approximating hitting prob for (96, 17, 50)
# (96, 17, 50): 0.10503843789479728
# (95, 18, 50): 0.10663755893468276
#
# Approximating hitting prob for (96, 50, 51)
# (96, 50, 51): 0.20552843861955858
# (95, 51, 51): 0.1646557711010518
#
# Approximating hitting prob for (96, 50, 82)
# (96, 50, 82): 0.2280770995838126
# (95, 51, 82): 0.22774563447974425
#
# Approximating hitting prob for (96, 50, 98)
# (96, 50, 98): 0.30166806344591895
# (95, 51, 98): 0.300949618244227
#
# Approximating hitting prob for (96, 26, 51)
# (96, 26, 51): 0.1181258720022151
# (95, 27, 51): 0.12110603768057847
#
# Approximating hitting prob for (96, 51, 52)
# (96, 51, 52): 0.20623616670639297
# (95, 52, 52): 0.16537337726044482
#
# Approximating hitting prob for (96, 51, 99)
# (96, 51, 99): 0.3023902429418173
# (95, 52, 99): 0.30165533034359393
#
# Approximating hitting prob for (96, 52, 53)
# (96, 52, 53): 0.20703482406238496
# (95, 53, 53): 0.16609511350875214
#
# Approximating hitting prob for (96, 52, 100)
# (96, 52, 100): 0.30316751475308007
# (95, 53, 100): 0.30263258202654714
#
# Approximating hitting prob for (96, 27, 53)
# (96, 27, 53): 0.12330520921269328
# (95, 28, 53): 0.1249354174558824
#
# Approximating hitting prob for (95, 54, 54)
# (95, 54, 54): 0.1670688019260859
# (94, 55, 54): 0.20972660956914027
#
# Approximating hitting prob for (95, 54, 81)
# (95, 54, 81): 0.22596348062283833
# (94, 55, 81): 0.23207421165847097
#
# Approximating hitting prob for (95, 54, 90)
# (95, 54, 90): 0.2392068738417347
# (94, 55, 90): 0.2420395666626144
#
# Approximating hitting prob for (95, 55, 55)
# (95, 55, 55): 0.16780182668011867
# (94, 56, 55): 0.21072857592526018
#
# Approximating hitting prob for (96, 28, 55)
# (96, 28, 55): 0.12606769067215032
# (95, 29, 55): 0.1283594767996679
#
# Approximating hitting prob for (96, 55, 56)
# (96, 55, 56): 0.20958628431535878
# (95, 56, 56): 0.16866260677929515
#
# Approximating hitting prob for (96, 55, 84)
# (96, 55, 84): 0.23211621870924012
# (95, 56, 84): 0.23140897023734605
#
# Approximating hitting prob for (96, 55, 87)
# (96, 55, 87): 0.23634956805846055
# (95, 56, 87): 0.23607708207730613
#
# Approximating hitting prob for (96, 56, 57)
# (96, 56, 57): 0.21055482444046825
# (95, 57, 57): 0.173080857772242
#
# Approximating hitting prob for (95, 58, 58)
# (95, 58, 58): 0.17421830284262205
# (94, 59, 58): 0.2172391179241364
#
# Approximating hitting prob for (95, 59, 59)
# (95, 59, 59): 0.17495531027000136
# (94, 60, 59): 0.2188534464592898
#
# Approximating hitting prob for (96, 58, 90)
# (96, 58, 90): 0.2409889542831023
# (95, 59, 90): 0.2404256165925256
#
# Approximating hitting prob for (96, 30, 59)
# (96, 30, 59): 0.1324758143029439
# (95, 31, 59): 0.1341033053970434
#
# Approximating hitting prob for (95, 60, 60)
# (95, 60, 60): 0.17688216482273314
# (94, 61, 60): 0.21984636658949722
#
# Approximating hitting prob for (95, 60, 90)
# (95, 60, 90): 0.23782977450969367
# (94, 61, 90): 0.24152243928649164
#
# Approximating hitting prob for (95, 60, 91)
# (95, 60, 91): 0.24116515982000394
# (94, 61, 91): 0.241549422220002
#
# Approximating hitting prob for (95, 61, 61)
# (95, 61, 61): 0.17724782259788785
# (94, 62, 61): 0.2207992879435936
#
# Approximating hitting prob for (95, 61, 92)
# (95, 61, 92): 0.2413102972434934
# (94, 62, 92): 0.24438106064109474
#
# Approximating hitting prob for (96, 31, 61)
# (96, 31, 61): 0.13449087621962566
# (95, 32, 61): 0.14670751864345732
#
# Approximating hitting prob for (96, 61, 62)
# (96, 61, 62): 0.21949966173838553
# (95, 62, 62): 0.1783528689947097
#
# Approximating hitting prob for (96, 61, 93)
# (96, 61, 93): 0.24323043085156917
# (95, 62, 93): 0.23948464872617503
#
# Approximating hitting prob for (96, 42, 62)
# (96, 42, 62): 0.1866457826987478
# (95, 43, 62): 0.18849016787362094
#
# Approximating hitting prob for (96, 62, 63)
# (96, 62, 63): 0.22059582606419945
# (95, 63, 63): 0.1788359727719986
#
# Approximating hitting prob for (96, 63, 64)
# (96, 63, 64): 0.2217462544137324
# (95, 64, 64): 0.18493095674762483
#
# Approximating hitting prob for (96, 64, 65)
# (96, 64, 65): 0.22691186403212993
# (95, 65, 65): 0.18564035397000525
#
# Approximating hitting prob for (96, 11, 65)
# (96, 11, 65): 0.11190638361230121
# (95, 12, 65): 0.11232732523115573
#
# Approximating hitting prob for (95, 66, 66)
# (95, 66, 66): 0.1864480621121588
# (94, 67, 66): 0.23117499813839082
#
# Approximating hitting prob for (95, 66, 97)
# (95, 66, 97): 0.32206809173142725
# (94, 67, 97): 0.32265972944210225
#
# Approximating hitting prob for (95, 67, 67)
# (95, 67, 67): 0.18845927859727787
# (94, 68, 67): 0.23226708270785154
#
# Approximating hitting prob for (95, 67, 98)
# (95, 67, 98): 0.32249122863807145
# (94, 68, 98): 0.3233780790047332
#
# Approximating hitting prob for (96, 34, 67)
# (96, 34, 67): 0.18640274580044638
# (95, 35, 67): 0.18765846404656972
#
# Approximating hitting prob for (96, 67, 68)
# (96, 67, 68): 0.23021962647318747
# (95, 68, 68): 0.18986021707400094
#
# Approximating hitting prob for (96, 67, 99)
# (96, 67, 99): 0.32412270275559774
# (95, 68, 99): 0.32323872342432064
#
# Approximating hitting prob for (95, 69, 69)
# (95, 69, 69): 0.19042168227504233
# (94, 70, 69): 0.23382761274979982
#
# Approximating hitting prob for (95, 69, 100)
# (95, 69, 100): 0.32370726516309406
# (94, 70, 100): 0.32483302033441924
#
# Approximating hitting prob for (95, 14, 70)
# (95, 14, 70): 0.1216434291601217
# (94, 15, 70): 0.1254022803288742
#
# Approximating hitting prob for (96, 35, 69)
# (96, 35, 69): 0.18809573271048885
# (95, 36, 69): 0.18953142896889455
#
# Approximating hitting prob for (96, 69, 70)
# (96, 69, 70): 0.23286978823898333
# (95, 70, 70): 0.19098456748460502
#
# Approximating hitting prob for (96, 70, 71)
# (96, 70, 71): 0.23351964577731762
# (95, 71, 71): 0.19138100679725636
#
# Approximating hitting prob for (96, 36, 71)
# (96, 36, 71): 0.1903539010098342
# (95, 37, 71): 0.19242475120959848
#
# Approximating hitting prob for (96, 71, 72)
# (96, 71, 72): 0.23539941320952548
# (95, 72, 72): 0.2007995943298834
#
# Approximating hitting prob for (96, 72, 73)
# (96, 72, 73): 0.24233708354095088
# (95, 73, 73): 0.20124754380829338
#
# Approximating hitting prob for (95, 74, 74)
# (95, 74, 74): 0.2026489044261797
# (94, 75, 74): 0.2461635242869239
#
# Approximating hitting prob for (95, 50, 75)
# (95, 50, 75): 0.21861542923260036
# (94, 51, 75): 0.2217571271473365
#
# Approximating hitting prob for (95, 75, 75)
# (95, 75, 75): 0.20309718274907462
# (94, 76, 75): 0.24747690001857933
#
# Approximating hitting prob for (96, 38, 75)
# (96, 38, 75): 0.19550600254273431
# (95, 39, 75): 0.1971319143413203
#
# Approximating hitting prob for (96, 75, 76)
# (96, 75, 76): 0.24578987890135692
# (95, 76, 76): 0.20445296973250157
#
# Approximating hitting prob for (96, 76, 77)
# (96, 76, 77): 0.246716862896548
# (95, 77, 77): 0.20505459018616337
#
# Approximating hitting prob for (96, 39, 77)
# (96, 39, 77): 0.20093962330562157
# (95, 40, 77): 0.2022209031794279
#
# Approximating hitting prob for (96, 77, 78)
# (96, 77, 78): 0.2478411018030419
# (95, 78, 78): 0.20565514132102514
#
# Approximating hitting prob for (96, 78, 79)
# (96, 78, 79): 0.24846386233489584
# (95, 79, 79): 0.20595436664560796
#
# Approximating hitting prob for (96, 20, 79)
# (96, 20, 79): 0.17287353236699723
# (95, 21, 79): 0.1740041677110248
#
# Approximating hitting prob for (95, 80, 80)
# (95, 80, 80): 0.2095311110085479
# (94, 81, 80): 0.2551258275015794
#
# Approximating hitting prob for (96, 27, 80)
# (96, 27, 80): 0.18436124752563587
# (95, 28, 80): 0.18560360055386796
#
# Approximating hitting prob for (95, 81, 81)
# (95, 81, 81): 0.2100647410788505
# (94, 82, 81): 0.25626510661394636
#
# Approximating hitting prob for (96, 41, 81)
# (96, 41, 81): 0.20386965717897032
# (95, 42, 81): 0.21004715829307372
#
# Approximating hitting prob for (96, 81, 82)
# (96, 81, 82): 0.25410733782521694
# (95, 82, 82): 0.2117417700191737
#
# Approximating hitting prob for (96, 82, 83)
# (96, 82, 83): 0.255259920023436
# (95, 83, 83): 0.21220759610943096
#
# Approximating hitting prob for (96, 28, 83)
# (96, 28, 83): 0.1897872257441816
# (95, 29, 83): 0.191749465220134
#
# Approximating hitting prob for (96, 56, 83)
# (96, 56, 83): 0.23191856078642548
# (95, 57, 83): 0.2346734023575401
#
# Approximating hitting prob for (96, 83, 84)
# (96, 83, 84): 0.2566684335857792
# (95, 84, 84): 0.2144648878776486
#
# Approximating hitting prob for (96, 84, 85)
# (96, 84, 85): 0.258341890615756
# (95, 85, 85): 0.21501626810617877
#
# Approximating hitting prob for (95, 86, 86)
# (95, 86, 86): 0.21579811705656418
# (94, 87, 86): 0.26149968172131516
#
# Approximating hitting prob for (96, 29, 86)
# (96, 29, 86): 0.1928196403228277
# (95, 30, 86): 0.19741831100118246
#
# Approximating hitting prob for (96, 58, 86)
# (96, 58, 86): 0.23621337398310296
# (95, 59, 86): 0.23783571812293544
#
# Approximating hitting prob for (96, 86, 87)
# (96, 86, 87): 0.2598302147644168
# (95, 87, 87): 0.21657759422062403
#
# Approximating hitting prob for (95, 88, 88)
# (95, 88, 88): 0.2176010917588325
# (94, 89, 88): 0.26344943074057775
#
# Approximating hitting prob for (95, 89, 89)
# (95, 89, 89): 0.21863978175917653
# (94, 90, 89): 0.2641825089805684
#
# Approximating hitting prob for (96, 30, 89)
# (96, 30, 89): 0.19925427257371722
# (95, 31, 89): 0.20157661682549402
#
# Approximating hitting prob for (96, 60, 89)
# (96, 60, 89): 0.23918892496640765
# (95, 61, 89): 0.24039539335236149
#
# Approximating hitting prob for (96, 89, 90)
# (96, 89, 90): 0.2626791655405718
# (95, 90, 90): 0.21945386122637278
#
# Approximating hitting prob for (96, 90, 91)
# (96, 90, 91): 0.26358234435462186
# (95, 91, 91): 0.2201012605823117
#
# Approximating hitting prob for (95, 92, 92)
# (95, 92, 92): 0.220876880479009
# (94, 93, 92): 0.26615301310188466
#
# Approximating hitting prob for (96, 31, 92)
# (96, 31, 92): 0.20342070200978832
# (95, 32, 92): 0.21630169308941952
#
# Approximating hitting prob for (95, 93, 93)
# (95, 93, 93): 0.22139366532684668
# (94, 94, 93): 0.32213983993287587
#
# Approximating hitting prob for (96, 47, 93)
# (96, 47, 93): 0.22432262146442117
# (95, 48, 93): 0.23724196608994355
#
# Approximating hitting prob for (96, 93, 94)
# (96, 93, 94): 0.26567173192485416
# (95, 94, 94): 0.22189525087496595
#
# Approximating hitting prob for (96, 96, 97)
# (96, 96, 97): 0.3890485444803284
# (95, 97, 97): 0.35596452581063315
#
# Approximating hitting prob for (96, 14, 97)
# (96, 14, 97): 0.24608909422658745
# (95, 15, 97): 0.24735412640901291
#
# Approximating hitting prob for (96, 97, 98)
# (96, 97, 98): 0.4003647673139072
# (95, 98, 98): 0.35623870829936544
#
# Approximating hitting prob for (95, 99, 99)
# (95, 99, 99): 0.35662736548499185
# (94, 100, 99): 0.401819663061469
#
# Approximating hitting prob for (95, 20, 100)
# (95, 20, 100): 0.2525293021905319
# (94, 21, 100): 0.2560801429003171
#
# Approximating hitting prob for (96, 25, 99)
# (96, 25, 99): 0.2587348635942796
# (95, 26, 99): 0.2601697770209758
#
# Approximating hitting prob for (95, 100, 100)
# (95, 100, 100): 0.3569686500000437
# (94, 101, 100): 0.40220065281551487
#
# Approximating hitting prob for (96, 2, 15)
# (96, 2, 15): 0.015068196607317147
# (95, 3, 15): 0.015636171848711775
#
# Approximating hitting prob for (97, 1, 34)
# (97, 1, 34): 0.061601602301526004
# (96, 2, 34): 0.061404212946109225
#
# Approximating hitting prob for (97, 1, 35)
# (97, 1, 35): 0.061954444356206555
# (96, 2, 35): 0.06181412840654877
#
# Approximating hitting prob for (97, 1, 100)
# (97, 1, 100): 0.24916750528791634
# (96, 2, 100): 0.247618823718423
#
# Approximating hitting prob for (97, 4, 5)
# (97, 4, 5): 0.003176749883620477
# (96, 5, 5): 0.0026669203692147804
#
# Approximating hitting prob for (97, 4, 10)
# (97, 4, 10): 0.00751165168976817
# (96, 5, 10): 0.0073423916890340704
#
# Approximating hitting prob for (97, 4, 7)
# (97, 4, 7): 0.0054095332045599525
# (96, 5, 7): 0.00607295465463395
#
# Approximating hitting prob for (97, 7, 8)
# (97, 7, 8): 0.010082944012385797
# (96, 8, 8): 0.007606113672316607
#
# Approximating hitting prob for (97, 7, 16)
# (97, 7, 16): 0.02122051156587122
# (96, 8, 16): 0.020819539783123876
#
# Approximating hitting prob for (97, 8, 9)
# (97, 8, 9): 0.011580663618607096
# (96, 9, 9): 0.008575677840419793
#
# Approximating hitting prob for (97, 8, 18)
# (97, 8, 18): 0.02514739500473212
# (96, 9, 18): 0.023476748819319798
#
# Approximating hitting prob for (96, 10, 10)
# (96, 10, 10): 0.011227853813094988
# (95, 11, 10): 0.0160372991633816
#
# Approximating hitting prob for (96, 10, 20)
# (96, 10, 20): 0.025834164641596935
# (95, 11, 20): 0.03153299222048191
#
# Approximating hitting prob for (96, 11, 11)
# (96, 11, 11): 0.012436406127136354
# (95, 12, 11): 0.019130455780381007
#
# Approximating hitting prob for (96, 11, 33)
# (96, 11, 33): 0.06447414786801599
# (95, 12, 33): 0.06837886872727832
#
# Approximating hitting prob for (96, 12, 12)
# (96, 12, 12): 0.01685987905192621
# (95, 13, 12): 0.023118093048523743
#
# Approximating hitting prob for (96, 12, 24)
# (96, 12, 24): 0.03624392813830257
# (95, 13, 24): 0.041481920645956405
#
# Approximating hitting prob for (96, 13, 13)
# (96, 13, 13): 0.018739731021958136
# (95, 14, 13): 0.026780119190507934
#
# Approximating hitting prob for (96, 13, 26)
# (96, 13, 26): 0.0393365826566127
# (95, 14, 26): 0.04780645450618879
#
# Approximating hitting prob for (96, 13, 39)
# (96, 13, 39): 0.07542275452415713
# (95, 14, 39): 0.08180460455229813
#
# Approximating hitting prob for (96, 13, 52)
# (96, 13, 52): 0.08946137337905113
# (95, 14, 52): 0.09424252787129055
#
# Approximating hitting prob for (96, 13, 65)
# (96, 13, 65): 0.11056515863282183
# (95, 14, 65): 0.11558978178225182
#
# Approximating hitting prob for (96, 14, 14)
# (96, 14, 14): 0.024120403117956418
# (95, 15, 14): 0.03007449955497836
#
# Approximating hitting prob for (96, 15, 15)
# (96, 15, 15): 0.024854792732706285
# (95, 16, 15): 0.03249382101650819
#
# Approximating hitting prob for (96, 15, 30)
# (96, 15, 30): 0.05616445170024622
# (95, 16, 30): 0.06413996605724591
#
# Approximating hitting prob for (96, 15, 45)
# (96, 15, 45): 0.08400056854934708
# (95, 16, 45): 0.09029906274491377
#
# Approximating hitting prob for (96, 15, 60)
# (96, 15, 60): 0.1103775851968019
# (95, 16, 60): 0.11553999825105842
#
# Approximating hitting prob for (97, 8, 15)
# (97, 8, 15): 0.022506238398532247
# (96, 9, 15): 0.022985723318865236
#
# Approximating hitting prob for (97, 15, 16)
# (97, 15, 16): 0.03157434007235859
# (96, 16, 16): 0.02913548107169975
#
# Approximating hitting prob for (97, 16, 17)
# (97, 16, 17): 0.03938897381056616
# (96, 17, 17): 0.03190705683676042
#
# Approximating hitting prob for (97, 16, 34)
# (97, 16, 34): 0.07523054624400848
# (96, 17, 34): 0.0733596361831656
#
# Approximating hitting prob for (97, 16, 51)
# (97, 16, 51): 0.1030246695283284
# (96, 17, 51): 0.102222509312895
#
# Approximating hitting prob for (96, 18, 18)
# (96, 18, 18): 0.033160522934205634
# (95, 19, 18): 0.04722755824045662
#
# Approximating hitting prob for (96, 18, 36)
# (96, 18, 36): 0.07482408900222925
# (95, 19, 36): 0.08270544683449861
#
# Approximating hitting prob for (96, 18, 54)
# (96, 18, 54): 0.10586933729953248
# (95, 19, 54): 0.11343672285755686
#
# Approximating hitting prob for (96, 18, 72)
# (96, 18, 72): 0.12788561784969957
# (95, 19, 72): 0.13356195800383067
#
# Approximating hitting prob for (96, 19, 19)
# (96, 19, 19): 0.03407256609076786
# (95, 20, 19): 0.04948654965250674
#
# Approximating hitting prob for (96, 19, 38)
# (96, 19, 38): 0.07565925934443936
# (95, 20, 38): 0.09702289211856678
#
# Approximating hitting prob for (96, 19, 57)
# (96, 19, 57): 0.10909833676709846
# (95, 20, 57): 0.1217169260203284
#
# Approximating hitting prob for (96, 19, 76)
# (96, 19, 76): 0.13136721370392312
# (95, 20, 76): 0.1712936483796632
#
# Approximating hitting prob for (96, 5, 20)
# (96, 5, 20): 0.020867186965362286
# (95, 6, 20): 0.02418788366296804
#
# Approximating hitting prob for (97, 10, 19)
# (97, 10, 19): 0.027829508645092694
# (96, 11, 19): 0.030128756366317667
#
# Approximating hitting prob for (97, 19, 20)
# (97, 19, 20): 0.04876951211624542
# (96, 20, 20): 0.03635093876802261
#
# Approximating hitting prob for (97, 19, 60)
# (97, 19, 60): 0.11967447443357249
# (96, 20, 60): 0.11884122114033054
#
# Approximating hitting prob for (97, 20, 21)
# (97, 20, 21): 0.05041849243678539
# (96, 21, 21): 0.03841739507832822
#
# Approximating hitting prob for (97, 20, 42)
# (97, 20, 42): 0.10353735844055922
# (96, 21, 42): 0.09635301586425472
#
# Approximating hitting prob for (97, 20, 63)
# (97, 20, 63): 0.12413454789227318
# (96, 21, 63): 0.12206668535770517
#
# Approximating hitting prob for (97, 20, 84)
# (97, 20, 84): 0.17565153366325215
# (96, 21, 84): 0.1753706861699932
#
# Approximating hitting prob for (97, 21, 22)
# (97, 21, 22): 0.0524631420392754
# (96, 22, 22): 0.03984019053489972
#
# Approximating hitting prob for (97, 21, 44)
# (97, 21, 44): 0.105176460274931
# (96, 22, 44): 0.09802904890988574
#
# Approximating hitting prob for (97, 21, 66)
# (97, 21, 66): 0.12802962912800217
# (96, 22, 66): 0.12510871375316832
#
# Approximating hitting prob for (97, 21, 68)
# (97, 21, 68): 0.13071423751088307
# (96, 22, 68): 0.13053720828372548
#
# Approximating hitting prob for (97, 21, 88)
# (97, 21, 88): 0.18305005725984783
# (96, 22, 88): 0.18190099520889622
#
# Approximating hitting prob for (97, 22, 23)
# (97, 22, 23): 0.05440468511237726
# (96, 23, 23): 0.041535785316914674
#
# Approximating hitting prob for (97, 22, 46)
# (97, 22, 46): 0.1081206602357568
# (96, 23, 46): 0.10139410485810411
#
# Approximating hitting prob for (97, 22, 69)
# (97, 22, 69): 0.13099806972924458
# (96, 23, 69): 0.1273128861549271
#
# Approximating hitting prob for (97, 22, 70)
# (97, 22, 70): 0.13253159064543749
# (96, 23, 70): 0.1320992003871321
#
# Approximating hitting prob for (96, 24, 24)
# (96, 24, 24): 0.053763440860215055
# (95, 25, 24): 0.07291878292150782
#
# Approximating hitting prob for (96, 24, 48)
# (96, 24, 48): 0.10550458715595556
# (95, 25, 48): 0.1159644475894146
#
# Approximating hitting prob for (96, 25, 25)
# (96, 25, 25): 0.05924095873027365
# (95, 26, 25): 0.07457952388163187
#
# Approximating hitting prob for (96, 25, 50)
# (96, 25, 50): 0.10835548262319593
# (95, 26, 50): 0.11809649005897056
#
# Approximating hitting prob for (96, 25, 75)
# (96, 25, 75): 0.1729952959070202
# (95, 26, 75): 0.18032869778731572
#
# Approximating hitting prob for (97, 13, 25)
# (97, 13, 25): 0.04144905830048252
# (96, 14, 25): 0.0448607098097284
#
# Approximating hitting prob for (97, 25, 26)
# (97, 25, 26): 0.07359029314595528
# (96, 26, 26): 0.06042012952518954
#
# Approximating hitting prob for (97, 25, 52)
# (97, 25, 52): 0.11776025491971513
# (96, 26, 52): 0.10989253718876396
#
# Approximating hitting prob for (96, 26, 78)
# (96, 26, 78): 0.1749815404175311
# (95, 27, 78): 0.18353245996896875
#
# Approximating hitting prob for (96, 9, 27)
# (96, 9, 27): 0.037115614613789094
# (95, 10, 27): 0.042403162047252065
#
# Approximating hitting prob for (96, 27, 27)
# (96, 27, 27): 0.06210664109800005
# (95, 28, 27): 0.07860902337816307
#
# Approximating hitting prob for (96, 27, 54)
# (96, 27, 54): 0.11544370352480011
# (95, 28, 54): 0.12563548193489402
#
# Approximating hitting prob for (96, 27, 76)
# (96, 27, 76): 0.18026774606261997
# (95, 28, 76): 0.18148736799117968
#
# Approximating hitting prob for (96, 27, 81)
# (96, 27, 81): 0.17782318637363456
# (95, 28, 81): 0.18794121438723074
#
# Approximating hitting prob for (96, 28, 28)
# (96, 28, 28): 0.06438841979399504
# (95, 29, 28): 0.08150115157741987
#
# Approximating hitting prob for (96, 28, 56)
# (96, 28, 56): 0.11785226874648037
# (95, 29, 56): 0.12877106294186869
#
# Approximating hitting prob for (96, 28, 84)
# (96, 28, 84): 0.18375958207394763
# (95, 29, 84): 0.19239632012093635
#
# Approximating hitting prob for (96, 29, 29)
# (96, 29, 29): 0.06751706062128167
# (95, 30, 29): 0.08515535273285378
#
# Approximating hitting prob for (96, 29, 58)
# (96, 29, 58): 0.12230767156512444
# (95, 30, 58): 0.13291094881888907
#
# Approximating hitting prob for (96, 29, 87)
# (96, 29, 87): 0.19004471423281158
# (95, 30, 87): 0.19825567385739504
#
# Approximating hitting prob for (97, 15, 29)
# (97, 15, 29): 0.05833644588482015
# (96, 16, 29): 0.06166227396054719
#
# Approximating hitting prob for (97, 29, 30)
# (97, 29, 30): 0.08318729219137475
# (96, 30, 30): 0.06898812000020638
#
# Approximating hitting prob for (97, 29, 60)
# (97, 29, 60): 0.13163492200993557
# (96, 30, 60): 0.12416934956017699
#
# Approximating hitting prob for (97, 29, 90)
# (97, 29, 90): 0.19805496736017547
# (96, 30, 90): 0.1933349373689359
#
# Approximating hitting prob for (97, 30, 31)
# (97, 30, 31): 0.08603002038271808
# (96, 31, 31): 0.07061049040994448
#
# Approximating hitting prob for (97, 30, 62)
# (97, 30, 62): 0.13366061077270944
# (96, 31, 62): 0.12567089471132675
#
# Approximating hitting prob for (97, 30, 63)
# (97, 30, 63): 0.1365758157980528
# (96, 31, 63): 0.13653087516065274
#
# Approximating hitting prob for (97, 30, 93)
# (97, 30, 93): 0.20260090166299793
# (96, 31, 93): 0.19730646070613175
#
# Approximating hitting prob for (97, 32, 33)
# (97, 32, 33): 0.10329961284654478
# (96, 33, 33): 0.0973207870862704
#
# Approximating hitting prob for (96, 34, 34)
# (96, 34, 34): 0.09801304374768845
# (95, 35, 34): 0.11599614084604248
#
# Approximating hitting prob for (96, 34, 68)
# (96, 34, 68): 0.1779700717162258
# (95, 35, 68): 0.18804356985320056
#
# Approximating hitting prob for (96, 35, 35)
# (96, 35, 35): 0.09893920294808939
# (95, 36, 35): 0.11758223215129932
#
# Approximating hitting prob for (96, 35, 70)
# (96, 35, 70): 0.1796742216062237
# (95, 36, 70): 0.19044493908015211
#
# Approximating hitting prob for (97, 18, 35)
# (97, 18, 35): 0.07850007255312931
# (96, 19, 35): 0.08188088335924983
#
# Approximating hitting prob for (97, 35, 36)
# (97, 35, 36): 0.11623280411161073
# (96, 36, 36): 0.10101028194464957
#
# Approximating hitting prob for (97, 35, 54)
# (97, 35, 54): 0.1405810791133869
# (96, 36, 54): 0.1399387540394642
#
# Approximating hitting prob for (97, 35, 72)
# (97, 35, 72): 0.18967768470970672
# (96, 36, 72): 0.1824478821019516
#
# Approximating hitting prob for (97, 36, 37)
# (97, 36, 37): 0.11858832347153002
# (96, 37, 37): 0.10226358603005238
#
# Approximating hitting prob for (97, 36, 74)
# (97, 36, 74): 0.19232437905187735
# (96, 37, 74): 0.18541773469966213
#
# Approximating hitting prob for (96, 38, 38)
# (96, 38, 38): 0.10326673375632178
# (95, 39, 38): 0.12259717493530603
#
# Approximating hitting prob for (96, 38, 57)
# (96, 38, 57): 0.14281210969960503
# (95, 39, 57): 0.18213299506655223
#
# Approximating hitting prob for (96, 38, 76)
# (96, 38, 76): 0.1867104239295174
# (95, 39, 76): 0.20106918215311165
#
# Approximating hitting prob for (96, 38, 95)
# (96, 38, 95): 0.21971652154250332
# (95, 39, 95): 0.2791757676435141
#
# Approximating hitting prob for (97, 13, 38)
# (97, 13, 38): 0.07738668373746206
# (96, 14, 38): 0.08076583160523666
#
# Approximating hitting prob for (97, 26, 38)
# (97, 26, 38): 0.1003699835726945
# (96, 27, 38): 0.10197212812952737
#
# Approximating hitting prob for (97, 38, 39)
# (97, 38, 39): 0.12123569163277233
# (96, 39, 39): 0.10475146331557637
#
# Approximating hitting prob for (96, 39, 78)
# (96, 39, 78): 0.19231636745416378
# (95, 40, 78): 0.20282459793430838
#
# Approximating hitting prob for (96, 10, 40)
# (96, 10, 40): 0.07353660853767992
# (95, 11, 40): 0.07743509136853692
#
# Approximating hitting prob for (96, 20, 40)
# (96, 20, 40): 0.09502373148276483
# (95, 21, 40): 0.10353482218038668
#
# Approximating hitting prob for (96, 40, 40)
# (96, 40, 40): 0.10587877499579529
# (95, 41, 40): 0.12481184561763388
#
# Approximating hitting prob for (96, 40, 60)
# (96, 40, 60): 0.1823247734011908
# (95, 41, 60): 0.1853600180761291
#
# Approximating hitting prob for (96, 40, 80)
# (96, 40, 80): 0.19385068200177302
# (95, 41, 80): 0.2059905178282964
#
# Approximating hitting prob for (96, 40, 98)
# (96, 40, 98): 0.2831557290897027
# (95, 41, 98): 0.284459552564587
#
# Approximating hitting prob for (96, 41, 41)
# (96, 41, 41): 0.10657452494607424
# (95, 42, 41): 0.12588926785203872
#
# Approximating hitting prob for (96, 41, 82)
# (96, 41, 82): 0.19463827480179627
# (95, 42, 82): 0.21221974114452768
#
# Approximating hitting prob for (96, 41, 100)
# (96, 41, 100): 0.2842120179354031
# (95, 42, 100): 0.28572914014072154
#
# Approximating hitting prob for (96, 14, 42)
# (96, 14, 42): 0.08051299034201047
# (95, 15, 42): 0.08535236394173334
#
# Approximating hitting prob for (97, 21, 41)
# (97, 21, 41): 0.10380881542093218
# (96, 22, 41): 0.10388490050317
#
# Approximating hitting prob for (97, 41, 42)
# (97, 41, 42): 0.12500282571198296
# (96, 42, 42): 0.10762015109783586
#
# Approximating hitting prob for (97, 41, 63)
# (97, 41, 63): 0.1859653422232428
# ...
# (97, 2, 34): 0.05924719705883097
#
# Approximating hitting prob for (98, 1, 35)
# (98, 1, 35): 0.061838782692468564
# (97, 2, 35): 0.06163837050878455
#
# Approximating hitting prob for (98, 2, 35)
# (98, 2, 35): 0.061459650955715796
# (97, 3, 35): 0.060651314772778624
#
# Approximating hitting prob for (98, 3, 36)
# (98, 3, 36): 0.0626884038600693
# (97, 4, 36): 0.061811702612950596
#
# Approximating hitting prob for (98, 4, 5)
# (98, 4, 5): 0.003137004151808023
# (97, 5, 5): 0.0026076322272275063
#
# Approximating hitting prob for (98, 4, 10)
# (98, 4, 10): 0.00730942894229451
# (97, 5, 10): 0.007240882487149237
#
# Approximating hitting prob for (98, 4, 37)
# (98, 4, 37): 0.06415638574282957
# (97, 5, 37): 0.06416277825994517
#
# Approximating hitting prob for (98, 5, 6)
# (98, 5, 6): 0.0043988726851698
# (97, 6, 6): 0.0038444842617234997
#
# Approximating hitting prob for (98, 5, 18)
# (98, 5, 18): 0.019894411160074236
# (97, 6, 18): 0.019410325702113627
#
# Approximating hitting prob for (98, 5, 38)
# (98, 5, 38): 0.06648568511942099
# (97, 6, 38): 0.06584793145885864
#
# Approximating hitting prob for (98, 5, 42)
# (98, 5, 42): 0.0692207445355683
# (97, 6, 42): 0.06897337044347124
#
# Approximating hitting prob for (98, 6, 39)
# (98, 6, 39): 0.06804637110374884
# (97, 7, 39): 0.06804304512529037
#
# Approximating hitting prob for (98, 4, 7)
# (98, 4, 7): 0.005356298296638347
# (97, 5, 7): 0.005892045223109735
#
# Approximating hitting prob for (98, 7, 8)
# (98, 7, 8): 0.009676363181793197
# (97, 8, 8): 0.007270246332834924
#
# Approximating hitting prob for (98, 7, 24)
# (98, 7, 24): 0.02946149486748145
# (97, 8, 24): 0.02877871456976165
#
# Approximating hitting prob for (98, 7, 40)
# (98, 7, 40): 0.07010741756141241
# (97, 8, 40): 0.06876894733834664
#
# Approximating hitting prob for (98, 8, 9)
# (98, 8, 9): 0.011461183412188552
# (97, 9, 9): 0.008439143247963488
#
# Approximating hitting prob for (98, 8, 18)
# (98, 8, 18): 0.024976973081155623
# (97, 9, 18): 0.023339150134705694
#
# Approximating hitting prob for (97, 10, 10)
# (97, 10, 10): 0.011062706856574121
# (96, 11, 10): 0.015802662697158788
#
# Approximating hitting prob for (97, 10, 20)
# (97, 10, 20): 0.025385758704225252
# (96, 11, 20): 0.03132184464307385
#
# Approximating hitting prob for (97, 11, 11)
# (97, 11, 11): 0.012390790283052046
# (96, 12, 11): 0.01769994444566657
#
# Approximating hitting prob for (97, 11, 33)
# (97, 11, 33): 0.06415642925842534
# (96, 12, 33): 0.06805418001074927
#
# Approximating hitting prob for (97, 12, 12)
# (97, 12, 12): 0.013500331808204945
# (96, 13, 12): 0.02290787790060354
#
# Approximating hitting prob for (97, 12, 24)
# (97, 12, 24): 0.03511884401864076
# (96, 13, 24): 0.0411226220373666
#
# Approximating hitting prob for (97, 12, 36)
# (97, 12, 36): 0.06635354846529987
# (96, 13, 36): 0.07271641859412468
#
# Approximating hitting prob for (97, 12, 48)
# (97, 12, 48): 0.08450870835506745
# (96, 13, 48): 0.0882842196096752
#
# Approximating hitting prob for (97, 12, 60)
# (97, 12, 60): 0.09703809034918733
# (96, 13, 60): 0.10858533999018667
#
# Approximating hitting prob for (97, 12, 84)
# (97, 12, 84): 0.1272248262576118
# (96, 13, 84): 0.16552479673849652
#
# Approximating hitting prob for (97, 13, 13)
# (97, 13, 13): 0.018634330634577607
# (96, 14, 13): 0.02646546150065109
#
# Approximating hitting prob for (97, 13, 26)
# (97, 13, 26): 0.03897851069875058
# (96, 14, 26): 0.047191667885498785
#
# Approximating hitting prob for (97, 13, 39)
# (97, 13, 39): 0.07510422562793524
# (96, 14, 39): 0.08114687413145784
#
# Approximating hitting prob for (97, 13, 45)
# (97, 13, 45): 0.08273952098943081
# (96, 14, 45): 0.08666996097691078
#
# Approximating hitting prob for (97, 13, 52)
# (97, 13, 52): 0.0891060194177385
# (96, 14, 52): 0.09390791026520322
#
# Approximating hitting prob for (97, 13, 65)
# (97, 13, 65): 0.11014433123176208
# (96, 14, 65): 0.11503726010781092
#
# Approximating hitting prob for (97, 14, 14)
# (97, 14, 14): 0.024049807483671623
# (96, 15, 14): 0.02986282049913022
#
# Approximating hitting prob for (97, 15, 15)
# (97, 15, 15): 0.02471850671904843
# (96, 16, 15): 0.03220440545650093
#
# Approximating hitting prob for (97, 15, 30)
# (97, 15, 30): 0.055891512460261805
# (96, 16, 30): 0.06315900289200892
# Approximating hitting prob for (97, 15, 45)
# (97, 15, 45): 0.08352180255552484
# (96, 16, 45): 0.08966256776485843
#
# Approximating hitting prob for (97, 15, 47)
# (97, 15, 47): 0.0881356774730472
# (96, 16, 47): 0.0907361911281931
#
# Approximating hitting prob for (97, 15, 57)
# (97, 15, 57): 0.10697278714102028
# (96, 16, 57): 0.10997610829913214
#
# Approximating hitting prob for (97, 15, 60)
# (97, 15, 60): 0.10976964975829985
# (96, 16, 60): 0.11484503119976537
#
# Approximating hitting prob for (97, 8, 16)
# (97, 8, 16): 0.02069608386034902
# (96, 9, 16): 0.024144006972485563
#
# Approximating hitting prob for (97, 16, 16)
# (97, 16, 16): 0.02521587511707292
# (96, 17, 16): 0.041990486082088684
#
# Approximating hitting prob for (97, 16, 32)
# (97, 16, 32): 0.05963327124289634
# (96, 17, 32): 0.07613889994226451
#
# Approximating hitting prob for (97, 16, 48)
# (97, 16, 48): 0.08579654861047453
# (96, 17, 48): 0.1020819454075394
#
# Approximating hitting prob for (97, 16, 58)
# (97, 16, 58): 0.10850221784333312
# (96, 17, 58): 0.11352413339412652
#
# Approximating hitting prob for (97, 16, 64)
# (97, 16, 64): 0.11354124880448059
# (96, 17, 64): 0.1223567089935601
#
# Approximating hitting prob for (97, 16, 80)
# (97, 16, 80): 0.130045845365448
# (96, 17, 80): 0.16943531935970255
#
# Approximating hitting prob for (97, 17, 17)
# (97, 17, 17): 0.03180163296724422
# (96, 18, 17): 0.04533321517781299
#
# Approximating hitting prob for (97, 17, 34)
# (97, 17, 34): 0.07297904867172787
# (96, 18, 34): 0.07856644432432962
#
# Approximating hitting prob for (97, 17, 51)
# (97, 17, 51): 0.10186518943207878
# (96, 18, 51): 0.10662117248596847
#
# Approximating hitting prob for (98, 6, 17)
# (98, 6, 17): 0.019779839151945075
# (97, 7, 17): 0.02239052253889014
#
# Approximating hitting prob for (97, 18, 18)
# (97, 18, 18): 0.03262798652490453
# (96, 19, 18): 0.046911052730503076
#
# Approximating hitting prob for (97, 18, 36)
# (97, 18, 36): 0.07461324375127555
# (96, 19, 36): 0.0822650171899688
#
# Approximating hitting prob for (97, 18, 50)
# (97, 18, 50): 0.10367586057517604
# (96, 19, 50): 0.10561334213757628
#
# Approximating hitting prob for (97, 18, 54)
# (97, 18, 54): 0.10403718472965484
# (96, 19, 54): 0.11108659383171615
#
# Approximating hitting prob for (97, 19, 19)
# (97, 19, 19): 0.03397644884691348
# (96, 20, 19): 0.049084732220058436
#
# Approximating hitting prob for (97, 19, 38)
# (97, 19, 38): 0.07557493327967764
# (96, 20, 38): 0.09644702032661583
#
# Approximating hitting prob for (97, 19, 51)
# (97, 19, 51): 0.10556983868229274
# (96, 20, 51): 0.10869686303130892
#
# Approximating hitting prob for (97, 19, 57)
# (97, 19, 57): 0.10869955673835584
# (96, 20, 57): 0.11957276131138145
#
# Approximating hitting prob for (97, 19, 63)
# (97, 19, 63): 0.12193729394505994
# (96, 20, 63): 0.12557436523449092
#
# Approximating hitting prob for (97, 19, 76)
# (97, 19, 76): 0.13095863149073397
# (96, 20, 76): 0.1593245870966375
#
# Approximating hitting prob for (97, 5, 20)
# (97, 5, 20): 0.020769567024885447
# (96, 6, 20): 0.02404759094569579
#
# Approximating hitting prob for (98, 10, 19)
# (98, 10, 19): 0.027624049305732982
# (97, 11, 19): 0.02880230004051225
#
# Approximating hitting prob for (98, 19, 20)
# (98, 19, 20): 0.04804513816214176
# (97, 20, 20): 0.036104123178910756
#
# Approximating hitting prob for (98, 19, 30)
# (98, 19, 30): 0.06634290391551308
# (97, 20, 30): 0.06594146652772812
#
# Approximating hitting prob for (98, 20, 21)
# (98, 20, 21): 0.04984200163238106
# (97, 21, 21): 0.03820185688630826
#
# Approximating hitting prob for (98, 20, 42)
# (98, 20, 42): 0.10235028141850622
# (97, 21, 42): 0.09584365192520217
#
# Approximating hitting prob for (98, 20, 53)
# (98, 20, 53): 0.1109971452661999
# (97, 21, 53): 0.10977435721071643
#
# Approximating hitting prob for (98, 20, 63)
# (98, 20, 63): 0.12376336236660068
# (97, 21, 63): 0.12160890340886941
#
# Approximating hitting prob for (98, 20, 84)
# (98, 20, 84): 0.1745238990286165
# (97, 21, 84): 0.17399123186148321
#
# Approximating hitting prob for (98, 21, 22)
# (98, 21, 22): 0.052152720914593075
# (97, 22, 22): 0.039326432316557434
#
# Approximating hitting prob for (98, 21, 44)
# (98, 21, 44): 0.10484407916293242
# (97, 22, 44): 0.09748237645856728
#
# Approximating hitting prob for (98, 21, 66)
# (98, 21, 66): 0.12701535894964716
# (97, 22, 66): 0.1244679342654777
#
# Approximating hitting prob for (98, 21, 68)
# (98, 21, 68): 0.12987402048977306
# (97, 22, 68): 0.12989429007111808
#
# Approximating hitting prob for (98, 21, 88)
# (98, 21, 88): 0.18222149854789002
# (97, 22, 88): 0.1812957505872946
#
# Approximating hitting prob for (98, 22, 23)
# (98, 22, 23): 0.05389593548696441
# (97, 23, 23): 0.041295380046120524
#
# Approximating hitting prob for (98, 22, 46)
# (98, 22, 46): 0.10750418705197302
# (97, 23, 46): 0.10053518417736153
#
# Approximating hitting prob for (98, 22, 55)
# (98, 22, 55): 0.12155818993056876
# (97, 23, 55): 0.11992483265534376
#
# Approximating hitting prob for (98, 22, 69)
# (98, 22, 69): 0.1300751030585257
# (97, 23, 69): 0.126918151195394
#
# Approximating hitting prob for (98, 22, 70)
# (98, 22, 70): 0.13206118237542855
# (97, 23, 70): 0.13157003217615312
#
# Approximating hitting prob for (98, 12, 23)
# (98, 12, 23): 0.03739208017780668
# (97, 13, 23): 0.0388167269267747
#
# Approximating hitting prob for (98, 23, 24)
# (98, 23, 24): 0.05614426451806855
# (97, 24, 24): 0.04212173483750922
#
# Approximating hitting prob for (98, 23, 36)
# (98, 23, 36): 0.09396396327032928
# (97, 24, 36): 0.09344354104102297
#
# Approximating hitting prob for (98, 23, 40)
# (98, 23, 40): 0.09881797586935155
# (97, 24, 40): 0.09875108661118258
#
# Approximating hitting prob for (98, 23, 48)
# (98, 23, 48): 0.10958088005845902
# (97, 24, 48): 0.10227568922183113
#
# Approximating hitting prob for (98, 23, 56)
# (98, 23, 56): 0.12229447683439965
# (97, 24, 56): 0.12105519877364179
#
# Approximating hitting prob for (98, 23, 72)
# (98, 23, 72): 0.1340436756105776
# (97, 24, 72): 0.12820719664051064
#
# Approximating hitting prob for (98, 23, 96)
# (98, 23, 96): 0.1959806491764644
# (97, 24, 96): 0.19533225253438466
#
# Approximating hitting prob for (98, 24, 25)
# (98, 24, 25): 0.06468000911842033
# (97, 25, 25): 0.05903687905596428
#
# Approximating hitting prob for (98, 24, 50)
# (98, 24, 50): 0.11418648991705697
# (97, 25, 50): 0.1075980048214457
#
# Approximating hitting prob for (97, 26, 26)
# (97, 26, 26): 0.05994055026339337
# (96, 27, 26): 0.07578771667380911
#
# Approximating hitting prob for (97, 26, 52)
# (97, 26, 52): 0.10962588148780628
# (96, 27, 52): 0.12115791729337633
#
# Approximating hitting prob for (97, 26, 58)
# (97, 26, 58): 0.1260510925091671
# (96, 27, 58): 0.12896568595207772
#
# Approximating hitting prob for (97, 26, 74)
# (97, 26, 74): 0.17572815206501827
# (96, 27, 74): 0.17686260357785757
#
# Approximating hitting prob for (97, 26, 78)
# (97, 26, 78): 0.17439403392320577
# (96, 27, 78): 0.18284742855692418
#
# Approximating hitting prob for (97, 9, 27)
# (97, 9, 27): 0.03660383802996675
# (96, 10, 27): 0.04206470648486867
#
# Approximating hitting prob for (97, 27, 27)
# (97, 27, 27): 0.06181006219732233
# (96, 28, 27): 0.077944609866627
#
# Approximating hitting prob for (97, 27, 54)
# (97, 27, 54): 0.11489179709176346
# (96, 28, 54): 0.12500883217302258
#
# Approximating hitting prob for (97, 27, 59)
# (97, 27, 59): 0.12892379196833276
# (96, 28, 59): 0.1304996106179087
#
# Approximating hitting prob for (97, 27, 75)
# (97, 27, 75): 0.1768663154726802
# (96, 28, 75): 0.1785264014611366
#
# Approximating hitting prob for (97, 27, 77)
# (97, 27, 77): 0.180007275433725
# (96, 28, 77): 0.18119949760570395
#
# Approximating hitting prob for (97, 27, 81)
# (97, 27, 81): 0.17737281915663158
# (96, 28, 81): 0.18543787659092162
#
# Approximating hitting prob for (97, 28, 28)
# (97, 28, 28): 0.06408795150440603
# (96, 29, 28): 0.08044160650809176
#
# Approximating hitting prob for (97, 28, 56)
# (97, 28, 56): 0.11742193552711506
# (96, 29, 56): 0.12805426937604766
#
# Approximating hitting prob for (97, 28, 60)
# (97, 28, 60): 0.13064748420483638
# (96, 29, 60): 0.13241986727844904
#
# Approximating hitting prob for (97, 28, 76)
# (97, 28, 76): 0.17824024392927215
# (96, 29, 76): 0.1798708186450689
#
# Approximating hitting prob for (97, 28, 78)
# (97, 28, 78): 0.181091121272248
# (96, 29, 78): 0.18346065752358187
#
# Approximating hitting prob for (97, 28, 84)
# (97, 28, 84): 0.18294567329998812
# (96, 29, 84): 0.19163757657414493
#
# Approximating hitting prob for (97, 29, 29)
# (97, 29, 29): 0.06487195546022868
# (96, 30, 29): 0.08436130470003145
# Approximating hitting prob for (97, 29, 58)
# (97, 29, 58): 0.11967698157905766
# (96, 30, 58): 0.13222720414119654
#
# Approximating hitting prob for (97, 29, 61)
# (97, 29, 61): 0.13220559976168075
# (96, 30, 61): 0.13365957180684904
#
# Approximating hitting prob for (97, 29, 77)
# (97, 29, 77): 0.17959248449818468
# (96, 30, 77): 0.1816660332826945
#
# Approximating hitting prob for (97, 29, 87)
# (97, 29, 87): 0.18510998130780543
# (96, 30, 87): 0.1973451541977782
#
# Approximating hitting prob for (98, 15, 29)
# (98, 15, 29): 0.057938282924055645
# (97, 16, 29): 0.0593847958630045
#
# Approximating hitting prob for (98, 29, 30)
# (98, 29, 30): 0.08196921943116936
# (97, 30, 30): 0.06832930867877104
#
# Approximating hitting prob for (98, 29, 60)
# (98, 29, 60): 0.13088751579503158
# (97, 30, 60): 0.12358317690323382
#
# Approximating hitting prob for (97, 30, 78)
# (97, 30, 78): 0.18141366361399655
# (96, 31, 78): 0.18311578585014968
#
# Approximating hitting prob for (97, 30, 90)
# (97, 30, 90): 0.1919805762274387
# (96, 31, 90): 0.201372897043114
#
# Approximating hitting prob for (97, 31, 31)
# (97, 31, 31): 0.07025962476096291
# (96, 32, 31): 0.09760840948546318
#
# Approximating hitting prob for (97, 31, 62)
# (97, 31, 62): 0.12535598778491513
# (96, 32, 62): 0.14490082158899667
#
# Approximating hitting prob for (97, 31, 63)
# (97, 31, 63): 0.13465859484633977
# (96, 32, 63): 0.14520220840923118
#
# Approximating hitting prob for (97, 31, 93)
# (97, 31, 93): 0.1962204101269848
# (96, 32, 93): 0.2139846168783761
#
# Approximating hitting prob for (98, 16, 31)
# (98, 16, 31): 0.06201464713774082
# (97, 17, 31): 0.06553135788118747
#
# Approximating hitting prob for (98, 31, 32)
# (98, 31, 32): 0.08749161368058404
# (97, 32, 32): 0.07150345651989669
#
# Approximating hitting prob for (98, 31, 48)
# (98, 31, 48): 0.12026037637947014
# (97, 32, 48): 0.11945841866390754
#
# Approximating hitting prob for (98, 31, 64)
# (98, 31, 64): 0.13703004025630186
# (97, 32, 64): 0.1264770760999147
#
# Approximating hitting prob for (98, 31, 80)
# (98, 31, 80): 0.18499323757268984
# (97, 32, 80): 0.1840126507165998
#
# Approximating hitting prob for (98, 31, 85)
# (98, 31, 85): 0.19214263518610133
# (97, 32, 85): 0.19206454067389178
#
# Approximating hitting prob for (98, 31, 96)
# (98, 31, 96): 0.20524857172348218
# (97, 32, 96): 0.19907647442684204
#
# Approximating hitting prob for (98, 32, 33)
# (98, 32, 33): 0.10072903211343405
# (97, 33, 33): 0.09712540859552199
#
# Approximating hitting prob for (97, 34, 34)
# (97, 34, 34): 0.09785015850788602
# (96, 35, 34): 0.11551973814907958
#
# Approximating hitting prob for (97, 34, 51)
# (97, 34, 51): 0.13435152403681141
# (96, 35, 51): 0.13918072631796427
#
# Approximating hitting prob for (97, 34, 68)
# (97, 34, 68): 0.17749628758459565
# (96, 35, 68): 0.18755478719667126
#
# Approximating hitting prob for (97, 34, 82)
# (97, 34, 82): 0.20080784331314191
# (96, 35, 82): 0.2020228068356765
#
# Approximating hitting prob for (97, 34, 88)
# (97, 34, 88): 0.2095531866572884
# (96, 35, 88): 0.21228855871988914
#
# Approximating hitting prob for (97, 35, 35)
# (97, 35, 35): 0.09865757963333242
# (96, 36, 35): 0.11658165412878885
#
# Approximating hitting prob for (97, 35, 67)
# (97, 35, 67): 0.18413906418598192
# (96, 36, 67): 0.18565513765565686
#
# Approximating hitting prob for (97, 35, 70)
# (97, 35, 70): 0.17912698527798218
# (96, 36, 70): 0.18940002586370216
#
# Approximating hitting prob for (97, 35, 83)
# (97, 35, 83): 0.2020038677335834
# (96, 36, 83): 0.2030976136115079
#
# Approximating hitting prob for (98, 12, 35)
# (98, 12, 35): 0.06873249023020447
# (97, 13, 35): 0.07184325639310339
#
# Approximating hitting prob for (98, 24, 35)
# (98, 24, 35): 0.09378979697324734
# (97, 25, 35): 0.09500417148283415
#
# Approximating hitting prob for (98, 35, 36)
# (98, 35, 36): 0.11590426165863738
# (97, 36, 36): 0.09939857940290618
