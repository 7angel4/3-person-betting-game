# %%
# %run 'game1_global.ipynb'
# %run 'game1_loser_analysis.ipynb'

# %% [markdown]
# # When is player 1 better off giving away $1?

# %%
betterGiving1 = findBetterGiving1(1,1000)
betterGiving1

# %%
exportStateProbs(DATA_DIR + 'game1_better_giving_1_memo_1-1000.csv', betterGiving1)

# %%
# retrieve probabilities from file
betterGiving1, given1 = readApproxBetterGiving1Probs(DATA_DIR + 'game1_better_giving_1_memo_1-100.csv')

# %%
betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
                                       filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv')
# Out:
# Approximating hitting prob for (11, 19, 48)
# (11, 19, 48): 0.5334260883826906
# (10, 19, 48): 0.5333426632228018
#
# Approximating hitting prob for (12, 21, 53)
# (12, 21, 53): 0.5340626283748265
# (11, 21, 53): 0.5334548685835285
#
# Approximating hitting prob for (12, 32, 42)
# (12, 32, 42): 0.5301153617677242
# (11, 32, 42): 0.5299467192997049
#
# Approximating hitting prob for (13, 22, 56)
# (13, 22, 56): 0.5328628830327213
# (12, 22, 56): 0.532734806781722
#
# Approximating hitting prob for (13, 23, 58)
# (13, 23, 58): 0.5343093271797525
# (12, 23, 58): 0.5335330764863161
#
# Approximating hitting prob for (13, 35, 46)
# (13, 35, 46): 0.5303291922468697
# (12, 35, 46): 0.5299937351500015
#
# Approximating hitting prob for (14, 24, 61)
# (14, 24, 61): 0.5334281050874531
# (13, 24, 61): 0.532844623278078
#
# Approximating hitting prob for (14, 25, 63)
# (14, 25, 63): 0.534598505539718
# (13, 25, 63): 0.5335740856592848
#
# Approximating hitting prob for (14, 38, 50)
# (14, 38, 50): 0.5306453312687435
# (13, 38, 50): 0.5300535494230575
#
# Approximating hitting prob for (15, 26, 66)
# (15, 26, 66): 0.5335384252806683
# (14, 26, 66): 0.532976559038264
#
# Approximating hitting prob for (15, 27, 68)
# (15, 27, 68): 0.5347937376379311
# (14, 27, 68): 0.5336038259570041
#
# Approximating hitting prob for (15, 40, 52)
# (15, 40, 52): 0.5298390830172897
# (14, 40, 52): 0.5294060634902246
#
# Approximating hitting prob for (15, 41, 54)
# (15, 41, 54): 0.530814252978444
# (14, 41, 54): 0.5300859465232839
#
# Approximating hitting prob for (16, 27, 69)
# (16, 27, 69): 0.5327214805171471
# (15, 27, 69): 0.5323471322790065
#
# Approximating hitting prob for (16, 28, 71)
# (16, 28, 71): 0.533984832978568
# (15, 28, 71): 0.5330636314503749
#
# Approximating hitting prob for (16, 29, 73)
# (16, 29, 73): 0.5349109988994238
# (15, 29, 73): 0.5336260136575318
#
# Approximating hitting prob for (16, 42, 54)
# (16, 42, 54): 0.528455476635441
# (15, 42, 54): 0.5285157285081951
#
# Approximating hitting prob for (16, 43, 56)
# (16, 43, 56): 0.5300165256608894
# (15, 43, 56): 0.5295344851774494
#
# Approximating hitting prob for (16, 44, 58)
# (16, 44, 58): 0.5309755142180325
# (15, 44, 58): 0.5301059314171186
#
# Approximating hitting prob for (17, 29, 74)
# (17, 29, 74): 0.5332717628242919
# (16, 29, 74): 0.5324865172144486
#
# Approximating hitting prob for (17, 30, 76)
# (17, 30, 76): 0.5341834675713876
# (16, 30, 76): 0.5331293350131605
#
# Approximating hitting prob for (17, 31, 78)
# (17, 31, 78): 0.535032026741298
# (16, 31, 78): 0.5336384909534596
#
# Approximating hitting prob for (17, 44, 56)
# (17, 44, 56): 0.5279972266134371
# (16, 44, 56): 0.5279422800090446
#
# Approximating hitting prob for (17, 45, 58)
# (17, 45, 58): 0.529004914693246
# (16, 45, 58): 0.528895160602941
#
# Approximating hitting prob for (17, 46, 60)
# (17, 46, 60): 0.5301804342251579
# (16, 46, 60): 0.5296194711867167
#
# Approximating hitting prob for (17, 47, 62)
# (17, 47, 62): 0.5311378673662993
# (16, 47, 62): 0.5301263625686753
#
# Approximating hitting prob for (18, 27, 71)
# (18, 27, 71): 0.525620501017532
# (17, 27, 71): 0.5254981980685945
#
# Approximating hitting prob for (18, 28, 73)
# (18, 28, 73): 0.5271004988262395
# (17, 28, 73): 0.5270411065910542
#
# Approximating hitting prob for (18, 31, 79)
# (18, 31, 79): 0.5335270635741508
# (17, 31, 79): 0.5326072076759126
#
# Approximating hitting prob for (18, 32, 81)
# (18, 32, 81): 0.5344121912790228
# (17, 32, 81): 0.5332080138741222
#
# Approximating hitting prob for (18, 33, 83)
# (18, 33, 83): 0.5351589143653502
# (17, 33, 83): 0.5336649245359243
#
# Approximating hitting prob for (18, 45, 56)
# (18, 45, 56): 0.5255722330999105
# (17, 45, 56): 0.5254786841463105
#
# Approximating hitting prob for (18, 47, 60)
# (18, 47, 60): 0.5284828625145415
# (17, 47, 60): 0.5281888889502253
#
# Approximating hitting prob for (18, 48, 62)
# (18, 48, 62): 0.5294526933438758
# (17, 48, 62): 0.5290045013080626
#
# Approximating hitting prob for (18, 49, 64)
# (18, 49, 64): 0.5304295920255223
# (17, 49, 64): 0.5297020995866109
#
# Approximating hitting prob for (18, 50, 66)
# (18, 50, 66): 0.5312826982045813
# (17, 50, 66): 0.5301457096165415
#
# Approximating hitting prob for (19, 20, 58)
# (19, 20, 58): 0.5076781471384154
# (18, 20, 58): 0.507459734940809
#
# Approximating hitting prob for (19, 32, 82)
# (19, 32, 82): 0.5327246501234508
# (18, 32, 82): 0.5320769507714677
#
# Approximating hitting prob for (19, 33, 84)
# (19, 33, 84): 0.5335489429772609
# (18, 33, 84): 0.532734806781722
#
# Approximating hitting prob for (19, 34, 86)
# (19, 34, 86): 0.5345634156030413
# (18, 34, 86): 0.5332648124986303
#
# Approximating hitting prob for (19, 35, 88)
# (19, 35, 88): 0.5345634156030413
# (18, 35, 88): 0.5332648124986303
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/659592125.py:18, in stricterFilter(candidates, timeLim, t, printOnGo, filename, continueFrom)
#      17 try:
# ---> 18     pLarge = LoserAnalysis(sLarge).getHittingProb()  # exact probs
#      19     pSmall = LoserAnalysis(sSmall).getHittingProb()
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:68, in LoserAnalysis.getHittingProb(self, asFloat, approx, t)
#      66     return Q(x, y, z, t)
# ---> 68 sol = self.solveEqns()
#      69 if sol:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:46, in LoserAnalysis.solveEqns(self, asFloat)
#      45 self.getEquations()
# ---> 46 sol = solve(self.equations, self.symbols)
#      47 return {s:float(p) for s, p in sol.items() if sol} if asFloat else sol
#
# File /usr/local/lib/python3.9/site-packages/sympy/solvers/solvers.py:1147, in solve(f, *symbols, **flags)
#    1146 else:
# -> 1147     linear, solution = _solve_system(f, symbols, **flags)
#    1148 assert type(solution) is list
#
# File /usr/local/lib/python3.9/site-packages/sympy/solvers/solvers.py:1799, in _solve_system(exprs, symbols, **flags)
#    1797     continue
# -> 1799 poly = g.as_poly(*symbols, extension=True)
#    1801 if poly is not None:
#
# File /usr/local/lib/python3.9/site-packages/sympy/core/expr.py:1102, in Expr.as_poly(self, *gens, **args)
#    1101 try:
# -> 1102     poly = Poly(self, *gens, **args)
#    1104     if not poly.is_Poly:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:182, in Poly.__new__(cls, rep, *gens, **args)
#     181 else:
# --> 182     return cls._from_expr(rep, opt)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:312, in Poly._from_expr(cls, rep, opt)
#     311 rep, opt = _dict_from_expr(rep, opt)
# --> 312 return cls._from_dict(rep, opt)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:261, in Poly._from_dict(cls, rep, opt)
#     259         rep[monom] = domain.convert(coeff)
# --> 261 return cls.new(DMP.from_dict(rep, level, domain), *gens)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polyclasses.py:279, in DMP.from_dict(cls, rep, lev, dom)
#     278 """Construct and instance of ``cls`` from a ``dict`` representation. """
# --> 279 return cls(dmp_from_dict(rep, lev, dom), dom, lev)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
#     [... skipping similar frames: dmp_from_dict at line 1012 (2958 times)]
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:998, in dmp_from_dict(f, u, K)
#     996 coeffs = {}
# --> 998 for monom, coeff in f.items():
#     999     head, tail = monom[0], monom[1:]
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# TimeoutException                          Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
#       2                                        filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv')
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/659592125.py:23, in stricterFilter(candidates, timeLim, t, printOnGo, filename, continueFrom)
#      21 except (TimeoutException, RecursionError):
#      22     print(f'Approximating hitting prob for {sLarge}')
# ---> 23     pLarge = LoserAnalysis(sLarge).getHittingProb(approx=True, t=t)
#      24     pSmall = LoserAnalysis(sSmall).getHittingProb(approx=True, t=t)
#      26 finally:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:66, in LoserAnalysis.getHittingProb(self, asFloat, approx, t)
#      64 if approx:
#      65     x, y, z = self.initState
# ---> 66     return Q(x, y, z, t)
#      68 sol = self.solveEqns()
#      69 if sol:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:31, in Q(x, y, z, t)
#      29 if x==0: return 1
#      30 if z*y==0: return 0
# ---> 31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
#      33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:31, in Q(x, y, z, t)
#      29 if x==0: return 1
#      30 if z*y==0: return 0
# ---> 31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
#      33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
#     [... skipping similar frames: memoize.<locals>.memodict.__call__ at line 8 (11 times), <genexpr> at line 33 (10 times), Q at line 33 (10 times), memoize.<locals>.memodict.__missing__ at line 11 (10 times)]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2027475117.py:12, in sigalarmHandler(signum, frame)
#       8 """
#       9 Handler function to be called when SIGALRM is received.
#      10 """
#      11 # We get signal!
# ---> 12 raise TimeoutException()
#
# TimeoutException:

# %%
betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
                                       filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv',
                                       continueFrom=(69,64,100))
# Out:
# Approximating hitting prob for (70, 12, 93)
# (70, 12, 93): 0.27064890356707977
# (69, 12, 93): 0.2704508979612977
#
# Approximating hitting prob for (70, 13, 95)
# (70, 13, 95): 0.273002814385276
# (69, 13, 95): 0.2728333555110289
#
# Approximating hitting prob for (70, 15, 99)
# (70, 15, 99): 0.2777183843625525
# (69, 15, 99): 0.27732957441332723
#
# Approximating hitting prob for (70, 30, 84)
# (70, 30, 84): 0.2928672871530125
# (69, 30, 84): 0.29290071879804375
#
# Approximating hitting prob for (70, 50, 94)
# (70, 50, 94): 0.32695735265836573
# (69, 50, 94): 0.3267132634013896
#
# Approximating hitting prob for (70, 58, 98)
# (70, 58, 98): 0.3430616778838396
# (69, 58, 98): 0.3428394039934912
#
# Approximating hitting prob for (70, 60, 99)
# (70, 60, 99): 0.34560612414415176
# (69, 60, 99): 0.34492499438010804
#
# Approximating hitting prob for (70, 84, 90)
# (70, 84, 90): 0.4148018936715927
# (69, 84, 90): 0.41468720846314083
#
# Approximating hitting prob for (71, 12, 94)
# (71, 12, 94): 0.27043453644878807
# (70, 12, 94): 0.2702550831661171
#
# Approximating hitting prob for (71, 15, 100)
# (71, 15, 100): 0.2774240055525448
# (70, 15, 100): 0.27714908068396565
#
# Approximating hitting prob for (71, 36, 88)
# (71, 36, 88): 0.3107284046458855
# (70, 36, 88): 0.3107029569244443
#
# Approximating hitting prob for (71, 44, 92)
# (71, 44, 92): 0.31946810865446534
# (70, 44, 92): 0.31933447137280896
#
# Approximating hitting prob for (71, 52, 96)
# (71, 52, 96): 0.3287350571698488
# (70, 52, 96): 0.32848900976647166
#
# Approximating hitting prob for (71, 60, 100)
# (71, 60, 100): 0.3432269284144038
# (70, 60, 100): 0.3428263666917539
#
# Approximating hitting prob for (72, 14, 99)
# (72, 14, 99): 0.27369224353294386
# (71, 14, 99): 0.27347335165357634
#
# Approximating hitting prob for (72, 40, 91)
# (72, 40, 91): 0.3129742549703007
# (71, 40, 91): 0.31282979281170153
#
# Approximating hitting prob for (72, 46, 94)
# (72, 46, 94): 0.32065055730266634
# (71, 46, 94): 0.32060860453920875
#
# Approximating hitting prob for (72, 50, 96)
# (72, 50, 96): 0.32548552599084296
# (71, 50, 96): 0.32522123422559995
#
# Approximating hitting prob for (72, 54, 98)
# (72, 54, 98): 0.33015250293768666
# (71, 54, 98): 0.3299310590778092
#
# Approximating hitting prob for (73, 11, 94)
# (73, 11, 94): 0.26568088778907833
# (72, 11, 94): 0.26555372470314254
#
# Approximating hitting prob for (73, 13, 98)
# (73, 13, 98): 0.2712824779940791
# (72, 13, 98): 0.27092732614422377
#
# Approximating hitting prob for (73, 14, 100)
# (73, 14, 100): 0.2735392177539206
# (72, 14, 100): 0.2733296833190661
#
# Approximating hitting prob for (73, 26, 85)
# (73, 26, 85): 0.2838182327188731
# (72, 26, 85): 0.2838382526274032
#
# Approximating hitting prob for (73, 40, 92)
# (73, 40, 92): 0.31265646156970867
# (72, 40, 92): 0.31256600858492634
#
# Approximating hitting prob for (73, 44, 94)
# (73, 44, 94): 0.31905281367702304
# (72, 44, 94): 0.31898130581150774
#
# Approximating hitting prob for (74, 12, 97)
# (74, 12, 97): 0.26803823241416097
# (73, 12, 97): 0.2678146488650772
#
# Approximating hitting prob for (74, 13, 99)
# (74, 13, 99): 0.27106341315623816
# (73, 13, 99): 0.2708043750088058
#
# Approximating hitting prob for (74, 30, 88)
# (74, 30, 88): 0.29121346643802504
# (73, 30, 88): 0.2911904861374854
#
# Approximating hitting prob for (74, 40, 93)
# (74, 40, 93): 0.3124715276947375
# (73, 40, 93): 0.3123265733297223
#
# Approximating hitting prob for (74, 46, 96)
# (74, 46, 96): 0.3194592906289733
# (73, 46, 96): 0.31936096416339166
#
# Approximating hitting prob for (74, 52, 99)
# (74, 52, 99): 0.32609715069378836
# (73, 52, 99): 0.32593271890358366
#
# Approximating hitting prob for (74, 54, 100)
# (74, 54, 100): 0.3285392810102394
# (73, 54, 100): 0.32834877261967127
#
# Approximating hitting prob for (75, 13, 100)
# (75, 13, 100): 0.2708561821230972
# (74, 13, 100): 0.27060467983388525
#
# Approximating hitting prob for (75, 38, 93)
# (75, 38, 93): 0.3107255922584125
# (74, 38, 93): 0.3106856959891582
#
# Approximating hitting prob for (75, 40, 94)
# (75, 40, 94): 0.31219750777533284
# (74, 40, 94): 0.31212211416489793
#
# Approximating hitting prob for (75, 48, 98)
# (75, 48, 98): 0.3206660566987458
# (74, 48, 98): 0.3206193374288369
#
# Approximating hitting prob for (75, 52, 100)
# (75, 52, 100): 0.32543894655115896
# (74, 52, 100): 0.3251891291627604
#
# Approximating hitting prob for (76, 42, 96)
# (76, 42, 96): 0.31283229353690856
# (75, 42, 96): 0.31269685409230785
#
# Approximating hitting prob for (77, 42, 97)
# (77, 42, 97): 0.31263411481005815
# (76, 42, 97): 0.3124896740010894
#
# Approximating hitting prob for (78, 42, 98)
# (78, 42, 98): 0.312441399741017
# (77, 42, 98): 0.3119828040723916
#
# Approximating hitting prob for (79, 32, 94)
# (79, 32, 94): 0.2912337154122105
# (78, 32, 94): 0.2911642829888588
#
# Approximating hitting prob for (79, 40, 98)
# (79, 40, 98): 0.31073467566545016
# (78, 40, 98): 0.31068391480047436
#
# Approximating hitting prob for (79, 42, 99)
# (79, 42, 99): 0.3121670959474713
# (78, 42, 99): 0.3120607193357822
#
# Approximating hitting prob for (79, 44, 100)
# (79, 44, 100): 0.3130463381703828
# (78, 44, 100): 0.3128490513416133
#
# Approximating hitting prob for (82, 34, 98)
# (82, 34, 98): 0.2917812876569657
# (81, 34, 98): 0.29172992113254753
#
# Approximating hitting prob for (84, 30, 98)
# (84, 30, 98): 0.2839368557613289
# (83, 30, 98): 0.2838357734914572
#
# Approximating hitting prob for (84, 34, 100)
# (84, 34, 100): 0.29123192191006453
# (83, 34, 100): 0.2911447291167216
#
# Approximating hitting prob for (93, 47, 62)
# (93, 47, 62): 0.2078449082948937
# (92, 47, 62): 0.20783817692579917
#
# Approximating hitting prob for (93, 47, 98)
# (93, 47, 98): 0.3020413154785515
# (92, 47, 98): 0.3020379983481061
#
# Approximating hitting prob for (95, 48, 100)
# (95, 48, 100): 0.30201302025080573
# (94, 48, 100): 0.30196433138324996
#
# Approximating hitting prob for (99, 50, 66)
# (99, 50, 66): 0.2078419114332157
# (98, 50, 66): 0.2078180397808808
#
# Approximating hitting prob for (100, 51, 67)
# (100, 51, 67): 0.2080190772886974
# (99, 51, 67): 0.20801576587712575

# %%
class TimeoutException(Exception):
    """
    Custom exception for timeout.
    """
    pass

def sigalarmHandler(signum, frame):
    """
    Handler function to be called when SIGALRM is received.
    """
    # We get signal!
    raise TimeoutException()

# %% [markdown]
# ## When is player 1 better off giving away $1 to another player?

# %%
betterGiving1ToAnother = findBetterGiving1(1,100, t=10, giveToAnother=True)
betterGiving1ToAnother
# Out:
# {(1, 5, 5): 0.5004434876119833,
#  (2, 4, 5): 0.5015168645690443,
#  (1, 6, 6): 0.506093654740131,
#  (2, 5, 6): 0.5184847144955884,
#  (1, 7, 7): 0.5131205254322682,
#  (2, 6, 7): 0.5396071019936831,
#  (1, 8, 8): 0.5177187986883774,
#  (2, 7, 8): 0.553386673567715,
#  (1, 9, 9): 0.5198030383135193,
#  (2, 8, 9): 0.5596511014686955,
#  (1, 10, 10): 0.521353326527545,
#  (2, 9, 10): 0.5643071756348541,
#  (1, 11, 11): 0.5225738105217701,
#  (2, 10, 11): 0.5679767313216567,
#  (1, 12, 12): 0.5237380978085997,
#  (2, 11, 12): 0.5714793837797846,
#  (1, 12, 36): 0.6316713165390184,
#  (2, 11, 36): 0.6317622599451304,
#  (1, 13, 13): 0.5248276325593998,
#  (2, 12, 13): 0.5747622273980084,
#  (1, 13, 39): 0.6325682808186844,
#  (2, 12, 39): 0.6347403712118326,
#  (1, 14, 14): 0.5256858644409728,
#  (2, 13, 14): 0.57733900685236,
#  (1, 14, 42): 0.6333982655030145,
#  (2, 13, 42): 0.6366529115385103,
#  (1, 15, 15): 0.5268432387720368,
#  (2, 14, 15): 0.5808387485922709,
#  (1, 15, 45): 0.63421194355006,
#  (2, 14, 45): 0.6395029512036614,
#  (1, 16, 16): 0.5279858610539553,
#  (2, 15, 16): 0.5842379051719758,
#  (1, 16, 48): 0.635051999980948,
#  (2, 15, 48): 0.6419747628823096,
#  (1, 17, 17): 0.5283821156475977,
#  (2, 16, 17): 0.5854285708426477,
#  (1, 17, 51): 0.6353974162348219,
#  (2, 16, 51): 0.6431331129655032,
#  (1, 18, 18): 0.5286972339709394,
#  (2, 17, 18): 0.586367542078401,
#  (1, 18, 54): 0.635696343688081,
#  (2, 17, 54): 0.6438519942124338,
#  (1, 19, 19): 0.5290239620908059,
#  (2, 18, 19): 0.5873462049262054,
#  (1, 19, 57): 0.6359734242165406,
#  (2, 18, 57): 0.644798126476528,
#  (1, 20, 20): 0.5292680655049197,
#  (2, 19, 20): 0.5880847500592729,
#  (1, 20, 60): 0.6362249863460855,
#  (2, 19, 60): 0.6453717860378668,
#  (1, 21, 21): 0.5295149142555335,
#  (2, 20, 21): 0.588833317324383,
#  (1, 21, 63): 0.6364634998581686,
#  (2, 20, 63): 0.6461849514015902,
#  (1, 21, 64): 0.646956969794154,
#  (2, 20, 64): 0.6472510681012803,
#  (1, 22, 22): 0.5297588522879303,
#  (2, 21, 22): 0.5895697621096462,
#  (1, 22, 66): 0.6366529446148538,
#  (2, 21, 66): 0.6466174245912294,
#  (1, 22, 67): 0.6471532117394029,
#  (2, 21, 67): 0.647774501235203,
#  (1, 23, 23): 0.5299781484445122,
#  (2, 22, 23): 0.5902254013880421,
#  (1, 23, 69): 0.6368433485854967,
#  (2, 22, 69): 0.6472793649130383,
#  (1, 23, 70): 0.647343764553591,
#  (2, 22, 70): 0.6483569921802232,
#  (1, 24, 24): 0.5301334749530051,
#  (2, 23, 24): 0.5907054714357991,
#  (1, 24, 72): 0.6370145682769819,
#  (2, 23, 72): 0.6476786129157565,
#  (1, 24, 73): 0.6475028948415723,
#  (2, 23, 73): 0.6487869019532507,
#  (1, 25, 25): 0.5303300145853443,
#  (2, 24, 25): 0.5913062701368778,
#  (1, 25, 75): 0.6371719124424207,
#  (2, 24, 75): 0.6482151442816559,
#  (1, 25, 76): 0.6476655808364664,
#  (2, 24, 76): 0.6492909523499552,
#  (1, 26, 26): 0.5305056830450136,
#  (2, 25, 26): 0.5918398411700453,
#  (1, 26, 78): 0.6373261970460974,
#  (2, 25, 78): 0.6485752629701603,
#  (1, 26, 79): 0.6478181289321158,
#  (2, 25, 79): 0.6496998090304239,
#  (1, 27, 27): 0.5306651440964284,
#  (2, 26, 27): 0.5923164712780911,
#  (1, 27, 81): 0.6374779182331624,
#  (2, 26, 81): 0.6491023179636827,
#  (1, 27, 82): 0.6479675843896594,
#  (2, 26, 82): 0.6501630597575742,
#  (1, 28, 28): 0.5308433925108808,
#  (2, 27, 28): 0.5928632397722654,
#  (1, 28, 84): 0.6376227926171485,
#  (2, 27, 84): 0.6494288807018324,
#  (1, 28, 85): 0.6481137818273807,
#  (2, 27, 85): 0.6505545513577707,
#  (1, 29, 29): 0.531019424810327,
#  (2, 28, 29): 0.593397753481219,
#  (1, 29, 87): 0.6377697342725956,
#  (2, 28, 87): 0.6499273246583346,
#  (1, 29, 88): 0.6482600123414454,
#  (2, 28, 88): 0.651006837277092,
#  (1, 30, 30): 0.5311653907136445,
#  (2, 29, 30): 0.5938409764824553,
#  (1, 30, 90): 0.6379076957008163,
#  (2, 29, 90): 0.650248810177776,
#  (1, 30, 91): 0.6483932438525631,
#  (2, 29, 91): 0.6513514100842097,
#  (1, 31, 31): 0.5313585565589595,
#  (2, 30, 31): 0.5944358379798981,
#  (1, 31, 93): 0.6380471455644888,
#  (2, 30, 93): 0.6507426069080341,
#  (1, 31, 94): 0.6485374236333384,
#  (2, 30, 94): 0.6518048371373775,
#  (1, 32, 32): 0.5316609404901015,
#  (2, 31, 32): 0.5953108064912191,
#  (1, 32, 96): 0.6382585695513472,
#  (2, 31, 96): 0.651341801406459,
#  (1, 32, 97): 0.6487406281488678,
#  (2, 31, 97): 0.6524211817198429,
#  (1, 33, 33): 0.5317385375916611,
#  (2, 32, 33): 0.5955452681512389,
#  (1, 33, 99): 0.6383231014972734,
#  (2, 32, 99): 0.6515462628230367,
#  (1, 33, 100): 0.6488068966028214,
#  (2, 32, 100): 0.6526188624860286,
#  (1, 34, 34): 0.5318062779428949,
#  (2, 33, 34): 0.5957485718957984,
#  (1, 35, 35): 0.5318679983996342,
#  (2, 34, 35): 0.5959310706203745,
#  (1, 36, 36): 0.5319251873973311,
#  (2, 35, 36): 0.5961088063515048,
#  (1, 37, 37): 0.5319769849510576,
#  (2, 36, 37): 0.5962632397987264,
#  (1, 38, 38): 0.5320250779543261,
#  (2, 37, 38): 0.5964045750139714,
#  (1, 39, 39): 0.5320778016456672,
#  (2, 38, 39): 0.5965617868740368,
#  (1, 40, 40): 0.5321167325018205,
#  (2, 39, 40): 0.5966842851117292,
#  (1, 41, 41): 0.5321571517934258,
#  (2, 40, 41): 0.5968058406736355,
#  (2, 14, 41): 0.6338000769223442,
#  (1, 42, 42): 0.5322013748645192,
#  (2, 41, 42): 0.5969399487078528,
#  (1, 43, 43): 0.5322408018658233,
#  (2, 42, 43): 0.5970633565449881,
#  (1, 44, 44): 0.5322755651027112,
#  (2, 43, 44): 0.5971704908211825,
#  (2, 15, 44): 0.6355654440591713,
#  (1, 45, 45): 0.5323146613405815,
#  (2, 44, 45): 0.5972896979627089,
#  (1, 46, 46): 0.5323509791656083,
#  (2, 45, 46): 0.5973977583765179,
#  (1, 47, 47): 0.532385014722942,
#  (2, 46, 47): 0.597498806605531,
#  (2, 16, 47): 0.6375855486545072,
#  (1, 48, 48): 0.5324148826610103,
#  (2, 47, 48): 0.5975902130804501,
#  (1, 49, 49): 0.5324444859883317,
#  (2, 48, 49): 0.5976821983913784,
#  (1, 50, 50): 0.5324711785974361,
#  (2, 49, 50): 0.5977623423713782,
#  (2, 17, 50): 0.6383571866691223,
#  (1, 51, 51): 0.5325028988107334,
#  (2, 50, 51): 0.5978603145004572,
#  (1, 52, 52): 0.5325307160155125,
#  (2, 51, 52): 0.597951109063024,
#  (1, 53, 53): 0.5325579709224543,
#  (2, 52, 53): 0.5980328572456773,
#  (2, 18, 53): 0.6393221393725973,
#  (1, 54, 54): 0.5325877396314925,
#  (2, 53, 54): 0.5981236683464157,
#  (1, 55, 55): 0.5326169460426934,
#  (2, 54, 55): 0.5982126271719249,
#  (1, 56, 56): 0.5326397687196227,
#  (2, 55, 56): 0.5982834436230927,
#  (2, 19, 56): 0.639912667869058,
#  (1, 57, 57): 0.5326706620243357,
#  (2, 56, 57): 0.5983790342554488,
#  (1, 58, 58): 0.5326991076796389,
#  (2, 57, 58): 0.5984666865653948,
#  (1, 59, 59): 0.5327241464715744,
#  (2, 58, 59): 0.5985425140825841,
#  (2, 20, 59): 0.6407575699842504,
#  (1, 60, 60): 0.5327515998365764,
#  (2, 59, 60): 0.5986312082973463,
#  (1, 60, 100): 0.6594202186690291,
#  (2, 59, 100): 0.6594714208485749,
#  (1, 61, 61): 0.5327806408660604,
#  (2, 60, 61): 0.5987212090276719,
#  (1, 62, 62): 0.5328041250698572,
#  (2, 61, 62): 0.5987947377389965,
#  (2, 21, 62): 0.6412867749400921,
#  (1, 63, 63): 0.5328350514509137,
#  (2, 62, 63): 0.5988899810697471,
#  (1, 64, 64): 0.5329295505639383,
#  (2, 63, 64): 0.5991591232757963,
#  (1, 65, 65): 0.5329439718496504,
#  (2, 64, 65): 0.5992017586824079,
#  (2, 22, 65): 0.6419519898198954,
#  (1, 66, 66): 0.5329563424020729,
#  (2, 65, 66): 0.5992384734235551,
#  (1, 67, 67): 0.5329692090996461,
#  (2, 66, 67): 0.5992765939092958,
#  (1, 68, 68): 0.5329786027811648,
#  (2, 67, 68): 0.5993086945005419,
#  (2, 23, 68): 0.6423572742552796,
#  (1, 69, 69): 0.5329891210583583,
#  (2, 68, 69): 0.5993394885762248,
#  (1, 70, 70): 0.5330002016333891,
#  (2, 69, 70): 0.5993723499233687,
#  (1, 71, 71): 0.5330110506740166,
#  (2, 70, 71): 0.5994039212931209,
#  (2, 24, 71): 0.6429282380946333,
#  (1, 72, 72): 0.5330189889964267,
#  (2, 71, 72): 0.5994280670237854,
#  (1, 73, 73): 0.5330284819069756,
#  (2, 72, 73): 0.5994564796027452,
#  (1, 74, 74): 0.5330374786723738,
#  (2, 73, 74): 0.599483089520991,
#  (2, 25, 74): 0.6432813280601704,
#  (1, 75, 75): 0.5330459131399347,
#  (2, 74, 75): 0.5995072187134837,
#  (1, 76, 76): 0.5330541822257785,
#  (2, 75, 76): 0.5995340767043049,
#  (1, 77, 77): 0.5330628151513997,
#  (2, 76, 77): 0.5995594131833307,
#  (2, 26, 77): 0.6438085649735813,
#  (1, 78, 78): 0.5330708527028399,
#  (2, 77, 78): 0.5995827154672391,
#  (1, 79, 79): 0.5330799817736117,
#  (2, 78, 79): 0.5996089284693644,
#  (1, 80, 80): 0.5330863985842266,
#  (2, 79, 80): 0.5996283608210977,
#  (2, 27, 80): 0.6441455136835509,
#  (1, 81, 81): 0.5330929477002151,
#  (2, 80, 81): 0.5996482893179816,
#  (1, 82, 82): 0.5331003237247879,
#  (2, 81, 82): 0.5996707812314773,
#  (1, 83, 83): 0.5331074682149571,
#  (2, 82, 83): 0.599691569713289,
#  (2, 28, 83): 0.6446484064082373,
#  (1, 84, 84): 0.5331135542621382,
#  (2, 83, 84): 0.5997103736144981,
#  (1, 85, 85): 0.5331207318286508,
#  (2, 84, 85): 0.5997354950972921,
#  (1, 86, 86): 0.5331267847994886,
#  (2, 85, 86): 0.5997556055140646,
#  (2, 29, 86): 0.6449977587469728,
#  (1, 87, 87): 0.5331327716176396,
#  (2, 86, 87): 0.5997733675104574,
#  (1, 88, 88): 0.5331386592067605,
#  (2, 87, 88): 0.599791989491778,
#  (1, 89, 89): 0.5331450098646887,
#  (2, 88, 89): 0.5998109256983607,
#  (2, 30, 89): 0.6454688981820182,
#  (1, 90, 90): 0.5331506328430625,
#  (2, 89, 90): 0.5998279269388559,
#  (1, 91, 91): 0.5331572150353944,
#  (2, 90, 91): 0.5998475412104778,
#  (1, 92, 92): 0.5331628049374249,
#  (2, 91, 92): 0.5998653528213856,
#  (2, 31, 92): 0.6457769216297059,
#  (1, 93, 93): 0.5331686925265458,
#  (2, 92, 93): 0.5998821225274772,
#  (1, 94, 94): 0.5331750431844738,
#  (2, 93, 94): 0.5999014225738369,
#  (1, 95, 95): 0.5331811953843418,
#  (2, 94, 95): 0.5999193995664617,
#  (2, 32, 95): 0.646300487069002,
#  (1, 96, 96): 0.5331852306982338,
#  (2, 95, 96): 0.599931571660824,
#  (1, 97, 97): 0.5331905890658605,
#  (2, 96, 97): 0.599948109832512,
#  (1, 98, 98): 0.5331949220668428,
#  (2, 97, 98): 0.5999628122671425,
#  (2, 33, 98): 0.6464613042504953,
#  (1, 99, 99): 0.5331994535258853,
#  (2, 98, 99): 0.59997640664427,
#  (2, 60, 99): 0.6594345241875391,
#  (1, 100, 100): 0.533204183442988,
#  (2, 99, 100): 0.5999915225331928,
#  (2, 6, 6): 0.4693452418753916,
#  (3, 5, 6): 0.4740014979614388,
#  (2, 7, 7): 0.48208386784704227,
#  (3, 6, 7): 0.4955659177124083,
#  (2, 8, 8): 0.49122878218725124,
#  (3, 7, 8): 0.5014666050652847,
#  (2, 9, 9): 0.494262775936087,
#  (3, 8, 9): 0.5178661041836018,
#  (2, 10, 10): 0.5004434876119833,
#  (3, 9, 10): 0.5342839937488357,
#  (2, 11, 11): 0.5025522368075666,
#  (3, 10, 11): 0.5431842258389219,
#  (2, 12, 12): 0.506093654740131,
#  (3, 11, 12): 0.5502830045015581,
#  (2, 13, 13): 0.5085600915129808,
#  (3, 12, 13): 0.5546173616138715,
#  (2, 14, 14): 0.5131205254322682,
#  (3, 13, 14): 0.5568134654323105,
#  (2, 15, 15): 0.5156899950147334,
#  (3, 14, 15): 0.5601744353735879,
#  (2, 16, 16): 0.5177187986883774,
#  (3, 15, 16): 0.5635269543091331,
#  (2, 17, 17): 0.5183972606437027,
#  (3, 16, 17): 0.5645428776577504,
#  (2, 18, 18): 0.5198030383135193,
#  (3, 17, 18): 0.5672856342031618,
#  (2, 19, 19): 0.5202042212823249,
#  (3, 18, 19): 0.5700392728655439,
#  (2, 20, 20): 0.521353326527545,
#  (3, 19, 20): 0.5708707459853257,
#  (2, 20, 60): 0.6295677107148301,
#  (3, 19, 60): 0.6304392723627834,
#  (2, 21, 21): 0.5216864383816829,
#  (3, 20, 21): 0.5735340366157767,
#  (2, 21, 63): 0.6301227813711917,
#  (3, 20, 63): 0.6311136824660452,
#  (2, 22, 22): 0.5225738105217701,
#  (3, 21, 22): 0.5764060555111009,
#  (2, 22, 66): 0.630719892059984,
#  (3, 21, 66): 0.6335248486691138,
#  (2, 23, 23): 0.5230437922847974,
#  (3, 22, 23): 0.5785014418639604,
#  (2, 23, 69): 0.6311993336572169,
#  (3, 22, 69): 0.6351912844629037,
#  (2, 23, 71): 0.641735372847127,
#  (3, 22, 71): 0.6419442003410304,
#  (2, 24, 24): 0.5237380978085997,
#  (3, 23, 24): 0.5800568899875528,
#  (2, 24, 72): 0.6316713165390184,
#  (3, 23, 72): 0.6362437075564361,
#  (2, 24, 74): 0.642247130031838,
#  (3, 23, 74): 0.6426527783069992,
#  (2, 25, 25): 0.524088839353757,
#  (3, 24, 25): 0.5809113180896375,
#  (2, 25, 75): 0.6320944621998256,
#  (3, 24, 75): 0.637120230655896,
#  (2, 25, 77): 0.6426200988797439,
#  (3, 24, 77): 0.6434655302164304,
#  (2, 26, 26): 0.5248276325593998,
#  (3, 25, 26): 0.5813076057596235,
#  (2, 26, 78): 0.6325682808186844,
#  (3, 25, 78): 0.6376919552511473,
#  (2, 26, 80): 0.6431372309702534,
#  (3, 25, 80): 0.6440306064666632,
#  (2, 27, 27): 0.5251138752349743,
#  (3, 26, 27): 0.582175396704432,
#  (2, 27, 81): 0.6329491879890007,
#  (3, 26, 81): 0.6380589868954174,
#  (2, 27, 83): 0.6434930993486342,
#  (3, 26, 83): 0.6444297387021796,
#  (2, 28, 28): 0.5256858644409728,
#  (3, 27, 28): 0.5828712072018578,
#  (2, 28, 84): 0.6333982655030145,
#  (3, 27, 84): 0.6388404320458433,
#  (2, 28, 86): 0.6439339408531474,
#  (3, 27, 86): 0.6451290222156598,
#  (2, 29, 29): 0.5261190653101662,
#  (3, 28, 29): 0.5831610717370319,
#  (2, 29, 87): 0.6337884340494758,
#  (3, 28, 87): 0.6392850773298446,
#  (2, 29, 88): 0.6449055088252976,
#  (3, 28, 88): 0.644998916418991,
#  (2, 29, 89): 0.6443102007972193,
#  (3, 28, 89): 0.6455973005470034,
#  (2, 30, 30): 0.5268432387720368,
#  (3, 29, 30): 0.5837543951845078,
#  (2, 30, 90): 0.63421194355006,
#  (3, 29, 90): 0.6395496715386797,
#  (2, 30, 92): 0.6447714007910802,
#  (3, 29, 92): 0.645899006413106,
#  (2, 31, 31): 0.5275615907974732,
#  (3, 30, 31): 0.5843650506359125,
#  (2, 31, 93): 0.6345886665629393,
#  (3, 30, 93): 0.640241909791021,
#  (2, 31, 94): 0.6457147711805027,
#  (3, 30, 94): 0.645921002181451,
#  (2, 31, 95): 0.6453186488922336,
#  (3, 30, 95): 0.6465264150324307,
#  (2, 32, 32): 0.5279858610539553,
#  (3, 31, 32): 0.5845853886973108,
#  (2, 32, 96): 0.635051999980948,
#  (3, 31, 96): 0.6406006558112753,
#  (2, 32, 97): 0.6461740362082762,
#  (3, 31, 97): 0.646306424272638,
#  (2, 32, 98): 0.645574742480821,
#  (3, 31, 98): 0.6468801499866637,
#  (2, 33, 33): 0.5281335800034718,
#  (3, 32, 33): 0.5851356798220545,
#  (2, 33, 99): 0.6352244269589663,
#  (3, 32, 99): 0.6407475974667225,
#  (2, 33, 100): 0.6463518546302647,
#  (3, 32, 100): 0.6464238949061373,
#  (2, 34, 34): 0.5283821156475977,
#  (3, 33, 34): 0.5857237441309336,
#  (2, 35, 35): 0.5284957328870937,
#  (3, 34, 35): 0.5859061105501363,
#  (2, 36, 36): 0.5286972339709394,
#  (3, 35, 36): 0.5863498462346949,
#  (2, 37, 37): 0.5288185579984419,
#  (3, 36, 37): 0.5868146350118123,
#  (2, 38, 38): 0.5290239620908059,
#  (3, 37, 38): 0.5870175583784231,
#  (2, 39, 39): 0.5291136651340412,
#  (3, 38, 39): 0.5874601198527918,
#  (2, 40, 40): 0.5292680655049197,
#  (3, 39, 40): 0.5879006636702145,
#  (2, 41, 41): 0.5293537993869498,
#  (3, 40, 41): 0.5880250307213077,
#  (2, 42, 42): 0.5295149142555335,
#  (3, 41, 42): 0.5884515170927959,
#  (2, 43, 43): 0.5296025334891361,
#  (3, 42, 43): 0.5889065483486172,
#  (2, 44, 44): 0.5297588522879303,
#  (3, 43, 44): 0.58904100368444,
#  (2, 45, 45): 0.5298143874684583,
#  (3, 44, 45): 0.5894975068375417,
#  (2, 46, 46): 0.5299781484445122,
#  (3, 45, 46): 0.5899698039446054,
#  (3, 45, 47): 0.5976479643759843,
#  (2, 47, 47): 0.5300331874798896,
#  (3, 46, 47): 0.5905717768558739,
#  (3, 46, 48): 0.5985042612914698,
#  (2, 48, 48): 0.5301334749530051,
#  (3, 47, 48): 0.5909074355884519,
#  (3, 47, 49): 0.5986030107146184,
#  (2, 49, 49): 0.5302022075945402,
#  (3, 48, 49): 0.5910961361274111,
#  (3, 48, 50): 0.5987849967558723,
#  (2, 50, 50): 0.5303300145853443,
#  (3, 49, 50): 0.5911701775220579,
#  (3, 49, 51): 0.5989254058335026,
#  (2, 51, 51): 0.530385152849752,
#  (3, 50, 51): 0.5913320862228827,
#  (3, 50, 52): 0.5990053844317854,
#  (2, 52, 52): 0.5305056830450136,
#  (3, 51, 52): 0.5914818062911734,
#  (3, 51, 53): 0.5991632908950618,
#  (2, 53, 53): 0.5305588367288184,
#  (3, 52, 53): 0.5915376556969635,
#  (3, 52, 54): 0.5992909986568359,
#  (2, 18, 54): 0.6281354554321411,
#  (3, 18, 53): 0.6282727553334942,
#  (2, 54, 54): 0.5306651440964284,
#  (3, 53, 54): 0.5916624692786923,
#  (3, 53, 55): 0.5993634193106573,
#  (2, 55, 55): 0.5307288160574269,
#  (3, 54, 55): 0.5918032587342715,
#  (3, 54, 56): 0.599478690367322,
#  (2, 56, 56): 0.5308433925108808,
#  (3, 55, 56): 0.5918555193568054,
#  (3, 55, 57): 0.5995967232986587,
#  (2, 19, 57): 0.6287977430555555,
#  (3, 19, 56): 0.6300712318900404,
#  (2, 57, 57): 0.5308984976989449,
#  (3, 56, 57): 0.5919839713363054,
#  (3, 56, 58): 0.5996486531577588,
#  (2, 58, 58): 0.531019424810327,
#  (3, 57, 58): 0.5921011938972294,
#  (3, 57, 59): 0.5997754843964335,
#  (2, 59, 59): 0.5310688408673304,
#  (3, 58, 59): 0.5921501799617691,
#  (3, 58, 60): 0.5998798898742993,
#  (3, 20, 59): 0.6308086193510897,
#  (2, 60, 60): 0.5311653907136445,
#  (3, 59, 60): 0.5922371045921607,
#  (3, 59, 61): 0.5999254359991278,
#  (2, 61, 61): 0.5312331972175651,
#  (3, 60, 61): 0.5923383678174059,
#  (3, 60, 62): 0.6000335791037951,
#  (2, 62, 62): 0.5313585565589595,
#  (3, 61, 62): 0.5923812182202493,
#  (3, 61, 63): 0.6001316835382479,
#  (3, 21, 62): 0.6330898947537215,
#  (2, 63, 63): 0.5315653498577452,
#  (3, 62, 63): 0.5925049402826467,
#  (3, 62, 64): 0.6001830180231672,
#  (2, 64, 64): 0.5316609404901015,
#  (3, 63, 64): 0.5925977525021593,
#  (3, 63, 65): 0.6002796836366832,
#  (2, 65, 65): 0.531690378435706,
#  (3, 64, 65): 0.592631788059493,
#  (3, 64, 66): 0.6003744142841115,
#  (3, 22, 65): 0.6346719031810446,
#  (2, 66, 66): 0.5317385375916611,
#  (3, 65, 66): 0.5927241372101983,
#  (3, 65, 67): 0.6004132789875781,
#  (2, 67, 67): 0.5317613271922471,
#  (3, 66, 67): 0.5928214643505817,
#  (3, 66, 68): 0.6005093823032567,
#  (2, 68, 68): 0.5318062779428949,
#  (3, 67, 68): 0.5928686808307507,
#  (3, 67, 69): 0.600597067689546,
#  (3, 23, 68): 0.6353617433984912,
#  (2, 69, 69): 0.5318268845048181,
#  (3, 68, 69): 0.5929494532612746,
#  (3, 68, 70): 0.6006299621130332,
#  (2, 70, 70): 0.5318679983996342,
#  (3, 69, 70): 0.5930456061914681,
#  (3, 69, 71): 0.6007228404852326,
#  (2, 71, 71): 0.5318853634799066,
#  (3, 70, 71): 0.5930765987252112,
#  (3, 70, 72): 0.6007995941400363,
#  (3, 24, 71): 0.6368715792445682,
#  (2, 72, 72): 0.5319251873973311,
#  (3, 71, 72): 0.5931494493714966,
#  (3, 71, 73): 0.600835432358084,
#  (2, 73, 73): 0.5319396086830429,
#  (3, 72, 73): 0.5932231434645379,
#  (3, 72, 74): 0.6009037846216702,
#  (2, 74, 74): 0.5319769849510576,
#  (3, 73, 74): 0.5932469749699402,
#  (3, 73, 75): 0.6009758414357144,
#  (3, 25, 74): 0.637481490478247,
#  (2, 75, 75): 0.5319899508776609,
#  (3, 74, 75): 0.5933288389197955,
#  (3, 74, 76): 0.600999127181451,
#  (2, 76, 76): 0.5320250779543261,
#  (3, 75, 76): 0.5934025495510085,
#  (3, 75, 77): 0.6010797838447729,
#  (2, 77, 77): 0.5320406899883995,
#  (3, 76, 77): 0.5934319544202696,
#  (3, 76, 78): 0.6011526014147149,
#  (3, 26, 77): 0.6378954574537672,
#  (2, 78, 78): 0.5320778016456672,
#  (3, 77, 78): 0.5934982559505665,
#  (3, 77, 79): 0.6011803855431506,
#  (2, 79, 79): 0.5320866991820353,
#  (3, 78, 79): 0.5935844198250606,
#  (3, 78, 80): 0.601249680482523,
#  (2, 80, 80): 0.5321167325018205,
#  (3, 79, 80): 0.5935997672483869,
#  (3, 79, 81): 0.6013253922325102,
#  (3, 27, 80): 0.6386029439004047,
#  (2, 81, 81): 0.5321278792295382,
#  (3, 80, 81): 0.5936775793461786,
#  (3, 80, 82): 0.6013561366936782,
#  (2, 82, 82): 0.5321571517934258,
#  (3, 81, 82): 0.5937518688134007,
#  (3, 81, 83): 0.601426787763129,
#  (2, 83, 83): 0.5321697869565954,
#  (3, 82, 83): 0.5937740134252909,
#  (3, 82, 84): 0.6014979184395587,
#  (3, 28, 83): 0.6390618120120578,
#  (2, 84, 84): 0.5322013748645192,
#  (3, 83, 84): 0.5938440691205609,
#  (3, 83, 85): 0.6015204268912259,
#  (2, 85, 85): 0.5322126208212671,
#  (3, 84, 85): 0.5939187058893884,
#  (3, 84, 86): 0.6015962874847584,
#  (2, 86, 86): 0.5322408018658233,
#  (3, 85, 86): 0.5939462915597639,
#  (3, 85, 87): 0.6016669550923809,
#  (3, 29, 86): 0.6394178126958119,
#  (2, 87, 87): 0.532251948593541,
#  (3, 86, 87): 0.5940234421306881,
#  (3, 86, 88): 0.601684650936087,
#  (2, 88, 88): 0.5322755651027112,
#  (3, 87, 88): 0.5940922243867381,
#  (3, 87, 89): 0.6017641830037341,
#  (2, 89, 89): 0.5322872410519229,
#  (3, 88, 89): 0.5941109952116039,
#  (3, 88, 90): 0.6018371328790496,
#  (3, 30, 89): 0.6400308661821116,
#  (2, 90, 90): 0.5323146613405815,
#  (3, 89, 90): 0.5941841270068079,
#  (3, 89, 91): 0.6018690019358922,
#  (2, 91, 91): 0.5323265357478535,
#  (3, 90, 91): 0.5942605664363495,
#  (3, 90, 92): 0.6019353200043608,
#  (2, 92, 92): 0.5323509791656083,
#  (3, 91, 92): 0.5942813383799895,
#  (3, 91, 93): 0.6020062026082151,
#  (3, 31, 92): 0.6404354725524564,
#  (2, 93, 93): 0.5323607366869041,
#  (3, 92, 93): 0.5943591835541245,
#  (3, 92, 94): 0.6020233692304272,
#  (2, 94, 94): 0.532385014722942,
#  (3, 93, 94): 0.5944335226358617,
#  (3, 93, 95): 0.6021049851077072,
#  (2, 95, 95): 0.5323954668474488,
#  (3, 94, 95): 0.5946310545585023,
#  (3, 94, 96): 0.6023667182128402,
#  (3, 32, 95): 0.6407084350761655,
#  (2, 96, 96): 0.5324148826610103,
#  (3, 95, 96): 0.5947102558627156,
#  (3, 95, 97): 0.6023858198011397,
#  (2, 97, 97): 0.5324242763425291,
#  (3, 96, 97): 0.5947447048743416,
#  (3, 96, 98): 0.6024215422519856,
#  (2, 98, 98): 0.5324444859883317,
#  (3, 97, 98): 0.5947557192966858,
#  (3, 97, 99): 0.6024459691315688,
#  (3, 33, 98): 0.6412241118075667,
#  (2, 99, 99): 0.532454276585971,
#  (3, 98, 99): 0.5947932940227607,
#  (3, 98, 100): 0.6024601919592203,
#  (2, 100, 100): 0.5324711785974361,
#  (3, 99, 100): 0.594818828959847,
#  (3, 7, 7): 0.44019443200773933,
#  (4, 6, 7): 0.45015962312549745,
#  (3, 8, 8): 0.4467808250351403,
#  (4, 7, 8): 0.4742427237336788,
#  (3, 9, 9): 0.4693452418753916,
#  (4, 8, 9): 0.49163882961608163,
#  (3, 10, 10): 0.47808047262654746,
#  (4, 9, 10): 0.4967868813136124,
#  (3, 11, 11): 0.48470119889837254,
#  (4, 10, 11): 0.502631388497265,
#  (3, 12, 12): 0.49122878218725124,
#  (4, 11, 12): 0.5167916853217244,
#  (3, 13, 13): 0.4935336740990533,
#  (4, 12, 13): 0.5312539030085183,
#  (3, 14, 14): 0.4956136137995563,
#  (4, 13, 14): 0.5362733208066606,
#  (3, 15, 15): 0.5004434876119833,
#  (4, 14, 15): 0.5434280646422885,
#  (3, 16, 16): 0.5020230153135531,
#  (4, 15, 16): 0.5478861768933428,
#  (3, 17, 17): 0.5030273123274739,
#  (4, 16, 17): 0.5516700278846806,
#  (3, 17, 51): 0.615492767394452,
#  (4, 16, 51): 0.6161914720719234,
#  (3, 18, 18): 0.506093654740131,
#  (4, 17, 18): 0.5534884163999391,
#  (3, 18, 54): 0.6177887948462294,
#  (4, 17, 54): 0.6190445216843214,
#  (3, 19, 19): 0.5081359535618724,
#  (4, 18, 19): 0.5547300196394097,
#  (3, 19, 57): 0.6196168251155819,
#  (4, 18, 57): 0.6206401410269438,
#  (3, 20, 20): 0.5092737466976579,
#  (4, 19, 20): 0.5579425760279598,
#  (3, 20, 60): 0.6203943672574895,
#  (4, 19, 60): 0.6215706116424494,
#  (3, 21, 21): 0.5131205254322682,
#  (4, 20, 21): 0.560842097902801,
#  (3, 21, 63): 0.6225665568796677,
#  (4, 20, 63): 0.6242344480325662,
#  (3, 22, 22): 0.5144697094785687,
#  (4, 21, 22): 0.5619077515336839,
#  (3, 22, 66): 0.624324547991922,
#  (4, 21, 66): 0.6264198516539231,
#  (3, 23, 23): 0.5164820742095548,
#  (4, 22, 23): 0.5623249765290268,
#  (3, 23, 69): 0.6249592168686177,
#  (4, 22, 69): 0.6269802310633965,
#  (3, 24, 24): 0.5177187986883774,
#  (4, 23, 24): 0.5647878741331352,
#  (3, 24, 72): 0.6264351494627344,
#  (4, 23, 72): 0.6274335588875342,
#  (3, 25, 25): 0.518164866255144,
#  (4, 24, 25): 0.5672480925534301,
#  (3, 25, 75): 0.6270372712175482,
#  (4, 24, 75): 0.6295931629610577,
#  (3, 26, 26): 0.5187485975630408,
#  (4, 25, 26): 0.5679596473903029,
#  (3, 26, 78): 0.6274313096961844,
#  (4, 25, 78): 0.6313052441087063,
#  (3, 27, 27): 0.5198030383135193,
#  (4, 26, 27): 0.5688839492677692,
#  (3, 27, 81): 0.6281354554321411,
#  (4, 26, 81): 0.6318541625652001,
#  (3, 28, 28): 0.5200221029356974,
#  (4, 27, 28): 0.571275650042761,
#  (3, 28, 84): 0.6286252830011939,
#  (4, 27, 84): 0.6323139071999525,
#  (3, 29, 29): 0.5204572222328067,
#  (4, 28, 29): 0.5737307747061763,
#  (3, 29, 87): 0.6289591721494013,
#  (4, 28, 87): 0.6344316035464191,
#  (3, 30, 30): 0.521353326527545,
#  (4, 29, 30): 0.5746018071326356,
#  (3, 30, 90): 0.6295677107148301,
#  (4, 29, 90): 0.636175140296618,
#  (4, 29, 93): 0.6410474510575962,
#  (3, 31, 31): 0.5216136373499127,
#  (4, 30, 31): 0.5765721483693628,
#  (3, 31, 93): 0.6299875487412996,
#  (4, 30, 93): 0.6364735716047266,
#  (4, 30, 96): 0.6419747628823096,
#  (3, 32, 32): 0.5218702105454792,
#  (4, 31, 32): 0.57749606986888,
#  (3, 32, 96): 0.6301997334840557,
#  (4, 31, 96): 0.6374555090105252,
#  (3, 32, 98): 0.6418308477122813,
#  (4, 31, 98): 0.64189207202387,
#  (4, 31, 99): 0.6423986858371861,
#  (3, 33, 33): 0.5225738105217701,
#  (4, 32, 33): 0.5782692459334621,
#  (3, 33, 99): 0.630719892059984,
#  (4, 32, 99): 0.6381510714353757,
#  (3, 34, 34): 0.5229414210020491,
#  (4, 33, 34): 0.5785625834846907,
#  (3, 35, 35): 0.5230813339345289,
#  (4, 34, 35): 0.5789247529064845,
#  (4, 34, 36): 0.586367542078401,
#  (3, 36, 36): 0.5237380978085997,
#  (4, 35, 36): 0.5796576089084913,
#  (3, 37, 37): 0.5239908341483345,
#  (4, 36, 37): 0.5802491462334248,
#  (4, 36, 38): 0.5873462049262054,
#  (3, 38, 38): 0.5241945844235296,
#  (4, 37, 38): 0.5804661601223137,
#  (4, 37, 39): 0.58762088741977,
#  (3, 39, 39): 0.5248276325593998,
#  (4, 38, 39): 0.5806532895349625,
#  (4, 38, 40): 0.5880847500592729,
#  (3, 40, 40): 0.5250622099866212,
#  (4, 39, 40): 0.5812160504411591,
#  (4, 39, 41): 0.5883475912219089,
#  (3, 41, 41): 0.5251781094938103,
#  (4, 40, 41): 0.581744395412073,
#  (4, 40, 42): 0.588833317324383,
#  (3, 42, 42): 0.5256858644409728,
#  (4, 41, 42): 0.5820000755463682,
#  (4, 41, 43): 0.5890965057886247,
#  (3, 43, 43): 0.5260332321991058,
#  (4, 42, 43): 0.5820988084313451,
#  (4, 42, 44): 0.5895697621096462,
#  (3, 44, 44): 0.5262173020499924,
#  (4, 43, 44): 0.5826556321339057,
#  (4, 43, 45): 0.5897379057011973,
#  (3, 45, 45): 0.5268432387720368,
#  (4, 44, 45): 0.5831276480920508,
#  (4, 44, 46): 0.5902254013880421,
#  (3, 46, 46): 0.5271012011740249,
#  (4, 45, 46): 0.583270240208344,
#  (3, 47, 47): 0.5277467521676913,
#  (4, 46, 47): 0.5834219779335806,
#  (3, 48, 48): 0.5279858610539553,
#  (4, 47, 48): 0.583798849790005,
#  (3, 49, 49): 0.5280672950113465,
#  (4, 48, 49): 0.58421129525373,
#  (4, 48, 50): 0.5913062701368778,
#  (3, 50, 50): 0.5281774061584447,
#  (4, 49, 50): 0.5844009880829905,
#  (4, 49, 51): 0.5914750587171248,
#  (4, 17, 50): 0.6165013477948399,
#  (3, 51, 51): 0.5283821156475977,
#  (4, 50, 51): 0.5845099911725855,
#  (4, 50, 52): 0.5918398411700453,
#  (3, 52, 52): 0.5284536267019764,
#  (4, 51, 52): 0.5848932467632814,
#  (4, 51, 53): 0.5920035690697556,
#  (3, 53, 53): 0.5285409151721452,
#  (4, 52, 53): 0.5853034761120002,
#  (4, 52, 54): 0.5923164712780911,
#  (4, 18, 53): 0.6181123476371319,
#  (3, 54, 54): 0.5286972339709394,
#  (4, 53, 54): 0.5854581080172822,
#  (4, 53, 55): 0.5925202546296297,
#  (3, 55, 55): 0.5287723172704025,
#  (4, 54, 55): 0.5854904070665887,
#  (4, 54, 56): 0.5928632397722654,
#  (3, 56, 56): 0.528849186692408,
#  (4, 55, 56): 0.585891077352072,
#  (4, 55, 57): 0.5930314164401599,
#  (3, 57, 57): 0.5290239620908059,
#  (4, 56, 57): 0.5862959648713356,
#  (4, 56, 58): 0.593397753481219,
#  (3, 58, 58): 0.529078174217599,
#  (4, 57, 58): 0.5864241191637455,
#  (4, 57, 59): 0.5935495408209707,
#  (3, 59, 59): 0.5291300048476689,
#  (4, 58, 59): 0.5865677035703398,
#  (4, 58, 60): 0.5938409764824553,
#  (4, 20, 59): 0.6220633830060628,
#  (3, 60, 60): 0.5292680655049197,
#  (4, 59, 60): 0.5869693992224677,
#  (4, 59, 61): 0.5940510939537503,
#  (3, 61, 61): 0.5293283636788938,
#  (4, 60, 61): 0.5873862934543769,
#  (4, 60, 62): 0.5944358379798981,
#  (3, 62, 62): 0.5293856188292774,
#  (4, 61, 62): 0.5875231799014378,
#  (4, 61, 63): 0.5950046353187607,
#  (4, 21, 62): 0.6242603302712578,
#  (3, 63, 63): 0.5295149142555335,
#  (4, 62, 63): 0.5881961511837626,
#  (4, 62, 64): 0.5953108064912191,
#  (3, 64, 64): 0.5295760062617487,
#  (4, 63, 64): 0.5883510807761351,
#  (4, 63, 65): 0.5954003937672526,
#  (3, 65, 65): 0.5296215523865772,
#  (4, 64, 65): 0.5884918206171993,
#  (4, 64, 66): 0.5955452681512389,
#  (4, 22, 65): 0.6248344032868888,
#  (3, 66, 66): 0.5297588522879303,
#  (4, 65, 66): 0.5885713692230182,
#  (4, 65, 67): 0.5956124131282917,
#  (3, 67, 67): 0.5298012561601383,
#  (4, 66, 67): 0.5886375219097698,
#  (4, 66, 68): 0.5957485718957984,
#  (3, 68, 68): 0.529846471521533,
#  (4, 67, 68): 0.5887764094756051,
#  (4, 67, 69): 0.5958102427380226,
#  (4, 23, 68): 0.6256472213490067,
#  (3, 69, 69): 0.5299781484445122,
#  (4, 68, 69): 0.5889008426793849,
#  (4, 68, 70): 0.5959310706203745,
#  (3, 70, 70): 0.5300216107597081,
#  (4, 69, 70): 0.5889561794018526,
#  (4, 69, 71): 0.5959897480535233,
#  (3, 71, 71): 0.5300431103829023,
#  (4, 70, 71): 0.5889931587537468,
#  (4, 70, 72): 0.5961088063515048,
#  (4, 24, 71): 0.6278304253935291,
#  (3, 72, 72): 0.5301334749530051,
#  (4, 71, 72): 0.5891061971572339,
#  (4, 71, 73): 0.596151656754348,
#  (3, 73, 73): 0.5301830563917255,
#  (4, 72, 73): 0.5892122399140968,
#  (4, 72, 74): 0.5962632397987264,
#  (3, 74, 74): 0.5302213918736981,
#  (4, 73, 74): 0.5892634255554708,
#  (4, 73, 75): 0.5963052632929854,
#  (4, 25, 74): 0.6295195515588748,
#  (3, 75, 75): 0.5303300145853443,
#  (4, 74, 75): 0.5893170257699115,
#  (4, 74, 76): 0.5964045750139714,
#  (3, 76, 76): 0.5303685816017206,
#  (4, 75, 76): 0.5894298161008231,
#  (4, 75, 77): 0.5964538256892581,
#  (3, 77, 77): 0.530398449539789,
#  (4, 76, 77): 0.5895255886530678,
#  (4, 76, 78): 0.5965617868740368,
#  (4, 26, 77): 0.6298821178967892,
#  (3, 78, 78): 0.5305056830450136,
#  (4, 77, 78): 0.5895662560172484,
#  (4, 77, 79): 0.5965969635652171,
#  (3, 79, 79): 0.5305416701066065,
#  (4, 78, 79): 0.5895925020957171,
#  (4, 78, 80): 0.5966842851117292,
#  (3, 80, 80): 0.5305744818392352,
#  (4, 79, 80): 0.5896747464235211,
#  (4, 79, 81): 0.5967190152722739,
#  (4, 27, 80): 0.6305618532913343,
#  (3, 81, 81): 0.5306651440964284,
#  (4, 80, 81): 0.5897592564808464,
#  (4, 80, 82): 0.5968058406736355,
#  (3, 82, 82): 0.5307149570695524,
#  (4, 81, 82): 0.5898063737319853,
#  (4, 81, 83): 0.5968468057249064,
#  (3, 83, 83): 0.5307373497540179,
#  (4, 82, 83): 0.5898409219726414,
#  (4, 82, 84): 0.5969399487078528,
#  (4, 28, 83): 0.632644984858973,
#  (3, 84, 84): 0.5308433925108808,
#  (4, 83, 84): 0.5899515788794052,
#  (4, 83, 85): 0.5969784495715423,
#  (3, 85, 85): 0.5308807357025521,
#  (4, 84, 85): 0.590039297342038,
#  (4, 84, 86): 0.5970633565449881,
#  (3, 86, 86): 0.5309161604663076,
#  (4, 85, 86): 0.5900632776909854,
#  (4, 85, 87): 0.5971014439543854,
#  (4, 29, 86): 0.6341472958369321,
#  (3, 87, 87): 0.531019424810327,
#  (4, 86, 87): 0.5900916241172586,
#  (4, 86, 88): 0.5971704908211825,
#  (3, 88, 88): 0.5310544195816186,
#  (4, 87, 88): 0.5901717184827432,
#  (4, 87, 89): 0.5972081978526308,
#  (3, 89, 89): 0.5310768122660842,
#  (4, 88, 89): 0.5902565427653305,
#  (4, 88, 90): 0.5972896979627089,
#  (4, 30, 89): 0.6345409208612762,
#  (3, 90, 90): 0.5311653907136445,
#  (4, 89, 90): 0.5902962343773815,
#  (4, 89, 91): 0.597325304646353,
#  (3, 91, 91): 0.5312151706104252,
#  (4, 90, 91): 0.5903176513097174,
#  (4, 90, 92): 0.5973977583765179,
#  (3, 92, 92): 0.5312498676946266,
#  (4, 91, 92): 0.5904037490315247,
#  (4, 91, 93): 0.5974274443946976,
#  (4, 31, 92): 0.6350845636410015,
#  (3, 93, 93): 0.5313585565589595,
#  (4, 92, 93): 0.5904832480228285,
#  (4, 92, 94): 0.597498806605531,
#  (3, 94, 94): 0.5313904421539738,
#  (4, 93, 94): 0.5905108667695473,
#  (4, 93, 95): 0.5975329083155515,
#  (3, 95, 95): 0.5316191650684178,
#  (4, 94, 95): 0.590518887782816,
#  (4, 94, 96): 0.5975902130804501,
#  (4, 32, 95): 0.6364357157297329,
#  (3, 96, 96): 0.5316609404901015,
#  (4, 95, 96): 0.5905898365393571,
#  (4, 95, 97): 0.5976202960147504,
#  (3, 97, 97): 0.5316739725693914,
#  (4, 96, 97): 0.5906563199895426,
#  (4, 96, 98): 0.5976821983913784,
#  (3, 98, 98): 0.5317002351860319,
#  (4, 97, 98): 0.5906784149869176,
#  (4, 97, 99): 0.5977121324821334,
#  (4, 33, 98): 0.6369774566197142,
#  (3, 99, 99): 0.5317385375916611,
#  (4, 98, 99): 0.5907043468401243,
#  (4, 98, 100): 0.5977623423713782,
#  (3, 100, 100): 0.53174793127318,
#  (4, 99, 100): 0.5907712272064303,
#  (4, 6, 6): 0.38529044734034446,
#  (5, 5, 6): 0.3960503141458788,
#  (4, 7, 7): 0.4024199248187945,
#  (5, 6, 7): 0.42052775091978695,
#  (4, 8, 8): 0.4285657819670951,
#  (5, 7, 8): 0.43856474403143997,
#  (4, 9, 9): 0.4379673356555573,
#  (5, 8, 9): 0.45166674671141765,
#  (4, 10, 10): 0.4425199304814645,
#  (5, 9, 10): 0.47425496198072786,
#  (4, 11, 11): 0.44806372408931566,
#  (5, 10, 11): 0.4900424495175617,
#  (4, 12, 12): 0.4693452418753916,
#  (5, 11, 12): 0.4940311588415976,
#  (4, 13, 13): 0.47675533508188117,
#  (5, 12, 13): 0.4998499491682755,
#  (4, 14, 14): 0.48208386784704227,
#  (5, 13, 14): 0.5030468273700656,
#  (4, 15, 15): 0.4852509608016224,
#  (5, 14, 15): 0.5158300733289302,
#  (4, 16, 16): 0.49122878218725124,
#  (5, 15, 16): 0.5299008986445578,
#  (4, 17, 17): 0.49264620272993614,
#  (5, 16, 17): 0.5345106990063337,
#  (4, 17, 51): 0.606547849164465,
#  (5, 16, 51): 0.6068501173284052,
#  (4, 18, 18): 0.494262775936087,
#  (5, 17, 18): 0.5398539672824688,
#  (4, 18, 54): 0.6085029752832394,
#  (5, 17, 54): 0.6086456500903911,
#  (4, 19, 19): 0.4959453033709292,
#  (5, 18, 19): 0.543222478630036,
#  (4, 19, 57): 0.6093778611037021,
#  (5, 18, 57): 0.6110883711250402,
#  (4, 20, 20): 0.5004434876119833,
#  (5, 19, 20): 0.5470177244216667,
#  (4, 20, 60): 0.6124243742485055,
#  (5, 19, 60): 0.6127122872794205,
#  (4, 21, 21): 0.501754931550492,
#  (5, 20, 21): 0.5505264463888041,
#  (4, 21, 63): 0.614252404517858,
#  (5, 20, 63): 0.6159845133914207,
#  (4, 22, 22): 0.5025522368075666,
#  (5, 21, 22): 0.5517973221921625,
#  (4, 22, 66): 0.6150826703511068,
#  (5, 21, 66): 0.6187561455845992,
#  (4, 23, 23): 0.5031675890997307,
#  (5, 22, 23): 0.5531504092469813,
#  (4, 23, 69): 0.6156283473259496,
#  (5, 22, 69): 0.6198103713388458,
#  (4, 24, 24): 0.506093654740131,
#  (5, 23, 24): 0.5539436130374774,
#  (4, 24, 72): 0.6177887948462294,
#  (5, 23, 72): 0.6206770046116361,
#  (4, 25, 25): 0.5079278041330082,
#  (5, 24, 25): 0.5569707103687193,
#  (4, 25, 75): 0.619438130170494,
#  (5, 24, 75): 0.6214497341455826,
#  (4, 26, 26): 0.5085600915129808,
#  (5, 25, 26): 0.5597136488340192,
#  (4, 26, 78): 0.6200700371725177,
#  (5, 25, 78): 0.6240545788772883,
#  (4, 27, 27): 0.5094988642906738,
#  (5, 26, 27): 0.5606478239999831,
#  (4, 27, 81): 0.6205027253583889,
#  (5, 26, 81): 0.6261406211631442,
#  (4, 28, 28): 0.5131205254322682,
#  (5, 27, 28): 0.5612278672955936,
#  (4, 28, 84): 0.6225665568796677,
#  (5, 27, 84): 0.6265492628473809,
#  (4, 29, 29): 0.5143106453432743,
#  (5, 28, 29): 0.5613912478936984,
#  (4, 29, 87): 0.6242289738977375,
#  (5, 28, 87): 0.626946129353376,
#  (4, 30, 30): 0.5156899950147334,
#  (5, 29, 30): 0.5637915319797965,
#  (4, 30, 90): 0.6246810778971702,
#  (5, 29, 90): 0.6272628022648563,
#  (4, 31, 31): 0.5166124611551424,
#  (5, 30, 31): 0.566074510814112,
#  (4, 31, 93): 0.6255271046080374,
#  (5, 30, 93): 0.6294413425449626,
#  (4, 32, 32): 0.5177187986883774,
#  (5, 31, 32): 0.5665562016026944,
#  (4, 32, 96): 0.6264351494627344,
#  (5, 31, 96): 0.6310857660322359,
#  (4, 33, 33): 0.5180689779356974,
#  (5, 32, 33): 0.5674294005296449,
#  (4, 33, 99): 0.626903626252138,
#  (5, 32, 99): 0.6314149087251689,
#  (4, 34, 34): 0.5183972606437027,
#  (5, 33, 34): 0.5680504584910413,
#  (4, 35, 35): 0.5188368121708242,
#  ...}

# %%
exportStateProbs(DATA_DIR + 'game1_better_giving_1_to_another_memo_1-100.csv', betterGiving1ToAnother)

# %%
betterGiving1ToAnother, given1ToAnother = readApproxBetterGiving1Probs(DATA_DIR + 'game1_better_giving_1_to_another_memo_1-100.csv')

# %%
betterGiving1ToAnother, given1ToAnother = stricterFilter(betterGiving1ToAnother, printOnGo=True,
                                                         filename=DATA_DIR + 'game1_better_giving_1_to_another_stricter_1-100.csv',
                                                         giveToAnother=True, continueFrom=(32,52,53))
# Out:
# Approximating hitting prob for (32, 27, 53)
# (32, 27, 53): 0.3388423991611947
# (31, 28, 53): 0.3468840680443627
#
# Approximating hitting prob for (32, 53, 54)
# (32, 53, 54): 0.45038531604746757
# (31, 54, 54): 0.4017268643143486
#
# Approximating hitting prob for (32, 54, 55)
# (32, 54, 55): 0.45302132503522924
# (31, 55, 55): 0.40362383571858423
#
# Approximating hitting prob for (32, 54, 65)
# (32, 54, 65): 0.4782515421669625
# (31, 55, 65): 0.4768620048216296
#
# Approximating hitting prob for (31, 56, 56)
# (31, 56, 56): 0.40437318628446356
# (30, 57, 56): 0.4593756784195304
#
# Approximating hitting prob for (31, 56, 66)
# (31, 56, 66): 0.47822202531925145
# (30, 57, 66): 0.4800002736222846
#
# Approximating hitting prob for (32, 19, 56)
# (32, 19, 56): 0.34519945396522217
# (31, 20, 56): 0.35175935403046193
#
# Approximating hitting prob for (32, 56, 57)
# (32, 56, 57): 0.45562223339781954
# (31, 57, 57): 0.40596793461320746
#
# Approximating hitting prob for (32, 56, 67)
# (32, 56, 67): 0.4793899474040016
# (31, 57, 67): 0.4788334709567628
#
# Approximating hitting prob for (31, 58, 58)
# (31, 58, 58): 0.40670587952207377
# (30, 59, 58): 0.45910484013062774
#
# Approximating hitting prob for (31, 58, 68)
# (31, 58, 68): 0.47933172681519814
# (30, 59, 68): 0.4810786318392288
#
# Approximating hitting prob for (31, 58, 73)
# (31, 58, 73): 0.48587204313056437
# (30, 59, 73): 0.48784471261701196
#
# Approximating hitting prob for (31, 59, 59)
# (31, 59, 59): 0.4076184228007371
# (30, 60, 59): 0.47250450387817206
#
# Approximating hitting prob for (31, 59, 69)
# (31, 59, 69): 0.4803518878254662
# (30, 60, 69): 0.4927702870694051
#
# Approximating hitting prob for (32, 20, 59)
# (32, 20, 59): 0.35104857155100594
# (31, 21, 59): 0.357559179096663
#
# Approximating hitting prob for (31, 60, 60)
# (31, 60, 60): 0.40831698974985214
# (30, 61, 60): 0.48530153094257517
#
# Approximating hitting prob for (32, 59, 61)
# (32, 59, 61): 0.45937407554258486
# (31, 60, 61): 0.4591220322298934
#
# Approximating hitting prob for (32, 59, 70)
# (32, 59, 70): 0.48172775465235995
# (31, 60, 70): 0.48069973189111187
#
# Approximating hitting prob for (32, 59, 75)
# (32, 59, 75): 0.48754498411106933
# (31, 60, 75): 0.4875652649534017
#
# Approximating hitting prob for (32, 60, 61)
# (32, 60, 61): 0.4595487835421252
# (31, 61, 61): 0.40884880930527245
#
# Approximating hitting prob for (32, 60, 71)
# (32, 60, 71): 0.48254966543917827
# (31, 61, 71): 0.4811757795979225
#
# Approximating hitting prob for (32, 60, 76)
# (32, 60, 76): 0.48835753402024845
# (31, 61, 76): 0.48810164822786106
#
# Approximating hitting prob for (32, 61, 62)
# (32, 61, 62): 0.4601982621574012
# (31, 62, 62): 0.4285714285714286
#
# Approximating hitting prob for (31, 63, 63)
# (31, 63, 63): 0.43380530581741555
# (30, 64, 63): 0.48718052313908006
#
# Approximating hitting prob for (31, 64, 64)
# (31, 64, 64): 0.43415909225281757
# (30, 65, 64): 0.48769860212555916
#
# Approximating hitting prob for (31, 13, 65)
# (31, 13, 65): 0.32698944959046866
# (30, 14, 65): 0.335840336166042
#
# Approximating hitting prob for (31, 65, 65)
# (31, 65, 65): 0.4345107419690686
# (30, 66, 65): 0.488754894197538
#
# Approximating hitting prob for (31, 65, 68)
# (31, 65, 68): 0.4870753737168613
# (30, 66, 68): 0.4906878737754206
#
# Approximating hitting prob for (31, 65, 75)
# (31, 65, 75): 0.49761991243648707
# (30, 66, 75): 0.4993183991423276
#
# Approximating hitting prob for (32, 22, 65)
# (32, 22, 65): 0.3596512561296317
# (31, 23, 65): 0.3633448187677059
#
# Approximating hitting prob for (32, 65, 66)
# (32, 65, 66): 0.4845368029242239
# (31, 66, 66): 0.4350090514651252
#
# Approximating hitting prob for (32, 65, 70)
# (32, 65, 70): 0.4896463196220148
# (31, 66, 70): 0.48882904288440066
#
# Approximating hitting prob for (32, 65, 76)
# (32, 65, 76): 0.5003862452110098
# (31, 66, 76): 0.49799994010854776
#
# Approximating hitting prob for (32, 65, 81)
# (32, 65, 81): 0.5042230052606606
# (31, 66, 81): 0.5035796890552628
#
# Approximating hitting prob for (32, 66, 67)
# (32, 66, 67): 0.4866304421384029
# (31, 67, 67): 0.43529786755904243
#
# Approximating hitting prob for (32, 66, 72)
# (32, 66, 72): 0.4914892181194262
# (31, 67, 72): 0.49096910146242734
#
# Approximating hitting prob for (32, 66, 77)
# (32, 66, 77): 0.5006175444230606
# (31, 67, 77): 0.4983874891530308
#
# Approximating hitting prob for (32, 66, 82)
# (32, 66, 82): 0.5045601722116075
# (31, 67, 82): 0.504304542958923
#
# Approximating hitting prob for (32, 67, 68)
# (32, 67, 68): 0.487069633048568
# (31, 68, 68): 0.4360113471369085
#
# Approximating hitting prob for (32, 67, 74)
# (32, 67, 74): 0.49371860272672413
# (31, 68, 74): 0.49264176575293295
#
# Approximating hitting prob for (31, 68, 83)
# (31, 68, 83): 0.5046833346428475
# (30, 69, 83): 0.5063748530359607
#
# Approximating hitting prob for (32, 23, 68)
# (32, 23, 68): 0.3626716155849536
# (31, 24, 68): 0.3657124684885817
#
# Approximating hitting prob for (32, 68, 69)
# (32, 68, 69): 0.4875294682600195
# (31, 69, 69): 0.43702028022646405
#
# Approximating hitting prob for (32, 68, 79)
# (32, 68, 79): 0.5012216117267952
# (31, 69, 79): 0.49988406251716005
#
# Approximating hitting prob for (32, 68, 84)
# (32, 68, 84): 0.5057769930367647
# (31, 69, 84): 0.505495922316338
#
# Approximating hitting prob for (32, 14, 69)
# (32, 14, 69): 0.3314773762972218
# (31, 15, 69): 0.3376798631005152
#
# Approximating hitting prob for (32, 69, 70)
# (32, 69, 70): 0.48824036707651003
# (31, 70, 70): 0.4385741294169406
#
# Approximating hitting prob for (32, 69, 78)
# (32, 69, 78): 0.4976872045287575
# (31, 70, 78): 0.4975144343333931
#
# Approximating hitting prob for (32, 69, 80)
# (32, 69, 80): 0.5015735259631365
# (31, 70, 80): 0.5004057531414418
#
# Approximating hitting prob for (32, 69, 85)
# (32, 69, 85): 0.5064248897888207
# (31, 70, 85): 0.506034206228201
#
# Approximating hitting prob for (32, 70, 71)
# (32, 70, 71): 0.48910562984197065
# (31, 71, 71): 0.43892281718562903
#
# Approximating hitting prob for (32, 70, 80)
# (32, 70, 80): 0.4990717220702951
# (31, 71, 80): 0.498691914345798
#
# Approximating hitting prob for (32, 70, 81)
# (32, 70, 81): 0.5024044527276741
# (31, 71, 81): 0.5008674275185443
#
# Approximating hitting prob for (32, 70, 86)
# (32, 70, 86): 0.5068732684071243
# (31, 71, 86): 0.5065267848879076
#
# Approximating hitting prob for (32, 71, 72)
# (32, 71, 72): 0.4899012003086669
# (31, 72, 72): 0.4395244878797477
#
# Approximating hitting prob for (32, 71, 82)
# (32, 71, 82): 0.5032408335710808
# (31, 72, 82): 0.4994079798962252
#
# Approximating hitting prob for (32, 71, 87)
# (32, 71, 87): 0.5075209659294191
# (31, 72, 87): 0.5069323938354651
#
# Approximating hitting prob for (32, 72, 73)
# (32, 72, 73): 0.49128871062798396
# (31, 73, 73): 0.44064728049384305
#
# Approximating hitting prob for (32, 72, 83)
# (32, 72, 83): 0.5035524465452335
# (31, 73, 83): 0.5022091436328492
#
# Approximating hitting prob for (32, 72, 84)
# (32, 72, 84): 0.5039330725878225
# (31, 73, 84): 0.5037389635030238
#
# Approximating hitting prob for (31, 74, 74)
# (31, 74, 74): 0.44105491118145773
# (30, 75, 74): 0.49604674486773753
#
# Approximating hitting prob for (31, 74, 84)
# (31, 74, 84): 0.5027192213420896
# (30, 75, 84): 0.5040249681928214
#
# Approximating hitting prob for (31, 74, 86)
# (31, 74, 86): 0.5046191947598172
# (30, 75, 86): 0.5077360742366929
#
# Approximating hitting prob for (31, 74, 89)
# (31, 74, 89): 0.507963448965579
# (30, 75, 89): 0.5090405071026901
#
# Approximating hitting prob for (32, 15, 74)
# (32, 15, 74): 0.33483882234669365
# (31, 16, 74): 0.3556902588221777
#
# Approximating hitting prob for (31, 75, 75)
# (31, 75, 75): 0.44142782229362343
# (30, 76, 75): 0.4966145483672408
#
# Approximating hitting prob for (31, 75, 85)
# (31, 75, 85): 0.5030121095989153
# (30, 76, 85): 0.5046634216191528
#
# Approximating hitting prob for (31, 75, 88)
# (31, 75, 88): 0.5053048580528045
# (30, 76, 88): 0.5087759875684271
#
# Approximating hitting prob for (31, 75, 90)
# (31, 75, 90): 0.5083915358810825
# (30, 76, 90): 0.5187327405368332
#
# Approximating hitting prob for (31, 76, 76)
# (31, 76, 76): 0.4417582854823577
# (30, 77, 76): 0.4980921877743685
#
# Approximating hitting prob for (31, 76, 86)
# (31, 76, 86): 0.5035841140905744
# (30, 77, 86): 0.5052682157486146
#
# Approximating hitting prob for (31, 76, 90)
# (31, 76, 90): 0.5064841852815184
# (30, 77, 90): 0.5188376484025171
#
# Approximating hitting prob for (31, 76, 91)
# (31, 76, 91): 0.5087047745829066
# (30, 77, 91): 0.5213092454998356
#
# Approximating hitting prob for (31, 77, 77)
# (31, 77, 77): 0.4419269093739478
# (30, 78, 77): 0.49855703710176114
# Approximating hitting prob for (31, 77, 87)
# (31, 77, 87): 0.5040121543818771
# (30, 78, 87): 0.5057060164523324
#
# Approximating hitting prob for (31, 77, 92)
# (31, 77, 92): 0.5071323101057504
# (30, 78, 92): 0.5217038480810077
#
# Approximating hitting prob for (32, 26, 77)
# (32, 26, 77): 0.37873686451942645
# (31, 27, 77): 0.38239476889824986
#
# Approximating hitting prob for (32, 77, 78)
# (32, 77, 78): 0.4942813167109932
# (31, 78, 78): 0.4449517994330379
#
# Approximating hitting prob for (32, 77, 88)
# (32, 77, 88): 0.5059866070592344
# (31, 78, 88): 0.504691755224793
#
# Approximating hitting prob for (32, 78, 79)
# (32, 78, 79): 0.4945667684702957
# (31, 79, 79): 0.44514736329590293
#
# Approximating hitting prob for (32, 78, 89)
# (32, 78, 89): 0.5065046798925308
# (31, 79, 89): 0.5051261673221286
#
# Approximating hitting prob for (32, 79, 80)
# (32, 79, 80): 0.49601044337965733
# (31, 80, 80): 0.4456903243858235
#
# Approximating hitting prob for (32, 79, 90)
# (32, 79, 90): 0.5070160578474078
# (31, 80, 90): 0.5055833278799274
#
# Approximating hitting prob for (32, 79, 98)
# (32, 79, 98): 0.5246768296293999
# (31, 80, 98): 0.5237225341172994
#
# Approximating hitting prob for (31, 81, 81)
# (31, 81, 81): 0.4460634973982374
# (30, 82, 81): 0.5004824941375529
#
# Approximating hitting prob for (31, 81, 91)
# (31, 81, 91): 0.5059807913968504
# (30, 82, 91): 0.5198543636076355
#
# Approximating hitting prob for (31, 81, 100)
# (31, 81, 100): 0.5249184239877347
# (30, 82, 100): 0.5282815936364073
#
# Approximating hitting prob for (32, 72, 81)
# (32, 72, 81): 0.49952440070962917
# (31, 73, 81): 0.5012631868021247
#
# Approximating hitting prob for (32, 81, 82)
# (32, 81, 82): 0.49803351752303354
# (31, 82, 82): 0.4465183609181386
#
# Approximating hitting prob for (32, 81, 92)
# (32, 81, 92): 0.5080425678348606
# (31, 82, 92): 0.5062620271428456
#
# Approximating hitting prob for (32, 81, 97)
# (32, 81, 97): 0.5230273124949145
# (31, 82, 97): 0.522491407434941
#
# Approximating hitting prob for (32, 82, 83)
# (32, 82, 83): 0.49843425843350153
# (31, 83, 83): 0.44717349669150347
#
# Approximating hitting prob for (32, 82, 98)
# (32, 82, 98): 0.5233928505137383
# (31, 83, 98): 0.5229815852541039
#
# Approximating hitting prob for (32, 14, 83)
# (32, 14, 83): 0.34726344669488046
# (31, 15, 83): 0.35111579332821635
#
# Approximating hitting prob for (31, 84, 84)
# (31, 84, 84): 0.4474755056974052
# (30, 85, 84): 0.5025888016704683
#
# Approximating hitting prob for (31, 84, 99)
# (31, 84, 99): 0.5232825654356799
# (30, 85, 99): 0.5258711271966606
#
# Approximating hitting prob for (31, 85, 85)
# (31, 85, 85): 0.44769601102512085
# (30, 86, 85): 0.502840354888233
#
# Approximating hitting prob for (31, 85, 100)
# (31, 85, 100): 0.5238021656910151
# (30, 86, 100): 0.5265137915206552
#
# Approximating hitting prob for (31, 86, 86)
# (31, 86, 86): 0.4488831718818189
# (30, 87, 86): 0.5033565388256163
#
# Approximating hitting prob for (32, 29, 86)
# (32, 29, 86): 0.38684481112174796
# (31, 30, 86): 0.3902665675569404
#
# Approximating hitting prob for (32, 86, 87)
# (32, 86, 87): 0.500294603260164
# (31, 87, 87): 0.44932719832409984
#
# Approximating hitting prob for (32, 86, 97)
# (32, 86, 97): 0.5228814686496899
# (31, 87, 97): 0.5211046564870857
#
# Approximating hitting prob for (31, 88, 88)
# (31, 88, 88): 0.44992189767986757
# (30, 89, 88): 0.5037253855906508
#
# Approximating hitting prob for (31, 88, 98)
# (31, 88, 98): 0.5215529798646946
# (30, 89, 98): 0.5228963362543425
#
# Approximating hitting prob for (31, 89, 89)
# (31, 89, 89): 0.45012548951922904
# (30, 90, 89): 0.5135409788586014
#
# Approximating hitting prob for (31, 89, 99)
# (31, 89, 99): 0.5218392300421684
# (30, 90, 99): 0.5324048783030458
#
# Approximating hitting prob for (32, 30, 89)
# (32, 30, 89): 0.38934921859117094
# (31, 31, 89): 0.4511752324728662
#
# Approximating hitting prob for (32, 54, 89)
# (32, 54, 89): 0.5129972968565935
# (31, 55, 89): 0.5144165079537842
#
# Approximating hitting prob for (31, 90, 90)
# (31, 90, 90): 0.4505623510970182
# (30, 91, 90): 0.525400255279221
#
# Approximating hitting prob for (31, 90, 100)
# (31, 90, 100): 0.5224880525101397
# (30, 91, 100): 0.5354994068008757
#
# Approximating hitting prob for (31, 91, 91)
# (31, 91, 91): 0.450835703503335
# (30, 92, 91): 0.5275551212570196
#
# Approximating hitting prob for (32, 77, 91)
# (32, 77, 91): 0.5073823377111343
# (31, 78, 91): 0.5087847402284456
#
# Approximating hitting prob for (32, 91, 92)
# (32, 91, 92): 0.5030631058723145
# (31, 92, 92): 0.45108526214853856
#
# Approximating hitting prob for (32, 92, 93)
# (32, 92, 93): 0.5033621502370844
# (31, 93, 93): 0.46941896024464413
#
# Approximating hitting prob for (32, 93, 94)
# (32, 93, 94): 0.5037190029842212
# (31, 94, 94): 0.47463068534718933
#
# Approximating hitting prob for (32, 94, 95)
# (32, 94, 95): 0.5037052793232385
# (31, 95, 95): 0.47489038127048766
#
# Approximating hitting prob for (32, 95, 96)
# (32, 95, 96): 0.5134950597487721
# (31, 96, 96): 0.4751217540446937
#
# Approximating hitting prob for (32, 96, 97)
# (32, 96, 97): 0.5253552690765602
# (31, 97, 97): 0.47560612000088404
#
# Approximating hitting prob for (31, 98, 98)
# (31, 98, 98): 0.47576687083217245
# (30, 99, 98): 0.5305699319334267
#
# Approximating hitting prob for (31, 33, 99)
# (31, 33, 99): 0.49967332438501205
# (30, 34, 99): 0.5105406769356804
#
# Approximating hitting prob for (31, 34, 99)
# (31, 34, 99): 0.5069882883538841
# (30, 35, 99): 0.5116910893863529
#
# Approximating hitting prob for (31, 99, 99)
# (31, 99, 99): 0.4762545721612474
# (30, 100, 99): 0.5310776941468658
#
# Approximating hitting prob for (31, 100, 100)
# (31, 100, 100): 0.4764926281195585
# (30, 101, 100): 0.5318025375267655
#
# Approximating hitting prob for (32, 5, 5)
# (32, 5, 5): 0.024854792732706285
# (31, 6, 5): 0.040231199898455104
#
# Approximating hitting prob for (32, 6, 6)
# (32, 6, 6): 0.033160522934205634
# (31, 7, 6): 0.05062182332496437
#
# Approximating hitting prob for (32, 6, 12)
# (32, 6, 12): 0.07482408900222925
# (31, 7, 12): 0.09648899274349597
#
# Approximating hitting prob for (32, 7, 7)
# (32, 7, 7): 0.03841739507832822
# (31, 8, 7): 0.06159447931665125
#
# Approximating hitting prob for (32, 8, 8)
# (32, 8, 8): 0.053763440860215055
# (31, 9, 8): 0.07601840386225966
#
# Approximating hitting prob for (32, 8, 16)
# (32, 8, 16): 0.10550458715595556
# (31, 9, 16): 0.1201600550082989
#
# Approximating hitting prob for (32, 9, 9)
# (32, 9, 9): 0.06210664109800005
# (31, 10, 9): 0.08428301743528542
#
# Approximating hitting prob for (32, 9, 18)
# (32, 9, 18): 0.11544370352480011
# (31, 10, 18): 0.12974402603428667
#
# Approximating hitting prob for (32, 10, 10)
# (32, 10, 10): 0.06898812000020638
# (31, 11, 10): 0.10415980829704015
#
# Approximating hitting prob for (32, 10, 20)
# (32, 10, 20): 0.12416934956017699
# (31, 11, 20): 0.17045738914599184
#
# Approximating hitting prob for (32, 10, 40)
# (32, 10, 40): 0.26591393155772985
# (31, 11, 40): 0.2923462033837584
#
# Approximating hitting prob for (33, 6, 11)
# (33, 6, 11): 0.07666082859255098
# (32, 7, 11): 0.08741396344946371
#
# Approximating hitting prob for (33, 11, 12)
# (33, 11, 12): 0.11458405043670065
# (32, 12, 12): 0.10101028194464957
#
# Approximating hitting prob for (33, 11, 24)
# (33, 11, 24): 0.1851798661257972
# (32, 12, 24): 0.1824478821019516
#
# Approximating hitting prob for (33, 12, 13)
# (33, 12, 13): 0.11994039310245096
# (32, 13, 13): 0.10475146331557637
#
# Approximating hitting prob for (33, 12, 26)
# (33, 12, 26): 0.19388791394667879
# (32, 13, 26): 0.19231636745416378
#
# Approximating hitting prob for (33, 12, 39)
# (33, 12, 39): 0.2857402012896397
# (32, 13, 39): 0.2846484007593424
#
# Approximating hitting prob for (33, 7, 13)
# (33, 7, 13): 0.09647980981546479
# (32, 8, 13): 0.09977335238479763
#
# Approximating hitting prob for (33, 13, 14)
# (33, 13, 14): 0.12457225863919737
# (32, 14, 14): 0.10762015109783586
#
# Approximating hitting prob for (33, 13, 28)
# (33, 13, 28): 0.20373417496228408
# (32, 14, 28): 0.20315371836708343
#
# Approximating hitting prob for (33, 13, 42)
# (33, 13, 42): 0.2932842707367423
# (32, 14, 42): 0.2898387601559147
#
# Approximating hitting prob for (33, 14, 15)
# (33, 14, 15): 0.1288682043147805
# (32, 15, 15): 0.11022844774071101
#
# Approximating hitting prob for (33, 14, 30)
# (33, 14, 30): 0.21498189251546398
# (32, 15, 30): 0.2106690273671765
#
# Approximating hitting prob for (33, 14, 45)
# (33, 14, 45): 0.2980218391679498
# (32, 15, 45): 0.29403158347510233
#
# Approximating hitting prob for (32, 17, 17)
# (32, 17, 17): 0.16434144356833144
# (31, 18, 17): 0.20835298822394907
# Approximating hitting prob for (33, 9, 17)
# (33, 9, 17): 0.11717124194116785
# (32, 10, 17): 0.1232111425762963
#
# Approximating hitting prob for (33, 17, 18)
# (33, 17, 18): 0.20270826700908337
# (32, 18, 18): 0.1665575877412034
#
# Approximating hitting prob for (33, 17, 36)
# (33, 17, 36): 0.303102577788166
# (32, 18, 36): 0.29587917276248393
#
# Approximating hitting prob for (33, 17, 54)
# (33, 17, 54): 0.3380346436526611
# (32, 18, 54): 0.33480729927054004
#
# Approximating hitting prob for (33, 17, 85)
# (33, 17, 85): 0.37408497366464627
# (32, 18, 85): 0.3728101933868075
#
# Approximating hitting prob for (33, 17, 86)
# (33, 17, 86): 0.372909171804239
# (32, 18, 86): 0.3727456499347497
#
# Approximating hitting prob for (33, 18, 19)
# (33, 18, 19): 0.20795840800761967
# (32, 19, 19): 0.16898523003494906
#
# Approximating hitting prob for (33, 18, 38)
# (33, 18, 38): 0.30685448668797505
# (32, 19, 38): 0.29837381523147993
#
# Approximating hitting prob for (33, 18, 57)
# (33, 18, 57): 0.3429113584306996
# (32, 19, 57): 0.33817428973356467
#
# Approximating hitting prob for (33, 18, 88)
# (33, 18, 88): 0.37528164729925884
# (32, 19, 88): 0.3748805374521544
#
# Approximating hitting prob for (33, 18, 89)
# (33, 18, 89): 0.3755298145936153
# (32, 19, 89): 0.37464186532368354
#
# Approximating hitting prob for (32, 20, 20)
# (32, 20, 20): 0.17595019969795658
# (31, 21, 20): 0.22352768367353418
#
# Approximating hitting prob for (32, 20, 40)
# (32, 20, 40): 0.306556505077879
# (31, 21, 40): 0.3241742984016876
#
# Approximating hitting prob for (32, 20, 60)
# (32, 20, 60): 0.34463728347787453
# (31, 21, 60): 0.35786099279279854
#
# Approximating hitting prob for (32, 21, 21)
# (32, 21, 21): 0.17853591689027073
# (31, 22, 21): 0.22956178991618045
#
# Approximating hitting prob for (32, 21, 42)
# (32, 21, 42): 0.30984919959615514
# (31, 22, 42): 0.3257911740771446
#
# Approximating hitting prob for (32, 21, 63)
# (32, 21, 63): 0.347415923073955
# (31, 22, 63): 0.3609367944590456
#
# Approximating hitting prob for (32, 21, 94)
# (32, 21, 94): 0.38207355618782796
# (31, 22, 94): 0.39681314267489415
#
# Approximating hitting prob for (32, 21, 95)
# (32, 21, 95): 0.38193276937195275
# (31, 22, 95): 0.3969858652873737
#
# Approximating hitting prob for (32, 22, 22)
# (32, 22, 22): 0.18600227743519707
# (31, 23, 22): 0.23337265647082453
#
# Approximating hitting prob for (32, 22, 44)
# (32, 22, 44): 0.31443949857167086
# (31, 23, 44): 0.33045800165585054
#
# Approximating hitting prob for (32, 22, 66)
# (32, 22, 66): 0.35277236550325936
# (31, 23, 66): 0.3634288714292823
#
# Approximating hitting prob for (32, 23, 23)
# (32, 23, 23): 0.18999397962898812
# (31, 24, 23): 0.2409550616531749
#
# Approximating hitting prob for (32, 23, 46)
# (32, 23, 46): 0.3184282306119435
# (31, 24, 46): 0.3336161213359677
#
# Approximating hitting prob for (32, 23, 69)
# (32, 23, 69): 0.3552610063933592
# (31, 24, 69): 0.3717421360508812
#
# Approximating hitting prob for (32, 23, 100)
# (32, 23, 100): 0.3981360171379955
# (31, 24, 100): 0.401550774538143
#
# Approximating hitting prob for (33, 12, 23)
# (33, 12, 23): 0.18607635690774602
# (32, 13, 23): 0.18945223183211699
#
# Approximating hitting prob for (33, 23, 24)
# (33, 23, 24): 0.2317579700895568
# (32, 24, 24): 0.19596772116592112
#
# Approximating hitting prob for (33, 23, 48)
# (33, 23, 48): 0.32925000513395813
# (32, 24, 48): 0.3204587476532555
#
# Approximating hitting prob for (33, 24, 25)
# (33, 24, 25): 0.23702214118342235
# (32, 25, 25): 0.2027699209064072
#
# Approximating hitting prob for (33, 24, 50)
# (33, 24, 50): 0.3321154628212191
# (32, 25, 50): 0.3231767004264366
#
# Approximating hitting prob for (33, 24, 75)
# (33, 24, 75): 0.3704562033965342
# (32, 25, 75): 0.3686005913740684
#
# Approximating hitting prob for (32, 26, 26)
# (32, 26, 26): 0.2052789677094485
# (31, 27, 26): 0.2548827385555806
#
# Approximating hitting prob for (32, 26, 52)
# (32, 26, 52): 0.32536601414508026
# (31, 27, 52): 0.3432825922759035
#
# Approximating hitting prob for (32, 26, 78)
# (32, 26, 78): 0.37036697182646755
# (31, 27, 78): 0.382659725865736
#
# Approximating hitting prob for (32, 9, 27)
# (32, 9, 27): 0.17782318637363456
# (31, 10, 27): 0.192156576099451
#
# Approximating hitting prob for (32, 27, 27)
# (32, 27, 27): 0.20961483468509015
# (31, 28, 27): 0.25871365005215247
#
# Approximating hitting prob for (32, 27, 54)
# (32, 27, 54): 0.32877952210019906
# (31, 28, 54): 0.34536933297006406
#
# Approximating hitting prob for (32, 27, 81)
# (32, 27, 81): 0.3736829217590764
# (31, 28, 81): 0.3862136639123712
#
# Approximating hitting prob for (32, 28, 28)
# (32, 28, 28): 0.21330055984615426
# (31, 29, 28): 0.2617033300865936
#
# Approximating hitting prob for (32, 28, 56)
# (32, 28, 56): 0.33034988900705786
# (31, 29, 56): 0.3482689307743896
#
# Approximating hitting prob for (32, 28, 57)
# (32, 28, 57): 0.3430974438575405
# (31, 29, 57): 0.34611665874434544
#
# Approximating hitting prob for (32, 28, 84)
# (32, 28, 84): 0.3763096189579583
# (31, 29, 84): 0.3886606938499691
#
# Approximating hitting prob for (32, 29, 29)
# (32, 29, 29): 0.21585971017887215
# (31, 30, 29): 0.26439847381527093
#
# Approximating hitting prob for (32, 29, 58)
# (32, 29, 58): 0.3314774977276738
# (31, 30, 58): 0.35640160798085513
#
# Approximating hitting prob for (32, 29, 59)
# (32, 29, 59): 0.34486785982125817
# (31, 30, 59): 0.3492522051877897
#
# Approximating hitting prob for (32, 29, 87)
# (32, 29, 87): 0.37888671076550634
# (31, 30, 87): 0.3905397601093447
#
# Approximating hitting prob for (33, 15, 29)
# (33, 15, 29): 0.21458516354712606
# (32, 16, 29): 0.2316348908985
#
# Approximating hitting prob for (33, 29, 30)
# (33, 29, 30): 0.2593564781652469
# (32, 30, 30): 0.2188577099626963
#
# Approximating hitting prob for (33, 29, 60)
# (33, 29, 60): 0.34592804055400395
# (32, 30, 60): 0.3323789398352908
#
# Approximating hitting prob for (33, 29, 90)
# (33, 29, 90): 0.3869976160378732
# (32, 30, 90): 0.3809604435247449
#
# Approximating hitting prob for (33, 30, 31)
# (33, 30, 31): 0.26212730762663483
# (32, 31, 31): 0.22092089295523165
#
# Approximating hitting prob for (33, 30, 62)
# (33, 30, 62): 0.34778311527630823
# (32, 31, 62): 0.33304739807168227
#
# Approximating hitting prob for (33, 30, 93)
# (33, 30, 93): 0.3868575070379486
# (32, 31, 93): 0.38260922595300206
#
# Approximating hitting prob for (33, 17, 33)
# (33, 17, 33): 0.2957982301669219
# (32, 18, 33): 0.3026252501216249
#
# Approximating hitting prob for (33, 33, 34)
# (33, 33, 34): 0.389498118436157
# (32, 34, 34): 0.35729675905828334
#
# Approximating hitting prob for (33, 34, 35)
# (33, 34, 35): 0.4015070830017277
# (32, 35, 35): 0.3585769496084041
#
# Approximating hitting prob for (33, 12, 35)
# (33, 12, 35): 0.28069626236264456
# (32, 13, 35): 0.28562847690841936
#
# Approximating hitting prob for (32, 36, 36)
# (32, 36, 36): 0.36029471770517746
# (31, 37, 36): 0.4086593911695928
#
# Approximating hitting prob for (32, 37, 37)
# (32, 37, 37): 0.3617798789172886
# (31, 38, 37): 0.4104473733009883
#
# Approximating hitting prob for (33, 19, 37)
# (33, 19, 37): 0.3069356698092449
# (32, 20, 37): 0.31566447158764266
#
# Approximating hitting prob for (33, 37, 38)
# (33, 37, 38): 0.4061873824981948
# (32, 38, 38): 0.36382639059288197
#
# Approximating hitting prob for (32, 39, 39)
# (32, 39, 39): 0.3656706189511357
# (31, 40, 39): 0.41563483257848505
#
# Approximating hitting prob for (33, 10, 39)
# (33, 10, 39): 0.26670100489997445
# (32, 11, 39): 0.28439739359139415
#
# Approximating hitting prob for (32, 40, 40)
# (32, 40, 40): 0.3679559744936582
# (31, 41, 40): 0.41689819363175973
#
# Approximating hitting prob for (32, 41, 41)
# (32, 41, 41): 0.37022107301053536
# (31, 42, 41): 0.4193034725827512
#
# Approximating hitting prob for (33, 14, 41)
# (33, 14, 41): 0.2937633284348536
# (32, 15, 41): 0.2974942058481121
#
# Approximating hitting prob for (32, 42, 42)
# (32, 42, 42): 0.37157121141349436
# (31, 43, 42): 0.4208120525893637
#
# Approximating hitting prob for (32, 43, 43)
# (32, 43, 43): 0.3740874168351685
# (31, 44, 43): 0.422403680752005
#
# Approximating hitting prob for (33, 22, 43)
# (33, 22, 43): 0.3232102340100872
# (32, 23, 43): 0.32747109240976835
#
# Approximating hitting prob for (33, 43, 44)
# (33, 43, 44): 0.4177070301818755
# (32, 44, 44): 0.37501017380220114
#
# Approximating hitting prob for (32, 45, 45)
# (32, 45, 45): 0.37662472354966753
# (31, 46, 45): 0.4244390023786979
#
# Approximating hitting prob for (33, 23, 45)
# (33, 23, 45): 0.32584161094440617
# (32, 24, 45): 0.330368686477116
#
# Approximating hitting prob for (33, 45, 46)
# (33, 45, 46): 0.42119014760283774
# (32, 46, 46): 0.3773700563408832
#
# Approximating hitting prob for (33, 46, 47)
# (33, 46, 47): 0.42255579916513003
# (32, 47, 47): 0.3780005581510528
#
# Approximating hitting prob for (32, 48, 48)
# (32, 48, 48): 0.38531294066601585
# (31, 49, 48): 0.44517142390124476
#
# Approximating hitting prob for (32, 49, 49)
# (32, 49, 49): 0.3926037164404778
# (31, 50, 49): 0.44588311206603426
#
# Approximating hitting prob for (33, 25, 49)
# (33, 25, 49): 0.3323093958051305
# (32, 26, 49): 0.3373849406886311
#
# Approximating hitting prob for (33, 49, 50)
# (33, 49, 50): 0.43554661848615367
# (32, 50, 50): 0.39321993388563553
#
# Approximating hitting prob for (33, 50, 51)
# (33, 50, 51): 0.4432176388532129
# (32, 51, 51): 0.393855471120085
#
# Approximating hitting prob for (32, 52, 52)
# (32, 52, 52): 0.3947469573259146
# (31, 53, 52): 0.4528985046470279
#
# Approximating hitting prob for (32, 53, 53)
# (32, 53, 53): 0.3953718070238695
# (31, 54, 53): 0.45355161310738334
#
# Approximating hitting prob for (32, 53, 63)
# (32, 53, 63): 0.4592836311249047
# (31, 54, 63): 0.47574556854490035
#
# Approximating hitting prob for (33, 18, 53)
# (33, 18, 53): 0.3385655882347127
# (32, 19, 53): 0.34192575139310327
#
# Approximating hitting prob for (32, 54, 54)
# (32, 54, 54): 0.4007384634436817
# (31, 55, 54): 0.45513153321960714
#
# Approximating hitting prob for (32, 55, 55)
# (32, 55, 55): 0.40133764205301053
# (31, 56, 55): 0.4560247264808432
#
# Approximating hitting prob for (33, 28, 55)
# (33, 28, 55): 0.3407122248379803
# (32, 29, 55): 0.3469677750119349
#
# Approximating hitting prob for (33, 55, 56)
# (33, 55, 56): 0.4523336296369907
# (32, 56, 56): 0.4025301176497849
#
# Approximating hitting prob for (32, 57, 57)
# (32, 57, 57): 0.40376559590097627
# (31, 58, 57): 0.45846742027716286
#
# Approximating hitting prob for (32, 57, 67)
# (32, 57, 67): 0.4771722694772877
# (31, 58, 67): 0.47889039435655584
#
# Approximating hitting prob for (32, 57, 95)
# (32, 57, 95): 0.513695275214071
# (31, 58, 95): 0.5277011310522882
#
# Approximating hitting prob for (33, 29, 57)
# (33, 29, 57): 0.34267843458130787
# (32, 30, 57): 0.3543663636491045
#
# Approximating hitting prob for (33, 57, 58)
# (33, 57, 58): 0.4542164337240145
# (32, 58, 58): 0.40446053690438927
#
# Approximating hitting prob for (33, 57, 61)
# (33, 57, 61): 0.4574865480924588
# (32, 58, 61): 0.45746139194429847
#
# Approximating hitting prob for (33, 58, 59)
# (33, 58, 59): 0.45573966411840194
# (32, 59, 59): 0.4060116779951721
#
# Approximating hitting prob for (33, 30, 59)
# (33, 30, 59): 0.344459738023371
# (32, 31, 59): 0.3574398647655735
#
# Approximating hitting prob for (33, 59, 60)
# (33, 59, 60): 0.45638569297572334
# (32, 60, 60): 0.40692635827340995
#
# Approximating hitting prob for (33, 59, 62)
# (33, 59, 62): 0.45868259823564256
# (32, 60, 62): 0.45865698648184733
#
# Approximating hitting prob for (33, 59, 70)
# (33, 59, 70): 0.47965975602989097
# (32, 60, 70): 0.47910167618259175
#
# Approximating hitting prob for (33, 59, 100)
# (33, 59, 100): 0.5267559336078383
# (32, 60, 100): 0.5265015144471672
#
# Approximating hitting prob for (33, 60, 61)
# (33, 60, 61): 0.4574760063760012
# (32, 61, 61): 0.407642141146953
#
# Approximating hitting prob for (32, 62, 62)
# (32, 62, 62): 0.4083547124385222
# (31, 63, 62): 0.4852733117802724
#
# Approximating hitting prob for (33, 61, 63)
# (33, 61, 63): 0.4595174215105781
# (32, 62, 63): 0.45914502621949005
#
# Approximating hitting prob for (32, 63, 63)
# (32, 63, 63): 0.4088632858569439
# (31, 64, 63): 0.4845671265250693
#
# Approximating hitting prob for (32, 63, 73)
# (32, 63, 73): 0.48117564834146725
# (31, 64, 73): 0.49606772995318166
#
# Approximating hitting prob for (32, 64, 64)
# (32, 64, 64): 0.4285714285714286
# (31, 65, 64): 0.4867068210211685
#
# Approximating hitting prob for (32, 65, 65)
# (32, 65, 65): 0.43379826493332335
# (31, 66, 65): 0.4871085884137434
#
# Approximating hitting prob for (33, 22, 65)
# (33, 22, 65): 0.3572072562982955
# (32, 23, 65): 0.36148414191091366
#
# Approximating hitting prob for (33, 65, 66)
# (33, 65, 66): 0.47247588852154115
# (32, 66, 66): 0.4341300809805498
#
# Approximating hitting prob for (33, 66, 67)
# (33, 66, 67): 0.48524200938156387
# (32, 67, 67): 0.43448990155094797
#
# Approximating hitting prob for (33, 66, 70)
# (33, 66, 70): 0.48747245896835145
# (32, 67, 70): 0.4870200022064521
#
# Approximating hitting prob for (33, 67, 68)
# (33, 67, 68): 0.484507437401603
# (32, 68, 68): 0.4349301594471646
#
# Approximating hitting prob for (33, 67, 72)
# (33, 67, 72): 0.4896025651484182
# (32, 68, 72): 0.4886453793005547
#
# Approximating hitting prob for (33, 67, 78)
# (33, 67, 78): 0.49896401185421646
# (32, 68, 78): 0.49787088872496893
#
# Approximating hitting prob for (33, 23, 68)
# (33, 23, 68): 0.3606190289164147
# (32, 24, 68): 0.36365085751765364
#
# Approximating hitting prob for (33, 68, 69)
# (33, 68, 69): 0.48660465416079796
# (32, 69, 69): 0.4352694959391117
#
# Approximating hitting prob for (33, 68, 74)
# (33, 68, 74): 0.49139677143164423
# (32, 69, 74): 0.4906434320359195
#
# Approximating hitting prob for (33, 68, 79)
# (33, 68, 79): 0.4991609487634506
# (32, 69, 79): 0.49823305591575867
#
# Approximating hitting prob for (33, 69, 70)
# (33, 69, 70): 0.4870149514882061
# (32, 70, 70): 0.4359614896449618
#
# Approximating hitting prob for (33, 69, 76)
# (33, 69, 76): 0.49343373760327774
# (32, 70, 76): 0.4925501386590682
#
# Approximating hitting prob for (32, 71, 71)
# (32, 71, 71): 0.4369625484416309
# (31, 72, 71): 0.492072660786747
#
# Approximating hitting prob for (32, 71, 81)
# (32, 71, 81): 0.4996368755720666
# (31, 72, 81): 0.5008249400089749
#
# Approximating hitting prob for (32, 24, 72)
# (32, 24, 72): 0.36246625785695336
# (31, 25, 72): 0.3777762435022754
#
# Approximating hitting prob for (32, 72, 72)
# (32, 72, 72): 0.4381003152708904
# (31, 73, 72): 0.49288166412821727
#
# Approximating hitting prob for (32, 72, 80)
# (32, 72, 80): 0.49704459867179973
# (31, 73, 80): 0.5000971663413648
#
# Approximating hitting prob for (32, 73, 73)
# (32, 73, 73): 0.4387903788834991
# (31, 74, 73): 0.4935978563572068
#
# Approximating hitting prob for (32, 73, 82)
# (32, 73, 82): 0.49831805163874626
# (31, 74, 82): 0.5016851034508111
#
# Approximating hitting prob for (32, 73, 83)
# (32, 73, 83): 0.5006631857810749
# (31, 74, 83): 0.5021650640341342
#
# Approximating hitting prob for (32, 21, 74)
# (32, 21, 74): 0.3598072722900099
# (31, 22, 74): 0.3748955429446295
#
# Approximating hitting prob for (32, 74, 74)
# (32, 74, 74): 0.4394351570727352
# (31, 75, 74): 0.4940471467344143
#
# Approximating hitting prob for (32, 74, 84)
# (32, 74, 84): 0.49920084239506557
# (31, 75, 84): 0.5025598900252773
#
# Approximating hitting prob for (32, 15, 75)
# (32, 15, 75): 0.33263343162051123
# (31, 16, 75): 0.35649758182851704
#
# Approximating hitting prob for (33, 25, 74)
# (33, 25, 74): 0.3714187208715652
# (32, 26, 74): 0.3778543714015099
#
# Approximating hitting prob for (33, 74, 75)
# (33, 74, 75): 0.49106656476467986
# (32, 75, 75): 0.4405839491283238
#
# Approximating hitting prob for (33, 74, 85)
# (33, 74, 85): 0.5021352221997891
# (32, 75, 85): 0.5017499947090881
#
# Approximating hitting prob for (32, 76, 76)
# (32, 76, 76): 0.4409467649855609
# (31, 77, 76): 0.494995137766792
#
# Approximating hitting prob for (32, 76, 86)
# (32, 76, 86): 0.502296082401568
# (31, 77, 86): 0.5035368968281687
#
# Approximating hitting prob for (32, 76, 88)
# (32, 76, 88): 0.5041483626303189
# (31, 77, 88): 0.5073612608528356
#
# Approximating hitting prob for (33, 75, 92)
# (33, 75, 92): 0.5100454576064612
# (32, 76, 92): 0.5100232922321457
#
# Approximating hitting prob for (33, 76, 77)
# (33, 76, 77): 0.49266905936234
# (32, 77, 77): 0.44135474498567673
#
# Approximating hitting prob for (33, 76, 87)
# (33, 76, 87): 0.5028200913535285
# (32, 77, 87): 0.5027740620181272
#
# Approximating hitting prob for (33, 76, 90)
# (33, 76, 90): 0.50564152021359
# (32, 77, 90): 0.5049912188869695
#
# Approximating hitting prob for (33, 76, 93)
# (33, 76, 93): 0.5103965113481717
# (32, 77, 93): 0.5103582120614535
#
# Approximating hitting prob for (32, 78, 78)
# (32, 78, 78): 0.4416752742409207
# (31, 79, 78): 0.49701308555984597
#
# Approximating hitting prob for (32, 78, 92)
# (32, 78, 92): 0.5062678252323166
# (31, 79, 92): 0.5091396732326823
#
# Approximating hitting prob for (32, 78, 94)
# (32, 78, 94): 0.5107995803178876
# (31, 79, 94): 0.5210445918876204
#
# Approximating hitting prob for (32, 79, 79)
# (32, 79, 79): 0.4418671448966301
# (31, 80, 79): 0.498071793263793
# Approximating hitting prob for (32, 79, 89)
# (32, 79, 89): 0.5037408545389922
# (31, 80, 89): 0.5052843691697735
#
# Approximating hitting prob for (32, 79, 94)
# (32, 79, 94): 0.5069349167216768
# (31, 80, 94): 0.521290743436564
#
# Approximating hitting prob for (32, 79, 95)
# (32, 79, 95): 0.5110135157362715
# (31, 80, 95): 0.5215866126303664
#
# Approximating hitting prob for (32, 80, 80)
# (32, 80, 80): 0.44255325660645745
# (31, 81, 80): 0.49872349161155055
#
# Approximating hitting prob for (32, 80, 90)
# (32, 80, 90): 0.5042010306726283
# (31, 81, 90): 0.5056483745116626
#
# Approximating hitting prob for (33, 27, 80)
# (33, 27, 80): 0.3790932738953336
# (32, 28, 80): 0.3827413731591798
#
# Approximating hitting prob for (33, 80, 81)
# (33, 80, 81): 0.4942128129123266
# (32, 81, 81): 0.44503359430924355
#
# Approximating hitting prob for (33, 80, 91)
# (33, 80, 91): 0.5048223701465441
# (32, 81, 91): 0.5047555382997576
#
# Approximating hitting prob for (33, 81, 82)
# (33, 81, 82): 0.4949816979812207
# (32, 82, 82): 0.44535099424553876
#
# Approximating hitting prob for (33, 81, 92)
# (33, 81, 92): 0.5054995089992407
# (32, 82, 92): 0.505308156106253
#
# Approximating hitting prob for (33, 81, 100)
# (33, 81, 100): 0.5244048642801845
# (32, 82, 100): 0.523366701908774
#
# Approximating hitting prob for (33, 82, 83)
# (33, 82, 83): 0.4962601099113381
# (32, 83, 83): 0.44580311450277416
#
# Approximating hitting prob for (33, 82, 93)
# (33, 82, 93): 0.5057815930780997
# (32, 83, 93): 0.5057297787729127
#
# Approximating hitting prob for (33, 74, 83)
# (33, 74, 83): 0.49927581071529215
# (32, 75, 83): 0.5006389757785359
#
# Approximating hitting prob for (33, 83, 84)
# (33, 83, 84): 0.4969777702187747
# (32, 84, 84): 0.44625991701326856
#
# Approximating hitting prob for (33, 83, 94)
# (33, 83, 94): 0.5064165653613597
# (32, 84, 94): 0.5060577797539169
#
# Approximating hitting prob for (33, 84, 85)
# (33, 84, 85): 0.4980173977928726
# (32, 85, 85): 0.4465764589290772
#
# Approximating hitting prob for (33, 84, 95)
# (33, 84, 95): 0.506777181216234
# (32, 85, 95): 0.5065399090215286
#
# Approximating hitting prob for (33, 85, 86)
# (33, 85, 86): 0.4986197364781193
# (32, 86, 86): 0.447223789992256
#
# Approximating hitting prob for (32, 87, 87)
# (32, 87, 87): 0.4475395182464968
# (31, 88, 87): 0.5026080076277809
#
# Approximating hitting prob for (32, 88, 88)
# (32, 88, 88): 0.44820689847484574
# (31, 89, 88): 0.5029382925233424
#
# Approximating hitting prob for (32, 89, 89)
# (32, 89, 89): 0.4489258369889854
# (31, 90, 89): 0.5033559728094289
#
# Approximating hitting prob for (33, 30, 89)
# (33, 30, 89): 0.3872586185282029
# (32, 31, 89): 0.3904409584554194
#
# Approximating hitting prob for (32, 90, 90)
# (32, 90, 90): 0.44938607610324555
# (31, 91, 90): 0.5037016633442398
#
# Approximating hitting prob for (32, 90, 100)
# (32, 90, 100): 0.5210720611930333
# (31, 91, 100): 0.5222446783292013
#
# Approximating hitting prob for (32, 91, 91)
# (32, 91, 91): 0.44994625504767227
# (31, 92, 91): 0.5037122051660162
#
# Approximating hitting prob for (32, 92, 92)
# (32, 92, 92): 0.4502250894161175
# (31, 93, 92): 0.5135167773782264
#
# Approximating hitting prob for (33, 31, 92)
# (33, 31, 92): 0.3894996050755896
# (32, 32, 92): 0.4511895700009371
#
# Approximating hitting prob for (33, 92, 93)
# (33, 92, 93): 0.5022097702470788
# (32, 93, 93): 0.4505783741334913
#
# Approximating hitting prob for (33, 93, 94)
# (33, 93, 94): 0.5026726675150842
# (32, 94, 94): 0.45086030319930753
#
# Approximating hitting prob for (32, 95, 95)
# (32, 95, 95): 0.45109116717588216
# (31, 96, 95): 0.5280862047186811
#
# Approximating hitting prob for (32, 96, 96)
# (32, 96, 96): 0.46941896024464413
# (31, 97, 96): 0.5284585695534592
#
# Approximating hitting prob for (32, 97, 97)
# (32, 97, 97): 0.4746244306721366
# (31, 98, 97): 0.5288485800580559
#
# Approximating hitting prob for (32, 98, 98)
# (32, 98, 98): 0.4748710064747097
# (31, 99, 98): 0.5292414685278866
#
# Approximating hitting prob for (32, 99, 99)
# (32, 99, 99): 0.47511027432582503
# (31, 100, 99): 0.5295523027793705
#
# Approximating hitting prob for (32, 100, 100)
# (32, 100, 100): 0.47550950914768597
# (31, 101, 100): 0.5299230526384554
#
# Approximating hitting prob for (33, 4, 4)
# (33, 4, 4): 0.013302534622365343
# (32, 5, 4): 0.02664051722966104
#
# Approximating hitting prob for (33, 6, 6)
# (33, 6, 6): 0.032266554720203344
# (32, 7, 6): 0.04923580353235051
#
# Approximating hitting prob for (33, 7, 7)
# (33, 7, 7): 0.036585521432283274
# (32, 8, 7): 0.05510823896504258
#
# Approximating hitting prob for (33, 8, 8)
# (33, 8, 8): 0.04179690754303767
# (32, 9, 8): 0.07441906701626536
#
# Approximating hitting prob for (33, 8, 16)
# (33, 8, 16): 0.10162400172632408
# (32, 9, 16): 0.11780909605538083
#
# Approximating hitting prob for (33, 8, 24)
# (33, 8, 24): 0.12774469680441572
# (32, 9, 24): 0.17474464526612843
#
# Approximating hitting prob for (33, 9, 9)
# (33, 9, 9): 0.06081596070063703
# (32, 10, 9): 0.08132861693438011
#
# Approximating hitting prob for (33, 9, 18)
# (33, 9, 18): 0.1124288216818159
# (32, 10, 18): 0.12721388379086693
#
# Approximating hitting prob for (33, 10, 10)
# (33, 10, 10): 0.06759997423396923
# (32, 11, 10): 0.10056467627001214
#
# Approximating hitting prob for (33, 10, 20)
# (33, 10, 20): 0.12241648685816488
# (32, 11, 20): 0.1463181001344791
#
# Approximating hitting prob for (33, 12, 12)
# (33, 12, 12): 0.09881769010474889
# (32, 13, 12): 0.12155447001783759
#
# Approximating hitting prob for (33, 13, 13)
# (33, 13, 13): 0.1031437420668667
# (32, 14, 13): 0.12611624573369273
#
# Approximating hitting prob for (33, 13, 26)
# (33, 13, 26): 0.18656275379610174
# (32, 14, 26): 0.20522178331222243
#
# Approximating hitting prob for (33, 13, 39)
# (33, 13, 39): 0.2814830059311694
# (32, 14, 39): 0.29308960747836527
#
# Approximating hitting prob for (33, 14, 14)
# (33, 14, 14): 0.10647397375748659
# (32, 15, 14): 0.13051152806662145
#
# Approximating hitting prob for (33, 14, 28)
# (33, 14, 28): 0.19450010747229599
# (32, 15, 28): 0.21502485713685462
#
# Approximating hitting prob for (33, 14, 42)
# (33, 14, 42): 0.2875719465598385
# (32, 15, 42): 0.2990065032775243
#
# Approximating hitting prob for (33, 15, 15)
# (33, 15, 15): 0.10943859940463435
# (32, 16, 15): 0.14005667220109688
#
# Approximating hitting prob for (33, 15, 30)
# (33, 15, 30): 0.20696436000065802
# (32, 16, 30): 0.233932116750974
#
# Approximating hitting prob for (33, 15, 45)
# (33, 15, 45): 0.2924521952683694
# (32, 16, 45): 0.3137064181555013
#
# Approximating hitting prob for (34, 8, 15)
# (34, 8, 15): 0.1056470946114501
# (33, 9, 15): 0.11181151627225387
#
# Approximating hitting prob for (34, 15, 16)
# (34, 15, 16): 0.13080755936824437
# (33, 16, 16): 0.11084495766771923
#
# Approximating hitting prob for (34, 15, 32)
# (34, 15, 32): 0.22157089897820625
# (33, 16, 32): 0.21351201774897274
#
# Approximating hitting prob for (34, 15, 48)
# (34, 15, 48): 0.3000318442372909
# (33, 16, 48): 0.29527420634189766
#
# Approximating hitting prob for (34, 15, 80)
# (34, 15, 80): 0.3366393895168294
# (33, 16, 80): 0.33339988794123515
#
# Approximating hitting prob for (34, 15, 81)
# (34, 15, 81): 0.33701111065537354
# (33, 16, 81): 0.3361341145702797
#
# Approximating hitting prob for (33, 18, 18)
# (33, 18, 18): 0.16524459731426341
# (32, 19, 18): 0.2095737261213435
#
# Approximating hitting prob for (33, 18, 36)
# (33, 18, 36): 0.2937768113033216
# (32, 19, 36): 0.308215341510979
#
# Approximating hitting prob for (33, 18, 54)
# (33, 18, 54): 0.33161656668246814
# (32, 19, 54): 0.34425686459602783
#
# Approximating hitting prob for (33, 19, 19)
# (33, 19, 19): 0.16752188146385938
# (32, 20, 19): 0.21467051161662085
#
# Approximating hitting prob for (33, 19, 38)
# (33, 19, 38): 0.2969251522972007
# (32, 20, 38): 0.31573962335283856
#
# Approximating hitting prob for (33, 19, 57)
# (33, 19, 57): 0.3361259692000402
# (32, 20, 57): 0.35042579282437575
#
# Approximating hitting prob for (33, 19, 89)
# (33, 19, 89): 0.3734546623287929
# (32, 20, 89): 0.37911462421805164
#
# Approximating hitting prob for (33, 19, 90)
# (33, 19, 90): 0.37385661202088194
# (32, 20, 90): 0.37989597167931244
#
# Approximating hitting prob for (34, 10, 19)
# (34, 10, 19): 0.12492640069868662
# (33, 11, 19): 0.13910016771999859
#
# Approximating hitting prob for (34, 19, 20)
# (34, 19, 20): 0.2091346714634159
# (33, 20, 20): 0.1740798206339398
#
# Approximating hitting prob for (34, 19, 40)
# (34, 19, 40): 0.30832532077548097
# (33, 20, 40): 0.3052664415601476
#
# Approximating hitting prob for (34, 19, 60)
# (34, 19, 60): 0.344009206491231
# (33, 20, 60): 0.34243422219588665
# Approximating hitting prob for (34, 20, 21)
# (34, 20, 21): 0.21408557686048016
# (33, 21, 21): 0.17707745397460653
#
# Approximating hitting prob for (34, 20, 42)
# (34, 20, 42): 0.3137820001945566
# (33, 21, 42): 0.3080530000872859
#
# Approximating hitting prob for (34, 20, 63)
# (34, 20, 63): 0.3471331488052169
# (33, 21, 63): 0.34608168615067697
#
# Approximating hitting prob for (34, 21, 22)
# (34, 21, 22): 0.2189208229345514
# (33, 22, 22): 0.18348623853210444
#
# Approximating hitting prob for (34, 21, 44)
# (34, 21, 44): 0.31933877111017667
# (33, 22, 44): 0.31260403488913774
#
# Approximating hitting prob for (34, 21, 66)
# (34, 21, 66): 0.35352737612692176
# (33, 22, 66): 0.35041358795203204
#
# Approximating hitting prob for (34, 22, 23)
# (34, 22, 23): 0.22356783313028192
# (33, 23, 23): 0.18652433533482793
#
# Approximating hitting prob for (34, 22, 46)
# (34, 22, 46): 0.3224897186530495
# (33, 23, 46): 0.31524700825833335
#
# Approximating hitting prob for (34, 22, 69)
# (34, 22, 69): 0.356590972455447
# (33, 23, 69): 0.3533111310455192
#
# Approximating hitting prob for (33, 12, 24)
# (33, 12, 24): 0.17949465414918586
# (32, 13, 24): 0.1941636505969657
#
# Approximating hitting prob for (33, 24, 24)
# (33, 24, 24): 0.19048276330106628
# (32, 25, 24): 0.24346931789875173
#
# Approximating hitting prob for (33, 24, 48)
# (33, 24, 48): 0.3187635821534672
# (32, 25, 48): 0.33439705877961684
#
# Approximating hitting prob for (33, 24, 72)
# (33, 24, 72): 0.35565433383563844
# (32, 25, 72): 0.3760127823580086
#
# Approximating hitting prob for (33, 24, 81)
# (33, 24, 81): 0.37449850439181187
# (32, 25, 81): 0.37996993976460125
#
# Approximating hitting prob for (33, 25, 25)
# (33, 25, 25): 0.20079326204492423
# (32, 26, 25): 0.24718897660732078
#
# Approximating hitting prob for (33, 25, 50)
# (33, 25, 50): 0.32127617318189194
# (32, 26, 50): 0.3370170644562145
#
# Approximating hitting prob for (34, 13, 25)
# (34, 13, 25): 0.19046877324515799
# (33, 14, 25): 0.1958723505954003
#
# Approximating hitting prob for (34, 25, 26)
# (34, 25, 26): 0.23894762570938574
# (33, 26, 26): 0.2030696777178386
#
# Approximating hitting prob for (34, 25, 52)
# (34, 25, 52): 0.33275408255414113
# (33, 26, 52): 0.32339050526919355
#
# Approximating hitting prob for (34, 25, 78)
# (34, 25, 78): 0.3740007614155169
# (33, 26, 78): 0.36906857754360384
#
# Approximating hitting prob for (34, 9, 26)
# (34, 9, 26): 0.17775673487809854
# (33, 10, 26): 0.17971994764368068
#
# Approximating hitting prob for (34, 26, 27)
# (34, 26, 27): 0.24539275152159412
# (33, 27, 27): 0.20556023200191997
#
# Approximating hitting prob for (34, 26, 54)
# (34, 26, 54): 0.3349129555297461
# (33, 27, 54): 0.325817229274621
#
# Approximating hitting prob for (34, 26, 81)
# (34, 26, 81): 0.3767434676115831
# (33, 27, 81): 0.37076543484061003
#
# Approximating hitting prob for (33, 28, 28)
# (33, 28, 28): 0.20990813484177062
# (32, 29, 28): 0.259091465609105
#
# Approximating hitting prob for (33, 28, 56)
# (33, 28, 56): 0.32922907722613876
# (32, 29, 56): 0.3454748101853973
#
# Approximating hitting prob for (33, 28, 57)
# (33, 28, 57): 0.3417108223432653
# (32, 29, 57): 0.3443219140048144
#
# Approximating hitting prob for (33, 28, 84)
# (33, 28, 84): 0.3738781426319134
# (32, 29, 84): 0.3863679245010346
#
# Approximating hitting prob for (33, 29, 29)
# (33, 29, 29): 0.21419963859685523
# (32, 30, 29): 0.26197945444940546
#
# Approximating hitting prob for (33, 29, 58)
# (33, 29, 58): 0.33049180848517845
# (32, 30, 58): 0.3483337812465756
#
# Approximating hitting prob for (33, 29, 59)
# (33, 29, 59): 0.3431950062869518
# (32, 30, 59): 0.34616417095523966
#
# Approximating hitting prob for (33, 29, 87)
# (33, 29, 87): 0.3770228379769174
# (32, 30, 87): 0.38887157008202305
#
# Approximating hitting prob for (34, 15, 29)
# (34, 15, 29): 0.210017214306056
# (33, 16, 29): 0.2170736725668594
#
# Approximating hitting prob for (34, 29, 30)
# (34, 29, 30): 0.25680496306510764
# (33, 30, 30): 0.21609698615287912
#
# Approximating hitting prob for (34, 29, 60)
# (34, 29, 60): 0.34439465244086676
# (33, 30, 60): 0.33157865494867217
#
# Approximating hitting prob for (34, 29, 61)
# (34, 29, 61): 0.3456617290295681
# (33, 30, 61): 0.3449820941226353
#
# Approximating hitting prob for (34, 29, 90)
# (34, 29, 90): 0.3841366929943186
# (33, 30, 90): 0.3790316949939627
#
# Approximating hitting prob for (34, 30, 31)
# (34, 30, 31): 0.25980263009351057
# (33, 31, 31): 0.21907059430033546
#
# Approximating hitting prob for (34, 30, 62)
# (34, 30, 62): 0.34608157734447115
# (33, 31, 62): 0.3324404708609597
#
# Approximating hitting prob for (34, 30, 93)
# (34, 30, 93): 0.3873153465747534
# (33, 31, 93): 0.38117138931243244
#
# Approximating hitting prob for (33, 32, 32)
# (33, 32, 32): 0.22097491730300545
# (32, 33, 32): 0.3895125413482494
#
# Approximating hitting prob for (33, 32, 64)
# (33, 32, 64): 0.33307548030482553
# (32, 33, 64): 0.4687448366470471
#
# Approximating hitting prob for (33, 32, 96)
# (33, 32, 96): 0.38264968640107905
# (32, 33, 96): 0.5044828578852236
#
# Approximating hitting prob for (33, 35, 35)
# (33, 35, 35): 0.35718528187635945
# (32, 36, 35): 0.4042952194888953
#
# Approximating hitting prob for (33, 12, 36)
# (33, 12, 36): 0.2741885136082182
# (32, 13, 36): 0.287117452379263
#
# Approximating hitting prob for (34, 18, 35)
# (34, 18, 35): 0.3021932957486554
# (33, 19, 35): 0.3038233081191269
#
# Approximating hitting prob for (34, 35, 36)
# (34, 35, 36): 0.40147631169282505
# (33, 36, 36): 0.35846076190696907
#
# Approximating hitting prob for (34, 36, 37)
# (34, 36, 37): 0.40267650980666736
# (33, 37, 37): 0.3596623559425114
#
# Approximating hitting prob for (33, 38, 38)
# (33, 38, 38): 0.36157517954028284
# (32, 39, 38): 0.4102133780433923
#
# Approximating hitting prob for (34, 13, 38)
# (34, 13, 38): 0.28547176101192595
# (33, 14, 38): 0.2911907989027292
#
# Approximating hitting prob for (34, 38, 39)
# (34, 38, 39): 0.4058623649948565
# (33, 39, 39): 0.36363833410299046
#
# Approximating hitting prob for (33, 40, 40)
# (33, 40, 40): 0.3652698362124187
# (32, 41, 40): 0.41533258140215307
#
# Approximating hitting prob for (33, 41, 41)
# (33, 41, 41): 0.36621701294445846
# (32, 42, 41): 0.4165777300882824
#
# Approximating hitting prob for (34, 14, 41)
# (34, 14, 41): 0.291260590793119
# (33, 15, 41): 0.29604564593373434
#
# Approximating hitting prob for (33, 42, 42)
# (33, 42, 42): 0.3699460087792124
# (32, 43, 42): 0.4183765610562744
#
# Approximating hitting prob for (33, 43, 43)
# (33, 43, 43): 0.371366622536719
# (32, 44, 43): 0.42005675310550245
#
# Approximating hitting prob for (34, 22, 43)
# (34, 22, 43): 0.31947690510862775
# (33, 23, 43): 0.32538073292395014
#
# Approximating hitting prob for (34, 43, 44)
# (34, 43, 44): 0.4160781033672973
# (33, 44, 44): 0.37265977777400555
#
# Approximating hitting prob for (34, 43, 60)
# (34, 43, 60): 0.45213311505126613
# (33, 44, 60): 0.4519534472242057
#
# Approximating hitting prob for (34, 9, 44)
# (34, 9, 44): 0.28079524781685766
# (33, 10, 44): 0.2837162176432269
#
# Approximating hitting prob for (33, 45, 45)
# (33, 45, 45): 0.37462300623853967
# (32, 46, 45): 0.4232872967137689
#
# ...
#
# Approximating hitting prob for (37, 30, 31)
# (37, 30, 31): 0.25013260168400125
# (36, 31, 31): 0.21168922586146863
#
# Approximating hitting prob for (37, 30, 62)
# (37, 30, 62): 0.3402279615613253
# (36, 31, 62): 0.32972902149674793
#
# Approximating hitting prob for (37, 30, 63)
# (37, 30, 63): 0.3423934205076092
# (36, 31, 63): 0.3421902259337188
#
# Approximating hitting prob for (37, 30, 93)
# (37, 30, 93): 0.3805010355740082
# (36, 31, 93): 0.37519184506966424
#
# Approximating hitting prob for (36, 32, 32)
# (36, 32, 32): 0.21480519348587843
# (35, 33, 32): 0.26250344121357017
#
# Approximating hitting prob for (36, 32, 64)
# (36, 32, 64): 0.3310296595577675
# (35, 33, 64): 0.3486465282728741
#
# Approximating hitting prob for (36, 32, 65)
# (36, 32, 65): 0.34368932819788034
# (35, 33, 65): 0.3463501369091515
#
# Approximating hitting prob for (36, 32, 96)
# (36, 32, 96): 0.37754528755718225
# (35, 33, 96): 0.38914067756919685
#
# Approximating hitting prob for (36, 33, 33)
# (36, 33, 33): 0.21686811675627718
# (35, 34, 33): 0.26478953207398787
#
# Approximating hitting prob for (36, 33, 66)
# (36, 33, 66): 0.331857301121022
# (35, 34, 66): 0.3565469079759154
#
# Approximating hitting prob for (36, 33, 67)
# (36, 33, 67): 0.34518362312902734
# (35, 34, 67): 0.34940361012451676
#
# Approximating hitting prob for (36, 33, 99)
# (36, 33, 99): 0.3795187996979468
# (35, 34, 99): 0.3907965371259858
#
# Approximating hitting prob for (37, 17, 33)
# (37, 17, 33): 0.21623590095886192
# (36, 18, 33): 0.23224267827047507
#
# Approximating hitting prob for (37, 33, 34)
# (37, 33, 34): 0.2604595555166543
# (36, 34, 34): 0.21927987391303042
#
# Approximating hitting prob for (37, 33, 68)
# (37, 33, 68): 0.3464774189693898
# (36, 34, 68): 0.33259998561769083
#
# Approximating hitting prob for (37, 34, 35)
# (37, 34, 35): 0.26277473632192766
# (36, 35, 35): 0.22107022763446207
#
# Approximating hitting prob for (37, 34, 70)
# (37, 34, 70): 0.34799214427540887
# (36, 35, 70): 0.33310267842700503
#
# Approximating hitting prob for (37, 19, 37)
# (37, 19, 37): 0.29573974616163506
# (36, 20, 37): 0.30187238669825195
#
# Approximating hitting prob for (37, 37, 38)
# (37, 37, 38): 0.38944225375829805
# (36, 38, 38): 0.357081224342597
#
# Approximating hitting prob for (37, 13, 38)
# (37, 13, 38): 0.2788815132624549
# (36, 14, 38): 0.2830795754869917
#
# Approximating hitting prob for (37, 38, 39)
# (37, 38, 39): 0.4013630077821895
# (36, 39, 39): 0.35819501228612277
#
# Approximating hitting prob for (36, 40, 40)
# (36, 40, 40): 0.35936162658100074
# (35, 41, 40): 0.4074429409109921
#
# Approximating hitting prob for (36, 41, 41)
# (36, 41, 41): 0.36100881822537284
# (35, 42, 41): 0.40939285306209255
#
# Approximating hitting prob for (37, 14, 41)
# (37, 14, 41): 0.28423750131026854
# (36, 15, 41): 0.28809225959425894
#
# Approximating hitting prob for (36, 42, 42)
# (36, 42, 42): 0.3626759287590275
# (35, 43, 42): 0.4108613136454511
#
# Approximating hitting prob for (36, 43, 43)
# (36, 43, 43): 0.3640313485020596
# (35, 44, 43): 0.41274963536591197
#
# Approximating hitting prob for (37, 11, 43)
# (37, 11, 43): 0.2653831923075765
# (36, 12, 43): 0.28055688901760895
#
# Approximating hitting prob for (36, 44, 44)
# (36, 44, 44): 0.36574702933319064
# (35, 45, 44): 0.4154991582106046
#
# Approximating hitting prob for (37, 15, 44)
# (37, 15, 44): 0.29121346643802504
# (36, 16, 44): 0.29409437342387607
#
# Approximating hitting prob for (37, 44, 45)
# (37, 44, 45): 0.41014549062348465
# (36, 45, 45): 0.3679559744936582
#
# Approximating hitting prob for (36, 46, 46)
# (36, 46, 46): 0.37011104261802935
# (35, 47, 46): 0.4183370692032136
#
# Approximating hitting prob for (36, 47, 47)
# (36, 47, 47): 0.37139949541556505
# (35, 48, 47): 0.41996620074410057
#
# Approximating hitting prob for (37, 16, 47)
# (37, 16, 47): 0.29552137724997185
# (36, 17, 47): 0.2990665834530948
#
# Approximating hitting prob for (36, 48, 48)
# (36, 48, 48): 0.37265977777400555
# (35, 49, 48): 0.4217444781098323
#
# Approximating hitting prob for (36, 49, 49)
# (36, 49, 49): 0.3745564473811194
# (35, 50, 49): 0.4229432287185812
#
# Approximating hitting prob for (37, 25, 49)
# (37, 25, 49): 0.3240593491950408
# (36, 26, 49): 0.3266448701274922
#
# Approximating hitting prob for (37, 49, 50)
# (37, 49, 50): 0.41916128211346537
# (36, 50, 50): 0.3754499342798961
#
# Approximating hitting prob for (36, 51, 51)
# (36, 51, 51): 0.37682525554075913
# (35, 52, 51): 0.4244583877512517
#
# Approximating hitting prob for (37, 26, 51)
# (37, 26, 51): 0.32611894442168066
# (36, 27, 51): 0.33140914134985283
#
# Approximating hitting prob for (37, 51, 52)
# (37, 51, 52): 0.4218356003008841
# (36, 52, 52): 0.3775245864012524
#
# Approximating hitting prob for (37, 52, 53)
# (37, 52, 53): 0.42309925126852166
# (36, 53, 53): 0.3780444530891414
#
# Approximating hitting prob for (36, 54, 54)
# (36, 54, 54): 0.38531294066601585
# (35, 55, 54): 0.4449950118102888
#
# Approximating hitting prob for (36, 55, 55)
# (36, 55, 55): 0.3925706342331789
# (35, 56, 55): 0.4455914921661887
#
# Approximating hitting prob for (37, 28, 55)
# (37, 28, 55): 0.3322427820678662
# (36, 29, 55): 0.3366483596829462
#
# Approximating hitting prob for (37, 55, 56)
# (37, 55, 56): 0.4355193868619285
# (36, 56, 56): 0.3930542519375145
#
# Approximating hitting prob for (37, 56, 57)
# (37, 56, 57): 0.4431435228501761
# (36, 57, 57): 0.3936104997905013
#
# Approximating hitting prob for (36, 58, 58)
# (36, 58, 58): 0.3943798198728233
# (35, 59, 58): 0.45036739709796886
#
# Approximating hitting prob for (36, 59, 59)
# (36, 59, 59): 0.3951015521147981
# (35, 60, 59): 0.45298793924617337
#
# Approximating hitting prob for (37, 20, 59)
# (37, 20, 59): 0.3381661561998051
# (36, 21, 59): 0.34072825494742504
#
# Approximating hitting prob for (36, 60, 60)
# (36, 60, 60): 0.39923107976612376
# (35, 61, 60): 0.45354719652283654
#
# Approximating hitting prob for (36, 61, 61)
# (36, 61, 61): 0.4008262564568201
# (35, 62, 61): 0.4550858756491974
#
# Approximating hitting prob for (37, 31, 61)
# (37, 31, 61): 0.3384707589377563
# (36, 32, 61): 0.3448087525114256
#
# Approximating hitting prob for (37, 61, 62)
# (37, 61, 62): 0.44963258268636513
# (36, 62, 62): 0.40145936156658796
#
# Approximating hitting prob for (36, 63, 63)
# (36, 63, 63): 0.4025301176497849
# (35, 64, 63): 0.45668069123178584
#
# Approximating hitting prob for (37, 32, 63)
# (37, 32, 63): 0.3417536425577818
# (36, 33, 63): 0.3474838359053238
#
# Approximating hitting prob for (37, 63, 64)
# (37, 63, 64): 0.45328887256964356
# (36, 64, 64): 0.403703722557115
#
# Approximating hitting prob for (37, 64, 65)
# (37, 64, 65): 0.4542002312641828
# (36, 65, 65): 0.4043657594082431
#
# Approximating hitting prob for (37, 33, 65)
# (37, 33, 65): 0.3433919554371367
# (36, 34, 65): 0.35473640061399525
#
# Approximating hitting prob for (37, 65, 66)
# (37, 65, 66): 0.45567123538372184
# (36, 66, 66): 0.40537758745520946
#
# Approximating hitting prob for (37, 65, 69)
# (37, 65, 69): 0.45835038418408997
# (36, 66, 69): 0.45823056779817345
#
# Approximating hitting prob for (37, 66, 67)
# (37, 66, 67): 0.4561888260966285
# (36, 67, 67): 0.4065640122111412
#
# Approximating hitting prob for (37, 34, 67)
# (37, 34, 67): 0.3447387647327642
# (36, 35, 67): 0.3575982088573193
#
# Approximating hitting prob for (37, 67, 68)
# (37, 67, 68): 0.45714969150151524
# (36, 68, 68): 0.40730915363163184
#
# Approximating hitting prob for (37, 67, 70)
# (37, 67, 70): 0.4588122444449187
# (36, 68, 70): 0.45875901038852246
#
# Approximating hitting prob for (36, 69, 69)
# (36, 69, 69): 0.4079108385741359
# (35, 70, 69): 0.47247130249142133
#
# Approximating hitting prob for (36, 14, 70)
# (36, 14, 70): 0.3227500639412437
# (35, 15, 70): 0.32888601585548977
#
# Approximating hitting prob for (37, 35, 69)
# (37, 35, 69): 0.34642943505150675
# (36, 36, 69): 0.4180632553474679
#
# Approximating hitting prob for (37, 69, 70)
# (37, 69, 70): 0.4592019414850819
# (36, 70, 70): 0.4084602880113615
#
# Approximating hitting prob for (36, 71, 71)
# (36, 71, 71): 0.40890199816827844
# (35, 72, 71): 0.4844644896622032
#
# Approximating hitting prob for (36, 71, 83)
# (36, 71, 83): 0.48288745872634625
# (35, 72, 83): 0.4971754775703398
#
# Approximating hitting prob for (37, 24, 71)
# (37, 24, 71): 0.35420357755319465
# (36, 25, 71): 0.35884932232546896
#
# Approximating hitting prob for (37, 71, 72)
# (37, 71, 72): 0.46042960169450486
# (36, 72, 72): 0.4285714285714286
#
# Approximating hitting prob for (37, 72, 73)
# (37, 72, 73): 0.459184968845074
# (36, 73, 73): 0.4337754470024005
#
# Approximating hitting prob for (37, 73, 74)
# (37, 73, 74): 0.4724637552867444
# (36, 74, 74): 0.43403388113506
#
# Approximating hitting prob for (37, 15, 74)
# (37, 15, 74): 0.3270046414588533
# (36, 16, 74): 0.3318562705212885
#
# Approximating hitting prob for (36, 75, 75)
# (36, 75, 75): 0.4343891715843085
# (35, 76, 75): 0.4877274107133454
#
# Approximating hitting prob for (36, 75, 78)
# (36, 75, 78): 0.4865632070162759
# (35, 76, 78): 0.48940974008835036
#
# Approximating hitting prob for (36, 76, 76)
# (36, 76, 76): 0.4347840793074833
# (35, 77, 76): 0.48874972471060923
#
# Approximating hitting prob for (36, 76, 80)
# (36, 76, 80): 0.48796704596303564
# (35, 77, 80): 0.49142841628658235
#
# Approximating hitting prob for (37, 75, 88)
# (37, 75, 88): 0.5004001491238855
# (36, 76, 88): 0.4996061845812571
#
# Approximating hitting prob for (36, 77, 77)
# (36, 77, 77): 0.4350971822733844
# (35, 78, 77): 0.48957635573854047
#
# Approximating hitting prob for (36, 77, 82)
# (36, 77, 82): 0.4890813512490384
# (35, 78, 82): 0.4934995095956322
#
# Approximating hitting prob for (37, 76, 89)
# (37, 76, 89): 0.5005771678250458
# (36, 77, 89): 0.4999734142454855
#
# Approximating hitting prob for (37, 75, 77)
# (37, 75, 77): 0.4867653846275591
# (36, 76, 77): 0.4872462664436578
#
# Approximating hitting prob for (37, 77, 78)
# (37, 77, 78): 0.48685125066520185
# (36, 78, 78): 0.43555797041404976
#
# Approximating hitting prob for (37, 77, 84)
# (37, 77, 84): 0.4920019669721003
# (36, 78, 84): 0.4917704680209092
#
# Approximating hitting prob for (36, 79, 79)
# (36, 79, 79): 0.43601648359927797
# (35, 80, 79): 0.4912911202774067
#
# Approximating hitting prob for (36, 79, 86)
# (36, 79, 86): 0.49265184710323684
# (35, 80, 86): 0.49741126400234736
#
# Approximating hitting prob for (37, 78, 91)
# (37, 78, 91): 0.5011689327198297
# (36, 79, 91): 0.5011146811052932
#
# Approximating hitting prob for (37, 16, 79)
# (37, 16, 79): 0.3308227096134477
# (36, 17, 79): 0.33637545263674173
#
# Approximating hitting prob for (37, 79, 80)
# (37, 79, 80): 0.487576133691441
# (36, 80, 80): 0.4369882221866643
#
# Approximating hitting prob for (37, 27, 80)
# (37, 27, 80): 0.36324260614762327
# (36, 28, 80): 0.37210767770812625
#
# Approximating hitting prob for (37, 80, 81)
# (37, 80, 81): 0.4882722715044468
# (36, 81, 81): 0.4381003152708904
#
# Approximating hitting prob for (37, 80, 90)
# (37, 80, 90): 0.49757428344957777
# (36, 81, 90): 0.49704459867179973
#
# Approximating hitting prob for (37, 81, 82)
# (37, 81, 82): 0.4891077276648374
# (36, 82, 82): 0.4387557103248005
#
# Approximating hitting prob for (37, 81, 92)
# (37, 81, 92): 0.49885110794074433
# (36, 82, 92): 0.4982575752661343
#
# Approximating hitting prob for (37, 82, 83)
# (37, 82, 83): 0.48978050231352194
# (36, 83, 83): 0.4393501129113575
#
# Approximating hitting prob for (37, 82, 94)
# (37, 82, 94): 0.4997878988959468
# (36, 83, 94): 0.4990435811474813
#
# Approximating hitting prob for (37, 28, 83)
# (37, 28, 83): 0.371410366757807
# (36, 29, 83): 0.37759274523937286
#
# Approximating hitting prob for (37, 83, 84)
# (37, 83, 84): 0.4910307837337711
# (36, 84, 84): 0.4403379450546962
# Approximating hitting prob for (37, 83, 96)
# (37, 83, 96): 0.5035926186038958
# (36, 84, 96): 0.5016113933275627
#
# Approximating hitting prob for (36, 85, 85)
# (36, 85, 85): 0.44076378047404635
# (35, 86, 85): 0.4942664772143388
#
# Approximating hitting prob for (36, 85, 98)
# (36, 85, 98): 0.5038573142357783
# (35, 86, 98): 0.5068825589501879
#
# Approximating hitting prob for (36, 86, 86)
# (36, 86, 86): 0.44108195378932197
# (35, 87, 86): 0.49497451208162785
#
# Approximating hitting prob for (36, 86, 100)
# (36, 86, 100): 0.5046400529471237
# (35, 87, 100): 0.5075777767706378
#
# Approximating hitting prob for (37, 29, 86)
# (37, 29, 86): 0.37719768561219724
# (36, 30, 86): 0.37934390131810575
#
# Approximating hitting prob for (37, 86, 87)
# (37, 86, 87): 0.4928115715149324
# (36, 87, 87): 0.4414166400543895
#
# Approximating hitting prob for (36, 88, 88)
# (36, 88, 88): 0.4417066621328852
# (35, 89, 88): 0.49695011551058865
#
# Approximating hitting prob for (36, 89, 89)
# (36, 89, 89): 0.44188392000100735
# (35, 90, 89): 0.4979177660004799
#
# Approximating hitting prob for (37, 30, 89)
# (37, 30, 89): 0.37867283585849104
# (36, 31, 89): 0.3817792422645557
#
# Approximating hitting prob for (37, 89, 90)
# (37, 89, 90): 0.49422871862832934
# (36, 90, 90): 0.44255325660645745
#
# Approximating hitting prob for (37, 90, 91)
# (37, 90, 91): 0.4942813048693693
# (36, 91, 91): 0.4450091294263209
#
# Approximating hitting prob for (37, 91, 92)
# (37, 91, 92): 0.4949659385411243
# (36, 92, 92): 0.44526863068094785
#
# Approximating hitting prob for (36, 93, 93)
# (36, 93, 93): 0.44572076580876246
# (35, 94, 93): 0.49974446880310675
#
# Approximating hitting prob for (36, 93, 100)
# (36, 93, 100): 0.5020590542608456
# (35, 94, 100): 0.5047936880021118
#
# Approximating hitting prob for (37, 83, 93)
# (37, 83, 93): 0.4992391582547578
# (36, 84, 93): 0.5004609999145261
#
# Approximating hitting prob for (37, 93, 94)
# (37, 93, 94): 0.49692767990092146
# (36, 94, 94): 0.44601893730437053
#
# Approximating hitting prob for (37, 94, 95)
# (37, 94, 95): 0.49783316047498927
# (36, 95, 95): 0.44643593140270593
#
# Approximating hitting prob for (36, 96, 96)
# (36, 96, 96): 0.44694562306725144
# (35, 97, 96): 0.5013899990549571
#
# Approximating hitting prob for (36, 97, 97)
# (36, 97, 97): 0.44727585249094987
# (35, 98, 97): 0.5020115383739711
#
# Approximating hitting prob for (36, 98, 98)
# (36, 98, 98): 0.4475590139953938
# (35, 99, 98): 0.5024308104975552
#
# Approximating hitting prob for (37, 33, 98)
# (37, 33, 98): 0.38611232657776434
# (36, 34, 98): 0.3888538076249355
#
# Approximating hitting prob for (37, 98, 99)
# (37, 98, 99): 0.4996632074126006
# (36, 99, 99): 0.44820689847484574
#
# Approximating hitting prob for (37, 99, 100)
# (37, 99, 100): 0.5000491478241897
# (36, 100, 100): 0.4489026356332815
#
# Approximating hitting prob for (38, 3, 4)
# (38, 3, 4): 0.011914522349217577
# (37, 4, 4): 0.011555275635296151
#
# Approximating hitting prob for (38, 3, 8)
# (38, 3, 8): 0.026797401091200133
# (37, 4, 8): 0.026395544524114422
#
# Approximating hitting prob for (38, 4, 5)
# (38, 4, 5): 0.019012758510749104
# (37, 5, 5): 0.01872148390003157
#
# Approximating hitting prob for (38, 5, 6)
# (38, 5, 6): 0.027143286451338927
# (37, 6, 6): 0.02512359265358942
#
# Approximating hitting prob for (38, 5, 18)
# (38, 5, 18): 0.08615012963985869
# (37, 6, 18): 0.08533473235776527
#
# Approximating hitting prob for (38, 6, 7)
# (38, 6, 7): 0.03725768825239587
# (37, 7, 7): 0.033343704960000185
#
# Approximating hitting prob for (38, 6, 14)
# (38, 6, 14): 0.07614839807613859
# (37, 7, 14): 0.0750024331409937
#
# Approximating hitting prob for (37, 8, 8)
# (37, 8, 8): 0.038186135730330965
# (36, 9, 8): 0.05537824083377113
#
# Approximating hitting prob for (37, 9, 9)
# (37, 9, 9): 0.04184324564063621
# (36, 10, 9): 0.07408491438112584
#
# Approximating hitting prob for (37, 9, 18)
# (37, 9, 18): 0.10180151558908139
# (36, 10, 18): 0.11712105259638744
#
# Approximating hitting prob for (37, 9, 27)
# (37, 9, 27): 0.12783278845918364
# (36, 10, 27): 0.1745957536475864
#
# Approximating hitting prob for (37, 10, 10)
# (37, 10, 10): 0.060380208013818465
# (36, 11, 10): 0.079751820086438
#
# Approximating hitting prob for (37, 10, 20)
# (37, 10, 20): 0.10984510874908134
# (36, 11, 20): 0.12631464542562826
#
# Approximating hitting prob for (37, 11, 11)
# (37, 11, 11): 0.06480918054717485
# (36, 12, 11): 0.09654659097378747
#
# Approximating hitting prob for (37, 11, 22)
# (37, 11, 22): 0.11952057160484054
# (36, 12, 22): 0.14332958850569136
#
# Approximating hitting prob for (37, 11, 33)
# (37, 11, 33): 0.1849317375886533
# (36, 12, 33): 0.20876780020923028
#
# Approximating hitting prob for (37, 11, 44)
# (37, 11, 44): 0.26377188155166525
# (36, 12, 44): 0.2810952708116327
#
# Approximating hitting prob for (37, 12, 12)
# (37, 12, 12): 0.0708342846388144
# (36, 13, 12): 0.11422281571920345
#
# Approximating hitting prob for (37, 12, 24)
# (37, 12, 24): 0.12589337304212878
# (36, 13, 24): 0.18259784634774734
