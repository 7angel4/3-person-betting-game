# %%
# %run 'game1_global.ipynb'
# %run 'game1_loser_analysis.ipynb'

# %% [markdown]
# # When is player 1 better off giving away $1?

# %%
betterGiving1 = findBetterGiving1(1,1000)
betterGiving1

# %%
exportStateProbs(DATA_DIR + 'game1_better_giving_1_memo_1-1000.csv', betterGiving1)

# %%
# retrieve probabilities from file
betterGiving1, given1 = readApproxBetterGiving1Probs(DATA_DIR + 'game1_better_giving_1_memo_1-100.csv')

# %%
betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
                                       filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv')
# Out:
# Approximating hitting prob for (11, 19, 48)
# (11, 19, 48): 0.5334260883826906
# (10, 19, 48): 0.5333426632228018
#
# Approximating hitting prob for (12, 21, 53)
# (12, 21, 53): 0.5340626283748265
# (11, 21, 53): 0.5334548685835285
#
# Approximating hitting prob for (12, 32, 42)
# (12, 32, 42): 0.5301153617677242
# (11, 32, 42): 0.5299467192997049
#
# Approximating hitting prob for (13, 22, 56)
# (13, 22, 56): 0.5328628830327213
# (12, 22, 56): 0.532734806781722
#
# Approximating hitting prob for (13, 23, 58)
# (13, 23, 58): 0.5343093271797525
# (12, 23, 58): 0.5335330764863161
#
# Approximating hitting prob for (13, 35, 46)
# (13, 35, 46): 0.5303291922468697
# (12, 35, 46): 0.5299937351500015
#
# Approximating hitting prob for (14, 24, 61)
# (14, 24, 61): 0.5334281050874531
# (13, 24, 61): 0.532844623278078
#
# Approximating hitting prob for (14, 25, 63)
# (14, 25, 63): 0.534598505539718
# (13, 25, 63): 0.5335740856592848
#
# Approximating hitting prob for (14, 38, 50)
# (14, 38, 50): 0.5306453312687435
# (13, 38, 50): 0.5300535494230575
#
# Approximating hitting prob for (15, 26, 66)
# (15, 26, 66): 0.5335384252806683
# (14, 26, 66): 0.532976559038264
#
# Approximating hitting prob for (15, 27, 68)
# (15, 27, 68): 0.5347937376379311
# (14, 27, 68): 0.5336038259570041
#
# Approximating hitting prob for (15, 40, 52)
# (15, 40, 52): 0.5298390830172897
# (14, 40, 52): 0.5294060634902246
#
# Approximating hitting prob for (15, 41, 54)
# (15, 41, 54): 0.530814252978444
# (14, 41, 54): 0.5300859465232839
#
# Approximating hitting prob for (16, 27, 69)
# (16, 27, 69): 0.5327214805171471
# (15, 27, 69): 0.5323471322790065
#
# Approximating hitting prob for (16, 28, 71)
# (16, 28, 71): 0.533984832978568
# (15, 28, 71): 0.5330636314503749
#
# Approximating hitting prob for (16, 29, 73)
# (16, 29, 73): 0.5349109988994238
# (15, 29, 73): 0.5336260136575318
#
# Approximating hitting prob for (16, 42, 54)
# (16, 42, 54): 0.528455476635441
# (15, 42, 54): 0.5285157285081951
#
# Approximating hitting prob for (16, 43, 56)
# (16, 43, 56): 0.5300165256608894
# (15, 43, 56): 0.5295344851774494
#
# Approximating hitting prob for (16, 44, 58)
# (16, 44, 58): 0.5309755142180325
# (15, 44, 58): 0.5301059314171186
#
# Approximating hitting prob for (17, 29, 74)
# (17, 29, 74): 0.5332717628242919
# (16, 29, 74): 0.5324865172144486
#
# Approximating hitting prob for (17, 30, 76)
# (17, 30, 76): 0.5341834675713876
# (16, 30, 76): 0.5331293350131605
#
# Approximating hitting prob for (17, 31, 78)
# (17, 31, 78): 0.535032026741298
# (16, 31, 78): 0.5336384909534596
#
# Approximating hitting prob for (17, 44, 56)
# (17, 44, 56): 0.5279972266134371
# (16, 44, 56): 0.5279422800090446
#
# Approximating hitting prob for (17, 45, 58)
# (17, 45, 58): 0.529004914693246
# (16, 45, 58): 0.528895160602941
#
# Approximating hitting prob for (17, 46, 60)
# (17, 46, 60): 0.5301804342251579
# (16, 46, 60): 0.5296194711867167
#
# Approximating hitting prob for (17, 47, 62)
# (17, 47, 62): 0.5311378673662993
# (16, 47, 62): 0.5301263625686753
#
# Approximating hitting prob for (18, 27, 71)
# (18, 27, 71): 0.525620501017532
# (17, 27, 71): 0.5254981980685945
#
# Approximating hitting prob for (18, 28, 73)
# (18, 28, 73): 0.5271004988262395
# (17, 28, 73): 0.5270411065910542
#
# Approximating hitting prob for (18, 31, 79)
# (18, 31, 79): 0.5335270635741508
# (17, 31, 79): 0.5326072076759126
#
# Approximating hitting prob for (18, 32, 81)
# (18, 32, 81): 0.5344121912790228
# (17, 32, 81): 0.5332080138741222
#
# Approximating hitting prob for (18, 33, 83)
# (18, 33, 83): 0.5351589143653502
# (17, 33, 83): 0.5336649245359243
#
# Approximating hitting prob for (18, 45, 56)
# (18, 45, 56): 0.5255722330999105
# (17, 45, 56): 0.5254786841463105
#
# Approximating hitting prob for (18, 47, 60)
# (18, 47, 60): 0.5284828625145415
# (17, 47, 60): 0.5281888889502253
#
# Approximating hitting prob for (18, 48, 62)
# (18, 48, 62): 0.5294526933438758
# (17, 48, 62): 0.5290045013080626
#
# Approximating hitting prob for (18, 49, 64)
# (18, 49, 64): 0.5304295920255223
# (17, 49, 64): 0.5297020995866109
#
# Approximating hitting prob for (18, 50, 66)
# (18, 50, 66): 0.5312826982045813
# (17, 50, 66): 0.5301457096165415
#
# Approximating hitting prob for (19, 20, 58)
# (19, 20, 58): 0.5076781471384154
# (18, 20, 58): 0.507459734940809
#
# Approximating hitting prob for (19, 32, 82)
# (19, 32, 82): 0.5327246501234508
# (18, 32, 82): 0.5320769507714677
#
# Approximating hitting prob for (19, 33, 84)
# (19, 33, 84): 0.5335489429772609
# (18, 33, 84): 0.532734806781722
#
# Approximating hitting prob for (19, 34, 86)
# (19, 34, 86): 0.5345634156030413
# (18, 34, 86): 0.5332648124986303
#
# Approximating hitting prob for (19, 35, 88)
# (19, 35, 88): 0.5345634156030413
# (18, 35, 88): 0.5332648124986303
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/659592125.py:18, in stricterFilter(candidates, timeLim, t, printOnGo, filename, continueFrom)
#      17 try:
# ---> 18     pLarge = LoserAnalysis(sLarge).getHittingProb()  # exact probs
#      19     pSmall = LoserAnalysis(sSmall).getHittingProb()
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:68, in LoserAnalysis.getHittingProb(self, asFloat, approx, t)
#      66     return Q(x, y, z, t)
# ---> 68 sol = self.solveEqns()
#      69 if sol:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:46, in LoserAnalysis.solveEqns(self, asFloat)
#      45 self.getEquations()
# ---> 46 sol = solve(self.equations, self.symbols)
#      47 return {s:float(p) for s, p in sol.items() if sol} if asFloat else sol
#
# File /usr/local/lib/python3.9/site-packages/sympy/solvers/solvers.py:1147, in solve(f, *symbols, **flags)
#    1146 else:
# -> 1147     linear, solution = _solve_system(f, symbols, **flags)
#    1148 assert type(solution) is list
#
# File /usr/local/lib/python3.9/site-packages/sympy/solvers/solvers.py:1799, in _solve_system(exprs, symbols, **flags)
#    1797     continue
# -> 1799 poly = g.as_poly(*symbols, extension=True)
#    1801 if poly is not None:
#
# File /usr/local/lib/python3.9/site-packages/sympy/core/expr.py:1102, in Expr.as_poly(self, *gens, **args)
#    1101 try:
# -> 1102     poly = Poly(self, *gens, **args)
#    1104     if not poly.is_Poly:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:182, in Poly.__new__(cls, rep, *gens, **args)
#     181 else:
# --> 182     return cls._from_expr(rep, opt)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:312, in Poly._from_expr(cls, rep, opt)
#     311 rep, opt = _dict_from_expr(rep, opt)
# --> 312 return cls._from_dict(rep, opt)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:261, in Poly._from_dict(cls, rep, opt)
#     259         rep[monom] = domain.convert(coeff)
# --> 261 return cls.new(DMP.from_dict(rep, level, domain), *gens)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polyclasses.py:279, in DMP.from_dict(cls, rep, lev, dom)
#     278 """Construct and instance of ``cls`` from a ``dict`` representation. """
# --> 279 return cls(dmp_from_dict(rep, lev, dom), dom, lev)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
#     [... skipping similar frames: dmp_from_dict at line 1012 (2958 times)]
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:998, in dmp_from_dict(f, u, K)
#     996 coeffs = {}
# --> 998 for monom, coeff in f.items():
#     999     head, tail = monom[0], monom[1:]
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# TimeoutException                          Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
#       2                                        filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv')
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/659592125.py:23, in stricterFilter(candidates, timeLim, t, printOnGo, filename, continueFrom)
#      21 except (TimeoutException, RecursionError):
#      22     print(f'Approximating hitting prob for {sLarge}')
# ---> 23     pLarge = LoserAnalysis(sLarge).getHittingProb(approx=True, t=t)
#      24     pSmall = LoserAnalysis(sSmall).getHittingProb(approx=True, t=t)
#      26 finally:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:66, in LoserAnalysis.getHittingProb(self, asFloat, approx, t)
#      64 if approx:
#      65     x, y, z = self.initState
# ---> 66     return Q(x, y, z, t)
#      68 sol = self.solveEqns()
#      69 if sol:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:31, in Q(x, y, z, t)
#      29 if x==0: return 1
#      30 if z*y==0: return 0
# ---> 31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
#      33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:31, in Q(x, y, z, t)
#      29 if x==0: return 1
#      30 if z*y==0: return 0
# ---> 31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
#      33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
#     [... skipping similar frames: memoize.<locals>.memodict.__call__ at line 8 (11 times), <genexpr> at line 33 (10 times), Q at line 33 (10 times), memoize.<locals>.memodict.__missing__ at line 11 (10 times)]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2027475117.py:12, in sigalarmHandler(signum, frame)
#       8 """
#       9 Handler function to be called when SIGALRM is received.
#      10 """
#      11 # We get signal!
# ---> 12 raise TimeoutException()
#
# TimeoutException:

# %%
betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
                                       filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv',
                                       continueFrom=(69,64,100))
# Out:
# Approximating hitting prob for (70, 12, 93)
# (70, 12, 93): 0.27064890356707977
# (69, 12, 93): 0.2704508979612977
#
# Approximating hitting prob for (70, 13, 95)
# (70, 13, 95): 0.273002814385276
# (69, 13, 95): 0.2728333555110289
#
# Approximating hitting prob for (70, 15, 99)
# (70, 15, 99): 0.2777183843625525
# (69, 15, 99): 0.27732957441332723
#
# Approximating hitting prob for (70, 30, 84)
# (70, 30, 84): 0.2928672871530125
# (69, 30, 84): 0.29290071879804375
#
# Approximating hitting prob for (70, 50, 94)
# (70, 50, 94): 0.32695735265836573
# (69, 50, 94): 0.3267132634013896
#
# Approximating hitting prob for (70, 58, 98)
# (70, 58, 98): 0.3430616778838396
# (69, 58, 98): 0.3428394039934912
#
# Approximating hitting prob for (70, 60, 99)
# (70, 60, 99): 0.34560612414415176
# (69, 60, 99): 0.34492499438010804
#
# Approximating hitting prob for (70, 84, 90)
# (70, 84, 90): 0.4148018936715927
# (69, 84, 90): 0.41468720846314083
#
# Approximating hitting prob for (71, 12, 94)
# (71, 12, 94): 0.27043453644878807
# (70, 12, 94): 0.2702550831661171
#
# Approximating hitting prob for (71, 15, 100)
# (71, 15, 100): 0.2774240055525448
# (70, 15, 100): 0.27714908068396565
#
# Approximating hitting prob for (71, 36, 88)
# (71, 36, 88): 0.3107284046458855
# (70, 36, 88): 0.3107029569244443
#
# Approximating hitting prob for (71, 44, 92)
# (71, 44, 92): 0.31946810865446534
# (70, 44, 92): 0.31933447137280896
#
# Approximating hitting prob for (71, 52, 96)
# (71, 52, 96): 0.3287350571698488
# (70, 52, 96): 0.32848900976647166
#
# Approximating hitting prob for (71, 60, 100)
# (71, 60, 100): 0.3432269284144038
# (70, 60, 100): 0.3428263666917539
#
# Approximating hitting prob for (72, 14, 99)
# (72, 14, 99): 0.27369224353294386
# (71, 14, 99): 0.27347335165357634
#
# Approximating hitting prob for (72, 40, 91)
# (72, 40, 91): 0.3129742549703007
# (71, 40, 91): 0.31282979281170153
#
# Approximating hitting prob for (72, 46, 94)
# (72, 46, 94): 0.32065055730266634
# (71, 46, 94): 0.32060860453920875
#
# Approximating hitting prob for (72, 50, 96)
# (72, 50, 96): 0.32548552599084296
# (71, 50, 96): 0.32522123422559995
#
# Approximating hitting prob for (72, 54, 98)
# (72, 54, 98): 0.33015250293768666
# (71, 54, 98): 0.3299310590778092
#
# Approximating hitting prob for (73, 11, 94)
# (73, 11, 94): 0.26568088778907833
# (72, 11, 94): 0.26555372470314254
#
# Approximating hitting prob for (73, 13, 98)
# (73, 13, 98): 0.2712824779940791
# (72, 13, 98): 0.27092732614422377
#
# Approximating hitting prob for (73, 14, 100)
# (73, 14, 100): 0.2735392177539206
# (72, 14, 100): 0.2733296833190661
#
# Approximating hitting prob for (73, 26, 85)
# (73, 26, 85): 0.2838182327188731
# (72, 26, 85): 0.2838382526274032
#
# Approximating hitting prob for (73, 40, 92)
# (73, 40, 92): 0.31265646156970867
# (72, 40, 92): 0.31256600858492634
#
# Approximating hitting prob for (73, 44, 94)
# (73, 44, 94): 0.31905281367702304
# (72, 44, 94): 0.31898130581150774
#
# Approximating hitting prob for (74, 12, 97)
# (74, 12, 97): 0.26803823241416097
# (73, 12, 97): 0.2678146488650772
#
# Approximating hitting prob for (74, 13, 99)
# (74, 13, 99): 0.27106341315623816
# (73, 13, 99): 0.2708043750088058
#
# Approximating hitting prob for (74, 30, 88)
# (74, 30, 88): 0.29121346643802504
# (73, 30, 88): 0.2911904861374854
#
# Approximating hitting prob for (74, 40, 93)
# (74, 40, 93): 0.3124715276947375
# (73, 40, 93): 0.3123265733297223
#
# Approximating hitting prob for (74, 46, 96)
# (74, 46, 96): 0.3194592906289733
# (73, 46, 96): 0.31936096416339166
#
# Approximating hitting prob for (74, 52, 99)
# (74, 52, 99): 0.32609715069378836
# (73, 52, 99): 0.32593271890358366
#
# Approximating hitting prob for (74, 54, 100)
# (74, 54, 100): 0.3285392810102394
# (73, 54, 100): 0.32834877261967127
#
# Approximating hitting prob for (75, 13, 100)
# (75, 13, 100): 0.2708561821230972
# (74, 13, 100): 0.27060467983388525
#
# Approximating hitting prob for (75, 38, 93)
# (75, 38, 93): 0.3107255922584125
# (74, 38, 93): 0.3106856959891582
#
# Approximating hitting prob for (75, 40, 94)
# (75, 40, 94): 0.31219750777533284
# (74, 40, 94): 0.31212211416489793
#
# Approximating hitting prob for (75, 48, 98)
# (75, 48, 98): 0.3206660566987458
# (74, 48, 98): 0.3206193374288369
#
# Approximating hitting prob for (75, 52, 100)
# (75, 52, 100): 0.32543894655115896
# (74, 52, 100): 0.3251891291627604
#
# Approximating hitting prob for (76, 42, 96)
# (76, 42, 96): 0.31283229353690856
# (75, 42, 96): 0.31269685409230785
#
# Approximating hitting prob for (77, 42, 97)
# (77, 42, 97): 0.31263411481005815
# (76, 42, 97): 0.3124896740010894
#
# Approximating hitting prob for (78, 42, 98)
# (78, 42, 98): 0.312441399741017
# (77, 42, 98): 0.3119828040723916
#
# Approximating hitting prob for (79, 32, 94)
# (79, 32, 94): 0.2912337154122105
# (78, 32, 94): 0.2911642829888588
#
# Approximating hitting prob for (79, 40, 98)
# (79, 40, 98): 0.31073467566545016
# (78, 40, 98): 0.31068391480047436
#
# Approximating hitting prob for (79, 42, 99)
# (79, 42, 99): 0.3121670959474713
# (78, 42, 99): 0.3120607193357822
#
# Approximating hitting prob for (79, 44, 100)
# (79, 44, 100): 0.3130463381703828
# (78, 44, 100): 0.3128490513416133
#
# Approximating hitting prob for (82, 34, 98)
# (82, 34, 98): 0.2917812876569657
# (81, 34, 98): 0.29172992113254753
#
# Approximating hitting prob for (84, 30, 98)
# (84, 30, 98): 0.2839368557613289
# (83, 30, 98): 0.2838357734914572
#
# Approximating hitting prob for (84, 34, 100)
# (84, 34, 100): 0.29123192191006453
# (83, 34, 100): 0.2911447291167216
#
# Approximating hitting prob for (93, 47, 62)
# (93, 47, 62): 0.2078449082948937
# (92, 47, 62): 0.20783817692579917
#
# Approximating hitting prob for (93, 47, 98)
# (93, 47, 98): 0.3020413154785515
# (92, 47, 98): 0.3020379983481061
#
# Approximating hitting prob for (95, 48, 100)
# (95, 48, 100): 0.30201302025080573
# (94, 48, 100): 0.30196433138324996
#
# Approximating hitting prob for (99, 50, 66)
# (99, 50, 66): 0.2078419114332157
# (98, 50, 66): 0.2078180397808808
#
# Approximating hitting prob for (100, 51, 67)
# (100, 51, 67): 0.2080190772886974
# (99, 51, 67): 0.20801576587712575

# %%
class TimeoutException(Exception):
    """
    Custom exception for timeout.
    """
    pass

def sigalarmHandler(signum, frame):
    """
    Handler function to be called when SIGALRM is received.
    """
    # We get signal!
    raise TimeoutException()

# %% [markdown]
# ## When is player 1 better off giving away $1 to another player?

# %%
betterGiving1ToAnother = findBetterGiving1(1,100, t=10, giveToAnother=True)
betterGiving1ToAnother
# Out:
# {(1, 5, 5): 0.5004434876119833,
#  (2, 4, 5): 0.5015168645690443,
#  (1, 6, 6): 0.506093654740131,
#  (2, 5, 6): 0.5184847144955884,
#  (1, 7, 7): 0.5131205254322682,
#  (2, 6, 7): 0.5396071019936831,
#  (1, 8, 8): 0.5177187986883774,
#  (2, 7, 8): 0.553386673567715,
#  (1, 9, 9): 0.5198030383135193,
#  (2, 8, 9): 0.5596511014686955,
#  (1, 10, 10): 0.521353326527545,
#  (2, 9, 10): 0.5643071756348541,
#  (1, 11, 11): 0.5225738105217701,
#  (2, 10, 11): 0.5679767313216567,
#  (1, 12, 12): 0.5237380978085997,
#  (2, 11, 12): 0.5714793837797846,
#  (1, 12, 36): 0.6316713165390184,
#  (2, 11, 36): 0.6317622599451304,
#  (1, 13, 13): 0.5248276325593998,
#  (2, 12, 13): 0.5747622273980084,
#  (1, 13, 39): 0.6325682808186844,
#  (2, 12, 39): 0.6347403712118326,
#  (1, 14, 14): 0.5256858644409728,
#  (2, 13, 14): 0.57733900685236,
#  (1, 14, 42): 0.6333982655030145,
#  (2, 13, 42): 0.6366529115385103,
#  (1, 15, 15): 0.5268432387720368,
#  (2, 14, 15): 0.5808387485922709,
#  (1, 15, 45): 0.63421194355006,
#  (2, 14, 45): 0.6395029512036614,
#  (1, 16, 16): 0.5279858610539553,
#  (2, 15, 16): 0.5842379051719758,
#  (1, 16, 48): 0.635051999980948,
#  (2, 15, 48): 0.6419747628823096,
#  (1, 17, 17): 0.5283821156475977,
#  (2, 16, 17): 0.5854285708426477,
#  (1, 17, 51): 0.6353974162348219,
#  (2, 16, 51): 0.6431331129655032,
#  (1, 18, 18): 0.5286972339709394,
#  (2, 17, 18): 0.586367542078401,
#  (1, 18, 54): 0.635696343688081,
#  (2, 17, 54): 0.6438519942124338,
#  (1, 19, 19): 0.5290239620908059,
#  (2, 18, 19): 0.5873462049262054,
#  (1, 19, 57): 0.6359734242165406,
#  (2, 18, 57): 0.644798126476528,
#  (1, 20, 20): 0.5292680655049197,
#  (2, 19, 20): 0.5880847500592729,
#  (1, 20, 60): 0.6362249863460855,
#  (2, 19, 60): 0.6453717860378668,
#  (1, 21, 21): 0.5295149142555335,
#  (2, 20, 21): 0.588833317324383,
#  (1, 21, 63): 0.6364634998581686,
#  (2, 20, 63): 0.6461849514015902,
#  (1, 21, 64): 0.646956969794154,
#  (2, 20, 64): 0.6472510681012803,
#  (1, 22, 22): 0.5297588522879303,
#  (2, 21, 22): 0.5895697621096462,
#  (1, 22, 66): 0.6366529446148538,
#  (2, 21, 66): 0.6466174245912294,
#  (1, 22, 67): 0.6471532117394029,
#  (2, 21, 67): 0.647774501235203,
#  (1, 23, 23): 0.5299781484445122,
#  (2, 22, 23): 0.5902254013880421,
#  (1, 23, 69): 0.6368433485854967,
#  (2, 22, 69): 0.6472793649130383,
#  (1, 23, 70): 0.647343764553591,
#  (2, 22, 70): 0.6483569921802232,
#  (1, 24, 24): 0.5301334749530051,
#  (2, 23, 24): 0.5907054714357991,
#  (1, 24, 72): 0.6370145682769819,
#  (2, 23, 72): 0.6476786129157565,
#  (1, 24, 73): 0.6475028948415723,
#  (2, 23, 73): 0.6487869019532507,
#  (1, 25, 25): 0.5303300145853443,
#  (2, 24, 25): 0.5913062701368778,
#  (1, 25, 75): 0.6371719124424207,
#  (2, 24, 75): 0.6482151442816559,
#  (1, 25, 76): 0.6476655808364664,
#  (2, 24, 76): 0.6492909523499552,
#  (1, 26, 26): 0.5305056830450136,
#  (2, 25, 26): 0.5918398411700453,
#  (1, 26, 78): 0.6373261970460974,
#  (2, 25, 78): 0.6485752629701603,
#  (1, 26, 79): 0.6478181289321158,
#  (2, 25, 79): 0.6496998090304239,
#  (1, 27, 27): 0.5306651440964284,
#  (2, 26, 27): 0.5923164712780911,
#  (1, 27, 81): 0.6374779182331624,
#  (2, 26, 81): 0.6491023179636827,
#  (1, 27, 82): 0.6479675843896594,
#  (2, 26, 82): 0.6501630597575742,
#  (1, 28, 28): 0.5308433925108808,
#  (2, 27, 28): 0.5928632397722654,
#  (1, 28, 84): 0.6376227926171485,
#  (2, 27, 84): 0.6494288807018324,
#  (1, 28, 85): 0.6481137818273807,
#  (2, 27, 85): 0.6505545513577707,
#  (1, 29, 29): 0.531019424810327,
#  (2, 28, 29): 0.593397753481219,
#  (1, 29, 87): 0.6377697342725956,
#  (2, 28, 87): 0.6499273246583346,
#  (1, 29, 88): 0.6482600123414454,
#  (2, 28, 88): 0.651006837277092,
#  (1, 30, 30): 0.5311653907136445,
#  (2, 29, 30): 0.5938409764824553,
#  (1, 30, 90): 0.6379076957008163,
#  (2, 29, 90): 0.650248810177776,
#  (1, 30, 91): 0.6483932438525631,
#  (2, 29, 91): 0.6513514100842097,
#  (1, 31, 31): 0.5313585565589595,
#  (2, 30, 31): 0.5944358379798981,
#  (1, 31, 93): 0.6380471455644888,
#  (2, 30, 93): 0.6507426069080341,
#  (1, 31, 94): 0.6485374236333384,
#  (2, 30, 94): 0.6518048371373775,
#  (1, 32, 32): 0.5316609404901015,
#  (2, 31, 32): 0.5953108064912191,
#  (1, 32, 96): 0.6382585695513472,
#  (2, 31, 96): 0.651341801406459,
#  (1, 32, 97): 0.6487406281488678,
#  (2, 31, 97): 0.6524211817198429,
#  (1, 33, 33): 0.5317385375916611,
#  (2, 32, 33): 0.5955452681512389,
#  (1, 33, 99): 0.6383231014972734,
#  (2, 32, 99): 0.6515462628230367,
#  (1, 33, 100): 0.6488068966028214,
#  (2, 32, 100): 0.6526188624860286,
#  (1, 34, 34): 0.5318062779428949,
#  (2, 33, 34): 0.5957485718957984,
#  (1, 35, 35): 0.5318679983996342,
#  (2, 34, 35): 0.5959310706203745,
#  (1, 36, 36): 0.5319251873973311,
#  (2, 35, 36): 0.5961088063515048,
#  (1, 37, 37): 0.5319769849510576,
#  (2, 36, 37): 0.5962632397987264,
#  (1, 38, 38): 0.5320250779543261,
#  (2, 37, 38): 0.5964045750139714,
#  (1, 39, 39): 0.5320778016456672,
#  (2, 38, 39): 0.5965617868740368,
#  (1, 40, 40): 0.5321167325018205,
#  (2, 39, 40): 0.5966842851117292,
#  (1, 41, 41): 0.5321571517934258,
#  (2, 40, 41): 0.5968058406736355,
#  (2, 14, 41): 0.6338000769223442,
#  (1, 42, 42): 0.5322013748645192,
#  (2, 41, 42): 0.5969399487078528,
#  (1, 43, 43): 0.5322408018658233,
#  (2, 42, 43): 0.5970633565449881,
#  (1, 44, 44): 0.5322755651027112,
#  (2, 43, 44): 0.5971704908211825,
#  (2, 15, 44): 0.6355654440591713,
#  (1, 45, 45): 0.5323146613405815,
#  (2, 44, 45): 0.5972896979627089,
#  (1, 46, 46): 0.5323509791656083,
#  (2, 45, 46): 0.5973977583765179,
#  (1, 47, 47): 0.532385014722942,
#  (2, 46, 47): 0.597498806605531,
#  (2, 16, 47): 0.6375855486545072,
#  (1, 48, 48): 0.5324148826610103,
#  (2, 47, 48): 0.5975902130804501,
#  (1, 49, 49): 0.5324444859883317,
#  (2, 48, 49): 0.5976821983913784,
#  (1, 50, 50): 0.5324711785974361,
#  (2, 49, 50): 0.5977623423713782,
#  (2, 17, 50): 0.6383571866691223,
#  (1, 51, 51): 0.5325028988107334,
#  (2, 50, 51): 0.5978603145004572,
#  (1, 52, 52): 0.5325307160155125,
#  (2, 51, 52): 0.597951109063024,
#  (1, 53, 53): 0.5325579709224543,
#  (2, 52, 53): 0.5980328572456773,
#  (2, 18, 53): 0.6393221393725973,
#  (1, 54, 54): 0.5325877396314925,
#  (2, 53, 54): 0.5981236683464157,
#  (1, 55, 55): 0.5326169460426934,
#  (2, 54, 55): 0.5982126271719249,
#  (1, 56, 56): 0.5326397687196227,
#  (2, 55, 56): 0.5982834436230927,
#  (2, 19, 56): 0.639912667869058,
#  (1, 57, 57): 0.5326706620243357,
#  (2, 56, 57): 0.5983790342554488,
#  (1, 58, 58): 0.5326991076796389,
#  (2, 57, 58): 0.5984666865653948,
#  (1, 59, 59): 0.5327241464715744,
#  (2, 58, 59): 0.5985425140825841,
#  (2, 20, 59): 0.6407575699842504,
#  (1, 60, 60): 0.5327515998365764,
#  (2, 59, 60): 0.5986312082973463,
#  (1, 60, 100): 0.6594202186690291,
#  (2, 59, 100): 0.6594714208485749,
#  (1, 61, 61): 0.5327806408660604,
#  (2, 60, 61): 0.5987212090276719,
#  (1, 62, 62): 0.5328041250698572,
#  (2, 61, 62): 0.5987947377389965,
#  (2, 21, 62): 0.6412867749400921,
#  (1, 63, 63): 0.5328350514509137,
#  (2, 62, 63): 0.5988899810697471,
#  (1, 64, 64): 0.5329295505639383,
#  (2, 63, 64): 0.5991591232757963,
#  (1, 65, 65): 0.5329439718496504,
#  (2, 64, 65): 0.5992017586824079,
#  (2, 22, 65): 0.6419519898198954,
#  (1, 66, 66): 0.5329563424020729,
#  (2, 65, 66): 0.5992384734235551,
#  (1, 67, 67): 0.5329692090996461,
#  (2, 66, 67): 0.5992765939092958,
#  (1, 68, 68): 0.5329786027811648,
#  (2, 67, 68): 0.5993086945005419,
#  (2, 23, 68): 0.6423572742552796,
#  (1, 69, 69): 0.5329891210583583,
#  (2, 68, 69): 0.5993394885762248,
#  (1, 70, 70): 0.5330002016333891,
#  (2, 69, 70): 0.5993723499233687,
#  (1, 71, 71): 0.5330110506740166,
#  (2, 70, 71): 0.5994039212931209,
#  (2, 24, 71): 0.6429282380946333,
#  (1, 72, 72): 0.5330189889964267,
#  (2, 71, 72): 0.5994280670237854,
#  (1, 73, 73): 0.5330284819069756,
#  (2, 72, 73): 0.5994564796027452,
#  (1, 74, 74): 0.5330374786723738,
#  (2, 73, 74): 0.599483089520991,
#  (2, 25, 74): 0.6432813280601704,
#  (1, 75, 75): 0.5330459131399347,
#  (2, 74, 75): 0.5995072187134837,
#  (1, 76, 76): 0.5330541822257785,
#  (2, 75, 76): 0.5995340767043049,
#  (1, 77, 77): 0.5330628151513997,
#  (2, 76, 77): 0.5995594131833307,
#  (2, 26, 77): 0.6438085649735813,
#  (1, 78, 78): 0.5330708527028399,
#  (2, 77, 78): 0.5995827154672391,
#  (1, 79, 79): 0.5330799817736117,
#  (2, 78, 79): 0.5996089284693644,
#  (1, 80, 80): 0.5330863985842266,
#  (2, 79, 80): 0.5996283608210977,
#  (2, 27, 80): 0.6441455136835509,
#  (1, 81, 81): 0.5330929477002151,
#  (2, 80, 81): 0.5996482893179816,
#  (1, 82, 82): 0.5331003237247879,
#  (2, 81, 82): 0.5996707812314773,
#  (1, 83, 83): 0.5331074682149571,
#  (2, 82, 83): 0.599691569713289,
#  (2, 28, 83): 0.6446484064082373,
#  (1, 84, 84): 0.5331135542621382,
#  (2, 83, 84): 0.5997103736144981,
#  (1, 85, 85): 0.5331207318286508,
#  (2, 84, 85): 0.5997354950972921,
#  (1, 86, 86): 0.5331267847994886,
#  (2, 85, 86): 0.5997556055140646,
#  (2, 29, 86): 0.6449977587469728,
#  (1, 87, 87): 0.5331327716176396,
#  (2, 86, 87): 0.5997733675104574,
#  (1, 88, 88): 0.5331386592067605,
#  (2, 87, 88): 0.599791989491778,
#  (1, 89, 89): 0.5331450098646887,
#  (2, 88, 89): 0.5998109256983607,
#  (2, 30, 89): 0.6454688981820182,
#  (1, 90, 90): 0.5331506328430625,
#  (2, 89, 90): 0.5998279269388559,
#  (1, 91, 91): 0.5331572150353944,
#  (2, 90, 91): 0.5998475412104778,
#  (1, 92, 92): 0.5331628049374249,
#  (2, 91, 92): 0.5998653528213856,
#  (2, 31, 92): 0.6457769216297059,
#  (1, 93, 93): 0.5331686925265458,
#  (2, 92, 93): 0.5998821225274772,
#  (1, 94, 94): 0.5331750431844738,
#  (2, 93, 94): 0.5999014225738369,
#  (1, 95, 95): 0.5331811953843418,
#  (2, 94, 95): 0.5999193995664617,
#  (2, 32, 95): 0.646300487069002,
#  (1, 96, 96): 0.5331852306982338,
#  (2, 95, 96): 0.599931571660824,
#  (1, 97, 97): 0.5331905890658605,
#  (2, 96, 97): 0.599948109832512,
#  (1, 98, 98): 0.5331949220668428,
#  (2, 97, 98): 0.5999628122671425,
#  (2, 33, 98): 0.6464613042504953,
#  (1, 99, 99): 0.5331994535258853,
#  (2, 98, 99): 0.59997640664427,
#  (2, 60, 99): 0.6594345241875391,
#  (1, 100, 100): 0.533204183442988,
#  (2, 99, 100): 0.5999915225331928,
#  (2, 6, 6): 0.4693452418753916,
#  (3, 5, 6): 0.4740014979614388,
#  (2, 7, 7): 0.48208386784704227,
#  (3, 6, 7): 0.4955659177124083,
#  (2, 8, 8): 0.49122878218725124,
#  (3, 7, 8): 0.5014666050652847,
#  (2, 9, 9): 0.494262775936087,
#  (3, 8, 9): 0.5178661041836018,
#  (2, 10, 10): 0.5004434876119833,
#  (3, 9, 10): 0.5342839937488357,
#  (2, 11, 11): 0.5025522368075666,
#  (3, 10, 11): 0.5431842258389219,
#  (2, 12, 12): 0.506093654740131,
#  (3, 11, 12): 0.5502830045015581,
#  (2, 13, 13): 0.5085600915129808,
#  (3, 12, 13): 0.5546173616138715,
#  (2, 14, 14): 0.5131205254322682,
#  (3, 13, 14): 0.5568134654323105,
#  (2, 15, 15): 0.5156899950147334,
#  (3, 14, 15): 0.5601744353735879,
#  (2, 16, 16): 0.5177187986883774,
#  (3, 15, 16): 0.5635269543091331,
#  (2, 17, 17): 0.5183972606437027,
#  (3, 16, 17): 0.5645428776577504,
#  (2, 18, 18): 0.5198030383135193,
#  (3, 17, 18): 0.5672856342031618,
#  (2, 19, 19): 0.5202042212823249,
#  (3, 18, 19): 0.5700392728655439,
#  (2, 20, 20): 0.521353326527545,
#  (3, 19, 20): 0.5708707459853257,
#  (2, 20, 60): 0.6295677107148301,
#  (3, 19, 60): 0.6304392723627834,
#  (2, 21, 21): 0.5216864383816829,
#  (3, 20, 21): 0.5735340366157767,
#  (2, 21, 63): 0.6301227813711917,
#  (3, 20, 63): 0.6311136824660452,
#  (2, 22, 22): 0.5225738105217701,
#  (3, 21, 22): 0.5764060555111009,
#  (2, 22, 66): 0.630719892059984,
#  (3, 21, 66): 0.6335248486691138,
#  (2, 23, 23): 0.5230437922847974,
#  (3, 22, 23): 0.5785014418639604,
#  (2, 23, 69): 0.6311993336572169,
#  (3, 22, 69): 0.6351912844629037,
#  (2, 23, 71): 0.641735372847127,
#  (3, 22, 71): 0.6419442003410304,
#  (2, 24, 24): 0.5237380978085997,
#  (3, 23, 24): 0.5800568899875528,
#  (2, 24, 72): 0.6316713165390184,
#  (3, 23, 72): 0.6362437075564361,
#  (2, 24, 74): 0.642247130031838,
#  (3, 23, 74): 0.6426527783069992,
#  (2, 25, 25): 0.524088839353757,
#  (3, 24, 25): 0.5809113180896375,
#  (2, 25, 75): 0.6320944621998256,
#  (3, 24, 75): 0.637120230655896,
#  (2, 25, 77): 0.6426200988797439,
#  (3, 24, 77): 0.6434655302164304,
#  (2, 26, 26): 0.5248276325593998,
#  (3, 25, 26): 0.5813076057596235,
#  (2, 26, 78): 0.6325682808186844,
#  (3, 25, 78): 0.6376919552511473,
#  (2, 26, 80): 0.6431372309702534,
#  (3, 25, 80): 0.6440306064666632,
#  (2, 27, 27): 0.5251138752349743,
#  (3, 26, 27): 0.582175396704432,
#  (2, 27, 81): 0.6329491879890007,
#  (3, 26, 81): 0.6380589868954174,
#  (2, 27, 83): 0.6434930993486342,
#  (3, 26, 83): 0.6444297387021796,
#  (2, 28, 28): 0.5256858644409728,
#  (3, 27, 28): 0.5828712072018578,
#  (2, 28, 84): 0.6333982655030145,
#  (3, 27, 84): 0.6388404320458433,
#  (2, 28, 86): 0.6439339408531474,
#  (3, 27, 86): 0.6451290222156598,
#  (2, 29, 29): 0.5261190653101662,
#  (3, 28, 29): 0.5831610717370319,
#  (2, 29, 87): 0.6337884340494758,
#  (3, 28, 87): 0.6392850773298446,
#  (2, 29, 88): 0.6449055088252976,
#  (3, 28, 88): 0.644998916418991,
#  (2, 29, 89): 0.6443102007972193,
#  (3, 28, 89): 0.6455973005470034,
#  (2, 30, 30): 0.5268432387720368,
#  (3, 29, 30): 0.5837543951845078,
#  (2, 30, 90): 0.63421194355006,
#  (3, 29, 90): 0.6395496715386797,
#  (2, 30, 92): 0.6447714007910802,
#  (3, 29, 92): 0.645899006413106,
#  (2, 31, 31): 0.5275615907974732,
#  (3, 30, 31): 0.5843650506359125,
#  (2, 31, 93): 0.6345886665629393,
#  (3, 30, 93): 0.640241909791021,
#  (2, 31, 94): 0.6457147711805027,
#  (3, 30, 94): 0.645921002181451,
#  (2, 31, 95): 0.6453186488922336,
#  (3, 30, 95): 0.6465264150324307,
#  (2, 32, 32): 0.5279858610539553,
#  (3, 31, 32): 0.5845853886973108,
#  (2, 32, 96): 0.635051999980948,
#  (3, 31, 96): 0.6406006558112753,
#  (2, 32, 97): 0.6461740362082762,
#  (3, 31, 97): 0.646306424272638,
#  (2, 32, 98): 0.645574742480821,
#  (3, 31, 98): 0.6468801499866637,
#  (2, 33, 33): 0.5281335800034718,
#  (3, 32, 33): 0.5851356798220545,
#  (2, 33, 99): 0.6352244269589663,
#  (3, 32, 99): 0.6407475974667225,
#  (2, 33, 100): 0.6463518546302647,
#  (3, 32, 100): 0.6464238949061373,
#  (2, 34, 34): 0.5283821156475977,
#  (3, 33, 34): 0.5857237441309336,
#  (2, 35, 35): 0.5284957328870937,
#  (3, 34, 35): 0.5859061105501363,
#  (2, 36, 36): 0.5286972339709394,
#  (3, 35, 36): 0.5863498462346949,
#  (2, 37, 37): 0.5288185579984419,
#  (3, 36, 37): 0.5868146350118123,
#  (2, 38, 38): 0.5290239620908059,
#  (3, 37, 38): 0.5870175583784231,
#  (2, 39, 39): 0.5291136651340412,
#  (3, 38, 39): 0.5874601198527918,
#  (2, 40, 40): 0.5292680655049197,
#  (3, 39, 40): 0.5879006636702145,
#  (2, 41, 41): 0.5293537993869498,
#  (3, 40, 41): 0.5880250307213077,
#  (2, 42, 42): 0.5295149142555335,
#  (3, 41, 42): 0.5884515170927959,
#  (2, 43, 43): 0.5296025334891361,
#  (3, 42, 43): 0.5889065483486172,
#  (2, 44, 44): 0.5297588522879303,
#  (3, 43, 44): 0.58904100368444,
#  (2, 45, 45): 0.5298143874684583,
#  (3, 44, 45): 0.5894975068375417,
#  (2, 46, 46): 0.5299781484445122,
#  (3, 45, 46): 0.5899698039446054,
#  (3, 45, 47): 0.5976479643759843,
#  (2, 47, 47): 0.5300331874798896,
#  (3, 46, 47): 0.5905717768558739,
#  (3, 46, 48): 0.5985042612914698,
#  (2, 48, 48): 0.5301334749530051,
#  (3, 47, 48): 0.5909074355884519,
#  (3, 47, 49): 0.5986030107146184,
#  (2, 49, 49): 0.5302022075945402,
#  (3, 48, 49): 0.5910961361274111,
#  (3, 48, 50): 0.5987849967558723,
#  (2, 50, 50): 0.5303300145853443,
#  (3, 49, 50): 0.5911701775220579,
#  (3, 49, 51): 0.5989254058335026,
#  (2, 51, 51): 0.530385152849752,
#  (3, 50, 51): 0.5913320862228827,
#  (3, 50, 52): 0.5990053844317854,
#  (2, 52, 52): 0.5305056830450136,
#  (3, 51, 52): 0.5914818062911734,
#  (3, 51, 53): 0.5991632908950618,
#  (2, 53, 53): 0.5305588367288184,
#  (3, 52, 53): 0.5915376556969635,
#  (3, 52, 54): 0.5992909986568359,
#  (2, 18, 54): 0.6281354554321411,
#  (3, 18, 53): 0.6282727553334942,
#  (2, 54, 54): 0.5306651440964284,
#  (3, 53, 54): 0.5916624692786923,
#  (3, 53, 55): 0.5993634193106573,
#  (2, 55, 55): 0.5307288160574269,
#  (3, 54, 55): 0.5918032587342715,
#  (3, 54, 56): 0.599478690367322,
#  (2, 56, 56): 0.5308433925108808,
#  (3, 55, 56): 0.5918555193568054,
#  (3, 55, 57): 0.5995967232986587,
#  (2, 19, 57): 0.6287977430555555,
#  (3, 19, 56): 0.6300712318900404,
#  (2, 57, 57): 0.5308984976989449,
#  (3, 56, 57): 0.5919839713363054,
#  (3, 56, 58): 0.5996486531577588,
#  (2, 58, 58): 0.531019424810327,
#  (3, 57, 58): 0.5921011938972294,
#  (3, 57, 59): 0.5997754843964335,
#  (2, 59, 59): 0.5310688408673304,
#  (3, 58, 59): 0.5921501799617691,
#  (3, 58, 60): 0.5998798898742993,
#  (3, 20, 59): 0.6308086193510897,
#  (2, 60, 60): 0.5311653907136445,
#  (3, 59, 60): 0.5922371045921607,
#  (3, 59, 61): 0.5999254359991278,
#  (2, 61, 61): 0.5312331972175651,
#  (3, 60, 61): 0.5923383678174059,
#  (3, 60, 62): 0.6000335791037951,
#  (2, 62, 62): 0.5313585565589595,
#  (3, 61, 62): 0.5923812182202493,
#  (3, 61, 63): 0.6001316835382479,
#  (3, 21, 62): 0.6330898947537215,
#  (2, 63, 63): 0.5315653498577452,
#  (3, 62, 63): 0.5925049402826467,
#  (3, 62, 64): 0.6001830180231672,
#  (2, 64, 64): 0.5316609404901015,
#  (3, 63, 64): 0.5925977525021593,
#  (3, 63, 65): 0.6002796836366832,
#  (2, 65, 65): 0.531690378435706,
#  (3, 64, 65): 0.592631788059493,
#  (3, 64, 66): 0.6003744142841115,
#  (3, 22, 65): 0.6346719031810446,
#  (2, 66, 66): 0.5317385375916611,
#  (3, 65, 66): 0.5927241372101983,
#  (3, 65, 67): 0.6004132789875781,
#  (2, 67, 67): 0.5317613271922471,
#  (3, 66, 67): 0.5928214643505817,
#  (3, 66, 68): 0.6005093823032567,
#  (2, 68, 68): 0.5318062779428949,
#  (3, 67, 68): 0.5928686808307507,
#  (3, 67, 69): 0.600597067689546,
#  (3, 23, 68): 0.6353617433984912,
#  (2, 69, 69): 0.5318268845048181,
#  (3, 68, 69): 0.5929494532612746,
#  (3, 68, 70): 0.6006299621130332,
#  (2, 70, 70): 0.5318679983996342,
#  (3, 69, 70): 0.5930456061914681,
#  (3, 69, 71): 0.6007228404852326,
#  (2, 71, 71): 0.5318853634799066,
#  (3, 70, 71): 0.5930765987252112,
#  (3, 70, 72): 0.6007995941400363,
#  (3, 24, 71): 0.6368715792445682,
#  (2, 72, 72): 0.5319251873973311,
#  (3, 71, 72): 0.5931494493714966,
#  (3, 71, 73): 0.600835432358084,
#  (2, 73, 73): 0.5319396086830429,
#  (3, 72, 73): 0.5932231434645379,
#  (3, 72, 74): 0.6009037846216702,
#  (2, 74, 74): 0.5319769849510576,
#  (3, 73, 74): 0.5932469749699402,
#  (3, 73, 75): 0.6009758414357144,
#  (3, 25, 74): 0.637481490478247,
#  (2, 75, 75): 0.5319899508776609,
#  (3, 74, 75): 0.5933288389197955,
#  (3, 74, 76): 0.600999127181451,
#  (2, 76, 76): 0.5320250779543261,
#  (3, 75, 76): 0.5934025495510085,
#  (3, 75, 77): 0.6010797838447729,
#  (2, 77, 77): 0.5320406899883995,
#  (3, 76, 77): 0.5934319544202696,
#  (3, 76, 78): 0.6011526014147149,
#  (3, 26, 77): 0.6378954574537672,
#  (2, 78, 78): 0.5320778016456672,
#  (3, 77, 78): 0.5934982559505665,
#  (3, 77, 79): 0.6011803855431506,
#  (2, 79, 79): 0.5320866991820353,
#  (3, 78, 79): 0.5935844198250606,
#  (3, 78, 80): 0.601249680482523,
#  (2, 80, 80): 0.5321167325018205,
#  (3, 79, 80): 0.5935997672483869,
#  (3, 79, 81): 0.6013253922325102,
#  (3, 27, 80): 0.6386029439004047,
#  (2, 81, 81): 0.5321278792295382,
#  (3, 80, 81): 0.5936775793461786,
#  (3, 80, 82): 0.6013561366936782,
#  (2, 82, 82): 0.5321571517934258,
#  (3, 81, 82): 0.5937518688134007,
#  (3, 81, 83): 0.601426787763129,
#  (2, 83, 83): 0.5321697869565954,
#  (3, 82, 83): 0.5937740134252909,
#  (3, 82, 84): 0.6014979184395587,
#  (3, 28, 83): 0.6390618120120578,
#  (2, 84, 84): 0.5322013748645192,
#  (3, 83, 84): 0.5938440691205609,
#  (3, 83, 85): 0.6015204268912259,
#  (2, 85, 85): 0.5322126208212671,
#  (3, 84, 85): 0.5939187058893884,
#  (3, 84, 86): 0.6015962874847584,
#  (2, 86, 86): 0.5322408018658233,
#  (3, 85, 86): 0.5939462915597639,
#  (3, 85, 87): 0.6016669550923809,
#  (3, 29, 86): 0.6394178126958119,
#  (2, 87, 87): 0.532251948593541,
#  (3, 86, 87): 0.5940234421306881,
#  (3, 86, 88): 0.601684650936087,
#  (2, 88, 88): 0.5322755651027112,
#  (3, 87, 88): 0.5940922243867381,
#  (3, 87, 89): 0.6017641830037341,
#  (2, 89, 89): 0.5322872410519229,
#  (3, 88, 89): 0.5941109952116039,
#  (3, 88, 90): 0.6018371328790496,
#  (3, 30, 89): 0.6400308661821116,
#  (2, 90, 90): 0.5323146613405815,
#  (3, 89, 90): 0.5941841270068079,
#  (3, 89, 91): 0.6018690019358922,
#  (2, 91, 91): 0.5323265357478535,
#  (3, 90, 91): 0.5942605664363495,
#  (3, 90, 92): 0.6019353200043608,
#  (2, 92, 92): 0.5323509791656083,
#  (3, 91, 92): 0.5942813383799895,
#  (3, 91, 93): 0.6020062026082151,
#  (3, 31, 92): 0.6404354725524564,
#  (2, 93, 93): 0.5323607366869041,
#  (3, 92, 93): 0.5943591835541245,
#  (3, 92, 94): 0.6020233692304272,
#  (2, 94, 94): 0.532385014722942,
#  (3, 93, 94): 0.5944335226358617,
#  (3, 93, 95): 0.6021049851077072,
#  (2, 95, 95): 0.5323954668474488,
#  (3, 94, 95): 0.5946310545585023,
#  (3, 94, 96): 0.6023667182128402,
#  (3, 32, 95): 0.6407084350761655,
#  (2, 96, 96): 0.5324148826610103,
#  (3, 95, 96): 0.5947102558627156,
#  (3, 95, 97): 0.6023858198011397,
#  (2, 97, 97): 0.5324242763425291,
#  (3, 96, 97): 0.5947447048743416,
#  (3, 96, 98): 0.6024215422519856,
#  (2, 98, 98): 0.5324444859883317,
#  (3, 97, 98): 0.5947557192966858,
#  (3, 97, 99): 0.6024459691315688,
#  (3, 33, 98): 0.6412241118075667,
#  (2, 99, 99): 0.532454276585971,
#  (3, 98, 99): 0.5947932940227607,
#  (3, 98, 100): 0.6024601919592203,
#  (2, 100, 100): 0.5324711785974361,
#  (3, 99, 100): 0.594818828959847,
#  (3, 7, 7): 0.44019443200773933,
#  (4, 6, 7): 0.45015962312549745,
#  (3, 8, 8): 0.4467808250351403,
#  (4, 7, 8): 0.4742427237336788,
#  (3, 9, 9): 0.4693452418753916,
#  (4, 8, 9): 0.49163882961608163,
#  (3, 10, 10): 0.47808047262654746,
#  (4, 9, 10): 0.4967868813136124,
#  (3, 11, 11): 0.48470119889837254,
#  (4, 10, 11): 0.502631388497265,
#  (3, 12, 12): 0.49122878218725124,
#  (4, 11, 12): 0.5167916853217244,
#  (3, 13, 13): 0.4935336740990533,
#  (4, 12, 13): 0.5312539030085183,
#  (3, 14, 14): 0.4956136137995563,
#  (4, 13, 14): 0.5362733208066606,
#  (3, 15, 15): 0.5004434876119833,
#  (4, 14, 15): 0.5434280646422885,
#  (3, 16, 16): 0.5020230153135531,
#  (4, 15, 16): 0.5478861768933428,
#  (3, 17, 17): 0.5030273123274739,
#  (4, 16, 17): 0.5516700278846806,
#  (3, 17, 51): 0.615492767394452,
#  (4, 16, 51): 0.6161914720719234,
#  (3, 18, 18): 0.506093654740131,
#  (4, 17, 18): 0.5534884163999391,
#  (3, 18, 54): 0.6177887948462294,
#  (4, 17, 54): 0.6190445216843214,
#  (3, 19, 19): 0.5081359535618724,
#  (4, 18, 19): 0.5547300196394097,
#  (3, 19, 57): 0.6196168251155819,
#  (4, 18, 57): 0.6206401410269438,
#  (3, 20, 20): 0.5092737466976579,
#  (4, 19, 20): 0.5579425760279598,
#  (3, 20, 60): 0.6203943672574895,
#  (4, 19, 60): 0.6215706116424494,
#  (3, 21, 21): 0.5131205254322682,
#  (4, 20, 21): 0.560842097902801,
#  (3, 21, 63): 0.6225665568796677,
#  (4, 20, 63): 0.6242344480325662,
#  (3, 22, 22): 0.5144697094785687,
#  (4, 21, 22): 0.5619077515336839,
#  (3, 22, 66): 0.624324547991922,
#  (4, 21, 66): 0.6264198516539231,
#  (3, 23, 23): 0.5164820742095548,
#  (4, 22, 23): 0.5623249765290268,
#  (3, 23, 69): 0.6249592168686177,
#  (4, 22, 69): 0.6269802310633965,
#  (3, 24, 24): 0.5177187986883774,
#  (4, 23, 24): 0.5647878741331352,
#  (3, 24, 72): 0.6264351494627344,
#  (4, 23, 72): 0.6274335588875342,
#  (3, 25, 25): 0.518164866255144,
#  (4, 24, 25): 0.5672480925534301,
#  (3, 25, 75): 0.6270372712175482,
#  (4, 24, 75): 0.6295931629610577,
#  (3, 26, 26): 0.5187485975630408,
#  (4, 25, 26): 0.5679596473903029,
#  (3, 26, 78): 0.6274313096961844,
#  (4, 25, 78): 0.6313052441087063,
#  (3, 27, 27): 0.5198030383135193,
#  (4, 26, 27): 0.5688839492677692,
#  (3, 27, 81): 0.6281354554321411,
#  (4, 26, 81): 0.6318541625652001,
#  (3, 28, 28): 0.5200221029356974,
#  (4, 27, 28): 0.571275650042761,
#  (3, 28, 84): 0.6286252830011939,
#  (4, 27, 84): 0.6323139071999525,
#  (3, 29, 29): 0.5204572222328067,
#  (4, 28, 29): 0.5737307747061763,
#  (3, 29, 87): 0.6289591721494013,
#  (4, 28, 87): 0.6344316035464191,
#  (3, 30, 30): 0.521353326527545,
#  (4, 29, 30): 0.5746018071326356,
#  (3, 30, 90): 0.6295677107148301,
#  (4, 29, 90): 0.636175140296618,
#  (4, 29, 93): 0.6410474510575962,
#  (3, 31, 31): 0.5216136373499127,
#  (4, 30, 31): 0.5765721483693628,
#  (3, 31, 93): 0.6299875487412996,
#  (4, 30, 93): 0.6364735716047266,
#  (4, 30, 96): 0.6419747628823096,
#  (3, 32, 32): 0.5218702105454792,
#  (4, 31, 32): 0.57749606986888,
#  (3, 32, 96): 0.6301997334840557,
#  (4, 31, 96): 0.6374555090105252,
#  (3, 32, 98): 0.6418308477122813,
#  (4, 31, 98): 0.64189207202387,
#  (4, 31, 99): 0.6423986858371861,
#  (3, 33, 33): 0.5225738105217701,
#  (4, 32, 33): 0.5782692459334621,
#  (3, 33, 99): 0.630719892059984,
#  (4, 32, 99): 0.6381510714353757,
#  (3, 34, 34): 0.5229414210020491,
#  (4, 33, 34): 0.5785625834846907,
#  (3, 35, 35): 0.5230813339345289,
#  (4, 34, 35): 0.5789247529064845,
#  (4, 34, 36): 0.586367542078401,
#  (3, 36, 36): 0.5237380978085997,
#  (4, 35, 36): 0.5796576089084913,
#  (3, 37, 37): 0.5239908341483345,
#  (4, 36, 37): 0.5802491462334248,
#  (4, 36, 38): 0.5873462049262054,
#  (3, 38, 38): 0.5241945844235296,
#  (4, 37, 38): 0.5804661601223137,
#  (4, 37, 39): 0.58762088741977,
#  (3, 39, 39): 0.5248276325593998,
#  (4, 38, 39): 0.5806532895349625,
#  (4, 38, 40): 0.5880847500592729,
#  (3, 40, 40): 0.5250622099866212,
#  (4, 39, 40): 0.5812160504411591,
#  (4, 39, 41): 0.5883475912219089,
#  (3, 41, 41): 0.5251781094938103,
#  (4, 40, 41): 0.581744395412073,
#  (4, 40, 42): 0.588833317324383,
#  (3, 42, 42): 0.5256858644409728,
#  (4, 41, 42): 0.5820000755463682,
#  (4, 41, 43): 0.5890965057886247,
#  (3, 43, 43): 0.5260332321991058,
#  (4, 42, 43): 0.5820988084313451,
#  (4, 42, 44): 0.5895697621096462,
#  (3, 44, 44): 0.5262173020499924,
#  (4, 43, 44): 0.5826556321339057,
#  (4, 43, 45): 0.5897379057011973,
#  (3, 45, 45): 0.5268432387720368,
#  (4, 44, 45): 0.5831276480920508,
#  (4, 44, 46): 0.5902254013880421,
#  (3, 46, 46): 0.5271012011740249,
#  (4, 45, 46): 0.583270240208344,
#  (3, 47, 47): 0.5277467521676913,
#  (4, 46, 47): 0.5834219779335806,
#  (3, 48, 48): 0.5279858610539553,
#  (4, 47, 48): 0.583798849790005,
#  (3, 49, 49): 0.5280672950113465,
#  (4, 48, 49): 0.58421129525373,
#  (4, 48, 50): 0.5913062701368778,
#  (3, 50, 50): 0.5281774061584447,
#  (4, 49, 50): 0.5844009880829905,
#  (4, 49, 51): 0.5914750587171248,
#  (4, 17, 50): 0.6165013477948399,
#  (3, 51, 51): 0.5283821156475977,
#  (4, 50, 51): 0.5845099911725855,
#  (4, 50, 52): 0.5918398411700453,
#  (3, 52, 52): 0.5284536267019764,
#  (4, 51, 52): 0.5848932467632814,
#  (4, 51, 53): 0.5920035690697556,
#  (3, 53, 53): 0.5285409151721452,
#  (4, 52, 53): 0.5853034761120002,
#  (4, 52, 54): 0.5923164712780911,
#  (4, 18, 53): 0.6181123476371319,
#  (3, 54, 54): 0.5286972339709394,
#  (4, 53, 54): 0.5854581080172822,
#  (4, 53, 55): 0.5925202546296297,
#  (3, 55, 55): 0.5287723172704025,
#  (4, 54, 55): 0.5854904070665887,
#  (4, 54, 56): 0.5928632397722654,
#  (3, 56, 56): 0.528849186692408,
#  (4, 55, 56): 0.585891077352072,
#  (4, 55, 57): 0.5930314164401599,
#  (3, 57, 57): 0.5290239620908059,
#  (4, 56, 57): 0.5862959648713356,
#  (4, 56, 58): 0.593397753481219,
#  (3, 58, 58): 0.529078174217599,
#  (4, 57, 58): 0.5864241191637455,
#  (4, 57, 59): 0.5935495408209707,
#  (3, 59, 59): 0.5291300048476689,
#  (4, 58, 59): 0.5865677035703398,
#  (4, 58, 60): 0.5938409764824553,
#  (4, 20, 59): 0.6220633830060628,
#  (3, 60, 60): 0.5292680655049197,
#  (4, 59, 60): 0.5869693992224677,
#  (4, 59, 61): 0.5940510939537503,
#  (3, 61, 61): 0.5293283636788938,
#  (4, 60, 61): 0.5873862934543769,
#  (4, 60, 62): 0.5944358379798981,
#  (3, 62, 62): 0.5293856188292774,
#  (4, 61, 62): 0.5875231799014378,
#  (4, 61, 63): 0.5950046353187607,
#  (4, 21, 62): 0.6242603302712578,
#  (3, 63, 63): 0.5295149142555335,
#  (4, 62, 63): 0.5881961511837626,
#  (4, 62, 64): 0.5953108064912191,
#  (3, 64, 64): 0.5295760062617487,
#  (4, 63, 64): 0.5883510807761351,
#  (4, 63, 65): 0.5954003937672526,
#  (3, 65, 65): 0.5296215523865772,
#  (4, 64, 65): 0.5884918206171993,
#  (4, 64, 66): 0.5955452681512389,
#  (4, 22, 65): 0.6248344032868888,
#  (3, 66, 66): 0.5297588522879303,
#  (4, 65, 66): 0.5885713692230182,
#  (4, 65, 67): 0.5956124131282917,
#  (3, 67, 67): 0.5298012561601383,
#  (4, 66, 67): 0.5886375219097698,
#  (4, 66, 68): 0.5957485718957984,
#  (3, 68, 68): 0.529846471521533,
#  (4, 67, 68): 0.5887764094756051,
#  (4, 67, 69): 0.5958102427380226,
#  (4, 23, 68): 0.6256472213490067,
#  (3, 69, 69): 0.5299781484445122,
#  (4, 68, 69): 0.5889008426793849,
#  (4, 68, 70): 0.5959310706203745,
#  (3, 70, 70): 0.5300216107597081,
#  (4, 69, 70): 0.5889561794018526,
#  (4, 69, 71): 0.5959897480535233,
#  (3, 71, 71): 0.5300431103829023,
#  (4, 70, 71): 0.5889931587537468,
#  (4, 70, 72): 0.5961088063515048,
#  (4, 24, 71): 0.6278304253935291,
#  (3, 72, 72): 0.5301334749530051,
#  (4, 71, 72): 0.5891061971572339,
#  (4, 71, 73): 0.596151656754348,
#  (3, 73, 73): 0.5301830563917255,
#  (4, 72, 73): 0.5892122399140968,
#  (4, 72, 74): 0.5962632397987264,
#  (3, 74, 74): 0.5302213918736981,
#  (4, 73, 74): 0.5892634255554708,
#  (4, 73, 75): 0.5963052632929854,
#  (4, 25, 74): 0.6295195515588748,
#  (3, 75, 75): 0.5303300145853443,
#  (4, 74, 75): 0.5893170257699115,
#  (4, 74, 76): 0.5964045750139714,
#  (3, 76, 76): 0.5303685816017206,
#  (4, 75, 76): 0.5894298161008231,
#  (4, 75, 77): 0.5964538256892581,
#  (3, 77, 77): 0.530398449539789,
#  (4, 76, 77): 0.5895255886530678,
#  (4, 76, 78): 0.5965617868740368,
#  (4, 26, 77): 0.6298821178967892,
#  (3, 78, 78): 0.5305056830450136,
#  (4, 77, 78): 0.5895662560172484,
#  (4, 77, 79): 0.5965969635652171,
#  (3, 79, 79): 0.5305416701066065,
#  (4, 78, 79): 0.5895925020957171,
#  (4, 78, 80): 0.5966842851117292,
#  (3, 80, 80): 0.5305744818392352,
#  (4, 79, 80): 0.5896747464235211,
#  (4, 79, 81): 0.5967190152722739,
#  (4, 27, 80): 0.6305618532913343,
#  (3, 81, 81): 0.5306651440964284,
#  (4, 80, 81): 0.5897592564808464,
#  (4, 80, 82): 0.5968058406736355,
#  (3, 82, 82): 0.5307149570695524,
#  (4, 81, 82): 0.5898063737319853,
#  (4, 81, 83): 0.5968468057249064,
#  (3, 83, 83): 0.5307373497540179,
#  (4, 82, 83): 0.5898409219726414,
#  (4, 82, 84): 0.5969399487078528,
#  (4, 28, 83): 0.632644984858973,
#  (3, 84, 84): 0.5308433925108808,
#  (4, 83, 84): 0.5899515788794052,
#  (4, 83, 85): 0.5969784495715423,
#  (3, 85, 85): 0.5308807357025521,
#  (4, 84, 85): 0.590039297342038,
#  (4, 84, 86): 0.5970633565449881,
#  (3, 86, 86): 0.5309161604663076,
#  (4, 85, 86): 0.5900632776909854,
#  (4, 85, 87): 0.5971014439543854,
#  (4, 29, 86): 0.6341472958369321,
#  (3, 87, 87): 0.531019424810327,
#  (4, 86, 87): 0.5900916241172586,
#  (4, 86, 88): 0.5971704908211825,
#  (3, 88, 88): 0.5310544195816186,
#  (4, 87, 88): 0.5901717184827432,
#  (4, 87, 89): 0.5972081978526308,
#  (3, 89, 89): 0.5310768122660842,
#  (4, 88, 89): 0.5902565427653305,
#  (4, 88, 90): 0.5972896979627089,
#  (4, 30, 89): 0.6345409208612762,
#  (3, 90, 90): 0.5311653907136445,
#  (4, 89, 90): 0.5902962343773815,
#  (4, 89, 91): 0.597325304646353,
#  (3, 91, 91): 0.5312151706104252,
#  (4, 90, 91): 0.5903176513097174,
#  (4, 90, 92): 0.5973977583765179,
#  (3, 92, 92): 0.5312498676946266,
#  (4, 91, 92): 0.5904037490315247,
#  (4, 91, 93): 0.5974274443946976,
#  (4, 31, 92): 0.6350845636410015,
#  (3, 93, 93): 0.5313585565589595,
#  (4, 92, 93): 0.5904832480228285,
#  (4, 92, 94): 0.597498806605531,
#  (3, 94, 94): 0.5313904421539738,
#  (4, 93, 94): 0.5905108667695473,
#  (4, 93, 95): 0.5975329083155515,
#  (3, 95, 95): 0.5316191650684178,
#  (4, 94, 95): 0.590518887782816,
#  (4, 94, 96): 0.5975902130804501,
#  (4, 32, 95): 0.6364357157297329,
#  (3, 96, 96): 0.5316609404901015,
#  (4, 95, 96): 0.5905898365393571,
#  (4, 95, 97): 0.5976202960147504,
#  (3, 97, 97): 0.5316739725693914,
#  (4, 96, 97): 0.5906563199895426,
#  (4, 96, 98): 0.5976821983913784,
#  (3, 98, 98): 0.5317002351860319,
#  (4, 97, 98): 0.5906784149869176,
#  (4, 97, 99): 0.5977121324821334,
#  (4, 33, 98): 0.6369774566197142,
#  (3, 99, 99): 0.5317385375916611,
#  (4, 98, 99): 0.5907043468401243,
#  (4, 98, 100): 0.5977623423713782,
#  (3, 100, 100): 0.53174793127318,
#  (4, 99, 100): 0.5907712272064303,
#  (4, 6, 6): 0.38529044734034446,
#  (5, 5, 6): 0.3960503141458788,
#  (4, 7, 7): 0.4024199248187945,
#  (5, 6, 7): 0.42052775091978695,
#  (4, 8, 8): 0.4285657819670951,
#  (5, 7, 8): 0.43856474403143997,
#  (4, 9, 9): 0.4379673356555573,
#  (5, 8, 9): 0.45166674671141765,
#  (4, 10, 10): 0.4425199304814645,
#  (5, 9, 10): 0.47425496198072786,
#  (4, 11, 11): 0.44806372408931566,
#  (5, 10, 11): 0.4900424495175617,
#  (4, 12, 12): 0.4693452418753916,
#  (5, 11, 12): 0.4940311588415976,
#  (4, 13, 13): 0.47675533508188117,
#  (5, 12, 13): 0.4998499491682755,
#  (4, 14, 14): 0.48208386784704227,
#  (5, 13, 14): 0.5030468273700656,
#  (4, 15, 15): 0.4852509608016224,
#  (5, 14, 15): 0.5158300733289302,
#  (4, 16, 16): 0.49122878218725124,
#  (5, 15, 16): 0.5299008986445578,
#  (4, 17, 17): 0.49264620272993614,
#  (5, 16, 17): 0.5345106990063337,
#  (4, 17, 51): 0.606547849164465,
#  (5, 16, 51): 0.6068501173284052,
#  (4, 18, 18): 0.494262775936087,
#  (5, 17, 18): 0.5398539672824688,
#  (4, 18, 54): 0.6085029752832394,
#  (5, 17, 54): 0.6086456500903911,
#  (4, 19, 19): 0.4959453033709292,
#  (5, 18, 19): 0.543222478630036,
#  (4, 19, 57): 0.6093778611037021,
#  (5, 18, 57): 0.6110883711250402,
#  (4, 20, 20): 0.5004434876119833,
#  (5, 19, 20): 0.5470177244216667,
#  (4, 20, 60): 0.6124243742485055,
#  (5, 19, 60): 0.6127122872794205,
#  (4, 21, 21): 0.501754931550492,
#  (5, 20, 21): 0.5505264463888041,
#  (4, 21, 63): 0.614252404517858,
#  (5, 20, 63): 0.6159845133914207,
#  (4, 22, 22): 0.5025522368075666,
#  (5, 21, 22): 0.5517973221921625,
#  (4, 22, 66): 0.6150826703511068,
#  (5, 21, 66): 0.6187561455845992,
#  (4, 23, 23): 0.5031675890997307,
#  (5, 22, 23): 0.5531504092469813,
#  (4, 23, 69): 0.6156283473259496,
#  (5, 22, 69): 0.6198103713388458,
#  (4, 24, 24): 0.506093654740131,
#  (5, 23, 24): 0.5539436130374774,
#  (4, 24, 72): 0.6177887948462294,
#  (5, 23, 72): 0.6206770046116361,
#  (4, 25, 25): 0.5079278041330082,
#  (5, 24, 25): 0.5569707103687193,
#  (4, 25, 75): 0.619438130170494,
#  (5, 24, 75): 0.6214497341455826,
#  (4, 26, 26): 0.5085600915129808,
#  (5, 25, 26): 0.5597136488340192,
#  (4, 26, 78): 0.6200700371725177,
#  (5, 25, 78): 0.6240545788772883,
#  (4, 27, 27): 0.5094988642906738,
#  (5, 26, 27): 0.5606478239999831,
#  (4, 27, 81): 0.6205027253583889,
#  (5, 26, 81): 0.6261406211631442,
#  (4, 28, 28): 0.5131205254322682,
#  (5, 27, 28): 0.5612278672955936,
#  (4, 28, 84): 0.6225665568796677,
#  (5, 27, 84): 0.6265492628473809,
#  (4, 29, 29): 0.5143106453432743,
#  (5, 28, 29): 0.5613912478936984,
#  (4, 29, 87): 0.6242289738977375,
#  (5, 28, 87): 0.626946129353376,
#  (4, 30, 30): 0.5156899950147334,
#  (5, 29, 30): 0.5637915319797965,
#  (4, 30, 90): 0.6246810778971702,
#  (5, 29, 90): 0.6272628022648563,
#  (4, 31, 31): 0.5166124611551424,
#  (5, 30, 31): 0.566074510814112,
#  (4, 31, 93): 0.6255271046080374,
#  (5, 30, 93): 0.6294413425449626,
#  (4, 32, 32): 0.5177187986883774,
#  (5, 31, 32): 0.5665562016026944,
#  (4, 32, 96): 0.6264351494627344,
#  (5, 31, 96): 0.6310857660322359,
#  (4, 33, 33): 0.5180689779356974,
#  (5, 32, 33): 0.5674294005296449,
#  (4, 33, 99): 0.626903626252138,
#  (5, 32, 99): 0.6314149087251689,
#  (4, 34, 34): 0.5183972606437027,
#  (5, 33, 34): 0.5680504584910413,
#  (4, 35, 35): 0.5188368121708242,
#  ...}

# %%
exportStateProbs(DATA_DIR + 'game1_better_giving_1_to_another_memo_1-100.csv', betterGiving1ToAnother)

# %%
betterGiving1ToAnother, given1ToAnother = readApproxBetterGiving1Probs(DATA_DIR + 'game1_better_giving_1_to_another_memo_1-100.csv')

# %%
betterGiving1ToAnother, given1ToAnother = stricterFilter(betterGiving1ToAnother, printOnGo=True,
                                                         filename=DATA_DIR + 'game1_better_giving_1_to_another_stricter_1-100.csv',
                                                         giveToAnother=True, continueFrom=(17,23,72))
# Out:
# Approximating hitting prob for (17, 24, 25)
# (17, 24, 25): 0.4242857498567869
# (16, 25, 25): 0.39321993388563553
#
# Approximating hitting prob for (17, 24, 75)
# (17, 24, 75): 0.5269327877501919
# (16, 25, 75): 0.5245554637658941
#
# Approximating hitting prob for (16, 26, 26)
# (16, 26, 26): 0.3947469573259146
# (15, 27, 26): 0.45579458539511997
#
# Approximating hitting prob for (16, 26, 78)
# (16, 26, 78): 0.5258894053029588
# (15, 27, 78): 0.543090896169331
#
# Approximating hitting prob for (16, 27, 27)
# (16, 27, 27): 0.4007384634436817
# (15, 28, 27): 0.45805028597259484
#
# Approximating hitting prob for (16, 27, 81)
# (16, 27, 81): 0.5301899864928376
# (15, 28, 81): 0.5454612622131987
#
# Approximating hitting prob for (17, 14, 27)
# (17, 14, 27): 0.33801093179716085
# (16, 15, 27): 0.35540501667819707
#
# Approximating hitting prob for (17, 27, 28)
# (17, 27, 28): 0.44683834264244565
# (16, 28, 28): 0.4025301176497849
#
# Approximating hitting prob for (17, 27, 84)
# (17, 27, 84): 0.5351089577651486
# (16, 28, 84): 0.5329836301279316
#
# Approximating hitting prob for (17, 28, 29)
# (17, 28, 29): 0.450691016944653
# (16, 29, 29): 0.40446053690438927
#
# Approximating hitting prob for (17, 28, 87)
# (17, 28, 87): 0.5364732219662345
# (16, 29, 87): 0.5354223130734442
#
# Approximating hitting prob for (16, 30, 30)
# (16, 30, 30): 0.40692635827340995
# (15, 31, 30): 0.48601232000914507
#
# Approximating hitting prob for (16, 30, 76)
# (16, 30, 76): 0.5331293350131605
# (15, 31, 76): 0.5696314937823813
#
# Approximating hitting prob for (16, 30, 90)
# (16, 30, 90): 0.5365545911050882
# (15, 31, 90): 0.5710555295678631
#
# Approximating hitting prob for (16, 31, 31)
# (16, 31, 31): 0.4083547124385222
# (15, 32, 31): 0.4858121847058265
#
# Approximating hitting prob for (16, 31, 78)
# (16, 31, 78): 0.5336384909534596
# (15, 32, 78): 0.5735835550929295
#
# Approximating hitting prob for (16, 31, 93)
# (16, 31, 93): 0.5378007795906751
# (15, 32, 93): 0.5720630924789214
#
# Approximating hitting prob for (16, 32, 32)
# (16, 32, 32): 0.4285714285714286
# (15, 33, 32): 0.48883297601742354
#
# Approximating hitting prob for (16, 11, 33)
# (16, 11, 33): 0.35277236550325936
# (15, 12, 33): 0.3726797025822906
#
# Approximating hitting prob for (16, 33, 33)
# (16, 33, 33): 0.4341300809805498
# (15, 34, 33): 0.4906878737754206
#
# Approximating hitting prob for (16, 34, 34)
# (16, 34, 34): 0.4349301594471646
# (15, 35, 34): 0.4927485147552157
#
# Approximating hitting prob for (16, 35, 35)
# (16, 35, 35): 0.4359614896449618
# (15, 36, 35): 0.4938428137410562
#
# Approximating hitting prob for (16, 36, 36)
# (16, 36, 36): 0.4381003152708904
# (15, 37, 36): 0.49524392755352115
#
# Approximating hitting prob for (16, 36, 41)
# (16, 36, 41): 0.5002321590671912
# (15, 37, 41): 0.5029772527487377
#
# Approximating hitting prob for (16, 37, 37)
# (16, 37, 37): 0.4394351570727352
# (15, 38, 37): 0.49685780940217755
#
# Approximating hitting prob for (16, 37, 42)
# (16, 37, 42): 0.49920084239506557
# (15, 38, 42): 0.5039866977220121
#
# Approximating hitting prob for (16, 38, 38)
# (16, 38, 38): 0.4409467649855609
# (15, 39, 38): 0.4979981720586235
#
# Approximating hitting prob for (16, 38, 43)
# (16, 38, 43): 0.502296082401568
# (15, 39, 43): 0.5052518510530816
#
# Approximating hitting prob for (16, 13, 39)
# (16, 13, 39): 0.37036697182646755
# (15, 14, 39): 0.38731509629337985
#
# Approximating hitting prob for (16, 39, 39)
# (16, 39, 39): 0.4416752742409207
# (15, 40, 39): 0.49969702341661626
#
# Approximating hitting prob for (16, 39, 44)
# (16, 39, 44): 0.5031946824431345
# (15, 40, 44): 0.5071521513552278
#
# Approximating hitting prob for (16, 40, 40)
# (16, 40, 40): 0.44255325660645745
# (15, 41, 40): 0.5008079827255693
#
# Approximating hitting prob for (16, 41, 41)
# (16, 41, 41): 0.44535099424553876
# (15, 42, 41): 0.502210009252971
#
# Approximating hitting prob for (17, 14, 41)
# (17, 14, 41): 0.37920925470622896
# (16, 15, 41): 0.3864921159504941
#
# Approximating hitting prob for (17, 41, 42)
# (17, 41, 42): 0.49515663023990397
# (16, 42, 42): 0.44625991701326856
#
# Approximating hitting prob for (17, 41, 47)
# (17, 41, 47): 0.5061232747782886
# (16, 42, 47): 0.5060577797539169
#
# Approximating hitting prob for (17, 42, 43)
# (17, 42, 43): 0.49672130923357605
# (16, 43, 43): 0.447223789992256
#
# Approximating hitting prob for (17, 43, 44)
# (17, 43, 44): 0.4978097808321997
# (16, 44, 44): 0.44820689847484574
#
# Approximating hitting prob for (16, 45, 45)
# (16, 45, 45): 0.44938607610324555
# (15, 46, 45): 0.526111325745607
#
# Approximating hitting prob for (16, 45, 58)
# (16, 45, 58): 0.528895160602941
# (15, 46, 58): 0.5478436566907252
#
# Approximating hitting prob for (16, 46, 46)
# (16, 46, 46): 0.4502250894161175
# (15, 47, 46): 0.5286999938377417
#
# Approximating hitting prob for (16, 46, 60)
# (16, 46, 60): 0.5296194711867167
# (15, 47, 60): 0.5562569498118839
#
# Approximating hitting prob for (16, 47, 47)
# (16, 47, 47): 0.45086030319930753
# (15, 48, 47): 0.5297340640115955
#
# Approximating hitting prob for (16, 47, 52)
# (16, 47, 52): 0.5227683343090042
# (15, 48, 52): 0.5369211822144141
#
# Approximating hitting prob for (16, 47, 62)
# (16, 47, 62): 0.5301263625686753
# (15, 48, 62): 0.5572083111981626
#
# Approximating hitting prob for (16, 48, 48)
# (16, 48, 48): 0.46941896024464413
# (15, 49, 48): 0.530502075127264
#
# Approximating hitting prob for (16, 49, 49)
# (16, 49, 49): 0.4748710064747097
# (15, 50, 49): 0.5315603049548098
#
# Approximating hitting prob for (16, 50, 50)
# (16, 50, 50): 0.47550950914768597
# (15, 51, 50): 0.5326679280848755
#
# Approximating hitting prob for (16, 51, 51)
# (16, 51, 51): 0.4762231428462376
# (15, 52, 51): 0.533426932672023
#
# Approximating hitting prob for (16, 52, 52)
# (16, 52, 52): 0.4769314080948765
# (15, 53, 52): 0.5368709663629055
#
# Approximating hitting prob for (16, 53, 53)
# (16, 53, 53): 0.47751640921248373
# (15, 54, 53): 0.539355237165937
#
# Approximating hitting prob for (16, 53, 58)
# (16, 53, 58): 0.5381664770143905
# (15, 54, 58): 0.5451900236234538
#
# Approximating hitting prob for (16, 18, 54)
# (16, 18, 54): 0.5024713472190601
# (15, 19, 54): 0.5162724034211803
#
# Approximating hitting prob for (16, 54, 54)
# (16, 54, 54): 0.4786704064457213
# (15, 55, 54): 0.5397857621609486
#
# Approximating hitting prob for (16, 55, 55)
# (16, 55, 55): 0.4791113977999834
# (15, 56, 55): 0.5404443671409889
#
# Approximating hitting prob for (16, 56, 56)
# (16, 56, 56): 0.4821387523777809
# (15, 57, 56): 0.5409513966132966
#
# Approximating hitting prob for (17, 19, 56)
# (17, 19, 56): 0.5100655854455413
# (16, 20, 56): 0.5132337322743433
#
# Approximating hitting prob for (17, 56, 57)
# (17, 56, 57): 0.5316505675580242
# (16, 57, 57): 0.48414107761188435
#
# Approximating hitting prob for (17, 57, 58)
# (17, 57, 58): 0.5326874357669772
# (16, 58, 58): 0.4845083068057355
#
# Approximating hitting prob for (17, 57, 63)
# (17, 57, 63): 0.5464928518824756
# (16, 58, 63): 0.5460424854979463
#
# Approximating hitting prob for (17, 58, 59)
# (17, 58, 59): 0.5333282883736272
# (16, 59, 59): 0.4850627519181905
#
# Approximating hitting prob for (17, 46, 59)
# (17, 46, 59): 0.5297382787997394
# (16, 47, 59): 0.5335409065408218
#
# Approximating hitting prob for (17, 59, 60)
# (17, 59, 60): 0.53673429571535
# (16, 60, 60): 0.48540954999808766
#
# Approximating hitting prob for (17, 60, 61)
# (17, 60, 61): 0.5391563125267506
# (16, 61, 61): 0.4860474489181683
#
# Approximating hitting prob for (16, 62, 62)
# (16, 62, 62): 0.48649121241909515
# (15, 63, 62): 0.5477524016471386
#
# Approximating hitting prob for (17, 21, 62)
# (17, 21, 62): 0.5153289071342173
# (16, 22, 62): 0.5199325679718331
#
# Approximating hitting prob for (17, 62, 63)
# (17, 62, 63): 0.5401342851785457
# (16, 63, 63): 0.4868869676408793
#
# Approximating hitting prob for (17, 62, 68)
# (17, 62, 68): 0.5515945885925219
# (16, 63, 68): 0.5504199192237839
#
# Approximating hitting prob for (17, 63, 64)
# (17, 63, 64): 0.5405727494291163
# (16, 64, 64): 0.49131100605898986
#
# Approximating hitting prob for (17, 64, 65)
# (17, 64, 65): 0.5409803716960413
# (16, 65, 65): 0.4919649948744795
#
# Approximating hitting prob for (16, 66, 66)
# (16, 66, 66): 0.4922082674917106
# (15, 67, 66): 0.5496767441104364
#
# Approximating hitting prob for (16, 67, 67)
# (16, 67, 67): 0.4925486161001296
# (15, 68, 67): 0.5502741971009918
#
# Approximating hitting prob for (16, 68, 68)
# (16, 68, 68): 0.49280520932956623
# (15, 69, 68): 0.5504876274192049
#
# Approximating hitting prob for (17, 23, 68)
# (17, 23, 68): 0.5202423986440831
# (16, 24, 68): 0.5263516920837397
# Approximating hitting prob for (17, 68, 69)
# (17, 68, 69): 0.5470850392177034
# (16, 69, 69): 0.493057633675599
#
# Approximating hitting prob for (17, 68, 74)
# (17, 68, 74): 0.5567039953870236
# (16, 69, 74): 0.5550327120153654
#
# Approximating hitting prob for (17, 68, 77)
# (17, 68, 77): 0.5618184831564245
# (16, 69, 77): 0.5614817542911682
#
# Approximating hitting prob for (17, 69, 70)
# (17, 69, 70): 0.5473286854358144
# (16, 70, 70): 0.4939735020559633
#
# Approximating hitting prob for (17, 69, 75)
# (17, 69, 75): 0.557146743510115
# (16, 70, 75): 0.5554738011140099
#
# Approximating hitting prob for (17, 69, 78)
# (17, 69, 78): 0.5621511846724776
# (16, 70, 78): 0.5621059732858112
#
# Approximating hitting prob for (17, 70, 71)
# (17, 70, 71): 0.547565673603665
# (16, 71, 71): 0.4942706001967058
#
# Approximating hitting prob for (17, 70, 76)
# (17, 70, 76): 0.5572961856994291
# (16, 71, 76): 0.5557421154302415
#
# Approximating hitting prob for (16, 72, 72)
# (16, 72, 72): 0.4943291983296177
# (15, 73, 72): 0.5519326104667903
#
# Approximating hitting prob for (16, 72, 77)
# (16, 72, 77): 0.5560418864859648
# (15, 73, 77): 0.5593800392197028
#
# Approximating hitting prob for (16, 73, 73)
# (16, 73, 73): 0.4953802924201565
# (15, 74, 73): 0.552168719491243
#
# Approximating hitting prob for (16, 73, 78)
# (16, 73, 78): 0.5563436235592438
# (15, 74, 78): 0.5595587878345071
#
# Approximating hitting prob for (16, 29, 74)
# (16, 29, 74): 0.5324865172144486
# (15, 30, 74): 0.5540603868839801
#
# Approximating hitting prob for (16, 74, 74)
# (16, 74, 74): 0.4955753951308321
# (15, 75, 74): 0.554217598000856
#
# Approximating hitting prob for (16, 74, 79)
# (16, 74, 79): 0.556413975400308
# (15, 75, 79): 0.5615792618643033
#
# Approximating hitting prob for (16, 75, 75)
# (16, 75, 75): 0.4958483280369516
# (15, 76, 75): 0.556567139713511
#
# Approximating hitting prob for (17, 30, 75)
# (17, 30, 75): 0.5341850688121413
# (16, 31, 75): 0.5406014557487419
#
# Approximating hitting prob for (17, 75, 76)
# (17, 75, 76): 0.5495719965600047
# (16, 76, 76): 0.4961191780067134
#
# Approximating hitting prob for (17, 75, 78)
# (17, 75, 78): 0.5529541479066534
# (16, 76, 78): 0.5529237679716587
#
# Approximating hitting prob for (17, 76, 77)
# (17, 76, 77): 0.5501388582280344
# (16, 77, 77): 0.49635202619784397
#
# Approximating hitting prob for (17, 76, 79)
# (17, 76, 79): 0.5531828985021912
# (16, 77, 79): 0.5531527431733536
#
# Approximating hitting prob for (17, 76, 85)
# (17, 76, 85): 0.5663264086964862
# (16, 77, 85): 0.5660778895900463
#
# Approximating hitting prob for (17, 31, 77)
# (17, 31, 77): 0.5352109499313725
# (16, 32, 77): 0.5539942567500559
#
# Approximating hitting prob for (17, 77, 78)
# (17, 77, 78): 0.5503341475602233
# (16, 78, 78): 0.4966102280611972
#
# Approximating hitting prob for (17, 77, 86)
# (17, 77, 86): 0.5666645456105988
# (16, 78, 86): 0.5663188956918613
#
# Approximating hitting prob for (17, 78, 79)
# (17, 78, 79): 0.550863778893775
# (16, 79, 79): 0.4967576272647007
#
# Approximating hitting prob for (17, 78, 87)
# (17, 78, 87): 0.5669411703132213
# (16, 79, 87): 0.5665511884658574
#
# Approximating hitting prob for (17, 79, 80)
# (17, 79, 80): 0.551111607658544
# (16, 80, 80): 0.5005600203855535
#
# Approximating hitting prob for (16, 81, 81)
# (16, 81, 81): 0.5014076684201466
# (15, 82, 81): 0.5581296789233481
#
# Approximating hitting prob for (16, 81, 86)
# (16, 81, 86): 0.5626021458258553
# (15, 82, 86): 0.5630002604371341
#
# Approximating hitting prob for (16, 82, 82)
# (16, 82, 82): 0.5015200574038023
# (15, 83, 82): 0.5582880278840489
#
# Approximating hitting prob for (16, 82, 87)
# (16, 82, 87): 0.5628119188088262
# (15, 83, 87): 0.5634452076263355
#
# Approximating hitting prob for (16, 83, 83)
# (16, 83, 83): 0.5016884462172645
# (15, 84, 83): 0.5584417365279389
#
# Approximating hitting prob for (17, 28, 83)
# (17, 28, 83): 0.5349984845977509
# (16, 29, 83): 0.5433652141415869
#
# Approximating hitting prob for (17, 83, 84)
# (17, 83, 84): 0.5520594704231941
# (16, 84, 84): 0.501925664345551
#
# Approximating hitting prob for (17, 83, 89)
# (17, 83, 89): 0.5631818967703549
# (16, 84, 89): 0.5631607835667369
#
# Approximating hitting prob for (17, 84, 85)
# (17, 84, 85): 0.5540978481542037
# (16, 85, 85): 0.5021416299295298
#
# Approximating hitting prob for (17, 84, 90)
# (17, 84, 90): 0.5633029594627005
# (16, 85, 90): 0.5632688993870562
#
# Approximating hitting prob for (17, 85, 86)
# (17, 85, 86): 0.5564278070836478
# (16, 86, 86): 0.502291089468979
#
# Approximating hitting prob for (16, 86, 91)
# (16, 86, 91): 0.5632653966071707
# (15, 87, 91): 0.5660537985225959
#
# Approximating hitting prob for (16, 86, 94)
# (16, 86, 94): 0.5699234854908964
# (15, 87, 94): 0.5707791033742851
#
# Approximating hitting prob for (17, 29, 86)
# (17, 29, 86): 0.5392690338105889
# (16, 30, 86): 0.54558008510331
#
# Approximating hitting prob for (17, 86, 87)
# (17, 86, 87): 0.5568727855653705
# (16, 87, 87): 0.5025069886430613
#
# Approximating hitting prob for (16, 87, 90)
# (16, 87, 90): 0.5610957741960009
# (15, 88, 90): 0.5621397868021553
#
# Approximating hitting prob for (16, 87, 92)
# (16, 87, 92): 0.5637378552372473
# (15, 88, 92): 0.5661734702598008
#
# Approximating hitting prob for (16, 87, 95)
# (16, 87, 95): 0.5701273335450453
# (15, 88, 95): 0.5710797498505916
#
# Approximating hitting prob for (16, 88, 88)
# (16, 88, 88): 0.5026381251870221
# (15, 89, 88): 0.5589500129388055
#
# Approximating hitting prob for (16, 88, 90)
# (16, 88, 90): 0.5595534805765084
# (15, 89, 90): 0.5609048981192853
#
# Approximating hitting prob for (16, 88, 91)
# (16, 88, 91): 0.5612974673515694
# (15, 89, 91): 0.562621668374473
#
# Approximating hitting prob for (16, 88, 93)
# (16, 88, 93): 0.5638767064336879
# (15, 89, 93): 0.5663498747336545
#
# Approximating hitting prob for (16, 89, 89)
# (16, 89, 89): 0.5028962789726098
# (15, 90, 89): 0.5609048981192853
#
# Approximating hitting prob for (17, 88, 90)
# (17, 88, 90): 0.5584795407185211
# (16, 89, 90): 0.5584117802652058
#
# Approximating hitting prob for (17, 88, 91)
# (17, 88, 91): 0.5602143078425824
# (16, 89, 91): 0.5597378882526495
#
# Approximating hitting prob for (17, 88, 92)
# (17, 88, 92): 0.5615535120589333
# (16, 89, 92): 0.5614179574213097
#
# Approximating hitting prob for (17, 88, 94)
# (17, 88, 94): 0.5662229072051193
# (16, 89, 94): 0.5640674906926589
#
# Approximating hitting prob for (17, 15, 89)
# (17, 15, 89): 0.41858306509305093
# (16, 16, 89): 0.4839356602228837
#
# Approximating hitting prob for (16, 90, 90)
# (16, 90, 90): 0.5030265686999019
# (15, 91, 90): 0.562932143611496
#
# Approximating hitting prob for (17, 89, 91)
# (17, 89, 91): 0.5587179869195241
# (16, 90, 91): 0.5586154853567448
#
# Approximating hitting prob for (17, 89, 92)
# (17, 89, 92): 0.5604949419252231
# (16, 90, 92): 0.5598384942016558
#
# Approximating hitting prob for (17, 89, 93)
# (17, 89, 93): 0.5617336043203679
# (16, 90, 93): 0.561268119993117
#
# Approximating hitting prob for (17, 89, 95)
# (17, 89, 95): 0.5663764583671368
# (16, 90, 95): 0.5642069735073888
#
# Approximating hitting prob for (17, 90, 91)
# (17, 90, 91): 0.5576326519804494
# (16, 91, 91): 0.5032325814972145
#
# Approximating hitting prob for (16, 91, 93)
# (16, 91, 93): 0.560051816312867
# (15, 92, 93): 0.5635299764183354
#
# Approximating hitting prob for (16, 91, 94)
# (16, 91, 94): 0.5617667897528911
# (15, 92, 94): 0.5645818776170406
#
# Approximating hitting prob for (16, 91, 96)
# (16, 91, 96): 0.5659435910666311
# (15, 92, 96): 0.5688225520784234
#
# Approximating hitting prob for (16, 92, 92)
# (16, 92, 92): 0.5033410974106731
# (15, 93, 92): 0.5635299764183354
#
# Approximating hitting prob for (17, 91, 93)
# (17, 91, 93): 0.5590415634614743
# (16, 92, 93): 0.5589414734960334
#
# Approximating hitting prob for (17, 91, 94)
# (17, 91, 94): 0.560832734780964
# (16, 92, 94): 0.5599162198397583
#
# Approximating hitting prob for (17, 91, 95)
# (17, 91, 95): 0.5620684179169347
# (16, 92, 95): 0.5618748201900682
#
# Approximating hitting prob for (17, 91, 97)
# (17, 91, 97): 0.5667227420362749
# (16, 92, 97): 0.5663908146305937
#
# Approximating hitting prob for (16, 93, 93)
# (16, 93, 93): 0.5034527373537426
# (15, 94, 93): 0.5636852300305549
#
# Approximating hitting prob for (17, 92, 94)
# (17, 92, 94): 0.5592582811374768
# (16, 93, 94): 0.5590403595322886
#
# Approximating hitting prob for (17, 92, 95)
# (17, 92, 95): 0.5609732726690269
# (16, 93, 95): 0.560327399898442
#
# Approximating hitting prob for (17, 92, 98)
# (17, 92, 98): 0.5669295079401167
# (16, 93, 98): 0.5665557236652498
# Approximating hitting prob for (17, 93, 94)
# (17, 93, 94): 0.5581541760383898
# (16, 94, 94): 0.5035998601058936
#
# Approximating hitting prob for (16, 94, 99)
# (16, 94, 99): 0.5666894071160092
# (15, 95, 99): 0.5692549333242215
#
# Approximating hitting prob for (16, 95, 95)
# (16, 95, 95): 0.5036711719120154
# (15, 96, 95): 0.5640361830668642
#
# Approximating hitting prob for (16, 95, 100)
# (16, 95, 100): 0.5667696702527917
# (15, 96, 100): 0.569419134942688
#
# Approximating hitting prob for (16, 96, 96)
# (16, 96, 96): 0.5062234648424173
# (15, 97, 96): 0.5642047443359095
#
# Approximating hitting prob for (16, 97, 97)
# (16, 97, 97): 0.5076757708315572
# (15, 98, 97): 0.5644858417344442
#
# Approximating hitting prob for (16, 98, 98)
# (16, 98, 98): 0.5077976168378497
# (15, 99, 98): 0.5646616012456073
#
# Approximating hitting prob for (16, 99, 99)
# (16, 99, 99): 0.5079553317809574
# (15, 100, 99): 0.5650149906293905
#
# Approximating hitting prob for (16, 100, 100)
# (16, 100, 100): 0.5081098880182108
# (15, 101, 100): 0.5652008984741467
#
# (17, 4, 4): 209045991451108908036703681774500862941693252841/5080208982897848758640055381292701264176397129219
# (16, 5, 4): 2001357106099451617320018106589147221157419884191/25401044914489243793200276906463506320881985646095
#
# Approximating hitting prob for (17, 5, 5)
# (17, 5, 5): 0.06461689400054516
# (16, 6, 5): 0.10519337918793148
#
# Approximating hitting prob for (17, 7, 7)
# (17, 7, 7): 0.10512934794655172
# (16, 8, 7): 0.13901840222160564
#
# Approximating hitting prob for (17, 8, 8)
# (17, 8, 8): 0.11034321985254757
# (16, 9, 8): 0.1997267047560071
#
# Approximating hitting prob for (17, 8, 16)
# (17, 8, 16): 0.21093436273745234
# (16, 9, 16): 0.29814813872127915
#
# Approximating hitting prob for (17, 8, 24)
# (17, 8, 24): 0.29419769394164136
# (16, 9, 24): 0.32315322398069773
#
# Approximating hitting prob for (17, 10, 10)
# (17, 10, 10): 0.16861899725525983
# (16, 11, 10): 0.22302319549902538
#
# Approximating hitting prob for (17, 10, 20)
# (17, 10, 20): 0.29805594094024607
# (16, 11, 20): 0.32407210692445815
#
# Approximating hitting prob for (17, 11, 11)
# (17, 11, 11): 0.17804128159557184
# (16, 12, 11): 0.23320730800934306
#
# Approximating hitting prob for (17, 11, 22)
# (17, 11, 22): 0.30927930256657327
# (16, 12, 22): 0.3292674672928731
#
# Approximating hitting prob for (17, 12, 12)
# (17, 12, 12): 0.1885192151996715
# (16, 13, 12): 0.24516716684388984
#
# Approximating hitting prob for (17, 12, 24)
# (17, 12, 24): 0.3156548113622559
# (16, 13, 24): 0.33747596893218484
#
# Approximating hitting prob for (17, 12, 36)
# (17, 12, 36): 0.3542957766263218
# (16, 13, 36): 0.3770993522240998
#
# Approximating hitting prob for (17, 13, 13)
# (17, 13, 13): 0.2010491048696937
# (16, 14, 13): 0.2531351691522615
#
# Approximating hitting prob for (17, 13, 26)
# (17, 13, 26): 0.32161953104574054
# (16, 14, 26): 0.34331069375227835
#
# Approximating hitting prob for (17, 14, 14)
# (17, 14, 14): 0.20574574337368526
# (16, 15, 14): 0.2608944581380093
#
# Approximating hitting prob for (17, 14, 28)
# (17, 14, 28): 0.3260373746853039
# (16, 15, 28): 0.3549377449209113
#
# Approximating hitting prob for (17, 14, 42)
# (17, 14, 42): 0.37109999883506134
# (16, 15, 42): 0.3878400113857056
#
# Approximating hitting prob for (17, 15, 15)
# (17, 15, 15): 0.2144030050658334
# (16, 16, 15): 0.32126946596978173
#
# Approximating hitting prob for (17, 15, 30)
# (17, 15, 30): 0.33068534322226345
# (16, 16, 30): 0.4177492826946867
#
# Approximating hitting prob for (17, 15, 45)
# (17, 15, 45): 0.3771747962574618
# (16, 16, 45): 0.45096918510820333
#
# Approximating hitting prob for (17, 16, 16)
# (17, 16, 16): 0.219140437838398
# (16, 17, 16): 0.39042978108059795
#
# Approximating hitting prob for (17, 16, 32)
# (17, 16, 32): 0.33253487300332357
# (16, 17, 32): 0.46888894205662174
#
# Approximating hitting prob for (17, 16, 48)
# (17, 16, 48): 0.3812229671885688
# (16, 17, 48): 0.5051919324841517
#
# Approximating hitting prob for (17, 16, 96)
# (17, 16, 96): 0.4182075509496599
# (16, 17, 96): 0.5398019629675438
#
# Approximating hitting prob for (17, 19, 19)
# (17, 19, 19): 0.3595891658281894
# (16, 20, 19): 0.41147128925249893
#
# Approximating hitting prob for (18, 10, 19)
# (18, 10, 19): 0.30435223792264193
# (17, 11, 19): 0.3147764548283276
#
# Approximating hitting prob for (18, 19, 20)
# (18, 19, 20): 0.40360476518776256
# (17, 20, 20): 0.36342365070381427
#
# Approximating hitting prob for (18, 19, 60)
# (18, 19, 60): 0.5105089912833427
# (17, 20, 60): 0.5048655469504136
#
# Approximating hitting prob for (18, 19, 77)
# (18, 19, 77): 0.52541728365565
# (17, 20, 77): 0.5249399626711988
#
# Approximating hitting prob for (18, 7, 20)
# (18, 7, 20): 0.2857336814042574
# (17, 8, 20): 0.29417604203749875
#
# Approximating hitting prob for (18, 20, 21)
# (18, 20, 21): 0.4065723085192168
# (17, 21, 21): 0.3661000307381755
#
# Approximating hitting prob for (18, 20, 63)
# (18, 20, 63): 0.5125085278533942
# (17, 21, 63): 0.506738402209587
#
# Approximating hitting prob for (18, 20, 80)
# (18, 20, 80): 0.5274187303121192
# (17, 21, 80): 0.5267882913846357
#
# Approximating hitting prob for (17, 22, 22)
# (17, 22, 22): 0.37107909195716354
# (16, 23, 22): 0.4233670196276392
#
# Approximating hitting prob for (17, 22, 66)
# (17, 22, 66): 0.509441271835688
# (16, 23, 66): 0.523061453332028
#
# Approximating hitting prob for (17, 22, 83)
# (17, 22, 83): 0.5290011231271463
# (16, 23, 83): 0.5333535733058424
#
# Approximating hitting prob for (17, 23, 23)
# (17, 23, 23): 0.37423710135001675
# (16, 24, 23): 0.4263162636266649
#
# Approximating hitting prob for (17, 23, 69)
# (17, 23, 69): 0.5117381831213681
# (16, 24, 69): 0.5264522452942543
#
# Approximating hitting prob for (18, 8, 23)
# (18, 8, 23): 0.296255108675939
# (17, 9, 23): 0.3150339592692581
#
# Approximating hitting prob for (17, 24, 24)
# (17, 24, 24): 0.3767109109341453
# (16, 25, 24): 0.4437261939944576
#
# Approximating hitting prob for (17, 24, 72)
# (17, 24, 72): 0.5140149994042696
# (16, 25, 72): 0.5289189911749559
#
# Approximating hitting prob for (17, 25, 25)
# (17, 25, 25): 0.37802328329454243
# (16, 26, 25): 0.44616133347321124
#
# Approximating hitting prob for (17, 25, 75)
# (17, 25, 75): 0.5156834135309943
# (16, 26, 75): 0.5344567047271799
#
# Approximating hitting prob for (17, 25, 91)
# (17, 25, 91): 0.5339488705452969
# (16, 26, 91): 0.5437283367767357
#
# Approximating hitting prob for (17, 25, 92)
# (17, 25, 92): 0.5338404760314089
# (16, 26, 92): 0.5439532256513905
#
# Approximating hitting prob for (18, 13, 25)
# (18, 13, 25): 0.3281989846859334
# (17, 14, 25): 0.3388092958729685
#
# Approximating hitting prob for (18, 25, 26)
# (18, 25, 26): 0.42351087834140033
# (17, 26, 26): 0.3925855782926289
#
# Approximating hitting prob for (18, 26, 27)
# (18, 26, 27): 0.42627711928802864
# (17, 27, 27): 0.39374943027699283
#
# Approximating hitting prob for (18, 26, 81)
# (18, 26, 81): 0.5293538901192832
# (17, 27, 81): 0.5250838006629462
#
# Approximating hitting prob for (17, 28, 28)
# (17, 28, 28): 0.395238589861771
# (16, 29, 28): 0.45639069613909294
#
# Approximating hitting prob for (17, 28, 84)
# (17, 28, 84): 0.5263344067909682
# (16, 29, 84): 0.5444758928749472
#
# Approximating hitting prob for (17, 28, 100)
# (17, 28, 100): 0.5444811394735837
# (16, 29, 100): 0.5514573239012619
#
# Approximating hitting prob for (17, 29, 29)
# (17, 29, 29): 0.40114838048980017
# (16, 30, 29): 0.45823621705256
#
# Approximating hitting prob for (17, 29, 87)
# (17, 29, 87): 0.5304892318379425
# (16, 30, 87): 0.545594894012935
#
# Approximating hitting prob for (17, 10, 30)
# (17, 10, 30): 0.3377979054942198
# (16, 11, 30): 0.35670028681801996
#
# Approximating hitting prob for (18, 15, 29)
# (18, 15, 29): 0.3389834233458751
# (17, 16, 29): 0.3556520492628715
#
# Approximating hitting prob for (18, 29, 30)
# (18, 29, 30): 0.4488624840391733
# (17, 30, 30): 0.4034849352228332
#
# Approximating hitting prob for (18, 29, 90)
# (18, 29, 90): 0.5357900760746058
# (17, 30, 90): 0.5347824775853248
#
# Approximating hitting prob for (18, 30, 31)
# (18, 30, 31): 0.45285520984362343
# (17, 31, 31): 0.40460837643143877
#
# Approximating hitting prob for (18, 30, 93)
# (18, 30, 93): 0.5384765656401298
# (17, 31, 93): 0.5355878730399785
#
# Approximating hitting prob for (17, 32, 32)
# (17, 32, 32): 0.407190299659324
# (16, 33, 32): 0.4858927245710675
#
# Approximating hitting prob for (17, 32, 81)
# (17, 32, 81): 0.5332080138741222
# (16, 33, 81): 0.5696093314319076
#
# Approximating hitting prob for (17, 32, 96)
# (17, 32, 96): 0.5367719552375875
# (16, 33, 96): 0.5709418427143382
# Approximating hitting prob for (17, 11, 33)
# (17, 11, 33): 0.346921683078167
# (16, 12, 33): 0.3636492699848204
#
# Approximating hitting prob for (17, 33, 33)
# (17, 33, 33): 0.40840353966570936
# (16, 34, 33): 0.48568468091633304
#
# Approximating hitting prob for (17, 33, 83)
# (17, 33, 83): 0.5336649245359243
# (16, 34, 83): 0.5734767583047097
#
# Approximating hitting prob for (17, 33, 99)
# (17, 33, 99): 0.5378562783888631
# (16, 34, 99): 0.571939248840306
#
# Approximating hitting prob for (17, 34, 34)
# (17, 34, 34): 0.4285714285714286
# (16, 35, 34): 0.48814809233570483
#
# Approximating hitting prob for (17, 35, 35)
# (17, 35, 35): 0.43406443191613914
# (16, 36, 35): 0.48972968087619434
#
# Approximating hitting prob for (18, 12, 35)
# (18, 12, 35): 0.35699291550748863
# (17, 13, 35): 0.36439227911649263
#
# Approximating hitting prob for (18, 35, 36)
# (18, 35, 36): 0.47269730129718307
# (17, 36, 36): 0.4348495798730609
#
# Approximating hitting prob for (18, 36, 37)
# (18, 36, 37): 0.4857783745263405
# (17, 37, 37): 0.43587175514412113
#
# Approximating hitting prob for (18, 37, 38)
# (18, 37, 38): 0.4853601738382722
# (17, 38, 38): 0.4371126396375207
#
# Approximating hitting prob for (18, 38, 39)
# (18, 38, 39): 0.48790915862183537
# (17, 39, 39): 0.4389477991897947
#
# Approximating hitting prob for (18, 38, 44)
# (18, 38, 44): 0.4996061845812571
# (17, 39, 44): 0.49873694566172855
#
# Approximating hitting prob for (18, 39, 40)
# (18, 39, 40): 0.4893291582047279
# (17, 40, 40): 0.44063887613047964
#
# Approximating hitting prob for (18, 40, 41)
# (18, 40, 41): 0.49095088226720224
# (17, 41, 41): 0.44139524678259273
#
# Approximating hitting prob for (17, 42, 42)
# (17, 42, 42): 0.441877595830281
# (16, 43, 42): 0.5001251646486778
#
# Approximating hitting prob for (17, 42, 50)
# (17, 42, 50): 0.5069525206945061
# (16, 43, 50): 0.5225276961563354
#
# Approximating hitting prob for (17, 43, 43)
# (17, 43, 43): 0.44501762502830305
# (16, 44, 43): 0.5010812239793271
#
# Approximating hitting prob for (17, 44, 44)
# (17, 44, 44): 0.4457576855400811
# (16, 45, 44): 0.5023362515594243
#
# Approximating hitting prob for (18, 15, 44)
# (18, 15, 44): 0.3800456990226986
# (17, 16, 44): 0.38721198910259397
#
# Approximating hitting prob for (18, 44, 45)
# (18, 44, 45): 0.49633613308656166
# (17, 45, 45): 0.4465271211211485
#
# Approximating hitting prob for (18, 44, 56)
# (18, 44, 56): 0.5257412408408483
# (17, 45, 56): 0.5254786841463105
#
# Approximating hitting prob for (18, 45, 46)
# (18, 45, 46): 0.49709874500346035
# (17, 46, 46): 0.44745908601310963
#
# Approximating hitting prob for (18, 46, 47)
# (18, 46, 47): 0.4988987539620328
# (17, 47, 47): 0.448803609721461
#
# Approximating hitting prob for (18, 46, 60)
# (18, 46, 60): 0.5284781062673811
# (17, 47, 60): 0.5281888889502253
#
# Approximating hitting prob for (17, 48, 48)
# (17, 48, 48): 0.4494691131773285
# (16, 49, 48): 0.5260052229674314
#
# Approximating hitting prob for (17, 48, 62)
# (17, 48, 62): 0.5290045013080626
# (16, 49, 62): 0.5478418067646228
#
# Approximating hitting prob for (17, 49, 49)
# (17, 49, 49): 0.4503379410148645
# (16, 50, 49): 0.5284910651504632
#
# Approximating hitting prob for (17, 49, 64)
# (17, 49, 64): 0.5297020995866109
# (16, 50, 64): 0.5561998643047715
#
# Approximating hitting prob for (17, 50, 50)
# (17, 50, 50): 0.45089301042448776
# (16, 51, 50): 0.5295674951291937
#
# Approximating hitting prob for (17, 50, 66)
# (17, 50, 66): 0.5301457096165415
# (16, 51, 66): 0.557169785838269
#
# Approximating hitting prob for (17, 51, 51)
# (17, 51, 51): 0.46941896024464413
# (16, 52, 51): 0.5301166641087178
#
# Approximating hitting prob for (17, 52, 52)
# (17, 52, 52): 0.47483872151507334
# (16, 53, 52): 0.5311007690397566
#
# Approximating hitting prob for (17, 53, 53)
# (17, 53, 53): 0.47536045181047354
# (16, 54, 53): 0.5320180674080556
#
# Approximating hitting prob for (17, 54, 54)
# (17, 54, 54): 0.4761697286180884
# (16, 55, 54): 0.5330218835765799
#
# Approximating hitting prob for (17, 55, 55)
# (17, 55, 55): 0.47654949609407077
# (16, 56, 55): 0.5335513471896995
#
# Approximating hitting prob for (17, 56, 56)
# (17, 56, 56): 0.47738324270537597
# (16, 57, 56): 0.5388043124594952
#
# Approximating hitting prob for (17, 19, 57)
# (17, 19, 57): 0.5020617341723929
# (16, 20, 57): 0.5154870663763541
#
# Approximating hitting prob for (17, 57, 57)
# (17, 57, 57): 0.47855909900720683
# (16, 58, 57): 0.5393895339865601
#
# Approximating hitting prob for (17, 58, 58)
# (17, 58, 58): 0.47900198188169596
# (16, 59, 58): 0.539974498937872
#
# Approximating hitting prob for (17, 59, 59)
# (17, 59, 59): 0.47924330888099936
# (16, 60, 59): 0.5404947775207429
#
# Approximating hitting prob for (18, 20, 59)
# (18, 20, 59): 0.5097846790810922
# (17, 21, 59): 0.5129115322895009
#
# Approximating hitting prob for (18, 59, 60)
# (18, 59, 60): 0.5314003369973536
# (17, 60, 60): 0.4840443716836795
#
# Approximating hitting prob for (18, 60, 61)
# (18, 60, 61): 0.5323159486367373
# (17, 61, 61): 0.4843463260236462
#
# Approximating hitting prob for (18, 61, 62)
# (18, 61, 62): 0.5329934751309147
# (17, 62, 62): 0.48462799593337963
#
# Approximating hitting prob for (17, 63, 63)
# (17, 63, 63): 0.48515113228085455
# (16, 64, 63): 0.5445002865090376
#
# Approximating hitting prob for (17, 64, 64)
# (17, 64, 64): 0.48570112763225537
# (16, 65, 64): 0.5471317113699506
#
# Approximating hitting prob for (17, 64, 72)
# (17, 64, 72): 0.5536758888532852
# (16, 65, 72): 0.5578154162710348
#
# Approximating hitting prob for (17, 65, 65)
# (17, 65, 65): 0.4860924963990568
# (16, 66, 65): 0.5473927796561179
#
# Approximating hitting prob for (17, 65, 73)
# (17, 65, 73): 0.5542602152555304
# (16, 66, 73): 0.5579892160814128
#
# Approximating hitting prob for (18, 22, 65)
# (18, 22, 65): 0.5150151188069105
# (17, 23, 65): 0.5195376975707799
#
# Approximating hitting prob for (17, 66, 66)
# (17, 66, 66): 0.48654243484719056
# (16, 67, 66): 0.5476329160731335
#
# Approximating hitting prob for (17, 67, 67)
# (17, 67, 67): 0.4869010286442881
# (16, 68, 67): 0.5479021298636074
#
# Approximating hitting prob for (17, 67, 72)
# (17, 67, 72): 0.5502226585680591
# (16, 68, 72): 0.553778489014684
#
# Approximating hitting prob for (17, 68, 68)
# (17, 68, 68): 0.49131100605898986
# (16, 69, 68): 0.5482803483271055
#
# Approximating hitting prob for (18, 23, 68)
# (18, 23, 68): 0.5167394601027243
# (17, 24, 68): 0.5220449440475908
#
# Approximating hitting prob for (18, 68, 69)
# (18, 68, 69): 0.5410476455564658
# (17, 69, 69): 0.4919515371830158
#
# Approximating hitting prob for (18, 69, 70)
# (18, 69, 70): 0.5415654844709318
# (17, 70, 70): 0.4921644019959827
#
# Approximating hitting prob for (18, 27, 70)
# (18, 27, 70): 0.5256066145820982
# (17, 28, 70): 0.5291578678690806
#
# Approximating hitting prob for (18, 70, 71)
# (18, 70, 71): 0.5419361302265626
# (17, 71, 71): 0.49253022220680803
#
# Approximating hitting prob for (17, 72, 72)
# (17, 72, 72): 0.4926658129068
# (16, 73, 72): 0.5503511277620282
#
# Approximating hitting prob for (17, 28, 73)
# (17, 28, 73): 0.5270411065910542
# (16, 29, 73): 0.5349109988994238
#
# Approximating hitting prob for (17, 73, 73)
# (17, 73, 73): 0.4930077965326692
# (16, 74, 73): 0.550806654200246
#
# Approximating hitting prob for (17, 73, 78)
# (17, 73, 78): 0.5547318940994405
# (16, 74, 78): 0.555540184953859
#
# Approximating hitting prob for (17, 73, 81)
# (17, 73, 81): 0.5592262659193664
# (16, 74, 81): 0.5627230315043675
#
# Approximating hitting prob for (17, 74, 74)
# (17, 74, 74): 0.4938970080063762
# (16, 75, 74): 0.5510679089359186
#
# Approximating hitting prob for (17, 74, 79)
# (17, 74, 79): 0.5552305460465042
# (16, 75, 79): 0.5561224397009533
#
# Approximating hitting prob for (17, 74, 82)
# (17, 74, 82): 0.5598394222378643
# (16, 75, 82): 0.5630803479180821
#
# Approximating hitting prob for (18, 25, 74)
# (18, 25, 74): 0.5215544900377348
# (17, 26, 74): 0.5276895656478399
#
# Approximating hitting prob for (18, 74, 75)
# (18, 74, 75): 0.5475037791434426
# (17, 75, 75): 0.4942063336501981
#
# Approximating hitting prob for (18, 74, 80)
# (18, 74, 80): 0.5557979779777592
# (17, 75, 80): 0.5554333191674644
#
# Approximating hitting prob for (18, 74, 83)
# (18, 74, 83): 0.560394788058373
# (17, 75, 83): 0.5601566564972416
#
# Approximating hitting prob for (18, 75, 76)
# (18, 75, 76): 0.5476779932841305
# (17, 76, 76): 0.49433392383737407
#
# Approximating hitting prob for (18, 75, 81)
# (18, 75, 81): 0.5560948110732223
# (17, 76, 81): 0.5557684100994457
#
# Approximating hitting prob for (18, 75, 84)
# (18, 75, 84): 0.5606308123883778
# (17, 76, 84): 0.560437221421585
# Approximating hitting prob for (18, 76, 77)
# (18, 76, 77): 0.5480321749301678
# (17, 77, 77): 0.49531161717239175
#
# Approximating hitting prob for (18, 76, 82)
# (18, 76, 82): 0.556415457892531
# (17, 77, 82): 0.5559561334568205
#
# Approximating hitting prob for (18, 77, 78)
# (18, 77, 78): 0.548527993940341
# (17, 78, 78): 0.49547458875445877
#
# Approximating hitting prob for (18, 77, 83)
# (18, 77, 83): 0.5566565663409131
# (17, 78, 83): 0.5561347635902212
#
# Approximating hitting prob for (18, 31, 78)
# (18, 31, 78): 0.533348643552558
# (17, 32, 78): 0.5400558977970569
#
# Approximating hitting prob for (18, 78, 79)
# (18, 78, 79): 0.5491328136866519
# (17, 79, 79): 0.49565564243754084
#
# Approximating hitting prob for (18, 78, 84)
# (18, 78, 84): 0.5570650765647572
# (17, 79, 84): 0.5563262057609253
#
# Approximating hitting prob for (18, 79, 80)
# (18, 79, 80): 0.549459760596528
# (17, 80, 80): 0.49593314630741153
#
# Approximating hitting prob for (18, 32, 80)
# (18, 32, 80): 0.5344524199601333
# (17, 33, 80): 0.5406380007156486
#
# Approximating hitting prob for (18, 80, 81)
# (18, 80, 81): 0.549945487074618
# (17, 81, 81): 0.4962358138584699
#
# Approximating hitting prob for (18, 81, 82)
# (18, 81, 82): 0.5502544625416935
# (17, 82, 82): 0.49638522504088406
#
# Approximating hitting prob for (18, 81, 90)
# (18, 81, 90): 0.564545744868895
# (17, 82, 90): 0.5639696983005239
#
# Approximating hitting prob for (17, 83, 83)
# (17, 83, 83): 0.4966420091381521
# (16, 84, 83): 0.557212438374295
#
# Approximating hitting prob for (17, 83, 91)
# (17, 83, 91): 0.5641555942438542
# (16, 84, 91): 0.5672142105580193
#
# Approximating hitting prob for (18, 28, 83)
# (18, 28, 83): 0.5330951662677522
# (17, 29, 83): 0.5390076219043085
#
# Approximating hitting prob for (18, 83, 84)
# (18, 83, 84): 0.5508750001343796
# (17, 84, 84): 0.4967640824708119
#
# Approximating hitting prob for (18, 83, 92)
# (18, 83, 92): 0.5650668444948955
# (17, 84, 92): 0.5644126928082195
#
# Approximating hitting prob for (18, 84, 85)
# (18, 84, 85): 0.5511824438150662
# (17, 85, 85): 0.5005600203855535
#
# Approximating hitting prob for (18, 85, 86)
# (18, 85, 86): 0.551426943689299
# (17, 86, 86): 0.5013972795707226
#
# Approximating hitting prob for (17, 87, 87)
# (17, 87, 87): 0.5015104279766226
# (16, 88, 87): 0.5581298078095495
#
# Approximating hitting prob for (17, 88, 88)
# (17, 88, 88): 0.5016754684839597
# (16, 89, 88): 0.5582704071350434
#
# Approximating hitting prob for (17, 89, 89)
# (17, 89, 89): 0.5017526243467731
# (16, 90, 89): 0.5584117802652058
#
# Approximating hitting prob for (18, 30, 89)
# (18, 30, 89): 0.537202535745565
# (17, 31, 89): 0.5447835661607245
#
# Approximating hitting prob for (18, 89, 90)
# (18, 89, 90): 0.5540597721689006
# (17, 90, 90): 0.5021015252040985
#
# Approximating hitting prob for (18, 90, 91)
# (18, 90, 91): 0.5563900452521376
# (17, 91, 91): 0.5022373017779056
#
# Approximating hitting prob for (18, 90, 96)
# (18, 90, 96): 0.5637442675590126
# (17, 91, 96): 0.563270643513335
#
# Approximating hitting prob for (18, 90, 99)
# (18, 90, 99): 0.5682163750511314
# (17, 91, 99): 0.5676719351466321
#
# Approximating hitting prob for (18, 91, 92)
# (18, 91, 92): 0.5568257885095739
# (17, 92, 92): 0.502466957410018
#
# Approximating hitting prob for (17, 92, 96)
# (17, 92, 96): 0.5622232848930248
# (16, 93, 96): 0.5636274534172133
#
# Approximating hitting prob for (17, 92, 97)
# (17, 92, 97): 0.5631906947599257
# (16, 93, 97): 0.5655964344684278
#
# Approximating hitting prob for (17, 92, 100)
# (17, 92, 100): 0.5678949040093858
# (16, 93, 100): 0.5705331012657863
#
# Approximating hitting prob for (18, 31, 92)
# (18, 31, 92): 0.5395383976108808
# (17, 32, 92): 0.5457610710853795
#
# Approximating hitting prob for (18, 92, 93)
# (18, 92, 93): 0.5569430313283252
# (17, 93, 93): 0.5025465577802689
#
# Approximating hitting prob for (17, 93, 96)
# (17, 93, 96): 0.5610666568319305
# (16, 94, 96): 0.5620012416303845
#
# Approximating hitting prob for (17, 93, 98)
# (17, 93, 98): 0.5636053069774423
# (16, 94, 98): 0.5657233914840882
#
# Approximating hitting prob for (17, 94, 94)
# (17, 94, 94): 0.50285437455246
# (16, 95, 94): 0.558875567690106
#
# Approximating hitting prob for (18, 93, 95)
# (18, 93, 95): 0.5583138742607382
# (17, 94, 95): 0.558293193998974
#
# Approximating hitting prob for (18, 93, 96)
# (18, 93, 96): 0.5598657886675368
# (17, 94, 96): 0.5595042440982331
#
# Approximating hitting prob for (18, 93, 97)
# (18, 93, 97): 0.561303483849395
# (17, 94, 97): 0.5612300798728406
#
# Approximating hitting prob for (18, 93, 98)
# (18, 93, 98): 0.5625081480219641
# (17, 94, 98): 0.562183241642495
#
# Approximating hitting prob for (18, 93, 99)
# (18, 93, 99): 0.5646649760896926
# (17, 94, 99): 0.56370921562272
#
# Approximating hitting prob for (18, 94, 95)
# (18, 94, 95): 0.5572776391206266
# (17, 95, 95): 0.5029389161536973
#
# Approximating hitting prob for (17, 95, 97)
# (17, 95, 97): 0.5596679913246663
# (16, 96, 97): 0.562837559943146
#
# Approximating hitting prob for (17, 95, 98)
# (17, 95, 98): 0.5613808639287214
# (16, 96, 98): 0.5641557492018816
#
# Approximating hitting prob for (17, 95, 99)
# (17, 95, 99): 0.5626438629803386
# (16, 96, 99): 0.5658891932611334
#
# Approximating hitting prob for (17, 95, 100)
# (17, 95, 100): 0.5639156454001365
# (16, 96, 100): 0.5675400562304328
#
# Approximating hitting prob for (18, 16, 95)
# (18, 16, 95): 0.4188451398722768
# (17, 17, 95): 0.48395604050292285
#
# Approximating hitting prob for (17, 96, 96)
# (17, 96, 96): 0.5030774733002193
# (16, 97, 96): 0.562837559943146
#
# Approximating hitting prob for (18, 95, 97)
# (18, 95, 97): 0.5587064132108445
# (17, 96, 97): 0.5586123629019756
#
# Approximating hitting prob for (18, 95, 98)
# (18, 95, 98): 0.5602472145769862
# (17, 96, 98): 0.5597570922831979
#
# Approximating hitting prob for (18, 95, 99)
# (18, 95, 99): 0.5616344559515327
# (17, 96, 99): 0.5612058595585653
#
# Approximating hitting prob for (18, 95, 100)
# (18, 95, 100): 0.5628403472960518
# (17, 96, 100): 0.5627931573533641
#
# Approximating hitting prob for (18, 96, 97)
# (18, 96, 97): 0.5576931030226304
# (17, 97, 97): 0.5032623698784998
#
# Approximating hitting prob for (17, 97, 99)
# (17, 97, 99): 0.5599773234654639
# (16, 98, 99): 0.5634128937437658
#
# Approximating hitting prob for (17, 97, 100)
# (17, 97, 100): 0.5617240943124361
# (16, 98, 100): 0.5644214277194651
#
# Approximating hitting prob for (17, 98, 98)
# (17, 98, 98): 0.503389299942845
# (16, 99, 98): 0.5634128937437658
#
# Approximating hitting prob for (18, 97, 99)
# (18, 97, 99): 0.5590342255902309
# (17, 98, 99): 0.5588992979368418
#
# Approximating hitting prob for (18, 97, 100)
# (18, 97, 100): 0.5605256561104097
# (17, 98, 100): 0.5598130654853353
#
# Approximating hitting prob for (17, 99, 99)
# (17, 99, 99): 0.5034660032514061
# (16, 100, 99): 0.563540495536323
#
# Approximating hitting prob for (18, 98, 100)
# (18, 98, 100): 0.5591897101924469
# (17, 99, 100): 0.5590222245963236
#
# Approximating hitting prob for (18, 99, 100)
# (18, 99, 100): 0.5581790992262419
# (17, 100, 100): 0.5036051482212667
#
# (19, 3, 4): 1086673414325105343500654313129949901557074273221622438235274828687/26295041537252972292166388359891453635601159045917786708416193658863
# (18, 4, 4): 8322220968/213378126031
#
# Approximating hitting prob for (19, 6, 7)
# (19, 6, 7): 0.10503074404770225
# (18, 7, 7): 0.10268433336242862
#
# Approximating hitting prob for (19, 7, 8)
# (19, 7, 8): 0.12388942908740165
# (18, 8, 8): 0.10824236969493321
#
# Approximating hitting prob for (19, 7, 24)
# (19, 7, 24): 0.29178864568769103
# (18, 8, 24): 0.29081560932166667
#
# Approximating hitting prob for (19, 9, 10)
# (19, 9, 10): 0.16855032631984537
# (18, 10, 10): 0.16596084427308347
#
# Approximating hitting prob for (19, 10, 11)
# (19, 10, 11): 0.2045061533509586
# (18, 11, 11): 0.1744884469817859
#
# Approximating hitting prob for (19, 10, 22)
# (19, 10, 22): 0.30654387187074633
# (18, 11, 22): 0.3055227964423127
#
# Approximating hitting prob for (19, 11, 12)
# (19, 11, 12): 0.21424205308622857
# (18, 12, 12): 0.18348623853210444
#
# Approximating hitting prob for (19, 11, 24)
# (19, 11, 24): 0.3145939483396923
# (18, 12, 24): 0.31260403488913774
#
# Approximating hitting prob for (19, 12, 13)
# (19, 12, 13): 0.223086657072286
# (18, 13, 13): 0.1901816956072473
#
# Approximating hitting prob for (19, 12, 26)
# (19, 12, 26): 0.32272924108744777
# (18, 13, 26): 0.3185371978640415
#
# Approximating hitting prob for (19, 12, 39)
# (19, 12, 39): 0.3561996572255119
# (18, 13, 39): 0.3554065805668693
#
# Approximating hitting prob for (19, 13, 14)
# (19, 13, 14): 0.231842683082331
# (18, 14, 14): 0.20249800445937116
#
# Approximating hitting prob for (19, 13, 28)
# (19, 13, 28): 0.3303167154589094
# (18, 14, 28): 0.3228604532935993
#
# Approximating hitting prob for (19, 14, 15)
# (19, 14, 15): 0.24194879268412559
# (18, 15, 15): 0.2077770400570025
#
# Approximating hitting prob for (19, 14, 30)
# (19, 14, 30): 0.3357553973020142
# (18, 15, 30): 0.32831579821399354
#
# Approximating hitting prob for (19, 14, 45)
# (19, 14, 45): 0.37472221011278695
# (18, 15, 45): 0.37261036104302364
#
# Approximating hitting prob for (19, 15, 16)
# (19, 15, 16): 0.2498290460212547
# (18, 16, 16): 0.21480519348587843
#
# Approximating hitting prob for (19, 15, 32)
# (19, 15, 32): 0.34224593875971615
# (18, 16, 32): 0.3310296595577675
#
# Approximating hitting prob for (19, 15, 48)
# (19, 15, 48): 0.380058914076415
# (18, 16, 48): 0.37754528755718225
#
# Approximating hitting prob for (19, 16, 17)
# (19, 16, 17): 0.2565998112231931
# (18, 17, 17): 0.21927987391303042
#
# Approximating hitting prob for (19, 16, 34)
# (19, 16, 34): 0.34564709681648537
# (18, 17, 34): 0.33259998561769083
#
# Approximating hitting prob for (19, 16, 51)
# (19, 16, 51): 0.38244795695192096
# (18, 17, 51): 0.38135112836261004
#
# Approximating hitting prob for (19, 16, 69)
# (19, 16, 69): 0.4098243186515831
# (18, 17, 69): 0.4095093304655786
#
# Approximating hitting prob for (19, 10, 19)
# (19, 10, 19): 0.2962414643477585
# (18, 11, 19): 0.30788749847030306
#
# Approximating hitting prob for (19, 19, 20)
# (19, 19, 20): 0.3902114742844012
# (18, 20, 20): 0.35936162658100074
#
# Approximating hitting prob for (19, 20, 21)
# (19, 20, 21): 0.40338074395724705
# (18, 21, 21): 0.3626759287590275
#
# Approximating hitting prob for (19, 20, 63)
# (19, 20, 63): 0.5098575365869292
# (18, 21, 63): 0.5045116888169837
#
# Approximating hitting prob for (19, 20, 80)
# (19, 20, 80): 0.5252126552962479
# (18, 21, 80): 0.5248710628533533
#
# Approximating hitting prob for (19, 20, 81)
# (19, 20, 81): 0.5253319220001255
# (18, 21, 81): 0.5246350740318987
#
# Approximating hitting prob for (18, 22, 22)
# (18, 22, 22): 0.36574702933319064
# (17, 23, 22): 0.4190192245575173
#
# Approximating hitting prob for (18, 22, 66)
# (18, 22, 66): 0.5065073466068032
# (17, 23, 66): 0.5196652074968994
#
# Approximating hitting prob for (18, 22, 84)
# (18, 22, 84): 0.5265788130792185
# (17, 23, 84): 0.5314356435121125
#
# Approximating hitting prob for (18, 23, 23)
# (18, 23, 23): 0.37011104261802935
# (17, 24, 23): 0.4220180146455709
#
# Approximating hitting prob for (18, 23, 69)
# (18, 23, 69): 0.5085551277228832
# (17, 24, 69): 0.5224008479159509
#
# Approximating hitting prob for (18, 23, 87)
# (18, 23, 87): 0.5282057733026165
# (17, 24, 87): 0.5331149074562701
#
# Approximating hitting prob for (19, 8, 23)
# (19, 8, 23): 0.29188353228081804
# (18, 9, 23): 0.3099700443656973
#
# Approximating hitting prob for (18, 24, 24)
# (18, 24, 24): 0.37265977777400555
# (17, 25, 24): 0.4242857498567869
#
# Approximating hitting prob for (18, 24, 72)
# (18, 24, 72): 0.5110406441009517
# (17, 25, 72): 0.523850024670145
#
# Approximating hitting prob for (18, 24, 90)
# (18, 24, 90): 0.530583205389776
# (17, 25, 90): 0.5341710495800088
#
# Approximating hitting prob for (18, 25, 25)
# (18, 25, 25): 0.3754499342798961
# (17, 26, 25): 0.43594186216098335
#
# Approximating hitting prob for (18, 25, 75)
# (18, 25, 75): 0.5129209548524486
# (17, 26, 75): 0.5281719432225417
#
# Approximating hitting prob for (18, 25, 93)
# (18, 25, 93): 0.5319454321954232
# (17, 26, 93): 0.5406337784955636
#
# Approximating hitting prob for (19, 13, 25)
# (19, 13, 25): 0.3245541719476078
# (18, 14, 25): 0.33102210502329005
#
# Approximating hitting prob for (19, 25, 26)
# (19, 25, 26): 0.41997502533726894
# (18, 26, 26): 0.3775245864012524
#
# Approximating hitting prob for (19, 25, 78)
# (19, 25, 78): 0.520031809628849
# (18, 26, 78): 0.5151434260209484
#
# Approximating hitting prob for (19, 25, 96)
# (19, 25, 96): 0.5342868882347258
# (18, 26, 96): 0.533410464346387
#
# Approximating hitting prob for (19, 26, 27)
# (19, 26, 27): 0.4226802243988365
# (18, 27, 27): 0.38531294066601585
#
# Approximating hitting prob for (19, 26, 81)
# (19, 26, 81): 0.5223546393712687
# (18, 27, 81): 0.520847348354239
#
# Approximating hitting prob for (18, 28, 28)
# (18, 28, 28): 0.3930542519375145
# (17, 29, 28): 0.450691016944653
#
# Approximating hitting prob for (18, 28, 84)
# (18, 28, 84): 0.5243874207401239
# (17, 29, 84): 0.5390096069992825
#
# Approximating hitting prob for (18, 29, 29)
# (18, 29, 29): 0.3943798198728233
# (17, 30, 29): 0.45442776916855204
#
# Approximating hitting prob for (18, 29, 87)
# (18, 29, 87): 0.5255885552800558
# (17, 30, 87): 0.5402890074488685
#
# Approximating hitting prob for (19, 15, 29)
# (19, 15, 29): 0.3348443791861548
# (18, 16, 29): 0.349447233464483
#
# Approximating hitting prob for (19, 29, 30)
# (19, 29, 30): 0.44393421346638134
# (18, 30, 30): 0.39923107976612376
#
# Approximating hitting prob for (19, 29, 90)
# (19, 29, 90): 0.5336893733136471
# (18, 30, 90): 0.5285380286570163
#
# Approximating hitting prob for (19, 30, 31)
# (19, 30, 31): 0.4464779749749197
# (18, 31, 31): 0.40145936156658796
#
# Approximating hitting prob for (19, 30, 93)
# (19, 30, 93): 0.5347950272599838
# (18, 31, 93): 0.5306731465757496
#
# Approximating hitting prob for (18, 32, 32)
# (18, 32, 32): 0.403703722557115
# (17, 33, 32): 0.4586532171701982
#
# Approximating hitting prob for (18, 32, 96)
# (18, 32, 96): 0.5349054782767223
# (17, 33, 96): 0.5467520444939259
#
# Approximating hitting prob for (18, 33, 33)
# (18, 33, 33): 0.40537758745520946
# (17, 34, 33): 0.47271117557275555
#
# Approximating hitting prob for (18, 33, 84)
# (18, 33, 84): 0.532734806781722
# (17, 34, 84): 0.5540625944634859
#
# Approximating hitting prob for (18, 33, 99)
# (18, 33, 99): 0.5357973435892338
# (17, 34, 99): 0.5602769586987216
#
# Approximating hitting prob for (19, 17, 33)
# (19, 17, 33): 0.344627413561561
# (18, 18, 33): 0.41737770134275753
#
# Approximating hitting prob for (19, 33, 34)
# (19, 33, 34): 0.4554921823884304
# (18, 34, 34): 0.40730915363163184
#
# Approximating hitting prob for (19, 33, 86)
# (19, 33, 86): 0.5340920992464655
# (18, 34, 86): 0.5332648124986303
#
# Approximating hitting prob for (19, 34, 35)
# (19, 34, 35): 0.4572430936799386
# (18, 35, 35): 0.4084602880113615
#
# Approximating hitting prob for (19, 34, 88)
# (19, 34, 88): 0.5347364361545704
# (18, 35, 88): 0.5336774231025768
#
# Approximating hitting prob for (19, 12, 35)
# (19, 12, 35): 0.35157237375398903
# (18, 13, 35): 0.36028114350965557
#
# Approximating hitting prob for (19, 35, 36)
# (19, 35, 36): 0.4591347225822377
# (18, 36, 36): 0.4285714285714286
#
# Approximating hitting prob for (19, 36, 37)
# (19, 36, 37): 0.45879390590765023
# (18, 37, 37): 0.43403388113506
#
# Approximating hitting prob for (19, 37, 38)
# (19, 37, 38): 0.47267173740207746
# (18, 38, 38): 0.4347840793074833
#
# Approximating hitting prob for (18, 39, 39)
# (18, 39, 39): 0.43555797041404976
# (17, 40, 39): 0.49305494211889805
#
# Approximating hitting prob for (18, 40, 40)
# (18, 40, 40): 0.4369882221866643
# (17, 41, 40): 0.493854810639067
#
# ...
# (24, 53, 54): 0.49000541163759515
# (23, 54, 54): 0.44060894817787616
#
# Approximating hitting prob for (24, 53, 62)
# (24, 53, 62): 0.503668214691772
# (23, 54, 62): 0.503632235203303
#
# Approximating hitting prob for (23, 55, 55)
# (23, 55, 55): 0.4411107396837834
# (22, 56, 55): 0.4968670861154166
#
# Approximating hitting prob for (23, 55, 64)
# (23, 55, 64): 0.5046901305847644
# (22, 56, 64): 0.5082683973073434
#
# Approximating hitting prob for (23, 55, 66)
# (23, 55, 66): 0.5079537648525417
# (22, 56, 66): 0.5187347866723832
#
# Approximating hitting prob for (23, 56, 56)
# (23, 56, 56): 0.4416451103810983
# (22, 57, 56): 0.49855876098211754
#
# Approximating hitting prob for (23, 56, 67)
# (23, 56, 67): 0.5085338059861304
# (22, 57, 67): 0.5215566111470894
#
# Approximating hitting prob for (24, 19, 56)
# (24, 19, 56): 0.3775130413536642
# (23, 20, 56): 0.381982617490499
#
# Approximating hitting prob for (24, 56, 57)
# (24, 56, 57): 0.49355143187375855
# (23, 57, 57): 0.4419095641765352
#
# Approximating hitting prob for (24, 56, 68)
# (24, 56, 68): 0.5096095349159204
# (23, 57, 68): 0.5070628514486916
#
# Approximating hitting prob for (24, 57, 58)
# (24, 57, 58): 0.4941618133517873
# (23, 58, 58): 0.4449804170896314
#
# Approximating hitting prob for (24, 58, 59)
# (24, 58, 59): 0.49455971297283585
# (23, 59, 59): 0.4453761085230154
#
# Approximating hitting prob for (23, 60, 60)
# (23, 60, 60): 0.44594403452844394
# (22, 61, 60): 0.5014594550609436
#
# Approximating hitting prob for (23, 60, 74)
# (23, 60, 74): 0.5248814587298204
# (22, 61, 74): 0.5283933336017945
#
# Approximating hitting prob for (23, 61, 61)
# (23, 61, 61): 0.4465503280146304
# (22, 62, 61): 0.5024122348427694
#
# Approximating hitting prob for (23, 61, 76)
# (23, 61, 76): 0.5255235908084157
# (22, 62, 76): 0.5301090366182336
#
# Approximating hitting prob for (23, 62, 62)
# (23, 62, 62): 0.4472789727028403
# (22, 63, 62): 0.5030010953989973
#
# Approximating hitting prob for (23, 62, 73)
# (23, 62, 73): 0.5231041551365193
# (22, 63, 73): 0.5261121789925017
#
# Approximating hitting prob for (23, 62, 78)
# (23, 62, 78): 0.526954578636229
# (22, 63, 78): 0.5321195118735546
#
# Approximating hitting prob for (24, 21, 62)
# (24, 21, 62): 0.38436690255359346
# (23, 22, 62): 0.3895771302654747
#
# Approximating hitting prob for (24, 62, 63)
# (24, 62, 63): 0.4989786616080521
# (23, 63, 63): 0.4476825522659389
#
# Approximating hitting prob for (24, 62, 80)
# (24, 62, 80): 0.5284733558279641
# (23, 63, 80): 0.5277070820414002
#
# Approximating hitting prob for (24, 63, 64)
# (24, 63, 64): 0.4997406513932607
# (23, 64, 64): 0.4489340002971363
#
# Approximating hitting prob for (24, 63, 82)
# (24, 63, 82): 0.5291910281637272
# (23, 64, 82): 0.5284499429584003
#
# Approximating hitting prob for (24, 64, 65)
# (24, 64, 65): 0.5002179976227933
# (23, 65, 65): 0.44948004776284955
#
# Approximating hitting prob for (24, 64, 84)
# (24, 64, 84): 0.5301153617677242
# (23, 65, 84): 0.5290337304282108
#
# Approximating hitting prob for (23, 66, 66)
# (23, 66, 66): 0.45011883512276346
# (22, 67, 66): 0.5256731047691142
#
# Approximating hitting prob for (23, 66, 73)
# (23, 66, 73): 0.5216864757374432
# (22, 67, 73): 0.534880300020402
#
# Approximating hitting prob for (23, 66, 86)
# (23, 66, 86): 0.5295523494497529
# (22, 67, 86): 0.5479952975131318
#
# Approximating hitting prob for (23, 67, 67)
# (23, 67, 67): 0.45062421343172127
# (22, 68, 67): 0.5279771960321749
#
# Approximating hitting prob for (23, 67, 88)
# (23, 67, 88): 0.5299840350303774
# (22, 68, 88): 0.5562721745381219
#
# Approximating hitting prob for (23, 68, 68)
# (23, 68, 68): 0.4510049662283137
# (22, 69, 68): 0.5286991701318776
#
# Approximating hitting prob for (23, 68, 75)
# (23, 68, 75): 0.5226743977943057
# (22, 69, 75): 0.5362477503494559
#
# Approximating hitting prob for (23, 68, 90)
# (23, 68, 90): 0.5302144996999092
# (22, 69, 90): 0.557072521001217
#
# Approximating hitting prob for (23, 69, 69)
# (23, 69, 69): 0.46941896024464413
# (22, 70, 69): 0.5293381442956179
#
# Approximating hitting prob for (23, 70, 70)
# (23, 70, 70): 0.4747104337623513
# (22, 71, 70): 0.5297559655234533
#
# Approximating hitting prob for (23, 71, 71)
# (23, 71, 71): 0.47507917820983486
# (22, 72, 71): 0.5303524638458662
#
# Approximating hitting prob for (23, 72, 72)
# (23, 72, 72): 0.47560893192203507
# (22, 73, 72): 0.5309147687437327
#
# Approximating hitting prob for (23, 73, 73)
# (23, 73, 73): 0.47616706370771356
# (22, 74, 73): 0.5316968193168378
#
# Approximating hitting prob for (23, 74, 74)
# (23, 74, 74): 0.4764581773985077
# (22, 75, 74): 0.5324657270328322
#
# Approximating hitting prob for (23, 74, 85)
# (23, 74, 85): 0.5420524554359075
# (22, 75, 85): 0.5482190237600281
#
# Approximating hitting prob for (23, 25, 75)
# (23, 25, 75): 0.5006350270348792
# (22, 26, 75): 0.5127822493564783
#
# Approximating hitting prob for (23, 26, 75)
# (23, 26, 75): 0.508065846400791
# (22, 27, 75): 0.5146194138498824
#
# Approximating hitting prob for (23, 75, 75)
# (23, 75, 75): 0.4771943184882128
# (22, 76, 75): 0.5329813960889681
#
# Approximating hitting prob for (23, 75, 82)
# (23, 75, 82): 0.5380462744694253
# (22, 76, 82): 0.5436772156085312
#
# Approximating hitting prob for (23, 76, 76)
# (23, 76, 76): 0.4774657892643988
# (22, 77, 76): 0.5333806852541025
#
# Approximating hitting prob for (23, 76, 83)
# (23, 76, 83): 0.5380820845737645
# (22, 77, 83): 0.5443571184320346
#
# Approximating hitting prob for (23, 77, 77)
# (23, 77, 77): 0.4785447517502965
# (22, 78, 77): 0.5385683742019206
#
# Approximating hitting prob for (24, 26, 77)
# (24, 26, 77): 0.5088021731442927
# (23, 27, 77): 0.5101829066953004
#
# Approximating hitting prob for (24, 77, 78)
# (24, 77, 78): 0.5298857971230906
# (23, 78, 78): 0.4787791134712052
#
# Approximating hitting prob for (24, 78, 79)
# (24, 78, 79): 0.5306807141770878
# (23, 79, 79): 0.4790988627015938
#
# Approximating hitting prob for (24, 79, 80)
# (24, 79, 80): 0.5312113039469565
# (23, 80, 80): 0.47926263204611175
#
# Approximating hitting prob for (24, 79, 91)
# (24, 79, 91): 0.5494468007835638
# (23, 80, 91): 0.548850165316214
#
# Approximating hitting prob for (23, 81, 81)
# (23, 81, 81): 0.48402859839089146
# (22, 82, 81): 0.540180736005904
#
# Approximating hitting prob for (24, 64, 81)
# (24, 64, 81): 0.5287237778245387
# (23, 65, 81): 0.530596495148312
#
# Approximating hitting prob for (24, 81, 82)
# (24, 81, 82): 0.5324582413515752
# (23, 82, 82): 0.4841541260916194
#
# Approximating hitting prob for (24, 81, 89)
# (24, 81, 89): 0.545456476938901
# (23, 82, 89): 0.5453955933945512
#
# Approximating hitting prob for (24, 30, 82)
# (24, 30, 82): 0.5153637681078594
# (23, 31, 82): 0.5190652702305827
#
# Approximating hitting prob for (24, 82, 83)
# (24, 82, 83): 0.5329562505462765
# (23, 83, 83): 0.4844455897088238
#
# Approximating hitting prob for (24, 65, 83)
# (24, 65, 83): 0.5296383688932479
# (23, 66, 83): 0.5314602588746437
#
# Approximating hitting prob for (24, 83, 84)
# (24, 83, 84): 0.5333321941116457
# (23, 84, 84): 0.4846424678981871
#
# Approximating hitting prob for (24, 84, 85)
# (24, 84, 85): 0.5385097839000186
# (23, 85, 85): 0.4850874093599555
#
# Approximating hitting prob for (24, 84, 96)
# (24, 84, 96): 0.55359136977543
# (23, 85, 96): 0.5530674307871443
#
# Approximating hitting prob for (23, 86, 86)
# (23, 86, 86): 0.485285317431787
# (22, 87, 86): 0.5419159308299532
#
# Approximating hitting prob for (23, 86, 97)
# (23, 86, 97): 0.5535141286251063
# (22, 87, 97): 0.5552367141682993
#
# Approximating hitting prob for (24, 29, 86)
# (24, 29, 86): 0.5148313870442108
# (23, 30, 86): 0.5176666857817394
#
# Approximating hitting prob for (24, 32, 86)
# (24, 32, 86): 0.5186888935913824
# (23, 33, 86): 0.5216698447527791
#
# Approximating hitting prob for (24, 86, 87)
# (24, 86, 87): 0.5393857030735448
# (23, 87, 87): 0.4857626854821801
#
# Approximating hitting prob for (24, 86, 98)
# (24, 86, 98): 0.5544337627253499
# (23, 87, 98): 0.5537430133881154
#
# Approximating hitting prob for (23, 88, 88)
# (23, 88, 88): 0.4860981489784835
# (22, 89, 88): 0.5468957040549035
#
# Approximating hitting prob for (23, 88, 99)
# (23, 88, 99): 0.554290775395059
# (22, 89, 99): 0.5579171700142896
#
# Approximating hitting prob for (23, 89, 89)
# (23, 89, 89): 0.4864394718701008
# (22, 90, 89): 0.5470488647078378
#
# Approximating hitting prob for (23, 89, 96)
# (23, 89, 96): 0.5499667824592557
# (22, 90, 96): 0.553088912335984
#
# Approximating hitting prob for (23, 89, 100)
# (23, 89, 100): 0.554861389506868
# (22, 90, 100): 0.5580267935537407
#
# Approximating hitting prob for (24, 30, 89)
# (24, 30, 89): 0.5158805157576855
# (23, 31, 89): 0.5194831844057218
#
# Approximating hitting prob for (23, 90, 90)
# (23, 90, 90): 0.4867528888985053
# (22, 91, 90): 0.5471898279123555
#
# Approximating hitting prob for (23, 90, 97)
# (23, 90, 97): 0.5502624578134462
# (22, 91, 97): 0.5536821588185648
#
# Approximating hitting prob for (23, 34, 91)
# (23, 34, 91): 0.520764504651185
# (22, 35, 91): 0.5274974085558403
#
# Approximating hitting prob for (23, 91, 91)
# (23, 91, 91): 0.4869547509653751
# (22, 92, 91): 0.5474486008851345
#
# Approximating hitting prob for (23, 91, 98)
# (23, 91, 98): 0.550440245199246
# (22, 92, 98): 0.5539196900281621
#
# Approximating hitting prob for (23, 92, 92)
# (23, 92, 92): 0.49131100605898986
# (22, 93, 92): 0.5476867884077605
#
# Approximating hitting prob for (24, 31, 92)
# (24, 31, 92): 0.5180839542994001
# (23, 32, 92): 0.5209514453061579
#
# Approximating hitting prob for (24, 92, 93)
# (24, 92, 93): 0.5413577879220769
# (23, 93, 93): 0.49191388567735944
#
# Approximating hitting prob for (24, 93, 94)
# (24, 93, 94): 0.5415876475702015
# (23, 94, 94): 0.49204051933117565
#
# Approximating hitting prob for (24, 36, 94)
# (24, 36, 94): 0.5256273551414045
# (23, 37, 94): 0.5281730015811051
#
# Approximating hitting prob for (24, 94, 95)
# (24, 94, 95): 0.5418911981886367
# (23, 95, 95): 0.4922297872478986
#
# Approximating hitting prob for (23, 96, 96)
# (23, 96, 96): 0.49252473061457297
# (22, 97, 96): 0.5491999286471546
#
# Approximating hitting prob for (23, 37, 97)
# (23, 37, 97): 0.5265554916237062
# (22, 38, 97): 0.5336504536204104
#
# Approximating hitting prob for (23, 97, 97)
# (23, 97, 97): 0.49262389191956296
# (22, 98, 97): 0.5494163009943
#
# Approximating hitting prob for (23, 98, 98)
# (23, 98, 98): 0.49293402575496464
# (22, 99, 98): 0.5498192513464122
#
# Approximating hitting prob for (24, 33, 98)
# (24, 33, 98): 0.5208260393647535
# (23, 34, 98): 0.524112082394064
#
# Approximating hitting prob for (24, 38, 98)
# (24, 38, 98): 0.527454526188018
# (23, 39, 98): 0.5328991821427508
#
# Approximating hitting prob for (24, 98, 99)
# (24, 98, 99): 0.5470892215067104
# (23, 99, 99): 0.4930398619704439
#
# Approximating hitting prob for (24, 99, 100)
# (24, 99, 100): 0.5473606946477872
# (23, 100, 100): 0.4938903034222885
#
# Approximating hitting prob for (25, 4, 5)
# (25, 4, 5): 0.04072366333831066
# (24, 5, 5): 0.03635093876802261
#
# Approximating hitting prob for (25, 6, 7)
# (25, 6, 7): 0.07177587715329445
# (24, 7, 7): 0.06438841979399504
#
# Approximating hitting prob for (25, 6, 14)
# (25, 6, 14): 0.11971344220274667
# (24, 7, 14): 0.11785226874648037
#
# Approximating hitting prob for (25, 8, 9)
# (25, 8, 9): 0.1044618137177784
# (24, 9, 9): 0.10101028194464957
#
# Approximating hitting prob for (25, 9, 10)
# (25, 9, 10): 0.12066060246355619
# (24, 10, 10): 0.10587877499579529
#
# Approximating hitting prob for (25, 9, 20)
# (25, 9, 20): 0.1944716893980162
# (24, 10, 20): 0.19385068200177302
#
# Approximating hitting prob for (25, 10, 11)
# (25, 10, 11): 0.1266665028358811
# (24, 11, 11): 0.10969679708428047
#
# Approximating hitting prob for (25, 10, 22)
# (25, 10, 22): 0.20882201949675303
# (24, 11, 22): 0.2078577804526379
#
# Approximating hitting prob for (25, 10, 33)
# (25, 10, 33): 0.2953932303244686
# (24, 11, 33): 0.2929638582195892
#
# Approximating hitting prob for (25, 6, 11)
# (25, 6, 11): 0.10609036713582487
# (24, 7, 11): 0.11491708370684717
#
# Approximating hitting prob for (25, 12, 13)
# (25, 12, 13): 0.16844904912024475
# (24, 13, 13): 0.164859544272948
#
# Approximating hitting prob for (24, 14, 14)
# (24, 14, 14): 0.1681780559678497
# (23, 15, 14): 0.21892376812739667
#
# Approximating hitting prob for (24, 14, 28)
# (24, 14, 28): 0.2976354789365605
# (23, 15, 28): 0.3188669100780736
#
# Approximating hitting prob for (24, 14, 42)
# (24, 14, 42): 0.3371546528019675
# (23, 15, 42): 0.3524201864534003
#
# Approximating hitting prob for (24, 14, 65)
# (24, 14, 65): 0.37401014463428556
# (23, 15, 65): 0.38059329831400984
#
# Approximating hitting prob for (24, 15, 15)
# (24, 15, 15): 0.17595019969795658
# (23, 16, 15): 0.22677011522370602
#
# Approximating hitting prob for (24, 15, 30)
# (24, 15, 30): 0.306556505077879
# (23, 16, 30): 0.3253372864157789
#
# Approximating hitting prob for (24, 16, 16)
# (24, 16, 16): 0.18348623853210444
# (23, 17, 16): 0.23270273611728695
#
# Approximating hitting prob for (24, 16, 32)
# (24, 16, 32): 0.31260403488913774
# (23, 17, 32): 0.3291101478987309
#
# Approximating hitting prob for (24, 16, 48)
# (24, 16, 48): 0.35041358795203204
# (23, 17, 48): 0.3630506499521789
#
# Approximating hitting prob for (24, 17, 17)
# (24, 17, 17): 0.18865411987950534
# (23, 18, 17): 0.24166685135084087
#
# Approximating hitting prob for (24, 17, 34)
# (24, 17, 34): 0.3157650646418631
# (23, 18, 34): 0.3348607387437886
#
# Approximating hitting prob for (24, 17, 51)
# (24, 17, 51): 0.35439871171015547
# (23, 18, 51): 0.3724916759787471
#
# Approximating hitting prob for (24, 9, 18)
# (24, 9, 18): 0.1824478821019516
# (23, 10, 18): 0.20093221784505033
#
# Approximating hitting prob for (24, 18, 18)
# (24, 18, 18): 0.19596772116592112
# (23, 19, 18): 0.24805890324983704
#
# Approximating hitting prob for (24, 18, 36)
# (24, 18, 36): 0.3204587476532555
# (23, 19, 36): 0.3381987733437577
#
# Approximating hitting prob for (24, 19, 19)
# (24, 19, 19): 0.20322824139244566
# (23, 20, 19): 0.25352573230068587
#
# Approximating hitting prob for (24, 19, 38)
# (24, 19, 38): 0.32392039780799337
# (23, 20, 38): 0.34153866189190274
#
# Approximating hitting prob for (24, 19, 57)
# (24, 19, 57): 0.36920718360061605
# (23, 20, 57): 0.38227518556536083
#
# Approximating hitting prob for (25, 10, 19)
# (25, 10, 19): 0.19415926189142974
# (24, 11, 19): 0.20580013738837352
#
# Approximating hitting prob for (25, 19, 20)
# (25, 19, 20): 0.24496738342527577
# (24, 20, 20): 0.2077770400570025
#
# Approximating hitting prob for (25, 19, 40)
# (25, 19, 40): 0.3357271215147815
# (24, 20, 40): 0.32831579821399354
#
# Approximating hitting prob for (25, 19, 60)
# (25, 19, 60): 0.3766838795987537
# (24, 20, 60): 0.37261036104302364
#
# Approximating hitting prob for (25, 20, 21)
# (25, 20, 21): 0.2498641981457249
# (24, 21, 21): 0.21330055984615426
#
# Approximating hitting prob for (25, 20, 42)
# (25, 20, 42): 0.3419135632306713
# (24, 21, 42): 0.33034988900705786
#
# Approximating hitting prob for (25, 20, 63)
# (25, 20, 63): 0.3803658303465218
# (24, 21, 63): 0.3763096189579583
#
# Approximating hitting prob for (25, 20, 87)
# (25, 20, 87): 0.40731974323539616
# (24, 21, 87): 0.4071506635974886
#
# Approximating hitting prob for (25, 21, 22)
# (25, 21, 22): 0.25569401883344667
# (24, 22, 22): 0.21686811675627718
#
# Approximating hitting prob for (25, 21, 44)
# (25, 21, 44): 0.34459263517879796
# (24, 22, 44): 0.331857301121022
#
# Approximating hitting prob for (25, 21, 66)
# (25, 21, 66): 0.38378918239321663
# (24, 22, 66): 0.3795187996979468
#
# Approximating hitting prob for (25, 21, 89)
# (25, 21, 89): 0.4096357369054105
# (24, 22, 89): 0.4091354391687767
#
# Approximating hitting prob for (25, 21, 90)
# (25, 21, 90): 0.40964075573707354
# (24, 22, 90): 0.40864321733672443
#
# Approximating hitting prob for (25, 22, 23)
# (25, 22, 23): 0.2601679609374632
# (24, 23, 23): 0.22016530937311132
#
# Approximating hitting prob for (25, 22, 46)
# (25, 22, 46): 0.3469014002787513
# (24, 23, 46): 0.3328825555428911
#
# Approximating hitting prob for (25, 22, 69)
# (25, 22, 69): 0.3854654012308702
# (24, 23, 69): 0.3820930742222603
#
# Approximating hitting prob for (25, 22, 92)
# (25, 22, 92): 0.4114470876290528
# (24, 23, 92): 0.4103591927457811
#
# Approximating hitting prob for (25, 22, 93)
# (25, 22, 93): 0.41154286998456086
# (24, 23, 93): 0.4098357923651521
#
# Approximating hitting prob for (25, 13, 25)
# (25, 13, 25): 0.2959882305197707
# (24, 14, 25): 0.3038480036890033
#
# Approximating hitting prob for (25, 25, 26)
# (25, 25, 26): 0.3898140487444503
# (24, 26, 26): 0.35819501228612277
#
# Approximating hitting prob for (25, 9, 26)
# (25, 9, 26): 0.27972412006352926
# (24, 10, 26): 0.2858935253342387

# %%
import signal

class TimeoutException(Exception):
    """
    Custom exception for timeout.
    """
    pass

def sigalarmHandler(signum, frame):
    """
    Handler function to be called when SIGALRM is received.
    """
    # We get signal!
    raise TimeoutException()
