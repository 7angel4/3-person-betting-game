# %%
# %run 'game1_global.ipynb'
# %run 'game1_loser_analysis.ipynb'

# %% [markdown]
# # When is player 1 better off giving away $1?

# %%
betterGiving1 = findBetterGiving1(1,1000)
betterGiving1

# %%
exportStateProbs(DATA_DIR + 'game1_better_giving_1_memo_1-1000.csv', betterGiving1)

# %%
# retrieve probabilities from file
betterGiving1, given1 = readApproxBetterGiving1Probs(DATA_DIR + 'game1_better_giving_1_memo_1-100.csv')

# %%
betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
                                       filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv')
# Out:
# Approximating hitting prob for (11, 19, 48)
# (11, 19, 48): 0.5334260883826906
# (10, 19, 48): 0.5333426632228018
#
# Approximating hitting prob for (12, 21, 53)
# (12, 21, 53): 0.5340626283748265
# (11, 21, 53): 0.5334548685835285
#
# Approximating hitting prob for (12, 32, 42)
# (12, 32, 42): 0.5301153617677242
# (11, 32, 42): 0.5299467192997049
#
# Approximating hitting prob for (13, 22, 56)
# (13, 22, 56): 0.5328628830327213
# (12, 22, 56): 0.532734806781722
#
# Approximating hitting prob for (13, 23, 58)
# (13, 23, 58): 0.5343093271797525
# (12, 23, 58): 0.5335330764863161
#
# Approximating hitting prob for (13, 35, 46)
# (13, 35, 46): 0.5303291922468697
# (12, 35, 46): 0.5299937351500015
#
# Approximating hitting prob for (14, 24, 61)
# (14, 24, 61): 0.5334281050874531
# (13, 24, 61): 0.532844623278078
#
# Approximating hitting prob for (14, 25, 63)
# (14, 25, 63): 0.534598505539718
# (13, 25, 63): 0.5335740856592848
#
# Approximating hitting prob for (14, 38, 50)
# (14, 38, 50): 0.5306453312687435
# (13, 38, 50): 0.5300535494230575
#
# Approximating hitting prob for (15, 26, 66)
# (15, 26, 66): 0.5335384252806683
# (14, 26, 66): 0.532976559038264
#
# Approximating hitting prob for (15, 27, 68)
# (15, 27, 68): 0.5347937376379311
# (14, 27, 68): 0.5336038259570041
#
# Approximating hitting prob for (15, 40, 52)
# (15, 40, 52): 0.5298390830172897
# (14, 40, 52): 0.5294060634902246
#
# Approximating hitting prob for (15, 41, 54)
# (15, 41, 54): 0.530814252978444
# (14, 41, 54): 0.5300859465232839
#
# Approximating hitting prob for (16, 27, 69)
# (16, 27, 69): 0.5327214805171471
# (15, 27, 69): 0.5323471322790065
#
# Approximating hitting prob for (16, 28, 71)
# (16, 28, 71): 0.533984832978568
# (15, 28, 71): 0.5330636314503749
#
# Approximating hitting prob for (16, 29, 73)
# (16, 29, 73): 0.5349109988994238
# (15, 29, 73): 0.5336260136575318
#
# Approximating hitting prob for (16, 42, 54)
# (16, 42, 54): 0.528455476635441
# (15, 42, 54): 0.5285157285081951
#
# Approximating hitting prob for (16, 43, 56)
# (16, 43, 56): 0.5300165256608894
# (15, 43, 56): 0.5295344851774494
#
# Approximating hitting prob for (16, 44, 58)
# (16, 44, 58): 0.5309755142180325
# (15, 44, 58): 0.5301059314171186
#
# Approximating hitting prob for (17, 29, 74)
# (17, 29, 74): 0.5332717628242919
# (16, 29, 74): 0.5324865172144486
#
# Approximating hitting prob for (17, 30, 76)
# (17, 30, 76): 0.5341834675713876
# (16, 30, 76): 0.5331293350131605
#
# Approximating hitting prob for (17, 31, 78)
# (17, 31, 78): 0.535032026741298
# (16, 31, 78): 0.5336384909534596
#
# Approximating hitting prob for (17, 44, 56)
# (17, 44, 56): 0.5279972266134371
# (16, 44, 56): 0.5279422800090446
#
# Approximating hitting prob for (17, 45, 58)
# (17, 45, 58): 0.529004914693246
# (16, 45, 58): 0.528895160602941
#
# Approximating hitting prob for (17, 46, 60)
# (17, 46, 60): 0.5301804342251579
# (16, 46, 60): 0.5296194711867167
#
# Approximating hitting prob for (17, 47, 62)
# (17, 47, 62): 0.5311378673662993
# (16, 47, 62): 0.5301263625686753
#
# Approximating hitting prob for (18, 27, 71)
# (18, 27, 71): 0.525620501017532
# (17, 27, 71): 0.5254981980685945
#
# Approximating hitting prob for (18, 28, 73)
# (18, 28, 73): 0.5271004988262395
# (17, 28, 73): 0.5270411065910542
#
# Approximating hitting prob for (18, 31, 79)
# (18, 31, 79): 0.5335270635741508
# (17, 31, 79): 0.5326072076759126
#
# Approximating hitting prob for (18, 32, 81)
# (18, 32, 81): 0.5344121912790228
# (17, 32, 81): 0.5332080138741222
#
# Approximating hitting prob for (18, 33, 83)
# (18, 33, 83): 0.5351589143653502
# (17, 33, 83): 0.5336649245359243
#
# Approximating hitting prob for (18, 45, 56)
# (18, 45, 56): 0.5255722330999105
# (17, 45, 56): 0.5254786841463105
#
# Approximating hitting prob for (18, 47, 60)
# (18, 47, 60): 0.5284828625145415
# (17, 47, 60): 0.5281888889502253
#
# Approximating hitting prob for (18, 48, 62)
# (18, 48, 62): 0.5294526933438758
# (17, 48, 62): 0.5290045013080626
#
# Approximating hitting prob for (18, 49, 64)
# (18, 49, 64): 0.5304295920255223
# (17, 49, 64): 0.5297020995866109
#
# Approximating hitting prob for (18, 50, 66)
# (18, 50, 66): 0.5312826982045813
# (17, 50, 66): 0.5301457096165415
#
# Approximating hitting prob for (19, 20, 58)
# (19, 20, 58): 0.5076781471384154
# (18, 20, 58): 0.507459734940809
#
# Approximating hitting prob for (19, 32, 82)
# (19, 32, 82): 0.5327246501234508
# (18, 32, 82): 0.5320769507714677
#
# Approximating hitting prob for (19, 33, 84)
# (19, 33, 84): 0.5335489429772609
# (18, 33, 84): 0.532734806781722
#
# Approximating hitting prob for (19, 34, 86)
# (19, 34, 86): 0.5345634156030413
# (18, 34, 86): 0.5332648124986303
#
# Approximating hitting prob for (19, 35, 88)
# (19, 35, 88): 0.5345634156030413
# (18, 35, 88): 0.5332648124986303
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/659592125.py:18, in stricterFilter(candidates, timeLim, t, printOnGo, filename, continueFrom)
#      17 try:
# ---> 18     pLarge = LoserAnalysis(sLarge).getHittingProb()  # exact probs
#      19     pSmall = LoserAnalysis(sSmall).getHittingProb()
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:68, in LoserAnalysis.getHittingProb(self, asFloat, approx, t)
#      66     return Q(x, y, z, t)
# ---> 68 sol = self.solveEqns()
#      69 if sol:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:46, in LoserAnalysis.solveEqns(self, asFloat)
#      45 self.getEquations()
# ---> 46 sol = solve(self.equations, self.symbols)
#      47 return {s:float(p) for s, p in sol.items() if sol} if asFloat else sol
#
# File /usr/local/lib/python3.9/site-packages/sympy/solvers/solvers.py:1147, in solve(f, *symbols, **flags)
#    1146 else:
# -> 1147     linear, solution = _solve_system(f, symbols, **flags)
#    1148 assert type(solution) is list
#
# File /usr/local/lib/python3.9/site-packages/sympy/solvers/solvers.py:1799, in _solve_system(exprs, symbols, **flags)
#    1797     continue
# -> 1799 poly = g.as_poly(*symbols, extension=True)
#    1801 if poly is not None:
#
# File /usr/local/lib/python3.9/site-packages/sympy/core/expr.py:1102, in Expr.as_poly(self, *gens, **args)
#    1101 try:
# -> 1102     poly = Poly(self, *gens, **args)
#    1104     if not poly.is_Poly:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:182, in Poly.__new__(cls, rep, *gens, **args)
#     181 else:
# --> 182     return cls._from_expr(rep, opt)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:312, in Poly._from_expr(cls, rep, opt)
#     311 rep, opt = _dict_from_expr(rep, opt)
# --> 312 return cls._from_dict(rep, opt)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polytools.py:261, in Poly._from_dict(cls, rep, opt)
#     259         rep[monom] = domain.convert(coeff)
# --> 261 return cls.new(DMP.from_dict(rep, level, domain), *gens)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/polyclasses.py:279, in DMP.from_dict(cls, rep, lev, dom)
#     278 """Construct and instance of ``cls`` from a ``dict`` representation. """
# --> 279 return cls(dmp_from_dict(rep, lev, dom), dom, lev)
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
#     [... skipping similar frames: dmp_from_dict at line 1012 (2958 times)]
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:1012, in dmp_from_dict(f, u, K)
#    1011 if coeff is not None:
# -> 1012     h.append(dmp_from_dict(coeff, v, K))
#    1013 else:
#
# File /usr/local/lib/python3.9/site-packages/sympy/polys/densebasic.py:998, in dmp_from_dict(f, u, K)
#     996 coeffs = {}
# --> 998 for monom, coeff in f.items():
#     999     head, tail = monom[0], monom[1:]
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# TimeoutException                          Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
#       2                                        filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv')
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/659592125.py:23, in stricterFilter(candidates, timeLim, t, printOnGo, filename, continueFrom)
#      21 except (TimeoutException, RecursionError):
#      22     print(f'Approximating hitting prob for {sLarge}')
# ---> 23     pLarge = LoserAnalysis(sLarge).getHittingProb(approx=True, t=t)
#      24     pSmall = LoserAnalysis(sSmall).getHittingProb(approx=True, t=t)
#      26 finally:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2673109336.py:66, in LoserAnalysis.getHittingProb(self, asFloat, approx, t)
#      64 if approx:
#      65     x, y, z = self.initState
# ---> 66     return Q(x, y, z, t)
#      68 sol = self.solveEqns()
#      69 if sol:
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:31, in Q(x, y, z, t)
#      29 if x==0: return 1
#      30 if z*y==0: return 0
# ---> 31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
#      33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:31, in Q(x, y, z, t)
#      29 if x==0: return 1
#      30 if z*y==0: return 0
# ---> 31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
#      33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
#     [... skipping similar frames: memoize.<locals>.memodict.__call__ at line 8 (11 times), <genexpr> at line 33 (10 times), Q at line 33 (10 times), memoize.<locals>.memodict.__missing__ at line 11 (10 times)]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:11, in memoize.<locals>.memodict.__missing__(self, key)
#      10 def __missing__(self, key):
# ---> 11     ret = self[key] = self.f(*key)
#      12     return ret
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in Q(x, y, z, t)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:33, in <genexpr>(.0)
#      31 if z<y: return Q(x,z,y,t)  # put smaller stack size at front
#      32 if t==0: return 0
# ---> 33 return sum(Q(X,Y,Z,t-1) for (X,Y,Z) in out3(x,y,z))/6
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/3209308454.py:8, in memoize.<locals>.memodict.__call__(self, *args)
#       7 def __call__(self, *args):
# ----> 8     return self[args]
#
# File /var/folders/tk/2zq7clf94gx3rdh5slf6rhc00000gn/T/ipykernel_64207/2027475117.py:12, in sigalarmHandler(signum, frame)
#       8 """
#       9 Handler function to be called when SIGALRM is received.
#      10 """
#      11 # We get signal!
# ---> 12 raise TimeoutException()
#
# TimeoutException:

# %%
betterGiving1, given1 = stricterFilter(betterGiving1, printOnGo=True,
                                       filename=DATA_DIR + 'game1_better_giving_1_stricter_1-100.csv',
                                       continueFrom=(69,64,100))
# Out:
# Approximating hitting prob for (70, 12, 93)
# (70, 12, 93): 0.27064890356707977
# (69, 12, 93): 0.2704508979612977
#
# Approximating hitting prob for (70, 13, 95)
# (70, 13, 95): 0.273002814385276
# (69, 13, 95): 0.2728333555110289
#
# Approximating hitting prob for (70, 15, 99)
# (70, 15, 99): 0.2777183843625525
# (69, 15, 99): 0.27732957441332723
#
# Approximating hitting prob for (70, 30, 84)
# (70, 30, 84): 0.2928672871530125
# (69, 30, 84): 0.29290071879804375
#
# Approximating hitting prob for (70, 50, 94)
# (70, 50, 94): 0.32695735265836573
# (69, 50, 94): 0.3267132634013896
#
# Approximating hitting prob for (70, 58, 98)
# (70, 58, 98): 0.3430616778838396
# (69, 58, 98): 0.3428394039934912
#
# Approximating hitting prob for (70, 60, 99)
# (70, 60, 99): 0.34560612414415176
# (69, 60, 99): 0.34492499438010804
#
# Approximating hitting prob for (70, 84, 90)
# (70, 84, 90): 0.4148018936715927
# (69, 84, 90): 0.41468720846314083
#
# Approximating hitting prob for (71, 12, 94)
# (71, 12, 94): 0.27043453644878807
# (70, 12, 94): 0.2702550831661171
#
# Approximating hitting prob for (71, 15, 100)
# (71, 15, 100): 0.2774240055525448
# (70, 15, 100): 0.27714908068396565
#
# Approximating hitting prob for (71, 36, 88)
# (71, 36, 88): 0.3107284046458855
# (70, 36, 88): 0.3107029569244443
#
# Approximating hitting prob for (71, 44, 92)
# (71, 44, 92): 0.31946810865446534
# (70, 44, 92): 0.31933447137280896
#
# Approximating hitting prob for (71, 52, 96)
# (71, 52, 96): 0.3287350571698488
# (70, 52, 96): 0.32848900976647166
#
# Approximating hitting prob for (71, 60, 100)
# (71, 60, 100): 0.3432269284144038
# (70, 60, 100): 0.3428263666917539
#
# Approximating hitting prob for (72, 14, 99)
# (72, 14, 99): 0.27369224353294386
# (71, 14, 99): 0.27347335165357634
#
# Approximating hitting prob for (72, 40, 91)
# (72, 40, 91): 0.3129742549703007
# (71, 40, 91): 0.31282979281170153
#
# Approximating hitting prob for (72, 46, 94)
# (72, 46, 94): 0.32065055730266634
# (71, 46, 94): 0.32060860453920875
#
# Approximating hitting prob for (72, 50, 96)
# (72, 50, 96): 0.32548552599084296
# (71, 50, 96): 0.32522123422559995
#
# Approximating hitting prob for (72, 54, 98)
# (72, 54, 98): 0.33015250293768666
# (71, 54, 98): 0.3299310590778092
#
# Approximating hitting prob for (73, 11, 94)
# (73, 11, 94): 0.26568088778907833
# (72, 11, 94): 0.26555372470314254
#
# Approximating hitting prob for (73, 13, 98)
# (73, 13, 98): 0.2712824779940791
# (72, 13, 98): 0.27092732614422377
#
# Approximating hitting prob for (73, 14, 100)
# (73, 14, 100): 0.2735392177539206
# (72, 14, 100): 0.2733296833190661
#
# Approximating hitting prob for (73, 26, 85)
# (73, 26, 85): 0.2838182327188731
# (72, 26, 85): 0.2838382526274032
#
# Approximating hitting prob for (73, 40, 92)
# (73, 40, 92): 0.31265646156970867
# (72, 40, 92): 0.31256600858492634
#
# Approximating hitting prob for (73, 44, 94)
# (73, 44, 94): 0.31905281367702304
# (72, 44, 94): 0.31898130581150774
#
# Approximating hitting prob for (74, 12, 97)
# (74, 12, 97): 0.26803823241416097
# (73, 12, 97): 0.2678146488650772
#
# Approximating hitting prob for (74, 13, 99)
# (74, 13, 99): 0.27106341315623816
# (73, 13, 99): 0.2708043750088058
#
# Approximating hitting prob for (74, 30, 88)
# (74, 30, 88): 0.29121346643802504
# (73, 30, 88): 0.2911904861374854
#
# Approximating hitting prob for (74, 40, 93)
# (74, 40, 93): 0.3124715276947375
# (73, 40, 93): 0.3123265733297223
#
# Approximating hitting prob for (74, 46, 96)
# (74, 46, 96): 0.3194592906289733
# (73, 46, 96): 0.31936096416339166
#
# Approximating hitting prob for (74, 52, 99)
# (74, 52, 99): 0.32609715069378836
# (73, 52, 99): 0.32593271890358366
#
# Approximating hitting prob for (74, 54, 100)
# (74, 54, 100): 0.3285392810102394
# (73, 54, 100): 0.32834877261967127
#
# Approximating hitting prob for (75, 13, 100)
# (75, 13, 100): 0.2708561821230972
# (74, 13, 100): 0.27060467983388525
#
# Approximating hitting prob for (75, 38, 93)
# (75, 38, 93): 0.3107255922584125
# (74, 38, 93): 0.3106856959891582
#
# Approximating hitting prob for (75, 40, 94)
# (75, 40, 94): 0.31219750777533284
# (74, 40, 94): 0.31212211416489793
#
# Approximating hitting prob for (75, 48, 98)
# (75, 48, 98): 0.3206660566987458
# (74, 48, 98): 0.3206193374288369
#
# Approximating hitting prob for (75, 52, 100)
# (75, 52, 100): 0.32543894655115896
# (74, 52, 100): 0.3251891291627604
#
# Approximating hitting prob for (76, 42, 96)
# (76, 42, 96): 0.31283229353690856
# (75, 42, 96): 0.31269685409230785
#
# Approximating hitting prob for (77, 42, 97)
# (77, 42, 97): 0.31263411481005815
# (76, 42, 97): 0.3124896740010894
#
# Approximating hitting prob for (78, 42, 98)
# (78, 42, 98): 0.312441399741017
# (77, 42, 98): 0.3119828040723916
#
# Approximating hitting prob for (79, 32, 94)
# (79, 32, 94): 0.2912337154122105
# (78, 32, 94): 0.2911642829888588
#
# Approximating hitting prob for (79, 40, 98)
# (79, 40, 98): 0.31073467566545016
# (78, 40, 98): 0.31068391480047436
#
# Approximating hitting prob for (79, 42, 99)
# (79, 42, 99): 0.3121670959474713
# (78, 42, 99): 0.3120607193357822
#
# Approximating hitting prob for (79, 44, 100)
# (79, 44, 100): 0.3130463381703828
# (78, 44, 100): 0.3128490513416133
#
# Approximating hitting prob for (82, 34, 98)
# (82, 34, 98): 0.2917812876569657
# (81, 34, 98): 0.29172992113254753
#
# Approximating hitting prob for (84, 30, 98)
# (84, 30, 98): 0.2839368557613289
# (83, 30, 98): 0.2838357734914572
#
# Approximating hitting prob for (84, 34, 100)
# (84, 34, 100): 0.29123192191006453
# (83, 34, 100): 0.2911447291167216
#
# Approximating hitting prob for (93, 47, 62)
# (93, 47, 62): 0.2078449082948937
# (92, 47, 62): 0.20783817692579917
#
# Approximating hitting prob for (93, 47, 98)
# (93, 47, 98): 0.3020413154785515
# (92, 47, 98): 0.3020379983481061
#
# Approximating hitting prob for (95, 48, 100)
# (95, 48, 100): 0.30201302025080573
# (94, 48, 100): 0.30196433138324996
#
# Approximating hitting prob for (99, 50, 66)
# (99, 50, 66): 0.2078419114332157
# (98, 50, 66): 0.2078180397808808
#
# Approximating hitting prob for (100, 51, 67)
# (100, 51, 67): 0.2080190772886974
# (99, 51, 67): 0.20801576587712575

# %%
class TimeoutException(Exception):
    """
    Custom exception for timeout.
    """
    pass

def sigalarmHandler(signum, frame):
    """
    Handler function to be called when SIGALRM is received.
    """
    # We get signal!
    raise TimeoutException()

# %% [markdown]
# ## When is player 1 better off giving away $1 to another player?

# %%
betterGiving1ToAnother = findBetterGiving1(1,100, t=10, giveToAnother=True)
betterGiving1ToAnother
# Out:
# {(1, 5, 5): 0.5004434876119833,
#  (2, 4, 5): 0.5015168645690443,
#  (1, 6, 6): 0.506093654740131,
#  (2, 5, 6): 0.5184847144955884,
#  (1, 7, 7): 0.5131205254322682,
#  (2, 6, 7): 0.5396071019936831,
#  (1, 8, 8): 0.5177187986883774,
#  (2, 7, 8): 0.553386673567715,
#  (1, 9, 9): 0.5198030383135193,
#  (2, 8, 9): 0.5596511014686955,
#  (1, 10, 10): 0.521353326527545,
#  (2, 9, 10): 0.5643071756348541,
#  (1, 11, 11): 0.5225738105217701,
#  (2, 10, 11): 0.5679767313216567,
#  (1, 12, 12): 0.5237380978085997,
#  (2, 11, 12): 0.5714793837797846,
#  (1, 12, 36): 0.6316713165390184,
#  (2, 11, 36): 0.6317622599451304,
#  (1, 13, 13): 0.5248276325593998,
#  (2, 12, 13): 0.5747622273980084,
#  (1, 13, 39): 0.6325682808186844,
#  (2, 12, 39): 0.6347403712118326,
#  (1, 14, 14): 0.5256858644409728,
#  (2, 13, 14): 0.57733900685236,
#  (1, 14, 42): 0.6333982655030145,
#  (2, 13, 42): 0.6366529115385103,
#  (1, 15, 15): 0.5268432387720368,
#  (2, 14, 15): 0.5808387485922709,
#  (1, 15, 45): 0.63421194355006,
#  (2, 14, 45): 0.6395029512036614,
#  (1, 16, 16): 0.5279858610539553,
#  (2, 15, 16): 0.5842379051719758,
#  (1, 16, 48): 0.635051999980948,
#  (2, 15, 48): 0.6419747628823096,
#  (1, 17, 17): 0.5283821156475977,
#  (2, 16, 17): 0.5854285708426477,
#  (1, 17, 51): 0.6353974162348219,
#  (2, 16, 51): 0.6431331129655032,
#  (1, 18, 18): 0.5286972339709394,
#  (2, 17, 18): 0.586367542078401,
#  (1, 18, 54): 0.635696343688081,
#  (2, 17, 54): 0.6438519942124338,
#  (1, 19, 19): 0.5290239620908059,
#  (2, 18, 19): 0.5873462049262054,
#  (1, 19, 57): 0.6359734242165406,
#  (2, 18, 57): 0.644798126476528,
#  (1, 20, 20): 0.5292680655049197,
#  (2, 19, 20): 0.5880847500592729,
#  (1, 20, 60): 0.6362249863460855,
#  (2, 19, 60): 0.6453717860378668,
#  (1, 21, 21): 0.5295149142555335,
#  (2, 20, 21): 0.588833317324383,
#  (1, 21, 63): 0.6364634998581686,
#  (2, 20, 63): 0.6461849514015902,
#  (1, 21, 64): 0.646956969794154,
#  (2, 20, 64): 0.6472510681012803,
#  (1, 22, 22): 0.5297588522879303,
#  (2, 21, 22): 0.5895697621096462,
#  (1, 22, 66): 0.6366529446148538,
#  (2, 21, 66): 0.6466174245912294,
#  (1, 22, 67): 0.6471532117394029,
#  (2, 21, 67): 0.647774501235203,
#  (1, 23, 23): 0.5299781484445122,
#  (2, 22, 23): 0.5902254013880421,
#  (1, 23, 69): 0.6368433485854967,
#  (2, 22, 69): 0.6472793649130383,
#  (1, 23, 70): 0.647343764553591,
#  (2, 22, 70): 0.6483569921802232,
#  (1, 24, 24): 0.5301334749530051,
#  (2, 23, 24): 0.5907054714357991,
#  (1, 24, 72): 0.6370145682769819,
#  (2, 23, 72): 0.6476786129157565,
#  (1, 24, 73): 0.6475028948415723,
#  (2, 23, 73): 0.6487869019532507,
#  (1, 25, 25): 0.5303300145853443,
#  (2, 24, 25): 0.5913062701368778,
#  (1, 25, 75): 0.6371719124424207,
#  (2, 24, 75): 0.6482151442816559,
#  (1, 25, 76): 0.6476655808364664,
#  (2, 24, 76): 0.6492909523499552,
#  (1, 26, 26): 0.5305056830450136,
#  (2, 25, 26): 0.5918398411700453,
#  (1, 26, 78): 0.6373261970460974,
#  (2, 25, 78): 0.6485752629701603,
#  (1, 26, 79): 0.6478181289321158,
#  (2, 25, 79): 0.6496998090304239,
#  (1, 27, 27): 0.5306651440964284,
#  (2, 26, 27): 0.5923164712780911,
#  (1, 27, 81): 0.6374779182331624,
#  (2, 26, 81): 0.6491023179636827,
#  (1, 27, 82): 0.6479675843896594,
#  (2, 26, 82): 0.6501630597575742,
#  (1, 28, 28): 0.5308433925108808,
#  (2, 27, 28): 0.5928632397722654,
#  (1, 28, 84): 0.6376227926171485,
#  (2, 27, 84): 0.6494288807018324,
#  (1, 28, 85): 0.6481137818273807,
#  (2, 27, 85): 0.6505545513577707,
#  (1, 29, 29): 0.531019424810327,
#  (2, 28, 29): 0.593397753481219,
#  (1, 29, 87): 0.6377697342725956,
#  (2, 28, 87): 0.6499273246583346,
#  (1, 29, 88): 0.6482600123414454,
#  (2, 28, 88): 0.651006837277092,
#  (1, 30, 30): 0.5311653907136445,
#  (2, 29, 30): 0.5938409764824553,
#  (1, 30, 90): 0.6379076957008163,
#  (2, 29, 90): 0.650248810177776,
#  (1, 30, 91): 0.6483932438525631,
#  (2, 29, 91): 0.6513514100842097,
#  (1, 31, 31): 0.5313585565589595,
#  (2, 30, 31): 0.5944358379798981,
#  (1, 31, 93): 0.6380471455644888,
#  (2, 30, 93): 0.6507426069080341,
#  (1, 31, 94): 0.6485374236333384,
#  (2, 30, 94): 0.6518048371373775,
#  (1, 32, 32): 0.5316609404901015,
#  (2, 31, 32): 0.5953108064912191,
#  (1, 32, 96): 0.6382585695513472,
#  (2, 31, 96): 0.651341801406459,
#  (1, 32, 97): 0.6487406281488678,
#  (2, 31, 97): 0.6524211817198429,
#  (1, 33, 33): 0.5317385375916611,
#  (2, 32, 33): 0.5955452681512389,
#  (1, 33, 99): 0.6383231014972734,
#  (2, 32, 99): 0.6515462628230367,
#  (1, 33, 100): 0.6488068966028214,
#  (2, 32, 100): 0.6526188624860286,
#  (1, 34, 34): 0.5318062779428949,
#  (2, 33, 34): 0.5957485718957984,
#  (1, 35, 35): 0.5318679983996342,
#  (2, 34, 35): 0.5959310706203745,
#  (1, 36, 36): 0.5319251873973311,
#  (2, 35, 36): 0.5961088063515048,
#  (1, 37, 37): 0.5319769849510576,
#  (2, 36, 37): 0.5962632397987264,
#  (1, 38, 38): 0.5320250779543261,
#  (2, 37, 38): 0.5964045750139714,
#  (1, 39, 39): 0.5320778016456672,
#  (2, 38, 39): 0.5965617868740368,
#  (1, 40, 40): 0.5321167325018205,
#  (2, 39, 40): 0.5966842851117292,
#  (1, 41, 41): 0.5321571517934258,
#  (2, 40, 41): 0.5968058406736355,
#  (2, 14, 41): 0.6338000769223442,
#  (1, 42, 42): 0.5322013748645192,
#  (2, 41, 42): 0.5969399487078528,
#  (1, 43, 43): 0.5322408018658233,
#  (2, 42, 43): 0.5970633565449881,
#  (1, 44, 44): 0.5322755651027112,
#  (2, 43, 44): 0.5971704908211825,
#  (2, 15, 44): 0.6355654440591713,
#  (1, 45, 45): 0.5323146613405815,
#  (2, 44, 45): 0.5972896979627089,
#  (1, 46, 46): 0.5323509791656083,
#  (2, 45, 46): 0.5973977583765179,
#  (1, 47, 47): 0.532385014722942,
#  (2, 46, 47): 0.597498806605531,
#  (2, 16, 47): 0.6375855486545072,
#  (1, 48, 48): 0.5324148826610103,
#  (2, 47, 48): 0.5975902130804501,
#  (1, 49, 49): 0.5324444859883317,
#  (2, 48, 49): 0.5976821983913784,
#  (1, 50, 50): 0.5324711785974361,
#  (2, 49, 50): 0.5977623423713782,
#  (2, 17, 50): 0.6383571866691223,
#  (1, 51, 51): 0.5325028988107334,
#  (2, 50, 51): 0.5978603145004572,
#  (1, 52, 52): 0.5325307160155125,
#  (2, 51, 52): 0.597951109063024,
#  (1, 53, 53): 0.5325579709224543,
#  (2, 52, 53): 0.5980328572456773,
#  (2, 18, 53): 0.6393221393725973,
#  (1, 54, 54): 0.5325877396314925,
#  (2, 53, 54): 0.5981236683464157,
#  (1, 55, 55): 0.5326169460426934,
#  (2, 54, 55): 0.5982126271719249,
#  (1, 56, 56): 0.5326397687196227,
#  (2, 55, 56): 0.5982834436230927,
#  (2, 19, 56): 0.639912667869058,
#  (1, 57, 57): 0.5326706620243357,
#  (2, 56, 57): 0.5983790342554488,
#  (1, 58, 58): 0.5326991076796389,
#  (2, 57, 58): 0.5984666865653948,
#  (1, 59, 59): 0.5327241464715744,
#  (2, 58, 59): 0.5985425140825841,
#  (2, 20, 59): 0.6407575699842504,
#  (1, 60, 60): 0.5327515998365764,
#  (2, 59, 60): 0.5986312082973463,
#  (1, 60, 100): 0.6594202186690291,
#  (2, 59, 100): 0.6594714208485749,
#  (1, 61, 61): 0.5327806408660604,
#  (2, 60, 61): 0.5987212090276719,
#  (1, 62, 62): 0.5328041250698572,
#  (2, 61, 62): 0.5987947377389965,
#  (2, 21, 62): 0.6412867749400921,
#  (1, 63, 63): 0.5328350514509137,
#  (2, 62, 63): 0.5988899810697471,
#  (1, 64, 64): 0.5329295505639383,
#  (2, 63, 64): 0.5991591232757963,
#  (1, 65, 65): 0.5329439718496504,
#  (2, 64, 65): 0.5992017586824079,
#  (2, 22, 65): 0.6419519898198954,
#  (1, 66, 66): 0.5329563424020729,
#  (2, 65, 66): 0.5992384734235551,
#  (1, 67, 67): 0.5329692090996461,
#  (2, 66, 67): 0.5992765939092958,
#  (1, 68, 68): 0.5329786027811648,
#  (2, 67, 68): 0.5993086945005419,
#  (2, 23, 68): 0.6423572742552796,
#  (1, 69, 69): 0.5329891210583583,
#  (2, 68, 69): 0.5993394885762248,
#  (1, 70, 70): 0.5330002016333891,
#  (2, 69, 70): 0.5993723499233687,
#  (1, 71, 71): 0.5330110506740166,
#  (2, 70, 71): 0.5994039212931209,
#  (2, 24, 71): 0.6429282380946333,
#  (1, 72, 72): 0.5330189889964267,
#  (2, 71, 72): 0.5994280670237854,
#  (1, 73, 73): 0.5330284819069756,
#  (2, 72, 73): 0.5994564796027452,
#  (1, 74, 74): 0.5330374786723738,
#  (2, 73, 74): 0.599483089520991,
#  (2, 25, 74): 0.6432813280601704,
#  (1, 75, 75): 0.5330459131399347,
#  (2, 74, 75): 0.5995072187134837,
#  (1, 76, 76): 0.5330541822257785,
#  (2, 75, 76): 0.5995340767043049,
#  (1, 77, 77): 0.5330628151513997,
#  (2, 76, 77): 0.5995594131833307,
#  (2, 26, 77): 0.6438085649735813,
#  (1, 78, 78): 0.5330708527028399,
#  (2, 77, 78): 0.5995827154672391,
#  (1, 79, 79): 0.5330799817736117,
#  (2, 78, 79): 0.5996089284693644,
#  (1, 80, 80): 0.5330863985842266,
#  (2, 79, 80): 0.5996283608210977,
#  (2, 27, 80): 0.6441455136835509,
#  (1, 81, 81): 0.5330929477002151,
#  (2, 80, 81): 0.5996482893179816,
#  (1, 82, 82): 0.5331003237247879,
#  (2, 81, 82): 0.5996707812314773,
#  (1, 83, 83): 0.5331074682149571,
#  (2, 82, 83): 0.599691569713289,
#  (2, 28, 83): 0.6446484064082373,
#  (1, 84, 84): 0.5331135542621382,
#  (2, 83, 84): 0.5997103736144981,
#  (1, 85, 85): 0.5331207318286508,
#  (2, 84, 85): 0.5997354950972921,
#  (1, 86, 86): 0.5331267847994886,
#  (2, 85, 86): 0.5997556055140646,
#  (2, 29, 86): 0.6449977587469728,
#  (1, 87, 87): 0.5331327716176396,
#  (2, 86, 87): 0.5997733675104574,
#  (1, 88, 88): 0.5331386592067605,
#  (2, 87, 88): 0.599791989491778,
#  (1, 89, 89): 0.5331450098646887,
#  (2, 88, 89): 0.5998109256983607,
#  (2, 30, 89): 0.6454688981820182,
#  (1, 90, 90): 0.5331506328430625,
#  (2, 89, 90): 0.5998279269388559,
#  (1, 91, 91): 0.5331572150353944,
#  (2, 90, 91): 0.5998475412104778,
#  (1, 92, 92): 0.5331628049374249,
#  (2, 91, 92): 0.5998653528213856,
#  (2, 31, 92): 0.6457769216297059,
#  (1, 93, 93): 0.5331686925265458,
#  (2, 92, 93): 0.5998821225274772,
#  (1, 94, 94): 0.5331750431844738,
#  (2, 93, 94): 0.5999014225738369,
#  (1, 95, 95): 0.5331811953843418,
#  (2, 94, 95): 0.5999193995664617,
#  (2, 32, 95): 0.646300487069002,
#  (1, 96, 96): 0.5331852306982338,
#  (2, 95, 96): 0.599931571660824,
#  (1, 97, 97): 0.5331905890658605,
#  (2, 96, 97): 0.599948109832512,
#  (1, 98, 98): 0.5331949220668428,
#  (2, 97, 98): 0.5999628122671425,
#  (2, 33, 98): 0.6464613042504953,
#  (1, 99, 99): 0.5331994535258853,
#  (2, 98, 99): 0.59997640664427,
#  (2, 60, 99): 0.6594345241875391,
#  (1, 100, 100): 0.533204183442988,
#  (2, 99, 100): 0.5999915225331928,
#  (2, 6, 6): 0.4693452418753916,
#  (3, 5, 6): 0.4740014979614388,
#  (2, 7, 7): 0.48208386784704227,
#  (3, 6, 7): 0.4955659177124083,
#  (2, 8, 8): 0.49122878218725124,
#  (3, 7, 8): 0.5014666050652847,
#  (2, 9, 9): 0.494262775936087,
#  (3, 8, 9): 0.5178661041836018,
#  (2, 10, 10): 0.5004434876119833,
#  (3, 9, 10): 0.5342839937488357,
#  (2, 11, 11): 0.5025522368075666,
#  (3, 10, 11): 0.5431842258389219,
#  (2, 12, 12): 0.506093654740131,
#  (3, 11, 12): 0.5502830045015581,
#  (2, 13, 13): 0.5085600915129808,
#  (3, 12, 13): 0.5546173616138715,
#  (2, 14, 14): 0.5131205254322682,
#  (3, 13, 14): 0.5568134654323105,
#  (2, 15, 15): 0.5156899950147334,
#  (3, 14, 15): 0.5601744353735879,
#  (2, 16, 16): 0.5177187986883774,
#  (3, 15, 16): 0.5635269543091331,
#  (2, 17, 17): 0.5183972606437027,
#  (3, 16, 17): 0.5645428776577504,
#  (2, 18, 18): 0.5198030383135193,
#  (3, 17, 18): 0.5672856342031618,
#  (2, 19, 19): 0.5202042212823249,
#  (3, 18, 19): 0.5700392728655439,
#  (2, 20, 20): 0.521353326527545,
#  (3, 19, 20): 0.5708707459853257,
#  (2, 20, 60): 0.6295677107148301,
#  (3, 19, 60): 0.6304392723627834,
#  (2, 21, 21): 0.5216864383816829,
#  (3, 20, 21): 0.5735340366157767,
#  (2, 21, 63): 0.6301227813711917,
#  (3, 20, 63): 0.6311136824660452,
#  (2, 22, 22): 0.5225738105217701,
#  (3, 21, 22): 0.5764060555111009,
#  (2, 22, 66): 0.630719892059984,
#  (3, 21, 66): 0.6335248486691138,
#  (2, 23, 23): 0.5230437922847974,
#  (3, 22, 23): 0.5785014418639604,
#  (2, 23, 69): 0.6311993336572169,
#  (3, 22, 69): 0.6351912844629037,
#  (2, 23, 71): 0.641735372847127,
#  (3, 22, 71): 0.6419442003410304,
#  (2, 24, 24): 0.5237380978085997,
#  (3, 23, 24): 0.5800568899875528,
#  (2, 24, 72): 0.6316713165390184,
#  (3, 23, 72): 0.6362437075564361,
#  (2, 24, 74): 0.642247130031838,
#  (3, 23, 74): 0.6426527783069992,
#  (2, 25, 25): 0.524088839353757,
#  (3, 24, 25): 0.5809113180896375,
#  (2, 25, 75): 0.6320944621998256,
#  (3, 24, 75): 0.637120230655896,
#  (2, 25, 77): 0.6426200988797439,
#  (3, 24, 77): 0.6434655302164304,
#  (2, 26, 26): 0.5248276325593998,
#  (3, 25, 26): 0.5813076057596235,
#  (2, 26, 78): 0.6325682808186844,
#  (3, 25, 78): 0.6376919552511473,
#  (2, 26, 80): 0.6431372309702534,
#  (3, 25, 80): 0.6440306064666632,
#  (2, 27, 27): 0.5251138752349743,
#  (3, 26, 27): 0.582175396704432,
#  (2, 27, 81): 0.6329491879890007,
#  (3, 26, 81): 0.6380589868954174,
#  (2, 27, 83): 0.6434930993486342,
#  (3, 26, 83): 0.6444297387021796,
#  (2, 28, 28): 0.5256858644409728,
#  (3, 27, 28): 0.5828712072018578,
#  (2, 28, 84): 0.6333982655030145,
#  (3, 27, 84): 0.6388404320458433,
#  (2, 28, 86): 0.6439339408531474,
#  (3, 27, 86): 0.6451290222156598,
#  (2, 29, 29): 0.5261190653101662,
#  (3, 28, 29): 0.5831610717370319,
#  (2, 29, 87): 0.6337884340494758,
#  (3, 28, 87): 0.6392850773298446,
#  (2, 29, 88): 0.6449055088252976,
#  (3, 28, 88): 0.644998916418991,
#  (2, 29, 89): 0.6443102007972193,
#  (3, 28, 89): 0.6455973005470034,
#  (2, 30, 30): 0.5268432387720368,
#  (3, 29, 30): 0.5837543951845078,
#  (2, 30, 90): 0.63421194355006,
#  (3, 29, 90): 0.6395496715386797,
#  (2, 30, 92): 0.6447714007910802,
#  (3, 29, 92): 0.645899006413106,
#  (2, 31, 31): 0.5275615907974732,
#  (3, 30, 31): 0.5843650506359125,
#  (2, 31, 93): 0.6345886665629393,
#  (3, 30, 93): 0.640241909791021,
#  (2, 31, 94): 0.6457147711805027,
#  (3, 30, 94): 0.645921002181451,
#  (2, 31, 95): 0.6453186488922336,
#  (3, 30, 95): 0.6465264150324307,
#  (2, 32, 32): 0.5279858610539553,
#  (3, 31, 32): 0.5845853886973108,
#  (2, 32, 96): 0.635051999980948,
#  (3, 31, 96): 0.6406006558112753,
#  (2, 32, 97): 0.6461740362082762,
#  (3, 31, 97): 0.646306424272638,
#  (2, 32, 98): 0.645574742480821,
#  (3, 31, 98): 0.6468801499866637,
#  (2, 33, 33): 0.5281335800034718,
#  (3, 32, 33): 0.5851356798220545,
#  (2, 33, 99): 0.6352244269589663,
#  (3, 32, 99): 0.6407475974667225,
#  (2, 33, 100): 0.6463518546302647,
#  (3, 32, 100): 0.6464238949061373,
#  (2, 34, 34): 0.5283821156475977,
#  (3, 33, 34): 0.5857237441309336,
#  (2, 35, 35): 0.5284957328870937,
#  (3, 34, 35): 0.5859061105501363,
#  (2, 36, 36): 0.5286972339709394,
#  (3, 35, 36): 0.5863498462346949,
#  (2, 37, 37): 0.5288185579984419,
#  (3, 36, 37): 0.5868146350118123,
#  (2, 38, 38): 0.5290239620908059,
#  (3, 37, 38): 0.5870175583784231,
#  (2, 39, 39): 0.5291136651340412,
#  (3, 38, 39): 0.5874601198527918,
#  (2, 40, 40): 0.5292680655049197,
#  (3, 39, 40): 0.5879006636702145,
#  (2, 41, 41): 0.5293537993869498,
#  (3, 40, 41): 0.5880250307213077,
#  (2, 42, 42): 0.5295149142555335,
#  (3, 41, 42): 0.5884515170927959,
#  (2, 43, 43): 0.5296025334891361,
#  (3, 42, 43): 0.5889065483486172,
#  (2, 44, 44): 0.5297588522879303,
#  (3, 43, 44): 0.58904100368444,
#  (2, 45, 45): 0.5298143874684583,
#  (3, 44, 45): 0.5894975068375417,
#  (2, 46, 46): 0.5299781484445122,
#  (3, 45, 46): 0.5899698039446054,
#  (3, 45, 47): 0.5976479643759843,
#  (2, 47, 47): 0.5300331874798896,
#  (3, 46, 47): 0.5905717768558739,
#  (3, 46, 48): 0.5985042612914698,
#  (2, 48, 48): 0.5301334749530051,
#  (3, 47, 48): 0.5909074355884519,
#  (3, 47, 49): 0.5986030107146184,
#  (2, 49, 49): 0.5302022075945402,
#  (3, 48, 49): 0.5910961361274111,
#  (3, 48, 50): 0.5987849967558723,
#  (2, 50, 50): 0.5303300145853443,
#  (3, 49, 50): 0.5911701775220579,
#  (3, 49, 51): 0.5989254058335026,
#  (2, 51, 51): 0.530385152849752,
#  (3, 50, 51): 0.5913320862228827,
#  (3, 50, 52): 0.5990053844317854,
#  (2, 52, 52): 0.5305056830450136,
#  (3, 51, 52): 0.5914818062911734,
#  (3, 51, 53): 0.5991632908950618,
#  (2, 53, 53): 0.5305588367288184,
#  (3, 52, 53): 0.5915376556969635,
#  (3, 52, 54): 0.5992909986568359,
#  (2, 18, 54): 0.6281354554321411,
#  (3, 18, 53): 0.6282727553334942,
#  (2, 54, 54): 0.5306651440964284,
#  (3, 53, 54): 0.5916624692786923,
#  (3, 53, 55): 0.5993634193106573,
#  (2, 55, 55): 0.5307288160574269,
#  (3, 54, 55): 0.5918032587342715,
#  (3, 54, 56): 0.599478690367322,
#  (2, 56, 56): 0.5308433925108808,
#  (3, 55, 56): 0.5918555193568054,
#  (3, 55, 57): 0.5995967232986587,
#  (2, 19, 57): 0.6287977430555555,
#  (3, 19, 56): 0.6300712318900404,
#  (2, 57, 57): 0.5308984976989449,
#  (3, 56, 57): 0.5919839713363054,
#  (3, 56, 58): 0.5996486531577588,
#  (2, 58, 58): 0.531019424810327,
#  (3, 57, 58): 0.5921011938972294,
#  (3, 57, 59): 0.5997754843964335,
#  (2, 59, 59): 0.5310688408673304,
#  (3, 58, 59): 0.5921501799617691,
#  (3, 58, 60): 0.5998798898742993,
#  (3, 20, 59): 0.6308086193510897,
#  (2, 60, 60): 0.5311653907136445,
#  (3, 59, 60): 0.5922371045921607,
#  (3, 59, 61): 0.5999254359991278,
#  (2, 61, 61): 0.5312331972175651,
#  (3, 60, 61): 0.5923383678174059,
#  (3, 60, 62): 0.6000335791037951,
#  (2, 62, 62): 0.5313585565589595,
#  (3, 61, 62): 0.5923812182202493,
#  (3, 61, 63): 0.6001316835382479,
#  (3, 21, 62): 0.6330898947537215,
#  (2, 63, 63): 0.5315653498577452,
#  (3, 62, 63): 0.5925049402826467,
#  (3, 62, 64): 0.6001830180231672,
#  (2, 64, 64): 0.5316609404901015,
#  (3, 63, 64): 0.5925977525021593,
#  (3, 63, 65): 0.6002796836366832,
#  (2, 65, 65): 0.531690378435706,
#  (3, 64, 65): 0.592631788059493,
#  (3, 64, 66): 0.6003744142841115,
#  (3, 22, 65): 0.6346719031810446,
#  (2, 66, 66): 0.5317385375916611,
#  (3, 65, 66): 0.5927241372101983,
#  (3, 65, 67): 0.6004132789875781,
#  (2, 67, 67): 0.5317613271922471,
#  (3, 66, 67): 0.5928214643505817,
#  (3, 66, 68): 0.6005093823032567,
#  (2, 68, 68): 0.5318062779428949,
#  (3, 67, 68): 0.5928686808307507,
#  (3, 67, 69): 0.600597067689546,
#  (3, 23, 68): 0.6353617433984912,
#  (2, 69, 69): 0.5318268845048181,
#  (3, 68, 69): 0.5929494532612746,
#  (3, 68, 70): 0.6006299621130332,
#  (2, 70, 70): 0.5318679983996342,
#  (3, 69, 70): 0.5930456061914681,
#  (3, 69, 71): 0.6007228404852326,
#  (2, 71, 71): 0.5318853634799066,
#  (3, 70, 71): 0.5930765987252112,
#  (3, 70, 72): 0.6007995941400363,
#  (3, 24, 71): 0.6368715792445682,
#  (2, 72, 72): 0.5319251873973311,
#  (3, 71, 72): 0.5931494493714966,
#  (3, 71, 73): 0.600835432358084,
#  (2, 73, 73): 0.5319396086830429,
#  (3, 72, 73): 0.5932231434645379,
#  (3, 72, 74): 0.6009037846216702,
#  (2, 74, 74): 0.5319769849510576,
#  (3, 73, 74): 0.5932469749699402,
#  (3, 73, 75): 0.6009758414357144,
#  (3, 25, 74): 0.637481490478247,
#  (2, 75, 75): 0.5319899508776609,
#  (3, 74, 75): 0.5933288389197955,
#  (3, 74, 76): 0.600999127181451,
#  (2, 76, 76): 0.5320250779543261,
#  (3, 75, 76): 0.5934025495510085,
#  (3, 75, 77): 0.6010797838447729,
#  (2, 77, 77): 0.5320406899883995,
#  (3, 76, 77): 0.5934319544202696,
#  (3, 76, 78): 0.6011526014147149,
#  (3, 26, 77): 0.6378954574537672,
#  (2, 78, 78): 0.5320778016456672,
#  (3, 77, 78): 0.5934982559505665,
#  (3, 77, 79): 0.6011803855431506,
#  (2, 79, 79): 0.5320866991820353,
#  (3, 78, 79): 0.5935844198250606,
#  (3, 78, 80): 0.601249680482523,
#  (2, 80, 80): 0.5321167325018205,
#  (3, 79, 80): 0.5935997672483869,
#  (3, 79, 81): 0.6013253922325102,
#  (3, 27, 80): 0.6386029439004047,
#  (2, 81, 81): 0.5321278792295382,
#  (3, 80, 81): 0.5936775793461786,
#  (3, 80, 82): 0.6013561366936782,
#  (2, 82, 82): 0.5321571517934258,
#  (3, 81, 82): 0.5937518688134007,
#  (3, 81, 83): 0.601426787763129,
#  (2, 83, 83): 0.5321697869565954,
#  (3, 82, 83): 0.5937740134252909,
#  (3, 82, 84): 0.6014979184395587,
#  (3, 28, 83): 0.6390618120120578,
#  (2, 84, 84): 0.5322013748645192,
#  (3, 83, 84): 0.5938440691205609,
#  (3, 83, 85): 0.6015204268912259,
#  (2, 85, 85): 0.5322126208212671,
#  (3, 84, 85): 0.5939187058893884,
#  (3, 84, 86): 0.6015962874847584,
#  (2, 86, 86): 0.5322408018658233,
#  (3, 85, 86): 0.5939462915597639,
#  (3, 85, 87): 0.6016669550923809,
#  (3, 29, 86): 0.6394178126958119,
#  (2, 87, 87): 0.532251948593541,
#  (3, 86, 87): 0.5940234421306881,
#  (3, 86, 88): 0.601684650936087,
#  (2, 88, 88): 0.5322755651027112,
#  (3, 87, 88): 0.5940922243867381,
#  (3, 87, 89): 0.6017641830037341,
#  (2, 89, 89): 0.5322872410519229,
#  (3, 88, 89): 0.5941109952116039,
#  (3, 88, 90): 0.6018371328790496,
#  (3, 30, 89): 0.6400308661821116,
#  (2, 90, 90): 0.5323146613405815,
#  (3, 89, 90): 0.5941841270068079,
#  (3, 89, 91): 0.6018690019358922,
#  (2, 91, 91): 0.5323265357478535,
#  (3, 90, 91): 0.5942605664363495,
#  (3, 90, 92): 0.6019353200043608,
#  (2, 92, 92): 0.5323509791656083,
#  (3, 91, 92): 0.5942813383799895,
#  (3, 91, 93): 0.6020062026082151,
#  (3, 31, 92): 0.6404354725524564,
#  (2, 93, 93): 0.5323607366869041,
#  (3, 92, 93): 0.5943591835541245,
#  (3, 92, 94): 0.6020233692304272,
#  (2, 94, 94): 0.532385014722942,
#  (3, 93, 94): 0.5944335226358617,
#  (3, 93, 95): 0.6021049851077072,
#  (2, 95, 95): 0.5323954668474488,
#  (3, 94, 95): 0.5946310545585023,
#  (3, 94, 96): 0.6023667182128402,
#  (3, 32, 95): 0.6407084350761655,
#  (2, 96, 96): 0.5324148826610103,
#  (3, 95, 96): 0.5947102558627156,
#  (3, 95, 97): 0.6023858198011397,
#  (2, 97, 97): 0.5324242763425291,
#  (3, 96, 97): 0.5947447048743416,
#  (3, 96, 98): 0.6024215422519856,
#  (2, 98, 98): 0.5324444859883317,
#  (3, 97, 98): 0.5947557192966858,
#  (3, 97, 99): 0.6024459691315688,
#  (3, 33, 98): 0.6412241118075667,
#  (2, 99, 99): 0.532454276585971,
#  (3, 98, 99): 0.5947932940227607,
#  (3, 98, 100): 0.6024601919592203,
#  (2, 100, 100): 0.5324711785974361,
#  (3, 99, 100): 0.594818828959847,
#  (3, 7, 7): 0.44019443200773933,
#  (4, 6, 7): 0.45015962312549745,
#  (3, 8, 8): 0.4467808250351403,
#  (4, 7, 8): 0.4742427237336788,
#  (3, 9, 9): 0.4693452418753916,
#  (4, 8, 9): 0.49163882961608163,
#  (3, 10, 10): 0.47808047262654746,
#  (4, 9, 10): 0.4967868813136124,
#  (3, 11, 11): 0.48470119889837254,
#  (4, 10, 11): 0.502631388497265,
#  (3, 12, 12): 0.49122878218725124,
#  (4, 11, 12): 0.5167916853217244,
#  (3, 13, 13): 0.4935336740990533,
#  (4, 12, 13): 0.5312539030085183,
#  (3, 14, 14): 0.4956136137995563,
#  (4, 13, 14): 0.5362733208066606,
#  (3, 15, 15): 0.5004434876119833,
#  (4, 14, 15): 0.5434280646422885,
#  (3, 16, 16): 0.5020230153135531,
#  (4, 15, 16): 0.5478861768933428,
#  (3, 17, 17): 0.5030273123274739,
#  (4, 16, 17): 0.5516700278846806,
#  (3, 17, 51): 0.615492767394452,
#  (4, 16, 51): 0.6161914720719234,
#  (3, 18, 18): 0.506093654740131,
#  (4, 17, 18): 0.5534884163999391,
#  (3, 18, 54): 0.6177887948462294,
#  (4, 17, 54): 0.6190445216843214,
#  (3, 19, 19): 0.5081359535618724,
#  (4, 18, 19): 0.5547300196394097,
#  (3, 19, 57): 0.6196168251155819,
#  (4, 18, 57): 0.6206401410269438,
#  (3, 20, 20): 0.5092737466976579,
#  (4, 19, 20): 0.5579425760279598,
#  (3, 20, 60): 0.6203943672574895,
#  (4, 19, 60): 0.6215706116424494,
#  (3, 21, 21): 0.5131205254322682,
#  (4, 20, 21): 0.560842097902801,
#  (3, 21, 63): 0.6225665568796677,
#  (4, 20, 63): 0.6242344480325662,
#  (3, 22, 22): 0.5144697094785687,
#  (4, 21, 22): 0.5619077515336839,
#  (3, 22, 66): 0.624324547991922,
#  (4, 21, 66): 0.6264198516539231,
#  (3, 23, 23): 0.5164820742095548,
#  (4, 22, 23): 0.5623249765290268,
#  (3, 23, 69): 0.6249592168686177,
#  (4, 22, 69): 0.6269802310633965,
#  (3, 24, 24): 0.5177187986883774,
#  (4, 23, 24): 0.5647878741331352,
#  (3, 24, 72): 0.6264351494627344,
#  (4, 23, 72): 0.6274335588875342,
#  (3, 25, 25): 0.518164866255144,
#  (4, 24, 25): 0.5672480925534301,
#  (3, 25, 75): 0.6270372712175482,
#  (4, 24, 75): 0.6295931629610577,
#  (3, 26, 26): 0.5187485975630408,
#  (4, 25, 26): 0.5679596473903029,
#  (3, 26, 78): 0.6274313096961844,
#  (4, 25, 78): 0.6313052441087063,
#  (3, 27, 27): 0.5198030383135193,
#  (4, 26, 27): 0.5688839492677692,
#  (3, 27, 81): 0.6281354554321411,
#  (4, 26, 81): 0.6318541625652001,
#  (3, 28, 28): 0.5200221029356974,
#  (4, 27, 28): 0.571275650042761,
#  (3, 28, 84): 0.6286252830011939,
#  (4, 27, 84): 0.6323139071999525,
#  (3, 29, 29): 0.5204572222328067,
#  (4, 28, 29): 0.5737307747061763,
#  (3, 29, 87): 0.6289591721494013,
#  (4, 28, 87): 0.6344316035464191,
#  (3, 30, 30): 0.521353326527545,
#  (4, 29, 30): 0.5746018071326356,
#  (3, 30, 90): 0.6295677107148301,
#  (4, 29, 90): 0.636175140296618,
#  (4, 29, 93): 0.6410474510575962,
#  (3, 31, 31): 0.5216136373499127,
#  (4, 30, 31): 0.5765721483693628,
#  (3, 31, 93): 0.6299875487412996,
#  (4, 30, 93): 0.6364735716047266,
#  (4, 30, 96): 0.6419747628823096,
#  (3, 32, 32): 0.5218702105454792,
#  (4, 31, 32): 0.57749606986888,
#  (3, 32, 96): 0.6301997334840557,
#  (4, 31, 96): 0.6374555090105252,
#  (3, 32, 98): 0.6418308477122813,
#  (4, 31, 98): 0.64189207202387,
#  (4, 31, 99): 0.6423986858371861,
#  (3, 33, 33): 0.5225738105217701,
#  (4, 32, 33): 0.5782692459334621,
#  (3, 33, 99): 0.630719892059984,
#  (4, 32, 99): 0.6381510714353757,
#  (3, 34, 34): 0.5229414210020491,
#  (4, 33, 34): 0.5785625834846907,
#  (3, 35, 35): 0.5230813339345289,
#  (4, 34, 35): 0.5789247529064845,
#  (4, 34, 36): 0.586367542078401,
#  (3, 36, 36): 0.5237380978085997,
#  (4, 35, 36): 0.5796576089084913,
#  (3, 37, 37): 0.5239908341483345,
#  (4, 36, 37): 0.5802491462334248,
#  (4, 36, 38): 0.5873462049262054,
#  (3, 38, 38): 0.5241945844235296,
#  (4, 37, 38): 0.5804661601223137,
#  (4, 37, 39): 0.58762088741977,
#  (3, 39, 39): 0.5248276325593998,
#  (4, 38, 39): 0.5806532895349625,
#  (4, 38, 40): 0.5880847500592729,
#  (3, 40, 40): 0.5250622099866212,
#  (4, 39, 40): 0.5812160504411591,
#  (4, 39, 41): 0.5883475912219089,
#  (3, 41, 41): 0.5251781094938103,
#  (4, 40, 41): 0.581744395412073,
#  (4, 40, 42): 0.588833317324383,
#  (3, 42, 42): 0.5256858644409728,
#  (4, 41, 42): 0.5820000755463682,
#  (4, 41, 43): 0.5890965057886247,
#  (3, 43, 43): 0.5260332321991058,
#  (4, 42, 43): 0.5820988084313451,
#  (4, 42, 44): 0.5895697621096462,
#  (3, 44, 44): 0.5262173020499924,
#  (4, 43, 44): 0.5826556321339057,
#  (4, 43, 45): 0.5897379057011973,
#  (3, 45, 45): 0.5268432387720368,
#  (4, 44, 45): 0.5831276480920508,
#  (4, 44, 46): 0.5902254013880421,
#  (3, 46, 46): 0.5271012011740249,
#  (4, 45, 46): 0.583270240208344,
#  (3, 47, 47): 0.5277467521676913,
#  (4, 46, 47): 0.5834219779335806,
#  (3, 48, 48): 0.5279858610539553,
#  (4, 47, 48): 0.583798849790005,
#  (3, 49, 49): 0.5280672950113465,
#  (4, 48, 49): 0.58421129525373,
#  (4, 48, 50): 0.5913062701368778,
#  (3, 50, 50): 0.5281774061584447,
#  (4, 49, 50): 0.5844009880829905,
#  (4, 49, 51): 0.5914750587171248,
#  (4, 17, 50): 0.6165013477948399,
#  (3, 51, 51): 0.5283821156475977,
#  (4, 50, 51): 0.5845099911725855,
#  (4, 50, 52): 0.5918398411700453,
#  (3, 52, 52): 0.5284536267019764,
#  (4, 51, 52): 0.5848932467632814,
#  (4, 51, 53): 0.5920035690697556,
#  (3, 53, 53): 0.5285409151721452,
#  (4, 52, 53): 0.5853034761120002,
#  (4, 52, 54): 0.5923164712780911,
#  (4, 18, 53): 0.6181123476371319,
#  (3, 54, 54): 0.5286972339709394,
#  (4, 53, 54): 0.5854581080172822,
#  (4, 53, 55): 0.5925202546296297,
#  (3, 55, 55): 0.5287723172704025,
#  (4, 54, 55): 0.5854904070665887,
#  (4, 54, 56): 0.5928632397722654,
#  (3, 56, 56): 0.528849186692408,
#  (4, 55, 56): 0.585891077352072,
#  (4, 55, 57): 0.5930314164401599,
#  (3, 57, 57): 0.5290239620908059,
#  (4, 56, 57): 0.5862959648713356,
#  (4, 56, 58): 0.593397753481219,
#  (3, 58, 58): 0.529078174217599,
#  (4, 57, 58): 0.5864241191637455,
#  (4, 57, 59): 0.5935495408209707,
#  (3, 59, 59): 0.5291300048476689,
#  (4, 58, 59): 0.5865677035703398,
#  (4, 58, 60): 0.5938409764824553,
#  (4, 20, 59): 0.6220633830060628,
#  (3, 60, 60): 0.5292680655049197,
#  (4, 59, 60): 0.5869693992224677,
#  (4, 59, 61): 0.5940510939537503,
#  (3, 61, 61): 0.5293283636788938,
#  (4, 60, 61): 0.5873862934543769,
#  (4, 60, 62): 0.5944358379798981,
#  (3, 62, 62): 0.5293856188292774,
#  (4, 61, 62): 0.5875231799014378,
#  (4, 61, 63): 0.5950046353187607,
#  (4, 21, 62): 0.6242603302712578,
#  (3, 63, 63): 0.5295149142555335,
#  (4, 62, 63): 0.5881961511837626,
#  (4, 62, 64): 0.5953108064912191,
#  (3, 64, 64): 0.5295760062617487,
#  (4, 63, 64): 0.5883510807761351,
#  (4, 63, 65): 0.5954003937672526,
#  (3, 65, 65): 0.5296215523865772,
#  (4, 64, 65): 0.5884918206171993,
#  (4, 64, 66): 0.5955452681512389,
#  (4, 22, 65): 0.6248344032868888,
#  (3, 66, 66): 0.5297588522879303,
#  (4, 65, 66): 0.5885713692230182,
#  (4, 65, 67): 0.5956124131282917,
#  (3, 67, 67): 0.5298012561601383,
#  (4, 66, 67): 0.5886375219097698,
#  (4, 66, 68): 0.5957485718957984,
#  (3, 68, 68): 0.529846471521533,
#  (4, 67, 68): 0.5887764094756051,
#  (4, 67, 69): 0.5958102427380226,
#  (4, 23, 68): 0.6256472213490067,
#  (3, 69, 69): 0.5299781484445122,
#  (4, 68, 69): 0.5889008426793849,
#  (4, 68, 70): 0.5959310706203745,
#  (3, 70, 70): 0.5300216107597081,
#  (4, 69, 70): 0.5889561794018526,
#  (4, 69, 71): 0.5959897480535233,
#  (3, 71, 71): 0.5300431103829023,
#  (4, 70, 71): 0.5889931587537468,
#  (4, 70, 72): 0.5961088063515048,
#  (4, 24, 71): 0.6278304253935291,
#  (3, 72, 72): 0.5301334749530051,
#  (4, 71, 72): 0.5891061971572339,
#  (4, 71, 73): 0.596151656754348,
#  (3, 73, 73): 0.5301830563917255,
#  (4, 72, 73): 0.5892122399140968,
#  (4, 72, 74): 0.5962632397987264,
#  (3, 74, 74): 0.5302213918736981,
#  (4, 73, 74): 0.5892634255554708,
#  (4, 73, 75): 0.5963052632929854,
#  (4, 25, 74): 0.6295195515588748,
#  (3, 75, 75): 0.5303300145853443,
#  (4, 74, 75): 0.5893170257699115,
#  (4, 74, 76): 0.5964045750139714,
#  (3, 76, 76): 0.5303685816017206,
#  (4, 75, 76): 0.5894298161008231,
#  (4, 75, 77): 0.5964538256892581,
#  (3, 77, 77): 0.530398449539789,
#  (4, 76, 77): 0.5895255886530678,
#  (4, 76, 78): 0.5965617868740368,
#  (4, 26, 77): 0.6298821178967892,
#  (3, 78, 78): 0.5305056830450136,
#  (4, 77, 78): 0.5895662560172484,
#  (4, 77, 79): 0.5965969635652171,
#  (3, 79, 79): 0.5305416701066065,
#  (4, 78, 79): 0.5895925020957171,
#  (4, 78, 80): 0.5966842851117292,
#  (3, 80, 80): 0.5305744818392352,
#  (4, 79, 80): 0.5896747464235211,
#  (4, 79, 81): 0.5967190152722739,
#  (4, 27, 80): 0.6305618532913343,
#  (3, 81, 81): 0.5306651440964284,
#  (4, 80, 81): 0.5897592564808464,
#  (4, 80, 82): 0.5968058406736355,
#  (3, 82, 82): 0.5307149570695524,
#  (4, 81, 82): 0.5898063737319853,
#  (4, 81, 83): 0.5968468057249064,
#  (3, 83, 83): 0.5307373497540179,
#  (4, 82, 83): 0.5898409219726414,
#  (4, 82, 84): 0.5969399487078528,
#  (4, 28, 83): 0.632644984858973,
#  (3, 84, 84): 0.5308433925108808,
#  (4, 83, 84): 0.5899515788794052,
#  (4, 83, 85): 0.5969784495715423,
#  (3, 85, 85): 0.5308807357025521,
#  (4, 84, 85): 0.590039297342038,
#  (4, 84, 86): 0.5970633565449881,
#  (3, 86, 86): 0.5309161604663076,
#  (4, 85, 86): 0.5900632776909854,
#  (4, 85, 87): 0.5971014439543854,
#  (4, 29, 86): 0.6341472958369321,
#  (3, 87, 87): 0.531019424810327,
#  (4, 86, 87): 0.5900916241172586,
#  (4, 86, 88): 0.5971704908211825,
#  (3, 88, 88): 0.5310544195816186,
#  (4, 87, 88): 0.5901717184827432,
#  (4, 87, 89): 0.5972081978526308,
#  (3, 89, 89): 0.5310768122660842,
#  (4, 88, 89): 0.5902565427653305,
#  (4, 88, 90): 0.5972896979627089,
#  (4, 30, 89): 0.6345409208612762,
#  (3, 90, 90): 0.5311653907136445,
#  (4, 89, 90): 0.5902962343773815,
#  (4, 89, 91): 0.597325304646353,
#  (3, 91, 91): 0.5312151706104252,
#  (4, 90, 91): 0.5903176513097174,
#  (4, 90, 92): 0.5973977583765179,
#  (3, 92, 92): 0.5312498676946266,
#  (4, 91, 92): 0.5904037490315247,
#  (4, 91, 93): 0.5974274443946976,
#  (4, 31, 92): 0.6350845636410015,
#  (3, 93, 93): 0.5313585565589595,
#  (4, 92, 93): 0.5904832480228285,
#  (4, 92, 94): 0.597498806605531,
#  (3, 94, 94): 0.5313904421539738,
#  (4, 93, 94): 0.5905108667695473,
#  (4, 93, 95): 0.5975329083155515,
#  (3, 95, 95): 0.5316191650684178,
#  (4, 94, 95): 0.590518887782816,
#  (4, 94, 96): 0.5975902130804501,
#  (4, 32, 95): 0.6364357157297329,
#  (3, 96, 96): 0.5316609404901015,
#  (4, 95, 96): 0.5905898365393571,
#  (4, 95, 97): 0.5976202960147504,
#  (3, 97, 97): 0.5316739725693914,
#  (4, 96, 97): 0.5906563199895426,
#  (4, 96, 98): 0.5976821983913784,
#  (3, 98, 98): 0.5317002351860319,
#  (4, 97, 98): 0.5906784149869176,
#  (4, 97, 99): 0.5977121324821334,
#  (4, 33, 98): 0.6369774566197142,
#  (3, 99, 99): 0.5317385375916611,
#  (4, 98, 99): 0.5907043468401243,
#  (4, 98, 100): 0.5977623423713782,
#  (3, 100, 100): 0.53174793127318,
#  (4, 99, 100): 0.5907712272064303,
#  (4, 6, 6): 0.38529044734034446,
#  (5, 5, 6): 0.3960503141458788,
#  (4, 7, 7): 0.4024199248187945,
#  (5, 6, 7): 0.42052775091978695,
#  (4, 8, 8): 0.4285657819670951,
#  (5, 7, 8): 0.43856474403143997,
#  (4, 9, 9): 0.4379673356555573,
#  (5, 8, 9): 0.45166674671141765,
#  (4, 10, 10): 0.4425199304814645,
#  (5, 9, 10): 0.47425496198072786,
#  (4, 11, 11): 0.44806372408931566,
#  (5, 10, 11): 0.4900424495175617,
#  (4, 12, 12): 0.4693452418753916,
#  (5, 11, 12): 0.4940311588415976,
#  (4, 13, 13): 0.47675533508188117,
#  (5, 12, 13): 0.4998499491682755,
#  (4, 14, 14): 0.48208386784704227,
#  (5, 13, 14): 0.5030468273700656,
#  (4, 15, 15): 0.4852509608016224,
#  (5, 14, 15): 0.5158300733289302,
#  (4, 16, 16): 0.49122878218725124,
#  (5, 15, 16): 0.5299008986445578,
#  (4, 17, 17): 0.49264620272993614,
#  (5, 16, 17): 0.5345106990063337,
#  (4, 17, 51): 0.606547849164465,
#  (5, 16, 51): 0.6068501173284052,
#  (4, 18, 18): 0.494262775936087,
#  (5, 17, 18): 0.5398539672824688,
#  (4, 18, 54): 0.6085029752832394,
#  (5, 17, 54): 0.6086456500903911,
#  (4, 19, 19): 0.4959453033709292,
#  (5, 18, 19): 0.543222478630036,
#  (4, 19, 57): 0.6093778611037021,
#  (5, 18, 57): 0.6110883711250402,
#  (4, 20, 20): 0.5004434876119833,
#  (5, 19, 20): 0.5470177244216667,
#  (4, 20, 60): 0.6124243742485055,
#  (5, 19, 60): 0.6127122872794205,
#  (4, 21, 21): 0.501754931550492,
#  (5, 20, 21): 0.5505264463888041,
#  (4, 21, 63): 0.614252404517858,
#  (5, 20, 63): 0.6159845133914207,
#  (4, 22, 22): 0.5025522368075666,
#  (5, 21, 22): 0.5517973221921625,
#  (4, 22, 66): 0.6150826703511068,
#  (5, 21, 66): 0.6187561455845992,
#  (4, 23, 23): 0.5031675890997307,
#  (5, 22, 23): 0.5531504092469813,
#  (4, 23, 69): 0.6156283473259496,
#  (5, 22, 69): 0.6198103713388458,
#  (4, 24, 24): 0.506093654740131,
#  (5, 23, 24): 0.5539436130374774,
#  (4, 24, 72): 0.6177887948462294,
#  (5, 23, 72): 0.6206770046116361,
#  (4, 25, 25): 0.5079278041330082,
#  (5, 24, 25): 0.5569707103687193,
#  (4, 25, 75): 0.619438130170494,
#  (5, 24, 75): 0.6214497341455826,
#  (4, 26, 26): 0.5085600915129808,
#  (5, 25, 26): 0.5597136488340192,
#  (4, 26, 78): 0.6200700371725177,
#  (5, 25, 78): 0.6240545788772883,
#  (4, 27, 27): 0.5094988642906738,
#  (5, 26, 27): 0.5606478239999831,
#  (4, 27, 81): 0.6205027253583889,
#  (5, 26, 81): 0.6261406211631442,
#  (4, 28, 28): 0.5131205254322682,
#  (5, 27, 28): 0.5612278672955936,
#  (4, 28, 84): 0.6225665568796677,
#  (5, 27, 84): 0.6265492628473809,
#  (4, 29, 29): 0.5143106453432743,
#  (5, 28, 29): 0.5613912478936984,
#  (4, 29, 87): 0.6242289738977375,
#  (5, 28, 87): 0.626946129353376,
#  (4, 30, 30): 0.5156899950147334,
#  (5, 29, 30): 0.5637915319797965,
#  (4, 30, 90): 0.6246810778971702,
#  (5, 29, 90): 0.6272628022648563,
#  (4, 31, 31): 0.5166124611551424,
#  (5, 30, 31): 0.566074510814112,
#  (4, 31, 93): 0.6255271046080374,
#  (5, 30, 93): 0.6294413425449626,
#  (4, 32, 32): 0.5177187986883774,
#  (5, 31, 32): 0.5665562016026944,
#  (4, 32, 96): 0.6264351494627344,
#  (5, 31, 96): 0.6310857660322359,
#  (4, 33, 33): 0.5180689779356974,
#  (5, 32, 33): 0.5674294005296449,
#  (4, 33, 99): 0.626903626252138,
#  (5, 32, 99): 0.6314149087251689,
#  (4, 34, 34): 0.5183972606437027,
#  (5, 33, 34): 0.5680504584910413,
#  (4, 35, 35): 0.5188368121708242,
#  ...}

# %%
exportStateProbs(DATA_DIR + 'game1_better_giving_1_to_another_memo_1-100.csv', betterGiving1ToAnother)

# %%
betterGiving1ToAnother, given1ToAnother = readApproxBetterGiving1Probs(DATA_DIR + 'game1_better_giving_1_to_another_memo_1-100.csv')

# %%
betterGiving1ToAnother, given1ToAnother = stricterFilter(betterGiving1ToAnother, printOnGo=True,
                                                         filename=DATA_DIR + 'game1_better_giving_1_to_another_stricter_1-100.csv',
                                                         giveToAnother=True, continueFrom=(83,12,36))
# Out:
# Approximating hitting prob for (84, 18, 35)
# (84, 18, 35): 0.10303654649700907
# (83, 19, 35): 0.10355768897974053
#
# Approximating hitting prob for (84, 35, 36)
# (84, 35, 36): 0.12465643320760383
# (83, 36, 36): 0.10725923307268535
#
# Approximating hitting prob for (84, 35, 54)
# (84, 35, 54): 0.18458609949426028
# (83, 36, 54): 0.18447328289108278
#
# Approximating hitting prob for (84, 35, 72)
# (84, 35, 72): 0.20484058262394267
# (83, 36, 72): 0.20265781338487368
#
# Approximating hitting prob for (84, 36, 37)
# (84, 36, 37): 0.12578990678788265
# (83, 37, 37): 0.108343603597392
#
# Approximating hitting prob for (83, 37, 74)
# (83, 37, 74): 0.20487236439599202
# (82, 38, 74): 0.21725707058624488
#
# Approximating hitting prob for (83, 37, 89)
# (83, 37, 89): 0.28629700345944264
# (82, 38, 89): 0.2896550351069984
#
# Approximating hitting prob for (84, 19, 37)
# (84, 19, 37): 0.10519475148468926
# (83, 20, 37): 0.10642148121920503
#
# Approximating hitting prob for (84, 37, 38)
# (84, 37, 38): 0.12719872770436752
# (83, 38, 38): 0.10959994988366119
#
# Approximating hitting prob for (83, 38, 57)
# (83, 38, 57): 0.18879113610552611
# (82, 39, 57): 0.19553107366477782
#
# Approximating hitting prob for (83, 38, 76)
# (83, 38, 76): 0.2078284729000723
# (82, 39, 76): 0.2205276005980226
#
# Approximating hitting prob for (83, 38, 79)
# (83, 38, 79): 0.22132604896860272
# (82, 39, 79): 0.2229900349675474
#
# Approximating hitting prob for (84, 13, 38)
# (84, 13, 38): 0.0858614173273949
# (83, 14, 38): 0.08925357363807468
#
# Approximating hitting prob for (84, 38, 39)
# (84, 38, 39): 0.12867822501577994
# (83, 39, 39): 0.11031224860691578
#
# Approximating hitting prob for (84, 38, 78)
# (84, 38, 78): 0.21895348237412468
# (83, 39, 78): 0.21079020168494467
#
# Approximating hitting prob for (84, 8, 39)
# (84, 8, 39): 0.07869897749128588
# (83, 9, 39): 0.08272184783419391
#
# Approximating hitting prob for (83, 40, 40)
# (83, 40, 40): 0.11073288295452473
# (82, 41, 40): 0.1403027371779166
#
# Approximating hitting prob for (83, 40, 60)
# (83, 40, 60): 0.1960444353096424
# (82, 41, 60): 0.21209334688127046
#
# Approximating hitting prob for (83, 40, 80)
# (83, 40, 80): 0.21292614058228118
# (82, 41, 80): 0.2361553357926498
#
# Approximating hitting prob for (83, 40, 81)
# (83, 40, 81): 0.22409994589857532
# (82, 41, 81): 0.23669442014137446
#
# Approximating hitting prob for (83, 40, 94)
# (83, 40, 94): 0.2914800033497849
# (82, 41, 94): 0.30438758241100466
#
# Approximating hitting prob for (83, 41, 41)
# (83, 41, 41): 0.11104755005298571
# (82, 42, 41): 0.19813238300593183
#
# Approximating hitting prob for (83, 41, 82)
# (83, 41, 82): 0.21466241599689165
# (82, 42, 82): 0.295709306787764
#
# Approximating hitting prob for (83, 41, 96)
# (83, 41, 96): 0.2929648749958149
# (82, 42, 96): 0.30740020288353503
#
# Approximating hitting prob for (84, 21, 41)
# (84, 21, 41): 0.11079816825485501
# (83, 22, 41): 0.1149400066059223
#
# Approximating hitting prob for (84, 42, 43)
# (84, 42, 43): 0.1981260231319458
# (83, 43, 43): 0.1637555581451031
#
# Approximating hitting prob for (84, 42, 86)
# (84, 42, 86): 0.30044016878093177
# (83, 43, 86): 0.2914937494263571
#
# Approximating hitting prob for (83, 44, 44)
# (83, 44, 44): 0.16427578417454933
# (82, 45, 44): 0.2066571901076868
#
# Approximating hitting prob for (83, 44, 71)
# (83, 44, 71): 0.22708220204593732
# (82, 45, 71): 0.22941284302261458
#
# Approximating hitting prob for (83, 44, 85)
# (83, 44, 85): 0.30031267321855215
# (82, 45, 85): 0.30164445371795917
#
# Approximating hitting prob for (83, 44, 88)
# (83, 44, 88): 0.2927369954048058
# (82, 45, 88): 0.304234465558416
#
# Approximating hitting prob for (83, 44, 100)
# (83, 44, 100): 0.3093785677795234
# (82, 45, 100): 0.3103482304461204
#
# Approximating hitting prob for (84, 15, 44)
# (84, 15, 44): 0.10534969171860638
# (83, 16, 44): 0.10751553520835096
#
# Approximating hitting prob for (84, 44, 45)
# (84, 44, 45): 0.20572824470325127
# (83, 45, 45): 0.1649107410597355
#
# Approximating hitting prob for (84, 44, 86)
# (84, 44, 86): 0.3018948485070321
# (83, 45, 86): 0.3013300461940937
#
# Approximating hitting prob for (84, 44, 90)
# (84, 44, 90): 0.30318194874515764
# (83, 45, 90): 0.29369832086079295
#
# Approximating hitting prob for (83, 46, 46)
# (83, 46, 46): 0.165784390137279
# (82, 47, 46): 0.2086699545521382
#
# Approximating hitting prob for (83, 46, 87)
# (83, 46, 87): 0.3023184468533109
# (82, 47, 87): 0.3035240330634861
#
# Approximating hitting prob for (83, 46, 92)
# (83, 46, 92): 0.2942489390923475
# (82, 47, 92): 0.30683535559291075
#
# Approximating hitting prob for (83, 47, 47)
# (83, 47, 47): 0.16686236144769173
# (82, 48, 47): 0.20968836518766443
#
# Approximating hitting prob for (83, 47, 88)
# (83, 47, 88): 0.30314842740931974
# (82, 48, 88): 0.3044819221000095
#
# Approximating hitting prob for (83, 47, 94)
# (83, 47, 94): 0.2961447603978898
# (82, 48, 94): 0.307878446902345
#
# Approximating hitting prob for (84, 16, 47)
# (84, 16, 47): 0.10854557840395122
# (83, 17, 47): 0.11369315707801297
#
# Approximating hitting prob for (84, 32, 47)
# (84, 32, 47): 0.14198035165991454
# (83, 33, 47): 0.14393833330724806
#
# Approximating hitting prob for (84, 47, 48)
# (84, 47, 48): 0.20853236349942636
# (83, 48, 48): 0.16778345830491145
#
# Approximating hitting prob for (84, 47, 75)
# (84, 47, 75): 0.2349720270057759
# (83, 48, 75): 0.23487711259842114
#
# Approximating hitting prob for (84, 47, 89)
# (84, 47, 89): 0.3045676151020191
# (83, 48, 89): 0.3038465543012763
#
# Approximating hitting prob for (84, 47, 96)
# (84, 47, 96): 0.30690027013559334
# (83, 48, 96): 0.2970719129923158
#
# Approximating hitting prob for (84, 48, 49)
# (84, 48, 49): 0.20953920603851414
# (83, 49, 49): 0.16868907901986352
#
# Approximating hitting prob for (84, 48, 98)
# (84, 48, 98): 0.30791585282194306
# (83, 49, 98): 0.29820188575671064
#
# Approximating hitting prob for (83, 50, 50)
# (83, 50, 50): 0.173978627126235
# (82, 51, 50): 0.21680652189839558
#
# Approximating hitting prob for (83, 50, 100)
# (83, 50, 100): 0.30512509518863445
# (82, 51, 100): 0.31630882326585874
#
# Approximating hitting prob for (83, 51, 51)
# (83, 51, 51): 0.1746551660977752
# (82, 52, 51): 0.21856272708821492
#
# Approximating hitting prob for (83, 13, 52)
# (83, 13, 52): 0.11044599116530886
# (82, 14, 52): 0.11643398790348813
#
# Approximating hitting prob for (84, 26, 51)
# (84, 26, 51): 0.13202584809174675
# (83, 27, 51): 0.13362958512914969
#
# Approximating hitting prob for (84, 51, 52)
# (84, 51, 52): 0.2164671781816746
# (83, 52, 52): 0.1767411225632679
#
# Approximating hitting prob for (84, 51, 78)
# (84, 51, 78): 0.23913741266083932
# (83, 52, 78): 0.2373795873146433
#
# Approximating hitting prob for (84, 51, 79)
# (84, 51, 79): 0.24124342911756838
# (83, 52, 79): 0.2407369439852802
#
# Approximating hitting prob for (84, 52, 53)
# (84, 52, 53): 0.21787929612344845
# (83, 53, 53): 0.17714049068985718
#
# Approximating hitting prob for (84, 52, 80)
# (84, 52, 80): 0.2420652011518484
# (83, 53, 80): 0.24108609233587383
#
# Approximating hitting prob for (84, 9, 53)
# (84, 9, 53): 0.09742048110724745
# (83, 10, 53): 0.10562439747926818
#
# Approximating hitting prob for (84, 27, 53)
# (84, 27, 53): 0.13417754878026766
# (83, 28, 53): 0.14659288259740344
#
# Approximating hitting prob for (83, 54, 54)
# (83, 54, 54): 0.17828813034895752
# (82, 55, 54): 0.22376543751583397
#
# Approximating hitting prob for (83, 54, 81)
# (83, 54, 81): 0.23934247757764726
# (82, 55, 81): 0.2519833789469572
#
# Approximating hitting prob for (83, 54, 95)
# (83, 54, 95): 0.31568587770142215
# (82, 55, 95): 0.3197084632375748
#
# Approximating hitting prob for (83, 11, 55)
# (83, 11, 55): 0.10973055850776593
# (82, 12, 55): 0.11473043208414972
#
# Approximating hitting prob for (83, 55, 55)
# (83, 55, 55): 0.1788217322516753
# (82, 56, 55): 0.22752523219652962
#
# Approximating hitting prob for (83, 56, 56)
# (83, 56, 56): 0.18497069816391956
# (82, 57, 56): 0.2284952104400156
#
# Approximating hitting prob for (84, 19, 56)
# (84, 19, 56): 0.12772805621828073
# (83, 20, 56): 0.1318960219121673
#
# Approximating hitting prob for (83, 57, 57)
# (83, 57, 57): 0.18575018351016517
# (82, 58, 57): 0.23008055603661623
#
# Approximating hitting prob for (83, 57, 95)
# (83, 57, 95): 0.31880064515584944
# (82, 58, 95): 0.3208196789330631
#
# Approximating hitting prob for (83, 57, 98)
# (83, 57, 98): 0.3206933373151138
# (82, 58, 98): 0.32223954151819045
#
# Approximating hitting prob for (83, 58, 58)
# (83, 58, 58): 0.18657580474475186
# (82, 59, 58): 0.23189648778591962
# Approximating hitting prob for (83, 58, 85)
# (83, 58, 85): 0.3221763282426909
# (82, 59, 85): 0.3232222022508778
#
# Approximating hitting prob for (83, 58, 99)
# (83, 58, 99): 0.32157150223389713
# (82, 59, 99): 0.3229515051366815
#
# Approximating hitting prob for (83, 59, 59)
# (83, 59, 59): 0.1888178868284903
# (82, 60, 59): 0.23300113678329193
#
# Approximating hitting prob for (83, 59, 86)
# (83, 59, 86): 0.32270782903799894
# (82, 60, 86): 0.32383059058925373
#
# Approximating hitting prob for (84, 58, 100)
# (84, 58, 100): 0.32307822336644043
# (83, 59, 100): 0.3224433842386402
#
# Approximating hitting prob for (84, 30, 59)
# (84, 30, 59): 0.18679870601220291
# (83, 31, 59): 0.18838246223621466
#
# Approximating hitting prob for (83, 60, 60)
# (83, 60, 60): 0.19031947214283476
# (82, 61, 60): 0.233746150547971
#
# Approximating hitting prob for (83, 60, 87)
# (83, 60, 87): 0.3235155439016135
# (82, 61, 87): 0.3247878798870392
#
# Approximating hitting prob for (83, 60, 100)
# (83, 60, 100): 0.32181551286779936
# (82, 61, 100): 0.33051677109392336
#
# Approximating hitting prob for (83, 61, 61)
# (83, 61, 61): 0.19087272586493972
# (82, 62, 61): 0.23876561913187075
#
# Approximating hitting prob for (83, 61, 88)
# (83, 61, 88): 0.3244315829042485
# (82, 62, 88): 0.3257200833629664
#
# Approximating hitting prob for (84, 31, 61)
# (84, 31, 61): 0.18880302469258392
# (83, 32, 61): 0.19069037164064281
#
# Approximating hitting prob for (84, 61, 62)
# (84, 61, 62): 0.23340886684321885
# (83, 62, 62): 0.19137212390600397
#
# Approximating hitting prob for (84, 61, 89)
# (84, 61, 89): 0.32558946745291834
# (83, 62, 89): 0.32511215083601575
#
# Approximating hitting prob for (84, 62, 63)
# (84, 62, 63): 0.23538253030022846
# (83, 63, 63): 0.20082961656347834
#
# Approximating hitting prob for (84, 62, 90)
# (84, 62, 90): 0.326512251349626
# (83, 63, 90): 0.3260772978045329
#
# Approximating hitting prob for (84, 32, 63)
# (84, 32, 63): 0.19207741038786508
# (83, 33, 63): 0.1937066734542886
#
# Approximating hitting prob for (84, 63, 64)
# (84, 63, 64): 0.2423818649986221
# (83, 64, 64): 0.20155633113751023
#
# Approximating hitting prob for (84, 63, 91)
# (84, 63, 91): 0.3274339086850146
# (83, 64, 91): 0.32653023365035355
#
# Approximating hitting prob for (84, 64, 65)
# (84, 64, 65): 0.24404997660459501
# (83, 65, 65): 0.20283118734786684
#
# Approximating hitting prob for (83, 66, 66)
# (83, 66, 66): 0.20341424045095066
# (82, 67, 66): 0.2481044161883382
#
# Approximating hitting prob for (83, 67, 67)
# (83, 67, 67): 0.2048806385588231
# (82, 68, 67): 0.24888218431065878
#
# Approximating hitting prob for (83, 67, 94)
# (83, 67, 94): 0.3296139915053066
# (82, 68, 94): 0.3315264934003168
#
# Approximating hitting prob for (84, 34, 67)
# (84, 34, 67): 0.19916923588937976
# (83, 35, 67): 0.20201780589912
#
# Approximating hitting prob for (84, 67, 68)
# (84, 67, 68): 0.24753438875963416
# (83, 68, 68): 0.20561300722532014
#
# Approximating hitting prob for (84, 67, 95)
# (84, 67, 95): 0.3309338315554233
# (83, 68, 95): 0.3307834279097799
#
# Approximating hitting prob for (83, 69, 69)
# (83, 69, 69): 0.20595191919526679
# (82, 70, 69): 0.2539232964583295
#
# Approximating hitting prob for (83, 69, 96)
# (83, 69, 96): 0.3317130040523294
# (82, 70, 96): 0.3343617732383006
#
# Approximating hitting prob for (84, 35, 69)
# (84, 35, 69): 0.20238288916152913
# (83, 36, 69): 0.2057319048927636
#
# Approximating hitting prob for (84, 69, 70)
# (84, 69, 70): 0.24942929107183662
# (83, 70, 70): 0.20956627195750321
#
# Approximating hitting prob for (84, 70, 71)
# (84, 70, 71): 0.25284893571257167
# (83, 71, 71): 0.21019276667271378
#
# Approximating hitting prob for (84, 24, 71)
# (84, 24, 71): 0.18515986457138223
# (83, 25, 71): 0.19029338275130805
#
# Approximating hitting prob for (83, 72, 72)
# (83, 72, 72): 0.21199132177791954
# (82, 73, 72): 0.25884795990546733
#
# Approximating hitting prob for (83, 72, 99)
# (83, 72, 99): 0.33576940087355084
# (82, 73, 99): 0.33717505927212854
#
# Approximating hitting prob for (83, 73, 73)
# (83, 73, 73): 0.21422897314354206
# (82, 74, 73): 0.2595924309959136
#
# Approximating hitting prob for (83, 73, 100)
# (83, 73, 100): 0.3362453489866735
# (82, 74, 100): 0.33798286376945197
#
# Approximating hitting prob for (84, 37, 73)
# (84, 37, 73): 0.21329578028083215
# (83, 38, 73): 0.2148835542030096
#
# Approximating hitting prob for (84, 73, 74)
# (84, 73, 74): 0.25749628543786
# (83, 74, 74): 0.21493283121265253
#
# Approximating hitting prob for (83, 75, 75)
# (83, 75, 75): 0.21576030673421856
# (82, 76, 75): 0.26153878945464015
#
# Approximating hitting prob for (84, 19, 75)
# (84, 19, 75): 0.1825327529698839
# (83, 20, 75): 0.18542561719355297
#
# Approximating hitting prob for (83, 76, 76)
# (83, 76, 76): 0.21657488456135363
# (82, 77, 76): 0.26280227139525575
#
# Approximating hitting prob for (83, 77, 77)
# (83, 77, 77): 0.21763070664375495
# (82, 78, 77): 0.26376486220340584
#
# Approximating hitting prob for (84, 26, 77)
# (84, 26, 77): 0.19789828023721623
# (83, 27, 77): 0.20025043171098958
#
# Approximating hitting prob for (84, 52, 77)
# (84, 52, 77): 0.2383999903306375
# (83, 53, 77): 0.23985685813955016
#
# Approximating hitting prob for (84, 77, 78)
# (84, 77, 78): 0.2617801718473279
# (83, 78, 78): 0.2190799475815525
#
# Approximating hitting prob for (84, 78, 79)
# (84, 78, 79): 0.2629588238250812
# (83, 79, 79): 0.2196368090055031
#
# Approximating hitting prob for (83, 80, 80)
# (83, 80, 80): 0.22051214919212125
# (82, 81, 80): 0.26604715272851237
#
# Approximating hitting prob for (84, 27, 80)
# (84, 27, 80): 0.20254663439545117
# (83, 28, 80): 0.21598995146657138
#
# Approximating hitting prob for (83, 81, 81)
# (83, 81, 81): 0.2212068991949011
# (82, 82, 81): 0.3221204750496144
#
# Approximating hitting prob for (84, 41, 81)
# (84, 41, 81): 0.22391047956253995
# (83, 42, 81): 0.2371586930911125
#
# Approximating hitting prob for (84, 81, 82)
# (84, 81, 82): 0.265405772711851
# (83, 82, 82): 0.22181907154638766
#
# Approximating hitting prob for (84, 84, 85)
# (84, 84, 85): 0.38908685024122563
# (83, 85, 85): 0.3560622327500307
#
# Approximating hitting prob for (84, 85, 86)
# (84, 85, 86): 0.40045601919199264
# (83, 86, 86): 0.35640268333879926
#
# Approximating hitting prob for (83, 87, 87)
# (83, 87, 87): 0.35682450545744726
# (82, 88, 87): 0.4021109708978196
#
# Approximating hitting prob for (84, 22, 87)
# (84, 22, 87): 0.25889404097723984
# (83, 23, 87): 0.26062057344527
#
# Approximating hitting prob for (83, 88, 88)
# (83, 88, 88): 0.35718117230956953
# (82, 89, 88): 0.402755140560007
#
# Approximating hitting prob for (83, 89, 89)
# (83, 89, 89): 0.35784790770668273
# (82, 90, 89): 0.4031718581801555
#
# Approximating hitting prob for (84, 15, 89)
# (84, 15, 89): 0.25137406908549664
# (83, 16, 89): 0.2524821474748172
#
# Approximating hitting prob for (84, 45, 89)
# (84, 45, 89): 0.3033455121612325
# (83, 46, 89): 0.3045897491855067
#
# Approximating hitting prob for (84, 89, 90)
# (84, 89, 90): 0.4019829995303557
# (83, 90, 90): 0.35835064606678335
#
# Approximating hitting prob for (84, 13, 90)
# (84, 13, 90): 0.24922188541688983
# (83, 14, 90): 0.25186928948596554
#
# Approximating hitting prob for (84, 90, 91)
# (84, 90, 91): 0.40261896427220895
# (83, 91, 91): 0.35863566079275033
#
# Approximating hitting prob for (84, 46, 91)
# (84, 46, 91): 0.304384884645695
# (83, 47, 91): 0.30543221645080076
#
# Approximating hitting prob for (84, 91, 92)
# (84, 91, 92): 0.403149010404632
# (83, 92, 92): 0.3593572896587404
#
# Approximating hitting prob for (83, 93, 93)
# (83, 93, 93): 0.3596482040202682
# (82, 94, 93): 0.40620898322636706
#
# Approximating hitting prob for (84, 47, 93)
# (84, 47, 93): 0.30569452957284066
# (83, 48, 93): 0.3071298554647304
#
# Approximating hitting prob for (84, 93, 94)
# (84, 93, 94): 0.40445337420445027
# (83, 94, 94): 0.36080945879437937
#
# Approximating hitting prob for (84, 57, 94)
# (84, 57, 94): 0.3192375207425214
# (83, 58, 94): 0.32012527448491274
#
# Approximating hitting prob for (84, 94, 95)
# (84, 94, 95): 0.40521491837830187
# (83, 95, 95): 0.36141648222683703
#
# Approximating hitting prob for (84, 24, 95)
# (84, 24, 95): 0.2634128221599658
# (83, 25, 95): 0.2653724575866689
#
# Approximating hitting prob for (84, 48, 95)
# (84, 48, 95): 0.30688947711801867
# (83, 49, 95): 0.30825387289682227
#
# Approximating hitting prob for (84, 95, 96)
# (84, 95, 96): 0.40599103764197464
# (83, 96, 96): 0.36179354317226725
#
# Approximating hitting prob for (84, 96, 97)
# (84, 96, 97): 0.4065888307067218
# (83, 97, 97): 0.3633179011902143
#
# Approximating hitting prob for (83, 98, 98)
# (83, 98, 98): 0.3635095236140444
# (82, 99, 98): 0.40973308890766497
#
# Approximating hitting prob for (84, 33, 98)
# (84, 33, 98): 0.2881648663009276
# (83, 34, 98): 0.2912208073141436
#
# Approximating hitting prob for (84, 98, 99)
# (84, 98, 99): 0.4085337281404437
# (83, 99, 99): 0.36400716624980195
#
# Approximating hitting prob for (84, 25, 99)
# (84, 25, 99): 0.2658023030713688
# (83, 26, 99): 0.2682442238752158
#
# Approximating hitting prob for (84, 60, 99)
# (84, 60, 99): 0.321796993791021
# (83, 61, 99): 0.33006147508387346
#
# Approximating hitting prob for (84, 99, 100)
# (84, 99, 100): 0.40875505790797373
# (83, 100, 100): 0.36512210793100425
#
# Approximating hitting prob for (85, 1, 88)
# (85, 1, 88): 0.24922767817188138
# (84, 2, 88): 0.24777053038216432
#
# Approximating hitting prob for (85, 1, 89)
# (85, 1, 89): 0.24930808910647106
# (84, 2, 89): 0.24796635925260468
#
# Approximating hitting prob for (85, 1, 92)
# (85, 1, 92): 0.2501859531555601
# (84, 2, 92): 0.25014874703037177
#
# Approximating hitting prob for (85, 1, 93)
# (85, 1, 93): 0.2502491114813607
# (84, 2, 93): 0.25028921689592737
#
# Approximating hitting prob for (85, 2, 91)
# (85, 2, 91): 0.24992556233738425
# (84, 3, 91): 0.24894516486105597
#
# Approximating hitting prob for (85, 2, 92)
# (85, 2, 92): 0.2500501096244369
# (84, 3, 92): 0.24911323104347396
#
# Approximating hitting prob for (85, 3, 4)
# (85, 3, 4): 0.002649729982749569
# (84, 4, 4): 0.002336710266151964
#
# Approximating hitting prob for (85, 3, 94)
# (85, 3, 94): 0.25096895386115814
# (84, 4, 94): 0.25014117570925637
#
# Approximating hitting prob for (85, 3, 95)
# (85, 3, 95): 0.25120936417229883
# (84, 4, 95): 0.25038725286450964
#
# Approximating hitting prob for (85, 4, 5)
# (85, 4, 5): 0.004030383590903994
# (84, 5, 5): 0.0036493714304991994
#
# Approximating hitting prob for (85, 4, 15)
# (85, 4, 15): 0.01905056708357371
# (84, 5, 15): 0.01895642573002651
#
# Approximating hitting prob for (85, 4, 97)
# (85, 4, 97): 0.252228141317083
# (84, 5, 97): 0.2514475951173302
#
# Approximating hitting prob for (85, 4, 98)
# (85, 4, 98): 0.2525223339587673
# (84, 5, 98): 0.2516203519422959
#
# Approximating hitting prob for (85, 6, 7)
# (85, 6, 7): 0.009247146975369215
# (84, 7, 7): 0.007606113672316607
#
# Approximating hitting prob for (85, 7, 8)
# (85, 7, 8): 0.011674163664522896
# (84, 8, 8): 0.008673532642124346
#
# Approximating hitting prob for (85, 7, 16)
# (85, 7, 16): 0.025295114593352517
# (84, 8, 16): 0.02367733875747464
#
# Approximating hitting prob for (85, 7, 24)
# (85, 7, 24): 0.03789520211457377
# (84, 8, 24): 0.03768594881757887
#
# Approximating hitting prob for (85, 8, 9)
# (85, 8, 9): 0.013914455760299593
# (84, 9, 9): 0.011490258839087657
#
# Approximating hitting prob for (85, 8, 18)
# (85, 8, 18): 0.02892003549312386
# (84, 9, 18): 0.026270886889387158
#
# Approximating hitting prob for (85, 9, 10)
# (85, 9, 10): 0.016250154585925467
# (84, 10, 10): 0.013078270691092532
#
# Approximating hitting prob for (85, 9, 20)
# (85, 9, 20): 0.03489706565241549
# (84, 10, 20): 0.03415155864202029
#
# Approximating hitting prob for (85, 9, 30)
# (85, 9, 30): 0.06693400751111707
# (84, 10, 30): 0.06562656841778958
#
# Approximating hitting prob for (85, 9, 40)
# (85, 9, 40): 0.08217860470162519
# (84, 10, 40): 0.08213548596862943
#
# Approximating hitting prob for (85, 10, 11)
# (85, 10, 11): 0.02010607927943608
# (84, 11, 11): 0.01812668531328041
#
# Approximating hitting prob for (85, 10, 22)
# (85, 10, 22): 0.03957992043796799
# (84, 11, 22): 0.038422701586378775
#
# Approximating hitting prob for (85, 12, 13)
# (85, 12, 13): 0.027858737764416455
# (84, 13, 13): 0.024722662229987664
#
# Approximating hitting prob for (85, 12, 26)
# (85, 12, 26): 0.0565524150022482
# (84, 13, 26): 0.05590299190392989
#
# Approximating hitting prob for (85, 12, 39)
# (85, 12, 39): 0.08363306400204862
# (84, 13, 39): 0.08355634955129798
#
# Approximating hitting prob for (85, 7, 13)
# (85, 7, 13): 0.021544328790560594
# (84, 8, 13): 0.02236502999025664
#
# Approximating hitting prob for (85, 13, 14)
# (85, 13, 14): 0.031507762788010804
# (84, 14, 14): 0.02913548107169975
#
# Approximating hitting prob for (85, 14, 15)
# (85, 14, 15): 0.03943507752547645
# (84, 15, 15): 0.032040847063420676
#
# Approximating hitting prob for (85, 14, 30)
# (85, 14, 30): 0.07533409027406172
# (84, 15, 30): 0.07347373246610885
#
# Approximating hitting prob for (85, 14, 45)
# (85, 14, 45): 0.10321111518485183
# (84, 15, 45): 0.10249697850173316
#
# Approximating hitting prob for (84, 16, 16)
# (84, 16, 16): 0.03346305187007657
# (83, 17, 16): 0.04804816345542481
#
# Approximating hitting prob for (84, 16, 32)
# (84, 16, 32): 0.07511752330854073
# (83, 17, 32): 0.08943755751801574
#
# Approximating hitting prob for (84, 16, 48)
# (84, 16, 48): 0.10712673831361065
# (83, 17, 48): 0.11451272926717698
#
# Approximating hitting prob for (84, 16, 64)
# (84, 16, 64): 0.1292265650907943
# (83, 17, 64): 0.135026767260062
#
# Approximating hitting prob for (84, 16, 96)
# (84, 16, 96): 0.25355249426146786
# (83, 17, 96): 0.25842849828329445
#
# Approximating hitting prob for (84, 17, 17)
# (84, 17, 17): 0.035667634470542886
# (83, 18, 17): 0.05033943812800732
#
# Approximating hitting prob for (85, 9, 17)
# (85, 9, 17): 0.028526819855205054
# (84, 10, 17): 0.031172816492401962
#
# Approximating hitting prob for (85, 17, 18)
# (85, 17, 18): 0.049552094600046726
# (84, 18, 18): 0.03747627389393863
#
# Approximating hitting prob for (85, 17, 36)
# (85, 17, 36): 0.10089031920924846
# (84, 18, 36): 0.0956032701589468
#
# Approximating hitting prob for (85, 17, 54)
# (85, 17, 54): 0.12267620424625154
# (84, 18, 54): 0.12073271135538947
#
# Approximating hitting prob for (85, 17, 72)
# (85, 17, 72): 0.17363668248681016
# (84, 18, 72): 0.17332267072322596
#
# Approximating hitting prob for (85, 18, 19)
# (85, 18, 19): 0.05171770132208788
# (84, 19, 19): 0.039299036831488075
#
# Approximating hitting prob for (85, 18, 38)
# (85, 18, 38): 0.1046005978495594
# (84, 19, 38): 0.09744192075384502
#
# Approximating hitting prob for (85, 18, 57)
# (85, 18, 57): 0.12666656573771046
# (84, 19, 57): 0.12440960760333687
#
# Approximating hitting prob for (85, 18, 95)
# (85, 18, 95): 0.2573063535469654
# (84, 19, 95): 0.25639455746982154
#
# Approximating hitting prob for (84, 20, 20)
# (84, 20, 20): 0.041389783186678665
# (83, 21, 20): 0.062315206301318725
#
# Approximating hitting prob for (84, 20, 40)
# (84, 20, 40): 0.10098990569089061
# (83, 21, 40): 0.11091979413440371
#
# Approximating hitting prob for (84, 20, 60)
# (84, 20, 60): 0.12709969624377174
# (83, 21, 60): 0.13577812876464154
#
# Approximating hitting prob for (84, 20, 61)
# (84, 20, 61): 0.1319277532445322
# (83, 21, 61): 0.13666842106853888
#
# Approximating hitting prob for (84, 20, 100)
# (84, 20, 100): 0.25953840585547305
# (83, 21, 100): 0.26460917849625126
#
# Approximating hitting prob for (84, 21, 21)
# (84, 21, 21): 0.053763440860215055
# (83, 22, 21): 0.0730642630800369
#
# Approximating hitting prob for (84, 21, 42)
# (84, 21, 42): 0.10550458715595556
# (83, 22, 42): 0.11605712393366878
#
# Approximating hitting prob for (85, 11, 21)
# (85, 11, 21): 0.039731206913049134
# (84, 12, 21): 0.04343247263184278
#
# Approximating hitting prob for (85, 21, 22)
# (85, 21, 22): 0.07027208808748436
# (84, 22, 22): 0.059384594277093826
#
# Approximating hitting prob for (85, 21, 44)
# (85, 21, 44): 0.11548394217705778
# (84, 22, 44): 0.10856748768388079
#
# Approximating hitting prob for (85, 21, 66)
# (85, 21, 66): 0.17364727345166017
# (84, 22, 66): 0.17330339499057867
#
# Approximating hitting prob for (85, 22, 23)
# (85, 22, 23): 0.0739145385787132
# (84, 23, 23): 0.06101469544570312
#
# Approximating hitting prob for (85, 22, 46)
# (85, 22, 46): 0.11815663734046322
# (84, 23, 46): 0.11442685748190566
#
# Approximating hitting prob for (85, 22, 69)
# (85, 22, 69): 0.179870872416664
# (84, 23, 69): 0.17605696526078504
#
# Approximating hitting prob for (85, 22, 92)
# (85, 22, 92): 0.2603169055286204
# (84, 23, 92): 0.2596981745175122
#
# Approximating hitting prob for (84, 24, 24)
# (84, 24, 24): 0.0632403073695315
# (83, 25, 24): 0.07999108800099924
#
# Approximating hitting prob for (84, 24, 48)
# (84, 24, 48): 0.11700666496792217
# (83, 25, 48): 0.1274765063522925
#
# Approximating hitting prob for (84, 24, 72)
# (84, 24, 72): 0.18061955541409938
# (83, 25, 72): 0.1911981461733957
#
# Approximating hitting prob for (84, 24, 96)
# (84, 24, 96): 0.26173204666721905
# (83, 25, 96): 0.2659202408945746
#
# Approximating hitting prob for (84, 25, 25)
# (84, 25, 25): 0.06482132629645002
# (83, 26, 25): 0.08444908174825254
# Approximating hitting prob for (84, 25, 50)
# (84, 25, 50): 0.11954978160669079
# (83, 26, 50): 0.13225196345073778
#
# Approximating hitting prob for (84, 25, 75)
# (84, 25, 75): 0.18496057334441343
# (83, 26, 75): 0.19724240504624246
#
# Approximating hitting prob for (84, 25, 100)
# (84, 25, 100): 0.2638057773021241
# (83, 26, 100): 0.26766386597254194
#
# Approximating hitting prob for (85, 13, 25)
# (85, 13, 25): 0.057622071007975895
# (84, 14, 25): 0.060745843691660535
#
# Approximating hitting prob for (85, 25, 26)
# (85, 25, 26): 0.08153320832921208
# (84, 26, 26): 0.06838616653153373
#
# Approximating hitting prob for (85, 25, 52)
# (85, 25, 52): 0.1307253468398492
# (84, 26, 52): 0.12360895964587716
#
# Approximating hitting prob for (85, 25, 78)
# (85, 25, 78): 0.19678140825970644
# (84, 26, 78): 0.19207885359328544
#
# Approximating hitting prob for (85, 9, 26)
# (85, 9, 26): 0.05165617718516588
# (84, 10, 26): 0.05341872839853476
#
# Approximating hitting prob for (85, 26, 27)
# (85, 26, 27): 0.0854457916701256
# (84, 27, 27): 0.07046014690629042
#
# Approximating hitting prob for (85, 26, 54)
# (85, 26, 54): 0.13329253431184718
# (84, 27, 54): 0.1255297369220967
#
# Approximating hitting prob for (85, 26, 81)
# (85, 26, 81): 0.20149593771543986
# (84, 27, 81): 0.1967581099130438
#
# Approximating hitting prob for (85, 28, 29)
# (85, 28, 29): 0.10335939523293003
# (84, 29, 29): 0.09739056482252777
#
# Approximating hitting prob for (85, 15, 29)
# (85, 15, 29): 0.07654214896289287
# (84, 16, 29): 0.07824146937340043
#
# Approximating hitting prob for (85, 20, 29)
# (85, 20, 29): 0.09121212768010184
# (84, 21, 29): 0.09208961028451552
#
# Approximating hitting prob for (85, 29, 30)
# (85, 29, 30): 0.1145244094962073
# (84, 30, 30): 0.09825757475018858
#
# Approximating hitting prob for (85, 29, 50)
# (85, 29, 50): 0.14234046293974215
# (84, 30, 50): 0.14228317002011828
#
# Approximating hitting prob for (85, 29, 60)
# (85, 29, 60): 0.18595643382095173
# (84, 30, 60): 0.17841760965409448
#
# Approximating hitting prob for (85, 29, 90)
# (85, 29, 90): 0.2790466957968155
# (84, 30, 90): 0.27352918403267146
#
# Approximating hitting prob for (85, 30, 31)
# (85, 30, 31): 0.115579134931668
# (84, 31, 31): 0.09924901654516932
#
# Approximating hitting prob for (85, 30, 62)
# (85, 30, 62): 0.18767120854539712
# (84, 31, 62): 0.18106224728179296
#
# Approximating hitting prob for (85, 30, 93)
# (85, 30, 93): 0.2808780826012788
# (84, 31, 93): 0.2748077381368278
#
# Approximating hitting prob for (84, 32, 32)
# (84, 32, 32): 0.10194522468701069
# (83, 33, 32): 0.12053743767057025
#
# Approximating hitting prob for (84, 32, 48)
# (84, 32, 48): 0.14093764978186166
# (83, 33, 48): 0.14456230444611975
#
# Approximating hitting prob for (84, 32, 64)
# (84, 32, 64): 0.18348561320783383
# (83, 33, 64): 0.19479918995015424
#
# Approximating hitting prob for (84, 32, 96)
# (84, 32, 96): 0.2796524155219125
# (83, 33, 96): 0.2879644583010303
#
# Approximating hitting prob for (84, 11, 33)
# (84, 11, 33): 0.07445748989970005
# (83, 12, 33): 0.08064597603726657
#
# Approximating hitting prob for (84, 33, 33)
# (84, 33, 33): 0.10309310085548667
# (83, 34, 33): 0.12255588715542336
#
# Approximating hitting prob for (84, 33, 66)
# (84, 33, 66): 0.18645674271366788
# (83, 34, 66): 0.1993587086547749
#
# Approximating hitting prob for (84, 33, 99)
# (84, 33, 99): 0.2813571870804227
# (83, 34, 99): 0.2914579531039284
#
# Approximating hitting prob for (84, 34, 34)
# (84, 34, 34): 0.1046552600073043
# (83, 35, 34): 0.12378847581086543
#
# Approximating hitting prob for (84, 34, 36)
# (84, 34, 36): 0.12463298194770256
# (83, 35, 36): 0.12518493729765046
#
# Approximating hitting prob for (84, 34, 68)
# (84, 34, 68): 0.19218876106672841
# (83, 35, 68): 0.20275302246960494
#
# Approximating hitting prob for (84, 35, 35)
# (84, 35, 35): 0.10587877499579529
# (83, 36, 35): 0.12518493729765046
#
# Approximating hitting prob for (84, 35, 70)
# (84, 35, 70): 0.19385068200177302
# (83, 36, 70): 0.20717854924630177
#
# Approximating hitting prob for (84, 35, 86)
# (84, 35, 86): 0.2831848684874037
# (83, 36, 86): 0.28474837237545175
#
# Approximating hitting prob for (84, 9, 36)
# (84, 9, 36): 0.07444364379648447
# (83, 10, 36): 0.07898912265318038
#
# Approximating hitting prob for (85, 18, 35)
# (85, 18, 35): 0.10278855068462506
# (84, 19, 35): 0.10311178223344002
#
# Approximating hitting prob for (85, 35, 36)
# (85, 35, 36): 0.12405574703455585
# (84, 36, 36): 0.10681958255107261
#
# Approximating hitting prob for (85, 35, 72)
# (85, 35, 72): 0.20388429261016008
# (84, 36, 72): 0.1985157958677145
#
# Approximating hitting prob for (85, 36, 37)
# (85, 36, 37): 0.12538762255875696
# (84, 37, 37): 0.10779359982344984
#
# Approximating hitting prob for (84, 37, 74)
# (84, 37, 74): 0.20353236340596007
# (83, 38, 74): 0.2161274058395425
#
# Approximating hitting prob for (85, 19, 37)
# (85, 19, 37): 0.10483085716733297
# (84, 20, 37): 0.1058514607153035
#
# Approximating hitting prob for (85, 37, 38)
# (85, 37, 38): 0.1266736076162678
# (84, 38, 38): 0.1087064254247997
#
# Approximating hitting prob for (84, 38, 76)
# (84, 38, 76): 0.20559398039713525
# (83, 39, 76): 0.2188375038693494
#
# Approximating hitting prob for (84, 38, 91)
# (84, 38, 91): 0.28683690022649394
# (83, 39, 91): 0.2897970952771333
#
# Approximating hitting prob for (85, 13, 38)
# (85, 13, 38): 0.08508098577288416
# (84, 14, 38): 0.08843254330309151
#
# Approximating hitting prob for (85, 38, 39)
# (85, 38, 39): 0.12810141548481443
# (84, 39, 39): 0.10998164572337475
#
# Approximating hitting prob for (84, 39, 78)
# (84, 39, 78): 0.20916849145497177
# (83, 40, 78): 0.22216671056055515
#
# Approximating hitting prob for (85, 10, 39)
# (85, 10, 39): 0.08297504989033365
# (84, 11, 39): 0.08391096250583156
#
# Approximating hitting prob for (84, 40, 40)
# (84, 40, 40): 0.11052621831617737
# (83, 41, 40): 0.1353037225768267
#
# Approximating hitting prob for (84, 40, 80)
# (84, 40, 80): 0.21172454757330908
# (83, 41, 80): 0.22388078627316102
#
# Approximating hitting prob for (84, 40, 94)
# (84, 40, 94): 0.29096613793566256
# (83, 41, 94): 0.2926601121287697
#
# Approximating hitting prob for (84, 41, 41)
# (84, 41, 41): 0.11091331936285304
# (83, 42, 41): 0.16826567961231684
#
# Approximating hitting prob for (84, 41, 82)
# (84, 41, 82): 0.21389112865774576
# (83, 42, 82): 0.23952372239838715
#
# Approximating hitting prob for (84, 41, 96)
# (84, 41, 96): 0.2919987591564314
# (83, 42, 96): 0.3058349684647203
#
# Approximating hitting prob for (85, 21, 41)
# (85, 21, 41): 0.11024808308740491
# (84, 22, 41): 0.1144306495395635
#
# Approximating hitting prob for (85, 42, 43)
# (85, 42, 43): 0.16826298201794865
# (84, 43, 43): 0.1635834108309304
#
# Approximating hitting prob for (84, 44, 44)
# (84, 44, 44): 0.16404211541334188
# (83, 45, 44): 0.20614797189382558
#
# Approximating hitting prob for (84, 44, 66)
# (84, 44, 66): 0.2178327335049813
# (83, 45, 66): 0.22168013629196706
#
# Approximating hitting prob for (84, 44, 88)
# (84, 44, 88): 0.291962361258945
# (83, 45, 88): 0.3036208598481929
#
# Approximating hitting prob for (84, 44, 100)
# (84, 44, 100): 0.309022403512959
# (83, 45, 100): 0.30939793707130203
#
# Approximating hitting prob for (85, 15, 44)
# (85, 15, 44): 0.1048936290455259
# (84, 16, 44): 0.10635317257226083
#
# Approximating hitting prob for (85, 44, 45)
# (85, 44, 45): 0.20541957968960656
# (84, 45, 45): 0.16459157971179456
#
# Approximating hitting prob for (85, 44, 90)
# (85, 44, 90): 0.3022467600160629
# (84, 45, 90): 0.2930734977003923
#
# Approximating hitting prob for (84, 46, 46)
# (84, 46, 46): 0.16542707979256388
# (83, 47, 46): 0.20809132971707903
#
# Approximating hitting prob for (84, 46, 92)
# (84, 46, 92): 0.29395432628625395
# (83, 47, 92): 0.30633642446868864
#
# Approximating hitting prob for (84, 47, 47)
# (84, 47, 47): 0.1661964748643668
# (83, 48, 47): 0.20915991519406854
#
# Approximating hitting prob for (84, 47, 94)
# (84, 47, 94): 0.29569162199097293
# (83, 48, 94): 0.3073486068717828
#
# Approximating hitting prob for (85, 16, 47)
# (85, 16, 47): 0.10774657888978405
# (84, 17, 47): 0.11279649360644968
#
# Approximating hitting prob for (85, 32, 47)
# (85, 32, 47): 0.14116026628802433
# (84, 33, 47): 0.14303478396125838
#
# Approximating hitting prob for (85, 47, 48)
# (85, 47, 48): 0.20798285375887524
# (84, 48, 48): 0.16730654501220313
#
# Approximating hitting prob for (85, 47, 96)
# (85, 47, 96): 0.30620219749837985
# (84, 48, 96): 0.29645307031430956
#
# Approximating hitting prob for (85, 48, 49)
# (85, 48, 49): 0.2089803585705139
# (84, 49, 49): 0.1681780559678497
# Approximating hitting prob for (85, 48, 98)
# (85, 48, 98): 0.30730261509498613
# (84, 49, 98): 0.2976354789365605
#
# Approximating hitting prob for (84, 50, 50)
# (84, 50, 50): 0.16904831872298876
# (83, 51, 50): 0.2161685998953541
#
# Approximating hitting prob for (84, 50, 75)
# (84, 50, 75): 0.23189409046533074
# (83, 51, 75): 0.2375190174214468
#
# Approximating hitting prob for (84, 50, 100)
# (84, 50, 100): 0.29844173515880945
# (83, 51, 100): 0.31531360061848274
#
# Approximating hitting prob for (84, 51, 51)
# (84, 51, 51): 0.17410960530095398
# (83, 52, 51): 0.21714480638771635
#
# Approximating hitting prob for (84, 13, 52)
# (84, 13, 52): 0.1097895055815535
# (83, 14, 52): 0.11529483656347154
#
# Approximating hitting prob for (85, 26, 51)
# (85, 26, 51): 0.1311804220333689
# (84, 27, 51): 0.13311083585370043
#
# Approximating hitting prob for (85, 51, 52)
# (85, 51, 52): 0.21571088774111855
# (84, 52, 52): 0.17483797755465413
#
# Approximating hitting prob for (85, 51, 78)
# (85, 51, 78): 0.2380181545614979
# (84, 52, 78): 0.23665240300248258
#
# Approximating hitting prob for (85, 52, 53)
# (85, 52, 53): 0.21694749664760907
# (84, 53, 53): 0.17688112469421502
#
# Approximating hitting prob for (84, 9, 54)
# (84, 9, 54): 0.09695161081996546
# (83, 10, 54): 0.10929038132911512
#
# Approximating hitting prob for (85, 18, 53)
# (85, 18, 53): 0.12257170653116656
# (84, 19, 53): 0.12501762684214981
#
# Approximating hitting prob for (84, 36, 54)
# (84, 36, 54): 0.18401171390004167
# (83, 37, 54): 0.18740013506271738
#
# Approximating hitting prob for (84, 54, 54)
# (84, 54, 54): 0.1776150040254999
# (83, 55, 54): 0.2213348943930018
#
# Approximating hitting prob for (84, 54, 81)
# (84, 54, 81): 0.23887752013649288
# (83, 55, 81): 0.2486043858567272
#
# Approximating hitting prob for (84, 54, 82)
# (84, 54, 82): 0.24366988734174314
# (83, 55, 82): 0.24461490060864155
#
# Approximating hitting prob for (84, 55, 55)
# (84, 55, 55): 0.17843990332724644
# (83, 56, 55): 0.22623647917456746
#
# Approximating hitting prob for (84, 55, 83)
# (84, 55, 83): 0.24417805047172636
# (83, 56, 83): 0.31092771132776
#
# Approximating hitting prob for (84, 56, 56)
# (84, 56, 56): 0.18348623853210444
# (83, 57, 56): 0.22790889717131724
#
# Approximating hitting prob for (85, 19, 56)
# (85, 19, 56): 0.12653056673976668
# (84, 20, 56): 0.13000885860378653
#
# Approximating hitting prob for (85, 38, 56)
# (85, 38, 56): 0.18821418920877933
# (84, 39, 56): 0.1900957947954448
#
# Approximating hitting prob for (85, 56, 57)
# (85, 56, 57): 0.22376617830228837
# (84, 57, 57): 0.18522278944646883
#
# Approximating hitting prob for (85, 29, 57)
# (85, 29, 57): 0.18259322262829183
# (84, 30, 57): 0.18351997234512016
#
# Approximating hitting prob for (85, 57, 58)
# (85, 57, 58): 0.22751241329998328
# (84, 58, 58): 0.18621975172835628
#
# Approximating hitting prob for (85, 58, 59)
# (85, 58, 59): 0.22844803790663135
# (84, 59, 59): 0.1883581701943221
#
# Approximating hitting prob for (84, 10, 60)
# (84, 10, 60): 0.11296146316907058
# (83, 11, 60): 0.1151823179389481
#
# Approximating hitting prob for (85, 20, 59)
# (85, 20, 59): 0.1299608793870747
# (84, 21, 59): 0.1342108232464957
#
# Approximating hitting prob for (84, 60, 60)
# (84, 60, 60): 0.18977369529147772
# (83, 61, 60): 0.23314105450761669
#
# Approximating hitting prob for (84, 61, 61)
# (84, 61, 61): 0.1904192257482009
# (83, 62, 61): 0.23436767244286136
#
# Approximating hitting prob for (85, 31, 61)
# (85, 31, 61): 0.18795733566261685
# (84, 32, 61): 0.1896283994049561
#
# Approximating hitting prob for (85, 61, 62)
# (85, 61, 62): 0.23284592111360727
# (84, 62, 62): 0.19105237536550848
#
# Approximating hitting prob for (85, 62, 63)
# (85, 62, 63): 0.23359052174131056
# (84, 63, 63): 0.19596772116592112
#
# Approximating hitting prob for (85, 32, 63)
# (85, 32, 63): 0.19048813442040227
# (84, 33, 63): 0.19313493218399003
#
# Approximating hitting prob for (85, 63, 64)
# (85, 63, 64): 0.23713247211453867
# (84, 64, 64): 0.20093585879785172
#
# Approximating hitting prob for (85, 64, 65)
# (85, 64, 65): 0.2429754299966187
# (84, 65, 65): 0.20177644526273428
#
# Approximating hitting prob for (85, 64, 93)
# (85, 64, 93): 0.32857465295775024
# (84, 65, 93): 0.3285471339659538
#
# Approximating hitting prob for (85, 33, 65)
# (85, 33, 65): 0.1934540997561612
# (84, 34, 65): 0.19549256402976392
#
# Approximating hitting prob for (84, 66, 66)
# (84, 66, 66): 0.20296443875000358
# (83, 67, 66): 0.24705979110125073
#
# Approximating hitting prob for (84, 67, 67)
# (84, 67, 67): 0.20348365828073148
# (83, 68, 67): 0.24822139038731492
#
# Approximating hitting prob for (85, 34, 67)
# (85, 34, 67): 0.19590683198243009
# (84, 35, 67): 0.20149241931447495
#
# Approximating hitting prob for (85, 67, 68)
# (85, 67, 68): 0.24626066109701836
# (84, 68, 68): 0.20501012941309785
#
# Approximating hitting prob for (84, 69, 69)
# (84, 69, 69): 0.2056792547194204
# (83, 70, 69): 0.2518856036987002
#
# Approximating hitting prob for (85, 35, 69)
# (85, 35, 69): 0.20172389512260178
# (84, 36, 69): 0.20319966740950715
#
# Approximating hitting prob for (85, 69, 70)
# (85, 69, 70): 0.2485057814202367
# (84, 70, 70): 0.2077770400570025
#
# Approximating hitting prob for (85, 70, 71)
# (85, 70, 71): 0.2502395059219445
# (84, 71, 71): 0.2096767436171879
#
# Approximating hitting prob for (85, 24, 71)
# (85, 24, 71): 0.18450982075492642
# (84, 25, 71): 0.18601860547725768
#
# Approximating hitting prob for (84, 72, 72)
# (84, 72, 72): 0.21108106781728822
# (83, 73, 72): 0.257407457274979
#
# Approximating hitting prob for (84, 73, 73)
# (84, 73, 73): 0.21205707966280787
# (83, 74, 73): 0.25890423116239325
#
# Approximating hitting prob for (85, 37, 73)
# (85, 37, 73): 0.21183764235438995
# (84, 38, 73): 0.21304721196010065
#
# Approximating hitting prob for (85, 73, 74)
# (85, 73, 74): 0.2561411272834149
# (84, 74, 74): 0.214270280785401
#
# Approximating hitting prob for (85, 50, 74)
# (85, 50, 74): 0.23234664301724695
# (84, 51, 74): 0.2361619576598699
#
# Approximating hitting prob for (85, 74, 75)
# (85, 74, 75): 0.25762065194577777
# (84, 75, 75): 0.21496713653735092
#
# Approximating hitting prob for (84, 76, 76)
# (84, 76, 76): 0.21578855550879664
# (83, 77, 76): 0.2616607734270359
#
# Approximating hitting prob for (84, 77, 77)
# (84, 77, 77): 0.21686811675627718
# (83, 78, 77): 0.26289284397765106
#
# Approximating hitting prob for (85, 26, 77)
# (85, 26, 77): 0.19709172733431368
# (84, 27, 77): 0.19839701716304847
#
# Approximating hitting prob for (85, 52, 77)
# (85, 52, 77): 0.23736450514061339
# (84, 53, 77): 0.23905803454954952
#
# Approximating hitting prob for (85, 77, 78)
# (85, 77, 78): 0.26077812313252163
# (84, 78, 78): 0.2178703900482322
#
# Approximating hitting prob for (85, 78, 79)
# (85, 78, 79): 0.2619103509057186
# (84, 79, 79): 0.21909910045368317
#
# Approximating hitting prob for (84, 80, 80)
# (84, 80, 80): 0.21966791416558873
# (83, 81, 80): 0.2653898471801667
#
# Approximating hitting prob for (85, 27, 80)
# (85, 27, 80): 0.2012645431951964
# (84, 28, 80): 0.21258350830093128
#
# Approximating hitting prob for (84, 81, 81)
# (84, 81, 81): 0.22056486550783228
# (83, 82, 81): 0.2660530555517286
#
# Approximating hitting prob for (85, 41, 81)
# (85, 41, 81): 0.22262040345173606
# (84, 42, 81): 0.2356181948449941
#
# Approximating hitting prob for (85, 81, 82)
# (85, 81, 82): 0.2646120119552127
# (84, 82, 82): 0.2212218197409586
#
# Approximating hitting prob for (85, 82, 83)
# (85, 82, 83): 0.26542391174494134
# (84, 83, 83): 0.2218232597962999
#
# Approximating hitting prob for (85, 43, 85)
# (85, 43, 85): 0.2955221069114008
# (84, 44, 85): 0.29984517711193914
#
# Approximating hitting prob for (85, 85, 86)
# (85, 85, 86): 0.3890799090789187
# (84, 86, 86): 0.3560411539166552
#
# Approximating hitting prob for (85, 29, 86)
# (85, 29, 86): 0.2780565040453686
# (84, 30, 86): 0.2788470195177315
#
# Approximating hitting prob for (85, 86, 87)
# (85, 86, 87): 0.4004345742416639
# (84, 87, 87): 0.3563744537261641
#
# Approximating hitting prob for (85, 22, 87)
# (85, 22, 87): 0.258383301959038
# (84, 23, 87): 0.26013844658076246
#
# Approximating hitting prob for (84, 88, 88)
# (84, 88, 88): 0.3568062535476822
# (83, 89, 88): 0.40206379186818436
#
# Approximating hitting prob for (84, 89, 89)
# (84, 89, 89): 0.35717171587685576
# (83, 90, 89): 0.4026873696799181
#
# Approximating hitting prob for (84, 15, 90)
# (84, 15, 90): 0.2507671133696447
# (83, 16, 90): 0.2530651538123468
#
# Approximating hitting prob for (85, 30, 89)
# (85, 30, 89): 0.27943379467873414
# (84, 31, 89): 0.28107867308869977
# Approximating hitting prob for (84, 90, 90)
# (84, 90, 90): 0.3577223991578171
# (83, 91, 90): 0.4031407782349506
#
# Approximating hitting prob for (84, 13, 91)
# (84, 13, 91): 0.2483625427010432
# (83, 14, 91): 0.252315064813139
#
# Approximating hitting prob for (84, 91, 91)
# (84, 91, 91): 0.35819501228612277
# (83, 92, 91): 0.40390072807308885
#
# Approximating hitting prob for (85, 23, 91)
# (85, 23, 91): 0.2604297781888774
# (84, 24, 91): 0.262423740743681
#
# Approximating hitting prob for (84, 92, 92)
# (84, 92, 92): 0.3586206396529954
# (83, 93, 92): 0.40448586449070173
#
# Approximating hitting prob for (85, 31, 92)
# (85, 31, 92): 0.28131447910906743
# (84, 32, 92): 0.28408513621753567
#
# Approximating hitting prob for (85, 92, 93)
# (85, 92, 93): 0.4030664514219246
# (84, 93, 93): 0.359338530417761
#
# Approximating hitting prob for (84, 94, 94)
# (84, 94, 94): 0.3596182525221099
# (83, 95, 94): 0.406084456134268
#
# Approximating hitting prob for (85, 19, 94)
# (85, 19, 94): 0.25742019321568316
# (84, 20, 94): 0.2591116274505734
#
# Approximating hitting prob for (85, 57, 94)
# (85, 57, 94): 0.31882822582790954
# (84, 58, 94): 0.31972439629222954
#
# Approximating hitting prob for (85, 94, 95)
# (85, 94, 95): 0.4044262138071351
# (84, 95, 95): 0.36077772821744913
#
# Approximating hitting prob for (85, 24, 95)
# (85, 24, 95): 0.2627227237820577
# (84, 25, 95): 0.2647004267557539
#
# Approximating hitting prob for (85, 48, 95)
# (85, 48, 95): 0.30637153875322426
# (84, 49, 95): 0.30766866292932965
#
# Approximating hitting prob for (85, 95, 96)
# (85, 95, 96): 0.40516278729669025
# (84, 96, 96): 0.36117495610369726
#
# Approximating hitting prob for (85, 96, 97)
# (85, 96, 97): 0.40585370978352525
# (84, 97, 97): 0.36174493314025624
#
# Approximating hitting prob for (84, 98, 98)
# (84, 98, 98): 0.3626759287590275
# (83, 99, 98): 0.40882033341577495
#
# Approximating hitting prob for (85, 33, 98)
# (85, 33, 98): 0.28733918301164524
# (84, 34, 98): 0.288884063148463
#
# Approximating hitting prob for (85, 98, 99)
# (85, 98, 99): 0.40659032657619276
# (84, 99, 99): 0.36347391378385296
#
# Approximating hitting prob for (85, 25, 99)
# (85, 25, 99): 0.26511486083295727
# (84, 26, 99): 0.26707109256164274
#
# Approximating hitting prob for (84, 100, 100)
# (84, 100, 100): 0.36392686015268966
# (83, 101, 100): 0.4104779120297093
#
# Approximating hitting prob for (85, 2, 30)
# (85, 2, 30): 0.05965771167632405
# (84, 3, 30): 0.06063491091107106
#
# Approximating hitting prob for (85, 2, 89)
# (85, 2, 89): 0.24776052848908436
# (84, 3, 89): 0.2486068172809254
#
# Approximating hitting prob for (85, 2, 90)
# (85, 2, 90): 0.24793323481932686
# (84, 3, 90): 0.24873970563429304
#
# Approximating hitting prob for (85, 2, 93)
# (85, 2, 93): 0.25013483769382727
# (84, 3, 93): 0.25100713843861394
#
# Approximating hitting prob for (85, 2, 94)
# (85, 2, 94): 0.25025739075434916
# (84, 3, 94): 0.2512804668426416
#
# Approximating hitting prob for (85, 3, 31)
# (85, 3, 31): 0.061190079610851995
# (84, 4, 31): 0.06296014906644624
#
# Approximating hitting prob for (85, 3, 92)
# (85, 3, 92): 0.248884451815699
# (84, 4, 92): 0.24969381423150408
#
# Approximating hitting prob for (85, 3, 93)
# (85, 3, 93): 0.24901984208358915
# (84, 4, 93): 0.2499302526929784
#
# Approximating hitting prob for (85, 4, 4)
# (85, 4, 4): 0.002313751759120083
# (84, 5, 4): 0.004078747920512772
#
# Approximating hitting prob for (85, 4, 8)
# (85, 4, 8): 0.0059404573091192394
# (84, 5, 8): 0.00824206358029994
#
# Approximating hitting prob for (85, 4, 32)
# (85, 4, 32): 0.06310324851580705
# (84, 5, 32): 0.06509143915113803
#
# Approximating hitting prob for (85, 4, 95)
# (85, 4, 95): 0.2500622765967556
# (84, 5, 95): 0.25098661459062616
#
# Approximating hitting prob for (85, 4, 96)
# (85, 4, 96): 0.2501938033976077
# (84, 5, 96): 0.2512867828656657
#
# Approximating hitting prob for (85, 5, 5)
# (85, 5, 5): 0.0035857367928645747
# (84, 6, 5): 0.006453259838129018
#
# Approximating hitting prob for (85, 5, 33)
# (85, 5, 33): 0.06541678798358819
# (84, 6, 33): 0.06740784491251701
#
# Approximating hitting prob for (85, 5, 98)
# (85, 5, 98): 0.2514022426375368
# (84, 6, 98): 0.25322220547398344
#
# Approximating hitting prob for (85, 5, 99)
# (85, 5, 99): 0.2515665117176663
# (84, 6, 99): 0.2534421797170845
#
# Approximating hitting prob for (85, 6, 6)
# (85, 6, 6): 0.005802734406270757
# (84, 7, 6): 0.009714256980166208
#
# Approximating hitting prob for (85, 6, 34)
# (85, 6, 34): 0.06757293177511298
# (84, 7, 34): 0.06954916588170199
#
# Approximating hitting prob for (85, 7, 7)
# (85, 7, 7): 0.007266599159230503
# (84, 8, 7): 0.011844357723873121
#
# Approximating hitting prob for (85, 7, 21)
# (85, 7, 21): 0.028769940692852488
# (84, 8, 21): 0.035435052308663686
#
# Approximating hitting prob for (85, 7, 35)
# (85, 7, 35): 0.06872768476190826
# (84, 8, 35): 0.0739974045123764
#
# Approximating hitting prob for (86, 4, 7)
# (86, 4, 7): 0.006166107535913477
# (85, 5, 7): 0.007019662593068549
#
# Approximating hitting prob for (86, 7, 8)
# (86, 7, 8): 0.01149185123387935
# (85, 8, 8): 0.008605019423701269
#
# Approximating hitting prob for (86, 7, 16)
# (86, 7, 16): 0.02506630681553508
# (85, 8, 16): 0.02351028546985731
#
# Approximating hitting prob for (86, 8, 9)
# (86, 8, 9): 0.013814434114904192
# (85, 9, 9): 0.011319710202999773
#
# Approximating hitting prob for (86, 8, 18)
# (86, 8, 18): 0.028492773341803848
# (85, 9, 18): 0.026082157929748318
#
# Approximating hitting prob for (86, 9, 10)
# (86, 9, 10): 0.015989063627144137
# (85, 10, 10): 0.01294019468402116
#
# Approximating hitting prob for (86, 9, 20)
# (86, 9, 20): 0.03469261041588289
# (85, 10, 20): 0.033889313521431506
#
# Approximating hitting prob for (86, 9, 30)
# (86, 9, 30): 0.06659203503658097
# (85, 10, 30): 0.0652979105972348
#
# Approximating hitting prob for (86, 9, 44)
# (86, 9, 44): 0.08723098664729027
# (85, 10, 44): 0.08719980986422866
#
# Approximating hitting prob for (86, 10, 11)
# (86, 10, 11): 0.019584829303677335
# (85, 11, 11): 0.017997498691923252
#
# Approximating hitting prob for (86, 10, 22)
# (86, 10, 22): 0.03885336500369498
# (85, 11, 22): 0.037309218381573084
#
# Approximating hitting prob for (86, 10, 39)
# (86, 10, 39): 0.0822754672864231
# (85, 11, 39): 0.08202376560996598
#
# Approximating hitting prob for (86, 11, 12)
# (86, 11, 12): 0.02347688110938995
# (85, 12, 12): 0.019827101167566002
#
# Approximating hitting prob for (86, 11, 24)
# (86, 11, 24): 0.04370856126658835
# (85, 12, 24): 0.04050099542480829
#
# Approximating hitting prob for (86, 11, 36)
# (86, 11, 36): 0.07824386138728226
# (85, 12, 36): 0.07694719670153931
#
# Approximating hitting prob for (86, 11, 48)
# (86, 11, 48): 0.09261310600860846
# (85, 12, 48): 0.09078324836569435
#
# Approximating hitting prob for (86, 11, 96)
# (86, 11, 96): 0.24581728865481497
# (85, 12, 96): 0.24572090255090903
#
# Approximating hitting prob for (86, 12, 13)
# (86, 12, 13): 0.027384384177993843
# (85, 13, 13): 0.024567717663535552
#
# Approximating hitting prob for (86, 12, 26)
# (86, 12, 26): 0.05573529644570959
# (85, 13, 26): 0.05487995807885773
#
# Approximating hitting prob for (86, 7, 13)
# (86, 7, 13): 0.021014348012780067
# (85, 8, 13): 0.022217709614283696
#
# Approximating hitting prob for (86, 13, 14)
# (86, 13, 14): 0.03055245154925246
# (85, 14, 14): 0.025210233251630857
#
# Approximating hitting prob for (86, 13, 28)
# (86, 13, 28): 0.06211460118662582
# (85, 14, 28): 0.05955337600440933
#
# Approximating hitting prob for (86, 13, 42)
# (86, 13, 42): 0.0901225505670295
# (85, 14, 42): 0.0857639773192851
#
# Approximating hitting prob for (86, 13, 56)
# (86, 13, 56): 0.11408066715649622
# (85, 14, 56): 0.11352155727334758
#
# Approximating hitting prob for (86, 13, 70)
# (86, 13, 70): 0.13086962387002107
# (85, 14, 70): 0.12998361688897495
#
# Approximating hitting prob for (86, 13, 98)
# (86, 13, 98): 0.2514053517584159
# (85, 14, 98): 0.2511052354333995
#
# Approximating hitting prob for (86, 14, 15)
# (86, 14, 15): 0.03703980842735078
# (85, 15, 15): 0.03186775671961438
#
# Approximating hitting prob for (86, 14, 30)
# (86, 14, 30): 0.07489229181359557
# (85, 15, 30): 0.07317457544192596
#
# Approximating hitting prob for (86, 14, 45)
# (86, 14, 45): 0.102792201925673
# (85, 15, 45): 0.10208147770639593
#
# Approximating hitting prob for (85, 16, 16)
# (85, 16, 16): 0.033313561828474274
# (84, 17, 16): 0.04739720358096758
#
# Approximating hitting prob for (85, 16, 32)
# (85, 16, 32): 0.07490773755472686
# (84, 17, 32): 0.08341918929545881
#
# Approximating hitting prob for (85, 16, 44)
# (85, 16, 44): 0.10396908368069215
# (84, 17, 44): 0.10789811955371663
# Approximating hitting prob for (85, 16, 64)
# (85, 16, 64): 0.12815678792359633
# (84, 17, 64): 0.13407542103087558
#
# Approximating hitting prob for (85, 16, 96)
# (85, 16, 96): 0.252935549168916
# (84, 17, 96): 0.25732421990941057
#
# Approximating hitting prob for (85, 17, 17)
# (85, 17, 17): 0.03516819571864877
# (84, 18, 17): 0.049765841298040986
#
# Approximating hitting prob for (85, 6, 18)
# (85, 6, 18): 0.02372503111387622
# (84, 7, 18): 0.02821240780832052
#
# Approximating hitting prob for (86, 9, 17)
# (86, 9, 17): 0.02818895191897526
# (85, 10, 17): 0.030862794767875245
#
# Approximating hitting prob for (86, 17, 18)
# (86, 17, 18): 0.04921139967367912
# (85, 18, 18): 0.03656780559661107
#
# Approximating hitting prob for (86, 17, 36)
# (86, 17, 36): 0.09792176379209878
# (85, 18, 36): 0.09536555059577782
#
# Approximating hitting prob for (86, 17, 54)
# (86, 17, 54): 0.12030312724346896
# (85, 18, 54): 0.11936509365940344
#
# Approximating hitting prob for (86, 18, 19)
# (86, 18, 19): 0.0511196285425334
# (85, 19, 19): 0.039122300525874676
#
# Approximating hitting prob for (86, 18, 38)
# (86, 18, 38): 0.10429173325626
# (85, 19, 38): 0.09698430546696313
#
# Approximating hitting prob for (86, 18, 57)
# (86, 18, 57): 0.12611620567200763
# (85, 19, 57): 0.12399870276069785
#
# Approximating hitting prob for (85, 20, 20)
# (85, 20, 20): 0.041149092912210174
# (84, 21, 20): 0.05668169948550863
#
# Approximating hitting prob for (85, 20, 40)
# (85, 20, 40): 0.10038915561035301
# (84, 21, 40): 0.10998584019232309
#
# Approximating hitting prob for (85, 20, 60)
# (85, 20, 60): 0.12668441292066515
# (84, 21, 60): 0.13465930636584575
#
# Approximating hitting prob for (85, 20, 61)
# (85, 20, 61): 0.1313374765576771
# (84, 21, 61): 0.13505666018106052
#
# Approximating hitting prob for (85, 20, 100)
# (85, 20, 100): 0.25903676805977555
# (84, 21, 100): 0.2640633164784255
#
# Approximating hitting prob for (86, 7, 20)
# (86, 7, 20): 0.029420448523404894
# (85, 8, 20): 0.030494377400918704
#
# Approximating hitting prob for (86, 20, 21)
# (86, 20, 21): 0.056046667833509735
# (85, 21, 21): 0.04209857451975869
#
# Approximating hitting prob for (86, 20, 42)
# (86, 20, 42): 0.10939600799671097
# (85, 21, 42): 0.10224999081508575
#
# Approximating hitting prob for (86, 20, 49)
# (86, 20, 49): 0.12216673667264492
# (85, 21, 49): 0.12101078972002775
#
# Approximating hitting prob for (86, 20, 63)
# (86, 20, 63): 0.13386133097960323
# (85, 21, 63): 0.12818509987317825
#
# Approximating hitting prob for (86, 20, 84)
# (86, 20, 84): 0.19563443537129568
# (85, 21, 84): 0.19520248594889875
#
# Approximating hitting prob for (85, 22, 22)
# (85, 22, 22): 0.0591277197202214
# (84, 23, 22): 0.07449986246196359
#
# Approximating hitting prob for (85, 22, 33)
# (85, 22, 33): 0.09750652227057295
# (84, 23, 33): 0.10125472844773463
#
# Approximating hitting prob for (85, 22, 44)
# (85, 22, 44): 0.10768960169668583
# (84, 23, 44): 0.11800324628669322
#
# Approximating hitting prob for (85, 23, 23)
# (85, 23, 23): 0.06039400142156806
# (84, 24, 23): 0.07643313827467295
#
# Approximating hitting prob for (85, 23, 46)
# (85, 23, 46): 0.10987431320044894
# (84, 24, 46): 0.12344265946120485
#
# Approximating hitting prob for (85, 23, 65)
# (85, 23, 65): 0.1759896809898088
# (84, 24, 65): 0.17725067297698907
#
# Approximating hitting prob for (85, 23, 69)
# (85, 23, 69): 0.17493205506305723
# (84, 24, 69): 0.18363207816372287
#
# Approximating hitting prob for (85, 23, 92)
# (85, 23, 92): 0.25844477842799873
# (84, 24, 92): 0.26261038965380856
#
# Approximating hitting prob for (85, 8, 24)
# (85, 8, 24): 0.037401730449007325
# (84, 9, 24): 0.0426557446211982
#
# Approximating hitting prob for (86, 12, 23)
# (86, 12, 23): 0.043283556113870914
# (85, 13, 23): 0.0484799554697686
#
# Approximating hitting prob for (86, 23, 24)
# (86, 23, 24): 0.07529304494674961
# (85, 24, 24): 0.06216283845340904
#
# Approximating hitting prob for (86, 23, 36)
# (86, 23, 36): 0.1024393967070447
# (85, 24, 36): 0.10143956708064929
#
# Approximating hitting prob for (86, 23, 48)
# (86, 23, 48): 0.12216939146669901
# (85, 24, 48): 0.11560356873407536
#
# Approximating hitting prob for (86, 23, 52)
# (86, 23, 52): 0.13043374450787593
# (85, 24, 52): 0.1295006808375851
#
# Approximating hitting prob for (86, 23, 66)
# (86, 23, 66): 0.17796574377615174
# (85, 24, 66): 0.17726309756487038
#
# Approximating hitting prob for (86, 23, 72)
# (86, 23, 72): 0.1831665666820285
# (85, 24, 72): 0.17802472596051264
#
# Approximating hitting prob for (86, 23, 96)
# (86, 23, 96): 0.2619776535664638
# (85, 24, 96): 0.2607088404758469
#
# Approximating hitting prob for (86, 24, 25)
# (86, 24, 25): 0.07764866803524126
# (85, 25, 25): 0.06461689400054516
#
# Approximating hitting prob for (86, 24, 50)
# (86, 24, 50): 0.12578463558829198
# (85, 25, 50): 0.11864798232674989
#
# Approximating hitting prob for (86, 24, 53)
# (86, 24, 53): 0.13178344316339466
# (85, 25, 53): 0.13153552104161698
#
# Approximating hitting prob for (86, 24, 67)
# (86, 24, 67): 0.1793492698693223
# (85, 25, 67): 0.17905517618524922
#
# Approximating hitting prob for (86, 24, 75)
# (86, 24, 75): 0.18968540250053056
# (85, 25, 75): 0.18439746175540841
#
# Approximating hitting prob for (86, 24, 100)
# (86, 24, 100): 0.26433025789815684
# (85, 25, 100): 0.26338329158664886
#
# Approximating hitting prob for (85, 26, 26)
# (85, 26, 26): 0.06784774320697844
# (84, 27, 26): 0.08625638212435893
#
# Approximating hitting prob for (85, 26, 52)
# (85, 26, 52): 0.12324877187188056
# (84, 27, 52): 0.13363957898149204
#
# Approximating hitting prob for (86, 25, 54)
# (86, 25, 54): 0.133633939046108
# (85, 26, 54): 0.13329253431184718
#
# Approximating hitting prob for (86, 25, 78)
# (86, 25, 78): 0.19590343468434449
# (85, 26, 78): 0.1908284366568632
#
# Approximating hitting prob for (86, 9, 26)
# (86, 9, 26): 0.051266498422412154
# (85, 10, 26): 0.052927255300140856
#
# Approximating hitting prob for (86, 26, 27)
# (86, 26, 27): 0.08458763283843969
# (85, 27, 27): 0.06975639242079175
#
# Approximating hitting prob for (86, 26, 54)
# (86, 26, 54): 0.13257827713799206
# (85, 27, 54): 0.12504480438818963
#
# Approximating hitting prob for (86, 26, 55)
# (86, 26, 55): 0.13561428392423183
# (85, 27, 55): 0.13447427055267416
#
# Approximating hitting prob for (86, 26, 81)
# (86, 26, 81): 0.20002022809364176
# (85, 27, 81): 0.19526947325730618
#
# Approximating hitting prob for (85, 28, 28)
# (85, 28, 28): 0.07144818564569251
# (84, 29, 28): 0.11297285558451749
#
# Approximating hitting prob for (85, 28, 42)
# (85, 28, 42): 0.11942977016343288
# (84, 29, 42): 0.1339166379646802
#
# Approximating hitting prob for (85, 28, 56)
# (85, 28, 56): 0.12642810154574982
# (84, 29, 56): 0.18198492370064656
#
# Approximating hitting prob for (85, 28, 70)
# (85, 28, 70): 0.1839506011083745
# (84, 29, 70): 0.19994396233821632
#
# Approximating hitting prob for (85, 28, 84)
# (85, 28, 84): 0.19896249825176116
# (84, 29, 84): 0.2747814903624926
#
# Approximating hitting prob for (85, 29, 29)
# (85, 29, 29): 0.09716156487487015
# (84, 30, 29): 0.11490904165241933
#
# Approximating hitting prob for (85, 6, 30)
# (85, 6, 30): 0.05985750499768087
# (84, 7, 30): 0.06301286390895795
#
# Approximating hitting prob for (86, 10, 29)
# (86, 10, 29): 0.06699636597811574
# (85, 11, 29): 0.06829511199605162
#
# Approximating hitting prob for (85, 30, 30)
# (85, 30, 30): 0.09792560376773353
# (84, 31, 30): 0.11609266332219381
#
# Approximating hitting prob for (85, 30, 60)
# (85, 30, 60): 0.17782904133930166
# (84, 31, 60): 0.1880398681596546
#
# Approximating hitting prob for (85, 30, 72)
# (85, 30, 72): 0.20125980187117717
# (84, 31, 72): 0.2023311039779405
#
# Approximating hitting prob for (85, 30, 90)
# (85, 30, 90): 0.2725654845082402
# (84, 31, 90): 0.2812942530129152
#
# Approximating hitting prob for (85, 31, 31)
# (85, 31, 31): 0.09894190267683374
# (84, 32, 31): 0.11790285092714653
#
# Approximating hitting prob for (85, 31, 59)
# (85, 31, 59): 0.18455641237614032
# (84, 32, 59): 0.1862004130373797
#
# Approximating hitting prob for (85, 31, 62)
# (85, 31, 62): 0.17967782668835597
# (84, 32, 62): 0.19063477486136518
#
# Approximating hitting prob for (85, 31, 73)
# (85, 31, 73): 0.2024321008796799
# (84, 32, 73): 0.2044588932551035
#
# Approximating hitting prob for (85, 31, 93)
# (85, 31, 93): 0.274427097334169
# (84, 32, 93): 0.28525603429219293
#
# Approximating hitting prob for (86, 16, 31)
# (86, 16, 31): 0.07853624099491209
# (85, 17, 31): 0.0819301378379043
#
# Approximating hitting prob for (86, 31, 32)
# (86, 31, 32): 0.11630779954189983
# (85, 32, 32): 0.1017260915936861
# Approximating hitting prob for (86, 31, 48)
# (86, 31, 48): 0.14062356208919094
# (85, 32, 48): 0.14015455774349392
#
# Approximating hitting prob for (86, 31, 60)
# (86, 31, 60): 0.18674944398798732
# (85, 32, 60): 0.18598790141809
#
# Approximating hitting prob for (86, 31, 64)
# (86, 31, 64): 0.1897758854340872
# (85, 32, 64): 0.18300169387260498
#
# Approximating hitting prob for (86, 31, 74)
# (86, 31, 74): 0.20408318594507444
# (85, 32, 74): 0.20405355566381886
#
# Approximating hitting prob for (86, 31, 96)
# (86, 31, 96): 0.2819490908421384
# (85, 32, 96): 0.2793019298344744
#
# Approximating hitting prob for (85, 33, 33)
# (85, 33, 33): 0.10236619875441895
# (84, 34, 33): 0.12181137126304675
#
# Approximating hitting prob for (85, 33, 61)
# (85, 33, 61): 0.18734513049655113
# (84, 34, 61): 0.18940258951466019
#
# Approximating hitting prob for (85, 33, 66)
# (85, 33, 66): 0.18560919679439603
# (84, 34, 66): 0.19654386900891105
#
# Approximating hitting prob for (85, 33, 99)
# (85, 33, 99): 0.2805570960683384
# (84, 34, 99): 0.28915989233000894
#
# Approximating hitting prob for (85, 34, 34)
# (85, 34, 34): 0.10420134496304477
# (84, 35, 34): 0.12301660788581488
#
# Approximating hitting prob for (85, 34, 62)
# (85, 34, 62): 0.18879421068598057
# (84, 35, 62): 0.19197181070595196
#
# Approximating hitting prob for (85, 34, 68)
# (85, 34, 68): 0.1897209221086149
# (84, 35, 68): 0.20183557418202844
#
# Approximating hitting prob for (85, 34, 76)
# (85, 34, 76): 0.2101215827209089
# (84, 35, 76): 0.211994558832721
#
# Approximating hitting prob for (85, 34, 84)
# (85, 34, 84): 0.2199854367325679
# (84, 35, 84): 0.2793489840577032
#
# Approximating hitting prob for (85, 35, 35)
# (85, 35, 35): 0.10512934794655172
# (84, 36, 35): 0.12465643320760383
#
# Approximating hitting prob for (85, 35, 70)
# (85, 35, 70): 0.1931652593820511
# (84, 36, 70): 0.20386135918603435
#
# Approximating hitting prob for (85, 35, 77)
# (85, 35, 77): 0.21133879694778726
# (84, 36, 77): 0.21651941662300564
#
# Approximating hitting prob for (85, 9, 36)
# (85, 9, 36): 0.07394657666291765
# (84, 10, 36): 0.0786633048317895
#
# Approximating hitting prob for (86, 12, 35)
# (86, 12, 35): 0.07890671091635913
# (85, 13, 35): 0.08248762329466461
#
# Approximating hitting prob for (86, 24, 35)
# (86, 24, 35): 0.10252083015257453
# (85, 25, 35): 0.10615222339531745
#
# Approximating hitting prob for (86, 35, 36)
# (86, 35, 36): 0.12339908373101004
# (85, 36, 36): 0.10645546313836535
#
# Approximating hitting prob for (86, 35, 54)
# (86, 35, 54): 0.18345706163485284
# (85, 36, 54): 0.18318767002912603
#
# Approximating hitting prob for (86, 35, 72)
# (86, 35, 72): 0.20292510769285163
# (85, 36, 72): 0.1944575317263074
#
# Approximating hitting prob for (86, 35, 88)
# (86, 35, 88): 0.28416425304903165
# (85, 36, 88): 0.28389893641490754
#
# Approximating hitting prob for (86, 36, 37)
# (86, 36, 37): 0.1247353047690329
# (85, 37, 37): 0.1073453248807049
#
# Approximating hitting prob for (85, 37, 65)
# (85, 37, 65): 0.19544094260500589
# (84, 38, 65): 0.20130049217815293
#
# Approximating hitting prob for (85, 37, 74)
# (85, 37, 74): 0.20287594640760911
# (84, 38, 74): 0.21441601947147534
#
# Approximating hitting prob for (86, 19, 37)
# (86, 19, 37): 0.10431576197774013
# (85, 20, 37): 0.10540768705234695
#
# Approximating hitting prob for (86, 37, 38)
# (86, 37, 38): 0.12590141705024552
# (85, 38, 38): 0.10838214631924002
#
# Approximating hitting prob for (85, 38, 76)
# (85, 38, 76): 0.2049510428628496
# (84, 39, 76): 0.21743070347206808
#
# Approximating hitting prob for (85, 38, 91)
# (85, 38, 91): 0.2862917859629613
# (84, 39, 91): 0.28928116889318106
#
# Approximating hitting prob for (85, 13, 39)
# (85, 13, 39): 0.08321967958768774
# (84, 14, 39): 0.08941115112666644
#
# Approximating hitting prob for (85, 39, 39)
# (85, 39, 39): 0.10973878775044597
# (84, 40, 39): 0.13062551619353177
#
# Approximating hitting prob for (86, 38, 40)
# (86, 38, 40): 0.12996309402671719
# (85, 39, 40): 0.1297690728143414
#
# Approximating hitting prob for (86, 38, 78)
# (86, 38, 78): 0.21599401806314225
# (85, 39, 78): 0.2078972784193581
#
# Approximating hitting prob for (86, 38, 81)
# (86, 38, 81): 0.2216079996167999
# (85, 39, 81): 0.22144163055209065
#
# Approximating hitting prob for (86, 20, 39)
# (86, 20, 39): 0.10650456082702513
# (85, 21, 39): 0.10854620984477452
#
# Approximating hitting prob for (86, 39, 40)
# (86, 39, 40): 0.12874480523272733
# (85, 40, 40): 0.11034321985254757
#
# Approximating hitting prob for (86, 39, 68)
# (86, 39, 68): 0.20633139601232156
# (85, 40, 68): 0.20612332127633895
#
# Approximating hitting prob for (86, 39, 80)
# (86, 39, 80): 0.21921299715926432
# (85, 40, 80): 0.21093436273745234
#
# Approximating hitting prob for (85, 41, 41)
# (85, 41, 41): 0.11074576817130127
# (84, 42, 41): 0.14030419064636815
#
# Approximating hitting prob for (85, 41, 69)
# (85, 41, 69): 0.20758237833749618
# (84, 42, 69): 0.2204878566140893
#
# Approximating hitting prob for (85, 41, 82)
# (85, 41, 82): 0.212955623878152
# (84, 42, 82): 0.23618987619857168
#
# Approximating hitting prob for (85, 41, 83)
# (85, 41, 83): 0.22413532513337073
# (84, 42, 83): 0.2367046893302116
#
# Approximating hitting prob for (85, 41, 96)
# (85, 41, 96): 0.29140131229195115
# (84, 42, 96): 0.30430488373121434
